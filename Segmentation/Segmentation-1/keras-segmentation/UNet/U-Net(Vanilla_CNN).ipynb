# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from skimage.transform import resize
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'Vanilla CNN'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = resize((np.expand_dims(masks, axis=-1)), (masks.shape[0], 64, 64, n_classes), preserve_range=True)
    masks = masks.reshape((masks.shape[0], -1, n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to ../../dataset/train_and_val_data.pickle
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 4096, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 4096, 10)

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_27 (ZeroPadding  (None, 130, 130, 3)  0          ['input_4[0][0]']
#  2D)
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 64  1792        ['zero_padding2d_27[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 64  256        ['conv2d_30[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  max_pooling2d_15 (MaxPooling2D  (None, 64, 64, 64)  0           ['activation_18[0][0]']
#  )
#
#  zero_padding2d_28 (ZeroPadding  (None, 66, 66, 64)  0           ['max_pooling2d_15[0][0]']
#  2D)
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 128)  73856       ['zero_padding2d_28[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 128)  512        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_28[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 32, 32, 128)  0          ['activation_19[0][0]']
#  )
#
#  zero_padding2d_29 (ZeroPadding  (None, 34, 34, 128)  0          ['max_pooling2d_16[0][0]']
#  2D)
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 256)  295168      ['zero_padding2d_29[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 16, 16, 256)  0          ['activation_20[0][0]']
#  )
#
#  zero_padding2d_30 (ZeroPadding  (None, 18, 18, 256)  0          ['max_pooling2d_17[0][0]']
#  2D)
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 256)  590080      ['zero_padding2d_30[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_30[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 8, 8, 256)   0           ['activation_21[0][0]']
#  )
#
#  zero_padding2d_32 (ZeroPadding  (None, 10, 10, 256)  0          ['max_pooling2d_18[0][0]']
#  2D)
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 512)    1180160     ['zero_padding2d_32[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_35[0][0]']
#  ormalization)
#
#  up_sampling2d_9 (UpSampling2D)  (None, 16, 16, 512)  0          ['batch_normalization_32[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 16, 16, 768)  0           ['up_sampling2d_9[0][0]',
#                                                                   'max_pooling2d_17[0][0]']
#
#  zero_padding2d_33 (ZeroPadding  (None, 18, 18, 768)  0          ['concatenate_9[0][0]']
#  2D)
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 256)  1769728     ['zero_padding2d_33[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  up_sampling2d_10 (UpSampling2D  (None, 32, 32, 256)  0          ['batch_normalization_33[0][0]']
#  )
#
#  concatenate_10 (Concatenate)   (None, 32, 32, 384)  0           ['up_sampling2d_10[0][0]',
#                                                                   'max_pooling2d_16[0][0]']
#
#  zero_padding2d_34 (ZeroPadding  (None, 34, 34, 384)  0          ['concatenate_10[0][0]']
#  2D)
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 128)  442496      ['zero_padding2d_34[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 128)  512        ['conv2d_37[0][0]']
#  ormalization)
#
#  up_sampling2d_11 (UpSampling2D  (None, 64, 64, 128)  0          ['batch_normalization_34[0][0]']
#  )
#
#  concatenate_11 (Concatenate)   (None, 64, 64, 192)  0           ['up_sampling2d_11[0][0]',
#                                                                   'max_pooling2d_15[0][0]']
#
#  zero_padding2d_35 (ZeroPadding  (None, 66, 66, 192)  0          ['concatenate_11[0][0]']
#  2D)
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 64)   110656      ['zero_padding2d_35[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 64)  256         ['conv2d_38[0][0]']
#  ormalization)
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 10)   5770        ['batch_normalization_35[0][0]']
#
#  reshape_3 (Reshape)            (None, 4096, 10)     0           ['conv2d_39[0][0]']
#
#  activation_23 (Activation)     (None, 4096, 10)     0           ['reshape_3[0][0]']
#
# ==================================================================================================
# Total params: 4,476,362
# Trainable params: 4,473,034
# Non-trainable params: 3,328
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 11s 38ms/step - loss: 0.9959 - iou_score: 0.4104 - val_loss: 0.9799 - val_iou_score: 0.3345
# Epoch 2/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.6668 - iou_score: 0.5046 - val_loss: 1.7861 - val_iou_score: 0.0856
# Epoch 3/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.6149 - iou_score: 0.5422 - val_loss: 0.7671 - val_iou_score: 0.4354
# Epoch 4/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.6003 - iou_score: 0.5537 - val_loss: 0.9015 - val_iou_score: 0.4304
# Epoch 5/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.5637 - iou_score: 0.5820 - val_loss: 0.6726 - val_iou_score: 0.5253
# Epoch 6/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.5331 - iou_score: 0.6045 - val_loss: 0.6354 - val_iou_score: 0.5651
# Epoch 7/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.5156 - iou_score: 0.6184 - val_loss: 0.6869 - val_iou_score: 0.5229
# Epoch 8/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.5004 - iou_score: 0.6306 - val_loss: 0.9929 - val_iou_score: 0.4415
# Epoch 9/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.4938 - iou_score: 0.6350 - val_loss: 0.5721 - val_iou_score: 0.5908
# Epoch 10/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.4671 - iou_score: 0.6549 - val_loss: 0.6873 - val_iou_score: 0.5258
# Epoch 11/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4563 - iou_score: 0.6631 - val_loss: 1.2762 - val_iou_score: 0.2502
# Epoch 12/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.4431 - iou_score: 0.6732 - val_loss: 0.7195 - val_iou_score: 0.4937
# Epoch 13/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4457 - iou_score: 0.6721 - val_loss: 0.6236 - val_iou_score: 0.5821
# Epoch 14/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4225 - iou_score: 0.6883 - val_loss: 0.7225 - val_iou_score: 0.5263
# Epoch 15/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4056 - iou_score: 0.7002 - val_loss: 0.7878 - val_iou_score: 0.4788
# Epoch 16/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3979 - iou_score: 0.7068 - val_loss: 0.5053 - val_iou_score: 0.6498
# Epoch 17/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.3964 - iou_score: 0.7079 - val_loss: 0.5707 - val_iou_score: 0.5899
# Epoch 18/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3837 - iou_score: 0.7170 - val_loss: 0.5035 - val_iou_score: 0.6412
# Epoch 19/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.3696 - iou_score: 0.7278 - val_loss: 0.4760 - val_iou_score: 0.6678
# Epoch 20/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.3691 - iou_score: 0.7274 - val_loss: 0.6607 - val_iou_score: 0.5414
# Epoch 21/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3602 - iou_score: 0.7347 - val_loss: 0.7157 - val_iou_score: 0.5807
# Epoch 22/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3397 - iou_score: 0.7495 - val_loss: 1.2124 - val_iou_score: 0.2749
# Epoch 23/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3369 - iou_score: 0.7519 - val_loss: 0.6757 - val_iou_score: 0.5476
# Epoch 24/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.3250 - iou_score: 0.7602 - val_loss: 0.5023 - val_iou_score: 0.6407
# Epoch 25/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.3274 - iou_score: 0.7595 - val_loss: 0.9567 - val_iou_score: 0.3878
# Epoch 26/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3106 - iou_score: 0.7714 - val_loss: 0.5429 - val_iou_score: 0.6238
# Epoch 27/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.3078 - iou_score: 0.7742 - val_loss: 0.9491 - val_iou_score: 0.3808
# Epoch 28/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3072 - iou_score: 0.7754 - val_loss: 0.6245 - val_iou_score: 0.5708
# Epoch 29/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.2832 - iou_score: 0.7920 - val_loss: 0.6798 - val_iou_score: 0.5365
# Epoch 30/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2844 - iou_score: 0.7916 - val_loss: 0.9264 - val_iou_score: 0.4099
# Epoch 31/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2765 - iou_score: 0.7967 - val_loss: 0.4664 - val_iou_score: 0.6666
# Epoch 32/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2766 - iou_score: 0.7976 - val_loss: 0.4599 - val_iou_score: 0.6781
# Epoch 33/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2617 - iou_score: 0.8081 - val_loss: 0.4540 - val_iou_score: 0.6831
# Epoch 34/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2507 - iou_score: 0.8170 - val_loss: 0.7121 - val_iou_score: 0.5809
# Epoch 35/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2517 - iou_score: 0.8164 - val_loss: 0.7415 - val_iou_score: 0.5253
# Epoch 36/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.2540 - iou_score: 0.8142 - val_loss: 0.5046 - val_iou_score: 0.6490
# Epoch 37/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.2365 - iou_score: 0.8275 - val_loss: 0.4876 - val_iou_score: 0.6759
# Epoch 38/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.2228 - iou_score: 0.8368 - val_loss: 0.5474 - val_iou_score: 0.6221
# Epoch 39/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2310 - iou_score: 0.8318 - val_loss: 1.0289 - val_iou_score: 0.3745
# Epoch 40/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2190 - iou_score: 0.8405 - val_loss: 0.6288 - val_iou_score: 0.5721
# Epoch 41/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2157 - iou_score: 0.8424 - val_loss: 0.4543 - val_iou_score: 0.6813
# Epoch 42/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.2131 - iou_score: 0.8451 - val_loss: 0.3921 - val_iou_score: 0.7247
# Epoch 43/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.2080 - iou_score: 0.8482 - val_loss: 0.5299 - val_iou_score: 0.6427
# Epoch 44/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2058 - iou_score: 0.8503 - val_loss: 0.4417 - val_iou_score: 0.6966
# Epoch 45/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1932 - iou_score: 0.8592 - val_loss: 0.4935 - val_iou_score: 0.6553
# Epoch 46/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1974 - iou_score: 0.8571 - val_loss: 0.4526 - val_iou_score: 0.6934
# Epoch 47/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1928 - iou_score: 0.8601 - val_loss: 0.4067 - val_iou_score: 0.7128
# Epoch 48/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1786 - iou_score: 0.8700 - val_loss: 0.4416 - val_iou_score: 0.6905
# Epoch 49/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1813 - iou_score: 0.8686 - val_loss: 0.4202 - val_iou_score: 0.7152
# Epoch 50/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1775 - iou_score: 0.8711 - val_loss: 0.5388 - val_iou_score: 0.6444
# Epoch 51/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1810 - iou_score: 0.8687 - val_loss: 0.4480 - val_iou_score: 0.6868
# Epoch 52/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1850 - iou_score: 0.8662 - val_loss: 0.6347 - val_iou_score: 0.5713
# Epoch 53/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1695 - iou_score: 0.8770 - val_loss: 0.4784 - val_iou_score: 0.6683
# Epoch 54/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1723 - iou_score: 0.8755 - val_loss: 0.4078 - val_iou_score: 0.7177
# Epoch 55/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1641 - iou_score: 0.8811 - val_loss: 0.4191 - val_iou_score: 0.7137
# Epoch 56/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1693 - iou_score: 0.8775 - val_loss: 0.5936 - val_iou_score: 0.6240
# Epoch 57/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1636 - iou_score: 0.8815 - val_loss: 0.4302 - val_iou_score: 0.7001
# Epoch 58/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1603 - iou_score: 0.8836 - val_loss: 0.5759 - val_iou_score: 0.6312
# Epoch 59/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1578 - iou_score: 0.8855 - val_loss: 0.5051 - val_iou_score: 0.6604
# Epoch 60/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1581 - iou_score: 0.8856 - val_loss: 0.5895 - val_iou_score: 0.6103
# Epoch 61/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1581 - iou_score: 0.8855 - val_loss: 0.4162 - val_iou_score: 0.7150
# Epoch 62/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1571 - iou_score: 0.8863 - val_loss: 0.6097 - val_iou_score: 0.5820
# Epoch 63/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1859 - iou_score: 0.8663 - val_loss: 0.5086 - val_iou_score: 0.6575
# Epoch 64/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1623 - iou_score: 0.8825 - val_loss: 0.4490 - val_iou_score: 0.6955
# Epoch 65/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1529 - iou_score: 0.8891 - val_loss: 0.3988 - val_iou_score: 0.7258
# Epoch 66/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1494 - iou_score: 0.8913 - val_loss: 0.3990 - val_iou_score: 0.7259
# Epoch 67/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1480 - iou_score: 0.8925 - val_loss: 0.4424 - val_iou_score: 0.6994
# Epoch 68/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1699 - iou_score: 0.8778 - val_loss: 0.5285 - val_iou_score: 0.6450
# Epoch 69/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1445 - iou_score: 0.8949 - val_loss: 0.4133 - val_iou_score: 0.7125
# Epoch 70/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1392 - iou_score: 0.8985 - val_loss: 0.3757 - val_iou_score: 0.7441
# Epoch 71/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1412 - iou_score: 0.8973 - val_loss: 0.4651 - val_iou_score: 0.6903
# Epoch 72/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1403 - iou_score: 0.8977 - val_loss: 0.3604 - val_iou_score: 0.7486
# Epoch 73/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1491 - iou_score: 0.8925 - val_loss: 0.7317 - val_iou_score: 0.5304
# Epoch 74/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1380 - iou_score: 0.8996 - val_loss: 0.5839 - val_iou_score: 0.6146
# Epoch 75/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1566 - iou_score: 0.8875 - val_loss: 0.8727 - val_iou_score: 0.4526
# Epoch 76/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1472 - iou_score: 0.8936 - val_loss: 0.4172 - val_iou_score: 0.7221
# Epoch 77/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1385 - iou_score: 0.8996 - val_loss: 0.5791 - val_iou_score: 0.6055
# Epoch 78/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1378 - iou_score: 0.9001 - val_loss: 0.3961 - val_iou_score: 0.7273
# Epoch 79/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1325 - iou_score: 0.9032 - val_loss: 0.3755 - val_iou_score: 0.7446
# Epoch 80/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1354 - iou_score: 0.9014 - val_loss: 0.3950 - val_iou_score: 0.7269
# Epoch 81/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1345 - iou_score: 0.9021 - val_loss: 0.4125 - val_iou_score: 0.7214
# Epoch 82/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1350 - iou_score: 0.9019 - val_loss: 0.4030 - val_iou_score: 0.7231
# Epoch 83/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1361 - iou_score: 0.9012 - val_loss: 0.3958 - val_iou_score: 0.7277
# Epoch 84/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1423 - iou_score: 0.8971 - val_loss: 0.3846 - val_iou_score: 0.7405
# Epoch 85/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1293 - iou_score: 0.9057 - val_loss: 0.3697 - val_iou_score: 0.7519
# Epoch 86/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1364 - iou_score: 0.9013 - val_loss: 0.4888 - val_iou_score: 0.6737
# Epoch 87/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1321 - iou_score: 0.9039 - val_loss: 0.3773 - val_iou_score: 0.7456
# Epoch 88/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1291 - iou_score: 0.9060 - val_loss: 0.3790 - val_iou_score: 0.7432
# Epoch 89/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1294 - iou_score: 0.9059 - val_loss: 0.3737 - val_iou_score: 0.7475
# Epoch 90/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1320 - iou_score: 0.9040 - val_loss: 0.4627 - val_iou_score: 0.6873
# Epoch 91/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1348 - iou_score: 0.9021 - val_loss: 0.4138 - val_iou_score: 0.7203
# Epoch 92/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1283 - iou_score: 0.9068 - val_loss: 0.3792 - val_iou_score: 0.7385
# Epoch 93/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1252 - iou_score: 0.9087 - val_loss: 0.3695 - val_iou_score: 0.7460
# Epoch 94/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1275 - iou_score: 0.9073 - val_loss: 0.4283 - val_iou_score: 0.7100
# Epoch 95/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1254 - iou_score: 0.9085 - val_loss: 0.3763 - val_iou_score: 0.7471
# Epoch 96/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1250 - iou_score: 0.9089 - val_loss: 0.3808 - val_iou_score: 0.7411
# Epoch 97/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1233 - iou_score: 0.9100 - val_loss: 0.4021 - val_iou_score: 0.7309
# Epoch 98/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1277 - iou_score: 0.9074 - val_loss: 0.3776 - val_iou_score: 0.7434
# Epoch 99/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1211 - iou_score: 0.9113 - val_loss: 0.4016 - val_iou_score: 0.7307
# Epoch 100/100
# 181/181 [==============================] - 5s 27ms/step - loss: 0.1386 - iou_score: 0.9001 - val_loss: 0.6200 - val_iou_score: 0.6075

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 4096, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  60.08443236351013 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)

print(y_pred.shape)
print(test_masks.shape) 

predicted_masks = y_pred.reshape((y_pred.shape[0], 64, 64, n_classes))
test_masks = test_masks.reshape((test_masks.shape[0], 64, 64, n_classes))

print(predicted_masks.shape)
print(test_masks.shape) 

predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 1s 41ms/step
# (448, 4096, 10)
# (448, 4096, 10)
# (448, 64, 64, 10)
# (448, 64, 64, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.37934068
# IoU for each class:
# Building Flooded: 0.3572391867637634
# Building Non-Flooded: 0.44563058018684387
# Road Flooded: 0.20109382271766663
# Road Non-Flooded: 0.43866100907325745
# Water: 0.5350022912025452
# Tree: 0.6003021001815796
# Vehicle: 0.20259037613868713
# Pool: 0.11213517934083939
# Grass: 0.7344468235969543
# Mean IoU (excluding Background): 0.40301123

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (64, 64)
# Predicted Mask Shape: (64, 64)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (64, 64)
# Predicted Mask Shape: (64, 64)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (64, 64)
# Predicted Mask Shape: (64, 64)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (64, 64)
# Predicted Mask Shape: (64, 64)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (64, 64)
# Predicted Mask Shape: (64, 64)
