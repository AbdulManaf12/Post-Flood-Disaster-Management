# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from skimage.transform import resize
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 4
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'VGG-16'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], -1, n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')
# Out:
# 100%|██████████| 1445/1445 [07:37<00:00,  3.16it/s]
# TRAIN: Images loaded: 1445
# TRAIN: Masks loaded: 1445
# 100%|██████████| 450/450 [02:31<00:00,  2.98it/s]
# VAL: Images loaded: 450
# VAL: Masks loaded: 450

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to ../../dataset/train_and_val_data.pickle
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 16384, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 16384, 10)

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_3[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv3[0][0]']
#
#  zero_padding2d_7 (ZeroPadding2  (None, 10, 10, 512)  0          ['block4_pool[0][0]']
#  D)
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 512)    2359808     ['zero_padding2d_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 512)   2048        ['conv2d_6[0][0]']
#  rmalization)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 16, 16, 512)  0          ['batch_normalization_5[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 16, 16, 768)  0           ['up_sampling2d_4[0][0]',
#                                                                   'block3_pool[0][0]']
#
#  zero_padding2d_8 (ZeroPadding2  (None, 18, 18, 768)  0          ['concatenate_3[0][0]']
#  D)
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  1769728     ['zero_padding2d_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 256)  0          ['batch_normalization_6[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 384)  0           ['up_sampling2d_5[0][0]',
#                                                                   'block2_pool[0][0]']
#
#  zero_padding2d_9 (ZeroPadding2  (None, 34, 34, 384)  0          ['concatenate_4[0][0]']
#  D)
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 128)  442496      ['zero_padding2d_9[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 128)  0          ['batch_normalization_7[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 192)  0           ['up_sampling2d_6[0][0]',
#                                                                   'block1_pool[0][0]']
#
#  zero_padding2d_10 (ZeroPadding  (None, 66, 66, 192)  0          ['concatenate_5[0][0]']
#  2D)
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 64)   110656      ['zero_padding2d_10[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 64  0          ['batch_normalization_8[0][0]']
#                                 )
#
#  zero_padding2d_11 (ZeroPadding  (None, 130, 130, 64  0          ['up_sampling2d_7[0][0]']
#  2D)                            )
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 12  73856       ['zero_padding2d_11[0][0]']
#                                 8)
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 12  512        ['conv2d_10[0][0]']
#  rmalization)                   8)
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 10  11530       ['batch_normalization_9[0][0]']
#                                 )
#
#  reshape_1 (Reshape)            (None, 16384, 10)    0           ['conv2d_11[0][0]']
#
#  activation_50 (Activation)     (None, 16384, 10)    0           ['reshape_1[0][0]']
#
# ==================================================================================================
# Total params: 12,407,690
# Trainable params: 12,405,514
# Non-trainable params: 2,176
# __________________________________________________________________________________________________

# %%
(None, model.input_shape[1]*model.input_shape[2], model.input_shape[3]), model.output_shape
# Out:
# ((None, 16384, 3), (None, 16384, 10))

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 362/362 [==============================] - 23s 48ms/step - loss: 0.8833 - iou_score: 0.3853 - val_loss: 2.4316 - val_iou_score: 0.4185
# Epoch 2/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.7586 - iou_score: 0.4456 - val_loss: 0.8906 - val_iou_score: 0.4434
# Epoch 3/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.7423 - iou_score: 0.4570 - val_loss: 2.3423 - val_iou_score: 0.1361
# Epoch 4/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.7295 - iou_score: 0.4646 - val_loss: 1.0411 - val_iou_score: 0.4486
# Epoch 5/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.7202 - iou_score: 0.4719 - val_loss: 2.3927 - val_iou_score: 0.1015
# Epoch 6/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.7113 - iou_score: 0.4774 - val_loss: 3.9520 - val_iou_score: 0.1087
# Epoch 7/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6993 - iou_score: 0.4865 - val_loss: 1.2505 - val_iou_score: 0.4197
# Epoch 8/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6923 - iou_score: 0.4919 - val_loss: 3.1073 - val_iou_score: 0.1506
# Epoch 9/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6848 - iou_score: 0.4972 - val_loss: 1.0911 - val_iou_score: 0.4310
# Epoch 10/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.6831 - iou_score: 0.4987 - val_loss: 2.4030 - val_iou_score: 0.0878
# Epoch 11/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.6795 - iou_score: 0.5023 - val_loss: 1.4593 - val_iou_score: 0.4475
# Epoch 12/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6647 - iou_score: 0.5117 - val_loss: 0.6349 - val_iou_score: 0.5491
# Epoch 13/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6563 - iou_score: 0.5157 - val_loss: 0.9902 - val_iou_score: 0.4410
# Epoch 14/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6590 - iou_score: 0.5152 - val_loss: 0.8472 - val_iou_score: 0.4827
# Epoch 15/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.6566 - iou_score: 0.5180 - val_loss: 2.6181 - val_iou_score: 0.0831
# Epoch 16/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6453 - iou_score: 0.5257 - val_loss: 0.9937 - val_iou_score: 0.3685
# Epoch 17/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6349 - iou_score: 0.5335 - val_loss: 0.6396 - val_iou_score: 0.5492
# Epoch 18/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6286 - iou_score: 0.5373 - val_loss: 1.0230 - val_iou_score: 0.3361
# Epoch 19/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6191 - iou_score: 0.5443 - val_loss: 0.6327 - val_iou_score: 0.5648
# Epoch 20/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6120 - iou_score: 0.5510 - val_loss: 1.0992 - val_iou_score: 0.4369
# Epoch 21/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.6074 - iou_score: 0.5542 - val_loss: 0.7419 - val_iou_score: 0.5322
# Epoch 22/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.6042 - iou_score: 0.5553 - val_loss: 0.6646 - val_iou_score: 0.5393
# Epoch 23/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.6001 - iou_score: 0.5587 - val_loss: 0.7610 - val_iou_score: 0.4826
# Epoch 24/100
# 362/362 [==============================] - 15s 40ms/step - loss: 0.5973 - iou_score: 0.5603 - val_loss: 1.1572 - val_iou_score: 0.2608
# Epoch 25/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.5946 - iou_score: 0.5639 - val_loss: 0.9672 - val_iou_score: 0.3519
# Epoch 26/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5771 - iou_score: 0.5766 - val_loss: 0.6222 - val_iou_score: 0.5853
# Epoch 27/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.5758 - iou_score: 0.5781 - val_loss: 0.8079 - val_iou_score: 0.4990
# Epoch 28/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5728 - iou_score: 0.5800 - val_loss: 0.9001 - val_iou_score: 0.4067
# Epoch 29/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5623 - iou_score: 0.5873 - val_loss: 0.6266 - val_iou_score: 0.5996
# Epoch 30/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.5645 - iou_score: 0.5850 - val_loss: 0.7997 - val_iou_score: 0.5013
# Epoch 31/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5516 - iou_score: 0.5960 - val_loss: 0.5916 - val_iou_score: 0.5732
# Epoch 32/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5422 - iou_score: 0.6032 - val_loss: 0.5760 - val_iou_score: 0.6084
# Epoch 33/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.5388 - iou_score: 0.6046 - val_loss: 0.5288 - val_iou_score: 0.6212
# Epoch 34/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5308 - iou_score: 0.6122 - val_loss: 0.5963 - val_iou_score: 0.5823
# Epoch 35/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5189 - iou_score: 0.6198 - val_loss: 0.7722 - val_iou_score: 0.5036
# Epoch 36/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5098 - iou_score: 0.6282 - val_loss: 0.5714 - val_iou_score: 0.6054
# Epoch 37/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5005 - iou_score: 0.6350 - val_loss: 0.4857 - val_iou_score: 0.6567
# Epoch 38/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.5029 - iou_score: 0.6327 - val_loss: 0.4800 - val_iou_score: 0.6571
# Epoch 39/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4887 - iou_score: 0.6437 - val_loss: 0.4505 - val_iou_score: 0.6782
# Epoch 40/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4798 - iou_score: 0.6507 - val_loss: 0.5219 - val_iou_score: 0.6345
# Epoch 41/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4776 - iou_score: 0.6534 - val_loss: 0.9684 - val_iou_score: 0.3691
# Epoch 42/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4678 - iou_score: 0.6602 - val_loss: 0.4962 - val_iou_score: 0.6543
# Epoch 43/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4606 - iou_score: 0.6646 - val_loss: 0.5233 - val_iou_score: 0.6258
# Epoch 44/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4481 - iou_score: 0.6743 - val_loss: 0.4880 - val_iou_score: 0.6507
# Epoch 45/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4418 - iou_score: 0.6800 - val_loss: 0.4916 - val_iou_score: 0.6436
# Epoch 46/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4300 - iou_score: 0.6875 - val_loss: 0.4353 - val_iou_score: 0.6919
# Epoch 47/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4206 - iou_score: 0.6942 - val_loss: 0.4830 - val_iou_score: 0.6601
# Epoch 48/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4158 - iou_score: 0.6984 - val_loss: 0.4465 - val_iou_score: 0.6821
# Epoch 49/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.4053 - iou_score: 0.7074 - val_loss: 0.5179 - val_iou_score: 0.6355
# Epoch 50/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3959 - iou_score: 0.7134 - val_loss: 0.4166 - val_iou_score: 0.7048
# Epoch 51/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3916 - iou_score: 0.7161 - val_loss: 0.4779 - val_iou_score: 0.6643
# Epoch 52/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3865 - iou_score: 0.7198 - val_loss: 0.4597 - val_iou_score: 0.6769
# Epoch 53/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3835 - iou_score: 0.7232 - val_loss: 0.3806 - val_iou_score: 0.7247
# Epoch 54/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.3735 - iou_score: 0.7304 - val_loss: 0.4634 - val_iou_score: 0.6731
# Epoch 55/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3580 - iou_score: 0.7407 - val_loss: 0.4111 - val_iou_score: 0.7055
# Epoch 56/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3415 - iou_score: 0.7530 - val_loss: 0.4003 - val_iou_score: 0.7143
# Epoch 57/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3508 - iou_score: 0.7479 - val_loss: 0.3699 - val_iou_score: 0.7332
# Epoch 58/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3403 - iou_score: 0.7550 - val_loss: 0.4099 - val_iou_score: 0.7100
# Epoch 59/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3271 - iou_score: 0.7652 - val_loss: 0.3901 - val_iou_score: 0.7253
# Epoch 60/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3320 - iou_score: 0.7615 - val_loss: 0.3830 - val_iou_score: 0.7270
# Epoch 61/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3113 - iou_score: 0.7761 - val_loss: 0.3782 - val_iou_score: 0.7283
# Epoch 62/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3126 - iou_score: 0.7751 - val_loss: 0.3902 - val_iou_score: 0.7217
# Epoch 63/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.3155 - iou_score: 0.7737 - val_loss: 0.4055 - val_iou_score: 0.7145
# Epoch 64/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2913 - iou_score: 0.7893 - val_loss: 0.3759 - val_iou_score: 0.7350
# Epoch 65/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2917 - iou_score: 0.7902 - val_loss: 0.3614 - val_iou_score: 0.7409
# Epoch 66/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2860 - iou_score: 0.7948 - val_loss: 0.4035 - val_iou_score: 0.7201
# Epoch 67/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2883 - iou_score: 0.7918 - val_loss: 0.3654 - val_iou_score: 0.7398
# Epoch 68/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2784 - iou_score: 0.7988 - val_loss: 0.4031 - val_iou_score: 0.7162
# Epoch 69/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.2694 - iou_score: 0.8052 - val_loss: 0.3577 - val_iou_score: 0.7480
# Epoch 70/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2624 - iou_score: 0.8120 - val_loss: 0.3643 - val_iou_score: 0.7403
# Epoch 71/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2561 - iou_score: 0.8174 - val_loss: 0.3578 - val_iou_score: 0.7448
# Epoch 72/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.2476 - iou_score: 0.8227 - val_loss: 0.3535 - val_iou_score: 0.7506
# Epoch 73/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2591 - iou_score: 0.8141 - val_loss: 0.3929 - val_iou_score: 0.7270
# Epoch 74/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2552 - iou_score: 0.8167 - val_loss: 0.3712 - val_iou_score: 0.7414
# Epoch 75/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.2389 - iou_score: 0.8305 - val_loss: 0.3548 - val_iou_score: 0.7511
# Epoch 76/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2266 - iou_score: 0.8383 - val_loss: 0.3514 - val_iou_score: 0.7537
# Epoch 77/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2328 - iou_score: 0.8335 - val_loss: 0.3471 - val_iou_score: 0.7553
# Epoch 78/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2257 - iou_score: 0.8398 - val_loss: 0.3673 - val_iou_score: 0.7471
# Epoch 79/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2132 - iou_score: 0.8486 - val_loss: 0.3721 - val_iou_score: 0.7429
# Epoch 80/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2146 - iou_score: 0.8475 - val_loss: 0.3434 - val_iou_score: 0.7603
# Epoch 81/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2156 - iou_score: 0.8463 - val_loss: 0.3345 - val_iou_score: 0.7644
# Epoch 82/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.2057 - iou_score: 0.8536 - val_loss: 0.3400 - val_iou_score: 0.7629
# Epoch 83/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1996 - iou_score: 0.8577 - val_loss: 0.3443 - val_iou_score: 0.7583
# Epoch 84/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.2157 - iou_score: 0.8464 - val_loss: 0.3783 - val_iou_score: 0.7450
# Epoch 85/100
# 362/362 [==============================] - 14s 39ms/step - loss: 0.2054 - iou_score: 0.8542 - val_loss: 0.3425 - val_iou_score: 0.7609
# Epoch 86/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1905 - iou_score: 0.8638 - val_loss: 0.3815 - val_iou_score: 0.7381
# Epoch 87/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1878 - iou_score: 0.8667 - val_loss: 0.3397 - val_iou_score: 0.7627
# Epoch 88/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1800 - iou_score: 0.8719 - val_loss: 0.3304 - val_iou_score: 0.7684
# Epoch 89/100
# 362/362 [==============================] - 14s 37ms/step - loss: 0.2005 - iou_score: 0.8578 - val_loss: 0.3441 - val_iou_score: 0.7622
# Epoch 90/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1778 - iou_score: 0.8735 - val_loss: 0.3585 - val_iou_score: 0.7543
# Epoch 91/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1841 - iou_score: 0.8693 - val_loss: 0.3396 - val_iou_score: 0.7678
# Epoch 92/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1855 - iou_score: 0.8679 - val_loss: 0.3433 - val_iou_score: 0.7632
# Epoch 93/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1754 - iou_score: 0.8749 - val_loss: 0.3292 - val_iou_score: 0.7717
# Epoch 94/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1630 - iou_score: 0.8840 - val_loss: 0.3461 - val_iou_score: 0.7607
# Epoch 95/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1721 - iou_score: 0.8775 - val_loss: 0.3488 - val_iou_score: 0.7602
# Epoch 96/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1645 - iou_score: 0.8829 - val_loss: 0.3409 - val_iou_score: 0.7682
# Epoch 97/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1703 - iou_score: 0.8793 - val_loss: 0.3554 - val_iou_score: 0.7532
# Epoch 98/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1656 - iou_score: 0.8826 - val_loss: 0.3792 - val_iou_score: 0.7437
# Epoch 99/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1979 - iou_score: 0.8604 - val_loss: 0.3556 - val_iou_score: 0.7549
# Epoch 100/100
# 362/362 [==============================] - 14s 38ms/step - loss: 0.1578 - iou_score: 0.8876 - val_loss: 0.3394 - val_iou_score: 0.7671

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 16384, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  75.55490732192993 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)

print(y_pred.shape)
print(test_masks.shape) 

predicted_masks = reverse_masks_shape(y_pred)
test_masks = reverse_masks_shape(test_masks)

print(predicted_masks.shape)
print(test_masks.shape) 

predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 1s 60ms/step
# (448, 16384, 10)
# (448, 16384, 10)
# (448, 128, 128, 10)
# (448, 128, 128, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.5514778
# IoU for each class:
# Building Flooded: 0.6002573370933533
# Building Non-Flooded: 0.6081405282020569
# Road Flooded: 0.4915373623371124
# Road Non-Flooded: 0.7384905815124512
# Water: 0.7193410992622375
# Tree: 0.7083567976951599
# Vehicle: 0.19287261366844177
# Pool: 0.3383222222328186
# Grass: 0.8311336636543274
# Mean IoU (excluding Background): 0.5809391

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
