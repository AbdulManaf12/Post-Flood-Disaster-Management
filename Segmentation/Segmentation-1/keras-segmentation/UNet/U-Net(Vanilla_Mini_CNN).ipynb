# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'Vanilla Mini CNN'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], -1, n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to ../../dataset/train_and_val_data.pickle
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 16384, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 16384, 10)

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 32  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 64)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 128)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['dropout_2[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 128)  0           ['conv2d_5[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 192)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   110656      ['concatenate[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 64)   0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   36928       ['dropout_3[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 64  0          ['conv2d_7[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 32  27680       ['concatenate_1[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 128, 128, 32  0           ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 32  9248        ['dropout_4[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 10  330         ['conv2d_9[0][0]']
#                                 )
#
#  reshape (Reshape)              (None, 16384, 10)    0           ['conv2d_10[0][0]']
#
#  activation (Activation)        (None, 16384, 10)    0           ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 471,850
# Trainable params: 471,850
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 11s 36ms/step - loss: 0.9296 - iou_score: 0.3553 - val_loss: 0.8579 - val_iou_score: 0.3848
# Epoch 2/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.8619 - iou_score: 0.3765 - val_loss: 0.8873 - val_iou_score: 0.4242
# Epoch 3/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.8267 - iou_score: 0.4012 - val_loss: 0.7799 - val_iou_score: 0.4424
# Epoch 4/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.8004 - iou_score: 0.4143 - val_loss: 0.8046 - val_iou_score: 0.4005
# Epoch 5/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.7838 - iou_score: 0.4267 - val_loss: 0.7493 - val_iou_score: 0.4656
# Epoch 6/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.7415 - iou_score: 0.4550 - val_loss: 0.7041 - val_iou_score: 0.4809
# Epoch 7/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.7023 - iou_score: 0.4799 - val_loss: 0.6530 - val_iou_score: 0.5118
# Epoch 8/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.6597 - iou_score: 0.5097 - val_loss: 0.6704 - val_iou_score: 0.5208
# Epoch 9/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.6496 - iou_score: 0.5162 - val_loss: 0.5956 - val_iou_score: 0.5623
# Epoch 10/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.6200 - iou_score: 0.5385 - val_loss: 0.6141 - val_iou_score: 0.5336
# Epoch 11/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.5963 - iou_score: 0.5547 - val_loss: 0.5665 - val_iou_score: 0.5834
# Epoch 12/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.5832 - iou_score: 0.5646 - val_loss: 0.5368 - val_iou_score: 0.6004
# Epoch 13/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.5639 - iou_score: 0.5791 - val_loss: 0.5350 - val_iou_score: 0.6083
# Epoch 14/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5625 - iou_score: 0.5806 - val_loss: 0.5120 - val_iou_score: 0.6217
# Epoch 15/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5409 - iou_score: 0.5966 - val_loss: 0.5041 - val_iou_score: 0.6282
# Epoch 16/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.5220 - iou_score: 0.6110 - val_loss: 0.4803 - val_iou_score: 0.6445
# Epoch 17/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.5045 - iou_score: 0.6245 - val_loss: 0.4754 - val_iou_score: 0.6476
# Epoch 18/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4950 - iou_score: 0.6309 - val_loss: 0.5047 - val_iou_score: 0.6310
# Epoch 19/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4911 - iou_score: 0.6341 - val_loss: 0.4729 - val_iou_score: 0.6460
# Epoch 20/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4926 - iou_score: 0.6336 - val_loss: 0.5059 - val_iou_score: 0.6242
# Epoch 21/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4733 - iou_score: 0.6476 - val_loss: 0.4514 - val_iou_score: 0.6670
# Epoch 22/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4605 - iou_score: 0.6567 - val_loss: 0.4716 - val_iou_score: 0.6499
# Epoch 23/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4542 - iou_score: 0.6623 - val_loss: 0.4322 - val_iou_score: 0.6794
# Epoch 24/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4430 - iou_score: 0.6700 - val_loss: 0.4546 - val_iou_score: 0.6666
# Epoch 25/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4434 - iou_score: 0.6703 - val_loss: 0.4338 - val_iou_score: 0.6808
# Epoch 26/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4386 - iou_score: 0.6732 - val_loss: 0.4189 - val_iou_score: 0.6940
# Epoch 27/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4359 - iou_score: 0.6753 - val_loss: 0.4495 - val_iou_score: 0.6653
# Epoch 28/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4211 - iou_score: 0.6860 - val_loss: 0.4031 - val_iou_score: 0.6991
# Epoch 29/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4284 - iou_score: 0.6812 - val_loss: 0.4504 - val_iou_score: 0.6672
# Epoch 30/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4151 - iou_score: 0.6905 - val_loss: 0.3932 - val_iou_score: 0.7112
# Epoch 31/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4041 - iou_score: 0.6985 - val_loss: 0.4012 - val_iou_score: 0.7073
# Epoch 32/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4030 - iou_score: 0.6998 - val_loss: 0.4168 - val_iou_score: 0.6949
# Epoch 33/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4058 - iou_score: 0.6974 - val_loss: 0.4183 - val_iou_score: 0.6908
# Epoch 34/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3975 - iou_score: 0.7034 - val_loss: 0.4103 - val_iou_score: 0.6961
# Epoch 35/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3947 - iou_score: 0.7056 - val_loss: 0.3950 - val_iou_score: 0.7127
# Epoch 36/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3862 - iou_score: 0.7115 - val_loss: 0.4228 - val_iou_score: 0.6881
# Epoch 37/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3829 - iou_score: 0.7141 - val_loss: 0.4000 - val_iou_score: 0.7071
# Epoch 38/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3877 - iou_score: 0.7111 - val_loss: 0.4162 - val_iou_score: 0.6910
# Epoch 39/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3839 - iou_score: 0.7136 - val_loss: 0.3897 - val_iou_score: 0.7081
# Epoch 40/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3702 - iou_score: 0.7238 - val_loss: 0.3888 - val_iou_score: 0.7121
# Epoch 41/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3683 - iou_score: 0.7249 - val_loss: 0.3991 - val_iou_score: 0.7065
# Epoch 42/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3623 - iou_score: 0.7298 - val_loss: 0.3703 - val_iou_score: 0.7231
# Epoch 43/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3746 - iou_score: 0.7211 - val_loss: 0.3861 - val_iou_score: 0.7167
# Epoch 44/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3612 - iou_score: 0.7303 - val_loss: 0.3772 - val_iou_score: 0.7213
# Epoch 45/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3594 - iou_score: 0.7320 - val_loss: 0.3604 - val_iou_score: 0.7322
# Epoch 46/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3532 - iou_score: 0.7365 - val_loss: 0.3568 - val_iou_score: 0.7378
# Epoch 47/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3534 - iou_score: 0.7361 - val_loss: 0.3780 - val_iou_score: 0.7222
# Epoch 48/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3485 - iou_score: 0.7398 - val_loss: 0.3787 - val_iou_score: 0.7195
# Epoch 49/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3458 - iou_score: 0.7418 - val_loss: 0.3644 - val_iou_score: 0.7309
# Epoch 50/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3401 - iou_score: 0.7464 - val_loss: 0.4037 - val_iou_score: 0.7081
# Epoch 51/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3449 - iou_score: 0.7421 - val_loss: 0.3589 - val_iou_score: 0.7341
# Epoch 52/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3407 - iou_score: 0.7453 - val_loss: 0.3687 - val_iou_score: 0.7254
# Epoch 53/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3417 - iou_score: 0.7446 - val_loss: 0.3685 - val_iou_score: 0.7323
# Epoch 54/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3349 - iou_score: 0.7500 - val_loss: 0.3580 - val_iou_score: 0.7385
# Epoch 55/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3323 - iou_score: 0.7521 - val_loss: 0.3692 - val_iou_score: 0.7249
# Epoch 56/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3400 - iou_score: 0.7458 - val_loss: 0.3552 - val_iou_score: 0.7388
# Epoch 57/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3280 - iou_score: 0.7555 - val_loss: 0.3611 - val_iou_score: 0.7325
# Epoch 58/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3199 - iou_score: 0.7608 - val_loss: 0.3877 - val_iou_score: 0.7178
# Epoch 59/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3336 - iou_score: 0.7510 - val_loss: 0.4173 - val_iou_score: 0.6933
# Epoch 60/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3275 - iou_score: 0.7551 - val_loss: 0.3501 - val_iou_score: 0.7444
# Epoch 61/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3132 - iou_score: 0.7660 - val_loss: 0.3835 - val_iou_score: 0.7177
# Epoch 62/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3217 - iou_score: 0.7595 - val_loss: 0.3478 - val_iou_score: 0.7455
# Epoch 63/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3180 - iou_score: 0.7624 - val_loss: 0.3446 - val_iou_score: 0.7461
# Epoch 64/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3130 - iou_score: 0.7660 - val_loss: 0.3479 - val_iou_score: 0.7433
# Epoch 65/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3173 - iou_score: 0.7630 - val_loss: 0.3477 - val_iou_score: 0.7459
# Epoch 66/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3164 - iou_score: 0.7638 - val_loss: 0.3470 - val_iou_score: 0.7465
# Epoch 67/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3066 - iou_score: 0.7708 - val_loss: 0.3524 - val_iou_score: 0.7422
# Epoch 68/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3070 - iou_score: 0.7705 - val_loss: 0.3432 - val_iou_score: 0.7479
# Epoch 69/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3066 - iou_score: 0.7712 - val_loss: 0.3603 - val_iou_score: 0.7355
# Epoch 70/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3013 - iou_score: 0.7748 - val_loss: 0.3706 - val_iou_score: 0.7324
# Epoch 71/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3029 - iou_score: 0.7733 - val_loss: 0.3478 - val_iou_score: 0.7462
# Epoch 72/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3027 - iou_score: 0.7732 - val_loss: 0.3425 - val_iou_score: 0.7467
# Epoch 73/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3011 - iou_score: 0.7750 - val_loss: 0.3597 - val_iou_score: 0.7371
# Epoch 74/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2944 - iou_score: 0.7801 - val_loss: 0.3459 - val_iou_score: 0.7495
# Epoch 75/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2998 - iou_score: 0.7759 - val_loss: 0.3431 - val_iou_score: 0.7486
# Epoch 76/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2993 - iou_score: 0.7759 - val_loss: 0.3475 - val_iou_score: 0.7455
# Epoch 77/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2907 - iou_score: 0.7826 - val_loss: 0.3517 - val_iou_score: 0.7421
# Epoch 78/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2935 - iou_score: 0.7805 - val_loss: 0.3644 - val_iou_score: 0.7373
# Epoch 79/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2959 - iou_score: 0.7788 - val_loss: 0.3473 - val_iou_score: 0.7469
# Epoch 80/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2884 - iou_score: 0.7843 - val_loss: 0.3408 - val_iou_score: 0.7496
# Epoch 81/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2895 - iou_score: 0.7839 - val_loss: 0.3531 - val_iou_score: 0.7419
# Epoch 82/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2900 - iou_score: 0.7830 - val_loss: 0.3526 - val_iou_score: 0.7418
# Epoch 83/100
# 181/181 [==============================] - 6s 31ms/step - loss: 0.2876 - iou_score: 0.7847 - val_loss: 0.3554 - val_iou_score: 0.7401
# Epoch 84/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2858 - iou_score: 0.7862 - val_loss: 0.3411 - val_iou_score: 0.7496
# Epoch 85/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2808 - iou_score: 0.7903 - val_loss: 0.3532 - val_iou_score: 0.7436
# Epoch 86/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2865 - iou_score: 0.7862 - val_loss: 0.3378 - val_iou_score: 0.7510
# Epoch 87/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2763 - iou_score: 0.7932 - val_loss: 0.3436 - val_iou_score: 0.7516
# Epoch 88/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2821 - iou_score: 0.7894 - val_loss: 0.3450 - val_iou_score: 0.7474
# Epoch 89/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2896 - iou_score: 0.7835 - val_loss: 0.3417 - val_iou_score: 0.7498
# Epoch 90/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2750 - iou_score: 0.7942 - val_loss: 0.3363 - val_iou_score: 0.7531
# Epoch 91/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2743 - iou_score: 0.7948 - val_loss: 0.3374 - val_iou_score: 0.7510
# Epoch 92/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2710 - iou_score: 0.7972 - val_loss: 0.3236 - val_iou_score: 0.7622
# Epoch 93/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2711 - iou_score: 0.7968 - val_loss: 0.3672 - val_iou_score: 0.7320
# Epoch 94/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2825 - iou_score: 0.7885 - val_loss: 0.3563 - val_iou_score: 0.7420
# Epoch 95/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2712 - iou_score: 0.7971 - val_loss: 0.3486 - val_iou_score: 0.7489
# Epoch 96/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2843 - iou_score: 0.7877 - val_loss: 0.3420 - val_iou_score: 0.7488
# Epoch 97/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2703 - iou_score: 0.7981 - val_loss: 0.3302 - val_iou_score: 0.7586
# Epoch 98/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2625 - iou_score: 0.8035 - val_loss: 0.3331 - val_iou_score: 0.7537
# Epoch 99/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2639 - iou_score: 0.8023 - val_loss: 0.3351 - val_iou_score: 0.7562
# Epoch 100/100
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2771 - iou_score: 0.7930 - val_loss: 0.3269 - val_iou_score: 0.7628

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 16384, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  74.94186162948608 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)


print(y_pred.shape)
print(test_masks.shape) 

predicted_masks = reverse_masks_shape(y_pred)
test_masks = reverse_masks_shape(test_masks)

print(predicted_masks.shape)
print(test_masks.shape) 

predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 1s 39ms/step
# (448, 16384, 10)
# (448, 16384, 10)
# (448, 128, 128, 10)
# (448, 128, 128, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.5114254
# IoU for each class:
# Building Flooded: 0.633701741695404
# Building Non-Flooded: 0.6217264533042908
# Road Flooded: 0.4301902949810028
# Road Non-Flooded: 0.7356526851654053
# Water: 0.6261075139045715
# Tree: 0.7262147068977356
# Vehicle: 0.15087656676769257
# Pool: 0.25391241908073425
# Grass: 0.8380624651908875
# Mean IoU (excluding Background): 0.55738276

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
