# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from skimage.transform import resize
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 224
SIZE_Y = 224
n_channels = 3
n_classes = 10
Batch_size = 4
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'MobileNet'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], -1, n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')
# Out:
#   0%|          | 0/1445 [00:00<?, ?it/s]
# 100%|██████████| 1445/1445 [07:00<00:00,  3.43it/s]
# TRAIN: Images loaded: 1445
# TRAIN: Masks loaded: 1445
# 100%|██████████| 450/450 [02:11<00:00,  3.43it/s]
# VAL: Images loaded: 450
# VAL: Masks loaded: 450

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = f'../../dataset/train_and_val_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to ../../dataset/train_and_val_data(224x224).pickle
# Shapes of loaded data:
# Train Images: (1445, 224, 224, 3)
# Train Masks: (1445, 224, 224)
# Val Images: (450, 224, 224, 3)
# Val Masks: (450, 224, 224)

# %%
pickle_file_path = f'../../dataset/train_and_val_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 224, 224, 3)
# Train Masks: (1445, 224, 224)
# Val Images: (450, 224, 224, 3)
# Val Masks: (450, 224, 224)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 224, 224, 3)
# Train Masks: (1445, 50176, 10)
# Val Images: (450, 224, 224, 3)
# Val Masks: (450, 50176, 10)

# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from skimage.transform import resize
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 608
SIZE_Y = 416
n_channels = 3
n_classes = 10
Batch_size = 4
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'MobileNet'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 16
#      14         model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
#      15     elif BACKBONE == 'MobileNet':
# ---> 16         model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
#      17 elif MODEL == 'pspnet':
#      18     if BACKBONE == 'Vanilla CNN':
#
# File c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_segmentation\models\unet.py:142, in mobilenet_unet(n_classes, input_height, input_width, encoder_level)
#     139 def mobilenet_unet(n_classes, input_height=224, input_width=224,
#     140                    encoder_level=3):
# --> 142     model = _unet(n_classes, get_mobilenet_encoder,
#     143                   input_height=input_height, input_width=input_width)
#     144     model.model_name = "mobilenet_unet"
#     145     return model
#
# File c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_segmentation\models\unet.py:72, in _unet(n_classes, encoder, l1_skip_conn, input_height, input_width)
#      69 def _unet(n_classes, encoder, l1_skip_conn=True, input_height=416,
#      70           input_width=608):
# ---> 72     img_input, levels = encoder(
#      73         input_height=input_height, input_width=input_width)
#      74     [f1, f2, f3, f4, f5] = levels
#      76     o = f4
#
# File c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_segmentation\models\mobilenet.py:68, in get_mobilenet_encoder(input_height, input_width, pretrained)
#      64 assert (K.image_data_format() ==
#      65         'channels_last'), "Currently only channels last mode is supported"
#      66 assert (IMAGE_ORDERING ==
#      67         'channels_last'), "Currently only channels last mode is supported"
# ---> 68 assert (input_height == 224), \
#      69     "For mobilenet , 224 input_height is supported "
#      70 assert (input_width == 224), "For mobilenet , 224 width is supported "
#      72 assert input_height % 32 == 0
#
# AssertionError: For mobilenet , 224 input_height is supported

# %%
(None, model.input_shape[1]*model.input_shape[2], model.input_shape[3]), model.output_shape
# Out:
# ((None, 50176, 3), (None, 50176, 10))

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 362/362 [==============================] - 35s 78ms/step - loss: 0.7471 - iou_score: 0.5219 - val_loss: 0.8419 - val_iou_score: 0.5133
# Epoch 2/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.5024 - iou_score: 0.6385 - val_loss: 0.5269 - val_iou_score: 0.6675
# Epoch 3/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.4472 - iou_score: 0.6783 - val_loss: 0.4310 - val_iou_score: 0.7169
# Epoch 4/100
# 362/362 [==============================] - 26s 71ms/step - loss: 0.4028 - iou_score: 0.7110 - val_loss: 0.4169 - val_iou_score: 0.7299
# Epoch 5/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.3865 - iou_score: 0.7232 - val_loss: 0.3847 - val_iou_score: 0.7395
# Epoch 6/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.3618 - iou_score: 0.7433 - val_loss: 0.3891 - val_iou_score: 0.7503
# Epoch 7/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.3352 - iou_score: 0.7604 - val_loss: 0.3561 - val_iou_score: 0.7451
# Epoch 8/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.3242 - iou_score: 0.7678 - val_loss: 0.3382 - val_iou_score: 0.7687
# Epoch 9/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.3019 - iou_score: 0.7837 - val_loss: 0.3225 - val_iou_score: 0.7692
# Epoch 10/100
# 362/362 [==============================] - 28s 78ms/step - loss: 0.2926 - iou_score: 0.7912 - val_loss: 0.3360 - val_iou_score: 0.7672
# Epoch 11/100
# 362/362 [==============================] - 28s 77ms/step - loss: 0.2832 - iou_score: 0.7970 - val_loss: 0.3133 - val_iou_score: 0.7786
# Epoch 12/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.2682 - iou_score: 0.8076 - val_loss: 0.3338 - val_iou_score: 0.7638
# Epoch 13/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.2509 - iou_score: 0.8183 - val_loss: 0.3093 - val_iou_score: 0.7840
# Epoch 14/100
# 362/362 [==============================] - 26s 71ms/step - loss: 0.2426 - iou_score: 0.8244 - val_loss: 0.3347 - val_iou_score: 0.7660
# Epoch 15/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.2378 - iou_score: 0.8283 - val_loss: 0.3079 - val_iou_score: 0.7807
# Epoch 16/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.2391 - iou_score: 0.8274 - val_loss: 0.2973 - val_iou_score: 0.7946
# Epoch 17/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.2285 - iou_score: 0.8346 - val_loss: 0.2959 - val_iou_score: 0.7909
# Epoch 18/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.2181 - iou_score: 0.8426 - val_loss: 0.2838 - val_iou_score: 0.7988
# Epoch 19/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1946 - iou_score: 0.8590 - val_loss: 0.3173 - val_iou_score: 0.7825
# Epoch 20/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.2131 - iou_score: 0.8470 - val_loss: 0.3244 - val_iou_score: 0.7810
# Epoch 21/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.2178 - iou_score: 0.8426 - val_loss: 0.3069 - val_iou_score: 0.7855
# Epoch 22/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1944 - iou_score: 0.8594 - val_loss: 0.3107 - val_iou_score: 0.7842
# Epoch 23/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1709 - iou_score: 0.8758 - val_loss: 0.2903 - val_iou_score: 0.7994
# Epoch 24/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1725 - iou_score: 0.8751 - val_loss: 0.3004 - val_iou_score: 0.7971
# Epoch 25/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1620 - iou_score: 0.8824 - val_loss: 0.2904 - val_iou_score: 0.8017
# Epoch 26/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1618 - iou_score: 0.8835 - val_loss: 0.3228 - val_iou_score: 0.7800
# Epoch 27/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1618 - iou_score: 0.8829 - val_loss: 0.2952 - val_iou_score: 0.7973
# Epoch 28/100
# 362/362 [==============================] - 26s 71ms/step - loss: 0.1663 - iou_score: 0.8800 - val_loss: 0.2884 - val_iou_score: 0.8034
# Epoch 29/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1551 - iou_score: 0.8876 - val_loss: 0.2844 - val_iou_score: 0.8048
# Epoch 30/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1443 - iou_score: 0.8950 - val_loss: 0.2810 - val_iou_score: 0.8073
# Epoch 31/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.1424 - iou_score: 0.8966 - val_loss: 0.2896 - val_iou_score: 0.8058
# Epoch 32/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1382 - iou_score: 0.8990 - val_loss: 0.3039 - val_iou_score: 0.7965
# Epoch 33/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1560 - iou_score: 0.8858 - val_loss: 0.2888 - val_iou_score: 0.8008
# Epoch 34/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1665 - iou_score: 0.8807 - val_loss: 0.2902 - val_iou_score: 0.8030
# Epoch 35/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1494 - iou_score: 0.8907 - val_loss: 0.3054 - val_iou_score: 0.7966
# Epoch 36/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.1499 - iou_score: 0.8923 - val_loss: 0.2848 - val_iou_score: 0.8037
# Epoch 37/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1299 - iou_score: 0.9057 - val_loss: 0.3115 - val_iou_score: 0.7817
# Epoch 38/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1295 - iou_score: 0.9060 - val_loss: 0.3221 - val_iou_score: 0.7764
# Epoch 39/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1272 - iou_score: 0.9072 - val_loss: 0.2839 - val_iou_score: 0.8085
# Epoch 40/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1231 - iou_score: 0.9103 - val_loss: 0.2847 - val_iou_score: 0.8096
# Epoch 41/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1236 - iou_score: 0.9104 - val_loss: 0.2928 - val_iou_score: 0.8013
# Epoch 42/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1222 - iou_score: 0.9112 - val_loss: 0.2784 - val_iou_score: 0.8137
# Epoch 43/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1228 - iou_score: 0.9102 - val_loss: 0.2746 - val_iou_score: 0.8117
# Epoch 44/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1173 - iou_score: 0.9143 - val_loss: 0.2826 - val_iou_score: 0.8100
# Epoch 45/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1168 - iou_score: 0.9148 - val_loss: 0.3531 - val_iou_score: 0.7575
# Epoch 46/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1745 - iou_score: 0.8744 - val_loss: 0.2928 - val_iou_score: 0.8033
# Epoch 47/100
# 362/362 [==============================] - 26s 71ms/step - loss: 0.1266 - iou_score: 0.9075 - val_loss: 0.2787 - val_iou_score: 0.8095
# Epoch 48/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1231 - iou_score: 0.9113 - val_loss: 0.2880 - val_iou_score: 0.8083
# Epoch 49/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1103 - iou_score: 0.9191 - val_loss: 0.2723 - val_iou_score: 0.8159
# Epoch 50/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1174 - iou_score: 0.9152 - val_loss: 0.2763 - val_iou_score: 0.8145
# Epoch 51/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1059 - iou_score: 0.9225 - val_loss: 0.2904 - val_iou_score: 0.8080
# Epoch 52/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.1073 - iou_score: 0.9225 - val_loss: 0.2820 - val_iou_score: 0.8167
# Epoch 53/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1135 - iou_score: 0.9186 - val_loss: 0.2844 - val_iou_score: 0.8100
# Epoch 54/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1034 - iou_score: 0.9235 - val_loss: 0.2697 - val_iou_score: 0.8190
# Epoch 55/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1228 - iou_score: 0.9108 - val_loss: 0.2902 - val_iou_score: 0.8086
# Epoch 56/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1114 - iou_score: 0.9196 - val_loss: 0.2719 - val_iou_score: 0.8189
# Epoch 57/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1019 - iou_score: 0.9257 - val_loss: 0.2792 - val_iou_score: 0.8165
# Epoch 58/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1005 - iou_score: 0.9260 - val_loss: 0.2724 - val_iou_score: 0.8164
# Epoch 59/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1038 - iou_score: 0.9241 - val_loss: 0.2841 - val_iou_score: 0.8140
# Epoch 60/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.0992 - iou_score: 0.9270 - val_loss: 0.2748 - val_iou_score: 0.8170
# Epoch 61/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1276 - iou_score: 0.9077 - val_loss: 0.2943 - val_iou_score: 0.8072
# Epoch 62/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1052 - iou_score: 0.9224 - val_loss: 0.2737 - val_iou_score: 0.8187
# Epoch 63/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1042 - iou_score: 0.9241 - val_loss: 0.2732 - val_iou_score: 0.8202
# Epoch 64/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.0980 - iou_score: 0.9276 - val_loss: 0.2704 - val_iou_score: 0.8209
# Epoch 65/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0977 - iou_score: 0.9287 - val_loss: 0.2786 - val_iou_score: 0.8187
# Epoch 66/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.1014 - iou_score: 0.9267 - val_loss: 0.2734 - val_iou_score: 0.8194
# Epoch 67/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.0953 - iou_score: 0.9309 - val_loss: 0.2702 - val_iou_score: 0.8203
# Epoch 68/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.1025 - iou_score: 0.9251 - val_loss: 0.2892 - val_iou_score: 0.8114
# Epoch 69/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.1003 - iou_score: 0.9264 - val_loss: 0.2769 - val_iou_score: 0.8177
# Epoch 70/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1036 - iou_score: 0.9245 - val_loss: 0.3311 - val_iou_score: 0.7928
# Epoch 71/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.1156 - iou_score: 0.9177 - val_loss: 0.2775 - val_iou_score: 0.8171
# Epoch 72/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.1002 - iou_score: 0.9270 - val_loss: 0.2858 - val_iou_score: 0.8098
# Epoch 73/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.0903 - iou_score: 0.9338 - val_loss: 0.2706 - val_iou_score: 0.8213
# Epoch 74/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.0896 - iou_score: 0.9341 - val_loss: 0.2753 - val_iou_score: 0.8147
# Epoch 75/100
# 362/362 [==============================] - 26s 72ms/step - loss: 0.1043 - iou_score: 0.9239 - val_loss: 0.2894 - val_iou_score: 0.8087
# Epoch 76/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.0911 - iou_score: 0.9335 - val_loss: 0.2821 - val_iou_score: 0.8142
# Epoch 77/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.0875 - iou_score: 0.9360 - val_loss: 0.2716 - val_iou_score: 0.8218
# Epoch 78/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0857 - iou_score: 0.9377 - val_loss: 0.2717 - val_iou_score: 0.8216
# Epoch 79/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.0849 - iou_score: 0.9378 - val_loss: 0.2797 - val_iou_score: 0.8166
# Epoch 80/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0938 - iou_score: 0.9319 - val_loss: 0.2726 - val_iou_score: 0.8223
# Epoch 81/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.0865 - iou_score: 0.9357 - val_loss: 0.2736 - val_iou_score: 0.8198
# Epoch 82/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.1103 - iou_score: 0.9194 - val_loss: 0.2889 - val_iou_score: 0.8111
# Epoch 83/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0880 - iou_score: 0.9357 - val_loss: 0.2707 - val_iou_score: 0.8239
# Epoch 84/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.0824 - iou_score: 0.9398 - val_loss: 0.2726 - val_iou_score: 0.8233
# Epoch 85/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0953 - iou_score: 0.9305 - val_loss: 0.2849 - val_iou_score: 0.8139
# Epoch 86/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.1009 - iou_score: 0.9269 - val_loss: 0.2722 - val_iou_score: 0.8209
# Epoch 87/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0852 - iou_score: 0.9380 - val_loss: 0.2777 - val_iou_score: 0.8199
# Epoch 88/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0826 - iou_score: 0.9392 - val_loss: 0.2728 - val_iou_score: 0.8230
# Epoch 89/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0825 - iou_score: 0.9392 - val_loss: 0.2757 - val_iou_score: 0.8208
# Epoch 90/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.0864 - iou_score: 0.9367 - val_loss: 0.2789 - val_iou_score: 0.8196
# Epoch 91/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0887 - iou_score: 0.9353 - val_loss: 0.2741 - val_iou_score: 0.8195
# Epoch 92/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.0951 - iou_score: 0.9313 - val_loss: 0.2985 - val_iou_score: 0.8079
# Epoch 93/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.0868 - iou_score: 0.9364 - val_loss: 0.2786 - val_iou_score: 0.8204
# Epoch 94/100
# 362/362 [==============================] - 27s 73ms/step - loss: 0.0943 - iou_score: 0.9313 - val_loss: 0.2786 - val_iou_score: 0.8200
# Epoch 95/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0907 - iou_score: 0.9346 - val_loss: 0.2826 - val_iou_score: 0.8169
# Epoch 96/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0822 - iou_score: 0.9400 - val_loss: 0.2996 - val_iou_score: 0.8027
# Epoch 97/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0881 - iou_score: 0.9350 - val_loss: 0.2736 - val_iou_score: 0.8210
# Epoch 98/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.0862 - iou_score: 0.9365 - val_loss: 0.2766 - val_iou_score: 0.8189
# Epoch 99/100
# 362/362 [==============================] - 27s 74ms/step - loss: 0.0875 - iou_score: 0.9370 - val_loss: 0.2775 - val_iou_score: 0.8184
# Epoch 100/100
# 362/362 [==============================] - 26s 73ms/step - loss: 0.0795 - iou_score: 0.9408 - val_loss: 0.2856 - val_iou_score: 0.8161

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:29<00:00,  3.01it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = f'../../dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../../dataset/test_data(224x224).pickle
# Shapes of loaded data:
# Test Images: (448, 224, 224, 3)
# Test Masks: (448, 50176, 10)

# %%
pickle_file_path = f'../../dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

# test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 224, 224, 3)
# Test Masks: (448, 50176, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  80.73879480361938 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)

print(y_pred.shape)
print(test_masks.shape) 

predicted_masks = reverse_masks_shape(y_pred)
test_masks = reverse_masks_shape(test_masks)

print(predicted_masks.shape)
print(test_masks.shape) 

predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 1s 111ms/step
# (448, 50176, 10)
# (448, 50176, 10)
# (448, 224, 224, 10)
# (448, 224, 224, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.6237442
# IoU for each class:
# Building Flooded: 0.688275933265686
# Building Non-Flooded: 0.7301141023635864
# Road Flooded: 0.5923824310302734
# Road Non-Flooded: 0.7917236685752869
# Water: 0.7642723917961121
# Tree: 0.7669268250465393
# Vehicle: 0.29132363200187683
# Pool: 0.3560245931148529
# Grass: 0.8705629706382751
# Mean IoU (excluding Background): 0.65017855

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)
