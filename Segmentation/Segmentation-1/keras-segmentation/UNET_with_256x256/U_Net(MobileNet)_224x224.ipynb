# %%
# !nvidia-smi
# Out:
# Tue Feb 20 06:51:39 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/FloodNet-Supervised_v1.0.zip'

# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from skimage.transform import resize
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

seed = 42
SIZE_X = 224
SIZE_Y = 224
n_channels = 3
n_classes = 10
Batch_size = 16
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'MobileNet'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0(customized)'

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}

color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128],
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format.
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3))))
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_data_gen_args = dict()
mask_data_gen_args = dict()

image_data_generator = ImageDataGenerator(**img_data_gen_args)
image_generator = image_data_generator.flow_from_directory(f"{parent_directory}/train_images",
                                                           seed=seed,
                                                           batch_size=Batch_size,
                                                           class_mode=None,
                                                           target_size=(SIZE_X, SIZE_Y))

mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
mask_generator = mask_data_generator.flow_from_directory(f"{parent_directory}/train_masks",
                                                         seed=seed,
                                                         batch_size=Batch_size,
                                                         color_mode = 'grayscale',
                                                         class_mode=None,
                                                         target_size=(SIZE_X, SIZE_Y))


valid_img_generator = image_data_generator.flow_from_directory(f"{parent_directory}/val_images",
                                                           seed=seed,
                                                           batch_size=Batch_size,
                                                           class_mode=None,
                                                           target_size=(SIZE_X, SIZE_Y))

valid_mask_generator = mask_data_generator.flow_from_directory(f"{parent_directory}/val_masks",
                                                         seed=seed,
                                                         batch_size=Batch_size,
                                                         color_mode = 'grayscale',
                                                         class_mode=None,
                                                         target_size=(SIZE_X, SIZE_Y))

train_generator = zip(image_generator, mask_generator)
valid_generator = zip(valid_img_generator, valid_mask_generator)
# Out:
# Found 1445 images belonging to 1 classes.
# Found 1445 images belonging to 1 classes.
# Found 450 images belonging to 1 classes.
# Found 450 images belonging to 1 classes.

# %%
batch = next(train_generator)
images, masks = batch

# %%
images.shape, masks.shape
# Out:
# ((16, 224, 224, 3), (16, 224, 224, 1))

# %%
import numpy as np
import random

num = random.randint(0, len(images)-1)
display_images_with_masks((images[num]).astype(np.uint8), np.squeeze(masks[num], axis=-1), np.squeeze(masks[num], axis=-1))

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)

    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], -1, n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
from tensorflow.keras.utils import to_categorical

def load_data(image_generator, mask_generator, preprocessing_function=None):
    for (img, mask) in zip(image_generator, mask_generator):
        img, mask = preprocess_data(img, mask)
        yield (img, mask)

# %%
train_generator = load_data(image_generator, mask_generator)
val_generator = load_data(valid_img_generator, valid_mask_generator)

# %%
batch = next(train_generator)
images, masks = batch

# %%
images[0].shape, masks[0].shape
# Out:
# ((224, 224, 3), (50176, 10))

# %%
images.shape, masks.shape
# Out:
# ((16, 224, 224, 3), (16, 50176, 10))

# %%
# !pip install keras_segmentation
# !pip install -U segmentation-models
# Out:
# Collecting keras_segmentation
#   Downloading keras_segmentation-0.3.0.tar.gz (23 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Keras>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (2.15.0)
# Collecting imageio==2.5.0 (from keras_segmentation)
#   Downloading imageio-2.5.0-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 15.2 MB/s eta 0:00:00
# Collecting imgaug==0.2.9 (from keras_segmentation)
#   Downloading imgaug-0.2.9-py2.py3-none-any.whl (753 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.3/753.3 kB 44.7 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (4.8.0.76)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (4.66.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio==2.5.0->keras_segmentation) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imageio==2.5.0->keras_segmentation) (9.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (1.11.4)
# Requirement already satisfied: scikit-image>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (3.7.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (2.0.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (2.8.2)
# Building wheels for collected packages: keras_segmentation
#   Building wheel for keras_segmentation (setup.py) ... done
#   Created wheel for keras_segmentation: filename=keras_segmentation-0.3.0-py3-none-any.whl size=29057 sha256=f73c7e477e54990b61efbfe77d5b954ffc8e9e9f20db41c41a0681977fcad35b
#   Stored in directory: /root/.cache/pip/wheels/2a/87/5b/ddc104c262fe1280e0565a2cc1b9b6b04963af12e462cdf068
# Successfully built keras_segmentation
# Installing collected packages: imageio, imgaug, keras_segmentation
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.31.6
#     Uninstalling imageio-2.31.6:
#       Successfully uninstalled imageio-2.31.6
#   Attempting uninstall: imgaug
#     Found existing installation: imgaug 0.4.0
#     Uninstalling imgaug-0.4.0:
#       Successfully uninstalled imgaug-0.4.0
# Successfully installed imageio-2.5.0 imgaug-0.2.9 keras_segmentation-0.3.0
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.5 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.5.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.2)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Segmentation Models: using `tf.keras` framework.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 226, 226, 3)          0         ['input_1[0][0]']
#
#  conv1 (Conv2D)              (None, 112, 112, 32)         864       ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 32)         128       ['conv1[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 32)         0         ['conv1_bn[0][0]']
#
#  conv_pad_1 (ZeroPadding2D)  (None, 114, 114, 32)         0         ['conv1_relu[0][0]']
#
#  conv_dw_1 (DepthwiseConv2D  (None, 112, 112, 32)         288       ['conv_pad_1[0][0]']
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 112, 112, 32)         128       ['conv_dw_1[0][0]']
#  zation)
#
#  conv_dw_1_relu (Activation  (None, 112, 112, 32)         0         ['conv_dw_1_bn[0][0]']
#  )
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)         2048      ['conv_dw_1_relu[0][0]']
#
#  conv_pw_1_bn (BatchNormali  (None, 112, 112, 64)         256       ['conv_pw_1[0][0]']
#  zation)
#
#  conv_pw_1_relu (Activation  (None, 112, 112, 64)         0         ['conv_pw_1_bn[0][0]']
#  )
#
#  conv_pad_2 (ZeroPadding2D)  (None, 114, 114, 64)         0         ['conv_pw_1_relu[0][0]']
#
#  conv_dw_2 (DepthwiseConv2D  (None, 56, 56, 64)           576       ['conv_pad_2[0][0]']
#  )
#
#  conv_dw_2_bn (BatchNormali  (None, 56, 56, 64)           256       ['conv_dw_2[0][0]']
#  zation)
#
#  conv_dw_2_relu (Activation  (None, 56, 56, 64)           0         ['conv_dw_2_bn[0][0]']
#  )
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)          8192      ['conv_dw_2_relu[0][0]']
#
#  conv_pw_2_bn (BatchNormali  (None, 56, 56, 128)          512       ['conv_pw_2[0][0]']
#  zation)
#
#  conv_pw_2_relu (Activation  (None, 56, 56, 128)          0         ['conv_pw_2_bn[0][0]']
#  )
#
#  conv_pad_3 (ZeroPadding2D)  (None, 58, 58, 128)          0         ['conv_pw_2_relu[0][0]']
#
#  conv_dw_3 (DepthwiseConv2D  (None, 56, 56, 128)          1152      ['conv_pad_3[0][0]']
#  )
#
#  conv_dw_3_bn (BatchNormali  (None, 56, 56, 128)          512       ['conv_dw_3[0][0]']
#  zation)
#
#  conv_dw_3_relu (Activation  (None, 56, 56, 128)          0         ['conv_dw_3_bn[0][0]']
#  )
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)          16384     ['conv_dw_3_relu[0][0]']
#
#  conv_pw_3_bn (BatchNormali  (None, 56, 56, 128)          512       ['conv_pw_3[0][0]']
#  zation)
#
#  conv_pw_3_relu (Activation  (None, 56, 56, 128)          0         ['conv_pw_3_bn[0][0]']
#  )
#
#  conv_pad_4 (ZeroPadding2D)  (None, 58, 58, 128)          0         ['conv_pw_3_relu[0][0]']
#
#  conv_dw_4 (DepthwiseConv2D  (None, 28, 28, 128)          1152      ['conv_pad_4[0][0]']
#  )
#
#  conv_dw_4_bn (BatchNormali  (None, 28, 28, 128)          512       ['conv_dw_4[0][0]']
#  zation)
#
#  conv_dw_4_relu (Activation  (None, 28, 28, 128)          0         ['conv_dw_4_bn[0][0]']
#  )
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)          32768     ['conv_dw_4_relu[0][0]']
#
#  conv_pw_4_bn (BatchNormali  (None, 28, 28, 256)          1024      ['conv_pw_4[0][0]']
#  zation)
#
#  conv_pw_4_relu (Activation  (None, 28, 28, 256)          0         ['conv_pw_4_bn[0][0]']
#  )
#
#  conv_pad_5 (ZeroPadding2D)  (None, 30, 30, 256)          0         ['conv_pw_4_relu[0][0]']
#
#  conv_dw_5 (DepthwiseConv2D  (None, 28, 28, 256)          2304      ['conv_pad_5[0][0]']
#  )
#
#  conv_dw_5_bn (BatchNormali  (None, 28, 28, 256)          1024      ['conv_dw_5[0][0]']
#  zation)
#
#  conv_dw_5_relu (Activation  (None, 28, 28, 256)          0         ['conv_dw_5_bn[0][0]']
#  )
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)          65536     ['conv_dw_5_relu[0][0]']
#
#  conv_pw_5_bn (BatchNormali  (None, 28, 28, 256)          1024      ['conv_pw_5[0][0]']
#  zation)
#
#  conv_pw_5_relu (Activation  (None, 28, 28, 256)          0         ['conv_pw_5_bn[0][0]']
#  )
#
#  conv_pad_6 (ZeroPadding2D)  (None, 30, 30, 256)          0         ['conv_pw_5_relu[0][0]']
#
#  conv_dw_6 (DepthwiseConv2D  (None, 14, 14, 256)          2304      ['conv_pad_6[0][0]']
#  )
#
#  conv_dw_6_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv_dw_6[0][0]']
#  zation)
#
#  conv_dw_6_relu (Activation  (None, 14, 14, 256)          0         ['conv_dw_6_bn[0][0]']
#  )
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)          131072    ['conv_dw_6_relu[0][0]']
#
#  conv_pw_6_bn (BatchNormali  (None, 14, 14, 512)          2048      ['conv_pw_6[0][0]']
#  zation)
#
#  conv_pw_6_relu (Activation  (None, 14, 14, 512)          0         ['conv_pw_6_bn[0][0]']
#  )
#
#  conv_pad_7 (ZeroPadding2D)  (None, 16, 16, 512)          0         ['conv_pw_6_relu[0][0]']
#
#  conv_dw_7 (DepthwiseConv2D  (None, 14, 14, 512)          4608      ['conv_pad_7[0][0]']
#  )
#
#  conv_dw_7_bn (BatchNormali  (None, 14, 14, 512)          2048      ['conv_dw_7[0][0]']
#  zation)
#
#  conv_dw_7_relu (Activation  (None, 14, 14, 512)          0         ['conv_dw_7_bn[0][0]']
#  )
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)          262144    ['conv_dw_7_relu[0][0]']
#
#  conv_pw_7_bn (BatchNormali  (None, 14, 14, 512)          2048      ['conv_pw_7[0][0]']
#  zation)
#
#  conv_pw_7_relu (Activation  (None, 14, 14, 512)          0         ['conv_pw_7_bn[0][0]']
#  )
#
#  conv_pad_8 (ZeroPadding2D)  (None, 16, 16, 512)          0         ['conv_pw_7_relu[0][0]']
#
#  conv_dw_8 (DepthwiseConv2D  (None, 14, 14, 512)          4608      ['conv_pad_8[0][0]']
#  )
#
#  conv_dw_8_bn (BatchNormali  (None, 14, 14, 512)          2048      ['conv_dw_8[0][0]']
#  zation)
#
#  conv_dw_8_relu (Activation  (None, 14, 14, 512)          0         ['conv_dw_8_bn[0][0]']
#  )
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)          262144    ['conv_dw_8_relu[0][0]']
#
#  conv_pw_8_bn (BatchNormali  (None, 14, 14, 512)          2048      ['conv_pw_8[0][0]']
#  zation)
#
#  conv_pw_8_relu (Activation  (None, 14, 14, 512)          0         ['conv_pw_8_bn[0][0]']
#  )
#
#  conv_pad_9 (ZeroPadding2D)  (None, 16, 16, 512)          0         ['conv_pw_8_relu[0][0]']
#
#  conv_dw_9 (DepthwiseConv2D  (None, 14, 14, 512)          4608      ['conv_pad_9[0][0]']
#  )
#
#  conv_dw_9_bn (BatchNormali  (None, 14, 14, 512)          2048      ['conv_dw_9[0][0]']
#  zation)
#
#  conv_dw_9_relu (Activation  (None, 14, 14, 512)          0         ['conv_dw_9_bn[0][0]']
#  )
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)          262144    ['conv_dw_9_relu[0][0]']
#
#  conv_pw_9_bn (BatchNormali  (None, 14, 14, 512)          2048      ['conv_pw_9[0][0]']
#  zation)
#
#  conv_pw_9_relu (Activation  (None, 14, 14, 512)          0         ['conv_pw_9_bn[0][0]']
#  )
#
#  conv_pad_10 (ZeroPadding2D  (None, 16, 16, 512)          0         ['conv_pw_9_relu[0][0]']
#  )
#
#  conv_dw_10 (DepthwiseConv2  (None, 14, 14, 512)          4608      ['conv_pad_10[0][0]']
#  D)
#
#  conv_dw_10_bn (BatchNormal  (None, 14, 14, 512)          2048      ['conv_dw_10[0][0]']
#  ization)
#
#  conv_dw_10_relu (Activatio  (None, 14, 14, 512)          0         ['conv_dw_10_bn[0][0]']
#  n)
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)          262144    ['conv_dw_10_relu[0][0]']
#
#  conv_pw_10_bn (BatchNormal  (None, 14, 14, 512)          2048      ['conv_pw_10[0][0]']
#  ization)
#
#  conv_pw_10_relu (Activatio  (None, 14, 14, 512)          0         ['conv_pw_10_bn[0][0]']
#  n)
#
#  conv_pad_11 (ZeroPadding2D  (None, 16, 16, 512)          0         ['conv_pw_10_relu[0][0]']
#  )
#
#  conv_dw_11 (DepthwiseConv2  (None, 14, 14, 512)          4608      ['conv_pad_11[0][0]']
#  D)
#
#  conv_dw_11_bn (BatchNormal  (None, 14, 14, 512)          2048      ['conv_dw_11[0][0]']
#  ization)
#
#  conv_dw_11_relu (Activatio  (None, 14, 14, 512)          0         ['conv_dw_11_bn[0][0]']
#  n)
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)          262144    ['conv_dw_11_relu[0][0]']
#
#  conv_pw_11_bn (BatchNormal  (None, 14, 14, 512)          2048      ['conv_pw_11[0][0]']
#  ization)
#
#  conv_pw_11_relu (Activatio  (None, 14, 14, 512)          0         ['conv_pw_11_bn[0][0]']
#  n)
#
#  zero_padding2d (ZeroPaddin  (None, 16, 16, 512)          0         ['conv_pw_11_relu[0][0]']
#  g2D)
#
#  conv2d (Conv2D)             (None, 14, 14, 512)          2359808   ['zero_padding2d[0][0]']
#
#  batch_normalization (Batch  (None, 14, 14, 512)          2048      ['conv2d[0][0]']
#  Normalization)
#
#  up_sampling2d (UpSampling2  (None, 28, 28, 512)          0         ['batch_normalization[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 28, 28, 768)          0         ['up_sampling2d[0][0]',
#                                                                      'conv_pw_5_relu[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 30, 30, 768)          0         ['concatenate[0][0]']
#  ing2D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 256)          1769728   ['zero_padding2d_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 28, 28, 256)          1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  up_sampling2d_1 (UpSamplin  (None, 56, 56, 256)          0         ['batch_normalization_1[0][0]'
#  g2D)                                                               ]
#
#  concatenate_1 (Concatenate  (None, 56, 56, 384)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'conv_pw_3_relu[0][0]']
#
#  zero_padding2d_2 (ZeroPadd  (None, 58, 58, 384)          0         ['concatenate_1[0][0]']
#  ing2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)          442496    ['zero_padding2d_2[0][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 128)          512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  up_sampling2d_2 (UpSamplin  (None, 112, 112, 128)        0         ['batch_normalization_2[0][0]'
#  g2D)                                                               ]
#
#  concatenate_2 (Concatenate  (None, 112, 112, 192)        0         ['up_sampling2d_2[0][0]',
#  )                                                                   'conv_pw_1_relu[0][0]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 114, 114, 192)        0         ['concatenate_2[0][0]']
#  ing2D)
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 64)         110656    ['zero_padding2d_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, 112, 112, 64)         256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  up_sampling2d_3 (UpSamplin  (None, 224, 224, 64)         0         ['batch_normalization_3[0][0]'
#  g2D)                                                               ]
#
#  conv2d_4 (Conv2D)           (None, 224, 224, 10)         5770      ['up_sampling2d_3[0][0]']
#
#  reshape (Reshape)           (None, 50176, 10)            0         ['conv2d_4[0][0]']
#
#  activation (Activation)     (None, 50176, 10)            0         ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 6320138 (24.11 MB)
# Trainable params: 6303498 (24.05 MB)
# Non-trainable params: 16640 (65.00 KB)
# __________________________________________________________________________________________________

# %%
model.input_shape, model.output_shape
# Out:
# ((None, 224, 224, 3), (None, 50176, 10))

# %%
train_samples = len(os.listdir(f"{parent_directory}/train_images/train"))
val_samples = len(os.listdir(f"{parent_directory}/val_images/val"))
train_samples, val_samples
# Out:
# (1445, 450)

# %%
history = model.fit(train_generator, steps_per_epoch=(train_samples//Batch_size), epochs=EPOCHS, validation_data=val_generator, validation_steps=(val_samples//Batch_size))
# Out:
# Epoch 1/100
# 90/90 [==============================] - 266s 3s/step - loss: 0.9837 - iou_score: 0.5406 - val_loss: 11.2964 - val_iou_score: 0.0810
# Epoch 2/100
# 90/90 [==============================] - 256s 3s/step - loss: 0.4901 - iou_score: 0.6626 - val_loss: 1.4290 - val_iou_score: 0.2697
# Epoch 3/100
# 90/90 [==============================] - 262s 3s/step - loss: 0.3963 - iou_score: 0.7091 - val_loss: 0.8186 - val_iou_score: 0.4804
# Epoch 4/100
# 90/90 [==============================] - 265s 3s/step - loss: 0.3836 - iou_score: 0.7184 - val_loss: 0.8857 - val_iou_score: 0.5065
# Epoch 5/100
# 90/90 [==============================] - 268s 3s/step - loss: 0.3315 - iou_score: 0.7537 - val_loss: 0.5633 - val_iou_score: 0.6147
# Epoch 6/100
# 90/90 [==============================] - 265s 3s/step - loss: 0.3078 - iou_score: 0.7694 - val_loss: 0.4615 - val_iou_score: 0.6744
# Epoch 7/100
# 90/90 [==============================] - 264s 3s/step - loss: 0.2898 - iou_score: 0.7842 - val_loss: 0.3828 - val_iou_score: 0.7306
# Epoch 8/100
# 90/90 [==============================] - 265s 3s/step - loss: 0.2607 - iou_score: 0.8065 - val_loss: 0.3608 - val_iou_score: 0.7443
# Epoch 9/100
# 90/90 [==============================] - 258s 3s/step - loss: 0.2539 - iou_score: 0.8111 - val_loss: 0.3452 - val_iou_score: 0.7550
# Epoch 10/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.2523 - iou_score: 0.8136 - val_loss: 0.3721 - val_iou_score: 0.7442
# Epoch 11/100
# 90/90 [==============================] - 257s 3s/step - loss: 0.2226 - iou_score: 0.8333 - val_loss: 0.3494 - val_iou_score: 0.7627
# Epoch 12/100
# 90/90 [==============================] - 270s 3s/step - loss: 0.2214 - iou_score: 0.8351 - val_loss: 0.3736 - val_iou_score: 0.7421
# Epoch 13/100
# 90/90 [==============================] - 260s 3s/step - loss: 0.1993 - iou_score: 0.8508 - val_loss: 0.3321 - val_iou_score: 0.7679
# Epoch 14/100
# 90/90 [==============================] - 257s 3s/step - loss: 0.1836 - iou_score: 0.8643 - val_loss: 0.3239 - val_iou_score: 0.7714
# Epoch 15/100
# 90/90 [==============================] - 258s 3s/step - loss: 0.1743 - iou_score: 0.8690 - val_loss: 0.3159 - val_iou_score: 0.7819
# Epoch 16/100
# 90/90 [==============================] - 256s 3s/step - loss: 0.1775 - iou_score: 0.8663 - val_loss: 0.3936 - val_iou_score: 0.7403
# Epoch 17/100
# 90/90 [==============================] - 260s 3s/step - loss: 0.1724 - iou_score: 0.8716 - val_loss: 0.3759 - val_iou_score: 0.7429
# Epoch 18/100
# 90/90 [==============================] - 269s 3s/step - loss: 0.1735 - iou_score: 0.8711 - val_loss: 0.3261 - val_iou_score: 0.7755
# Epoch 19/100
# 90/90 [==============================] - 262s 3s/step - loss: 0.1559 - iou_score: 0.8831 - val_loss: 0.3108 - val_iou_score: 0.7834
# Epoch 20/100
# 90/90 [==============================] - 256s 3s/step - loss: 0.1508 - iou_score: 0.8866 - val_loss: 0.3162 - val_iou_score: 0.7846
# Epoch 21/100
# 90/90 [==============================] - 252s 3s/step - loss: 0.1480 - iou_score: 0.8886 - val_loss: 0.3108 - val_iou_score: 0.7838
# Epoch 22/100
# 90/90 [==============================] - 261s 3s/step - loss: 0.1298 - iou_score: 0.9023 - val_loss: 0.3097 - val_iou_score: 0.7845
# Epoch 23/100
# 90/90 [==============================] - 265s 3s/step - loss: 0.1330 - iou_score: 0.8995 - val_loss: 0.3185 - val_iou_score: 0.7878
# Epoch 24/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.1333 - iou_score: 0.9006 - val_loss: 0.3285 - val_iou_score: 0.7759
# Epoch 25/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.1251 - iou_score: 0.9063 - val_loss: 0.3151 - val_iou_score: 0.7865
# Epoch 26/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.1217 - iou_score: 0.9093 - val_loss: 0.3118 - val_iou_score: 0.7883
# Epoch 27/100
# 90/90 [==============================] - 257s 3s/step - loss: 0.1192 - iou_score: 0.9104 - val_loss: 0.3149 - val_iou_score: 0.7883
# Epoch 28/100
# 90/90 [==============================] - 259s 3s/step - loss: 0.1168 - iou_score: 0.9129 - val_loss: 0.3114 - val_iou_score: 0.7863
# Epoch 29/100
# 90/90 [==============================] - 268s 3s/step - loss: 0.1158 - iou_score: 0.9132 - val_loss: 0.3530 - val_iou_score: 0.7639
# Epoch 30/100
# 90/90 [==============================] - 258s 3s/step - loss: 0.1266 - iou_score: 0.9045 - val_loss: 0.3407 - val_iou_score: 0.7813
# Epoch 31/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.1190 - iou_score: 0.9108 - val_loss: 0.3267 - val_iou_score: 0.7828
# Epoch 32/100
# 90/90 [==============================] - 256s 3s/step - loss: 0.1149 - iou_score: 0.9140 - val_loss: 0.3362 - val_iou_score: 0.7755
# Epoch 33/100
# 90/90 [==============================] - 267s 3s/step - loss: 0.1197 - iou_score: 0.9114 - val_loss: 0.3391 - val_iou_score: 0.7808
# Epoch 34/100
# 90/90 [==============================] - 263s 3s/step - loss: 0.1384 - iou_score: 0.8976 - val_loss: 0.3919 - val_iou_score: 0.7432
# Epoch 35/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.1622 - iou_score: 0.8811 - val_loss: 0.4166 - val_iou_score: 0.7330
# Epoch 36/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.1392 - iou_score: 0.8954 - val_loss: 0.3201 - val_iou_score: 0.7860
# Epoch 37/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.1166 - iou_score: 0.9120 - val_loss: 0.3185 - val_iou_score: 0.7877
# Epoch 38/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.1057 - iou_score: 0.9208 - val_loss: 0.3047 - val_iou_score: 0.7926
# Epoch 39/100
# 90/90 [==============================] - 258s 3s/step - loss: 0.1105 - iou_score: 0.9170 - val_loss: 0.3112 - val_iou_score: 0.7914
# Epoch 40/100
# 90/90 [==============================] - 268s 3s/step - loss: 0.1076 - iou_score: 0.9195 - val_loss: 0.3064 - val_iou_score: 0.7950
# Epoch 41/100
# 90/90 [==============================] - 252s 3s/step - loss: 0.0979 - iou_score: 0.9269 - val_loss: 0.3032 - val_iou_score: 0.7970
# Epoch 42/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.0958 - iou_score: 0.9279 - val_loss: 0.3078 - val_iou_score: 0.7944
# Epoch 43/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0873 - iou_score: 0.9337 - val_loss: 0.3036 - val_iou_score: 0.7972
# Epoch 44/100
# 90/90 [==============================] - 259s 3s/step - loss: 0.0905 - iou_score: 0.9320 - val_loss: 0.3081 - val_iou_score: 0.7982
# Epoch 45/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.1110 - iou_score: 0.9171 - val_loss: 0.4545 - val_iou_score: 0.7156
# Epoch 46/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.1215 - iou_score: 0.9097 - val_loss: 0.3664 - val_iou_score: 0.7703
# Epoch 47/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.1052 - iou_score: 0.9220 - val_loss: 0.3187 - val_iou_score: 0.7923
# Epoch 48/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.1067 - iou_score: 0.9204 - val_loss: 0.3398 - val_iou_score: 0.7851
# Epoch 49/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0989 - iou_score: 0.9263 - val_loss: 0.3213 - val_iou_score: 0.7884
# Epoch 50/100
# 90/90 [==============================] - 262s 3s/step - loss: 0.0924 - iou_score: 0.9308 - val_loss: 0.3125 - val_iou_score: 0.7945
# Epoch 51/100
# 90/90 [==============================] - 263s 3s/step - loss: 0.0823 - iou_score: 0.9384 - val_loss: 0.3146 - val_iou_score: 0.7950
# Epoch 52/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0858 - iou_score: 0.9355 - val_loss: 0.3160 - val_iou_score: 0.7962
# Epoch 53/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0825 - iou_score: 0.9383 - val_loss: 0.3211 - val_iou_score: 0.7930
# Epoch 54/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0808 - iou_score: 0.9393 - val_loss: 0.3187 - val_iou_score: 0.7935
# Epoch 55/100
# 90/90 [==============================] - 256s 3s/step - loss: 0.0844 - iou_score: 0.9369 - val_loss: 0.3151 - val_iou_score: 0.7980
# Epoch 56/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0815 - iou_score: 0.9390 - val_loss: 0.3211 - val_iou_score: 0.7974
# Epoch 57/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.0761 - iou_score: 0.9431 - val_loss: 0.3136 - val_iou_score: 0.7975
# Epoch 58/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0783 - iou_score: 0.9415 - val_loss: 0.3184 - val_iou_score: 0.7967
# Epoch 59/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.0735 - iou_score: 0.9450 - val_loss: 0.3188 - val_iou_score: 0.7970
# Epoch 60/100
# 90/90 [==============================] - 256s 3s/step - loss: 0.0856 - iou_score: 0.9367 - val_loss: 0.3407 - val_iou_score: 0.7857
# Epoch 61/100
# 90/90 [==============================] - 265s 3s/step - loss: 0.1015 - iou_score: 0.9251 - val_loss: 0.4137 - val_iou_score: 0.7461
# Epoch 62/100
# 90/90 [==============================] - 259s 3s/step - loss: 0.1423 - iou_score: 0.8968 - val_loss: 0.5790 - val_iou_score: 0.6843
# Epoch 63/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.1287 - iou_score: 0.9048 - val_loss: 0.3747 - val_iou_score: 0.7639
# Epoch 64/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.1054 - iou_score: 0.9214 - val_loss: 0.3239 - val_iou_score: 0.7897
# Epoch 65/100
# 90/90 [==============================] - 256s 3s/step - loss: 0.0907 - iou_score: 0.9322 - val_loss: 0.3180 - val_iou_score: 0.7947
# Epoch 66/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0862 - iou_score: 0.9351 - val_loss: 0.3228 - val_iou_score: 0.7913
# Epoch 67/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.0870 - iou_score: 0.9350 - val_loss: 0.3461 - val_iou_score: 0.7766
# Epoch 68/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.0843 - iou_score: 0.9371 - val_loss: 0.3160 - val_iou_score: 0.7953
# Epoch 69/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0765 - iou_score: 0.9429 - val_loss: 0.3191 - val_iou_score: 0.7963
# Epoch 70/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0728 - iou_score: 0.9454 - val_loss: 0.3180 - val_iou_score: 0.7979
# Epoch 71/100
# 90/90 [==============================] - 262s 3s/step - loss: 0.0714 - iou_score: 0.9467 - val_loss: 0.3216 - val_iou_score: 0.7964
# Epoch 72/100
# 90/90 [==============================] - 269s 3s/step - loss: 0.0859 - iou_score: 0.9354 - val_loss: 0.5728 - val_iou_score: 0.6599
# Epoch 73/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0937 - iou_score: 0.9304 - val_loss: 0.3416 - val_iou_score: 0.7846
# Epoch 74/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0789 - iou_score: 0.9411 - val_loss: 0.3298 - val_iou_score: 0.7926
# Epoch 75/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0754 - iou_score: 0.9438 - val_loss: 0.3197 - val_iou_score: 0.7993
# Epoch 76/100
# 90/90 [==============================] - 266s 3s/step - loss: 0.0720 - iou_score: 0.9462 - val_loss: 0.3158 - val_iou_score: 0.8022
# Epoch 77/100
# 90/90 [==============================] - 257s 3s/step - loss: 0.0693 - iou_score: 0.9483 - val_loss: 0.3257 - val_iou_score: 0.7968
# Epoch 78/100
# 90/90 [==============================] - 252s 3s/step - loss: 0.0694 - iou_score: 0.9484 - val_loss: 0.3186 - val_iou_score: 0.7982
# Epoch 79/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.0691 - iou_score: 0.9483 - val_loss: 0.3359 - val_iou_score: 0.7924
# Epoch 80/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0690 - iou_score: 0.9484 - val_loss: 0.3318 - val_iou_score: 0.7974
# Epoch 81/100
# 90/90 [==============================] - 256s 3s/step - loss: 0.0688 - iou_score: 0.9488 - val_loss: 0.3172 - val_iou_score: 0.8013
# Epoch 82/100
# 90/90 [==============================] - 266s 3s/step - loss: 0.0662 - iou_score: 0.9509 - val_loss: 0.3150 - val_iou_score: 0.8027
# Epoch 83/100
# 90/90 [==============================] - 264s 3s/step - loss: 0.0639 - iou_score: 0.9523 - val_loss: 0.3278 - val_iou_score: 0.7982
# Epoch 84/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0658 - iou_score: 0.9510 - val_loss: 0.3318 - val_iou_score: 0.7963
# Epoch 85/100
# 90/90 [==============================] - 252s 3s/step - loss: 0.0643 - iou_score: 0.9524 - val_loss: 0.3237 - val_iou_score: 0.7998
# Epoch 86/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0651 - iou_score: 0.9515 - val_loss: 0.3281 - val_iou_score: 0.8002
# Epoch 87/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0640 - iou_score: 0.9523 - val_loss: 0.3292 - val_iou_score: 0.7986
# Epoch 88/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0641 - iou_score: 0.9524 - val_loss: 0.3335 - val_iou_score: 0.7978
# Epoch 89/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.0634 - iou_score: 0.9528 - val_loss: 0.3277 - val_iou_score: 0.7981
# Epoch 90/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.0628 - iou_score: 0.9528 - val_loss: 0.3298 - val_iou_score: 0.7953
# Epoch 91/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0650 - iou_score: 0.9514 - val_loss: 0.3385 - val_iou_score: 0.7946
# Epoch 92/100
# 90/90 [==============================] - 254s 3s/step - loss: 0.0663 - iou_score: 0.9508 - val_loss: 0.3404 - val_iou_score: 0.7932
# Epoch 93/100
# 90/90 [==============================] - 263s 3s/step - loss: 0.0650 - iou_score: 0.9517 - val_loss: 0.3333 - val_iou_score: 0.7955
# Epoch 94/100
# 90/90 [==============================] - 262s 3s/step - loss: 0.0648 - iou_score: 0.9518 - val_loss: 0.3250 - val_iou_score: 0.7997
# Epoch 95/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0632 - iou_score: 0.9530 - val_loss: 0.3404 - val_iou_score: 0.7959
# Epoch 96/100
# 90/90 [==============================] - 252s 3s/step - loss: 0.0632 - iou_score: 0.9529 - val_loss: 0.3350 - val_iou_score: 0.7986
# Epoch 97/100
# 90/90 [==============================] - 255s 3s/step - loss: 0.0644 - iou_score: 0.9522 - val_loss: 0.3387 - val_iou_score: 0.7950
# Epoch 98/100
# 90/90 [==============================] - 259s 3s/step - loss: 0.0722 - iou_score: 0.9468 - val_loss: 0.4513 - val_iou_score: 0.7287
# Epoch 99/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.1885 - iou_score: 0.8679 - val_loss: 0.6454 - val_iou_score: 0.6256
# Epoch 100/100
# 90/90 [==============================] - 249s 3s/step - loss: 0.1420 - iou_score: 0.8943 - val_loss: 0.3693 - val_iou_score: 0.7617

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']
plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y}).hdf5')

# %%
dir = '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/keras-segmentation/UNet with higher'
model.load_weights(f'{dir}/weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y}).hdf5')

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = []

    image_folder_path = f'{parent_directory}/{split}/{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)

    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
# test_parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'
test_parent_directory = r'/content/FloodNet-Supervised_v1.0'

test_images, test_masks = load_images(test_parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:12<00:00,  3.38it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = f'../../dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)

# %%
pickle_file_path = f'../../dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 224, 224, 3)
# Test Masks: (448, 224, 224, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  66.91465377807617 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)

print(y_pred.shape)
print(test_masks.shape)

predicted_masks = reverse_masks_shape(y_pred)
test_masks = reverse_masks_shape(test_masks)

print(predicted_masks.shape)
print(test_masks.shape)

predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 2s 109ms/step
# (448, 50176, 10)
# (448, 50176, 10)
# (448, 224, 224, 10)
# (448, 224, 224, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0:
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.4161651
# IoU for each class:
# Building Flooded: 0.260065495967865
# Building Non-Flooded: 0.49847176671028137
# Road Flooded: 0.3363546133041382
# Road Non-Flooded: 0.698965847492218
# Water: 0.5918024778366089
# Tree: 0.622666597366333
# Vehicle: 0.11914538592100143
# Pool: 0.04341194033622742
# Grass: 0.7794257998466492
# Mean IoU (excluding Background): 0.43892333

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha='right')

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)

# %%
display_random_function()
# Out:
# Image Shape: (224, 224, 3)
# Ground Truth Mask Shape: (224, 224)
# Predicted Mask Shape: (224, 224)
