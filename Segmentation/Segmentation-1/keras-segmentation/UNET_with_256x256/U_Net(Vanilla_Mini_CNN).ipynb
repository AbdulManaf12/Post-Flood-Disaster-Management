# %%
# !nvidia-smi
# Out:
# Wed Feb 21 04:31:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0              23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from skimage.transform import resize
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

seed = 42
SIZE_X = 448
SIZE_Y = 448
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'Vanilla Mini CNN'

parent_directory = r'/content/FloodNet-Supervised_v1.0'

# %%
# !unzip '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/FloodNet-Supervised_v1.0.zip'

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}

color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128],
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format.
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3))))
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_data_gen_args = dict()
mask_data_gen_args = dict()

image_data_generator = ImageDataGenerator(**img_data_gen_args)
image_generator = image_data_generator.flow_from_directory(f"{parent_directory}/train_images",
                                                           seed=seed,
                                                           batch_size=Batch_size,
                                                           class_mode=None,
                                                           target_size=(SIZE_X, SIZE_Y))

mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
mask_generator = mask_data_generator.flow_from_directory(f"{parent_directory}/train_masks",
                                                         seed=seed,
                                                         batch_size=Batch_size,
                                                         color_mode = 'grayscale',
                                                         class_mode=None,
                                                         target_size=(SIZE_X, SIZE_Y))


valid_img_generator = image_data_generator.flow_from_directory(f"{parent_directory}/val_images",
                                                           seed=seed,
                                                           batch_size=Batch_size,
                                                           class_mode=None,
                                                           target_size=(SIZE_X, SIZE_Y))

valid_mask_generator = mask_data_generator.flow_from_directory(f"{parent_directory}/val_masks",
                                                         seed=seed,
                                                         batch_size=Batch_size,
                                                         color_mode = 'grayscale',
                                                         class_mode=None,
                                                         target_size=(SIZE_X, SIZE_Y))

train_generator = zip(image_generator, mask_generator)
valid_generator = zip(valid_img_generator, valid_mask_generator)
# Out:
# Found 1445 images belonging to 1 classes.
# Found 1445 images belonging to 1 classes.
# Found 450 images belonging to 1 classes.
# Found 450 images belonging to 1 classes.

# %%
batch = next(train_generator)
images, masks = batch

# %%
images.shape, masks.shape
# Out:
# ((8, 448, 448, 3), (8, 448, 448, 1))

# %%
import numpy as np
import random

num = random.randint(0, len(images)-1)
display_images_with_masks((images[num]).astype(np.uint8), np.squeeze(masks[num], axis=-1), np.squeeze(masks[num], axis=-1))

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)

    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], -1, n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
from tensorflow.keras.utils import to_categorical

def load_data(image_generator, mask_generator, preprocessing_function=None):
    for (img, mask) in zip(image_generator, mask_generator):
        img, mask = preprocess_data(img, mask)
        yield (img, mask)

# %%
train_generator = load_data(image_generator, mask_generator)
val_generator = load_data(valid_img_generator, valid_mask_generator)

# %%
batch = next(train_generator)
images, masks = batch

# %%
images[0].shape, masks[0].shape
# Out:
# ((448, 448, 3), (200704, 10))

# %%
images.shape, masks.shape
# Out:
# ((8, 448, 448, 3), (8, 200704, 10))

# %%
# !pip install keras_segmentation
# !pip install segmentation_models
# Out:
# Collecting keras_segmentation
#   Downloading keras_segmentation-0.3.0.tar.gz (23 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Keras>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (2.15.0)
# Collecting imageio==2.5.0 (from keras_segmentation)
#   Downloading imageio-2.5.0-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 13.7 MB/s eta 0:00:00
# Collecting imgaug==0.2.9 (from keras_segmentation)
#   Downloading imgaug-0.2.9-py2.py3-none-any.whl (753 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.3/753.3 kB 34.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (4.8.0.76)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (4.66.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio==2.5.0->keras_segmentation) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imageio==2.5.0->keras_segmentation) (9.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (1.11.4)
# Requirement already satisfied: scikit-image>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (3.7.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (2.0.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (2.8.2)
# Building wheels for collected packages: keras_segmentation
#   Building wheel for keras_segmentation (setup.py) ... done
#   Created wheel for keras_segmentation: filename=keras_segmentation-0.3.0-py3-none-any.whl size=29057 sha256=366ed740ad75ec08e9fb699dd2cef189c283c0b0a51561ac6921b4dc29c61c0c
#   Stored in directory: /root/.cache/pip/wheels/2a/87/5b/ddc104c262fe1280e0565a2cc1b9b6b04963af12e462cdf068
# Successfully built keras_segmentation
# Installing collected packages: imageio, imgaug, keras_segmentation
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.31.6
#     Uninstalling imageio-2.31.6:
#       Successfully uninstalled imageio-2.31.6
#   Attempting uninstall: imgaug
#     Found existing installation: imgaug 0.4.0
#     Uninstalling imgaug-0.4.0:
#       Successfully uninstalled imgaug-0.4.0
# Successfully installed imageio-2.5.0 imgaug-0.2.9 keras_segmentation-0.3.0
# Collecting segmentation_models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation_models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.7 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation_models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation_models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.5.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (23.2)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation_models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation_models-1.0.1

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Segmentation Models: using `tf.keras` framework.
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 448, 448, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 448, 448, 32)         896       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 448, 448, 32)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 448, 448, 32)         9248      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 224, 224, 32)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 224, 224, 64)         18496     ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 224, 224, 64)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 224, 224, 64)         36928     ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 112, 112, 64)         0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 112, 112, 128)        73856     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 112, 112, 128)        0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 112, 112, 128)        147584    ['dropout_2[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 224, 224, 128)        0         ['conv2d_5[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 224, 224, 192)        0         ['up_sampling2d[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 224, 224, 64)         110656    ['concatenate[0][0]']
#
#  dropout_3 (Dropout)         (None, 224, 224, 64)         0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 224, 224, 64)         36928     ['dropout_3[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 448, 448, 64)         0         ['conv2d_7[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 448, 448, 96)         0         ['up_sampling2d_1[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 448, 448, 32)         27680     ['concatenate_1[0][0]']
#
#  dropout_4 (Dropout)         (None, 448, 448, 32)         0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 448, 448, 32)         9248      ['dropout_4[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 448, 448, 10)         330       ['conv2d_9[0][0]']
#
#  reshape (Reshape)           (None, 200704, 10)           0         ['conv2d_10[0][0]']
#
#  activation (Activation)     (None, 200704, 10)           0         ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 471850 (1.80 MB)
# Trainable params: 471850 (1.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.input_shape, model.output_shape
# Out:
# ((None, 448, 448, 3), (None, 200704, 10))

# %%
train_samples = len(os.listdir(f"{parent_directory}/train_images/train"))
val_samples = len(os.listdir(f"{parent_directory}/val_images/val"))
train_samples, val_samples
# Out:
# (1445, 450)

# %%
history = model.fit(train_generator, steps_per_epoch=(train_samples//Batch_size), epochs=EPOCHS, validation_data=val_generator, validation_steps=(val_samples//Batch_size))
# Out:
# Epoch 1/100
# 180/180 [==============================] - 291s 2s/step - loss: 0.9217 - iou_score: 0.3568 - val_loss: 0.8824 - val_iou_score: 0.3699
# Epoch 2/100
# 180/180 [==============================] - 290s 2s/step - loss: 0.8655 - iou_score: 0.3742 - val_loss: 0.8880 - val_iou_score: 0.3399
# Epoch 3/100
# 180/180 [==============================] - 288s 2s/step - loss: 0.8480 - iou_score: 0.3847 - val_loss: 0.8235 - val_iou_score: 0.3900
# Epoch 4/100
# 180/180 [==============================] - 286s 2s/step - loss: 0.8126 - iou_score: 0.4079 - val_loss: 0.8295 - val_iou_score: 0.3882
# Epoch 5/100
# 180/180 [==============================] - 276s 2s/step - loss: 0.7975 - iou_score: 0.4157 - val_loss: 0.7907 - val_iou_score: 0.4225
# Epoch 6/100
# 180/180 [==============================] - 275s 2s/step - loss: 0.7788 - iou_score: 0.4245 - val_loss: 0.7592 - val_iou_score: 0.4323
# Epoch 7/100
# 180/180 [==============================] - 284s 2s/step - loss: 0.7651 - iou_score: 0.4328 - val_loss: 0.7923 - val_iou_score: 0.4314
# Epoch 8/100
# 180/180 [==============================] - 287s 2s/step - loss: 0.7549 - iou_score: 0.4459 - val_loss: 0.7567 - val_iou_score: 0.4352
# Epoch 9/100
# 180/180 [==============================] - 286s 2s/step - loss: 0.7350 - iou_score: 0.4575 - val_loss: 0.7061 - val_iou_score: 0.4819
# Epoch 10/100
# 180/180 [==============================] - 282s 2s/step - loss: 0.7034 - iou_score: 0.4811 - val_loss: 0.6902 - val_iou_score: 0.4826
# Epoch 11/100
# 180/180 [==============================] - 284s 2s/step - loss: 0.6660 - iou_score: 0.5056 - val_loss: 0.6448 - val_iou_score: 0.5273
# Epoch 12/100
# 180/180 [==============================] - 280s 2s/step - loss: 0.6452 - iou_score: 0.5208 - val_loss: 0.6648 - val_iou_score: 0.5043
# Epoch 13/100
# 180/180 [==============================] - 277s 2s/step - loss: 0.6289 - iou_score: 0.5331 - val_loss: 0.6464 - val_iou_score: 0.5209
# Epoch 14/100
# 180/180 [==============================] - 278s 2s/step - loss: 0.6318 - iou_score: 0.5303 - val_loss: 0.6087 - val_iou_score: 0.5474
# Epoch 15/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.6111 - iou_score: 0.5447 - val_loss: 0.6189 - val_iou_score: 0.5421
# Epoch 16/100
# 180/180 [==============================] - 262s 1s/step - loss: 0.6097 - iou_score: 0.5467 - val_loss: 0.6406 - val_iou_score: 0.5281
# Epoch 17/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.6033 - iou_score: 0.5511 - val_loss: 0.6007 - val_iou_score: 0.5621
# Epoch 18/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.5917 - iou_score: 0.5589 - val_loss: 0.6147 - val_iou_score: 0.5445
# Epoch 19/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.5862 - iou_score: 0.5633 - val_loss: 0.5635 - val_iou_score: 0.5787
# Epoch 20/100
# 180/180 [==============================] - 258s 1s/step - loss: 0.5731 - iou_score: 0.5731 - val_loss: 0.5979 - val_iou_score: 0.5522
# Epoch 21/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.5729 - iou_score: 0.5728 - val_loss: 0.5540 - val_iou_score: 0.5847
# Epoch 22/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.5580 - iou_score: 0.5835 - val_loss: 0.5657 - val_iou_score: 0.5834
# Epoch 23/100
# 180/180 [==============================] - 263s 1s/step - loss: 0.5630 - iou_score: 0.5807 - val_loss: 0.5782 - val_iou_score: 0.5678
# Epoch 24/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.5502 - iou_score: 0.5887 - val_loss: 0.5600 - val_iou_score: 0.5865
# Epoch 25/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.5466 - iou_score: 0.5929 - val_loss: 0.5377 - val_iou_score: 0.6006
# Epoch 26/100
# 180/180 [==============================] - 262s 1s/step - loss: 0.5467 - iou_score: 0.5926 - val_loss: 0.5233 - val_iou_score: 0.6087
# Epoch 27/100
# 180/180 [==============================] - 262s 1s/step - loss: 0.5298 - iou_score: 0.6051 - val_loss: 0.5395 - val_iou_score: 0.6007
# Epoch 28/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.5108 - iou_score: 0.6190 - val_loss: 0.5217 - val_iou_score: 0.6171
# Epoch 29/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.5243 - iou_score: 0.6099 - val_loss: 0.5305 - val_iou_score: 0.6039
# Epoch 30/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.5179 - iou_score: 0.6133 - val_loss: 0.5228 - val_iou_score: 0.6233
# Epoch 31/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.4901 - iou_score: 0.6347 - val_loss: 0.5059 - val_iou_score: 0.6289
# Epoch 32/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.5059 - iou_score: 0.6229 - val_loss: 0.5047 - val_iou_score: 0.6221
# Epoch 33/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.4995 - iou_score: 0.6280 - val_loss: 0.4783 - val_iou_score: 0.6424
# Epoch 34/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.4822 - iou_score: 0.6410 - val_loss: 0.4763 - val_iou_score: 0.6432
# Epoch 35/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.4710 - iou_score: 0.6492 - val_loss: 0.5098 - val_iou_score: 0.6232
# Epoch 36/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.4913 - iou_score: 0.6339 - val_loss: 0.4669 - val_iou_score: 0.6519
# Epoch 37/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.4801 - iou_score: 0.6432 - val_loss: 0.4587 - val_iou_score: 0.6574
# Epoch 38/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.4640 - iou_score: 0.6550 - val_loss: 0.4860 - val_iou_score: 0.6364
# Epoch 39/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.4698 - iou_score: 0.6506 - val_loss: 0.4440 - val_iou_score: 0.6696
# Epoch 40/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.4527 - iou_score: 0.6633 - val_loss: 0.6020 - val_iou_score: 0.5633
# Epoch 41/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.4685 - iou_score: 0.6512 - val_loss: 0.4828 - val_iou_score: 0.6446
# Epoch 42/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.4531 - iou_score: 0.6632 - val_loss: 0.4581 - val_iou_score: 0.6576
# Epoch 43/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.4481 - iou_score: 0.6666 - val_loss: 0.4438 - val_iou_score: 0.6705
# Epoch 44/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.4495 - iou_score: 0.6657 - val_loss: 0.4628 - val_iou_score: 0.6572
# Epoch 45/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.4508 - iou_score: 0.6651 - val_loss: 0.4388 - val_iou_score: 0.6742
# Epoch 46/100
# 180/180 [==============================] - 262s 1s/step - loss: 0.4524 - iou_score: 0.6638 - val_loss: 0.4587 - val_iou_score: 0.6582
# Epoch 47/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.4405 - iou_score: 0.6735 - val_loss: 0.4624 - val_iou_score: 0.6570
# Epoch 48/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.4427 - iou_score: 0.6707 - val_loss: 0.4710 - val_iou_score: 0.6483
# Epoch 49/100
# 180/180 [==============================] - 262s 1s/step - loss: 0.4302 - iou_score: 0.6795 - val_loss: 0.4597 - val_iou_score: 0.6634
# Epoch 50/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.4471 - iou_score: 0.6678 - val_loss: 0.4513 - val_iou_score: 0.6613
# Epoch 51/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.4259 - iou_score: 0.6837 - val_loss: 0.4497 - val_iou_score: 0.6671
# Epoch 52/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.4398 - iou_score: 0.6741 - val_loss: 0.4375 - val_iou_score: 0.6747
# Epoch 53/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.4185 - iou_score: 0.6888 - val_loss: 0.4415 - val_iou_score: 0.6724
# Epoch 54/100
# 180/180 [==============================] - 263s 1s/step - loss: 0.4189 - iou_score: 0.6889 - val_loss: 0.4305 - val_iou_score: 0.6816
# Epoch 55/100
# 180/180 [==============================] - 271s 2s/step - loss: 0.4215 - iou_score: 0.6871 - val_loss: 0.4114 - val_iou_score: 0.6939
# Epoch 56/100
# 180/180 [==============================] - 284s 2s/step - loss: 0.4136 - iou_score: 0.6928 - val_loss: 0.4444 - val_iou_score: 0.6678
# Epoch 57/100
# 180/180 [==============================] - 318s 2s/step - loss: 0.4190 - iou_score: 0.6882 - val_loss: 0.4300 - val_iou_score: 0.6872
# Epoch 58/100
# 180/180 [==============================] - 307s 2s/step - loss: 0.4239 - iou_score: 0.6859 - val_loss: 0.4367 - val_iou_score: 0.6752
# Epoch 59/100
# 180/180 [==============================] - 317s 2s/step - loss: 0.4221 - iou_score: 0.6867 - val_loss: 0.4149 - val_iou_score: 0.6928
# Epoch 60/100
# 180/180 [==============================] - 315s 2s/step - loss: 0.3993 - iou_score: 0.7037 - val_loss: 0.4614 - val_iou_score: 0.6586
# Epoch 61/100
# 180/180 [==============================] - 303s 2s/step - loss: 0.4149 - iou_score: 0.6921 - val_loss: 0.4078 - val_iou_score: 0.7001
# Epoch 62/100
# 180/180 [==============================] - 311s 2s/step - loss: 0.4051 - iou_score: 0.6998 - val_loss: 0.4222 - val_iou_score: 0.6866
# Epoch 63/100
# 180/180 [==============================] - 314s 2s/step - loss: 0.4116 - iou_score: 0.6943 - val_loss: 0.4215 - val_iou_score: 0.6865
# Epoch 64/100
# 180/180 [==============================] - 307s 2s/step - loss: 0.4023 - iou_score: 0.7015 - val_loss: 0.4291 - val_iou_score: 0.6817
# Epoch 65/100
# 180/180 [==============================] - 309s 2s/step - loss: 0.4085 - iou_score: 0.6973 - val_loss: 0.4031 - val_iou_score: 0.6981
# Epoch 66/100
# 180/180 [==============================] - 324s 2s/step - loss: 0.4129 - iou_score: 0.6932 - val_loss: 0.4116 - val_iou_score: 0.6952
# Epoch 67/100
# 180/180 [==============================] - 325s 2s/step - loss: 0.4018 - iou_score: 0.7012 - val_loss: 0.4197 - val_iou_score: 0.6886
# Epoch 68/100
# 180/180 [==============================] - 299s 2s/step - loss: 0.3962 - iou_score: 0.7052 - val_loss: 0.4288 - val_iou_score: 0.6853
# Epoch 69/100
# 180/180 [==============================] - 294s 2s/step - loss: 0.3893 - iou_score: 0.7111 - val_loss: 0.4114 - val_iou_score: 0.6971
# Epoch 70/100
# 180/180 [==============================] - 313s 2s/step - loss: 0.4010 - iou_score: 0.7025 - val_loss: 0.4034 - val_iou_score: 0.7054
# Epoch 71/100
# 180/180 [==============================] - 283s 2s/step - loss: 0.3977 - iou_score: 0.7053 - val_loss: 0.4270 - val_iou_score: 0.6830
# Epoch 72/100
# 180/180 [==============================] - 262s 1s/step - loss: 0.3882 - iou_score: 0.7122 - val_loss: 0.4008 - val_iou_score: 0.7033
# Epoch 73/100
# 180/180 [==============================] - 266s 1s/step - loss: 0.4078 - iou_score: 0.6976 - val_loss: 0.4067 - val_iou_score: 0.6975
# Epoch 74/100
# 180/180 [==============================] - 271s 2s/step - loss: 0.3898 - iou_score: 0.7102 - val_loss: 0.4006 - val_iou_score: 0.7045
# Epoch 75/100
# 180/180 [==============================] - 268s 1s/step - loss: 0.3946 - iou_score: 0.7071 - val_loss: 0.4454 - val_iou_score: 0.6695
# Epoch 76/100
# 180/180 [==============================] - 268s 1s/step - loss: 0.3875 - iou_score: 0.7117 - val_loss: 0.3956 - val_iou_score: 0.7096
# Epoch 77/100
# 180/180 [==============================] - 269s 1s/step - loss: 0.3829 - iou_score: 0.7161 - val_loss: 0.4038 - val_iou_score: 0.7014
# Epoch 78/100
# 180/180 [==============================] - 292s 2s/step - loss: 0.3867 - iou_score: 0.7129 - val_loss: 0.3973 - val_iou_score: 0.7086
# Epoch 79/100
# 180/180 [==============================] - 290s 2s/step - loss: 0.3975 - iou_score: 0.7050 - val_loss: 0.4149 - val_iou_score: 0.6984
# Epoch 80/100
# 180/180 [==============================] - 280s 2s/step - loss: 0.3909 - iou_score: 0.7105 - val_loss: 0.3927 - val_iou_score: 0.7078
# Epoch 81/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.3787 - iou_score: 0.7184 - val_loss: 0.3924 - val_iou_score: 0.7087
# Epoch 82/100
# 180/180 [==============================] - 262s 1s/step - loss: 0.3927 - iou_score: 0.7085 - val_loss: 0.4012 - val_iou_score: 0.7008
# Epoch 83/100
# 180/180 [==============================] - 262s 1s/step - loss: 0.3854 - iou_score: 0.7143 - val_loss: 0.3985 - val_iou_score: 0.7020
# Epoch 84/100
# 180/180 [==============================] - 263s 1s/step - loss: 0.3810 - iou_score: 0.7165 - val_loss: 0.3921 - val_iou_score: 0.7074
# Epoch 85/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.3898 - iou_score: 0.7112 - val_loss: 0.3936 - val_iou_score: 0.7098
# Epoch 86/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.3790 - iou_score: 0.7184 - val_loss: 0.3884 - val_iou_score: 0.7135
# Epoch 87/100
# 180/180 [==============================] - 262s 1s/step - loss: 0.3851 - iou_score: 0.7140 - val_loss: 0.3911 - val_iou_score: 0.7081
# Epoch 88/100
# 180/180 [==============================] - 261s 1s/step - loss: 0.3709 - iou_score: 0.7245 - val_loss: 0.3974 - val_iou_score: 0.7041
# Epoch 89/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.3774 - iou_score: 0.7203 - val_loss: 0.3901 - val_iou_score: 0.7105
# Epoch 90/100
# 180/180 [==============================] - 257s 1s/step - loss: 0.3894 - iou_score: 0.7104 - val_loss: 0.3901 - val_iou_score: 0.7082
# Epoch 91/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.3681 - iou_score: 0.7267 - val_loss: 0.3987 - val_iou_score: 0.7022
# Epoch 92/100
# 180/180 [==============================] - 258s 1s/step - loss: 0.3684 - iou_score: 0.7262 - val_loss: 0.3909 - val_iou_score: 0.7093
# Epoch 93/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.3831 - iou_score: 0.7149 - val_loss: 0.3960 - val_iou_score: 0.7044
# Epoch 94/100
# 180/180 [==============================] - 260s 1s/step - loss: 0.3769 - iou_score: 0.7192 - val_loss: 0.3863 - val_iou_score: 0.7159
# Epoch 95/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.3706 - iou_score: 0.7248 - val_loss: 0.3870 - val_iou_score: 0.7129
# Epoch 96/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.3800 - iou_score: 0.7185 - val_loss: 0.3996 - val_iou_score: 0.7043
# Epoch 97/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.3759 - iou_score: 0.7214 - val_loss: 0.4040 - val_iou_score: 0.6974
# Epoch 98/100
# 180/180 [==============================] - 258s 1s/step - loss: 0.3569 - iou_score: 0.7349 - val_loss: 0.3830 - val_iou_score: 0.7166
# Epoch 99/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.3672 - iou_score: 0.7278 - val_loss: 0.3967 - val_iou_score: 0.7043
# Epoch 100/100
# 180/180 [==============================] - 259s 1s/step - loss: 0.3771 - iou_score: 0.7201 - val_loss: 0.3791 - val_iou_score: 0.7215

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']
plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y}).hdf5')

# %%
model.load_weights(f'/content/drive/MyDrive/Experiments/weights/UNET_model_with_100_epochs(UNET_Vanilla mini cnn)-(448x448).hdf5')
# model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y}).hdf5')

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = []

    image_folder_path = f'{parent_directory}/{split}/{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)

    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
test_parent_directory = r'/content/FloodNet-Supervised_v1.0'

test_images, test_masks = load_images(test_parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [01:52<00:00,  3.98it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = f'../../dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)

# %%
pickle_file_path = f'../../dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 224, 224, 3)
# Test Masks: (448, 224, 224, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  48.932307958602905 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)

print(y_pred.shape)
print(test_masks.shape)

predicted_masks = reverse_masks_shape(y_pred)
test_masks = reverse_masks_shape(test_masks)

print(predicted_masks.shape)
print(test_masks.shape)

predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 8s 116ms/step
# (448, 200704, 10)
# (448, 200704, 10)
# (448, 448, 448, 10)
# (448, 448, 448, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0:
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.24138856
# IoU for each class:
# Building Flooded: 0.23635540902614594
# Building Non-Flooded: 0.1997734010219574
# Road Flooded: 0.22727607190608978
# Road Non-Flooded: 0.4709557592868805
# Water: 0.4487113952636719
# Tree: 0.30302268266677856
# Vehicle: 0.08824257552623749
# Pool: 0.0016126445261761546
# Grass: 0.42434486746788025
# Mean IoU (excluding Background): 0.2666994

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha='right')

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (448, 448, 3)
# Ground Truth Mask Shape: (448, 448)
# Predicted Mask Shape: (448, 448)

# %%
display_random_function()
# Out:
# Image Shape: (448, 448, 3)
# Ground Truth Mask Shape: (448, 448)
# Predicted Mask Shape: (448, 448)

# %%
display_random_function()
# Out:
# Image Shape: (448, 448, 3)
# Ground Truth Mask Shape: (448, 448)
# Predicted Mask Shape: (448, 448)

# %%
display_random_function()
# Out:
# Image Shape: (448, 448, 3)
# Ground Truth Mask Shape: (448, 448)
# Predicted Mask Shape: (448, 448)

# %%
display_random_function()
# Out:
# Image Shape: (448, 448, 3)
# Ground Truth Mask Shape: (448, 448)
# Predicted Mask Shape: (448, 448)
