# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from keras.metrics import MeanIoU
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 144
SIZE_Y = 144
n_channels = 3
n_classes = 10
Batch_size = 16
EPOCHS = 100
MODEL = 'pspnet'
BACKBONE = 'mobilenetv2'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')
# Out:
# 100%|██████████| 1445/1445 [07:44<00:00,  3.11it/s]
# TRAIN: Images loaded: 1445
# TRAIN: Masks loaded: 1445
# 100%|██████████| 450/450 [02:41<00:00,  2.79it/s]
# VAL: Images loaded: 450
# VAL: Masks loaded: 450

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

# pickle_file_path = '../dataset/train_and_val_data.pickle'
pickle_file_path = f'../../dataset/train_and_val_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to ../dataset/train_and_val_data(144x144).pickle
# Shapes of loaded data:
# Train Images: (1445, 144, 144, 3)
# Train Masks: (1445, 144, 144)
# Val Images: (450, 144, 144, 3)
# Val Masks: (450, 144, 144)

# %%
# pickle_file_path = '../../dataset/train_and_val_data.pickle'
pickle_file_path = f'../../dataset/train_and_val_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 144, 144, 3)
# Train Masks: (1445, 144, 144)
# Val Images: (450, 144, 144, 3)
# Val Masks: (450, 144, 144)

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 144, 144, 3)
# Train Masks: (1445, 144, 144, 10)
# Val Images: (450, 144, 144, 3)
# Val Masks: (450, 144, 144, 10)

# %%
import tensorflow as tf

if MODEL == 'unet':
    model = sm.Unet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'fpn':
    model = sm.FPN(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
else:
    raise ValueError('Unknown model')

base_learning_rate = 0.0001
momentum = 0.9
weight_decay = 0.0001
power = 0.9
weight_auxiliary_loss = 0.4

# Define the polynomial learning rate decay schedule
learning_rate_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=base_learning_rate,
    decay_steps=EPOCHS,  # Decay steps set to total epochs for a full decay
    end_learning_rate=0.0,      # End learning rate set to 0
    power=power
)

# Define the optimizer with custom parameters
optimizer = tf.keras.optimizers.Adam(
    learning_rate=learning_rate_schedule,
    beta_1=momentum,
    beta_2=0.999,  # Default value for beta_2
    epsilon=1e-7,  # Default value for epsilon
    decay=weight_decay,
    amsgrad=False  # Default value for amsgrad
)

model.compile(optimizer=optimizer, loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
# model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 144, 144, 3  0           []
#                                 )]
#
#  Conv1_pad (ZeroPadding2D)      (None, 145, 145, 3)  0           ['input_1[0][0]']
#
#  Conv1 (Conv2D)                 (None, 72, 72, 32)   864         ['Conv1_pad[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 72, 72, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 72, 72, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 72, 72, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 72, 72, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 72, 72, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 72, 72, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 72, 72, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 72, 72, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 72, 72, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 72, 72, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 73, 73, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 36, 36, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 36, 36, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 36, 36, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 36, 36, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 36, 36, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 36, 36, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 36, 36, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 36, 36, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 36, 36, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 36, 36, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 36, 36, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 36, 36, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 36, 36, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 36, 36, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 36, 36, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 36, 36, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 36, 36, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 37, 37, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 18, 18, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 18, 18, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 18, 18, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 18, 18, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 18, 18, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 18, 18, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 18, 18, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 18, 18, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 18, 18, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 18, 18, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 18, 18, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 18, 18, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 18, 18, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 18, 18, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 18, 18, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 18, 18, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 18, 18, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 18, 18, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 18, 18, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 18, 18, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 18, 18, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 18, 18, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 18, 18, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 18, 18, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 18, 18, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 18, 18, 192)  0           ['block_6_expand_BN[0][0]']
#
#  psp_level1_pooling (AveragePoo  (None, 1, 1, 192)   0           ['block_6_expand_relu[0][0]']
#  ling2D)
#
#  psp_level2_pooling (AveragePoo  (None, 2, 2, 192)   0           ['block_6_expand_relu[0][0]']
#  ling2D)
#
#  psp_level3_pooling (AveragePoo  (None, 3, 3, 192)   0           ['block_6_expand_relu[0][0]']
#  ling2D)
#
#  psp_level6_pooling (AveragePoo  (None, 6, 6, 192)   0           ['block_6_expand_relu[0][0]']
#  ling2D)
#
#  psp_level1_conv (Conv2D)       (None, 1, 1, 512)    98304       ['psp_level1_pooling[0][0]']
#
#  psp_level2_conv (Conv2D)       (None, 2, 2, 512)    98304       ['psp_level2_pooling[0][0]']
#
#  psp_level3_conv (Conv2D)       (None, 3, 3, 512)    98304       ['psp_level3_pooling[0][0]']
#
#  psp_level6_conv (Conv2D)       (None, 6, 6, 512)    98304       ['psp_level6_pooling[0][0]']
#
#  psp_level1_bn (BatchNormalizat  (None, 1, 1, 512)   2048        ['psp_level1_conv[0][0]']
#  ion)
#
#  psp_level2_bn (BatchNormalizat  (None, 2, 2, 512)   2048        ['psp_level2_conv[0][0]']
#  ion)
#
#  psp_level3_bn (BatchNormalizat  (None, 3, 3, 512)   2048        ['psp_level3_conv[0][0]']
#  ion)
#
#  psp_level6_bn (BatchNormalizat  (None, 6, 6, 512)   2048        ['psp_level6_conv[0][0]']
#  ion)
#
#  psp_level1_relu (Activation)   (None, 1, 1, 512)    0           ['psp_level1_bn[0][0]']
#
#  psp_level2_relu (Activation)   (None, 2, 2, 512)    0           ['psp_level2_bn[0][0]']
#
#  psp_level3_relu (Activation)   (None, 3, 3, 512)    0           ['psp_level3_bn[0][0]']
#
#  psp_level6_relu (Activation)   (None, 6, 6, 512)    0           ['psp_level6_bn[0][0]']
#
#  psp_level1_upsampling (UpSampl  (None, 18, 18, 512)  0          ['psp_level1_relu[0][0]']
#  ing2D)
#
#  psp_level2_upsampling (UpSampl  (None, 18, 18, 512)  0          ['psp_level2_relu[0][0]']
#  ing2D)
#
#  psp_level3_upsampling (UpSampl  (None, 18, 18, 512)  0          ['psp_level3_relu[0][0]']
#  ing2D)
#
#  psp_level6_upsampling (UpSampl  (None, 18, 18, 512)  0          ['psp_level6_relu[0][0]']
#  ing2D)
#
#  psp_concat (Concatenate)       (None, 18, 18, 2240  0           ['block_6_expand_relu[0][0]',
#                                 )                                 'psp_level1_upsampling[0][0]',
#                                                                   'psp_level2_upsampling[0][0]',
#                                                                   'psp_level3_upsampling[0][0]',
#                                                                   'psp_level6_upsampling[0][0]']
#
#  aggregation_conv (Conv2D)      (None, 18, 18, 512)  1146880     ['psp_concat[0][0]']
#
#  aggregation_bn (BatchNormaliza  (None, 18, 18, 512)  2048       ['aggregation_conv[0][0]']
#  tion)
#
#  aggregation_relu (Activation)  (None, 18, 18, 512)  0           ['aggregation_bn[0][0]']
#
#  final_conv (Conv2D)            (None, 18, 18, 10)   46090       ['aggregation_relu[0][0]']
#
#  final_upsampling (UpSampling2D  (None, 144, 144, 10  0          ['final_conv[0][0]']
#  )                              )
#
#  softmax (Activation)           (None, 144, 144, 10  0           ['final_upsampling[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 1,662,346
# Trainable params: 1,653,322
# Non-trainable params: 9,024
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 91/91 [==============================] - 11s 64ms/step - loss: 1.0031 - iou_score: 0.1918 - val_loss: 1.0804 - val_iou_score: 0.1091
# Epoch 2/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8899 - iou_score: 0.2451 - val_loss: 1.0383 - val_iou_score: 0.1246
# Epoch 3/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8883 - iou_score: 0.2472 - val_loss: 1.0550 - val_iou_score: 0.1165
# Epoch 4/100
# 91/91 [==============================] - 4s 48ms/step - loss: 0.8911 - iou_score: 0.2437 - val_loss: 1.0656 - val_iou_score: 0.1131
# Epoch 5/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8868 - iou_score: 0.2484 - val_loss: 1.0642 - val_iou_score: 0.1149
# Epoch 6/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8882 - iou_score: 0.2460 - val_loss: 1.0563 - val_iou_score: 0.1194
# Epoch 7/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8901 - iou_score: 0.2457 - val_loss: 1.0460 - val_iou_score: 0.1249
# Epoch 8/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8898 - iou_score: 0.2449 - val_loss: 1.0355 - val_iou_score: 0.1306
# Epoch 9/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.8893 - iou_score: 0.2459 - val_loss: 1.0255 - val_iou_score: 0.1361
# Epoch 10/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.8929 - iou_score: 0.2427 - val_loss: 1.0165 - val_iou_score: 0.1413
# Epoch 11/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.8893 - iou_score: 0.2461 - val_loss: 1.0074 - val_iou_score: 0.1462
# Epoch 12/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8915 - iou_score: 0.2440 - val_loss: 1.0005 - val_iou_score: 0.1502
# Epoch 13/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8919 - iou_score: 0.2438 - val_loss: 0.9938 - val_iou_score: 0.1541
# Epoch 14/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.8905 - iou_score: 0.2443 - val_loss: 0.9881 - val_iou_score: 0.1573
# Epoch 15/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.8859 - iou_score: 0.2482 - val_loss: 0.9830 - val_iou_score: 0.1604
# Epoch 16/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8888 - iou_score: 0.2462 - val_loss: 0.9784 - val_iou_score: 0.1632
# Epoch 17/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8872 - iou_score: 0.2476 - val_loss: 0.9749 - val_iou_score: 0.1654
# Epoch 18/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8869 - iou_score: 0.2479 - val_loss: 0.9713 - val_iou_score: 0.1677
# Epoch 19/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8914 - iou_score: 0.2437 - val_loss: 0.9683 - val_iou_score: 0.1697
# Epoch 20/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.8911 - iou_score: 0.2442 - val_loss: 0.9658 - val_iou_score: 0.1713
# Epoch 21/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.8900 - iou_score: 0.2459 - val_loss: 0.9635 - val_iou_score: 0.1729
# Epoch 22/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8896 - iou_score: 0.2459 - val_loss: 0.9616 - val_iou_score: 0.1742
# Epoch 23/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8930 - iou_score: 0.2428 - val_loss: 0.9598 - val_iou_score: 0.1754
# Epoch 24/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8949 - iou_score: 0.2410 - val_loss: 0.9585 - val_iou_score: 0.1764
# Epoch 25/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.8934 - iou_score: 0.2421 - val_loss: 0.9574 - val_iou_score: 0.1772
# Epoch 26/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.8897 - iou_score: 0.2458 - val_loss: 0.9563 - val_iou_score: 0.1780
# Epoch 27/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.8911 - iou_score: 0.2438 - val_loss: 0.9552 - val_iou_score: 0.1789
# Epoch 28/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.8892 - iou_score: 0.2461 - val_loss: 0.9544 - val_iou_score: 0.1795
# Epoch 29/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8879 - iou_score: 0.2469 - val_loss: 0.9534 - val_iou_score: 0.1802
# Epoch 30/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8888 - iou_score: 0.2466 - val_loss: 0.9526 - val_iou_score: 0.1808
# Epoch 31/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.8907 - iou_score: 0.2439 - val_loss: 0.9522 - val_iou_score: 0.1811
# Epoch 32/100
# 91/91 [==============================] - 4s 48ms/step - loss: 0.8936 - iou_score: 0.2427 - val_loss: 0.9518 - val_iou_score: 0.1815
# Epoch 33/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8930 - iou_score: 0.2439 - val_loss: 0.9512 - val_iou_score: 0.1819
# Epoch 34/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8889 - iou_score: 0.2470 - val_loss: 0.9511 - val_iou_score: 0.1821
# Epoch 35/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8883 - iou_score: 0.2473 - val_loss: 0.9509 - val_iou_score: 0.1823
# Epoch 36/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8872 - iou_score: 0.2472 - val_loss: 0.9506 - val_iou_score: 0.1825
# Epoch 37/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.8892 - iou_score: 0.2460 - val_loss: 0.9504 - val_iou_score: 0.1827
# Epoch 38/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8929 - iou_score: 0.2424 - val_loss: 0.9501 - val_iou_score: 0.1829
# Epoch 39/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8877 - iou_score: 0.2466 - val_loss: 0.9497 - val_iou_score: 0.1833
# Epoch 40/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8923 - iou_score: 0.2436 - val_loss: 0.9497 - val_iou_score: 0.1833
# Epoch 41/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.8920 - iou_score: 0.2436 - val_loss: 0.9494 - val_iou_score: 0.1836
# Epoch 42/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.8873 - iou_score: 0.2481 - val_loss: 0.9493 - val_iou_score: 0.1836
# Epoch 43/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8891 - iou_score: 0.2463 - val_loss: 0.9491 - val_iou_score: 0.1838
# Epoch 44/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.8927 - iou_score: 0.2428 - val_loss: 0.9491 - val_iou_score: 0.1839
# Epoch 45/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8935 - iou_score: 0.2421 - val_loss: 0.9489 - val_iou_score: 0.1840
# Epoch 46/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.8947 - iou_score: 0.2407 - val_loss: 0.9489 - val_iou_score: 0.1841
# Epoch 47/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8846 - iou_score: 0.2496 - val_loss: 0.9489 - val_iou_score: 0.1840
# Epoch 48/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.8901 - iou_score: 0.2451 - val_loss: 0.9486 - val_iou_score: 0.1842
# Epoch 49/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.8924 - iou_score: 0.2437 - val_loss: 0.9485 - val_iou_score: 0.1843
# Epoch 50/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8872 - iou_score: 0.2477 - val_loss: 0.9484 - val_iou_score: 0.1844
# Epoch 51/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8912 - iou_score: 0.2451 - val_loss: 0.9482 - val_iou_score: 0.1846
# Epoch 52/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8875 - iou_score: 0.2474 - val_loss: 0.9484 - val_iou_score: 0.1845
# Epoch 53/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8867 - iou_score: 0.2482 - val_loss: 0.9482 - val_iou_score: 0.1846
# Epoch 54/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8887 - iou_score: 0.2464 - val_loss: 0.9484 - val_iou_score: 0.1845
# Epoch 55/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8860 - iou_score: 0.2475 - val_loss: 0.9483 - val_iou_score: 0.1846
# Epoch 56/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8874 - iou_score: 0.2473 - val_loss: 0.9482 - val_iou_score: 0.1846
# Epoch 57/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8869 - iou_score: 0.2475 - val_loss: 0.9482 - val_iou_score: 0.1847
# Epoch 58/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8891 - iou_score: 0.2466 - val_loss: 0.9480 - val_iou_score: 0.1847
# Epoch 59/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8909 - iou_score: 0.2441 - val_loss: 0.9481 - val_iou_score: 0.1847
# Epoch 60/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8932 - iou_score: 0.2419 - val_loss: 0.9483 - val_iou_score: 0.1847
# Epoch 61/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8915 - iou_score: 0.2428 - val_loss: 0.9484 - val_iou_score: 0.1846
# Epoch 62/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8875 - iou_score: 0.2476 - val_loss: 0.9483 - val_iou_score: 0.1847
# Epoch 63/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8872 - iou_score: 0.2484 - val_loss: 0.9480 - val_iou_score: 0.1848
# Epoch 64/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8899 - iou_score: 0.2442 - val_loss: 0.9483 - val_iou_score: 0.1847
# Epoch 65/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8871 - iou_score: 0.2473 - val_loss: 0.9482 - val_iou_score: 0.1847
# Epoch 66/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8917 - iou_score: 0.2432 - val_loss: 0.9481 - val_iou_score: 0.1848
# Epoch 67/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8890 - iou_score: 0.2463 - val_loss: 0.9481 - val_iou_score: 0.1848
# Epoch 68/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8912 - iou_score: 0.2445 - val_loss: 0.9480 - val_iou_score: 0.1848
# Epoch 69/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8898 - iou_score: 0.2457 - val_loss: 0.9481 - val_iou_score: 0.1848
# Epoch 70/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8882 - iou_score: 0.2474 - val_loss: 0.9479 - val_iou_score: 0.1850
# Epoch 71/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8917 - iou_score: 0.2434 - val_loss: 0.9479 - val_iou_score: 0.1850
# Epoch 72/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8877 - iou_score: 0.2470 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 73/100
# 91/91 [==============================] - 5s 57ms/step - loss: 0.8883 - iou_score: 0.2472 - val_loss: 0.9479 - val_iou_score: 0.1849
# Epoch 74/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8881 - iou_score: 0.2465 - val_loss: 0.9479 - val_iou_score: 0.1849
# Epoch 75/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8906 - iou_score: 0.2455 - val_loss: 0.9481 - val_iou_score: 0.1848
# Epoch 76/100
# 91/91 [==============================] - 4s 48ms/step - loss: 0.8929 - iou_score: 0.2427 - val_loss: 0.9481 - val_iou_score: 0.1848
# Epoch 77/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8892 - iou_score: 0.2460 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 78/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8920 - iou_score: 0.2440 - val_loss: 0.9479 - val_iou_score: 0.1850
# Epoch 79/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8873 - iou_score: 0.2479 - val_loss: 0.9478 - val_iou_score: 0.1850
# Epoch 80/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8935 - iou_score: 0.2424 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 81/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8899 - iou_score: 0.2451 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 82/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8950 - iou_score: 0.2405 - val_loss: 0.9481 - val_iou_score: 0.1848
# Epoch 83/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.8921 - iou_score: 0.2430 - val_loss: 0.9482 - val_iou_score: 0.1848
# Epoch 84/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8891 - iou_score: 0.2462 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 85/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8905 - iou_score: 0.2445 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 86/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8937 - iou_score: 0.2421 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 87/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8872 - iou_score: 0.2479 - val_loss: 0.9478 - val_iou_score: 0.1850
# Epoch 88/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8919 - iou_score: 0.2436 - val_loss: 0.9477 - val_iou_score: 0.1851
# Epoch 89/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8888 - iou_score: 0.2468 - val_loss: 0.9478 - val_iou_score: 0.1851
# Epoch 90/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8895 - iou_score: 0.2460 - val_loss: 0.9479 - val_iou_score: 0.1850
# Epoch 91/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8931 - iou_score: 0.2425 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 92/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8889 - iou_score: 0.2455 - val_loss: 0.9479 - val_iou_score: 0.1850
# Epoch 93/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8950 - iou_score: 0.2409 - val_loss: 0.9481 - val_iou_score: 0.1849
# Epoch 94/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8925 - iou_score: 0.2439 - val_loss: 0.9482 - val_iou_score: 0.1848
# Epoch 95/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8882 - iou_score: 0.2467 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 96/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8922 - iou_score: 0.2430 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 97/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8915 - iou_score: 0.2444 - val_loss: 0.9480 - val_iou_score: 0.1849
# Epoch 98/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8889 - iou_score: 0.2455 - val_loss: 0.9481 - val_iou_score: 0.1848
# Epoch 99/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.8909 - iou_score: 0.2439 - val_loss: 0.9479 - val_iou_score: 0.1850
# Epoch 100/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.8898 - iou_score: 0.2450 - val_loss: 0.9480 - val_iou_score: 0.1850

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images
# Out:
# 100%|██████████| 448/448 [02:13<00:00,  3.37it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data(144x144).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data(144x144).pickle
# Shapes of loaded data:
# Test Images: (448, 144, 144, 3)
# Test Masks: (448, 144, 144)

# %%
pickle_file_path = '../../dataset/test_data(144x144).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 144, 144, 3)
# Test Masks: (448, 144, 144, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  19.720828533172607 %

# %%
y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 1s 16ms/step
# (448, 144, 144)
# (448, 144, 144)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.30936056
# IoU for each class:
# Building Flooded: 0.2919832468032837
# Building Non-Flooded: 0.36099180579185486
# Road Flooded: 0.2456158548593521
# Road Non-Flooded: 0.42950019240379333
# Water: 0.5666104555130005
# Tree: 0.4715668261051178
# Vehicle: 0.0
# Pool: 0.0
# Grass: 0.7272260785102844
# Mean IoU (excluding Background): 0.3437216

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (144, 144, 3)
# Ground Truth Mask Shape: (144, 144)
# Predicted Mask Shape: (144, 144)

# %%
display_random_function()
# Out:
# Image Shape: (144, 144, 3)
# Ground Truth Mask Shape: (144, 144)
# Predicted Mask Shape: (144, 144)

# %%
display_random_function()
# Out:
# Image Shape: (144, 144, 3)
# Ground Truth Mask Shape: (144, 144)
# Predicted Mask Shape: (144, 144)

# %%
display_random_function()
# Out:
# Image Shape: (144, 144, 3)
# Ground Truth Mask Shape: (144, 144)
# Predicted Mask Shape: (144, 144)

# %%
display_random_function()
# Out:
# Image Shape: (144, 144, 3)
# Ground Truth Mask Shape: (144, 144)
# Predicted Mask Shape: (144, 144)
