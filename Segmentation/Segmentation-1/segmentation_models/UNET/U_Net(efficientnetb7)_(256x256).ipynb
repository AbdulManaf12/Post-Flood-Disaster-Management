# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/FloodNet-Supervised_v1.0.zip'
# Out:
# Archive:  /content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/FloodNet-Supervised_v1.0.zip
#    creating: FloodNet-Supervised_v1.0/
#   inflating: FloodNet-Supervised_v1.0/DATASET-VERSION-NOTE-v1.0.txt
#    creating: FloodNet-Supervised_v1.0/test/
#    creating: FloodNet-Supervised_v1.0/test/test-label-img/
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10163.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10164.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10167.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10174.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10183.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10808.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10812.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10813.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10814.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10823.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10829.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10838.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10839.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/10843.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/11483.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6336.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6342.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6353.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6362.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6371.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6377.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6383.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6389.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6391.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6394.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6405.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6412.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6417.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6419.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6420.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6445.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6449.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6452.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6467.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6468.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6476.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6488.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6514.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6517.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6536.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6545.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6550.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6553.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6557.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6558.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6561.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6562.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6567.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6568.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6583.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6590.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6593.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6594.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6602.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6619.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6624.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6632.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6638.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6659.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6663.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6671.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6672.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6677.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6679.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6680.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6688.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6691.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6695.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6700.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6717.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6718.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6733.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6744.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6751.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6761.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6765.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6768.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6771.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6774.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6775.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6778.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6780.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6785.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6786.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6794.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6795.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6796.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6809.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6815.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6825.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6827.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6831.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6844.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6850.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6856.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6893.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6895.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6896.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6898.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6905.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6906.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6907.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6910.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6912.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6915.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6920.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6927.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6951.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6952.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6954.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6959.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6961.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6963.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/6979.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7004.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7016.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7023.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7029.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7031.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7035.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7041.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7042.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7054.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7056.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7057.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7063.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7069.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7085.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7092.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7105.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7126.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7141.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7143.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7149.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7154.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7158.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7172.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7191.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7213.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7215.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7220.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7223.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7231.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7232.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7233.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7241.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7253.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7268.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7279.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7284.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7291.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7294.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7300.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7301.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7307.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7308.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7315.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7320.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7323.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7333.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7339.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7348.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7355.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7359.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7361.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7370.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7376.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7406.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7413.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7415.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7420.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7423.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7431.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7450.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7457.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7461.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7464.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7476.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7486.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7541.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7543.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7577.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7581.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7583.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7584.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7586.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7590.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7593.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7595.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7604.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7605.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7611.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7616.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7644.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7647.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7651.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7652.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7658.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7666.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7684.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7689.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7690.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7698.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7708.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7723.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7730.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7733.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7740.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7743.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7755.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7757.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7758.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7759.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7763.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7771.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7772.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7773.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7780.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7794.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7803.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7804.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7812.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7813.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7817.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7821.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7822.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7835.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7839.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7840.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7853.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7866.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7874.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7876.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7877.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7880.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7881.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7888.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7889.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7899.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7903.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7904.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7906.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7911.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7915.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7921.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7926.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7927.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7928.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7930.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7935.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7946.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7956.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7957.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7960.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7961.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7964.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7969.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7983.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7985.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7986.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7993.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7995.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/7997.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8007.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8017.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8018.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8021.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8022.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8026.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8027.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8028.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8031.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8040.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8041.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8048.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8062.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8064.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8066.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8069.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8073.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8076.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8100.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8103.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8104.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8111.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8112.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8115.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8125.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8126.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8136.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8140.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8147.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8154.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8160.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8162.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8169.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8170.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8183.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8189.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8194.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8195.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8199.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8201.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8203.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8211.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8214.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8219.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8233.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8237.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8250.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8259.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8262.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8279.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8287.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8290.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8292.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8293.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8302.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8303.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8307.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8308.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8309.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8310.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8316.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8324.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8329.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8332.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8338.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8339.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8340.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8341.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8343.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8346.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8356.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8358.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8362.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8363.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8364.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8367.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8372.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8376.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8378.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8391.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8397.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8399.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8401.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8402.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8421.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8428.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8439.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8440.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8447.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8462.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8478.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8486.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8494.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8511.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8514.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8523.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8525.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8530.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8533.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8541.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8542.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8543.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8544.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8557.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8558.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8592.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8601.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8762.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8767.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8773.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8776.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8778.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8781.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8784.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8789.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8792.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8795.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8797.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8810.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8812.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8814.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8815.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8860.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8898.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8902.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8912.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8919.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8926.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8930.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8934.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8937.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8942.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8945.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8948.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8949.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8959.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8961.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8972.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8981.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8983.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8989.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8991.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8993.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/8999.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9001.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9002.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9004.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9006.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9009.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9012.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9013.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9018.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9032.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9035.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9037.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9042.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9044.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9045.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9054.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9055.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9056.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9058.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9060.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9067.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9068.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9082.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9092.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9096.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9107.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9109.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9112.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9113.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9114.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9231.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9344.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9348.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9367.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9539.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9721.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9872.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9878.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9883.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9886.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9889.png
#   inflating: FloodNet-Supervised_v1.0/test/test-label-img/9891.png
#    creating: FloodNet-Supervised_v1.0/test/test-org-img/
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10163.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10164.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10167.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10174.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10183.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10808.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10812.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10813.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10814.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10823.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10829.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10838.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10839.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/10843.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/11483.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6336.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6342.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6353.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6362.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6371.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6377.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6383.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6389.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6391.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6394.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6405.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6412.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6417.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6419.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6420.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6445.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6449.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6452.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6467.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6468.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6476.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6488.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6514.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6517.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6536.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6545.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6550.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6553.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6557.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6558.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6561.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6562.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6567.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6568.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6583.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6590.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6593.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6594.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6602.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6619.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6624.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6632.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6638.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6659.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6663.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6671.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6672.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6677.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6679.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6680.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6688.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6691.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6695.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6700.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6717.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6718.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6733.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6744.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6751.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6761.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6765.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6768.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6771.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6774.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6775.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6778.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6780.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6785.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6786.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6794.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6795.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6796.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6809.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6815.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6825.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6827.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6831.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6844.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6850.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6856.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6893.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6895.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6896.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6898.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6905.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6906.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6907.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6910.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6912.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6915.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6920.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6927.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6951.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6952.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6954.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6959.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6961.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6963.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/6979.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7004.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7016.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7023.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7029.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7031.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7035.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7041.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7042.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7054.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7056.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7057.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7063.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7069.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7085.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7092.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7105.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7126.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7141.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7143.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7149.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7154.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7158.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7172.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7191.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7213.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7215.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7220.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7223.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7231.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7232.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7233.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7241.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7253.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7268.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7279.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7284.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7291.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7294.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7300.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7301.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7307.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7308.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7315.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7320.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7323.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7333.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7339.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7348.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7355.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7359.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7361.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7370.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7376.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7406.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7413.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7415.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7420.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7423.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7431.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7450.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7457.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7461.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7464.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7476.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7486.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7541.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7543.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7577.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7581.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7583.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7584.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7586.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7590.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7593.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7595.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7604.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7605.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7611.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7616.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7644.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7647.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7651.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7652.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7658.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7666.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7684.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7689.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7690.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7698.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7708.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7723.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7730.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7733.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7740.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7743.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7755.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7757.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7758.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7759.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7763.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7771.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7772.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7773.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7780.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7794.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7803.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7804.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7812.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7813.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7817.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7821.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7822.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7835.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7839.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7840.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7853.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7866.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7874.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7876.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7877.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7880.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7881.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7888.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7889.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7899.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7903.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7904.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7906.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7911.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7915.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7921.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7926.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7927.jpg
#   inflating: FloodNet-Supervised_v1.0/test/test-org-img/7928.jpg
# ...
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7558.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7569.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7570.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7572.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7576.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7578.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7588.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7592.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7598.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7599.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7607.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7608.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7610.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7613.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7642.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7649.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7656.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7657.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7660.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7663.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7667.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7668.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7669.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7676.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7679.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7683.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7687.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7694.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7699.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7701.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7716.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7732.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7734.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7738.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7741.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7742.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7747.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7762.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7769.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7779.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7781.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7785.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7790.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7793.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7797.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7799.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7811.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7819.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7823.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7824.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7826.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7836.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7838.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7846.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7850.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7851.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7854.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7860.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7885.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7886.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7887.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7891.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7897.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7898.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7900.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7912.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7913.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7943.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7955.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7970.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7976.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7978.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7984.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7988.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7990.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7991.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7992.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/7994.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8004.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8006.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8012.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8019.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8025.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8035.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8036.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8050.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8054.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8058.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8067.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8071.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8078.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8079.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8084.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8088.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8092.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8097.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8105.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8113.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8114.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8120.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8124.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8127.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8128.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8144.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8155.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8163.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8171.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8179.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8180.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8181.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8186.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8187.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8188.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8191.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8198.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8204.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8209.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8213.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8218.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8220.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8238.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8239.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8246.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8254.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8257.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8258.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8263.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8266.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8268.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8270.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8273.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8283.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8285.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8289.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8291.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8295.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8296.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8300.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8301.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8323.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8325.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8327.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8328.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8331.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8333.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8337.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8349.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8353.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8360.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8365.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8373.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8377.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8395.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8414.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8435.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8441.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8444.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8466.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8468.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8471.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8474.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8489.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8503.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8505.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8509.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8513.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8519.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8532.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8534.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8537.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8549.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8554.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8559.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8591.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8595.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8596.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8602.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8620.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8624.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8771.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8772.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8779.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8780.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8782.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8787.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8788.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8790.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8793.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8806.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8808.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8811.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8813.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8819.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8896.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8897.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8899.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8903.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8908.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8913.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8920.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8936.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8939.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8941.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8944.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8946.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8950.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8954.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8964.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8976.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8979.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8985.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8988.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8990.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8992.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/8997.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9005.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9014.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9016.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9020.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9024.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9031.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9041.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9046.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9048.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9051.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9057.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9097.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9102.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9313.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9347.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9350.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9352.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9364.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9458.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9460.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9504.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9536.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9726.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9746.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9873.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9881.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9882.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9888.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9893.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9923.jpg
#   inflating: FloodNet-Supervised_v1.0/val/val-org-img/9924.jpg

# %%
# !nvidia-smi
# Out:
# Wed Feb 21 06:23:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0              41W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 256
SIZE_Y = 256
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'efficientnetb7'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'/content/FloodNet-Supervised_v1.0'
folder_path = f'/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/UNET'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = []

    image_folder_path = f'{parent_directory}/{split}/{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)

    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)

    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}

color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128],
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format.
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3))))
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')
# Out:
# 100%|██████████| 450/450 [01:58<00:00,  3.79it/s]
# VAL: Images loaded: 450
# VAL: Masks loaded: 450

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = f'{folder_path}/dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to /content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/UNET/dataset/train_and_val_data.pickle
# Shapes of loaded data:
# Train Images: (1445, 256, 256, 3)
# Train Masks: (1445, 256, 256)
# Val Images: (450, 256, 256, 3)
# Val Masks: (450, 256, 256)

# %%
pickle_file_path = f'{folder_path}/dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 256, 256, 3)
# Train Masks: (1445, 256, 256)
# Val Images: (450, 256, 256, 3)
# Val Masks: (450, 256, 256)

# %%
random_image_num = np.random.randint(0, train_images.shape[0])
display_images_with_masks(train_images[random_image_num], train_masks[random_image_num], train_masks[random_image_num])

# %%
# !pip install segmentation_models
# Out:
# Collecting segmentation_models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation_models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 7.1 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation_models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation_models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (23.2)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation_models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation_models-1.0.1

# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `tf.keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 256, 256, 3)
# Train Masks: (1445, 256, 256, 10)
# Val Images: (450, 256, 256, 3)
# Val Masks: (450, 256, 256, 10)

# %%
if MODEL == 'unet':
    model = sm.Unet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'fpn':
    model = sm.FPN(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
else:
    raise ValueError('Unknown model')

model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b7_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 258434480/258434480 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  stem_conv (Conv2D)          (None, 128, 128, 64)         1728      ['input_1[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 128, 128, 64)         256       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 128, 128, 64)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 128, 128, 64)         576       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 128, 128, 64)         256       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 128, 128, 64)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 64)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 64)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 16)             1040      ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 64)             1088      ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 128, 128, 64)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 128, 128, 32)         2048      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 128, 128, 32)         128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 128, 128, 32)         288       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 128, 128, 32)         128       ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 128, 128, 32)         0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 32)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 128, 128, 32)         0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 128, 128, 32)         1024      ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 128, 128, 32)         128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (FixedDropout  (None, 128, 128, 32)         0         ['block1b_project_bn[0][0]']
#  )
#
#  block1b_add (Add)           (None, 128, 128, 32)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 128, 128, 32)         288       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 128, 128, 32)         128       ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 128, 128, 32)         0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 32)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 128, 128, 32)         0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 128, 128, 32)         1024      ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 128, 128, 32)         128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (FixedDropout  (None, 128, 128, 32)         0         ['block1c_project_bn[0][0]']
#  )
#
#  block1c_add (Add)           (None, 128, 128, 32)         0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseC  (None, 128, 128, 32)         288       ['block1c_add[0][0]']
#  onv2D)
#
#  block1d_bn (BatchNormaliza  (None, 128, 128, 32)         128       ['block1d_dwconv[0][0]']
#  tion)
#
#  block1d_activation (Activa  (None, 128, 128, 32)         0         ['block1d_bn[0][0]']
#  tion)
#
#  block1d_se_squeeze (Global  (None, 32)                   0         ['block1d_activation[0][0]']
#  AveragePooling2D)
#
#  block1d_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1d_se_squeeze[0][0]']
#  e)
#
#  block1d_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multipl  (None, 128, 128, 32)         0         ['block1d_activation[0][0]',
#  y)                                                                  'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv  (None, 128, 128, 32)         1024      ['block1d_se_excite[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 128, 128, 32)         128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_drop (FixedDropout  (None, 128, 128, 32)         0         ['block1d_project_bn[0][0]']
#  )
#
#  block1d_add (Add)           (None, 128, 128, 32)         0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 128, 128, 192)        6144      ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 128, 128, 192)        768       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 128, 128, 192)        0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv (DepthwiseC  (None, 64, 64, 192)          1728      ['block2a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2a_bn (BatchNormaliza  (None, 64, 64, 192)          768       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 64, 64, 192)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 192)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 64, 64, 192)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 64, 64, 48)           9216      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 64, 64, 288)          13824     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 64, 64, 288)          1152      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 64, 64, 288)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 64, 64, 288)          2592      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 64, 64, 288)          1152      ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 64, 64, 288)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 288)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 64, 64, 288)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 64, 64, 48)           13824     ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (FixedDropout  (None, 64, 64, 48)           0         ['block2b_project_bn[0][0]']
#  )
#
#  block2b_add (Add)           (None, 64, 64, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 64, 64, 288)          13824     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 64, 64, 288)          1152      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 64, 64, 288)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 64, 64, 288)          2592      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 64, 64, 288)          1152      ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 64, 64, 288)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 288)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 64, 64, 288)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 64, 64, 48)           13824     ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (FixedDropout  (None, 64, 64, 48)           0         ['block2c_project_bn[0][0]']
#  )
#
#  block2c_add (Add)           (None, 64, 64, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 64, 64, 288)          13824     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 64, 64, 288)          1152      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 64, 64, 288)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 64, 64, 288)          2592      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 64, 64, 288)          1152      ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 64, 64, 288)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 288)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 64, 64, 288)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 64, 64, 48)           13824     ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (FixedDropout  (None, 64, 64, 48)           0         ['block2d_project_bn[0][0]']
#  )
#
#  block2d_add (Add)           (None, 64, 64, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 64, 64, 288)          13824     ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 64, 64, 288)          1152      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 64, 64, 288)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 64, 64, 288)          2592      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 64, 64, 288)          1152      ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 64, 64, 288)          0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 288)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 64, 64, 288)          0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 64, 64, 48)           13824     ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (FixedDropout  (None, 64, 64, 48)           0         ['block2e_project_bn[0][0]']
#  )
#
#  block2e_add (Add)           (None, 64, 64, 48)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 64, 64, 288)          13824     ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 64, 64, 288)          1152      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 64, 64, 288)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_dwconv (DepthwiseC  (None, 64, 64, 288)          2592      ['block2f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2f_bn (BatchNormaliza  (None, 64, 64, 288)          1152      ['block2f_dwconv[0][0]']
#  tion)
#
#  block2f_activation (Activa  (None, 64, 64, 288)          0         ['block2f_bn[0][0]']
#  tion)
#
#  block2f_se_squeeze (Global  (None, 288)                  0         ['block2f_activation[0][0]']
#  AveragePooling2D)
#
#  block2f_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2f_se_squeeze[0][0]']
#  e)
#
#  block2f_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multipl  (None, 64, 64, 288)          0         ['block2f_activation[0][0]',
#  y)                                                                  'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv  (None, 64, 64, 48)           13824     ['block2f_se_excite[0][0]']
#  2D)
#
#  block2f_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (FixedDropout  (None, 64, 64, 48)           0         ['block2f_project_bn[0][0]']
#  )
#
#  block2f_add (Add)           (None, 64, 64, 48)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 64, 64, 288)          13824     ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 64, 64, 288)          1152      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 64, 64, 288)          0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_dwconv (DepthwiseC  (None, 64, 64, 288)          2592      ['block2g_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2g_bn (BatchNormaliza  (None, 64, 64, 288)          1152      ['block2g_dwconv[0][0]']
#  tion)
#
#  block2g_activation (Activa  (None, 64, 64, 288)          0         ['block2g_bn[0][0]']
#  tion)
#
#  block2g_se_squeeze (Global  (None, 288)                  0         ['block2g_activation[0][0]']
#  AveragePooling2D)
#
#  block2g_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2g_se_squeeze[0][0]']
#  e)
#
#  block2g_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multipl  (None, 64, 64, 288)          0         ['block2g_activation[0][0]',
#  y)                                                                  'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv  (None, 64, 64, 48)           13824     ['block2g_se_excite[0][0]']
#  2D)
#
#  block2g_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (FixedDropout  (None, 64, 64, 48)           0         ['block2g_project_bn[0][0]']
#  )
#
#  block2g_add (Add)           (None, 64, 64, 48)           0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 64, 64, 288)          13824     ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 64, 64, 288)          1152      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 64, 64, 288)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv (DepthwiseC  (None, 32, 32, 288)          7200      ['block3a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3a_bn (BatchNormaliza  (None, 32, 32, 288)          1152      ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 32, 32, 288)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 288)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 32, 32, 288)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 32, 32, 80)           23040     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 32, 32, 80)           320       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 32, 32, 480)          38400     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 32, 32, 480)          1920      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 32, 32, 480)          0         ['block3b_expand_bn[0][0]']
# ...
#  e)
#
#  block7d_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multipl  (None, 8, 8, 3840)           0         ['block7d_activation[0][0]',
#  y)                                                                  'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv  (None, 8, 8, 640)            2457600   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 8, 8, 640)            2560      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (FixedDropout  (None, 8, 8, 640)            0         ['block7d_project_bn[0][0]']
#  )
#
#  block7d_add (Add)           (None, 8, 8, 640)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  top_conv (Conv2D)           (None, 8, 8, 2560)           1638400   ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 8, 8, 2560)           10240     ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 8, 8, 2560)           0         ['top_bn[0][0]']
#  )
#
#  decoder_stage0_upsampling   (None, 16, 16, 2560)         0         ['top_activation[0][0]']
#  (UpSampling2D)
#
#  decoder_stage0_concat (Con  (None, 16, 16, 3904)         0         ['decoder_stage0_upsampling[0]
#  catenate)                                                          [0]',
#                                                                      'block6a_expand_activation[0]
#                                                                     [0]']
#
#  decoder_stage0a_conv (Conv  (None, 16, 16, 256)          8994816   ['decoder_stage0_concat[0][0]'
#  2D)                                                                ]
#
#  decoder_stage0a_bn (BatchN  (None, 16, 16, 256)          1024      ['decoder_stage0a_conv[0][0]']
#  ormalization)
#
#  decoder_stage0a_relu (Acti  (None, 16, 16, 256)          0         ['decoder_stage0a_bn[0][0]']
#  vation)
#
#  decoder_stage0b_conv (Conv  (None, 16, 16, 256)          589824    ['decoder_stage0a_relu[0][0]']
#  2D)
#
#  decoder_stage0b_bn (BatchN  (None, 16, 16, 256)          1024      ['decoder_stage0b_conv[0][0]']
#  ormalization)
#
#  decoder_stage0b_relu (Acti  (None, 16, 16, 256)          0         ['decoder_stage0b_bn[0][0]']
#  vation)
#
#  decoder_stage1_upsampling   (None, 32, 32, 256)          0         ['decoder_stage0b_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage1_concat (Con  (None, 32, 32, 736)          0         ['decoder_stage1_upsampling[0]
#  catenate)                                                          [0]',
#                                                                      'block4a_expand_activation[0]
#                                                                     [0]']
#
#  decoder_stage1a_conv (Conv  (None, 32, 32, 128)          847872    ['decoder_stage1_concat[0][0]'
#  2D)                                                                ]
#
#  decoder_stage1a_bn (BatchN  (None, 32, 32, 128)          512       ['decoder_stage1a_conv[0][0]']
#  ormalization)
#
#  decoder_stage1a_relu (Acti  (None, 32, 32, 128)          0         ['decoder_stage1a_bn[0][0]']
#  vation)
#
#  decoder_stage1b_conv (Conv  (None, 32, 32, 128)          147456    ['decoder_stage1a_relu[0][0]']
#  2D)
#
#  decoder_stage1b_bn (BatchN  (None, 32, 32, 128)          512       ['decoder_stage1b_conv[0][0]']
#  ormalization)
#
#  decoder_stage1b_relu (Acti  (None, 32, 32, 128)          0         ['decoder_stage1b_bn[0][0]']
#  vation)
#
#  decoder_stage2_upsampling   (None, 64, 64, 128)          0         ['decoder_stage1b_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage2_concat (Con  (None, 64, 64, 416)          0         ['decoder_stage2_upsampling[0]
#  catenate)                                                          [0]',
#                                                                      'block3a_expand_activation[0]
#                                                                     [0]']
#
#  decoder_stage2a_conv (Conv  (None, 64, 64, 64)           239616    ['decoder_stage2_concat[0][0]'
#  2D)                                                                ]
#
#  decoder_stage2a_bn (BatchN  (None, 64, 64, 64)           256       ['decoder_stage2a_conv[0][0]']
#  ormalization)
#
#  decoder_stage2a_relu (Acti  (None, 64, 64, 64)           0         ['decoder_stage2a_bn[0][0]']
#  vation)
#
#  decoder_stage2b_conv (Conv  (None, 64, 64, 64)           36864     ['decoder_stage2a_relu[0][0]']
#  2D)
#
#  decoder_stage2b_bn (BatchN  (None, 64, 64, 64)           256       ['decoder_stage2b_conv[0][0]']
#  ormalization)
#
#  decoder_stage2b_relu (Acti  (None, 64, 64, 64)           0         ['decoder_stage2b_bn[0][0]']
#  vation)
#
#  decoder_stage3_upsampling   (None, 128, 128, 64)         0         ['decoder_stage2b_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage3_concat (Con  (None, 128, 128, 256)        0         ['decoder_stage3_upsampling[0]
#  catenate)                                                          [0]',
#                                                                      'block2a_expand_activation[0]
#                                                                     [0]']
#
#  decoder_stage3a_conv (Conv  (None, 128, 128, 32)         73728     ['decoder_stage3_concat[0][0]'
#  2D)                                                                ]
#
#  decoder_stage3a_bn (BatchN  (None, 128, 128, 32)         128       ['decoder_stage3a_conv[0][0]']
#  ormalization)
#
#  decoder_stage3a_relu (Acti  (None, 128, 128, 32)         0         ['decoder_stage3a_bn[0][0]']
#  vation)
#
#  decoder_stage3b_conv (Conv  (None, 128, 128, 32)         9216      ['decoder_stage3a_relu[0][0]']
#  2D)
#
#  decoder_stage3b_bn (BatchN  (None, 128, 128, 32)         128       ['decoder_stage3b_conv[0][0]']
#  ormalization)
#
#  decoder_stage3b_relu (Acti  (None, 128, 128, 32)         0         ['decoder_stage3b_bn[0][0]']
#  vation)
#
#  decoder_stage4_upsampling   (None, 256, 256, 32)         0         ['decoder_stage3b_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage4a_conv (Conv  (None, 256, 256, 16)         4608      ['decoder_stage4_upsampling[0]
#  2D)                                                                [0]']
#
#  decoder_stage4a_bn (BatchN  (None, 256, 256, 16)         64        ['decoder_stage4a_conv[0][0]']
#  ormalization)
#
#  decoder_stage4a_relu (Acti  (None, 256, 256, 16)         0         ['decoder_stage4a_bn[0][0]']
#  vation)
#
#  decoder_stage4b_conv (Conv  (None, 256, 256, 16)         2304      ['decoder_stage4a_relu[0][0]']
#  2D)
#
#  decoder_stage4b_bn (BatchN  (None, 256, 256, 16)         64        ['decoder_stage4b_conv[0][0]']
#  ormalization)
#
#  decoder_stage4b_relu (Acti  (None, 256, 256, 16)         0         ['decoder_stage4b_bn[0][0]']
#  vation)
#
#  final_conv (Conv2D)         (None, 256, 256, 10)         1450      ['decoder_stage4b_relu[0][0]']
#
#  softmax (Activation)        (None, 256, 256, 10)         0         ['final_conv[0][0]']
#
# ==================================================================================================
# Total params: 75049402 (286.29 MB)
# Trainable params: 74736698 (285.10 MB)
# Non-trainable params: 312704 (1.19 MB)
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 180s 257ms/step - loss: 0.9614 - iou_score: 0.2346 - val_loss: 0.8872 - val_iou_score: 0.2509
# Epoch 2/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.7432 - iou_score: 0.3641 - val_loss: 3.9690 - val_iou_score: 0.1031
# Epoch 3/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.6716 - iou_score: 0.4226 - val_loss: 0.6654 - val_iou_score: 0.4276
# Epoch 4/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.6426 - iou_score: 0.4461 - val_loss: 0.6421 - val_iou_score: 0.4517
# Epoch 5/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.6087 - iou_score: 0.4752 - val_loss: 0.6624 - val_iou_score: 0.4357
# Epoch 6/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.5871 - iou_score: 0.4946 - val_loss: 0.5598 - val_iou_score: 0.5133
# Epoch 7/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.5465 - iou_score: 0.5291 - val_loss: 0.6205 - val_iou_score: 0.4833
# Epoch 8/100
# 181/181 [==============================] - 37s 204ms/step - loss: 0.5435 - iou_score: 0.5295 - val_loss: 0.5497 - val_iou_score: 0.5248
# Epoch 9/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.5464 - iou_score: 0.5263 - val_loss: 0.5562 - val_iou_score: 0.5241
# Epoch 10/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.5202 - iou_score: 0.5499 - val_loss: 0.5578 - val_iou_score: 0.5161
# Epoch 11/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.5124 - iou_score: 0.5551 - val_loss: 0.5501 - val_iou_score: 0.5263
# Epoch 12/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.5035 - iou_score: 0.5599 - val_loss: 0.5293 - val_iou_score: 0.5427
# Epoch 13/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4998 - iou_score: 0.5634 - val_loss: 0.5614 - val_iou_score: 0.5196
# Epoch 14/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4923 - iou_score: 0.5697 - val_loss: 0.5236 - val_iou_score: 0.5481
# Epoch 15/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4959 - iou_score: 0.5662 - val_loss: 0.5421 - val_iou_score: 0.5365
# Epoch 16/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4861 - iou_score: 0.5745 - val_loss: 0.5489 - val_iou_score: 0.5385
# Epoch 17/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4860 - iou_score: 0.5735 - val_loss: 0.5223 - val_iou_score: 0.5459
# Epoch 18/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4735 - iou_score: 0.5860 - val_loss: 0.5096 - val_iou_score: 0.5557
# Epoch 19/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4732 - iou_score: 0.5852 - val_loss: 0.5029 - val_iou_score: 0.5638
# Epoch 20/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4710 - iou_score: 0.5868 - val_loss: 0.4993 - val_iou_score: 0.5628
# Epoch 21/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4631 - iou_score: 0.5931 - val_loss: 0.4956 - val_iou_score: 0.5674
# Epoch 22/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4560 - iou_score: 0.5983 - val_loss: 0.9018 - val_iou_score: 0.3761
# Epoch 23/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4480 - iou_score: 0.6066 - val_loss: 0.5003 - val_iou_score: 0.5657
# Epoch 24/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4527 - iou_score: 0.6002 - val_loss: 0.5125 - val_iou_score: 0.5649
# Epoch 25/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4465 - iou_score: 0.6053 - val_loss: 0.4889 - val_iou_score: 0.5733
# Epoch 26/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4375 - iou_score: 0.6119 - val_loss: 0.5109 - val_iou_score: 0.5604
# Epoch 27/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4286 - iou_score: 0.6199 - val_loss: 0.4756 - val_iou_score: 0.5839
# Epoch 28/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4285 - iou_score: 0.6183 - val_loss: 0.4903 - val_iou_score: 0.5753
# Epoch 29/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4192 - iou_score: 0.6272 - val_loss: 0.5568 - val_iou_score: 0.5318
# Epoch 30/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4211 - iou_score: 0.6254 - val_loss: 0.5022 - val_iou_score: 0.5678
# Epoch 31/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4155 - iou_score: 0.6303 - val_loss: 0.4901 - val_iou_score: 0.5715
# Epoch 32/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4102 - iou_score: 0.6337 - val_loss: 0.4905 - val_iou_score: 0.5792
# Epoch 33/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.4079 - iou_score: 0.6370 - val_loss: 0.4860 - val_iou_score: 0.5830
# Epoch 34/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4050 - iou_score: 0.6383 - val_loss: 0.4801 - val_iou_score: 0.5822
# Epoch 35/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4105 - iou_score: 0.6337 - val_loss: 0.5235 - val_iou_score: 0.5507
# Epoch 36/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4026 - iou_score: 0.6387 - val_loss: 0.4755 - val_iou_score: 0.5895
# Epoch 37/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4015 - iou_score: 0.6417 - val_loss: 0.4836 - val_iou_score: 0.5861
# Epoch 38/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3962 - iou_score: 0.6446 - val_loss: 0.4927 - val_iou_score: 0.5805
# Epoch 39/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4019 - iou_score: 0.6418 - val_loss: 0.5079 - val_iou_score: 0.5630
# Epoch 40/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4026 - iou_score: 0.6398 - val_loss: 0.5041 - val_iou_score: 0.5698
# Epoch 41/100
# 181/181 [==============================] - 37s 205ms/step - loss: 0.3934 - iou_score: 0.6480 - val_loss: 0.4845 - val_iou_score: 0.5840
# Epoch 42/100
# 181/181 [==============================] - 37s 204ms/step - loss: 0.3889 - iou_score: 0.6509 - val_loss: 0.5186 - val_iou_score: 0.5510
# Epoch 43/100
# 181/181 [==============================] - 37s 205ms/step - loss: 0.3943 - iou_score: 0.6475 - val_loss: 0.5081 - val_iou_score: 0.5685
# Epoch 44/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.3913 - iou_score: 0.6509 - val_loss: 0.5132 - val_iou_score: 0.5630
# Epoch 45/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3924 - iou_score: 0.6488 - val_loss: 0.4901 - val_iou_score: 0.5774
# Epoch 46/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3771 - iou_score: 0.6611 - val_loss: 0.4918 - val_iou_score: 0.5791
# Epoch 47/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3793 - iou_score: 0.6584 - val_loss: 0.4875 - val_iou_score: 0.5840
# Epoch 48/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3772 - iou_score: 0.6603 - val_loss: 0.4820 - val_iou_score: 0.5858
# Epoch 49/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3755 - iou_score: 0.6623 - val_loss: 0.4815 - val_iou_score: 0.5870
# Epoch 50/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3752 - iou_score: 0.6602 - val_loss: 0.4820 - val_iou_score: 0.5874
# Epoch 51/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3656 - iou_score: 0.6708 - val_loss: 0.5001 - val_iou_score: 0.5773
# Epoch 52/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.4022 - iou_score: 0.6410 - val_loss: 0.4839 - val_iou_score: 0.5850
# Epoch 53/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3684 - iou_score: 0.6687 - val_loss: 0.4748 - val_iou_score: 0.5885
# Epoch 54/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3674 - iou_score: 0.6687 - val_loss: 0.4765 - val_iou_score: 0.5893
# Epoch 55/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3573 - iou_score: 0.6780 - val_loss: 0.4834 - val_iou_score: 0.5883
# Epoch 56/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3649 - iou_score: 0.6695 - val_loss: 0.4661 - val_iou_score: 0.5981
# Epoch 57/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3588 - iou_score: 0.6748 - val_loss: 0.4725 - val_iou_score: 0.5944
# Epoch 58/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3559 - iou_score: 0.6768 - val_loss: 0.4986 - val_iou_score: 0.5848
# Epoch 59/100
# 181/181 [==============================] - 37s 205ms/step - loss: 0.3665 - iou_score: 0.6690 - val_loss: 0.4780 - val_iou_score: 0.5873
# Epoch 60/100
# 181/181 [==============================] - 37s 205ms/step - loss: 0.3461 - iou_score: 0.6856 - val_loss: 0.4691 - val_iou_score: 0.5956
# Epoch 61/100
# 181/181 [==============================] - 37s 204ms/step - loss: 0.3703 - iou_score: 0.6656 - val_loss: 0.4927 - val_iou_score: 0.5856
# Epoch 62/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3634 - iou_score: 0.6690 - val_loss: 0.4858 - val_iou_score: 0.5835
# Epoch 63/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3662 - iou_score: 0.6701 - val_loss: 0.4983 - val_iou_score: 0.5803
# Epoch 64/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3692 - iou_score: 0.6657 - val_loss: 0.4798 - val_iou_score: 0.5905
# Epoch 65/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3464 - iou_score: 0.6857 - val_loss: 0.4888 - val_iou_score: 0.5885
# Epoch 66/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3713 - iou_score: 0.6666 - val_loss: 0.4811 - val_iou_score: 0.5908
# Epoch 67/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3644 - iou_score: 0.6692 - val_loss: 0.4714 - val_iou_score: 0.5947
# Epoch 68/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3519 - iou_score: 0.6804 - val_loss: 0.4809 - val_iou_score: 0.5889
# Epoch 69/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3455 - iou_score: 0.6860 - val_loss: 0.4810 - val_iou_score: 0.5913
# Epoch 70/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3514 - iou_score: 0.6803 - val_loss: 0.4746 - val_iou_score: 0.5917
# Epoch 71/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.3456 - iou_score: 0.6863 - val_loss: 0.4684 - val_iou_score: 0.5967
# Epoch 72/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3494 - iou_score: 0.6819 - val_loss: 0.5012 - val_iou_score: 0.5856
# Epoch 73/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.3542 - iou_score: 0.6782 - val_loss: 0.4734 - val_iou_score: 0.5962
# Epoch 74/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.3403 - iou_score: 0.6894 - val_loss: 0.4696 - val_iou_score: 0.5989
# Epoch 75/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.3491 - iou_score: 0.6805 - val_loss: 0.5207 - val_iou_score: 0.5768
# Epoch 76/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3464 - iou_score: 0.6855 - val_loss: 0.4900 - val_iou_score: 0.5878
# Epoch 77/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.3569 - iou_score: 0.6750 - val_loss: 0.4866 - val_iou_score: 0.5902
# Epoch 78/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3527 - iou_score: 0.6802 - val_loss: 0.4929 - val_iou_score: 0.5787
# Epoch 79/100
# 181/181 [==============================] - 36s 202ms/step - loss: 0.3508 - iou_score: 0.6799 - val_loss: 0.4818 - val_iou_score: 0.5875
# Epoch 80/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3425 - iou_score: 0.6878 - val_loss: 0.4882 - val_iou_score: 0.5875
# Epoch 81/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3339 - iou_score: 0.6947 - val_loss: 0.4758 - val_iou_score: 0.5952
# Epoch 82/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3543 - iou_score: 0.6786 - val_loss: 0.5214 - val_iou_score: 0.5625
# Epoch 83/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3639 - iou_score: 0.6690 - val_loss: 0.4865 - val_iou_score: 0.5883
# Epoch 84/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3447 - iou_score: 0.6852 - val_loss: 0.4718 - val_iou_score: 0.5995
# Epoch 85/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.3274 - iou_score: 0.6997 - val_loss: 0.4670 - val_iou_score: 0.6018
# Epoch 86/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3292 - iou_score: 0.6969 - val_loss: 0.4788 - val_iou_score: 0.5945
# Epoch 87/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3408 - iou_score: 0.6895 - val_loss: 0.4919 - val_iou_score: 0.5830
# Epoch 88/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3362 - iou_score: 0.6926 - val_loss: 0.4901 - val_iou_score: 0.5867
# Epoch 89/100
# 181/181 [==============================] - 36s 202ms/step - loss: 0.3322 - iou_score: 0.6954 - val_loss: 0.4868 - val_iou_score: 0.5926
# Epoch 90/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3177 - iou_score: 0.7089 - val_loss: 0.4706 - val_iou_score: 0.5964
# Epoch 91/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3366 - iou_score: 0.6908 - val_loss: 0.4807 - val_iou_score: 0.5964
# Epoch 92/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.3385 - iou_score: 0.6913 - val_loss: 0.4701 - val_iou_score: 0.5993
# Epoch 93/100
# 181/181 [==============================] - 37s 203ms/step - loss: 0.3356 - iou_score: 0.6913 - val_loss: 0.4666 - val_iou_score: 0.6034
# Epoch 94/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3397 - iou_score: 0.6878 - val_loss: 0.4716 - val_iou_score: 0.5988
# Epoch 95/100
# 181/181 [==============================] - 36s 202ms/step - loss: 0.3236 - iou_score: 0.7024 - val_loss: 0.4664 - val_iou_score: 0.6043
# Epoch 96/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3295 - iou_score: 0.6974 - val_loss: 0.4687 - val_iou_score: 0.5993
# Epoch 97/100
# 181/181 [==============================] - 36s 202ms/step - loss: 0.3242 - iou_score: 0.7022 - val_loss: 0.4802 - val_iou_score: 0.5982
# Epoch 98/100
# 181/181 [==============================] - 37s 202ms/step - loss: 0.3289 - iou_score: 0.6976 - val_loss: 0.4665 - val_iou_score: 0.6026
# Epoch 99/100
# 181/181 [==============================] - 36s 202ms/step - loss: 0.3205 - iou_score: 0.7052 - val_loss: 0.4667 - val_iou_score: 0.6036
# Epoch 100/100
# 181/181 [==============================] - 36s 201ms/step - loss: 0.3313 - iou_score: 0.6943 - val_loss: 0.4676 - val_iou_score: 0.6032

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'{folder_path}/weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)
# Out:
# 100%|██████████| 448/448 [01:48<00:00,  4.14it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = f'{folder_path}/dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to /content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/UNET/dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 256, 256, 3)
# Test Masks: (448, 256, 256, 10)

# %%
pickle_file_path = f'{folder_path}/dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 256, 256, 3)
# Test Masks: (448, 256, 256, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  69.98142600059509 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 6s 117ms/step
# (448, 256, 256)
# (448, 256, 256)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0:
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.71127856
# IoU for each class:
# Building Flooded: 0.7241079211235046
# Building Non-Flooded: 0.7931119799613953
# Road Flooded: 0.6545457243919373
# Road Non-Flooded: 0.8322752118110657
# Water: 0.7884145379066467
# Tree: 0.8444666862487793
# Vehicle: 0.4714009761810303
# Pool: 0.534946858882904
# Grass: 0.9052640199661255
# Mean IoU (excluding Background): 0.7276148

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha='right')

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)
