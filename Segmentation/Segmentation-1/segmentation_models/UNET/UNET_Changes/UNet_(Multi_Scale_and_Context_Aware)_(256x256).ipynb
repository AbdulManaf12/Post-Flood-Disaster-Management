# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset'
# Out:
# 'test_data(256x256).pickle'           'train_and_val_data(448x448).pickle'
# 'train_and_val_data(256x256).pickle'

# %%
# !unzip '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/FloodNet-Supervised_v1.0.zip'

# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 256
SIZE_Y = 256
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'efficientnetb7'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = []

    image_folder_path = f'{parent_directory}/{split}/{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)

    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)

    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}

color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128],
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format.
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3))))
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/train_and_val_data(256x256).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 256, 256, 3)
# Train Masks: (1445, 256, 256)
# Val Images: (450, 256, 256, 3)
# Val Masks: (450, 256, 256)

# %%
num = 100
display_images_with_masks(train_images[num], train_masks[num], train_masks[num])

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 256, 256, 3)
# Train Masks: (1445, 256, 256, 10)
# Val Images: (450, 256, 256, 3)
# Val Masks: (450, 256, 256, 10)

# %%
# !pip install segmentation_models
# Out:
# Collecting segmentation_models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation_models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.1 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation_models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation_models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (23.2)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation_models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation_models-1.0.1

# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Concatenate, Softmax
from tensorflow.keras.layers import concatenate, BatchNormalization, UpSampling2D, Activation, Conv2DTranspose

def res_inception_unit(input_layer, filters):
    # First convolutional block
    conv1x1_1 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv1x1_1 = BatchNormalization()(conv1x1_1)

    # Second convolutional block
    conv1x1_2 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv3x3_2 = Conv2D(filters, (3, 3), padding='same')(conv1x1_2)
    conv3x3_2 = BatchNormalization()(conv3x3_2)

    # Third convolutional block
    conv1x1_3 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv3x3_3 = Conv2D(filters, (3, 3), padding='same')(conv1x1_3)
    conv3x3_3 = BatchNormalization()(conv3x3_3)
    conv3x3_3 = Conv2D(filters, (3, 3), padding='same')(conv3x3_3)
    conv3x3_3 = BatchNormalization()(conv3x3_3)

    concatenated = concatenate([conv1x1_1, conv3x3_2, conv3x3_3], axis=-1)

    output = Conv2D(filters, (1, 1), padding='same')(concatenated)
    output = Activation('relu')(output)
    return output

def pyramid_pooling_module(input_layer, levels=[1, 2, 4, 8]):
    pooled_outputs = []
    for level in levels:
        pooled = MaxPooling2D(pool_size=(level, level))(input_layer)
        pooled = Conv2D(filters=input_layer.shape[-1], kernel_size=(1, 1), padding='same', activation='relu')(pooled)
        pooled_outputs.append(pooled)
    upsampled_outputs = [UpSampling2D(size=(level, level))(pooled) for level, pooled in zip(levels, pooled_outputs)]
    concatenated = Concatenate(axis=-1)([input_layer] + upsampled_outputs)
    return concatenated

def dense_upsampling_convolution(input_layer, filters):
    x = Conv2DTranspose(filters, kernel_size=(3, 3), strides=(2, 2), padding='same')(input_layer)
    x = Conv2D(filters, kernel_size=(3, 3), padding='same')(x)
    return x

def encoder(inputs, encoder_filters):
    encoder_outputs = [inputs]
    for i, filters in enumerate(encoder_filters):
        x = res_inception_unit(encoder_outputs[-1], filters)
        encoder_outputs.append(MaxPooling2D(pool_size=(2, 2))(x) if i < len(encoder_filters) - 1 else x)
    return encoder_outputs

def decoder(global_feature_map, encoder_outputs, decoder_filters):
    x = global_feature_map
    for i, filters in enumerate(decoder_filters):
        x = dense_upsampling_convolution(x, filters)
        encoder_output = encoder_outputs[-(i + 2)]

        if encoder_output.shape[1:3] != x.shape[1:3]:
            encoder_output = Conv2D(filters, kernel_size=(1, 1), padding='same')(encoder_output)
            encoder_output = UpSampling2D(size=(2, 2))(encoder_output)
        x = concatenate([x, encoder_output], axis=-1)
        x = res_inception_unit(x, filters)
    return x

def build_model(input_shape, num_classes):
    inputs = Input(input_shape)
    encoder_filters = [32, 64, 128, 256, 512]

    encoder_outputs = encoder(inputs, encoder_filters)

    bridge_output = pyramid_pooling_module(encoder_outputs[-1], levels=[1, 2, 4, 8])

    decoder_filters = [512, 256, 128, 64]
    segmentation_map = decoder(bridge_output, encoder_outputs, decoder_filters)

    segmentation_map = Conv2D(num_classes, kernel_size=(1, 1), padding='same')(segmentation_map)
    segmentation_map = Softmax()(segmentation_map)

    model = Model(inputs, segmentation_map)
    return model
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
import tensorflow as tf

input_shape = (SIZE_X, SIZE_Y, n_channels)
model = build_model(input_shape, n_classes)

dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.CategoricalFocalLoss()
hybrid_loss = dice_loss + (1 * focal_loss)

optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)

model.compile(optimizer=optimizer, loss=hybrid_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 32)         128       ['input_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 32)         9248      ['conv2d_3[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)         128       ['input_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 256, 256, 32)         128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  conv2d (Conv2D)             (None, 256, 256, 32)         128       ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 32)         9248      ['conv2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 32)         9248      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 256, 256, 32)         128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 256, 256, 32)         128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  concatenate (Concatenate)   (None, 256, 256, 96)         0         ['batch_normalization[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     , 'batch_normalization_3[0][0]
#                                                                     ']
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 32)         3104      ['concatenate[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['conv2d_6[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 32)         0         ['activation[0][0]']
#  D)
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 64)         2112      ['max_pooling2d[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 64)         36928     ['conv2d_10[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 64)         2112      ['max_pooling2d[0][0]']
#
#  batch_normalization_6 (Bat  (None, 128, 128, 64)         256       ['conv2d_11[0][0]']
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 64)         2112      ['max_pooling2d[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 128, 128, 64)         36928     ['conv2d_8[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 64)         36928     ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 128, 128, 64)         256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 128, 128, 64)         256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['conv2d_12[0][0]']
#  chNormalization)
#
#  concatenate_1 (Concatenate  (None, 128, 128, 192)        0         ['batch_normalization_4[0][0]'
#  )                                                                  , 'batch_normalization_5[0][0]
#                                                                     ',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 64)         12352     ['concatenate_1[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['conv2d_13[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 64)           0         ['activation_1[0][0]']
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 128)          8320      ['max_pooling2d_1[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 128)          147584    ['conv2d_17[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 128)          8320      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 64, 64, 128)          512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 128)          8320      ['max_pooling2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 128)          147584    ['conv2d_15[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 128)          147584    ['batch_normalization_10[0][0]
#                                                                     ']
#
#  batch_normalization_8 (Bat  (None, 64, 64, 128)          512       ['conv2d_14[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 64, 64, 128)          512       ['conv2d_16[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 64, 64, 128)          512       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 384)          0         ['batch_normalization_8[0][0]'
#  )                                                                  , 'batch_normalization_9[0][0]
#                                                                     ',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 128)          49280     ['concatenate_2[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['conv2d_20[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 128)          0         ['activation_2[0][0]']
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 256)          33024     ['max_pooling2d_2[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 256)          590080    ['conv2d_24[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 32, 32, 256)          33024     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 256)          1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 256)          33024     ['max_pooling2d_2[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 32, 32, 256)          590080    ['conv2d_22[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 256)          590080    ['batch_normalization_14[0][0]
#                                                                     ']
#
#  batch_normalization_12 (Ba  (None, 32, 32, 256)          1024      ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_13 (Ba  (None, 32, 32, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 32, 32, 256)          1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 768)          0         ['batch_normalization_12[0][0]
#  )                                                                  ',
#                                                                      'batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 32, 32, 256)          196864    ['concatenate_3[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['conv2d_27[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 256)          0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 16, 16, 512)          131584    ['max_pooling2d_3[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 512)          2359808   ['conv2d_31[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 512)          131584    ['max_pooling2d_3[0][0]']
#
#  batch_normalization_18 (Ba  (None, 16, 16, 512)          2048      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  conv2d_28 (Conv2D)          (None, 16, 16, 512)          131584    ['max_pooling2d_3[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 512)          2359808   ['conv2d_29[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 512)          2359808   ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization_16 (Ba  (None, 16, 16, 512)          2048      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 16, 16, 512)          2048      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 16, 16, 512)          2048      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  concatenate_4 (Concatenate  (None, 16, 16, 1536)         0         ['batch_normalization_16[0][0]
#  )                                                                  ',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 512)          786944    ['concatenate_4[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 512)          0         ['conv2d_34[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 512)          0         ['activation_4[0][0]']
#  g2D)
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 512)            0         ['activation_4[0][0]']
#  g2D)
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 512)            0         ['activation_4[0][0]']
#  g2D)
#
#  max_pooling2d_7 (MaxPoolin  (None, 2, 2, 512)            0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 16, 16, 512)          262656    ['max_pooling2d_4[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 8, 8, 512)            262656    ['max_pooling2d_5[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 4, 4, 512)            262656    ['max_pooling2d_6[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 2, 2, 512)            262656    ['max_pooling2d_7[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 16, 16, 512)          0         ['conv2d_35[0][0]']
#  D)
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 512)          0         ['conv2d_36[0][0]']
#  g2D)
#
#  up_sampling2d_2 (UpSamplin  (None, 16, 16, 512)          0         ['conv2d_37[0][0]']
#  g2D)
#
#  up_sampling2d_3 (UpSamplin  (None, 16, 16, 512)          0         ['conv2d_38[0][0]']
#  g2D)
#
#  concatenate_5 (Concatenate  (None, 16, 16, 2560)         0         ['activation_4[0][0]',
#  )                                                                   'up_sampling2d[0][0]',
#                                                                      'up_sampling2d_1[0][0]',
#                                                                      'up_sampling2d_2[0][0]',
#                                                                      'up_sampling2d_3[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 512)          1179699   ['concatenate_5[0][0]']
#  anspose)                                                 2
#
#  conv2d_40 (Conv2D)          (None, 16, 16, 512)          131584    ['max_pooling2d_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 32, 32, 512)          2359808   ['conv2d_transpose[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, 32, 32, 512)          0         ['conv2d_40[0][0]']
#  g2D)
#
#  concatenate_6 (Concatenate  (None, 32, 32, 1024)         0         ['conv2d_39[0][0]',
#  )                                                                   'up_sampling2d_4[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 32, 32, 512)          524800    ['concatenate_6[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 32, 32, 512)          2359808   ['conv2d_44[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 512)          524800    ['concatenate_6[0][0]']
#
#  batch_normalization_22 (Ba  (None, 32, 32, 512)          2048      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 512)          524800    ['concatenate_6[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 512)          2359808   ['conv2d_42[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 32, 32, 512)          2359808   ['batch_normalization_22[0][0]
#                                                                     ']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 512)          2048      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 32, 32, 512)          2048      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 32, 32, 512)          2048      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  concatenate_7 (Concatenate  (None, 32, 32, 1536)         0         ['batch_normalization_20[0][0]
#  )                                                                  ',
#                                                                      'batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 32, 32, 512)          786944    ['concatenate_7[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 512)          0         ['conv2d_47[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 256)          1179904   ['activation_5[0][0]']
#  Transpose)
#
#  conv2d_49 (Conv2D)          (None, 32, 32, 256)          33024     ['max_pooling2d_2[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_transpose_1[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, 64, 64, 256)          0         ['conv2d_49[0][0]']
#  g2D)
#
#  concatenate_8 (Concatenate  (None, 64, 64, 512)          0         ['conv2d_48[0][0]',
#  )                                                                   'up_sampling2d_5[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 64, 64, 256)          131328    ['concatenate_8[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_53[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 64, 64, 256)          131328    ['concatenate_8[0][0]']
#
#  batch_normalization_26 (Ba  (None, 64, 64, 256)          1024      ['conv2d_54[0][0]']
#  tchNormalization)
#
#  conv2d_50 (Conv2D)          (None, 64, 64, 256)          131328    ['concatenate_8[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_51[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 64, 64, 256)          590080    ['batch_normalization_26[0][0]
#                                                                     ']
#
#  batch_normalization_24 (Ba  (None, 64, 64, 256)          1024      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 64, 64, 256)          1024      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 64, 64, 256)          1024      ['conv2d_55[0][0]']
#  tchNormalization)
#
#  concatenate_9 (Concatenate  (None, 64, 64, 768)          0         ['batch_normalization_24[0][0]
#  )                                                                  ',
#                                                                      'batch_normalization_25[0][0]
#                                                                     ',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_56 (Conv2D)          (None, 64, 64, 256)          196864    ['concatenate_9[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 256)          0         ['conv2d_56[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 128)        295040    ['activation_6[0][0]']
#  Transpose)
#
#  conv2d_58 (Conv2D)          (None, 64, 64, 128)          8320      ['max_pooling2d_1[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_transpose_2[0][0]']
#
#  up_sampling2d_6 (UpSamplin  (None, 128, 128, 128)        0         ['conv2d_58[0][0]']
#  g2D)
#
#  concatenate_10 (Concatenat  (None, 128, 128, 256)        0         ['conv2d_57[0][0]',
#  e)                                                                  'up_sampling2d_6[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 128, 128, 128)        32896     ['concatenate_10[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_62[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 128, 128, 128)        32896     ['concatenate_10[0][0]']
#
#  batch_normalization_30 (Ba  (None, 128, 128, 128)        512       ['conv2d_63[0][0]']
#  tchNormalization)
#
#  conv2d_59 (Conv2D)          (None, 128, 128, 128)        32896     ['concatenate_10[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_60[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 128, 128, 128)        147584    ['batch_normalization_30[0][0]
#                                                                     ']
#
#  batch_normalization_28 (Ba  (None, 128, 128, 128)        512       ['conv2d_59[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 128, 128, 128)        512       ['conv2d_61[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 128, 128, 128)        512       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  concatenate_11 (Concatenat  (None, 128, 128, 384)        0         ['batch_normalization_28[0][0]
#  e)                                                                 ',
#                                                                      'batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_65 (Conv2D)          (None, 128, 128, 128)        49280     ['concatenate_11[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 128)        0         ['conv2d_65[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 64)         73792     ['activation_7[0][0]']
#  Transpose)
#
#  conv2d_67 (Conv2D)          (None, 128, 128, 64)         2112      ['max_pooling2d[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_transpose_3[0][0]']
#
#  up_sampling2d_7 (UpSamplin  (None, 256, 256, 64)         0         ['conv2d_67[0][0]']
#  g2D)
#
#  concatenate_12 (Concatenat  (None, 256, 256, 128)        0         ['conv2d_66[0][0]',
#  e)                                                                  'up_sampling2d_7[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 256, 256, 64)         8256      ['concatenate_12[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_71[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 256, 256, 64)         8256      ['concatenate_12[0][0]']
#
#  batch_normalization_34 (Ba  (None, 256, 256, 64)         256       ['conv2d_72[0][0]']
#  tchNormalization)
#
#  conv2d_68 (Conv2D)          (None, 256, 256, 64)         8256      ['concatenate_12[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_69[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 256, 256, 64)         36928     ['batch_normalization_34[0][0]
#                                                                     ']
#
#  batch_normalization_32 (Ba  (None, 256, 256, 64)         256       ['conv2d_68[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 256, 256, 64)         256       ['conv2d_70[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 256, 256, 64)         256       ['conv2d_73[0][0]']
#  tchNormalization)
#
#  concatenate_13 (Concatenat  (None, 256, 256, 192)        0         ['batch_normalization_32[0][0]
#  e)                                                                 ',
#                                                                      'batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_74 (Conv2D)          (None, 256, 256, 64)         12352     ['concatenate_13[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 64)         0         ['conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 256, 256, 10)         650       ['activation_8[0][0]']
#
#  softmax (Softmax)           (None, 256, 256, 10)         0         ['conv2d_75[0][0]']
#
# ==================================================================================================
# Total params: 41283146 (157.48 MB)
# Trainable params: 41267530 (157.42 MB)
# Non-trainable params: 15616 (61.00 KB)
# __________________________________________________________________________________________________

# %%
model.input_shape, model.output_shape
# Out:
# ((None, 256, 256, 3), (None, 256, 256, 10))

# %%
len(model.layers)
# Out:
# 157

# %%
layers = [type(layer) for layer in model.layers]

from collections import Counter
item_occurrence = Counter(layers)
for item, occurrence in item_occurrence.items():
    print(f"{item}: {occurrence}")
# Out:
# <class 'keras.src.engine.input_layer.InputLayer'>: 1
# <class 'keras.src.layers.convolutional.conv2d.Conv2D'>: 76
# <class 'keras.src.layers.normalization.batch_normalization.BatchNormalization'>: 36
# <class 'keras.src.layers.merging.concatenate.Concatenate'>: 14
# <class 'keras.src.layers.core.activation.Activation'>: 9
# <class 'keras.src.layers.pooling.max_pooling2d.MaxPooling2D'>: 8
# <class 'keras.src.layers.reshaping.up_sampling2d.UpSampling2D'>: 8
# <class 'keras.src.layers.convolutional.conv2d_transpose.Conv2DTranspose'>: 4
# <class 'keras.src.layers.activation.softmax.Softmax'>: 1

# %%
#plot model
from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 65s 195ms/step - loss: 0.9122 - iou_score: 0.0723 - val_loss: 0.9778 - val_iou_score: 0.0366
# Epoch 2/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.8454 - iou_score: 0.1165 - val_loss: 1.0295 - val_iou_score: 0.0252
# Epoch 3/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.8107 - iou_score: 0.1453 - val_loss: 0.9212 - val_iou_score: 0.0791
# Epoch 4/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.7867 - iou_score: 0.1645 - val_loss: 0.7966 - val_iou_score: 0.1580
# Epoch 5/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.7648 - iou_score: 0.1811 - val_loss: 0.7522 - val_iou_score: 0.1923
# Epoch 6/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.7463 - iou_score: 0.1956 - val_loss: 0.7293 - val_iou_score: 0.2096
# Epoch 7/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.7291 - iou_score: 0.2092 - val_loss: 0.7152 - val_iou_score: 0.2210
# Epoch 8/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.7113 - iou_score: 0.2226 - val_loss: 0.7242 - val_iou_score: 0.2156
# Epoch 9/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.6928 - iou_score: 0.2369 - val_loss: 0.6805 - val_iou_score: 0.2479
# Epoch 10/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.6781 - iou_score: 0.2493 - val_loss: 0.6615 - val_iou_score: 0.2644
# Epoch 11/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.6611 - iou_score: 0.2638 - val_loss: 0.7022 - val_iou_score: 0.2285
# Epoch 12/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.6457 - iou_score: 0.2766 - val_loss: 0.6712 - val_iou_score: 0.2575
# Epoch 13/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.6346 - iou_score: 0.2868 - val_loss: 0.6586 - val_iou_score: 0.2663
# Epoch 14/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.6221 - iou_score: 0.2984 - val_loss: 0.6455 - val_iou_score: 0.2775
# Epoch 15/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.6034 - iou_score: 0.3138 - val_loss: 0.6273 - val_iou_score: 0.2931
# Epoch 16/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5922 - iou_score: 0.3232 - val_loss: 0.6289 - val_iou_score: 0.2938
# Epoch 17/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5846 - iou_score: 0.3317 - val_loss: 0.5912 - val_iou_score: 0.3253
# Epoch 18/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5809 - iou_score: 0.3349 - val_loss: 0.6005 - val_iou_score: 0.3149
# Epoch 19/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5661 - iou_score: 0.3479 - val_loss: 0.6014 - val_iou_score: 0.3183
# Epoch 20/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5501 - iou_score: 0.3626 - val_loss: 0.6504 - val_iou_score: 0.2763
# Epoch 21/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5471 - iou_score: 0.3660 - val_loss: 0.6013 - val_iou_score: 0.3204
# Epoch 22/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5392 - iou_score: 0.3740 - val_loss: 0.5780 - val_iou_score: 0.3381
# Epoch 23/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5314 - iou_score: 0.3806 - val_loss: 0.6423 - val_iou_score: 0.2822
# Epoch 24/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5206 - iou_score: 0.3914 - val_loss: 0.6622 - val_iou_score: 0.2670
# Epoch 25/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5198 - iou_score: 0.3929 - val_loss: 0.5659 - val_iou_score: 0.3489
# Epoch 26/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5149 - iou_score: 0.3975 - val_loss: 0.5913 - val_iou_score: 0.3298
# Epoch 27/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5025 - iou_score: 0.4111 - val_loss: 0.6741 - val_iou_score: 0.2597
# Epoch 28/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4992 - iou_score: 0.4134 - val_loss: 0.5309 - val_iou_score: 0.3829
# Epoch 29/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.5014 - iou_score: 0.4135 - val_loss: 0.6366 - val_iou_score: 0.2847
# Epoch 30/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4822 - iou_score: 0.4308 - val_loss: 0.5925 - val_iou_score: 0.3279
# Epoch 31/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4750 - iou_score: 0.4386 - val_loss: 0.5552 - val_iou_score: 0.3598
# Epoch 32/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4642 - iou_score: 0.4479 - val_loss: 0.6255 - val_iou_score: 0.3024
# Epoch 33/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4710 - iou_score: 0.4434 - val_loss: 0.5890 - val_iou_score: 0.3262
# Epoch 34/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4588 - iou_score: 0.4552 - val_loss: 0.7577 - val_iou_score: 0.1989
# Epoch 35/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4606 - iou_score: 0.4540 - val_loss: 0.5562 - val_iou_score: 0.3539
# Epoch 36/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4444 - iou_score: 0.4682 - val_loss: 0.5359 - val_iou_score: 0.3764
# Epoch 37/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4403 - iou_score: 0.4727 - val_loss: 0.7690 - val_iou_score: 0.1960
# Epoch 38/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4404 - iou_score: 0.4734 - val_loss: 0.5425 - val_iou_score: 0.3735
# Epoch 39/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4401 - iou_score: 0.4738 - val_loss: 0.7862 - val_iou_score: 0.1903
# Epoch 40/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4273 - iou_score: 0.4855 - val_loss: 0.5890 - val_iou_score: 0.3298
# Epoch 41/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4216 - iou_score: 0.4911 - val_loss: 0.5459 - val_iou_score: 0.3680
# Epoch 42/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4169 - iou_score: 0.4970 - val_loss: 0.5381 - val_iou_score: 0.3761
# Epoch 43/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4170 - iou_score: 0.4958 - val_loss: 0.5237 - val_iou_score: 0.3813
# Epoch 44/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4206 - iou_score: 0.4939 - val_loss: 0.5721 - val_iou_score: 0.3446
# Epoch 45/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4103 - iou_score: 0.5026 - val_loss: 0.6006 - val_iou_score: 0.3209
# Epoch 46/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4099 - iou_score: 0.5035 - val_loss: 0.5875 - val_iou_score: 0.3338
# Epoch 47/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4096 - iou_score: 0.5037 - val_loss: 0.7354 - val_iou_score: 0.2231
# Epoch 48/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4002 - iou_score: 0.5132 - val_loss: 0.5732 - val_iou_score: 0.3403
# Epoch 49/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.4095 - iou_score: 0.5043 - val_loss: 0.6836 - val_iou_score: 0.2536
# Epoch 50/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3950 - iou_score: 0.5172 - val_loss: 0.4913 - val_iou_score: 0.4210
# Epoch 51/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3908 - iou_score: 0.5241 - val_loss: 0.5976 - val_iou_score: 0.3270
# Epoch 52/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3926 - iou_score: 0.5223 - val_loss: 0.5776 - val_iou_score: 0.3362
# Epoch 53/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3835 - iou_score: 0.5323 - val_loss: 0.5381 - val_iou_score: 0.3750
# Epoch 54/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3909 - iou_score: 0.5241 - val_loss: 0.5203 - val_iou_score: 0.3904
# Epoch 55/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3784 - iou_score: 0.5375 - val_loss: 0.4852 - val_iou_score: 0.4237
# Epoch 56/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3822 - iou_score: 0.5355 - val_loss: 0.4977 - val_iou_score: 0.4107
# Epoch 57/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3710 - iou_score: 0.5452 - val_loss: 0.5008 - val_iou_score: 0.4096
# Epoch 58/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3619 - iou_score: 0.5543 - val_loss: 0.4558 - val_iou_score: 0.4554
# Epoch 59/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3777 - iou_score: 0.5410 - val_loss: 0.5532 - val_iou_score: 0.3636
# Epoch 60/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3643 - iou_score: 0.5537 - val_loss: 0.5465 - val_iou_score: 0.3661
# Epoch 61/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3682 - iou_score: 0.5500 - val_loss: 0.4768 - val_iou_score: 0.4346
# Epoch 62/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3601 - iou_score: 0.5584 - val_loss: 0.5028 - val_iou_score: 0.4055
# Epoch 63/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3583 - iou_score: 0.5589 - val_loss: 0.5135 - val_iou_score: 0.4014
# Epoch 64/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3655 - iou_score: 0.5525 - val_loss: 0.5184 - val_iou_score: 0.3962
# Epoch 65/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3546 - iou_score: 0.5647 - val_loss: 0.5253 - val_iou_score: 0.3840
# Epoch 66/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3509 - iou_score: 0.5677 - val_loss: 0.4852 - val_iou_score: 0.4234
# Epoch 67/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3483 - iou_score: 0.5699 - val_loss: 0.5158 - val_iou_score: 0.3950
# Epoch 68/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3403 - iou_score: 0.5785 - val_loss: 0.4774 - val_iou_score: 0.4316
# Epoch 69/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3541 - iou_score: 0.5648 - val_loss: 0.4834 - val_iou_score: 0.4251
# Epoch 70/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3566 - iou_score: 0.5640 - val_loss: 0.4647 - val_iou_score: 0.4475
# Epoch 71/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3404 - iou_score: 0.5779 - val_loss: 0.4682 - val_iou_score: 0.4441
# Epoch 72/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3359 - iou_score: 0.5835 - val_loss: 0.4734 - val_iou_score: 0.4388
# Epoch 73/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3400 - iou_score: 0.5808 - val_loss: 0.5060 - val_iou_score: 0.4062
# Epoch 74/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3343 - iou_score: 0.5880 - val_loss: 0.4698 - val_iou_score: 0.4407
# Epoch 75/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3304 - iou_score: 0.5910 - val_loss: 0.4788 - val_iou_score: 0.4341
# Epoch 76/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3332 - iou_score: 0.5889 - val_loss: 0.5789 - val_iou_score: 0.3417
# Epoch 77/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3253 - iou_score: 0.5952 - val_loss: 0.4655 - val_iou_score: 0.4471
# Epoch 78/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3399 - iou_score: 0.5834 - val_loss: 0.4781 - val_iou_score: 0.4335
# Epoch 79/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3313 - iou_score: 0.5922 - val_loss: 0.4783 - val_iou_score: 0.4369
# Epoch 80/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3217 - iou_score: 0.5994 - val_loss: 0.4841 - val_iou_score: 0.4273
# Epoch 81/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3332 - iou_score: 0.5907 - val_loss: 0.5482 - val_iou_score: 0.3670
# Epoch 82/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3487 - iou_score: 0.5753 - val_loss: 0.4442 - val_iou_score: 0.4695
# Epoch 83/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3257 - iou_score: 0.5988 - val_loss: 0.5192 - val_iou_score: 0.4030
# Epoch 84/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3174 - iou_score: 0.6068 - val_loss: 0.4544 - val_iou_score: 0.4597
# Epoch 85/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3208 - iou_score: 0.6035 - val_loss: 0.4536 - val_iou_score: 0.4604
# Epoch 86/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3212 - iou_score: 0.6023 - val_loss: 0.5024 - val_iou_score: 0.4131
# Epoch 87/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3098 - iou_score: 0.6132 - val_loss: 0.6073 - val_iou_score: 0.3320
# Epoch 88/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3253 - iou_score: 0.5991 - val_loss: 0.4698 - val_iou_score: 0.4449
# Epoch 89/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3263 - iou_score: 0.5984 - val_loss: 0.4661 - val_iou_score: 0.4528
# Epoch 90/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3209 - iou_score: 0.6047 - val_loss: 0.4536 - val_iou_score: 0.4624
# Epoch 91/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3062 - iou_score: 0.6182 - val_loss: 0.4813 - val_iou_score: 0.4323
# Epoch 92/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3133 - iou_score: 0.6101 - val_loss: 0.5165 - val_iou_score: 0.4001
# Epoch 93/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3116 - iou_score: 0.6135 - val_loss: 0.4835 - val_iou_score: 0.4323
# Epoch 94/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3170 - iou_score: 0.6087 - val_loss: 0.4903 - val_iou_score: 0.4248
# Epoch 95/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3097 - iou_score: 0.6166 - val_loss: 0.4800 - val_iou_score: 0.4321
# Epoch 96/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3020 - iou_score: 0.6239 - val_loss: 0.4914 - val_iou_score: 0.4218
# Epoch 97/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3078 - iou_score: 0.6187 - val_loss: 0.4491 - val_iou_score: 0.4644
# Epoch 98/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3098 - iou_score: 0.6165 - val_loss: 0.4566 - val_iou_score: 0.4565
# Epoch 99/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3124 - iou_score: 0.6147 - val_loss: 0.4441 - val_iou_score: 0.4705
# Epoch 100/100
# 181/181 [==============================] - 24s 135ms/step - loss: 0.3021 - iou_score: 0.6254 - val_loss: 0.4876 - val_iou_score: 0.4282

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
path = '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/UNET/weights'
model.save(f'{path}/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y})-(Multi-Scale_&_Context_Aware).hdf5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(f'/content/FloodNet-Supervised_v1.0', split='test')
test_images_seperate = test_images
# Out:
# 100%|██████████| 448/448 [01:52<00:00,  3.97it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = f'/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/test_data({SIZE_X}x{SIZE_Y}-Simple).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to /content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/test_data(256x256-Simple).pickle
# Shapes of loaded data:
# Test Images: (448, 256, 256, 3)
# Test Masks: (448, 256, 256)

# %%
pickle_file_path = f'/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/test_data({SIZE_X}x{SIZE_Y}-Simple).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']
# Out:
# Shapes of loaded data:
# Test Images: (448, 256, 256, 3)
# Test Masks: (448, 65536, 10, 10)

# %%
test_images, test_masks = preprocess_data(test_images, test_masks)
print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 256, 256, 3)
# Test Masks: (448, 256, 256, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  49.529269337654114 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 2s 125ms/step
# (448, 256, 256)
# (448, 256, 256)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0:
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.51501215
# IoU for each class:
# Building Flooded: 0.6437965631484985
# Building Non-Flooded: 0.50310879945755
# Road Flooded: 0.49274948239326477
# Road Non-Flooded: 0.6385941505432129
# Water: 0.6965490579605103
# Tree: 0.5200019478797913
# Vehicle: 0.2836982309818268
# Pool: 0.33831214904785156
# Grass: 0.7823305130004883
# Mean IoU (excluding Background): 0.54434896

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha='right')

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)
