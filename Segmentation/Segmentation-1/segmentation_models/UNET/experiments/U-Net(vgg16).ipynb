# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score
from segmentation_models.utils import set_trainable

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'vgg16'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
if MODEL == 'unet':
    model = sm.Unet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation, encoder_freeze=True)
elif MODEL == 'fpn':
    model = sm.FPN(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
else:
    raise ValueError('Unknown model')

set_trainable(model, recompile=False)
model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_7[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 4, 4, 512)    0           ['block5_conv3[0][0]']
#
#  center_block1_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['block5_pool[0][0]']
#
#  center_block1_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block1_conv[0][0]']
#  zation)
#
#  center_block1_relu (Activation  (None, 4, 4, 512)   0           ['center_block1_bn[0][0]']
#  )
#
#  center_block2_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['center_block1_relu[0][0]']
#
#  center_block2_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block2_conv[0][0]']
#  zation)
#
#  center_block2_relu (Activation  (None, 4, 4, 512)   0           ['center_block2_bn[0][0]']
#  )
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 512)   0           ['center_block2_relu[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 1024)  0           ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block5_conv3[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 8, 8, 256)    2359296     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 8, 8, 256)    589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 768)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block4_conv3[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 16, 16, 128)  884736      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 16, 16, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 384)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block3_conv3[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 32, 32, 64)   221184      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 32, 32, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64)  0           ['decoder_stage2b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 192)  0          ['decoder_stage3_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block2_conv2[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 32)   55296       ['decoder_stage3_concat[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3b_conv (Conv2D)  (None, 64, 64, 32)   9216        ['decoder_stage3a_relu[0][0]']
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3b_conv[0][0]']
#  lization)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3b_bn[0][0]']
#  on)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 128, 128, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 128, 128, 10  1450        ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  softmax (Activation)           (None, 128, 128, 10  0           ['final_conv[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 23,753,578
# Trainable params: 23,749,546
# Non-trainable params: 4,032
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 15s 68ms/step - loss: 1.0339 - iou_score: 0.1826 - val_loss: 0.9976 - val_iou_score: 0.1824
# Epoch 2/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.8898 - iou_score: 0.2527 - val_loss: 0.9164 - val_iou_score: 0.2169
# Epoch 3/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.8514 - iou_score: 0.2800 - val_loss: 0.9329 - val_iou_score: 0.2138
# Epoch 4/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.8217 - iou_score: 0.3024 - val_loss: 0.9541 - val_iou_score: 0.2177
# Epoch 5/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.7778 - iou_score: 0.3430 - val_loss: 0.8201 - val_iou_score: 0.2879
# Epoch 6/100
# 181/181 [==============================] - 11s 62ms/step - loss: 0.7331 - iou_score: 0.3819 - val_loss: 0.8269 - val_iou_score: 0.2850
# Epoch 7/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.7062 - iou_score: 0.4026 - val_loss: 0.7832 - val_iou_score: 0.3146
# Epoch 8/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.6897 - iou_score: 0.4160 - val_loss: 0.8030 - val_iou_score: 0.3003
# Epoch 9/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.6673 - iou_score: 0.4360 - val_loss: 0.7748 - val_iou_score: 0.3219
# Epoch 10/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.6645 - iou_score: 0.4360 - val_loss: 0.8089 - val_iou_score: 0.3108
# Epoch 11/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.6409 - iou_score: 0.4558 - val_loss: 0.7678 - val_iou_score: 0.3313
# Epoch 12/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.6403 - iou_score: 0.4552 - val_loss: 0.7769 - val_iou_score: 0.3261
# Epoch 13/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.6270 - iou_score: 0.4667 - val_loss: 0.7607 - val_iou_score: 0.3375
# Epoch 14/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.6154 - iou_score: 0.4761 - val_loss: 0.7534 - val_iou_score: 0.3402
# Epoch 15/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.6092 - iou_score: 0.4800 - val_loss: 0.7468 - val_iou_score: 0.3425
# Epoch 16/100
# 181/181 [==============================] - 11s 62ms/step - loss: 0.6012 - iou_score: 0.4866 - val_loss: 0.7507 - val_iou_score: 0.3406
# Epoch 17/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5876 - iou_score: 0.4975 - val_loss: 0.7306 - val_iou_score: 0.3594
# Epoch 18/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5856 - iou_score: 0.4995 - val_loss: 0.7465 - val_iou_score: 0.3461
# Epoch 19/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5761 - iou_score: 0.5069 - val_loss: 0.7610 - val_iou_score: 0.3434
# Epoch 20/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5713 - iou_score: 0.5115 - val_loss: 0.7223 - val_iou_score: 0.3613
# Epoch 21/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5644 - iou_score: 0.5159 - val_loss: 0.7216 - val_iou_score: 0.3626
# Epoch 22/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5604 - iou_score: 0.5182 - val_loss: 0.7371 - val_iou_score: 0.3523
# Epoch 23/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5512 - iou_score: 0.5255 - val_loss: 0.7169 - val_iou_score: 0.3660
# Epoch 24/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5464 - iou_score: 0.5295 - val_loss: 0.7401 - val_iou_score: 0.3517
# Epoch 25/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5407 - iou_score: 0.5354 - val_loss: 0.7191 - val_iou_score: 0.3649
# Epoch 26/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5311 - iou_score: 0.5428 - val_loss: 0.7146 - val_iou_score: 0.3678
# Epoch 27/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5327 - iou_score: 0.5420 - val_loss: 0.7242 - val_iou_score: 0.3661
# Epoch 28/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5279 - iou_score: 0.5459 - val_loss: 0.7316 - val_iou_score: 0.3658
# Epoch 29/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5182 - iou_score: 0.5542 - val_loss: 0.7061 - val_iou_score: 0.3752
# Epoch 30/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5118 - iou_score: 0.5594 - val_loss: 0.7141 - val_iou_score: 0.3702
# Epoch 31/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5046 - iou_score: 0.5641 - val_loss: 0.7162 - val_iou_score: 0.3687
# Epoch 32/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5011 - iou_score: 0.5675 - val_loss: 0.7090 - val_iou_score: 0.3738
# Epoch 33/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5046 - iou_score: 0.5631 - val_loss: 0.7157 - val_iou_score: 0.3697
# Epoch 34/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5025 - iou_score: 0.5670 - val_loss: 0.7112 - val_iou_score: 0.3752
# Epoch 35/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4894 - iou_score: 0.5766 - val_loss: 0.7046 - val_iou_score: 0.3781
# Epoch 36/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5000 - iou_score: 0.5659 - val_loss: 0.7003 - val_iou_score: 0.3802
# Epoch 37/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4857 - iou_score: 0.5800 - val_loss: 0.7114 - val_iou_score: 0.3727
# Epoch 38/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4792 - iou_score: 0.5838 - val_loss: 0.7232 - val_iou_score: 0.3706
# Epoch 39/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4776 - iou_score: 0.5833 - val_loss: 0.7027 - val_iou_score: 0.3784
# Epoch 40/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4728 - iou_score: 0.5884 - val_loss: 0.6972 - val_iou_score: 0.3845
# Epoch 41/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4710 - iou_score: 0.5905 - val_loss: 0.7092 - val_iou_score: 0.3749
# Epoch 42/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4765 - iou_score: 0.5846 - val_loss: 0.7037 - val_iou_score: 0.3791
# Epoch 43/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4640 - iou_score: 0.5928 - val_loss: 0.7100 - val_iou_score: 0.3794
# Epoch 44/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4563 - iou_score: 0.6008 - val_loss: 0.7007 - val_iou_score: 0.3790
# Epoch 45/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4586 - iou_score: 0.5989 - val_loss: 0.7115 - val_iou_score: 0.3742
# Epoch 46/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4459 - iou_score: 0.6090 - val_loss: 0.6976 - val_iou_score: 0.3840
# Epoch 47/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4573 - iou_score: 0.6000 - val_loss: 0.7069 - val_iou_score: 0.3788
# Epoch 48/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4441 - iou_score: 0.6090 - val_loss: 0.7197 - val_iou_score: 0.3728
# Epoch 49/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4492 - iou_score: 0.6060 - val_loss: 0.7059 - val_iou_score: 0.3780
# Epoch 50/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4485 - iou_score: 0.6071 - val_loss: 0.7188 - val_iou_score: 0.3694
# Epoch 51/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4375 - iou_score: 0.6156 - val_loss: 0.7005 - val_iou_score: 0.3816
# Epoch 52/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4295 - iou_score: 0.6209 - val_loss: 0.7151 - val_iou_score: 0.3743
# Epoch 53/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4251 - iou_score: 0.6256 - val_loss: 0.6996 - val_iou_score: 0.3837
# Epoch 54/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4198 - iou_score: 0.6280 - val_loss: 0.7046 - val_iou_score: 0.3797
# Epoch 55/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4098 - iou_score: 0.6383 - val_loss: 0.7133 - val_iou_score: 0.3748
# Epoch 56/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4289 - iou_score: 0.6229 - val_loss: 0.7002 - val_iou_score: 0.3826
# Epoch 57/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4135 - iou_score: 0.6329 - val_loss: 0.7007 - val_iou_score: 0.3838
# Epoch 58/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4083 - iou_score: 0.6369 - val_loss: 0.7070 - val_iou_score: 0.3810
# Epoch 59/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4135 - iou_score: 0.6322 - val_loss: 0.7080 - val_iou_score: 0.3809
# Epoch 60/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4237 - iou_score: 0.6249 - val_loss: 0.7746 - val_iou_score: 0.3562
# Epoch 61/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4159 - iou_score: 0.6335 - val_loss: 0.6937 - val_iou_score: 0.3879
# Epoch 62/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4091 - iou_score: 0.6354 - val_loss: 0.7011 - val_iou_score: 0.3843
# Epoch 63/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3992 - iou_score: 0.6448 - val_loss: 0.6979 - val_iou_score: 0.3852
# Epoch 64/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4133 - iou_score: 0.6319 - val_loss: 0.7059 - val_iou_score: 0.3817
# Epoch 65/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4003 - iou_score: 0.6433 - val_loss: 0.7045 - val_iou_score: 0.3829
# Epoch 66/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4161 - iou_score: 0.6306 - val_loss: 0.7147 - val_iou_score: 0.3826
# Epoch 67/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4148 - iou_score: 0.6300 - val_loss: 0.6950 - val_iou_score: 0.3880
# Epoch 68/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4037 - iou_score: 0.6395 - val_loss: 0.7238 - val_iou_score: 0.3746
# Epoch 69/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3960 - iou_score: 0.6471 - val_loss: 0.7030 - val_iou_score: 0.3857
# Epoch 70/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3919 - iou_score: 0.6496 - val_loss: 0.6963 - val_iou_score: 0.3875
# Epoch 71/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3931 - iou_score: 0.6480 - val_loss: 0.6930 - val_iou_score: 0.3907
# Epoch 72/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3800 - iou_score: 0.6578 - val_loss: 0.6941 - val_iou_score: 0.3918
# Epoch 73/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3751 - iou_score: 0.6627 - val_loss: 0.7125 - val_iou_score: 0.3771
# Epoch 74/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3823 - iou_score: 0.6568 - val_loss: 0.7029 - val_iou_score: 0.3847
# Epoch 75/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3723 - iou_score: 0.6656 - val_loss: 0.6997 - val_iou_score: 0.3889
# Epoch 76/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3809 - iou_score: 0.6574 - val_loss: 0.7096 - val_iou_score: 0.3831
# Epoch 77/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3945 - iou_score: 0.6458 - val_loss: 0.6976 - val_iou_score: 0.3917
# Epoch 78/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3819 - iou_score: 0.6567 - val_loss: 0.7166 - val_iou_score: 0.3769
# Epoch 79/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3830 - iou_score: 0.6547 - val_loss: 0.6991 - val_iou_score: 0.3866
# Epoch 80/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3752 - iou_score: 0.6611 - val_loss: 0.7046 - val_iou_score: 0.3876
# Epoch 81/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3648 - iou_score: 0.6717 - val_loss: 0.7166 - val_iou_score: 0.3795
# Epoch 82/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3724 - iou_score: 0.6639 - val_loss: 0.7130 - val_iou_score: 0.3798
# Epoch 83/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3954 - iou_score: 0.6484 - val_loss: 0.7208 - val_iou_score: 0.3755
# Epoch 84/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3853 - iou_score: 0.6542 - val_loss: 0.7028 - val_iou_score: 0.3839
# Epoch 85/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3625 - iou_score: 0.6715 - val_loss: 0.7016 - val_iou_score: 0.3881
# Epoch 86/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3651 - iou_score: 0.6686 - val_loss: 0.6934 - val_iou_score: 0.3929
# Epoch 87/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3488 - iou_score: 0.6828 - val_loss: 0.7025 - val_iou_score: 0.3862
# Epoch 88/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3576 - iou_score: 0.6743 - val_loss: 0.7244 - val_iou_score: 0.3731
# Epoch 89/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3668 - iou_score: 0.6688 - val_loss: 0.7024 - val_iou_score: 0.3891
# Epoch 90/100
# 181/181 [==============================] - 11s 62ms/step - loss: 0.3621 - iou_score: 0.6721 - val_loss: 0.7016 - val_iou_score: 0.3881
# Epoch 91/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3666 - iou_score: 0.6667 - val_loss: 0.7022 - val_iou_score: 0.3885
# Epoch 92/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3554 - iou_score: 0.6752 - val_loss: 0.7052 - val_iou_score: 0.3898
# Epoch 93/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3445 - iou_score: 0.6856 - val_loss: 0.7005 - val_iou_score: 0.3926
# Epoch 94/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3469 - iou_score: 0.6822 - val_loss: 0.6954 - val_iou_score: 0.3972
# Epoch 95/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3387 - iou_score: 0.6903 - val_loss: 0.7029 - val_iou_score: 0.3934
# Epoch 96/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3718 - iou_score: 0.6657 - val_loss: 0.7000 - val_iou_score: 0.3932
# Epoch 97/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3534 - iou_score: 0.6783 - val_loss: 0.7031 - val_iou_score: 0.3905
# Epoch 98/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3604 - iou_score: 0.6738 - val_loss: 0.7313 - val_iou_score: 0.3725
# Epoch 99/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3879 - iou_score: 0.6512 - val_loss: 0.7031 - val_iou_score: 0.3900
# Epoch 100/100
# 181/181 [==============================] - 11s 62ms/step - loss: 0.3513 - iou_score: 0.6793 - val_loss: 0.6969 - val_iou_score: 0.3936

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images
# Out:
#   0%|          | 0/448 [00:00<?, ?it/s]
# 100%|██████████| 448/448 [02:18<00:00,  3.24it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128)

# %%
pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  47.161537408828735 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 1s 34ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

class_APs = []

for i in range(n_classes):
    class_predicted_masks = (predicted_masks == i).astype(int)
    class_test_masks = (test_masks_ == i).astype(int)
    
    class_predicted_masks_flat = class_predicted_masks.flatten().reshape(-1, 1)
    class_test_masks_flat = class_test_masks.flatten().reshape(-1, 1)
    
    class_APs.append(average_precision_score(class_test_masks_flat, class_predicted_masks_flat, average='micro'))

mAP_score = np.mean(class_APs)
print("Overall mAP score =", mAP_score)
# Out:
# Mean IoU = 0.6392802
# IoU for each class:
# Background: 0.4263826012611389
# Building Flooded: 0.6626525521278381
# Building Non-Flooded: 0.7227672338485718
# Road Flooded: 0.5691387057304382
# Road Non-Flooded: 0.8016215562820435
# Water: 0.7815571427345276
# Tree: 0.7688241004943848
# Vehicle: 0.3205970823764801
# Pool: 0.4700896739959717
# Grass: 0.8691719770431519
# Overall mAP score = 0.6213382821833884

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names, class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.6392802
# IoU for each class:
# Building Flooded: 0.6626525521278381
# Building Non-Flooded: 0.7227672338485718
# Road Flooded: 0.5691387057304382
# Road Non-Flooded: 0.8016215562820435
# Water: 0.7815571427345276
# Tree: 0.7688241004943848
# Vehicle: 0.3205970823764801
# Pool: 0.4700896739959717
# Grass: 0.8691719770431519
# Mean IoU (excluding Background): 0.66293555

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
