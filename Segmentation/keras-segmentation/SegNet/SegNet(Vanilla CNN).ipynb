# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'segnet'
BACKBONE = 'Vanilla CNN'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], -1, n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to ../../dataset/train_and_val_data.pickle
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 16384, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 16384, 10)

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  zero_padding2d_10 (ZeroPadd  (None, 130, 130, 3)      0
#  ing2D)
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 64)      1792
#
#  batch_normalization_10 (Bat  (None, 128, 128, 64)     256
#  chNormalization)
#
#  activation_6 (Activation)   (None, 128, 128, 64)      0
#
#  max_pooling2d_5 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  zero_padding2d_11 (ZeroPadd  (None, 66, 66, 64)       0
#  ing2D)
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 128)       73856
#
#  batch_normalization_11 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  activation_7 (Activation)   (None, 64, 64, 128)       0
#
#  max_pooling2d_6 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  zero_padding2d_12 (ZeroPadd  (None, 34, 34, 128)      0
#  ing2D)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_12 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_8 (Activation)   (None, 32, 32, 256)       0
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  zero_padding2d_13 (ZeroPadd  (None, 18, 18, 256)      0
#  ing2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_13 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 256)       0
#
#  max_pooling2d_8 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  zero_padding2d_15 (ZeroPadd  (None, 10, 10, 256)      0
#  ing2D)
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  batch_normalization_15 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  up_sampling2d_4 (UpSampling  (None, 16, 16, 512)      0
#  2D)
#
#  zero_padding2d_16 (ZeroPadd  (None, 18, 18, 512)      0
#  ing2D)
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 256)       1179904
#
#  batch_normalization_16 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  up_sampling2d_5 (UpSampling  (None, 32, 32, 256)      0
#  2D)
#
#  zero_padding2d_17 (ZeroPadd  (None, 34, 34, 256)      0
#  ing2D)
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 128)       295040
#
#  batch_normalization_17 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  up_sampling2d_6 (UpSampling  (None, 64, 64, 128)      0
#  2D)
#
#  zero_padding2d_18 (ZeroPadd  (None, 66, 66, 128)      0
#  ing2D)
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 64)        73792
#
#  batch_normalization_18 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  up_sampling2d_7 (UpSampling  (None, 128, 128, 64)     0
#  2D)
#
#  zero_padding2d_19 (ZeroPadd  (None, 130, 130, 64)     0
#  ing2D)
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 128)     73856
#
#  batch_normalization_19 (Bat  (None, 128, 128, 128)    512
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 10)      11530
#
#  reshape_1 (Reshape)         (None, 16384, 10)         0
#
#  activation_11 (Activation)  (None, 16384, 10)         0
#
# =================================================================
# Total params: 3,782,346
# Trainable params: 3,778,762
# Non-trainable params: 3,584
# _________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 14s 50ms/step - loss: 0.9889 - iou_score: 0.3948 - val_loss: 3.8136 - val_iou_score: 0.0650
# Epoch 2/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.7144 - iou_score: 0.4748 - val_loss: 1.4580 - val_iou_score: 0.1193
# Epoch 3/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.6837 - iou_score: 0.4981 - val_loss: 1.1357 - val_iou_score: 0.3503
# Epoch 4/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.6381 - iou_score: 0.5313 - val_loss: 0.6585 - val_iou_score: 0.5232
# Epoch 5/100
# 181/181 [==============================] - 8s 46ms/step - loss: 0.6091 - iou_score: 0.5508 - val_loss: 0.9008 - val_iou_score: 0.4465
# Epoch 6/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.5900 - iou_score: 0.5649 - val_loss: 2.9704 - val_iou_score: 0.0851
# Epoch 7/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.5759 - iou_score: 0.5785 - val_loss: 1.1668 - val_iou_score: 0.2562
# Epoch 8/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.5633 - iou_score: 0.5883 - val_loss: 0.7914 - val_iou_score: 0.5109
# Epoch 9/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.5412 - iou_score: 0.6033 - val_loss: 1.2791 - val_iou_score: 0.2807
# Epoch 10/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.5253 - iou_score: 0.6144 - val_loss: 0.5926 - val_iou_score: 0.5802
# Epoch 11/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.5137 - iou_score: 0.6241 - val_loss: 0.9457 - val_iou_score: 0.4178
# Epoch 12/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.5036 - iou_score: 0.6317 - val_loss: 0.9117 - val_iou_score: 0.4649
# Epoch 13/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.4924 - iou_score: 0.6408 - val_loss: 0.7348 - val_iou_score: 0.5053
# Epoch 14/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.4808 - iou_score: 0.6493 - val_loss: 0.7045 - val_iou_score: 0.4939
# Epoch 15/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.4639 - iou_score: 0.6619 - val_loss: 0.8777 - val_iou_score: 0.4219
# Epoch 16/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.4485 - iou_score: 0.6737 - val_loss: 1.5212 - val_iou_score: 0.2005
# Epoch 17/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.4442 - iou_score: 0.6769 - val_loss: 0.6422 - val_iou_score: 0.5351
# Epoch 18/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.4307 - iou_score: 0.6861 - val_loss: 0.5640 - val_iou_score: 0.6095
# Epoch 19/100
# 181/181 [==============================] - 8s 42ms/step - loss: 0.4298 - iou_score: 0.6873 - val_loss: 0.8161 - val_iou_score: 0.4900
# Epoch 20/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.4105 - iou_score: 0.7006 - val_loss: 0.7005 - val_iou_score: 0.5103
# Epoch 21/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.4099 - iou_score: 0.7021 - val_loss: 1.4980 - val_iou_score: 0.1780
# Epoch 22/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.3971 - iou_score: 0.7131 - val_loss: 0.6338 - val_iou_score: 0.5466
# Epoch 23/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.3839 - iou_score: 0.7219 - val_loss: 0.6315 - val_iou_score: 0.5536
# Epoch 24/100
# 181/181 [==============================] - 8s 43ms/step - loss: 0.3792 - iou_score: 0.7248 - val_loss: 0.5611 - val_iou_score: 0.5950
# Epoch 25/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.3760 - iou_score: 0.7287 - val_loss: 0.7178 - val_iou_score: 0.5073
# Epoch 26/100
# 181/181 [==============================] - 8s 43ms/step - loss: 0.3645 - iou_score: 0.7353 - val_loss: 0.7591 - val_iou_score: 0.4888
# Epoch 27/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.3431 - iou_score: 0.7508 - val_loss: 0.5228 - val_iou_score: 0.6214
# Epoch 28/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.3427 - iou_score: 0.7511 - val_loss: 0.5599 - val_iou_score: 0.6117
# Epoch 29/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.3345 - iou_score: 0.7575 - val_loss: 0.6726 - val_iou_score: 0.5410
# Epoch 30/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.3224 - iou_score: 0.7665 - val_loss: 0.8032 - val_iou_score: 0.5163
# Epoch 31/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.3167 - iou_score: 0.7699 - val_loss: 0.6858 - val_iou_score: 0.5340
# Epoch 32/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.3060 - iou_score: 0.7786 - val_loss: 0.6849 - val_iou_score: 0.5435
# Epoch 33/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.3061 - iou_score: 0.7788 - val_loss: 0.6901 - val_iou_score: 0.5368
# Epoch 34/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2932 - iou_score: 0.7877 - val_loss: 0.8185 - val_iou_score: 0.4566
# Epoch 35/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2828 - iou_score: 0.7946 - val_loss: 0.5764 - val_iou_score: 0.6233
# Epoch 36/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2985 - iou_score: 0.7848 - val_loss: 0.6956 - val_iou_score: 0.5095
# Epoch 37/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.2773 - iou_score: 0.7991 - val_loss: 0.5531 - val_iou_score: 0.6165
# Epoch 38/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2786 - iou_score: 0.7990 - val_loss: 0.9158 - val_iou_score: 0.4070
# Epoch 39/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2687 - iou_score: 0.8055 - val_loss: 1.1305 - val_iou_score: 0.2670
# Epoch 40/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2651 - iou_score: 0.8088 - val_loss: 0.5045 - val_iou_score: 0.6657
# Epoch 41/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.2560 - iou_score: 0.8155 - val_loss: 0.5554 - val_iou_score: 0.6279
# Epoch 42/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2573 - iou_score: 0.8148 - val_loss: 0.4413 - val_iou_score: 0.6984
# Epoch 43/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.2431 - iou_score: 0.8255 - val_loss: 0.7619 - val_iou_score: 0.5053
# Epoch 44/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2436 - iou_score: 0.8245 - val_loss: 0.6779 - val_iou_score: 0.5601
# Epoch 45/100
# 181/181 [==============================] - 8s 42ms/step - loss: 0.2396 - iou_score: 0.8275 - val_loss: 0.6164 - val_iou_score: 0.6177
# Epoch 46/100
# 181/181 [==============================] - 8s 46ms/step - loss: 0.2295 - iou_score: 0.8351 - val_loss: 0.7288 - val_iou_score: 0.5418
# Epoch 47/100
# 181/181 [==============================] - 8s 43ms/step - loss: 0.2299 - iou_score: 0.8344 - val_loss: 0.4661 - val_iou_score: 0.6841
# Epoch 48/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2289 - iou_score: 0.8360 - val_loss: 0.4685 - val_iou_score: 0.6860
# Epoch 49/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.2187 - iou_score: 0.8428 - val_loss: 0.5273 - val_iou_score: 0.6459
# Epoch 50/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.2056 - iou_score: 0.8518 - val_loss: 0.9353 - val_iou_score: 0.4214
# Epoch 51/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2175 - iou_score: 0.8442 - val_loss: 0.5922 - val_iou_score: 0.6014
# Epoch 52/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.2047 - iou_score: 0.8534 - val_loss: 0.4100 - val_iou_score: 0.7157
# Epoch 53/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1959 - iou_score: 0.8594 - val_loss: 0.4691 - val_iou_score: 0.6761
# Epoch 54/100
# 181/181 [==============================] - 8s 42ms/step - loss: 0.2059 - iou_score: 0.8526 - val_loss: 0.5102 - val_iou_score: 0.6558
# Epoch 55/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.2036 - iou_score: 0.8544 - val_loss: 0.4705 - val_iou_score: 0.6909
# Epoch 56/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1859 - iou_score: 0.8660 - val_loss: 0.4747 - val_iou_score: 0.6785
# Epoch 57/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1859 - iou_score: 0.8670 - val_loss: 0.5122 - val_iou_score: 0.6628
# Epoch 58/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1826 - iou_score: 0.8694 - val_loss: 0.4314 - val_iou_score: 0.7039
# Epoch 59/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1882 - iou_score: 0.8652 - val_loss: 0.4782 - val_iou_score: 0.6777
# Epoch 60/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1837 - iou_score: 0.8688 - val_loss: 0.4860 - val_iou_score: 0.6692
# Epoch 61/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1846 - iou_score: 0.8680 - val_loss: 0.6841 - val_iou_score: 0.5794
# Epoch 62/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1773 - iou_score: 0.8727 - val_loss: 0.4044 - val_iou_score: 0.7285
# Epoch 63/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.1983 - iou_score: 0.8591 - val_loss: 0.7712 - val_iou_score: 0.5175
# Epoch 64/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1763 - iou_score: 0.8737 - val_loss: 0.6530 - val_iou_score: 0.6018
# Epoch 65/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1780 - iou_score: 0.8728 - val_loss: 0.6094 - val_iou_score: 0.6177
# Epoch 66/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1758 - iou_score: 0.8744 - val_loss: 0.5405 - val_iou_score: 0.6385
# Epoch 67/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1757 - iou_score: 0.8745 - val_loss: 0.9176 - val_iou_score: 0.4523
# Epoch 68/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1722 - iou_score: 0.8770 - val_loss: 0.4236 - val_iou_score: 0.7164
# Epoch 69/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1629 - iou_score: 0.8835 - val_loss: 0.4217 - val_iou_score: 0.7142
# Epoch 70/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1717 - iou_score: 0.8777 - val_loss: 0.4277 - val_iou_score: 0.7081
# Epoch 71/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.1735 - iou_score: 0.8760 - val_loss: 0.7445 - val_iou_score: 0.5415
# Epoch 72/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1743 - iou_score: 0.8760 - val_loss: 0.4541 - val_iou_score: 0.7038
# Epoch 73/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1612 - iou_score: 0.8849 - val_loss: 0.4301 - val_iou_score: 0.7044
# Epoch 74/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1543 - iou_score: 0.8894 - val_loss: 0.4893 - val_iou_score: 0.6813
# Epoch 75/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1570 - iou_score: 0.8877 - val_loss: 0.4314 - val_iou_score: 0.7108
# Epoch 76/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1622 - iou_score: 0.8847 - val_loss: 0.4345 - val_iou_score: 0.7035
# Epoch 77/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1563 - iou_score: 0.8884 - val_loss: 0.4452 - val_iou_score: 0.7025
# Epoch 78/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1703 - iou_score: 0.8792 - val_loss: 0.4652 - val_iou_score: 0.6878
# Epoch 79/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.1659 - iou_score: 0.8818 - val_loss: 0.4138 - val_iou_score: 0.7218
# Epoch 80/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1510 - iou_score: 0.8917 - val_loss: 0.4434 - val_iou_score: 0.7038
# Epoch 81/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1535 - iou_score: 0.8910 - val_loss: 0.4412 - val_iou_score: 0.7031
# Epoch 82/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1495 - iou_score: 0.8933 - val_loss: 0.9369 - val_iou_score: 0.4461
# Epoch 83/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1487 - iou_score: 0.8940 - val_loss: 0.4463 - val_iou_score: 0.7015
# Epoch 84/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1466 - iou_score: 0.8953 - val_loss: 0.5002 - val_iou_score: 0.6800
# Epoch 85/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1485 - iou_score: 0.8943 - val_loss: 0.8492 - val_iou_score: 0.4765
# Epoch 86/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1516 - iou_score: 0.8920 - val_loss: 0.4560 - val_iou_score: 0.7067
# Epoch 87/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1506 - iou_score: 0.8928 - val_loss: 0.4198 - val_iou_score: 0.7240
# Epoch 88/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.1460 - iou_score: 0.8956 - val_loss: 0.4853 - val_iou_score: 0.6841
# Epoch 89/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1422 - iou_score: 0.8985 - val_loss: 0.4458 - val_iou_score: 0.7019
# Epoch 90/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1448 - iou_score: 0.8970 - val_loss: 0.5544 - val_iou_score: 0.6571
# Epoch 91/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1468 - iou_score: 0.8957 - val_loss: 0.4692 - val_iou_score: 0.6894
# Epoch 92/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1394 - iou_score: 0.9002 - val_loss: 0.4902 - val_iou_score: 0.6753
# Epoch 93/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1394 - iou_score: 0.9004 - val_loss: 0.4655 - val_iou_score: 0.6930
# Epoch 94/100
# 181/181 [==============================] - 7s 40ms/step - loss: 0.1363 - iou_score: 0.9025 - val_loss: 0.4082 - val_iou_score: 0.7300
# Epoch 95/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1387 - iou_score: 0.9012 - val_loss: 0.4424 - val_iou_score: 0.7115
# Epoch 96/100
# 181/181 [==============================] - 7s 41ms/step - loss: 0.1366 - iou_score: 0.9024 - val_loss: 0.4217 - val_iou_score: 0.7180
# Epoch 97/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1418 - iou_score: 0.8989 - val_loss: 0.5814 - val_iou_score: 0.6238
# Epoch 98/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1372 - iou_score: 0.9020 - val_loss: 0.6436 - val_iou_score: 0.5886
# Epoch 99/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1335 - iou_score: 0.9043 - val_loss: 0.4268 - val_iou_score: 0.7154
# Epoch 100/100
# 181/181 [==============================] - 7s 39ms/step - loss: 0.1334 - iou_score: 0.9045 - val_loss: 0.4191 - val_iou_score: 0.7248

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 16384, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  71.47044539451599 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)

print('Before Predicted and Actual Masks Shapes:')
print(y_pred.shape)
print(test_masks.shape) 

predicted_masks = reverse_masks_shape(y_pred)
test_masks = reverse_masks_shape(test_masks)

print('Reshaping Predicted and Actual Masks Shapes:')
print(predicted_masks.shape)
print(test_masks.shape) 

print('Final Predicted and Actual Masks Shapes:')
predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 1s 39ms/step
# Before Predicted and Actual Masks Shapes:
# (448, 16384, 10)
# (448, 16384, 10)
# Reshaping Predicted and Actual Masks Shapes:
# (448, 128, 128, 10)
# (448, 128, 128, 10)
# Final Predicted and Actual Masks Shapes:

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.44412914
# IoU for each class:
# Building Flooded: 0.4426214396953583
# Building Non-Flooded: 0.5481693744659424
# Road Flooded: 0.38964298367500305
# Road Non-Flooded: 0.6202857494354248
# Water: 0.6681777238845825
# Tree: 0.6580172181129456
# Vehicle: 0.004304920788854361
# Pool: 0.12033756822347641
# Grass: 0.8112062811851501
# Mean IoU (excluding Background): 0.47364038

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
