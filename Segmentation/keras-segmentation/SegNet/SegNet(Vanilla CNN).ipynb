# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'segnet'
BACKBONE = 'Vanilla CNN'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to ../../dataset/train_and_val_data.pickle
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 128, 128, 3)]     0
#
#  zero_padding2d_60 (ZeroPadd  (None, 130, 130, 3)      0
#  ing2D)
#
#  conv2d_52 (Conv2D)          (None, 128, 128, 64)      1792
#
#  batch_normalization_60 (Bat  (None, 128, 128, 64)     256
#  chNormalization)
#
#  activation_46 (Activation)  (None, 128, 128, 64)      0
#
#  max_pooling2d_45 (MaxPoolin  (None, 64, 64, 64)       0
#  g2D)
#
#  zero_padding2d_61 (ZeroPadd  (None, 66, 66, 64)       0
#  ing2D)
#
#  conv2d_53 (Conv2D)          (None, 64, 64, 128)       73856
#
#  batch_normalization_61 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  activation_47 (Activation)  (None, 64, 64, 128)       0
#
#  max_pooling2d_46 (MaxPoolin  (None, 32, 32, 128)      0
#  g2D)
#
#  zero_padding2d_62 (ZeroPadd  (None, 34, 34, 128)      0
#  ing2D)
#
#  conv2d_54 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_62 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_48 (Activation)  (None, 32, 32, 256)       0
#
#  max_pooling2d_47 (MaxPoolin  (None, 16, 16, 256)      0
#  g2D)
#
#  zero_padding2d_63 (ZeroPadd  (None, 18, 18, 256)      0
#  ing2D)
#
#  conv2d_55 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_63 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_49 (Activation)  (None, 16, 16, 256)       0
#
#  max_pooling2d_48 (MaxPoolin  (None, 8, 8, 256)        0
#  g2D)
#
#  zero_padding2d_65 (ZeroPadd  (None, 10, 10, 256)      0
#  ing2D)
#
#  conv2d_57 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  batch_normalization_65 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  up_sampling2d_16 (UpSamplin  (None, 16, 16, 512)      0
#  g2D)
#
#  zero_padding2d_66 (ZeroPadd  (None, 18, 18, 512)      0
#  ing2D)
#
#  conv2d_58 (Conv2D)          (None, 16, 16, 256)       1179904
#
#  batch_normalization_66 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  up_sampling2d_17 (UpSamplin  (None, 32, 32, 256)      0
#  g2D)
#
#  zero_padding2d_67 (ZeroPadd  (None, 34, 34, 256)      0
#  ing2D)
#
#  conv2d_59 (Conv2D)          (None, 32, 32, 128)       295040
#
#  batch_normalization_67 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  up_sampling2d_18 (UpSamplin  (None, 64, 64, 128)      0
#  g2D)
#
#  zero_padding2d_68 (ZeroPadd  (None, 66, 66, 128)      0
#  ing2D)
#
#  conv2d_60 (Conv2D)          (None, 64, 64, 64)        73792
#
#  batch_normalization_68 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  conv2d_61 (Conv2D)          (None, 64, 64, 10)        5770
#
#  reshape_1 (Reshape)         (None, 4096, 10)          0
#
#  activation_51 (Activation)  (None, 4096, 10)          0
#
# =================================================================
# Total params: 3,702,218
# Trainable params: 3,698,890
# Non-trainable params: 3,328
# _________________________________________________________________

# %%
from keras.models import Sequential
from keras.layers import UpSampling2D, ZeroPadding2D, Conv2D, BatchNormalization, Softmax

input_layer = model.layers[0] #Input Layer
model_layers = model.layers[1:-2] #All layers except the last two layers

model = Sequential()
model.add(input_layer)

for layer in model_layers:
    model.add(layer)

model.add(UpSampling2D((2, 2)))
model.add(ZeroPadding2D((1, 1)))
model.add(Conv2D(128, (3, 3), padding='valid', name="seg_feats1"))
model.add(BatchNormalization())

#Output Layer using Softmax Activation
model.add(Conv2D(n_classes, (1, 1), padding='valid', name="seg_feats2"))
model.add(Softmax()) 

model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  zero_padding2d_60 (ZeroPadd  (None, 130, 130, 3)      0
#  ing2D)
#
#  conv2d_52 (Conv2D)          (None, 128, 128, 64)      1792
#
#  batch_normalization_60 (Bat  (None, 128, 128, 64)     256
#  chNormalization)
#
#  activation_46 (Activation)  (None, 128, 128, 64)      0
#
#  max_pooling2d_45 (MaxPoolin  (None, 64, 64, 64)       0
#  g2D)
#
#  zero_padding2d_61 (ZeroPadd  (None, 66, 66, 64)       0
#  ing2D)
#
#  conv2d_53 (Conv2D)          (None, 64, 64, 128)       73856
#
#  batch_normalization_61 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  activation_47 (Activation)  (None, 64, 64, 128)       0
#
#  max_pooling2d_46 (MaxPoolin  (None, 32, 32, 128)      0
#  g2D)
#
#  zero_padding2d_62 (ZeroPadd  (None, 34, 34, 128)      0
#  ing2D)
#
#  conv2d_54 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_62 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_48 (Activation)  (None, 32, 32, 256)       0
#
#  max_pooling2d_47 (MaxPoolin  (None, 16, 16, 256)      0
#  g2D)
#
#  zero_padding2d_63 (ZeroPadd  (None, 18, 18, 256)      0
#  ing2D)
#
#  conv2d_55 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_63 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_49 (Activation)  (None, 16, 16, 256)       0
#
#  max_pooling2d_48 (MaxPoolin  (None, 8, 8, 256)        0
#  g2D)
#
#  zero_padding2d_65 (ZeroPadd  (None, 10, 10, 256)      0
#  ing2D)
#
#  conv2d_57 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  batch_normalization_65 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  up_sampling2d_16 (UpSamplin  (None, 16, 16, 512)      0
#  g2D)
#
#  zero_padding2d_66 (ZeroPadd  (None, 18, 18, 512)      0
#  ing2D)
#
#  conv2d_58 (Conv2D)          (None, 16, 16, 256)       1179904
#
#  batch_normalization_66 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  up_sampling2d_17 (UpSamplin  (None, 32, 32, 256)      0
#  g2D)
#
#  zero_padding2d_67 (ZeroPadd  (None, 34, 34, 256)      0
#  ing2D)
#
#  conv2d_59 (Conv2D)          (None, 32, 32, 128)       295040
#
#  batch_normalization_67 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  up_sampling2d_18 (UpSamplin  (None, 64, 64, 128)      0
#  g2D)
#
#  zero_padding2d_68 (ZeroPadd  (None, 66, 66, 128)      0
#  ing2D)
#
#  conv2d_60 (Conv2D)          (None, 64, 64, 64)        73792
#
#  batch_normalization_68 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  conv2d_61 (Conv2D)          (None, 64, 64, 10)        5770
#
#  up_sampling2d_20 (UpSamplin  (None, 128, 128, 10)     0
#  g2D)
#
#  zero_padding2d_70 (ZeroPadd  (None, 130, 130, 10)     0
#  ing2D)
#
#  seg_feats1 (Conv2D)         (None, 128, 128, 128)     11648
#
#  batch_normalization_70 (Bat  (None, 128, 128, 128)    512
#  chNormalization)
#
#  seg_feats2 (Conv2D)         (None, 128, 128, 10)      1290
#
#  softmax_2 (Softmax)         (None, 128, 128, 10)      0
#
# =================================================================
# Total params: 3,715,668
# Trainable params: 3,712,084
# Non-trainable params: 3,584
# _________________________________________________________________

# %%
model.input_shape, model.output_shape
# Out:
# ((None, 128, 128, 3), (None, 128, 128, 10))

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 13s 42ms/step - loss: 1.1034 - iou_score: 0.1238 - val_loss: 2.1969 - val_iou_score: 0.0174
# Epoch 2/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.9939 - iou_score: 0.1722 - val_loss: 2.0196 - val_iou_score: 0.0190
# Epoch 3/100
# 181/181 [==============================] - 6s 31ms/step - loss: 0.9627 - iou_score: 0.1945 - val_loss: 2.0533 - val_iou_score: 0.0191
# Epoch 4/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.9364 - iou_score: 0.2153 - val_loss: 0.9934 - val_iou_score: 0.1697
# Epoch 5/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.9066 - iou_score: 0.2414 - val_loss: 1.0541 - val_iou_score: 0.1690
# Epoch 6/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.8834 - iou_score: 0.2582 - val_loss: 1.1003 - val_iou_score: 0.1380
# Epoch 7/100
# 181/181 [==============================] - 6s 33ms/step - loss: 0.8664 - iou_score: 0.2717 - val_loss: 1.3716 - val_iou_score: 0.0992
# Epoch 8/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.8439 - iou_score: 0.2918 - val_loss: 1.1360 - val_iou_score: 0.1372
# Epoch 9/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.8246 - iou_score: 0.3068 - val_loss: 1.1274 - val_iou_score: 0.1275
# Epoch 10/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.8089 - iou_score: 0.3189 - val_loss: 1.2081 - val_iou_score: 0.1280
# Epoch 11/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.8022 - iou_score: 0.3231 - val_loss: 1.2634 - val_iou_score: 0.1170
# Epoch 12/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.7925 - iou_score: 0.3318 - val_loss: 1.1418 - val_iou_score: 0.1540
# Epoch 13/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.7753 - iou_score: 0.3463 - val_loss: 1.1378 - val_iou_score: 0.1403
# Epoch 14/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.7642 - iou_score: 0.3545 - val_loss: 1.3164 - val_iou_score: 0.1344
# Epoch 15/100
# 181/181 [==============================] - 6s 33ms/step - loss: 0.7569 - iou_score: 0.3597 - val_loss: 0.9687 - val_iou_score: 0.1949
# Epoch 16/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.7447 - iou_score: 0.3704 - val_loss: 1.1805 - val_iou_score: 0.1580
# Epoch 17/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.7338 - iou_score: 0.3801 - val_loss: 1.2808 - val_iou_score: 0.1310
# Epoch 18/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.7185 - iou_score: 0.3889 - val_loss: 1.0779 - val_iou_score: 0.1855
# Epoch 19/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.7070 - iou_score: 0.3999 - val_loss: 1.0114 - val_iou_score: 0.1788
# Epoch 20/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.7020 - iou_score: 0.4039 - val_loss: 0.9440 - val_iou_score: 0.2179
# Epoch 21/100
# 181/181 [==============================] - 6s 33ms/step - loss: 0.6857 - iou_score: 0.4155 - val_loss: 1.0657 - val_iou_score: 0.1817
# Epoch 22/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6760 - iou_score: 0.4242 - val_loss: 1.0649 - val_iou_score: 0.1800
# Epoch 23/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6870 - iou_score: 0.4165 - val_loss: 1.0392 - val_iou_score: 0.1816
# Epoch 24/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6696 - iou_score: 0.4274 - val_loss: 1.1603 - val_iou_score: 0.1624
# Epoch 25/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6474 - iou_score: 0.4445 - val_loss: 1.0296 - val_iou_score: 0.2027
# Epoch 26/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6492 - iou_score: 0.4422 - val_loss: 1.0096 - val_iou_score: 0.2123
# Epoch 27/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6427 - iou_score: 0.4487 - val_loss: 0.9102 - val_iou_score: 0.2392
# Epoch 28/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6247 - iou_score: 0.4633 - val_loss: 0.9286 - val_iou_score: 0.2347
# Epoch 29/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6285 - iou_score: 0.4593 - val_loss: 1.0332 - val_iou_score: 0.2081
# Epoch 30/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6200 - iou_score: 0.4674 - val_loss: 0.9601 - val_iou_score: 0.2186
# Epoch 31/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6146 - iou_score: 0.4701 - val_loss: 1.0718 - val_iou_score: 0.1762
# Epoch 32/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.6089 - iou_score: 0.4748 - val_loss: 0.8903 - val_iou_score: 0.2558
# Epoch 33/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5937 - iou_score: 0.4883 - val_loss: 1.0618 - val_iou_score: 0.1874
# Epoch 34/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5763 - iou_score: 0.5005 - val_loss: 0.8977 - val_iou_score: 0.2543
# Epoch 35/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5721 - iou_score: 0.5026 - val_loss: 0.9601 - val_iou_score: 0.2397
# Epoch 36/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5805 - iou_score: 0.4973 - val_loss: 1.0419 - val_iou_score: 0.1855
# Epoch 37/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5769 - iou_score: 0.5003 - val_loss: 0.8834 - val_iou_score: 0.2648
# Epoch 38/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5752 - iou_score: 0.5022 - val_loss: 0.9019 - val_iou_score: 0.2464
# Epoch 39/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5519 - iou_score: 0.5183 - val_loss: 0.8993 - val_iou_score: 0.2648
# Epoch 40/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5530 - iou_score: 0.5184 - val_loss: 1.0353 - val_iou_score: 0.1963
# Epoch 41/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5509 - iou_score: 0.5205 - val_loss: 1.0606 - val_iou_score: 0.2076
# Epoch 42/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5328 - iou_score: 0.5350 - val_loss: 0.8980 - val_iou_score: 0.2609
# Epoch 43/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5358 - iou_score: 0.5309 - val_loss: 0.8701 - val_iou_score: 0.2786
# Epoch 44/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5398 - iou_score: 0.5275 - val_loss: 0.8776 - val_iou_score: 0.2698
# Epoch 45/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5291 - iou_score: 0.5376 - val_loss: 1.0983 - val_iou_score: 0.1988
# Epoch 46/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5278 - iou_score: 0.5386 - val_loss: 1.0218 - val_iou_score: 0.2238
# Epoch 47/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5215 - iou_score: 0.5414 - val_loss: 1.0322 - val_iou_score: 0.2194
# Epoch 48/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5136 - iou_score: 0.5493 - val_loss: 0.9796 - val_iou_score: 0.2419
# Epoch 49/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5249 - iou_score: 0.5398 - val_loss: 0.9271 - val_iou_score: 0.2567
# Epoch 50/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5224 - iou_score: 0.5422 - val_loss: 0.8699 - val_iou_score: 0.2785
# Epoch 51/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5022 - iou_score: 0.5595 - val_loss: 0.8934 - val_iou_score: 0.2684
# Epoch 52/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4969 - iou_score: 0.5628 - val_loss: 1.0377 - val_iou_score: 0.2237
# Epoch 53/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4986 - iou_score: 0.5611 - val_loss: 1.0166 - val_iou_score: 0.2161
# Epoch 54/100
# 181/181 [==============================] - 6s 33ms/step - loss: 0.5067 - iou_score: 0.5533 - val_loss: 0.9089 - val_iou_score: 0.2748
# Epoch 55/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.5027 - iou_score: 0.5562 - val_loss: 0.9605 - val_iou_score: 0.2443
# Epoch 56/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4931 - iou_score: 0.5645 - val_loss: 0.8734 - val_iou_score: 0.2820
# Epoch 57/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4863 - iou_score: 0.5701 - val_loss: 0.9517 - val_iou_score: 0.2511
# Epoch 58/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4955 - iou_score: 0.5623 - val_loss: 0.8856 - val_iou_score: 0.2749
# Epoch 59/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4909 - iou_score: 0.5656 - val_loss: 0.8827 - val_iou_score: 0.2806
# Epoch 60/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4844 - iou_score: 0.5710 - val_loss: 0.9779 - val_iou_score: 0.2276
# Epoch 61/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4886 - iou_score: 0.5689 - val_loss: 0.9394 - val_iou_score: 0.2506
# Epoch 62/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4893 - iou_score: 0.5675 - val_loss: 1.0015 - val_iou_score: 0.2321
# Epoch 63/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4855 - iou_score: 0.5693 - val_loss: 0.8681 - val_iou_score: 0.2882
# Epoch 64/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4797 - iou_score: 0.5762 - val_loss: 0.8886 - val_iou_score: 0.2834
# Epoch 65/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4890 - iou_score: 0.5683 - val_loss: 0.8966 - val_iou_score: 0.2720
# Epoch 66/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4761 - iou_score: 0.5790 - val_loss: 0.8603 - val_iou_score: 0.2876
# Epoch 67/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4731 - iou_score: 0.5800 - val_loss: 0.8722 - val_iou_score: 0.2921
# Epoch 68/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4594 - iou_score: 0.5918 - val_loss: 0.8866 - val_iou_score: 0.2806
# Epoch 69/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4722 - iou_score: 0.5813 - val_loss: 0.9778 - val_iou_score: 0.2495
# Epoch 70/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4752 - iou_score: 0.5779 - val_loss: 0.9316 - val_iou_score: 0.2470
# Epoch 71/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4756 - iou_score: 0.5771 - val_loss: 1.0005 - val_iou_score: 0.2335
# Epoch 72/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4736 - iou_score: 0.5789 - val_loss: 0.9027 - val_iou_score: 0.2744
# Epoch 73/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4701 - iou_score: 0.5817 - val_loss: 0.9085 - val_iou_score: 0.2664
# Epoch 74/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4622 - iou_score: 0.5897 - val_loss: 0.8613 - val_iou_score: 0.2888
# Epoch 75/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4529 - iou_score: 0.5961 - val_loss: 0.8608 - val_iou_score: 0.2860
# Epoch 76/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4575 - iou_score: 0.5918 - val_loss: 0.9516 - val_iou_score: 0.2585
# Epoch 77/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4510 - iou_score: 0.5994 - val_loss: 0.9177 - val_iou_score: 0.2735
# Epoch 78/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4518 - iou_score: 0.5977 - val_loss: 0.8439 - val_iou_score: 0.3035
# Epoch 79/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4575 - iou_score: 0.5928 - val_loss: 0.9523 - val_iou_score: 0.2454
# Epoch 80/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4543 - iou_score: 0.5954 - val_loss: 0.8702 - val_iou_score: 0.2900
# Epoch 81/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4561 - iou_score: 0.5917 - val_loss: 1.0806 - val_iou_score: 0.2230
# Epoch 82/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4492 - iou_score: 0.6005 - val_loss: 0.8772 - val_iou_score: 0.2927
# Epoch 83/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4535 - iou_score: 0.5968 - val_loss: 0.8790 - val_iou_score: 0.2873
# Epoch 84/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4611 - iou_score: 0.5876 - val_loss: 0.8569 - val_iou_score: 0.3013
# Epoch 85/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4460 - iou_score: 0.6008 - val_loss: 0.9023 - val_iou_score: 0.2679
# Epoch 86/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4593 - iou_score: 0.5919 - val_loss: 0.9687 - val_iou_score: 0.2590
# Epoch 87/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4564 - iou_score: 0.5939 - val_loss: 0.8827 - val_iou_score: 0.2830
# Epoch 88/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4389 - iou_score: 0.6070 - val_loss: 0.8714 - val_iou_score: 0.2917
# Epoch 89/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4405 - iou_score: 0.6059 - val_loss: 0.8767 - val_iou_score: 0.2854
# Epoch 90/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4437 - iou_score: 0.6023 - val_loss: 0.9262 - val_iou_score: 0.2770
# Epoch 91/100
# 181/181 [==============================] - 6s 33ms/step - loss: 0.4495 - iou_score: 0.5976 - val_loss: 0.8649 - val_iou_score: 0.2897
# Epoch 92/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4423 - iou_score: 0.6046 - val_loss: 0.8842 - val_iou_score: 0.2882
# Epoch 93/100
# 181/181 [==============================] - 6s 33ms/step - loss: 0.4404 - iou_score: 0.6044 - val_loss: 0.8411 - val_iou_score: 0.3026
# Epoch 94/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4370 - iou_score: 0.6081 - val_loss: 0.9065 - val_iou_score: 0.2807
# Epoch 95/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4490 - iou_score: 0.5978 - val_loss: 0.9702 - val_iou_score: 0.2557
# Epoch 96/100
# 181/181 [==============================] - 6s 33ms/step - loss: 0.4385 - iou_score: 0.6058 - val_loss: 0.8928 - val_iou_score: 0.2836
# Epoch 97/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4400 - iou_score: 0.6052 - val_loss: 0.9848 - val_iou_score: 0.2628
# Epoch 98/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4467 - iou_score: 0.6024 - val_loss: 0.9528 - val_iou_score: 0.2460
# Epoch 99/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4414 - iou_score: 0.6030 - val_loss: 0.8955 - val_iou_score: 0.2741
# Epoch 100/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.4275 - iou_score: 0.6166 - val_loss: 0.8908 - val_iou_score: 0.2862

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  34.25801694393158 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)

print(y_pred.shape)
print(test_masks.shape) 

predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(y_pred.shape)
print(test_masks.shape)
# Out:
# 14/14 [==============================] - 0s 25ms/step
# (448, 128, 128, 10)
# (448, 128, 128, 10)
# (448, 128, 128, 10)
# (448, 128, 128, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.45445028
# IoU for each class:
# Building Flooded: 0.4456179738044739
# Building Non-Flooded: 0.5182446241378784
# Road Flooded: 0.38478386402130127
# Road Non-Flooded: 0.6185706257820129
# Water: 0.6677457690238953
# Tree: 0.569774329662323
# Vehicle: 0.06666269898414612
# Pool: 0.2245958149433136
# Grass: 0.7823107242584229
# Mean IoU (excluding Background): 0.4753674

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
