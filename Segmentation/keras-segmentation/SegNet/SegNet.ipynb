# %%
from keras_segmentation.models.segnet import segnet

model = segnet(n_classes=10 , input_height=256, input_width=256)

# %%
model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  zero_padding2d_8 (ZeroPaddi  (None, 258, 258, 3)      0
#  ng2D)
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 64)      1792
#
#  batch_normalization_8 (Batc  (None, 256, 256, 64)     256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256, 256, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 64)     0
#  )
#
#  zero_padding2d_9 (ZeroPaddi  (None, 130, 130, 64)     0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 128)     73856
#
#  batch_normalization_9 (Batc  (None, 128, 128, 128)    512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 128)     0
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 128)      0
#  2D)
#
#  zero_padding2d_10 (ZeroPadd  (None, 66, 66, 128)      0
#  ing2D)
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 256)       295168
#
#  batch_normalization_10 (Bat  (None, 64, 64, 256)      1024
#  chNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 256)      0
#  2D)
#
#  zero_padding2d_11 (ZeroPadd  (None, 34, 34, 256)      0
#  ing2D)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_11 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 256)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  zero_padding2d_13 (ZeroPadd  (None, 18, 18, 256)      0
#  ing2D)
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 512)       1180160
#
#  batch_normalization_13 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  up_sampling2d_6 (UpSampling  (None, 32, 32, 512)      0
#  2D)
#
#  zero_padding2d_14 (ZeroPadd  (None, 34, 34, 512)      0
#  ing2D)
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 256)       1179904
#
#  batch_normalization_14 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  up_sampling2d_7 (UpSampling  (None, 64, 64, 256)      0
#  2D)
#
#  zero_padding2d_15 (ZeroPadd  (None, 66, 66, 256)      0
#  ing2D)
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 128)       295040
#
#  batch_normalization_15 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  up_sampling2d_8 (UpSampling  (None, 128, 128, 128)    0
#  2D)
#
#  zero_padding2d_16 (ZeroPadd  (None, 130, 130, 128)    0
#  ing2D)
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 64)      73792
#
#  batch_normalization_16 (Bat  (None, 128, 128, 64)     256
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 10)      5770
#
#  reshape_2 (Reshape)         (None, 16384, 10)         0
#
#  activation_7 (Activation)   (None, 16384, 10)         0
#
# =================================================================
# Total params: 3,702,218
# Trainable params: 3,698,890
# Non-trainable params: 3,328
# _________________________________________________________________

# %%
model.train(
    train_images =  "dataset1/images_prepped_train/",
    train_annotations = "dataset1/annotations_prepped_train/",
    checkpoints_path = "/tmp/vgg_unet_1" , epochs=5
)

out = model.predict_segmentation(
    inp="dataset1/images_prepped_test/0016E5_07965.png",
    out_fname="/tmp/out.png"
)

import matplotlib.pyplot as plt
plt.imshow(out)

# evaluating the model 
print(model.evaluate_segmentation( inp_images_dir="dataset1/images_prepped_test/"  , annotations_dir="dataset1/annotations_prepped_test/" ) )
