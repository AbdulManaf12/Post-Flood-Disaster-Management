# %%
# !nvidia-smi
# Out:
# Tue Feb 20 13:02:03 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0              25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/FloodNet-Supervised_v1.0.zip'

# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from skimage.transform import resize
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

seed = 42
SIZE_X = 256
SIZE_Y = 256
n_channels = 3
n_classes = 10
Batch_size = 4
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'Vanilla Mini CNN'

parent_directory = r'/content/FloodNet-Supervised_v1.0'

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}

color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128],
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format.
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3))))
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = []

    image_folder_path = f'{parent_directory}/{split}/{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)

    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)

    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], -1, n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')
# Out:
# 100%|██████████| 1445/1445 [06:22<00:00,  3.78it/s]
# TRAIN: Images loaded: 1445
# TRAIN: Masks loaded: 1445
# 100%|██████████| 450/450 [01:59<00:00,  3.77it/s]
# VAL: Images loaded: 450
# VAL: Masks loaded: 450

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = f'/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/train_and_val_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to /content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/train_and_val_data(256x256).pickle
# Shapes of loaded data:
# Train Images: (1445, 256, 256, 3)
# Train Masks: (1445, 256, 256)
# Val Images: (450, 256, 256, 3)
# Val Masks: (450, 256, 256)

# %%
pickle_file_path = f'/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/train_and_val_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 448, 448, 3)
# Train Masks: (1445, 448, 448)
# Val Images: (450, 448, 448, 3)
# Val Masks: (450, 448, 448)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 256, 256, 3)
# Train Masks: (1445, 65536, 10)
# Val Images: (450, 256, 256, 3)
# Val Masks: (450, 65536, 10)

# %%
# !pip install keras_segmentation
# !pip install segmentation_models
# Out:
# Requirement already satisfied: keras_segmentation in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: Keras>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (2.15.0)
# Requirement already satisfied: imageio==2.5.0 in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (2.5.0)
# Requirement already satisfied: imgaug==0.2.9 in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (0.2.9)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (4.8.0.76)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from keras_segmentation) (4.66.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio==2.5.0->keras_segmentation) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imageio==2.5.0->keras_segmentation) (9.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (1.11.4)
# Requirement already satisfied: scikit-image>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (3.7.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug==0.2.9->keras_segmentation) (2.0.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras_segmentation) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.2.9->keras_segmentation) (2.8.2)
# Requirement already satisfied: segmentation_models in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from segmentation_models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.5.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (23.2)

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Segmentation Models: using `tf.keras` framework.
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 32)         896       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 256, 256, 32)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)         9248      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 32)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)         18496     ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 128, 128, 64)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 64)         36928     ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 64)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)          73856     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 64, 64, 128)          0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)          147584    ['dropout_2[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 128, 128, 128)        0         ['conv2d_5[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 128, 128, 192)        0         ['up_sampling2d[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 64)         110656    ['concatenate[0][0]']
#
#  dropout_3 (Dropout)         (None, 128, 128, 64)         0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 64)         36928     ['dropout_3[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 256, 256, 64)         0         ['conv2d_7[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 256, 256, 96)         0         ['up_sampling2d_1[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 32)         27680     ['concatenate_1[0][0]']
#
#  dropout_4 (Dropout)         (None, 256, 256, 32)         0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 32)         9248      ['dropout_4[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 10)         330       ['conv2d_9[0][0]']
#
#  reshape (Reshape)           (None, 65536, 10)            0         ['conv2d_10[0][0]']
#
#  activation (Activation)     (None, 65536, 10)            0         ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 471850 (1.80 MB)
# Trainable params: 471850 (1.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.input_shape, model.output_shape
# Out:
# ((None, 256, 256, 3), (None, 65536, 10))

# %%
train_images.shape, train_masks.shape
# Out:
# ((1445, 256, 256, 3), (1445, 65536, 10))

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 362/362 [==============================] - 18s 40ms/step - loss: 0.9089 - iou_score: 0.3596 - val_loss: 0.8747 - val_iou_score: 0.3663
# Epoch 2/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.8321 - iou_score: 0.3966 - val_loss: 0.8295 - val_iou_score: 0.3982
# Epoch 3/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.7794 - iou_score: 0.4284 - val_loss: 0.7654 - val_iou_score: 0.4474
# Epoch 4/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.7571 - iou_score: 0.4412 - val_loss: 0.7245 - val_iou_score: 0.4569
# Epoch 5/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.7374 - iou_score: 0.4563 - val_loss: 0.7936 - val_iou_score: 0.4331
# Epoch 6/100
# 362/362 [==============================] - 11s 30ms/step - loss: 0.7074 - iou_score: 0.4766 - val_loss: 0.6649 - val_iou_score: 0.5097
# Epoch 7/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.7032 - iou_score: 0.4825 - val_loss: 0.6780 - val_iou_score: 0.4916
# Epoch 8/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.6877 - iou_score: 0.4904 - val_loss: 0.6740 - val_iou_score: 0.5090
# Epoch 9/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.6832 - iou_score: 0.4958 - val_loss: 0.7274 - val_iou_score: 0.4626
# Epoch 10/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.6937 - iou_score: 0.4895 - val_loss: 0.6722 - val_iou_score: 0.4996
# Epoch 11/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.6713 - iou_score: 0.5048 - val_loss: 0.6258 - val_iou_score: 0.5352
# Epoch 12/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.6460 - iou_score: 0.5225 - val_loss: 0.6385 - val_iou_score: 0.5422
# Epoch 13/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.6054 - iou_score: 0.5509 - val_loss: 0.5809 - val_iou_score: 0.5699
# Epoch 14/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.6015 - iou_score: 0.5534 - val_loss: 0.5707 - val_iou_score: 0.5754
# Epoch 15/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.5693 - iou_score: 0.5775 - val_loss: 0.5516 - val_iou_score: 0.5889
# Epoch 16/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.5624 - iou_score: 0.5827 - val_loss: 0.5511 - val_iou_score: 0.5881
# Epoch 17/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.5532 - iou_score: 0.5896 - val_loss: 0.5667 - val_iou_score: 0.5800
# Epoch 18/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.5406 - iou_score: 0.5993 - val_loss: 0.5247 - val_iou_score: 0.6177
# Epoch 19/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.5260 - iou_score: 0.6101 - val_loss: 0.5698 - val_iou_score: 0.5872
# Epoch 20/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.5170 - iou_score: 0.6165 - val_loss: 0.5221 - val_iou_score: 0.6125
# Epoch 21/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.5116 - iou_score: 0.6189 - val_loss: 0.5033 - val_iou_score: 0.6247
# Epoch 22/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.5018 - iou_score: 0.6279 - val_loss: 0.5462 - val_iou_score: 0.5902
# Epoch 23/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4926 - iou_score: 0.6343 - val_loss: 0.4959 - val_iou_score: 0.6344
# Epoch 24/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4839 - iou_score: 0.6412 - val_loss: 0.4897 - val_iou_score: 0.6411
# Epoch 25/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4800 - iou_score: 0.6441 - val_loss: 0.4676 - val_iou_score: 0.6507
# Epoch 26/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4727 - iou_score: 0.6497 - val_loss: 0.4774 - val_iou_score: 0.6461
# Epoch 27/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4624 - iou_score: 0.6569 - val_loss: 0.4468 - val_iou_score: 0.6680
# Epoch 28/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4640 - iou_score: 0.6557 - val_loss: 0.4516 - val_iou_score: 0.6661
# Epoch 29/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4565 - iou_score: 0.6617 - val_loss: 0.4570 - val_iou_score: 0.6575
# Epoch 30/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4577 - iou_score: 0.6614 - val_loss: 0.4448 - val_iou_score: 0.6725
# Epoch 31/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4457 - iou_score: 0.6697 - val_loss: 0.4704 - val_iou_score: 0.6519
# Epoch 32/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4434 - iou_score: 0.6717 - val_loss: 0.4786 - val_iou_score: 0.6450
# Epoch 33/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4384 - iou_score: 0.6751 - val_loss: 0.4262 - val_iou_score: 0.6801
# Epoch 34/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4277 - iou_score: 0.6832 - val_loss: 0.4439 - val_iou_score: 0.6677
# Epoch 35/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4270 - iou_score: 0.6832 - val_loss: 0.4140 - val_iou_score: 0.6938
# Epoch 36/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4233 - iou_score: 0.6868 - val_loss: 0.4177 - val_iou_score: 0.6903
# Epoch 37/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4132 - iou_score: 0.6941 - val_loss: 0.4470 - val_iou_score: 0.6679
# Epoch 38/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4116 - iou_score: 0.6956 - val_loss: 0.4791 - val_iou_score: 0.6423
# Epoch 39/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4107 - iou_score: 0.6960 - val_loss: 0.4241 - val_iou_score: 0.6869
# Epoch 40/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4018 - iou_score: 0.7020 - val_loss: 0.4216 - val_iou_score: 0.6879
# Epoch 41/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4014 - iou_score: 0.7030 - val_loss: 0.4331 - val_iou_score: 0.6826
# Epoch 42/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.4078 - iou_score: 0.6974 - val_loss: 0.3929 - val_iou_score: 0.7066
# Epoch 43/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3958 - iou_score: 0.7076 - val_loss: 0.3942 - val_iou_score: 0.7070
# Epoch 44/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3918 - iou_score: 0.7095 - val_loss: 0.3955 - val_iou_score: 0.7056
# Epoch 45/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3923 - iou_score: 0.7086 - val_loss: 0.4192 - val_iou_score: 0.6878
# Epoch 46/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3880 - iou_score: 0.7123 - val_loss: 0.3937 - val_iou_score: 0.7092
# Epoch 47/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3845 - iou_score: 0.7151 - val_loss: 0.3951 - val_iou_score: 0.7049
# Epoch 48/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3836 - iou_score: 0.7157 - val_loss: 0.4021 - val_iou_score: 0.7010
# Epoch 49/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3830 - iou_score: 0.7154 - val_loss: 0.4173 - val_iou_score: 0.6949
# Epoch 50/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3777 - iou_score: 0.7207 - val_loss: 0.3981 - val_iou_score: 0.7034
# Epoch 51/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3760 - iou_score: 0.7215 - val_loss: 0.3960 - val_iou_score: 0.7082
# Epoch 52/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3732 - iou_score: 0.7237 - val_loss: 0.4166 - val_iou_score: 0.6918
# Epoch 53/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3671 - iou_score: 0.7284 - val_loss: 0.3887 - val_iou_score: 0.7132
# Epoch 54/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3661 - iou_score: 0.7287 - val_loss: 0.3828 - val_iou_score: 0.7175
# Epoch 55/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3741 - iou_score: 0.7230 - val_loss: 0.3848 - val_iou_score: 0.7193
# Epoch 56/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3675 - iou_score: 0.7283 - val_loss: 0.3901 - val_iou_score: 0.7097
# Epoch 57/100
# 362/362 [==============================] - 11s 30ms/step - loss: 0.3619 - iou_score: 0.7324 - val_loss: 0.3970 - val_iou_score: 0.7061
# Epoch 58/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3626 - iou_score: 0.7319 - val_loss: 0.3823 - val_iou_score: 0.7203
# Epoch 59/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3587 - iou_score: 0.7345 - val_loss: 0.3728 - val_iou_score: 0.7211
# Epoch 60/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3512 - iou_score: 0.7402 - val_loss: 0.3799 - val_iou_score: 0.7183
# Epoch 61/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3546 - iou_score: 0.7376 - val_loss: 0.3670 - val_iou_score: 0.7290
# Epoch 62/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3523 - iou_score: 0.7398 - val_loss: 0.3674 - val_iou_score: 0.7272
# Epoch 63/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3503 - iou_score: 0.7410 - val_loss: 0.3689 - val_iou_score: 0.7274
# Epoch 64/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3498 - iou_score: 0.7411 - val_loss: 0.3769 - val_iou_score: 0.7216
# Epoch 65/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3515 - iou_score: 0.7382 - val_loss: 0.3885 - val_iou_score: 0.7160
# Epoch 66/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3496 - iou_score: 0.7413 - val_loss: 0.3612 - val_iou_score: 0.7338
# Epoch 67/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3427 - iou_score: 0.7472 - val_loss: 0.4028 - val_iou_score: 0.7055
# Epoch 68/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3465 - iou_score: 0.7438 - val_loss: 0.3705 - val_iou_score: 0.7234
# Epoch 69/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3465 - iou_score: 0.7439 - val_loss: 0.3898 - val_iou_score: 0.7119
# Epoch 70/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3409 - iou_score: 0.7479 - val_loss: 0.3658 - val_iou_score: 0.7311
# Epoch 71/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3417 - iou_score: 0.7478 - val_loss: 0.3748 - val_iou_score: 0.7238
# Epoch 72/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3401 - iou_score: 0.7485 - val_loss: 0.3721 - val_iou_score: 0.7301
# Epoch 73/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3350 - iou_score: 0.7523 - val_loss: 0.3759 - val_iou_score: 0.7228
# Epoch 74/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3364 - iou_score: 0.7518 - val_loss: 0.3738 - val_iou_score: 0.7236
# Epoch 75/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3386 - iou_score: 0.7500 - val_loss: 0.3629 - val_iou_score: 0.7353
# Epoch 76/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3316 - iou_score: 0.7553 - val_loss: 0.3574 - val_iou_score: 0.7384
# Epoch 77/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3368 - iou_score: 0.7516 - val_loss: 0.3528 - val_iou_score: 0.7410
# Epoch 78/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3320 - iou_score: 0.7539 - val_loss: 0.3560 - val_iou_score: 0.7402
# Epoch 79/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3288 - iou_score: 0.7574 - val_loss: 0.3769 - val_iou_score: 0.7219
# Epoch 80/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3266 - iou_score: 0.7584 - val_loss: 0.3533 - val_iou_score: 0.7399
# Epoch 81/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3298 - iou_score: 0.7567 - val_loss: 0.3643 - val_iou_score: 0.7341
# Epoch 82/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3275 - iou_score: 0.7580 - val_loss: 0.3540 - val_iou_score: 0.7402
# Epoch 83/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3249 - iou_score: 0.7601 - val_loss: 0.3642 - val_iou_score: 0.7313
# Epoch 84/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3255 - iou_score: 0.7596 - val_loss: 0.3654 - val_iou_score: 0.7323
# Epoch 85/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3247 - iou_score: 0.7599 - val_loss: 0.3555 - val_iou_score: 0.7392
# Epoch 86/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3285 - iou_score: 0.7572 - val_loss: 0.3642 - val_iou_score: 0.7318
# Epoch 87/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3217 - iou_score: 0.7624 - val_loss: 0.3487 - val_iou_score: 0.7425
# Epoch 88/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3229 - iou_score: 0.7616 - val_loss: 0.3464 - val_iou_score: 0.7448
# Epoch 89/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3166 - iou_score: 0.7667 - val_loss: 0.3611 - val_iou_score: 0.7349
# Epoch 90/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3182 - iou_score: 0.7651 - val_loss: 0.3956 - val_iou_score: 0.7070
# Epoch 91/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3158 - iou_score: 0.7668 - val_loss: 0.3511 - val_iou_score: 0.7420
# Epoch 92/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3172 - iou_score: 0.7658 - val_loss: 0.3586 - val_iou_score: 0.7401
# Epoch 93/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3194 - iou_score: 0.7639 - val_loss: 0.3474 - val_iou_score: 0.7447
# Epoch 94/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3111 - iou_score: 0.7693 - val_loss: 0.3461 - val_iou_score: 0.7452
# Epoch 95/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3111 - iou_score: 0.7699 - val_loss: 0.3511 - val_iou_score: 0.7394
# Epoch 96/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3147 - iou_score: 0.7666 - val_loss: 0.3689 - val_iou_score: 0.7290
# Epoch 97/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3124 - iou_score: 0.7692 - val_loss: 0.3634 - val_iou_score: 0.7323
# Epoch 98/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3092 - iou_score: 0.7717 - val_loss: 0.3488 - val_iou_score: 0.7434
# Epoch 99/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3093 - iou_score: 0.7716 - val_loss: 0.3466 - val_iou_score: 0.7450
# Epoch 100/100
# 362/362 [==============================] - 11s 29ms/step - loss: 0.3082 - iou_score: 0.7728 - val_loss: 0.3448 - val_iou_score: 0.7464

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']
plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y}).hdf5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
dir = '/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/keras-segmentation/Unet_weights_256x256'
model.load_weights(f'{dir}/weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y}).hdf5')

# %%
test_parent_directory = r'/content/FloodNet-Supervised_v1.0'

test_images, test_masks = load_images(test_parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = f'/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to /content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/test_data(256x256).pickle
# Shapes of loaded data:
# Test Images: (448, 256, 256, 3)
# Test Masks: (448, 65536, 10)

# %%
pickle_file_path = f'/content/drive/MyDrive/Post-Flood Disaster Management/Code/Segmentation/segmentation_models/dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 256, 256, 3)
# Test Masks: (448, 65536, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  73.4454333782196 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)

print(y_pred.shape)
print(test_masks.shape)

predicted_masks = reverse_masks_shape(y_pred)
test_masks = reverse_masks_shape(test_masks)

print(predicted_masks.shape)
print(test_masks.shape)

predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 1s 41ms/step
# (448, 65536, 10)
# (448, 65536, 10)
# (448, 256, 256, 10)
# (448, 256, 256, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0:
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.51552844
# IoU for each class:
# Building Flooded: 0.6453368663787842
# Building Non-Flooded: 0.6056528687477112
# Road Flooded: 0.37982377409935
# Road Non-Flooded: 0.7082857489585876
# Water: 0.6029483079910278
# Tree: 0.7264900207519531
# Vehicle: 0.26065438985824585
# Pool: 0.3463427722454071
# Grass: 0.8364803791046143
# Mean IoU (excluding Background): 0.5680016

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha='right')

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)

# %%
display_random_function()
# Out:
# Image Shape: (256, 256, 3)
# Ground Truth Mask Shape: (256, 256)
# Predicted Mask Shape: (256, 256)
