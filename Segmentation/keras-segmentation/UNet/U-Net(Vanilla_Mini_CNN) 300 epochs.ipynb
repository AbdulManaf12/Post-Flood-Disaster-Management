# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 300
MODEL = 'unet'
BACKBONE = 'Vanilla Mini CNN'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], -1, n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Data saved to ../../dataset/train_and_val_data.pickle
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 16384, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 16384, 10)

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Segmentation Models: using `keras` framework.
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 32  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 64)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 128)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['dropout_2[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 128)  0           ['conv2d_5[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 192)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   110656      ['concatenate[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 64)   0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   36928       ['dropout_3[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 64  0          ['conv2d_7[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 32  27680       ['concatenate_1[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 128, 128, 32  0           ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 32  9248        ['dropout_4[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 10  330         ['conv2d_9[0][0]']
#                                 )
#
#  reshape (Reshape)              (None, 16384, 10)    0           ['conv2d_10[0][0]']
#
#  activation (Activation)        (None, 16384, 10)    0           ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 471,850
# Trainable params: 471,850
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/300
# 181/181 [==============================] - 11s 36ms/step - loss: 0.9171 - iou_score: 0.3555 - val_loss: 0.8686 - val_iou_score: 0.3998
# Epoch 2/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.8663 - iou_score: 0.3742 - val_loss: 0.8429 - val_iou_score: 0.3874
# Epoch 3/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.8402 - iou_score: 0.3924 - val_loss: 0.8097 - val_iou_score: 0.4276
# Epoch 4/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.8092 - iou_score: 0.4109 - val_loss: 0.7740 - val_iou_score: 0.4402
# Epoch 5/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.7858 - iou_score: 0.4222 - val_loss: 0.7452 - val_iou_score: 0.4464
# Epoch 6/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.7538 - iou_score: 0.4433 - val_loss: 0.7250 - val_iou_score: 0.4700
# Epoch 7/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.7412 - iou_score: 0.4514 - val_loss: 0.7299 - val_iou_score: 0.4709
# Epoch 8/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.7065 - iou_score: 0.4767 - val_loss: 0.6083 - val_iou_score: 0.5481
# Epoch 9/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.6750 - iou_score: 0.4994 - val_loss: 0.6114 - val_iou_score: 0.5390
# Epoch 10/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.6250 - iou_score: 0.5349 - val_loss: 0.5671 - val_iou_score: 0.5833
# Epoch 11/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.6014 - iou_score: 0.5537 - val_loss: 0.5696 - val_iou_score: 0.5750
# Epoch 12/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5937 - iou_score: 0.5581 - val_loss: 0.5447 - val_iou_score: 0.5965
# Epoch 13/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.5635 - iou_score: 0.5801 - val_loss: 0.5389 - val_iou_score: 0.6007
# Epoch 14/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5370 - iou_score: 0.6007 - val_loss: 0.5188 - val_iou_score: 0.6191
# Epoch 15/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5242 - iou_score: 0.6099 - val_loss: 0.5321 - val_iou_score: 0.6120
# Epoch 16/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5162 - iou_score: 0.6158 - val_loss: 0.4935 - val_iou_score: 0.6361
# Epoch 17/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4992 - iou_score: 0.6276 - val_loss: 0.4937 - val_iou_score: 0.6357
# Epoch 18/300
# 181/181 [==============================] - 6s 31ms/step - loss: 0.4807 - iou_score: 0.6415 - val_loss: 0.4535 - val_iou_score: 0.6638
# Epoch 19/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4734 - iou_score: 0.6479 - val_loss: 0.4429 - val_iou_score: 0.6726
# Epoch 20/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4735 - iou_score: 0.6472 - val_loss: 0.4474 - val_iou_score: 0.6756
# Epoch 21/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4598 - iou_score: 0.6583 - val_loss: 0.4514 - val_iou_score: 0.6663
# Epoch 22/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4469 - iou_score: 0.6672 - val_loss: 0.4327 - val_iou_score: 0.6853
# Epoch 23/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4464 - iou_score: 0.6678 - val_loss: 0.4678 - val_iou_score: 0.6501
# Epoch 24/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4399 - iou_score: 0.6718 - val_loss: 0.4311 - val_iou_score: 0.6818
# Epoch 25/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4335 - iou_score: 0.6773 - val_loss: 0.4264 - val_iou_score: 0.6800
# Epoch 26/300
# 181/181 [==============================] - 6s 33ms/step - loss: 0.4190 - iou_score: 0.6876 - val_loss: 0.4307 - val_iou_score: 0.6845
# Epoch 27/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4197 - iou_score: 0.6870 - val_loss: 0.4325 - val_iou_score: 0.6794
# Epoch 28/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4179 - iou_score: 0.6887 - val_loss: 0.4102 - val_iou_score: 0.6926
# Epoch 29/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4033 - iou_score: 0.6993 - val_loss: 0.4154 - val_iou_score: 0.6956
# Epoch 30/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.4031 - iou_score: 0.6997 - val_loss: 0.4287 - val_iou_score: 0.6859
# Epoch 31/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3978 - iou_score: 0.7032 - val_loss: 0.4006 - val_iou_score: 0.7065
# Epoch 32/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3866 - iou_score: 0.7117 - val_loss: 0.4094 - val_iou_score: 0.6973
# Epoch 33/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3873 - iou_score: 0.7114 - val_loss: 0.4047 - val_iou_score: 0.7000
# Epoch 34/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3797 - iou_score: 0.7169 - val_loss: 0.3875 - val_iou_score: 0.7129
# Epoch 35/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3725 - iou_score: 0.7219 - val_loss: 0.3907 - val_iou_score: 0.7183
# Epoch 36/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3776 - iou_score: 0.7186 - val_loss: 0.3883 - val_iou_score: 0.7126
# Epoch 37/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3682 - iou_score: 0.7253 - val_loss: 0.4025 - val_iou_score: 0.7033
# Epoch 38/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3738 - iou_score: 0.7212 - val_loss: 0.4460 - val_iou_score: 0.6703
# Epoch 39/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3667 - iou_score: 0.7267 - val_loss: 0.4162 - val_iou_score: 0.6930
# Epoch 40/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3488 - iou_score: 0.7397 - val_loss: 0.3792 - val_iou_score: 0.7200
# Epoch 41/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3513 - iou_score: 0.7372 - val_loss: 0.3960 - val_iou_score: 0.7084
# Epoch 42/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3529 - iou_score: 0.7365 - val_loss: 0.3746 - val_iou_score: 0.7269
# Epoch 43/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3556 - iou_score: 0.7346 - val_loss: 0.3763 - val_iou_score: 0.7203
# Epoch 44/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.3570 - iou_score: 0.7333 - val_loss: 0.3828 - val_iou_score: 0.7174
# Epoch 45/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.3389 - iou_score: 0.7471 - val_loss: 0.3796 - val_iou_score: 0.7192
# Epoch 46/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3366 - iou_score: 0.7487 - val_loss: 0.4246 - val_iou_score: 0.6907
# Epoch 47/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3400 - iou_score: 0.7459 - val_loss: 0.3636 - val_iou_score: 0.7297
# Epoch 48/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3444 - iou_score: 0.7427 - val_loss: 0.3740 - val_iou_score: 0.7236
# Epoch 49/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3348 - iou_score: 0.7501 - val_loss: 0.3576 - val_iou_score: 0.7337
# Epoch 50/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3383 - iou_score: 0.7469 - val_loss: 0.3757 - val_iou_score: 0.7213
# Epoch 51/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3276 - iou_score: 0.7549 - val_loss: 0.3618 - val_iou_score: 0.7335
# Epoch 52/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3223 - iou_score: 0.7590 - val_loss: 0.4014 - val_iou_score: 0.7075
# Epoch 53/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3252 - iou_score: 0.7570 - val_loss: 0.3758 - val_iou_score: 0.7199
# Epoch 54/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3242 - iou_score: 0.7582 - val_loss: 0.3915 - val_iou_score: 0.7130
# Epoch 55/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3173 - iou_score: 0.7631 - val_loss: 0.3570 - val_iou_score: 0.7381
# Epoch 56/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3130 - iou_score: 0.7660 - val_loss: 0.3831 - val_iou_score: 0.7178
# Epoch 57/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3167 - iou_score: 0.7633 - val_loss: 0.3656 - val_iou_score: 0.7310
# Epoch 58/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3100 - iou_score: 0.7686 - val_loss: 0.3500 - val_iou_score: 0.7386
# Epoch 59/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3082 - iou_score: 0.7696 - val_loss: 0.3611 - val_iou_score: 0.7335
# Epoch 60/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3080 - iou_score: 0.7698 - val_loss: 0.3561 - val_iou_score: 0.7386
# Epoch 61/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3032 - iou_score: 0.7730 - val_loss: 0.3633 - val_iou_score: 0.7358
# Epoch 62/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3077 - iou_score: 0.7702 - val_loss: 0.3656 - val_iou_score: 0.7319
# Epoch 63/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3131 - iou_score: 0.7661 - val_loss: 0.3603 - val_iou_score: 0.7351
# Epoch 64/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3038 - iou_score: 0.7731 - val_loss: 0.3593 - val_iou_score: 0.7359
# Epoch 65/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2958 - iou_score: 0.7793 - val_loss: 0.3436 - val_iou_score: 0.7502
# Epoch 66/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3023 - iou_score: 0.7736 - val_loss: 0.3726 - val_iou_score: 0.7288
# Epoch 67/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.3036 - iou_score: 0.7735 - val_loss: 0.3815 - val_iou_score: 0.7231
# Epoch 68/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3043 - iou_score: 0.7729 - val_loss: 0.3432 - val_iou_score: 0.7485
# Epoch 69/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2951 - iou_score: 0.7797 - val_loss: 0.3376 - val_iou_score: 0.7554
# Epoch 70/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2939 - iou_score: 0.7805 - val_loss: 0.3654 - val_iou_score: 0.7314
# Epoch 71/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2887 - iou_score: 0.7832 - val_loss: 0.3656 - val_iou_score: 0.7341
# Epoch 72/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2891 - iou_score: 0.7842 - val_loss: 0.3544 - val_iou_score: 0.7380
# Epoch 73/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2866 - iou_score: 0.7855 - val_loss: 0.3597 - val_iou_score: 0.7347
# Epoch 74/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2849 - iou_score: 0.7869 - val_loss: 0.3715 - val_iou_score: 0.7272
# Epoch 75/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2815 - iou_score: 0.7898 - val_loss: 0.3459 - val_iou_score: 0.7477
# Epoch 76/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2872 - iou_score: 0.7850 - val_loss: 0.3419 - val_iou_score: 0.7501
# Epoch 77/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2837 - iou_score: 0.7879 - val_loss: 0.3473 - val_iou_score: 0.7474
# Epoch 78/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2831 - iou_score: 0.7882 - val_loss: 0.3501 - val_iou_score: 0.7455
# Epoch 79/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2775 - iou_score: 0.7924 - val_loss: 0.3424 - val_iou_score: 0.7476
# Epoch 80/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2814 - iou_score: 0.7899 - val_loss: 0.3674 - val_iou_score: 0.7296
# Epoch 81/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2781 - iou_score: 0.7919 - val_loss: 0.3517 - val_iou_score: 0.7427
# Epoch 82/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2723 - iou_score: 0.7967 - val_loss: 0.3451 - val_iou_score: 0.7481
# Epoch 83/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2747 - iou_score: 0.7945 - val_loss: 0.3383 - val_iou_score: 0.7542
# Epoch 84/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2700 - iou_score: 0.7982 - val_loss: 0.3522 - val_iou_score: 0.7451
# Epoch 85/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2746 - iou_score: 0.7950 - val_loss: 0.3562 - val_iou_score: 0.7386
# Epoch 86/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2684 - iou_score: 0.7991 - val_loss: 0.3438 - val_iou_score: 0.7497
# Epoch 87/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2721 - iou_score: 0.7967 - val_loss: 0.3522 - val_iou_score: 0.7452
# Epoch 88/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2686 - iou_score: 0.7991 - val_loss: 0.3506 - val_iou_score: 0.7454
# Epoch 89/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2659 - iou_score: 0.8011 - val_loss: 0.3403 - val_iou_score: 0.7531
# Epoch 90/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2604 - iou_score: 0.8055 - val_loss: 0.3440 - val_iou_score: 0.7511
# Epoch 91/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2687 - iou_score: 0.7997 - val_loss: 0.3382 - val_iou_score: 0.7528
# Epoch 92/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2657 - iou_score: 0.8014 - val_loss: 0.3446 - val_iou_score: 0.7518
# Epoch 93/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2627 - iou_score: 0.8038 - val_loss: 0.3427 - val_iou_score: 0.7551
# Epoch 94/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2620 - iou_score: 0.8046 - val_loss: 0.3443 - val_iou_score: 0.7501
# Epoch 95/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2621 - iou_score: 0.8043 - val_loss: 0.3494 - val_iou_score: 0.7463
# Epoch 96/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2630 - iou_score: 0.8033 - val_loss: 0.3402 - val_iou_score: 0.7515
# Epoch 97/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2668 - iou_score: 0.8003 - val_loss: 0.3465 - val_iou_score: 0.7477
# Epoch 98/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2744 - iou_score: 0.7952 - val_loss: 0.3346 - val_iou_score: 0.7558
# Epoch 99/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2525 - iou_score: 0.8115 - val_loss: 0.3474 - val_iou_score: 0.7445
# Epoch 100/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2574 - iou_score: 0.8076 - val_loss: 0.3463 - val_iou_score: 0.7501
# Epoch 101/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2606 - iou_score: 0.8051 - val_loss: 0.3451 - val_iou_score: 0.7490
# Epoch 102/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2531 - iou_score: 0.8113 - val_loss: 0.3351 - val_iou_score: 0.7543
# Epoch 103/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2524 - iou_score: 0.8116 - val_loss: 0.3534 - val_iou_score: 0.7459
# Epoch 104/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2452 - iou_score: 0.8170 - val_loss: 0.3416 - val_iou_score: 0.7516
# Epoch 105/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2549 - iou_score: 0.8097 - val_loss: 0.3411 - val_iou_score: 0.7539
# Epoch 106/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2461 - iou_score: 0.8157 - val_loss: 0.3336 - val_iou_score: 0.7594
# Epoch 107/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2545 - iou_score: 0.8100 - val_loss: 0.3391 - val_iou_score: 0.7529
# Epoch 108/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2428 - iou_score: 0.8185 - val_loss: 0.3411 - val_iou_score: 0.7513
# Epoch 109/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2480 - iou_score: 0.8146 - val_loss: 0.3469 - val_iou_score: 0.7490
# Epoch 110/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2456 - iou_score: 0.8162 - val_loss: 0.3440 - val_iou_score: 0.7502
# Epoch 111/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2414 - iou_score: 0.8193 - val_loss: 0.3545 - val_iou_score: 0.7465
# Epoch 112/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2468 - iou_score: 0.8155 - val_loss: 0.3543 - val_iou_score: 0.7475
# Epoch 113/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2443 - iou_score: 0.8171 - val_loss: 0.3468 - val_iou_score: 0.7523
# Epoch 114/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2435 - iou_score: 0.8180 - val_loss: 0.3307 - val_iou_score: 0.7601
# Epoch 115/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2457 - iou_score: 0.8166 - val_loss: 0.3414 - val_iou_score: 0.7538
# Epoch 116/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2393 - iou_score: 0.8211 - val_loss: 0.3618 - val_iou_score: 0.7421
# Epoch 117/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2399 - iou_score: 0.8205 - val_loss: 0.3299 - val_iou_score: 0.7613
# Epoch 118/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2391 - iou_score: 0.8212 - val_loss: 0.3311 - val_iou_score: 0.7592
# Epoch 119/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2377 - iou_score: 0.8224 - val_loss: 0.3406 - val_iou_score: 0.7570
# Epoch 120/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2376 - iou_score: 0.8226 - val_loss: 0.3432 - val_iou_score: 0.7530
# Epoch 121/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2393 - iou_score: 0.8213 - val_loss: 0.3506 - val_iou_score: 0.7459
# Epoch 122/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2371 - iou_score: 0.8228 - val_loss: 0.3498 - val_iou_score: 0.7498
# Epoch 123/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2332 - iou_score: 0.8254 - val_loss: 0.3557 - val_iou_score: 0.7393
# Epoch 124/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2350 - iou_score: 0.8243 - val_loss: 0.3536 - val_iou_score: 0.7459
# Epoch 125/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2367 - iou_score: 0.8230 - val_loss: 0.3310 - val_iou_score: 0.7601
# Epoch 126/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2291 - iou_score: 0.8283 - val_loss: 0.3435 - val_iou_score: 0.7519
# Epoch 127/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2325 - iou_score: 0.8258 - val_loss: 0.3321 - val_iou_score: 0.7617
# Epoch 128/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2321 - iou_score: 0.8264 - val_loss: 0.3436 - val_iou_score: 0.7549
# Epoch 129/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2376 - iou_score: 0.8226 - val_loss: 0.3409 - val_iou_score: 0.7522
# Epoch 130/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2325 - iou_score: 0.8260 - val_loss: 0.3428 - val_iou_score: 0.7549
# Epoch 131/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2330 - iou_score: 0.8253 - val_loss: 0.3387 - val_iou_score: 0.7565
# Epoch 132/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2280 - iou_score: 0.8296 - val_loss: 0.3361 - val_iou_score: 0.7577
# Epoch 133/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2291 - iou_score: 0.8288 - val_loss: 0.3413 - val_iou_score: 0.7562
# Epoch 134/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2287 - iou_score: 0.8291 - val_loss: 0.3572 - val_iou_score: 0.7437
# Epoch 135/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2263 - iou_score: 0.8307 - val_loss: 0.3308 - val_iou_score: 0.7631
# Epoch 136/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2205 - iou_score: 0.8350 - val_loss: 0.3413 - val_iou_score: 0.7568
# Epoch 137/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2332 - iou_score: 0.8254 - val_loss: 0.3449 - val_iou_score: 0.7497
# Epoch 138/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2314 - iou_score: 0.8272 - val_loss: 0.3302 - val_iou_score: 0.7629
# Epoch 139/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2273 - iou_score: 0.8299 - val_loss: 0.3366 - val_iou_score: 0.7585
# Epoch 140/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2191 - iou_score: 0.8358 - val_loss: 0.3400 - val_iou_score: 0.7582
# Epoch 141/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2189 - iou_score: 0.8363 - val_loss: 0.3473 - val_iou_score: 0.7532
# Epoch 142/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2163 - iou_score: 0.8383 - val_loss: 0.3515 - val_iou_score: 0.7473
# Epoch 143/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2194 - iou_score: 0.8358 - val_loss: 0.3368 - val_iou_score: 0.7591
# Epoch 144/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2352 - iou_score: 0.8239 - val_loss: 0.3355 - val_iou_score: 0.7587
# Epoch 145/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2161 - iou_score: 0.8381 - val_loss: 0.3463 - val_iou_score: 0.7521
# Epoch 146/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2238 - iou_score: 0.8328 - val_loss: 0.3417 - val_iou_score: 0.7560
# Epoch 147/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2165 - iou_score: 0.8380 - val_loss: 0.3373 - val_iou_score: 0.7586
# Epoch 148/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2170 - iou_score: 0.8376 - val_loss: 0.3342 - val_iou_score: 0.7617
# Epoch 149/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2161 - iou_score: 0.8384 - val_loss: 0.3324 - val_iou_score: 0.7602
# Epoch 150/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2148 - iou_score: 0.8393 - val_loss: 0.3405 - val_iou_score: 0.7553
# Epoch 151/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2216 - iou_score: 0.8340 - val_loss: 0.3391 - val_iou_score: 0.7580
# Epoch 152/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2199 - iou_score: 0.8356 - val_loss: 0.3316 - val_iou_score: 0.7616
# Epoch 153/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2142 - iou_score: 0.8394 - val_loss: 0.3306 - val_iou_score: 0.7606
# Epoch 154/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2157 - iou_score: 0.8386 - val_loss: 0.3386 - val_iou_score: 0.7594
# Epoch 155/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2208 - iou_score: 0.8349 - val_loss: 0.3323 - val_iou_score: 0.7626
# Epoch 156/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2161 - iou_score: 0.8382 - val_loss: 0.3356 - val_iou_score: 0.7595
# Epoch 157/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2101 - iou_score: 0.8429 - val_loss: 0.3257 - val_iou_score: 0.7685
# Epoch 158/300
# 181/181 [==============================] - 6s 31ms/step - loss: 0.2118 - iou_score: 0.8415 - val_loss: 0.3451 - val_iou_score: 0.7577
# Epoch 159/300
# 181/181 [==============================] - 6s 31ms/step - loss: 0.2108 - iou_score: 0.8426 - val_loss: 0.3495 - val_iou_score: 0.7492
# Epoch 160/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2112 - iou_score: 0.8418 - val_loss: 0.3315 - val_iou_score: 0.7611
# Epoch 161/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2146 - iou_score: 0.8396 - val_loss: 0.3406 - val_iou_score: 0.7547
# Epoch 162/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2177 - iou_score: 0.8371 - val_loss: 0.3315 - val_iou_score: 0.7627
# Epoch 163/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2169 - iou_score: 0.8376 - val_loss: 0.3307 - val_iou_score: 0.7626
# Epoch 164/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2105 - iou_score: 0.8426 - val_loss: 0.3390 - val_iou_score: 0.7603
# Epoch 165/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2072 - iou_score: 0.8447 - val_loss: 0.3430 - val_iou_score: 0.7555
# Epoch 166/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2080 - iou_score: 0.8445 - val_loss: 0.3338 - val_iou_score: 0.7611
# Epoch 167/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2204 - iou_score: 0.8351 - val_loss: 0.3242 - val_iou_score: 0.7679
# Epoch 168/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2047 - iou_score: 0.8469 - val_loss: 0.3370 - val_iou_score: 0.7611
# Epoch 169/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2146 - iou_score: 0.8397 - val_loss: 0.3427 - val_iou_score: 0.7558
# Epoch 170/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2078 - iou_score: 0.8444 - val_loss: 0.3363 - val_iou_score: 0.7629
# Epoch 171/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2161 - iou_score: 0.8384 - val_loss: 0.3691 - val_iou_score: 0.7375
# Epoch 172/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2091 - iou_score: 0.8433 - val_loss: 0.3396 - val_iou_score: 0.7593
# Epoch 173/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2049 - iou_score: 0.8465 - val_loss: 0.3594 - val_iou_score: 0.7486
# Epoch 174/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2085 - iou_score: 0.8441 - val_loss: 0.3306 - val_iou_score: 0.7659
# Epoch 175/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2057 - iou_score: 0.8461 - val_loss: 0.3242 - val_iou_score: 0.7678
# Epoch 176/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2075 - iou_score: 0.8447 - val_loss: 0.3426 - val_iou_score: 0.7578
# Epoch 177/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2042 - iou_score: 0.8472 - val_loss: 0.3302 - val_iou_score: 0.7660
# Epoch 178/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2051 - iou_score: 0.8465 - val_loss: 0.3557 - val_iou_score: 0.7492
# Epoch 179/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2119 - iou_score: 0.8413 - val_loss: 0.3300 - val_iou_score: 0.7645
# Epoch 180/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2024 - iou_score: 0.8484 - val_loss: 0.3337 - val_iou_score: 0.7656
# Epoch 181/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2041 - iou_score: 0.8474 - val_loss: 0.3357 - val_iou_score: 0.7598
# Epoch 182/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2009 - iou_score: 0.8497 - val_loss: 0.3337 - val_iou_score: 0.7620
# Epoch 183/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1991 - iou_score: 0.8506 - val_loss: 0.3299 - val_iou_score: 0.7640
# Epoch 184/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2000 - iou_score: 0.8503 - val_loss: 0.3359 - val_iou_score: 0.7599
# Epoch 185/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1998 - iou_score: 0.8502 - val_loss: 0.3310 - val_iou_score: 0.7649
# Epoch 186/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2026 - iou_score: 0.8481 - val_loss: 0.3455 - val_iou_score: 0.7545
# Epoch 187/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1975 - iou_score: 0.8522 - val_loss: 0.3338 - val_iou_score: 0.7625
# Epoch 188/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2071 - iou_score: 0.8449 - val_loss: 0.3363 - val_iou_score: 0.7592
# Epoch 189/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2021 - iou_score: 0.8487 - val_loss: 0.3281 - val_iou_score: 0.7662
# Epoch 190/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1973 - iou_score: 0.8522 - val_loss: 0.3442 - val_iou_score: 0.7536
# Epoch 191/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1995 - iou_score: 0.8506 - val_loss: 0.3351 - val_iou_score: 0.7621
# Epoch 192/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2024 - iou_score: 0.8485 - val_loss: 0.3432 - val_iou_score: 0.7540
# Epoch 193/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1953 - iou_score: 0.8537 - val_loss: 0.3236 - val_iou_score: 0.7722
# Epoch 194/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1973 - iou_score: 0.8524 - val_loss: 0.3363 - val_iou_score: 0.7612
# Epoch 195/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2000 - iou_score: 0.8503 - val_loss: 0.3416 - val_iou_score: 0.7611
# Epoch 196/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1972 - iou_score: 0.8522 - val_loss: 0.3348 - val_iou_score: 0.7640
# Epoch 197/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1988 - iou_score: 0.8511 - val_loss: 0.3546 - val_iou_score: 0.7525
# Epoch 198/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2027 - iou_score: 0.8481 - val_loss: 0.3285 - val_iou_score: 0.7689
# Epoch 199/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1963 - iou_score: 0.8530 - val_loss: 0.3434 - val_iou_score: 0.7601
# Epoch 200/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1930 - iou_score: 0.8554 - val_loss: 0.3313 - val_iou_score: 0.7651
# Epoch 201/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1963 - iou_score: 0.8532 - val_loss: 0.3421 - val_iou_score: 0.7585
# Epoch 202/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1930 - iou_score: 0.8553 - val_loss: 0.3454 - val_iou_score: 0.7583
# Epoch 203/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1983 - iou_score: 0.8516 - val_loss: 0.3430 - val_iou_score: 0.7569
# Epoch 204/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1967 - iou_score: 0.8528 - val_loss: 0.3419 - val_iou_score: 0.7554
# Epoch 205/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1932 - iou_score: 0.8553 - val_loss: 0.3361 - val_iou_score: 0.7617
# Epoch 206/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1940 - iou_score: 0.8547 - val_loss: 0.3505 - val_iou_score: 0.7525
# Epoch 207/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1945 - iou_score: 0.8543 - val_loss: 0.3347 - val_iou_score: 0.7624
# Epoch 208/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1933 - iou_score: 0.8550 - val_loss: 0.3456 - val_iou_score: 0.7520
# Epoch 209/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1960 - iou_score: 0.8533 - val_loss: 0.3447 - val_iou_score: 0.7595
# Epoch 210/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1942 - iou_score: 0.8546 - val_loss: 0.3347 - val_iou_score: 0.7652
# Epoch 211/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1982 - iou_score: 0.8518 - val_loss: 0.3380 - val_iou_score: 0.7603
# Epoch 212/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1955 - iou_score: 0.8537 - val_loss: 0.3294 - val_iou_score: 0.7661
# Epoch 213/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1901 - iou_score: 0.8577 - val_loss: 0.3265 - val_iou_score: 0.7679
# Epoch 214/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1895 - iou_score: 0.8580 - val_loss: 0.3688 - val_iou_score: 0.7446
# Epoch 215/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.2061 - iou_score: 0.8456 - val_loss: 0.3380 - val_iou_score: 0.7615
# Epoch 216/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1892 - iou_score: 0.8583 - val_loss: 0.3346 - val_iou_score: 0.7682
# Epoch 217/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1916 - iou_score: 0.8565 - val_loss: 0.3344 - val_iou_score: 0.7609
# Epoch 218/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1866 - iou_score: 0.8602 - val_loss: 0.3392 - val_iou_score: 0.7615
# Epoch 219/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1916 - iou_score: 0.8565 - val_loss: 0.3334 - val_iou_score: 0.7650
# Epoch 220/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1924 - iou_score: 0.8561 - val_loss: 0.3434 - val_iou_score: 0.7625
# Epoch 221/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1895 - iou_score: 0.8576 - val_loss: 0.3360 - val_iou_score: 0.7623
# Epoch 222/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1879 - iou_score: 0.8593 - val_loss: 0.3247 - val_iou_score: 0.7673
# Epoch 223/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1922 - iou_score: 0.8561 - val_loss: 0.3390 - val_iou_score: 0.7601
# Epoch 224/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1937 - iou_score: 0.8548 - val_loss: 0.3457 - val_iou_score: 0.7571
# Epoch 225/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1908 - iou_score: 0.8571 - val_loss: 0.3317 - val_iou_score: 0.7662
# Epoch 226/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1904 - iou_score: 0.8574 - val_loss: 0.3442 - val_iou_score: 0.7562
# Epoch 227/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1901 - iou_score: 0.8577 - val_loss: 0.3332 - val_iou_score: 0.7657
# Epoch 228/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1842 - iou_score: 0.8620 - val_loss: 0.3319 - val_iou_score: 0.7663
# Epoch 229/300
# 181/181 [==============================] - 6s 31ms/step - loss: 0.1852 - iou_score: 0.8612 - val_loss: 0.3456 - val_iou_score: 0.7574
# Epoch 230/300
# 181/181 [==============================] - 6s 31ms/step - loss: 0.1897 - iou_score: 0.8579 - val_loss: 0.3391 - val_iou_score: 0.7636
# Epoch 231/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1907 - iou_score: 0.8575 - val_loss: 0.3394 - val_iou_score: 0.7637
# Epoch 232/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1917 - iou_score: 0.8562 - val_loss: 0.3522 - val_iou_score: 0.7504
# Epoch 233/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1918 - iou_score: 0.8567 - val_loss: 0.3353 - val_iou_score: 0.7644
# Epoch 234/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1832 - iou_score: 0.8628 - val_loss: 0.3314 - val_iou_score: 0.7687
# Epoch 235/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1806 - iou_score: 0.8648 - val_loss: 0.3338 - val_iou_score: 0.7646
# Epoch 236/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1858 - iou_score: 0.8609 - val_loss: 0.3355 - val_iou_score: 0.7675
# Epoch 237/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1878 - iou_score: 0.8593 - val_loss: 0.3457 - val_iou_score: 0.7579
# Epoch 238/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1873 - iou_score: 0.8597 - val_loss: 0.3501 - val_iou_score: 0.7546
# Epoch 239/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1876 - iou_score: 0.8594 - val_loss: 0.3377 - val_iou_score: 0.7658
# Epoch 240/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1881 - iou_score: 0.8591 - val_loss: 0.3312 - val_iou_score: 0.7665
# Epoch 241/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1978 - iou_score: 0.8517 - val_loss: 0.3269 - val_iou_score: 0.7664
# Epoch 242/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1839 - iou_score: 0.8622 - val_loss: 0.3263 - val_iou_score: 0.7733
# Epoch 243/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1785 - iou_score: 0.8664 - val_loss: 0.3401 - val_iou_score: 0.7618
# Epoch 244/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1833 - iou_score: 0.8626 - val_loss: 0.3364 - val_iou_score: 0.7662
# Epoch 245/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1838 - iou_score: 0.8621 - val_loss: 0.3336 - val_iou_score: 0.7671
# Epoch 246/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1882 - iou_score: 0.8591 - val_loss: 0.3241 - val_iou_score: 0.7687
# Epoch 247/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1839 - iou_score: 0.8623 - val_loss: 0.3338 - val_iou_score: 0.7664
# Epoch 248/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1816 - iou_score: 0.8640 - val_loss: 0.3316 - val_iou_score: 0.7678
# Epoch 249/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1841 - iou_score: 0.8622 - val_loss: 0.3384 - val_iou_score: 0.7594
# Epoch 250/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1837 - iou_score: 0.8622 - val_loss: 0.3308 - val_iou_score: 0.7672
# Epoch 251/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1781 - iou_score: 0.8660 - val_loss: 0.3442 - val_iou_score: 0.7557
# Epoch 252/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1843 - iou_score: 0.8619 - val_loss: 0.3426 - val_iou_score: 0.7604
# Epoch 253/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1792 - iou_score: 0.8652 - val_loss: 0.3422 - val_iou_score: 0.7635
# Epoch 254/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1848 - iou_score: 0.8614 - val_loss: 0.3501 - val_iou_score: 0.7541
# Epoch 255/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1801 - iou_score: 0.8649 - val_loss: 0.3218 - val_iou_score: 0.7693
# Epoch 256/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1812 - iou_score: 0.8641 - val_loss: 0.3533 - val_iou_score: 0.7537
# Epoch 257/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1807 - iou_score: 0.8644 - val_loss: 0.3418 - val_iou_score: 0.7634
# Epoch 258/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1812 - iou_score: 0.8642 - val_loss: 0.3320 - val_iou_score: 0.7660
# Epoch 259/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1762 - iou_score: 0.8679 - val_loss: 0.3389 - val_iou_score: 0.7615
# Epoch 260/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1840 - iou_score: 0.8622 - val_loss: 0.3461 - val_iou_score: 0.7573
# Epoch 261/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1848 - iou_score: 0.8613 - val_loss: 0.3357 - val_iou_score: 0.7657
# Epoch 262/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1797 - iou_score: 0.8651 - val_loss: 0.3274 - val_iou_score: 0.7698
# Epoch 263/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1816 - iou_score: 0.8640 - val_loss: 0.3315 - val_iou_score: 0.7665
# Epoch 264/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1791 - iou_score: 0.8657 - val_loss: 0.3306 - val_iou_score: 0.7672
# Epoch 265/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1778 - iou_score: 0.8665 - val_loss: 0.3280 - val_iou_score: 0.7694
# Epoch 266/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1780 - iou_score: 0.8665 - val_loss: 0.3539 - val_iou_score: 0.7522
# Epoch 267/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1932 - iou_score: 0.8553 - val_loss: 0.3335 - val_iou_score: 0.7646
# Epoch 268/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1780 - iou_score: 0.8666 - val_loss: 0.3472 - val_iou_score: 0.7614
# Epoch 269/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1757 - iou_score: 0.8682 - val_loss: 0.3241 - val_iou_score: 0.7724
# Epoch 270/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1772 - iou_score: 0.8671 - val_loss: 0.3369 - val_iou_score: 0.7634
# Epoch 271/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1803 - iou_score: 0.8649 - val_loss: 0.3291 - val_iou_score: 0.7678
# Epoch 272/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1750 - iou_score: 0.8687 - val_loss: 0.3287 - val_iou_score: 0.7694
# Epoch 273/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1793 - iou_score: 0.8656 - val_loss: 0.3418 - val_iou_score: 0.7613
# Epoch 274/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1757 - iou_score: 0.8682 - val_loss: 0.3339 - val_iou_score: 0.7657
# Epoch 275/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1791 - iou_score: 0.8658 - val_loss: 0.3375 - val_iou_score: 0.7629
# Epoch 276/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1763 - iou_score: 0.8679 - val_loss: 0.3438 - val_iou_score: 0.7613
# Epoch 277/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1736 - iou_score: 0.8698 - val_loss: 0.3388 - val_iou_score: 0.7648
# Epoch 278/300
# 181/181 [==============================] - 5s 30ms/step - loss: 0.1742 - iou_score: 0.8694 - val_loss: 0.3497 - val_iou_score: 0.7609
# Epoch 279/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1766 - iou_score: 0.8677 - val_loss: 0.3379 - val_iou_score: 0.7659
# Epoch 280/300
# 181/181 [==============================] - 6s 35ms/step - loss: 0.1747 - iou_score: 0.8690 - val_loss: 0.3232 - val_iou_score: 0.7737
# Epoch 281/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1833 - iou_score: 0.8626 - val_loss: 0.3367 - val_iou_score: 0.7616
# Epoch 282/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1771 - iou_score: 0.8672 - val_loss: 0.3265 - val_iou_score: 0.7689
# Epoch 283/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1743 - iou_score: 0.8693 - val_loss: 0.3399 - val_iou_score: 0.7595
# Epoch 284/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1724 - iou_score: 0.8706 - val_loss: 0.3267 - val_iou_score: 0.7706
# Epoch 285/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1736 - iou_score: 0.8697 - val_loss: 0.3385 - val_iou_score: 0.7652
# Epoch 286/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1820 - iou_score: 0.8638 - val_loss: 0.3318 - val_iou_score: 0.7709
# Epoch 287/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1743 - iou_score: 0.8694 - val_loss: 0.3297 - val_iou_score: 0.7674
# Epoch 288/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1705 - iou_score: 0.8720 - val_loss: 0.3380 - val_iou_score: 0.7637
# Epoch 289/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1762 - iou_score: 0.8679 - val_loss: 0.3301 - val_iou_score: 0.7695
# Epoch 290/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1782 - iou_score: 0.8662 - val_loss: 0.3341 - val_iou_score: 0.7672
# Epoch 291/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1725 - iou_score: 0.8704 - val_loss: 0.3329 - val_iou_score: 0.7677
# Epoch 292/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1780 - iou_score: 0.8669 - val_loss: 0.3376 - val_iou_score: 0.7649
# Epoch 293/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1718 - iou_score: 0.8711 - val_loss: 0.3369 - val_iou_score: 0.7631
# Epoch 294/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1757 - iou_score: 0.8681 - val_loss: 0.3418 - val_iou_score: 0.7631
# Epoch 295/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1731 - iou_score: 0.8701 - val_loss: 0.3280 - val_iou_score: 0.7726
# Epoch 296/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1730 - iou_score: 0.8701 - val_loss: 0.3334 - val_iou_score: 0.7684
# Epoch 297/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1726 - iou_score: 0.8705 - val_loss: 0.3227 - val_iou_score: 0.7734
# Epoch 298/300
# 181/181 [==============================] - 5s 29ms/step - loss: 0.1699 - iou_score: 0.8727 - val_loss: 0.3239 - val_iou_score: 0.7747
# Epoch 299/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1708 - iou_score: 0.8718 - val_loss: 0.3593 - val_iou_score: 0.7489
# Epoch 300/300
# 181/181 [==============================] - 5s 28ms/step - loss: 0.1745 - iou_score: 0.8693 - val_loss: 0.3347 - val_iou_score: 0.7675

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 16384, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  76.25907063484192 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)


print(y_pred.shape)
print(test_masks.shape) 

predicted_masks = reverse_masks_shape(y_pred)
test_masks = reverse_masks_shape(test_masks)

print(predicted_masks.shape)
print(test_masks.shape) 

predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 1s 30ms/step
# (448, 16384, 10)
# (448, 16384, 10)
# (448, 128, 128, 10)
# (448, 128, 128, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.5420785
# IoU for each class:
# Building Flooded: 0.6221388578414917
# Building Non-Flooded: 0.6451685428619385
# Road Flooded: 0.4282863140106201
# Road Non-Flooded: 0.7530733942985535
# Water: 0.6522808074951172
# Tree: 0.7420325875282288
# Vehicle: 0.2086489051580429
# Pool: 0.3012505769729614
# Grass: 0.8458319902420044
# Mean IoU (excluding Background): 0.57763463

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
