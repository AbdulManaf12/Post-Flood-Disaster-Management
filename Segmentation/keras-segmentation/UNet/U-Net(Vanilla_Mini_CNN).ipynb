# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'Vanilla Mini CNN'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], -1, n_classes))
    # masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

def reverse_masks_shape(masks):
    masks = masks.reshape((masks.shape[0], SIZE_X, SIZE_Y, n_classes))
    return masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
# import segmentation_models as sm

# preprocess_input = sm.get_preprocessing(BACKBONE)

# train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
# val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 16384, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 16384, 10)

# %%
from keras_segmentation.models.all_models import unet, pspnet, fcn, segnet
import segmentation_models as sm

model = None

if MODEL == 'unet':
    if BACKBONE == 'Vanilla Mini CNN':
        model = unet.unet_mini(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y)
    elif BACKBONE == 'Vanilla CNN':
        model = unet.unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'ResNet-50':
        model = unet.resnet50_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'VGG-16':
        model = unet.vgg_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'MobileNet':
        model = unet.mobilenet_unet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
elif MODEL == 'pspnet':
    if BACKBONE == 'Vanilla CNN':
        model = pspnet.pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'Vanilla CNN (50)':
        model = pspnet.pspnet_50(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'Vanilla CNN (101)':
        model = pspnet.pspnet_101(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'ResNet-50':
        model = pspnet.resnet50_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'VGG-16':
        model = pspnet.vgg_pspnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
elif MODEL == 'segnet':
    if BACKBONE == 'Vanilla CNN':
        model = segnet.segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'ResNet-50':
        model = segnet.resnet50_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'VGG-16':
        model = segnet.vgg_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
    elif BACKBONE == 'MobileNet':
        model = segnet.mobilenet_segnet(n_classes=n_classes , input_height=SIZE_X, input_width=SIZE_Y, channels=n_channels)
else:
    raise ValueError('Unknown model')

if model:
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    model.summary()
else:
    print('Model not found')
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 32  896         ['input_3[0][0]']
#                                 )
#
#  dropout_10 (Dropout)           (None, 128, 128, 32  0           ['conv2d_22[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_10[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 32)  0           ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d_4[0][0]']
#
#  dropout_11 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_11[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_5[0][0]']
#
#  dropout_12 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_12[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 128)  0          ['conv2d_27[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 192)  0           ['up_sampling2d_4[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 64)   110656      ['concatenate_4[0][0]']
#
#  dropout_13 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_13[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 64  0          ['conv2d_29[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_5[0][0]',
#                                 )                                 'conv2d_23[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 32  27680       ['concatenate_5[0][0]']
#                                 )
#
#  dropout_14 (Dropout)           (None, 128, 128, 32  0           ['conv2d_30[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_14[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 10  330         ['conv2d_31[0][0]']
#                                 )
#
#  reshape_2 (Reshape)            (None, 16384, 10)    0           ['conv2d_32[0][0]']
#
#  activation_2 (Activation)      (None, 16384, 10)    0           ['reshape_2[0][0]']
#
# ==================================================================================================
# Total params: 471,850
# Trainable params: 471,850
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 11s 37ms/step - loss: 0.9568 - iou_score: 0.3420 - val_loss: 0.8645 - val_iou_score: 0.3934
# Epoch 2/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.8680 - iou_score: 0.3739 - val_loss: 0.8161 - val_iou_score: 0.3981
# Epoch 3/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.8492 - iou_score: 0.3857 - val_loss: 0.8102 - val_iou_score: 0.4008
# Epoch 4/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.8208 - iou_score: 0.4039 - val_loss: 0.7801 - val_iou_score: 0.4273
# Epoch 5/100
# 181/181 [==============================] - 6s 31ms/step - loss: 0.8012 - iou_score: 0.4167 - val_loss: 0.7683 - val_iou_score: 0.4284
# Epoch 6/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.7772 - iou_score: 0.4283 - val_loss: 0.7610 - val_iou_score: 0.4374
# Epoch 7/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.7428 - iou_score: 0.4508 - val_loss: 0.7074 - val_iou_score: 0.4686
# Epoch 8/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.7357 - iou_score: 0.4576 - val_loss: 0.6677 - val_iou_score: 0.5119
# Epoch 9/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.6959 - iou_score: 0.4836 - val_loss: 0.6635 - val_iou_score: 0.5002
# Epoch 10/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.6504 - iou_score: 0.5159 - val_loss: 0.5693 - val_iou_score: 0.5794
# Epoch 11/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.6140 - iou_score: 0.5430 - val_loss: 0.5927 - val_iou_score: 0.5674
# Epoch 12/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5748 - iou_score: 0.5722 - val_loss: 0.5389 - val_iou_score: 0.6025
# Epoch 13/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5565 - iou_score: 0.5856 - val_loss: 0.5853 - val_iou_score: 0.5645
# Epoch 14/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5440 - iou_score: 0.5948 - val_loss: 0.5298 - val_iou_score: 0.6199
# Epoch 15/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5234 - iou_score: 0.6104 - val_loss: 0.5287 - val_iou_score: 0.6176
# Epoch 16/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.5100 - iou_score: 0.6207 - val_loss: 0.4655 - val_iou_score: 0.6575
# Epoch 17/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.5146 - iou_score: 0.6176 - val_loss: 0.4927 - val_iou_score: 0.6313
# Epoch 18/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4997 - iou_score: 0.6284 - val_loss: 0.4898 - val_iou_score: 0.6333
# Epoch 19/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4825 - iou_score: 0.6410 - val_loss: 0.4588 - val_iou_score: 0.6624
# Epoch 20/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4687 - iou_score: 0.6506 - val_loss: 0.4587 - val_iou_score: 0.6615
# Epoch 21/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4685 - iou_score: 0.6513 - val_loss: 0.4572 - val_iou_score: 0.6656
# Epoch 22/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4564 - iou_score: 0.6599 - val_loss: 0.4531 - val_iou_score: 0.6620
# Epoch 23/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4383 - iou_score: 0.6740 - val_loss: 0.4845 - val_iou_score: 0.6439
# Epoch 24/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.4432 - iou_score: 0.6696 - val_loss: 0.4345 - val_iou_score: 0.6789
# Epoch 25/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4255 - iou_score: 0.6829 - val_loss: 0.4178 - val_iou_score: 0.6930
# Epoch 26/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4350 - iou_score: 0.6764 - val_loss: 0.4431 - val_iou_score: 0.6721
# Epoch 27/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4289 - iou_score: 0.6807 - val_loss: 0.4129 - val_iou_score: 0.6985
# Epoch 28/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4217 - iou_score: 0.6861 - val_loss: 0.4294 - val_iou_score: 0.6806
# Epoch 29/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4063 - iou_score: 0.6973 - val_loss: 0.4311 - val_iou_score: 0.6889
# Epoch 30/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.4061 - iou_score: 0.6972 - val_loss: 0.4119 - val_iou_score: 0.6968
# Epoch 31/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.4003 - iou_score: 0.7015 - val_loss: 0.3980 - val_iou_score: 0.7062
# Epoch 32/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.3973 - iou_score: 0.7035 - val_loss: 0.3964 - val_iou_score: 0.7047
# Epoch 33/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.3923 - iou_score: 0.7078 - val_loss: 0.3937 - val_iou_score: 0.7079
# Epoch 34/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.3872 - iou_score: 0.7115 - val_loss: 0.4173 - val_iou_score: 0.6922
# Epoch 35/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3805 - iou_score: 0.7165 - val_loss: 0.3923 - val_iou_score: 0.7132
# Epoch 36/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3787 - iou_score: 0.7178 - val_loss: 0.4115 - val_iou_score: 0.6929
# Epoch 37/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.3735 - iou_score: 0.7212 - val_loss: 0.3929 - val_iou_score: 0.7119
# Epoch 38/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3698 - iou_score: 0.7241 - val_loss: 0.3791 - val_iou_score: 0.7208
# Epoch 39/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3694 - iou_score: 0.7248 - val_loss: 0.3936 - val_iou_score: 0.7107
# Epoch 40/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3600 - iou_score: 0.7315 - val_loss: 0.3679 - val_iou_score: 0.7278
# Epoch 41/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3575 - iou_score: 0.7333 - val_loss: 0.3784 - val_iou_score: 0.7246
# Epoch 42/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3556 - iou_score: 0.7354 - val_loss: 0.4180 - val_iou_score: 0.6909
# Epoch 43/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3494 - iou_score: 0.7390 - val_loss: 0.3726 - val_iou_score: 0.7264
# Epoch 44/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3550 - iou_score: 0.7355 - val_loss: 0.3805 - val_iou_score: 0.7181
# Epoch 45/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3519 - iou_score: 0.7383 - val_loss: 0.3729 - val_iou_score: 0.7269
# Epoch 46/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3468 - iou_score: 0.7412 - val_loss: 0.3946 - val_iou_score: 0.7102
# Epoch 47/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3490 - iou_score: 0.7401 - val_loss: 0.3714 - val_iou_score: 0.7250
# Epoch 48/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3390 - iou_score: 0.7467 - val_loss: 0.3764 - val_iou_score: 0.7272
# Epoch 49/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3372 - iou_score: 0.7481 - val_loss: 0.3647 - val_iou_score: 0.7293
# Epoch 50/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3357 - iou_score: 0.7496 - val_loss: 0.3619 - val_iou_score: 0.7351
# Epoch 51/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3391 - iou_score: 0.7470 - val_loss: 0.3585 - val_iou_score: 0.7346
# Epoch 52/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.3281 - iou_score: 0.7547 - val_loss: 0.3875 - val_iou_score: 0.7175
# Epoch 53/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3299 - iou_score: 0.7537 - val_loss: 0.3822 - val_iou_score: 0.7205
# Epoch 54/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3251 - iou_score: 0.7569 - val_loss: 0.3671 - val_iou_score: 0.7306
# Epoch 55/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3221 - iou_score: 0.7597 - val_loss: 0.3839 - val_iou_score: 0.7220
# Epoch 56/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3236 - iou_score: 0.7582 - val_loss: 0.3553 - val_iou_score: 0.7379
# Epoch 57/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3260 - iou_score: 0.7567 - val_loss: 0.3713 - val_iou_score: 0.7237
# Epoch 58/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.3136 - iou_score: 0.7657 - val_loss: 0.3577 - val_iou_score: 0.7347
# Epoch 59/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3272 - iou_score: 0.7555 - val_loss: 0.4047 - val_iou_score: 0.7071
# Epoch 60/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3246 - iou_score: 0.7577 - val_loss: 0.3611 - val_iou_score: 0.7372
# Epoch 61/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3113 - iou_score: 0.7676 - val_loss: 0.3530 - val_iou_score: 0.7424
# Epoch 62/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.3071 - iou_score: 0.7707 - val_loss: 0.3692 - val_iou_score: 0.7234
# Epoch 63/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3113 - iou_score: 0.7673 - val_loss: 0.3596 - val_iou_score: 0.7329
# Epoch 64/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3120 - iou_score: 0.7673 - val_loss: 0.3564 - val_iou_score: 0.7354
# Epoch 65/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3111 - iou_score: 0.7676 - val_loss: 0.3642 - val_iou_score: 0.7298
# Epoch 66/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3043 - iou_score: 0.7725 - val_loss: 0.3635 - val_iou_score: 0.7338
# Epoch 67/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3087 - iou_score: 0.7692 - val_loss: 0.3565 - val_iou_score: 0.7381
# Epoch 68/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2987 - iou_score: 0.7771 - val_loss: 0.3691 - val_iou_score: 0.7321
# Epoch 69/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3054 - iou_score: 0.7718 - val_loss: 0.3479 - val_iou_score: 0.7450
# Epoch 70/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2990 - iou_score: 0.7765 - val_loss: 0.3491 - val_iou_score: 0.7419
# Epoch 71/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.3128 - iou_score: 0.7665 - val_loss: 0.3647 - val_iou_score: 0.7281
# Epoch 72/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2997 - iou_score: 0.7762 - val_loss: 0.3617 - val_iou_score: 0.7370
# Epoch 73/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2948 - iou_score: 0.7795 - val_loss: 0.3454 - val_iou_score: 0.7489
# Epoch 74/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2870 - iou_score: 0.7857 - val_loss: 0.3464 - val_iou_score: 0.7451
# Epoch 75/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2881 - iou_score: 0.7847 - val_loss: 0.3381 - val_iou_score: 0.7524
# Epoch 76/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2898 - iou_score: 0.7835 - val_loss: 0.3468 - val_iou_score: 0.7449
# Epoch 77/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2930 - iou_score: 0.7811 - val_loss: 0.3508 - val_iou_score: 0.7444
# Epoch 78/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2900 - iou_score: 0.7834 - val_loss: 0.3567 - val_iou_score: 0.7397
# Epoch 79/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2865 - iou_score: 0.7861 - val_loss: 0.3353 - val_iou_score: 0.7556
# Epoch 80/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2883 - iou_score: 0.7845 - val_loss: 0.3408 - val_iou_score: 0.7490
# Epoch 81/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2877 - iou_score: 0.7851 - val_loss: 0.3416 - val_iou_score: 0.7517
# Epoch 82/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2833 - iou_score: 0.7887 - val_loss: 0.3687 - val_iou_score: 0.7288
# Epoch 83/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2834 - iou_score: 0.7881 - val_loss: 0.3404 - val_iou_score: 0.7497
# Epoch 84/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2758 - iou_score: 0.7936 - val_loss: 0.3557 - val_iou_score: 0.7370
# Epoch 85/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2745 - iou_score: 0.7947 - val_loss: 0.3481 - val_iou_score: 0.7435
# Epoch 86/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2738 - iou_score: 0.7952 - val_loss: 0.3446 - val_iou_score: 0.7471
# Epoch 87/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2828 - iou_score: 0.7883 - val_loss: 0.3400 - val_iou_score: 0.7509
# Epoch 88/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2748 - iou_score: 0.7946 - val_loss: 0.3506 - val_iou_score: 0.7437
# Epoch 89/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2723 - iou_score: 0.7966 - val_loss: 0.3342 - val_iou_score: 0.7568
# Epoch 90/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2785 - iou_score: 0.7919 - val_loss: 0.3403 - val_iou_score: 0.7489
# Epoch 91/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2687 - iou_score: 0.7988 - val_loss: 0.3549 - val_iou_score: 0.7421
# Epoch 92/100
# 181/181 [==============================] - 6s 32ms/step - loss: 0.2710 - iou_score: 0.7977 - val_loss: 0.3408 - val_iou_score: 0.7496
# Epoch 93/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2727 - iou_score: 0.7961 - val_loss: 0.3426 - val_iou_score: 0.7489
# Epoch 94/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2682 - iou_score: 0.7998 - val_loss: 0.3543 - val_iou_score: 0.7412
# Epoch 95/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2703 - iou_score: 0.7976 - val_loss: 0.3340 - val_iou_score: 0.7559
# Epoch 96/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2657 - iou_score: 0.8017 - val_loss: 0.3463 - val_iou_score: 0.7466
# Epoch 97/100
# 181/181 [==============================] - 5s 29ms/step - loss: 0.2624 - iou_score: 0.8042 - val_loss: 0.3534 - val_iou_score: 0.7403
# Epoch 98/100
# 181/181 [==============================] - 6s 31ms/step - loss: 0.2661 - iou_score: 0.8010 - val_loss: 0.3878 - val_iou_score: 0.7170
# Epoch 99/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2806 - iou_score: 0.7901 - val_loss: 0.3384 - val_iou_score: 0.7525
# Epoch 100/100
# 181/181 [==============================] - 5s 30ms/step - loss: 0.2601 - iou_score: 0.8058 - val_loss: 0.3380 - val_iou_score: 0.7537

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

# test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)
test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

# test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)
test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 16384, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  74.29859042167664 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)


print(y_pred.shape)
print(test_masks.shape) 

predicted_masks = reverse_masks_shape(y_pred)
test_masks = reverse_masks_shape(test_masks)

print(predicted_masks.shape)
print(test_masks.shape) 

predicted_masks = np.argmax(predicted_masks, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)
# Out:
# 14/14 [==============================] - 1s 49ms/step
# (448, 16384, 10)
# (448, 16384, 10)
# (448, 128, 128, 10)
# (448, 128, 128, 10)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.5103302
# IoU for each class:
# Building Flooded: 0.624756932258606
# Building Non-Flooded: 0.6261510252952576
# Road Flooded: 0.4015948176383972
# Road Non-Flooded: 0.7307916879653931
# Water: 0.6324601173400879
# Tree: 0.726426899433136
# Vehicle: 0.17885619401931763
# Pool: 0.2759074568748474
# Grass: 0.8351563215255737
# Mean IoU (excluding Background): 0.5591224

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
