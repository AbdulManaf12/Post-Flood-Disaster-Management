# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'efficientnetb7'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
import segmentation_models as sm
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Concatenate, Softmax
from tensorflow.keras.layers import concatenate, BatchNormalization, UpSampling2D, Activation, Conv2DTranspose

def res_inception_unit(input_layer, filters):
    # First convolutional block
    conv1x1_1 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv1x1_1 = BatchNormalization()(conv1x1_1)

    # Second convolutional block
    conv1x1_2 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv3x3_2 = Conv2D(filters, (3, 3), padding='same')(conv1x1_2)
    conv3x3_2 = BatchNormalization()(conv3x3_2)

    # Third convolutional block
    conv1x1_3 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv3x3_3 = Conv2D(filters, (3, 3), padding='same')(conv1x1_3)
    conv3x3_3 = BatchNormalization()(conv3x3_3)
    conv3x3_3 = Conv2D(filters, (3, 3), padding='same')(conv3x3_3)
    conv3x3_3 = BatchNormalization()(conv3x3_3)

    concatenated = concatenate([conv1x1_1, conv3x3_2, conv3x3_3], axis=-1)

    output = Conv2D(filters, (1, 1), padding='same')(concatenated)
    output = Activation('relu')(output)
    return output

def pyramid_pooling_module(input_layer, levels=[1, 2, 4, 8]):
    pooled_outputs = []
    for level in levels:
        pooled = MaxPooling2D(pool_size=(level, level))(input_layer)
        pooled = Conv2D(filters=input_layer.shape[-1], kernel_size=(1, 1), padding='same', activation='relu')(pooled)
        pooled_outputs.append(pooled)
    upsampled_outputs = [UpSampling2D(size=(level, level))(pooled) for level, pooled in zip(levels, pooled_outputs)]
    concatenated = Concatenate(axis=-1)([input_layer] + upsampled_outputs)
    return concatenated

def dense_upsampling_convolution(input_layer, filters):
    x = Conv2DTranspose(filters, kernel_size=(3, 3), strides=(2, 2), padding='same')(input_layer)
    x = Conv2D(filters, kernel_size=(3, 3), padding='same')(x)
    return x

def encoder(inputs, encoder_filters):
    encoder_outputs = [inputs]
    for i, filters in enumerate(encoder_filters):
        x = res_inception_unit(encoder_outputs[-1], filters)
        encoder_outputs.append(MaxPooling2D(pool_size=(2, 2))(x) if i < len(encoder_filters) - 1 else x)
    return encoder_outputs

def decoder(global_feature_map, encoder_outputs, decoder_filters):
    x = global_feature_map
    for i, filters in enumerate(decoder_filters):
        x = dense_upsampling_convolution(x, filters)
        encoder_output = encoder_outputs[-(i + 2)]

        if encoder_output.shape[1:3] != x.shape[1:3]:
            encoder_output = Conv2D(filters, kernel_size=(1, 1), padding='same')(encoder_output)
            encoder_output = UpSampling2D(size=(2, 2))(encoder_output)
        x = concatenate([x, encoder_output], axis=-1)
        x = res_inception_unit(x, filters)
    return x

def build_model(input_shape, num_classes):
    inputs = Input(input_shape)
    encoder_filters = [32, 64, 128, 256, 512]

    encoder_outputs = encoder(inputs, encoder_filters)
    
    bridge_output = pyramid_pooling_module(encoder_outputs[-1], levels=[1, 2, 4, 8])

    decoder_filters = [512, 256, 128, 64]
    segmentation_map = decoder(bridge_output, encoder_outputs, decoder_filters)

    segmentation_map = Conv2D(num_classes, kernel_size=(1, 1), padding='same')(segmentation_map)
    segmentation_map = Softmax()(segmentation_map)

    model = Model(inputs, segmentation_map)
    return model

# %%
import tensorflow as tf

input_shape = (SIZE_X, SIZE_Y, n_channels)
model = build_model(input_shape, n_classes)

dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.CategoricalFocalLoss()
hybrid_loss = dice_loss + (1 * focal_loss)

optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)

model.compile(optimizer=optimizer, loss=hybrid_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_853 (Conv2D)            (None, 128, 128, 32  128         ['input_18[0][0]']
#                                 )
#
#  conv2d_854 (Conv2D)            (None, 128, 128, 32  9248        ['conv2d_853[0][0]']
#                                 )
#
#  conv2d_851 (Conv2D)            (None, 128, 128, 32  128         ['input_18[0][0]']
#                                 )
#
#  batch_normalization_414 (Batch  (None, 128, 128, 32  128        ['conv2d_854[0][0]']
#  Normalization)                 )
#
#  conv2d_850 (Conv2D)            (None, 128, 128, 32  128         ['input_18[0][0]']
#                                 )
#
#  conv2d_852 (Conv2D)            (None, 128, 128, 32  9248        ['conv2d_851[0][0]']
#                                 )
#
#  conv2d_855 (Conv2D)            (None, 128, 128, 32  9248        ['batch_normalization_414[0][0]']
#                                 )
#
#  batch_normalization_412 (Batch  (None, 128, 128, 32  128        ['conv2d_850[0][0]']
#  Normalization)                 )
#
#  batch_normalization_413 (Batch  (None, 128, 128, 32  128        ['conv2d_852[0][0]']
#  Normalization)                 )
#
#  batch_normalization_415 (Batch  (None, 128, 128, 32  128        ['conv2d_855[0][0]']
#  Normalization)                 )
#
#  concatenate_150 (Concatenate)  (None, 128, 128, 96  0           ['batch_normalization_412[0][0]',
#                                 )                                 'batch_normalization_413[0][0]',
#                                                                   'batch_normalization_415[0][0]']
#
#  conv2d_856 (Conv2D)            (None, 128, 128, 32  3104        ['concatenate_150[0][0]']
#                                 )
#
#  activation_106 (Activation)    (None, 128, 128, 32  0           ['conv2d_856[0][0]']
#                                 )
#
#  max_pooling2d_121 (MaxPooling2  (None, 64, 64, 32)  0           ['activation_106[0][0]']
#  D)
#
#  conv2d_860 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_121[0][0]']
#
#  conv2d_861 (Conv2D)            (None, 64, 64, 64)   36928       ['conv2d_860[0][0]']
#
#  conv2d_858 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_121[0][0]']
#
#  batch_normalization_418 (Batch  (None, 64, 64, 64)  256         ['conv2d_861[0][0]']
#  Normalization)
#
#  conv2d_857 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_121[0][0]']
#
#  conv2d_859 (Conv2D)            (None, 64, 64, 64)   36928       ['conv2d_858[0][0]']
#
#  conv2d_862 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_418[0][0]']
#
#  batch_normalization_416 (Batch  (None, 64, 64, 64)  256         ['conv2d_857[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 64, 64, 64)  256         ['conv2d_859[0][0]']
#  Normalization)
#
#  batch_normalization_419 (Batch  (None, 64, 64, 64)  256         ['conv2d_862[0][0]']
#  Normalization)
#
#  concatenate_151 (Concatenate)  (None, 64, 64, 192)  0           ['batch_normalization_416[0][0]',
#                                                                   'batch_normalization_417[0][0]',
#                                                                   'batch_normalization_419[0][0]']
#
#  conv2d_863 (Conv2D)            (None, 64, 64, 64)   12352       ['concatenate_151[0][0]']
#
#  activation_107 (Activation)    (None, 64, 64, 64)   0           ['conv2d_863[0][0]']
#
#  max_pooling2d_122 (MaxPooling2  (None, 32, 32, 64)  0           ['activation_107[0][0]']
#  D)
#
#  conv2d_867 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_122[0][0]']
#
#  conv2d_868 (Conv2D)            (None, 32, 32, 128)  147584      ['conv2d_867[0][0]']
#
#  conv2d_865 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_122[0][0]']
#
#  batch_normalization_422 (Batch  (None, 32, 32, 128)  512        ['conv2d_868[0][0]']
#  Normalization)
#
#  conv2d_864 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_122[0][0]']
#
#  conv2d_866 (Conv2D)            (None, 32, 32, 128)  147584      ['conv2d_865[0][0]']
#
#  conv2d_869 (Conv2D)            (None, 32, 32, 128)  147584      ['batch_normalization_422[0][0]']
#
#  batch_normalization_420 (Batch  (None, 32, 32, 128)  512        ['conv2d_864[0][0]']
#  Normalization)
#
#  batch_normalization_421 (Batch  (None, 32, 32, 128)  512        ['conv2d_866[0][0]']
#  Normalization)
#
#  batch_normalization_423 (Batch  (None, 32, 32, 128)  512        ['conv2d_869[0][0]']
#  Normalization)
#
#  concatenate_152 (Concatenate)  (None, 32, 32, 384)  0           ['batch_normalization_420[0][0]',
#                                                                   'batch_normalization_421[0][0]',
#                                                                   'batch_normalization_423[0][0]']
#
#  conv2d_870 (Conv2D)            (None, 32, 32, 128)  49280       ['concatenate_152[0][0]']
#
#  activation_108 (Activation)    (None, 32, 32, 128)  0           ['conv2d_870[0][0]']
#
#  max_pooling2d_123 (MaxPooling2  (None, 16, 16, 128)  0          ['activation_108[0][0]']
#  D)
#
#  conv2d_874 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_123[0][0]']
#
#  conv2d_875 (Conv2D)            (None, 16, 16, 256)  590080      ['conv2d_874[0][0]']
#
#  conv2d_872 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_123[0][0]']
#
#  batch_normalization_426 (Batch  (None, 16, 16, 256)  1024       ['conv2d_875[0][0]']
#  Normalization)
#
#  conv2d_871 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_123[0][0]']
#
#  conv2d_873 (Conv2D)            (None, 16, 16, 256)  590080      ['conv2d_872[0][0]']
#
#  conv2d_876 (Conv2D)            (None, 16, 16, 256)  590080      ['batch_normalization_426[0][0]']
#
#  batch_normalization_424 (Batch  (None, 16, 16, 256)  1024       ['conv2d_871[0][0]']
#  Normalization)
#
#  batch_normalization_425 (Batch  (None, 16, 16, 256)  1024       ['conv2d_873[0][0]']
#  Normalization)
#
#  batch_normalization_427 (Batch  (None, 16, 16, 256)  1024       ['conv2d_876[0][0]']
#  Normalization)
#
#  concatenate_153 (Concatenate)  (None, 16, 16, 768)  0           ['batch_normalization_424[0][0]',
#                                                                   'batch_normalization_425[0][0]',
#                                                                   'batch_normalization_427[0][0]']
#
#  conv2d_877 (Conv2D)            (None, 16, 16, 256)  196864      ['concatenate_153[0][0]']
#
#  activation_109 (Activation)    (None, 16, 16, 256)  0           ['conv2d_877[0][0]']
#
#  max_pooling2d_124 (MaxPooling2  (None, 8, 8, 256)   0           ['activation_109[0][0]']
#  D)
#
#  conv2d_881 (Conv2D)            (None, 8, 8, 512)    131584      ['max_pooling2d_124[0][0]']
#
#  conv2d_882 (Conv2D)            (None, 8, 8, 512)    2359808     ['conv2d_881[0][0]']
#
#  conv2d_879 (Conv2D)            (None, 8, 8, 512)    131584      ['max_pooling2d_124[0][0]']
#
#  batch_normalization_430 (Batch  (None, 8, 8, 512)   2048        ['conv2d_882[0][0]']
#  Normalization)
#
#  conv2d_878 (Conv2D)            (None, 8, 8, 512)    131584      ['max_pooling2d_124[0][0]']
#
#  conv2d_880 (Conv2D)            (None, 8, 8, 512)    2359808     ['conv2d_879[0][0]']
#
#  conv2d_883 (Conv2D)            (None, 8, 8, 512)    2359808     ['batch_normalization_430[0][0]']
#
#  batch_normalization_428 (Batch  (None, 8, 8, 512)   2048        ['conv2d_878[0][0]']
#  Normalization)
#
#  batch_normalization_429 (Batch  (None, 8, 8, 512)   2048        ['conv2d_880[0][0]']
#  Normalization)
#
#  batch_normalization_431 (Batch  (None, 8, 8, 512)   2048        ['conv2d_883[0][0]']
#  Normalization)
#
#  concatenate_154 (Concatenate)  (None, 8, 8, 1536)   0           ['batch_normalization_428[0][0]',
#                                                                   'batch_normalization_429[0][0]',
#                                                                   'batch_normalization_431[0][0]']
#
#  conv2d_884 (Conv2D)            (None, 8, 8, 512)    786944      ['concatenate_154[0][0]']
#
#  activation_110 (Activation)    (None, 8, 8, 512)    0           ['conv2d_884[0][0]']
#
#  max_pooling2d_125 (MaxPooling2  (None, 8, 8, 512)   0           ['activation_110[0][0]']
#  D)
#
#  max_pooling2d_126 (MaxPooling2  (None, 4, 4, 512)   0           ['activation_110[0][0]']
#  D)
#
#  max_pooling2d_127 (MaxPooling2  (None, 2, 2, 512)   0           ['activation_110[0][0]']
#  D)
#
#  max_pooling2d_128 (MaxPooling2  (None, 1, 1, 512)   0           ['activation_110[0][0]']
#  D)
#
#  conv2d_885 (Conv2D)            (None, 8, 8, 512)    262656      ['max_pooling2d_125[0][0]']
#
#  conv2d_886 (Conv2D)            (None, 4, 4, 512)    262656      ['max_pooling2d_126[0][0]']
#
#  conv2d_887 (Conv2D)            (None, 2, 2, 512)    262656      ['max_pooling2d_127[0][0]']
#
#  conv2d_888 (Conv2D)            (None, 1, 1, 512)    262656      ['max_pooling2d_128[0][0]']
#
#  up_sampling2d_72 (UpSampling2D  (None, 8, 8, 512)   0           ['conv2d_885[0][0]']
#  )
#
#  up_sampling2d_73 (UpSampling2D  (None, 8, 8, 512)   0           ['conv2d_886[0][0]']
#  )
#
#  up_sampling2d_74 (UpSampling2D  (None, 8, 8, 512)   0           ['conv2d_887[0][0]']
#  )
#
#  up_sampling2d_75 (UpSampling2D  (None, 8, 8, 512)   0           ['conv2d_888[0][0]']
#  )
#
#  concatenate_155 (Concatenate)  (None, 8, 8, 2560)   0           ['activation_110[0][0]',
#                                                                   'up_sampling2d_72[0][0]',
#                                                                   'up_sampling2d_73[0][0]',
#                                                                   'up_sampling2d_74[0][0]',
#                                                                   'up_sampling2d_75[0][0]']
#
#  conv2d_transpose_33 (Conv2DTra  (None, 16, 16, 512)  11796992   ['concatenate_155[0][0]']
#  nspose)
#
#  conv2d_890 (Conv2D)            (None, 8, 8, 512)    131584      ['max_pooling2d_124[0][0]']
#
#  conv2d_889 (Conv2D)            (None, 16, 16, 512)  2359808     ['conv2d_transpose_33[0][0]']
#
#  up_sampling2d_76 (UpSampling2D  (None, 16, 16, 512)  0          ['conv2d_890[0][0]']
#  )
#
#  concatenate_156 (Concatenate)  (None, 16, 16, 1024  0           ['conv2d_889[0][0]',
#                                 )                                 'up_sampling2d_76[0][0]']
#
#  conv2d_894 (Conv2D)            (None, 16, 16, 512)  524800      ['concatenate_156[0][0]']
#
#  conv2d_895 (Conv2D)            (None, 16, 16, 512)  2359808     ['conv2d_894[0][0]']
#
#  conv2d_892 (Conv2D)            (None, 16, 16, 512)  524800      ['concatenate_156[0][0]']
#
#  batch_normalization_434 (Batch  (None, 16, 16, 512)  2048       ['conv2d_895[0][0]']
#  Normalization)
#
#  conv2d_891 (Conv2D)            (None, 16, 16, 512)  524800      ['concatenate_156[0][0]']
#
#  conv2d_893 (Conv2D)            (None, 16, 16, 512)  2359808     ['conv2d_892[0][0]']
#
#  conv2d_896 (Conv2D)            (None, 16, 16, 512)  2359808     ['batch_normalization_434[0][0]']
#
#  batch_normalization_432 (Batch  (None, 16, 16, 512)  2048       ['conv2d_891[0][0]']
#  Normalization)
#
#  batch_normalization_433 (Batch  (None, 16, 16, 512)  2048       ['conv2d_893[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 16, 16, 512)  2048       ['conv2d_896[0][0]']
#  Normalization)
#
#  concatenate_157 (Concatenate)  (None, 16, 16, 1536  0           ['batch_normalization_432[0][0]',
#                                 )                                 'batch_normalization_433[0][0]',
#                                                                   'batch_normalization_435[0][0]']
#
#  conv2d_897 (Conv2D)            (None, 16, 16, 512)  786944      ['concatenate_157[0][0]']
#
#  activation_111 (Activation)    (None, 16, 16, 512)  0           ['conv2d_897[0][0]']
#
#  conv2d_transpose_34 (Conv2DTra  (None, 32, 32, 256)  1179904    ['activation_111[0][0]']
#  nspose)
#
#  conv2d_899 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_123[0][0]']
#
#  conv2d_898 (Conv2D)            (None, 32, 32, 256)  590080      ['conv2d_transpose_34[0][0]']
#
#  up_sampling2d_77 (UpSampling2D  (None, 32, 32, 256)  0          ['conv2d_899[0][0]']
#  )
#
#  concatenate_158 (Concatenate)  (None, 32, 32, 512)  0           ['conv2d_898[0][0]',
#                                                                   'up_sampling2d_77[0][0]']
#
#  conv2d_903 (Conv2D)            (None, 32, 32, 256)  131328      ['concatenate_158[0][0]']
#
#  conv2d_904 (Conv2D)            (None, 32, 32, 256)  590080      ['conv2d_903[0][0]']
#
#  conv2d_901 (Conv2D)            (None, 32, 32, 256)  131328      ['concatenate_158[0][0]']
#
#  batch_normalization_438 (Batch  (None, 32, 32, 256)  1024       ['conv2d_904[0][0]']
#  Normalization)
#
#  conv2d_900 (Conv2D)            (None, 32, 32, 256)  131328      ['concatenate_158[0][0]']
#
#  conv2d_902 (Conv2D)            (None, 32, 32, 256)  590080      ['conv2d_901[0][0]']
#
#  conv2d_905 (Conv2D)            (None, 32, 32, 256)  590080      ['batch_normalization_438[0][0]']
#
#  batch_normalization_436 (Batch  (None, 32, 32, 256)  1024       ['conv2d_900[0][0]']
#  Normalization)
#
#  batch_normalization_437 (Batch  (None, 32, 32, 256)  1024       ['conv2d_902[0][0]']
#  Normalization)
#
#  batch_normalization_439 (Batch  (None, 32, 32, 256)  1024       ['conv2d_905[0][0]']
#  Normalization)
#
#  concatenate_159 (Concatenate)  (None, 32, 32, 768)  0           ['batch_normalization_436[0][0]',
#                                                                   'batch_normalization_437[0][0]',
#                                                                   'batch_normalization_439[0][0]']
#
#  conv2d_906 (Conv2D)            (None, 32, 32, 256)  196864      ['concatenate_159[0][0]']
#
#  activation_112 (Activation)    (None, 32, 32, 256)  0           ['conv2d_906[0][0]']
#
#  conv2d_transpose_35 (Conv2DTra  (None, 64, 64, 128)  295040     ['activation_112[0][0]']
#  nspose)
#
#  conv2d_908 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_122[0][0]']
#
#  conv2d_907 (Conv2D)            (None, 64, 64, 128)  147584      ['conv2d_transpose_35[0][0]']
#
#  up_sampling2d_78 (UpSampling2D  (None, 64, 64, 128)  0          ['conv2d_908[0][0]']
#  )
#
#  concatenate_160 (Concatenate)  (None, 64, 64, 256)  0           ['conv2d_907[0][0]',
#                                                                   'up_sampling2d_78[0][0]']
#
#  conv2d_912 (Conv2D)            (None, 64, 64, 128)  32896       ['concatenate_160[0][0]']
#
#  conv2d_913 (Conv2D)            (None, 64, 64, 128)  147584      ['conv2d_912[0][0]']
#
#  conv2d_910 (Conv2D)            (None, 64, 64, 128)  32896       ['concatenate_160[0][0]']
#
#  batch_normalization_442 (Batch  (None, 64, 64, 128)  512        ['conv2d_913[0][0]']
#  Normalization)
#
#  conv2d_909 (Conv2D)            (None, 64, 64, 128)  32896       ['concatenate_160[0][0]']
#
#  conv2d_911 (Conv2D)            (None, 64, 64, 128)  147584      ['conv2d_910[0][0]']
#
#  conv2d_914 (Conv2D)            (None, 64, 64, 128)  147584      ['batch_normalization_442[0][0]']
#
#  batch_normalization_440 (Batch  (None, 64, 64, 128)  512        ['conv2d_909[0][0]']
#  Normalization)
#
#  batch_normalization_441 (Batch  (None, 64, 64, 128)  512        ['conv2d_911[0][0]']
#  Normalization)
#
#  batch_normalization_443 (Batch  (None, 64, 64, 128)  512        ['conv2d_914[0][0]']
#  Normalization)
#
#  concatenate_161 (Concatenate)  (None, 64, 64, 384)  0           ['batch_normalization_440[0][0]',
#                                                                   'batch_normalization_441[0][0]',
#                                                                   'batch_normalization_443[0][0]']
#
#  conv2d_915 (Conv2D)            (None, 64, 64, 128)  49280       ['concatenate_161[0][0]']
#
#  activation_113 (Activation)    (None, 64, 64, 128)  0           ['conv2d_915[0][0]']
#
#  conv2d_transpose_36 (Conv2DTra  (None, 128, 128, 64  73792      ['activation_113[0][0]']
#  nspose)                        )
#
#  conv2d_917 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_121[0][0]']
#
#  conv2d_916 (Conv2D)            (None, 128, 128, 64  36928       ['conv2d_transpose_36[0][0]']
#                                 )
#
#  up_sampling2d_79 (UpSampling2D  (None, 128, 128, 64  0          ['conv2d_917[0][0]']
#  )                              )
#
#  concatenate_162 (Concatenate)  (None, 128, 128, 12  0           ['conv2d_916[0][0]',
#                                 8)                                'up_sampling2d_79[0][0]']
#
#  conv2d_921 (Conv2D)            (None, 128, 128, 64  8256        ['concatenate_162[0][0]']
#                                 )
#
#  conv2d_922 (Conv2D)            (None, 128, 128, 64  36928       ['conv2d_921[0][0]']
#                                 )
#
#  conv2d_919 (Conv2D)            (None, 128, 128, 64  8256        ['concatenate_162[0][0]']
#                                 )
#
#  batch_normalization_446 (Batch  (None, 128, 128, 64  256        ['conv2d_922[0][0]']
#  Normalization)                 )
#
#  conv2d_918 (Conv2D)            (None, 128, 128, 64  8256        ['concatenate_162[0][0]']
#                                 )
#
#  conv2d_920 (Conv2D)            (None, 128, 128, 64  36928       ['conv2d_919[0][0]']
#                                 )
#
#  conv2d_923 (Conv2D)            (None, 128, 128, 64  36928       ['batch_normalization_446[0][0]']
#                                 )
#
#  batch_normalization_444 (Batch  (None, 128, 128, 64  256        ['conv2d_918[0][0]']
#  Normalization)                 )
#
#  batch_normalization_445 (Batch  (None, 128, 128, 64  256        ['conv2d_920[0][0]']
#  Normalization)                 )
#
#  batch_normalization_447 (Batch  (None, 128, 128, 64  256        ['conv2d_923[0][0]']
#  Normalization)                 )
#
#  concatenate_163 (Concatenate)  (None, 128, 128, 19  0           ['batch_normalization_444[0][0]',
#                                 2)                                'batch_normalization_445[0][0]',
#                                                                   'batch_normalization_447[0][0]']
#
#  conv2d_924 (Conv2D)            (None, 128, 128, 64  12352       ['concatenate_163[0][0]']
#                                 )
#
#  activation_114 (Activation)    (None, 128, 128, 64  0           ['conv2d_924[0][0]']
#                                 )
#
#  conv2d_925 (Conv2D)            (None, 128, 128, 10  650         ['activation_114[0][0]']
#                                 )
#
#  softmax_6 (Softmax)            (None, 128, 128, 10  0           ['conv2d_925[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 41,283,146
# Trainable params: 41,267,530
# Non-trainable params: 15,616
# __________________________________________________________________________________________________

# %%
model.input_shape, model.output_shape
# Out:
# ((None, 128, 128, 3), (None, 128, 128, 10))

# %%
len(model.layers)
# Out:
# 157

# %%
layers = [type(layer) for layer in model.layers]

from collections import Counter
item_occurrence = Counter(layers)
for item, occurrence in item_occurrence.items():
    print(f"{item}: {occurrence}")
# Out:
# <class 'keras.engine.input_layer.InputLayer'>: 1
# <class 'keras.layers.convolutional.conv2d.Conv2D'>: 76
# <class 'keras.layers.normalization.batch_normalization.BatchNormalization'>: 36
# <class 'keras.layers.merging.concatenate.Concatenate'>: 14
# <class 'keras.layers.core.activation.Activation'>: 9
# <class 'keras.layers.pooling.max_pooling2d.MaxPooling2D'>: 8
# <class 'keras.layers.reshaping.up_sampling2d.UpSampling2D'>: 8
# <class 'keras.layers.convolutional.conv2d_transpose.Conv2DTranspose'>: 4
# <class 'keras.layers.activation.softmax.Softmax'>: 1

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 44s 190ms/step - loss: 0.9372 - iou_score: 0.0632 - val_loss: 0.9850 - val_iou_score: 0.0353
# Epoch 2/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.8649 - iou_score: 0.1046 - val_loss: 1.0301 - val_iou_score: 0.0260
# Epoch 3/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.8257 - iou_score: 0.1345 - val_loss: 0.9511 - val_iou_score: 0.0672
# Epoch 4/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.8037 - iou_score: 0.1525 - val_loss: 0.8461 - val_iou_score: 0.1298
# Epoch 5/100
# 181/181 [==============================] - 30s 165ms/step - loss: 0.7877 - iou_score: 0.1650 - val_loss: 0.8158 - val_iou_score: 0.1517
# Epoch 6/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.7739 - iou_score: 0.1757 - val_loss: 0.8079 - val_iou_score: 0.1594
# Epoch 7/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.7566 - iou_score: 0.1886 - val_loss: 0.7982 - val_iou_score: 0.1679
# Epoch 8/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.7329 - iou_score: 0.2063 - val_loss: 0.7842 - val_iou_score: 0.1793
# Epoch 9/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.7176 - iou_score: 0.2189 - val_loss: 0.7696 - val_iou_score: 0.1934
# Epoch 10/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.7010 - iou_score: 0.2328 - val_loss: 0.7843 - val_iou_score: 0.1823
# Epoch 11/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.6898 - iou_score: 0.2418 - val_loss: 0.7763 - val_iou_score: 0.1873
# Epoch 12/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.6769 - iou_score: 0.2519 - val_loss: 0.7577 - val_iou_score: 0.2050
# Epoch 13/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.6659 - iou_score: 0.2614 - val_loss: 0.7403 - val_iou_score: 0.2207
# Epoch 14/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.6491 - iou_score: 0.2757 - val_loss: 0.7385 - val_iou_score: 0.2201
# Epoch 15/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.6400 - iou_score: 0.2843 - val_loss: 0.7401 - val_iou_score: 0.2193
# Epoch 16/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.6296 - iou_score: 0.2927 - val_loss: 0.7341 - val_iou_score: 0.2251
# Epoch 17/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.6205 - iou_score: 0.3005 - val_loss: 0.7310 - val_iou_score: 0.2263
# Epoch 18/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.6152 - iou_score: 0.3057 - val_loss: 0.7641 - val_iou_score: 0.1957
# Epoch 19/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.6048 - iou_score: 0.3151 - val_loss: 0.7392 - val_iou_score: 0.2180
# Epoch 20/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5944 - iou_score: 0.3233 - val_loss: 0.7052 - val_iou_score: 0.2490
# Epoch 21/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5830 - iou_score: 0.3339 - val_loss: 0.7270 - val_iou_score: 0.2303
# Epoch 22/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5740 - iou_score: 0.3421 - val_loss: 0.7659 - val_iou_score: 0.2021
# Epoch 23/100
# 181/181 [==============================] - 30s 169ms/step - loss: 0.5621 - iou_score: 0.3516 - val_loss: 0.7026 - val_iou_score: 0.2518
# Epoch 24/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5550 - iou_score: 0.3591 - val_loss: 0.7667 - val_iou_score: 0.2080
# Epoch 25/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5486 - iou_score: 0.3664 - val_loss: 0.7820 - val_iou_score: 0.1864
# Epoch 26/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5335 - iou_score: 0.3790 - val_loss: 0.7694 - val_iou_score: 0.1992
# Epoch 27/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5314 - iou_score: 0.3815 - val_loss: 0.6955 - val_iou_score: 0.2555
# Epoch 28/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5193 - iou_score: 0.3926 - val_loss: 0.6942 - val_iou_score: 0.2607
# Epoch 29/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5063 - iou_score: 0.4044 - val_loss: 0.7083 - val_iou_score: 0.2463
# Epoch 30/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.5017 - iou_score: 0.4094 - val_loss: 0.7712 - val_iou_score: 0.2038
# Epoch 31/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.4937 - iou_score: 0.4171 - val_loss: 0.6829 - val_iou_score: 0.2702
# Epoch 32/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.4959 - iou_score: 0.4154 - val_loss: 0.7342 - val_iou_score: 0.2269
# Epoch 33/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.4888 - iou_score: 0.4229 - val_loss: 0.6891 - val_iou_score: 0.2651
# Epoch 34/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.4832 - iou_score: 0.4280 - val_loss: 0.6788 - val_iou_score: 0.2703
# Epoch 35/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.4791 - iou_score: 0.4326 - val_loss: 0.7385 - val_iou_score: 0.2240
# Epoch 36/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.4707 - iou_score: 0.4394 - val_loss: 0.6799 - val_iou_score: 0.2689
# Epoch 37/100
# 181/181 [==============================] - 30s 169ms/step - loss: 0.4675 - iou_score: 0.4444 - val_loss: 0.8281 - val_iou_score: 0.1619
# Epoch 38/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.4691 - iou_score: 0.4428 - val_loss: 0.6689 - val_iou_score: 0.2806
# Epoch 39/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.4567 - iou_score: 0.4547 - val_loss: 0.6832 - val_iou_score: 0.2634
# Epoch 40/100
# 181/181 [==============================] - 30s 169ms/step - loss: 0.4469 - iou_score: 0.4638 - val_loss: 0.6735 - val_iou_score: 0.2771
# Epoch 41/100
# 181/181 [==============================] - 30s 169ms/step - loss: 0.4473 - iou_score: 0.4654 - val_loss: 0.6721 - val_iou_score: 0.2792
# Epoch 42/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.4529 - iou_score: 0.4599 - val_loss: 0.6988 - val_iou_score: 0.2557
# Epoch 43/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.4435 - iou_score: 0.4681 - val_loss: 0.6696 - val_iou_score: 0.2789
# Epoch 44/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.4406 - iou_score: 0.4726 - val_loss: 0.6735 - val_iou_score: 0.2773
# Epoch 45/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.4364 - iou_score: 0.4764 - val_loss: 0.6726 - val_iou_score: 0.2785
# Epoch 46/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.4225 - iou_score: 0.4902 - val_loss: 0.6613 - val_iou_score: 0.2853
# Epoch 47/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.4258 - iou_score: 0.4874 - val_loss: 0.6517 - val_iou_score: 0.2952
# Epoch 48/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.4254 - iou_score: 0.4880 - val_loss: 0.6688 - val_iou_score: 0.2773
# Epoch 49/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.4303 - iou_score: 0.4842 - val_loss: 0.6661 - val_iou_score: 0.2829
# Epoch 50/100
# 181/181 [==============================] - 30s 169ms/step - loss: 0.4157 - iou_score: 0.4986 - val_loss: 0.6585 - val_iou_score: 0.2923
# Epoch 51/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.4109 - iou_score: 0.5027 - val_loss: 0.6577 - val_iou_score: 0.2885
# Epoch 52/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.4048 - iou_score: 0.5098 - val_loss: 0.6372 - val_iou_score: 0.3114
# Epoch 53/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.3971 - iou_score: 0.5166 - val_loss: 0.6829 - val_iou_score: 0.2701
# Epoch 54/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.4020 - iou_score: 0.5131 - val_loss: 0.6991 - val_iou_score: 0.2513
# Epoch 55/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.4067 - iou_score: 0.5086 - val_loss: 0.6493 - val_iou_score: 0.2967
# Epoch 56/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3883 - iou_score: 0.5267 - val_loss: 0.6986 - val_iou_score: 0.2585
# Epoch 57/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3980 - iou_score: 0.5187 - val_loss: 0.6686 - val_iou_score: 0.2831
# Epoch 58/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.3902 - iou_score: 0.5263 - val_loss: 0.6478 - val_iou_score: 0.3025
# Epoch 59/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.3943 - iou_score: 0.5229 - val_loss: 0.6436 - val_iou_score: 0.3060
# Epoch 60/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.3899 - iou_score: 0.5264 - val_loss: 0.6709 - val_iou_score: 0.2781
# Epoch 61/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.3757 - iou_score: 0.5400 - val_loss: 0.6683 - val_iou_score: 0.2810
# Epoch 62/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.3821 - iou_score: 0.5356 - val_loss: 0.6446 - val_iou_score: 0.3055
# Epoch 63/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.3882 - iou_score: 0.5298 - val_loss: 0.6441 - val_iou_score: 0.3041
# Epoch 64/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3765 - iou_score: 0.5406 - val_loss: 0.6484 - val_iou_score: 0.2966
# Epoch 65/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3838 - iou_score: 0.5347 - val_loss: 0.6604 - val_iou_score: 0.2907
# Epoch 66/100
# 181/181 [==============================] - 30s 165ms/step - loss: 0.3765 - iou_score: 0.5421 - val_loss: 0.6387 - val_iou_score: 0.3117
# Epoch 67/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3671 - iou_score: 0.5491 - val_loss: 0.7270 - val_iou_score: 0.2493
# Epoch 68/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3668 - iou_score: 0.5526 - val_loss: 0.6456 - val_iou_score: 0.3057
# Epoch 69/100
# 181/181 [==============================] - 31s 169ms/step - loss: 0.3713 - iou_score: 0.5469 - val_loss: 0.6512 - val_iou_score: 0.3008
# Epoch 70/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3676 - iou_score: 0.5521 - val_loss: 0.6345 - val_iou_score: 0.3126
# Epoch 71/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3719 - iou_score: 0.5487 - val_loss: 0.6292 - val_iou_score: 0.3189
# Epoch 72/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3646 - iou_score: 0.5550 - val_loss: 0.6492 - val_iou_score: 0.2981
# Epoch 73/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3592 - iou_score: 0.5601 - val_loss: 0.6465 - val_iou_score: 0.3055
# Epoch 74/100
# 181/181 [==============================] - 30s 168ms/step - loss: 0.3638 - iou_score: 0.5568 - val_loss: 0.6582 - val_iou_score: 0.2942
# Epoch 75/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3585 - iou_score: 0.5618 - val_loss: 0.6768 - val_iou_score: 0.2811
# Epoch 76/100
# 181/181 [==============================] - 30s 165ms/step - loss: 0.3512 - iou_score: 0.5693 - val_loss: 0.6245 - val_iou_score: 0.3228
# Epoch 77/100
# 181/181 [==============================] - 30s 165ms/step - loss: 0.3564 - iou_score: 0.5641 - val_loss: 0.6414 - val_iou_score: 0.3077
# Epoch 78/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3502 - iou_score: 0.5717 - val_loss: 0.6641 - val_iou_score: 0.2890
# Epoch 79/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3477 - iou_score: 0.5722 - val_loss: 0.6456 - val_iou_score: 0.3072
# Epoch 80/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3624 - iou_score: 0.5595 - val_loss: 0.6247 - val_iou_score: 0.3215
# Epoch 81/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3477 - iou_score: 0.5740 - val_loss: 0.6254 - val_iou_score: 0.3232
# Epoch 82/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3551 - iou_score: 0.5696 - val_loss: 0.6432 - val_iou_score: 0.3050
# Epoch 83/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3490 - iou_score: 0.5731 - val_loss: 0.6342 - val_iou_score: 0.3135
# Epoch 84/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3489 - iou_score: 0.5752 - val_loss: 0.6232 - val_iou_score: 0.3268
# Epoch 85/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3468 - iou_score: 0.5769 - val_loss: 0.6383 - val_iou_score: 0.3132
# Epoch 86/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3431 - iou_score: 0.5799 - val_loss: 0.6400 - val_iou_score: 0.3083
# Epoch 87/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3596 - iou_score: 0.5659 - val_loss: 0.6751 - val_iou_score: 0.2835
# Epoch 88/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3480 - iou_score: 0.5747 - val_loss: 0.6341 - val_iou_score: 0.3164
# Epoch 89/100
# 181/181 [==============================] - 30s 165ms/step - loss: 0.3340 - iou_score: 0.5893 - val_loss: 0.6383 - val_iou_score: 0.3122
# Epoch 90/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3361 - iou_score: 0.5873 - val_loss: 0.6599 - val_iou_score: 0.2957
# Epoch 91/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3446 - iou_score: 0.5809 - val_loss: 0.6368 - val_iou_score: 0.3116
# Epoch 92/100
# 181/181 [==============================] - 30s 165ms/step - loss: 0.3318 - iou_score: 0.5920 - val_loss: 0.6293 - val_iou_score: 0.3219
# Epoch 93/100
# 181/181 [==============================] - 30s 165ms/step - loss: 0.3413 - iou_score: 0.5838 - val_loss: 0.6231 - val_iou_score: 0.3278
# Epoch 94/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3370 - iou_score: 0.5878 - val_loss: 0.6209 - val_iou_score: 0.3274
# Epoch 95/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3370 - iou_score: 0.5882 - val_loss: 0.6498 - val_iou_score: 0.2993
# Epoch 96/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3407 - iou_score: 0.5841 - val_loss: 0.7145 - val_iou_score: 0.2487
# Epoch 97/100
# 181/181 [==============================] - 30s 167ms/step - loss: 0.3318 - iou_score: 0.5925 - val_loss: 0.6553 - val_iou_score: 0.2963
# Epoch 98/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3305 - iou_score: 0.5937 - val_loss: 0.6461 - val_iou_score: 0.3066
# Epoch 99/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3259 - iou_score: 0.6010 - val_loss: 0.6305 - val_iou_score: 0.3207
# Epoch 100/100
# 181/181 [==============================] - 30s 166ms/step - loss: 0.3289 - iou_score: 0.5964 - val_loss: 0.6234 - val_iou_score: 0.3248

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '..../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  37.42790222167969 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 3s 153ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.5216276
# IoU for each class:
# Building Flooded: 0.6016571521759033
# Building Non-Flooded: 0.618789792060852
# Road Flooded: 0.4477539360523224
# Road Non-Flooded: 0.7030544877052307
# Water: 0.6544091105461121
# Tree: 0.6406502723693848
# Vehicle: 0.20538011193275452
# Pool: 0.30668818950653076
# Grass: 0.7792553305625916
# Mean IoU (excluding Background): 0.5508487

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
