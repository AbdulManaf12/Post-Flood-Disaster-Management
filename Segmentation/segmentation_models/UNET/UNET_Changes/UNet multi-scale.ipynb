# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'efficientnetb7'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate, BatchNormalization, UpSampling2D, Activation, Conv2DTranspose
from tensorflow.keras.models import Model

def res_inception_unit(input_layer, filters):
    # First convolutional block
    conv1x1_1 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv1x1_1 = BatchNormalization()(conv1x1_1)
    conv1x1_1 = Activation('relu')(conv1x1_1)

    # Second convolutional block
    conv1x1_2 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv1x1_2 = BatchNormalization()(conv1x1_2)
    conv1x1_2 = Activation('relu')(conv1x1_2)
    conv3x3_2 = Conv2D(filters, (3, 3), padding='same')(conv1x1_2)
    conv3x3_2 = BatchNormalization()(conv3x3_2)
    conv3x3_2 = Activation('relu')(conv3x3_2)

    # Third convolutional block
    conv1x1_3 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv1x1_3 = BatchNormalization()(conv1x1_3)
    conv1x1_3 = Activation('relu')(conv1x1_3)
    conv3x3_3 = Conv2D(filters, (3, 3), padding='same')(conv1x1_3)
    conv3x3_3 = BatchNormalization()(conv3x3_3)
    conv3x3_3 = Activation('relu')(conv3x3_3)
    conv3x3_3 = Conv2D(filters, (3, 3), padding='same')(conv3x3_3)
    conv3x3_3 = BatchNormalization()(conv3x3_3)
    conv3x3_3 = Activation('relu')(conv3x3_3)

    # Concatenate the outputs
    concatenated = concatenate([conv1x1_1, conv3x3_2, conv3x3_3], axis=-1)
    
    # Final convolution to merge outputs
    output = Conv2D(filters, (1, 1), padding='same')(concatenated)
    output = BatchNormalization()(output)
    output = Activation('relu')(output)
    
    return output

def build_model(input_shape, num_classes):
    # Encoder
    inputs = Input(input_shape)
    encoder_filters = [32, 64, 128, 256, 512]
    encoder_outputs = [inputs]
    for i, filters in enumerate(encoder_filters):
        x = res_inception_unit(encoder_outputs[-1], filters)
        encoder_outputs.append(MaxPooling2D(pool_size=(2, 2))(x) if i < len(encoder_filters) - 1 else x)

    # Bridge module
    bridge_filters = 1024
    bridge_output = res_inception_unit(encoder_outputs[-1], bridge_filters)

    # Decoder
    decoder_filters = [512, 256, 128, 64]
    x = bridge_output
    for i, filters in enumerate(decoder_filters):
        x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(x)
        # Adjust spatial dimensions of encoder output to match those of decoder output
        encoder_output = encoder_outputs[-(i + 2)]
        encoder_output = Conv2D(filters, (1, 1), padding='same')(encoder_output)
        if encoder_output.shape[1] != x.shape[1]:
            encoder_output = UpSampling2D(size=(2, 2))(encoder_output)
        if encoder_output.shape[2] != x.shape[2]:
            encoder_output = UpSampling2D(size=(2, 2))(encoder_output)
        x = concatenate([x, encoder_output], axis=-1)
        x = res_inception_unit(x, filters)

    # Output layer
    outputs = Conv2D(num_classes, (1, 1), activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# %%
input_shape = (SIZE_X, SIZE_Y, n_channels)
model = build_model(input_shape, n_classes)
model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_413 (Conv2D)            (None, 128, 128, 32  128         ['input_7[0][0]']
#                                 )
#
#  batch_normalization_388 (Batch  (None, 128, 128, 32  128        ['conv2d_413[0][0]']
#  Normalization)                 )
#
#  activation_388 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_388[0][0]']
#                                 )
#
#  conv2d_411 (Conv2D)            (None, 128, 128, 32  128         ['input_7[0][0]']
#                                 )
#
#  conv2d_414 (Conv2D)            (None, 128, 128, 32  9248        ['activation_388[0][0]']
#                                 )
#
#  batch_normalization_386 (Batch  (None, 128, 128, 32  128        ['conv2d_411[0][0]']
#  Normalization)                 )
#
#  batch_normalization_389 (Batch  (None, 128, 128, 32  128        ['conv2d_414[0][0]']
#  Normalization)                 )
#
#  activation_386 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_386[0][0]']
#                                 )
#
#  activation_389 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_389[0][0]']
#                                 )
#
#  conv2d_410 (Conv2D)            (None, 128, 128, 32  128         ['input_7[0][0]']
#                                 )
#
#  conv2d_412 (Conv2D)            (None, 128, 128, 32  9248        ['activation_386[0][0]']
#                                 )
#
#  conv2d_415 (Conv2D)            (None, 128, 128, 32  9248        ['activation_389[0][0]']
#                                 )
#
#  batch_normalization_385 (Batch  (None, 128, 128, 32  128        ['conv2d_410[0][0]']
#  Normalization)                 )
#
#  batch_normalization_387 (Batch  (None, 128, 128, 32  128        ['conv2d_412[0][0]']
#  Normalization)                 )
#
#  batch_normalization_390 (Batch  (None, 128, 128, 32  128        ['conv2d_415[0][0]']
#  Normalization)                 )
#
#  activation_385 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_385[0][0]']
#                                 )
#
#  activation_387 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_387[0][0]']
#                                 )
#
#  activation_390 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_390[0][0]']
#                                 )
#
#  concatenate_75 (Concatenate)   (None, 128, 128, 96  0           ['activation_385[0][0]',
#                                 )                                 'activation_387[0][0]',
#                                                                   'activation_390[0][0]']
#
#  conv2d_416 (Conv2D)            (None, 128, 128, 32  3104        ['concatenate_75[0][0]']
#                                 )
#
#  batch_normalization_391 (Batch  (None, 128, 128, 32  128        ['conv2d_416[0][0]']
#  Normalization)                 )
#
#  activation_391 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_391[0][0]']
#                                 )
#
#  max_pooling2d_24 (MaxPooling2D  (None, 64, 64, 32)  0           ['activation_391[0][0]']
#  )
#
#  conv2d_420 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_24[0][0]']
#
#  batch_normalization_395 (Batch  (None, 64, 64, 64)  256         ['conv2d_420[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_395[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_24[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 64, 64, 64)   36928       ['activation_395[0][0]']
#
#  batch_normalization_393 (Batch  (None, 64, 64, 64)  256         ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_396 (Batch  (None, 64, 64, 64)  256         ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_393 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_393[0][0]']
#
#  activation_396 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_396[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_24[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 64, 64, 64)   36928       ['activation_393[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 64, 64, 64)   36928       ['activation_396[0][0]']
#
#  batch_normalization_392 (Batch  (None, 64, 64, 64)  256         ['conv2d_417[0][0]']
#  Normalization)
#
#  batch_normalization_394 (Batch  (None, 64, 64, 64)  256         ['conv2d_419[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 64, 64, 64)  256         ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_392 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_392[0][0]']
#
#  activation_394 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_394[0][0]']
#
#  activation_397 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_397[0][0]']
#
#  concatenate_76 (Concatenate)   (None, 64, 64, 192)  0           ['activation_392[0][0]',
#                                                                   'activation_394[0][0]',
#                                                                   'activation_397[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 64, 64, 64)   12352       ['concatenate_76[0][0]']
#
#  batch_normalization_398 (Batch  (None, 64, 64, 64)  256         ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_398[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 32, 32, 64)  0           ['activation_398[0][0]']
#  )
#
#  conv2d_427 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_25[0][0]']
#
#  batch_normalization_402 (Batch  (None, 32, 32, 128)  512        ['conv2d_427[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_402[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_25[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 32, 32, 128)  147584      ['activation_402[0][0]']
#
#  batch_normalization_400 (Batch  (None, 32, 32, 128)  512        ['conv2d_425[0][0]']
#  Normalization)
#
#  batch_normalization_403 (Batch  (None, 32, 32, 128)  512        ['conv2d_428[0][0]']
#  Normalization)
#
#  activation_400 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_400[0][0]']
#
#  activation_403 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_403[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_25[0][0]']
#
#  conv2d_426 (Conv2D)            (None, 32, 32, 128)  147584      ['activation_400[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 32, 32, 128)  147584      ['activation_403[0][0]']
#
#  batch_normalization_399 (Batch  (None, 32, 32, 128)  512        ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 32, 32, 128)  512        ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_404 (Batch  (None, 32, 32, 128)  512        ['conv2d_429[0][0]']
#  Normalization)
#
#  activation_399 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_399[0][0]']
#
#  activation_401 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_401[0][0]']
#
#  activation_404 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_404[0][0]']
#
#  concatenate_77 (Concatenate)   (None, 32, 32, 384)  0           ['activation_399[0][0]',
#                                                                   'activation_401[0][0]',
#                                                                   'activation_404[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 32, 32, 128)  49280       ['concatenate_77[0][0]']
#
#  batch_normalization_405 (Batch  (None, 32, 32, 128)  512        ['conv2d_430[0][0]']
#  Normalization)
#
#  activation_405 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_405[0][0]']
#
#  max_pooling2d_26 (MaxPooling2D  (None, 16, 16, 128)  0          ['activation_405[0][0]']
#  )
#
#  conv2d_434 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_26[0][0]']
#
#  batch_normalization_409 (Batch  (None, 16, 16, 256)  1024       ['conv2d_434[0][0]']
#  Normalization)
#
#  activation_409 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_409[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_26[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 16, 16, 256)  590080      ['activation_409[0][0]']
#
#  batch_normalization_407 (Batch  (None, 16, 16, 256)  1024       ['conv2d_432[0][0]']
#  Normalization)
#
#  batch_normalization_410 (Batch  (None, 16, 16, 256)  1024       ['conv2d_435[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_407[0][0]']
#
#  activation_410 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_410[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_26[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 16, 16, 256)  590080      ['activation_407[0][0]']
#
#  conv2d_436 (Conv2D)            (None, 16, 16, 256)  590080      ['activation_410[0][0]']
#
#  batch_normalization_406 (Batch  (None, 16, 16, 256)  1024       ['conv2d_431[0][0]']
#  Normalization)
#
#  batch_normalization_408 (Batch  (None, 16, 16, 256)  1024       ['conv2d_433[0][0]']
#  Normalization)
#
#  batch_normalization_411 (Batch  (None, 16, 16, 256)  1024       ['conv2d_436[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_406[0][0]']
#
#  activation_408 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_408[0][0]']
#
#  activation_411 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_411[0][0]']
#
#  concatenate_78 (Concatenate)   (None, 16, 16, 768)  0           ['activation_406[0][0]',
#                                                                   'activation_408[0][0]',
#                                                                   'activation_411[0][0]']
#
#  conv2d_437 (Conv2D)            (None, 16, 16, 256)  196864      ['concatenate_78[0][0]']
#
#  batch_normalization_412 (Batch  (None, 16, 16, 256)  1024       ['conv2d_437[0][0]']
#  Normalization)
#
#  activation_412 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_412[0][0]']
#
#  max_pooling2d_27 (MaxPooling2D  (None, 8, 8, 256)   0           ['activation_412[0][0]']
#  )
#
#  conv2d_441 (Conv2D)            (None, 8, 8, 512)    131584      ['max_pooling2d_27[0][0]']
#
#  batch_normalization_416 (Batch  (None, 8, 8, 512)   2048        ['conv2d_441[0][0]']
#  Normalization)
#
#  activation_416 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_416[0][0]']
#
#  conv2d_439 (Conv2D)            (None, 8, 8, 512)    131584      ['max_pooling2d_27[0][0]']
#
#  conv2d_442 (Conv2D)            (None, 8, 8, 512)    2359808     ['activation_416[0][0]']
#
#  batch_normalization_414 (Batch  (None, 8, 8, 512)   2048        ['conv2d_439[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 8, 8, 512)   2048        ['conv2d_442[0][0]']
#  Normalization)
#
#  activation_414 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_414[0][0]']
#
#  activation_417 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_417[0][0]']
#
#  conv2d_438 (Conv2D)            (None, 8, 8, 512)    131584      ['max_pooling2d_27[0][0]']
#
#  conv2d_440 (Conv2D)            (None, 8, 8, 512)    2359808     ['activation_414[0][0]']
#
#  conv2d_443 (Conv2D)            (None, 8, 8, 512)    2359808     ['activation_417[0][0]']
#
#  batch_normalization_413 (Batch  (None, 8, 8, 512)   2048        ['conv2d_438[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 8, 8, 512)   2048        ['conv2d_440[0][0]']
#  Normalization)
#
#  batch_normalization_418 (Batch  (None, 8, 8, 512)   2048        ['conv2d_443[0][0]']
#  Normalization)
#
#  activation_413 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_413[0][0]']
#
#  activation_415 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_415[0][0]']
#
#  activation_418 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_418[0][0]']
#
#  concatenate_79 (Concatenate)   (None, 8, 8, 1536)   0           ['activation_413[0][0]',
#                                                                   'activation_415[0][0]',
#                                                                   'activation_418[0][0]']
#
#  conv2d_444 (Conv2D)            (None, 8, 8, 512)    786944      ['concatenate_79[0][0]']
#
#  batch_normalization_419 (Batch  (None, 8, 8, 512)   2048        ['conv2d_444[0][0]']
#  Normalization)
#
#  activation_419 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_419[0][0]']
#
#  conv2d_448 (Conv2D)            (None, 8, 8, 1024)   525312      ['activation_419[0][0]']
#
#  batch_normalization_423 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_448[0][0]']
#  Normalization)
#
#  activation_423 (Activation)    (None, 8, 8, 1024)   0           ['batch_normalization_423[0][0]']
#
#  conv2d_446 (Conv2D)            (None, 8, 8, 1024)   525312      ['activation_419[0][0]']
#
#  conv2d_449 (Conv2D)            (None, 8, 8, 1024)   9438208     ['activation_423[0][0]']
#
#  batch_normalization_421 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_446[0][0]']
#  Normalization)
#
#  batch_normalization_424 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_449[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 8, 8, 1024)   0           ['batch_normalization_421[0][0]']
#
#  activation_424 (Activation)    (None, 8, 8, 1024)   0           ['batch_normalization_424[0][0]']
#
#  conv2d_445 (Conv2D)            (None, 8, 8, 1024)   525312      ['activation_419[0][0]']
#
#  conv2d_447 (Conv2D)            (None, 8, 8, 1024)   9438208     ['activation_421[0][0]']
#
#  conv2d_450 (Conv2D)            (None, 8, 8, 1024)   9438208     ['activation_424[0][0]']
#
#  batch_normalization_420 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_445[0][0]']
#  Normalization)
#
#  batch_normalization_422 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_447[0][0]']
#  Normalization)
#
#  batch_normalization_425 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_450[0][0]']
#  Normalization)
#
#  activation_420 (Activation)    (None, 8, 8, 1024)   0           ['batch_normalization_420[0][0]']
#
#  activation_422 (Activation)    (None, 8, 8, 1024)   0           ['batch_normalization_422[0][0]']
#
#  activation_425 (Activation)    (None, 8, 8, 1024)   0           ['batch_normalization_425[0][0]']
#
#  concatenate_80 (Concatenate)   (None, 8, 8, 3072)   0           ['activation_420[0][0]',
#                                                                   'activation_422[0][0]',
#                                                                   'activation_425[0][0]']
#
#  conv2d_451 (Conv2D)            (None, 8, 8, 1024)   3146752     ['concatenate_80[0][0]']
#
#  batch_normalization_426 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_451[0][0]']
#  Normalization)
#
#  activation_426 (Activation)    (None, 8, 8, 1024)   0           ['batch_normalization_426[0][0]']
#
#  conv2d_452 (Conv2D)            (None, 8, 8, 512)    131584      ['max_pooling2d_27[0][0]']
#
#  conv2d_transpose_20 (Conv2DTra  (None, 16, 16, 512)  2097664    ['activation_426[0][0]']
#  nspose)
#
#  up_sampling2d_24 (UpSampling2D  (None, 16, 16, 512)  0          ['conv2d_452[0][0]']
#  )
#
#  concatenate_81 (Concatenate)   (None, 16, 16, 1024  0           ['conv2d_transpose_20[0][0]',
#                                 )                                 'up_sampling2d_24[0][0]']
#
#  conv2d_456 (Conv2D)            (None, 16, 16, 512)  524800      ['concatenate_81[0][0]']
#
#  batch_normalization_430 (Batch  (None, 16, 16, 512)  2048       ['conv2d_456[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_430[0][0]']
#
#  conv2d_454 (Conv2D)            (None, 16, 16, 512)  524800      ['concatenate_81[0][0]']
#
#  conv2d_457 (Conv2D)            (None, 16, 16, 512)  2359808     ['activation_430[0][0]']
#
#  batch_normalization_428 (Batch  (None, 16, 16, 512)  2048       ['conv2d_454[0][0]']
#  Normalization)
#
#  batch_normalization_431 (Batch  (None, 16, 16, 512)  2048       ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_428 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_428[0][0]']
#
#  activation_431 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_431[0][0]']
#
#  conv2d_453 (Conv2D)            (None, 16, 16, 512)  524800      ['concatenate_81[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 16, 16, 512)  2359808     ['activation_428[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 16, 16, 512)  2359808     ['activation_431[0][0]']
#
#  batch_normalization_427 (Batch  (None, 16, 16, 512)  2048       ['conv2d_453[0][0]']
#  Normalization)
#
#  batch_normalization_429 (Batch  (None, 16, 16, 512)  2048       ['conv2d_455[0][0]']
#  Normalization)
#
#  batch_normalization_432 (Batch  (None, 16, 16, 512)  2048       ['conv2d_458[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_427[0][0]']
#
#  activation_429 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_429[0][0]']
#
#  activation_432 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_432[0][0]']
#
#  concatenate_82 (Concatenate)   (None, 16, 16, 1536  0           ['activation_427[0][0]',
#                                 )                                 'activation_429[0][0]',
#                                                                   'activation_432[0][0]']
#
#  conv2d_459 (Conv2D)            (None, 16, 16, 512)  786944      ['concatenate_82[0][0]']
#
#  batch_normalization_433 (Batch  (None, 16, 16, 512)  2048       ['conv2d_459[0][0]']
#  Normalization)
#
#  activation_433 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_433[0][0]']
#
#  conv2d_460 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_26[0][0]']
#
#  conv2d_transpose_21 (Conv2DTra  (None, 32, 32, 256)  524544     ['activation_433[0][0]']
#  nspose)
#
#  up_sampling2d_25 (UpSampling2D  (None, 32, 32, 256)  0          ['conv2d_460[0][0]']
#  )
#
#  concatenate_83 (Concatenate)   (None, 32, 32, 512)  0           ['conv2d_transpose_21[0][0]',
#                                                                   'up_sampling2d_25[0][0]']
#
#  conv2d_464 (Conv2D)            (None, 32, 32, 256)  131328      ['concatenate_83[0][0]']
#
#  batch_normalization_437 (Batch  (None, 32, 32, 256)  1024       ['conv2d_464[0][0]']
#  Normalization)
#
#  activation_437 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_437[0][0]']
#
#  conv2d_462 (Conv2D)            (None, 32, 32, 256)  131328      ['concatenate_83[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_437[0][0]']
#
#  batch_normalization_435 (Batch  (None, 32, 32, 256)  1024       ['conv2d_462[0][0]']
#  Normalization)
#
#  batch_normalization_438 (Batch  (None, 32, 32, 256)  1024       ['conv2d_465[0][0]']
#  Normalization)
#
#  activation_435 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_435[0][0]']
#
#  activation_438 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_438[0][0]']
#
#  conv2d_461 (Conv2D)            (None, 32, 32, 256)  131328      ['concatenate_83[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_435[0][0]']
#
#  conv2d_466 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_438[0][0]']
#
#  batch_normalization_434 (Batch  (None, 32, 32, 256)  1024       ['conv2d_461[0][0]']
#  Normalization)
#
#  batch_normalization_436 (Batch  (None, 32, 32, 256)  1024       ['conv2d_463[0][0]']
#  Normalization)
#
#  batch_normalization_439 (Batch  (None, 32, 32, 256)  1024       ['conv2d_466[0][0]']
#  Normalization)
#
#  activation_434 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_434[0][0]']
#
#  activation_436 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_436[0][0]']
#
#  activation_439 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_439[0][0]']
#
#  concatenate_84 (Concatenate)   (None, 32, 32, 768)  0           ['activation_434[0][0]',
#                                                                   'activation_436[0][0]',
#                                                                   'activation_439[0][0]']
#
#  conv2d_467 (Conv2D)            (None, 32, 32, 256)  196864      ['concatenate_84[0][0]']
#
#  batch_normalization_440 (Batch  (None, 32, 32, 256)  1024       ['conv2d_467[0][0]']
#  Normalization)
#
#  activation_440 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_440[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_25[0][0]']
#
#  conv2d_transpose_22 (Conv2DTra  (None, 64, 64, 128)  131200     ['activation_440[0][0]']
#  nspose)
#
#  up_sampling2d_26 (UpSampling2D  (None, 64, 64, 128)  0          ['conv2d_468[0][0]']
#  )
#
#  concatenate_85 (Concatenate)   (None, 64, 64, 256)  0           ['conv2d_transpose_22[0][0]',
#                                                                   'up_sampling2d_26[0][0]']
#
#  conv2d_472 (Conv2D)            (None, 64, 64, 128)  32896       ['concatenate_85[0][0]']
#
#  batch_normalization_444 (Batch  (None, 64, 64, 128)  512        ['conv2d_472[0][0]']
#  Normalization)
#
#  activation_444 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_444[0][0]']
#
#  conv2d_470 (Conv2D)            (None, 64, 64, 128)  32896       ['concatenate_85[0][0]']
#
#  conv2d_473 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_444[0][0]']
#
#  batch_normalization_442 (Batch  (None, 64, 64, 128)  512        ['conv2d_470[0][0]']
#  Normalization)
#
#  batch_normalization_445 (Batch  (None, 64, 64, 128)  512        ['conv2d_473[0][0]']
#  Normalization)
#
#  activation_442 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_442[0][0]']
#
#  activation_445 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_445[0][0]']
#
#  conv2d_469 (Conv2D)            (None, 64, 64, 128)  32896       ['concatenate_85[0][0]']
#
#  conv2d_471 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_442[0][0]']
#
#  conv2d_474 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_445[0][0]']
#
#  batch_normalization_441 (Batch  (None, 64, 64, 128)  512        ['conv2d_469[0][0]']
#  Normalization)
#
#  batch_normalization_443 (Batch  (None, 64, 64, 128)  512        ['conv2d_471[0][0]']
#  Normalization)
#
#  batch_normalization_446 (Batch  (None, 64, 64, 128)  512        ['conv2d_474[0][0]']
#  Normalization)
#
#  activation_441 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_441[0][0]']
#
#  activation_443 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_443[0][0]']
#
#  activation_446 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_446[0][0]']
#
#  concatenate_86 (Concatenate)   (None, 64, 64, 384)  0           ['activation_441[0][0]',
#                                                                   'activation_443[0][0]',
#                                                                   'activation_446[0][0]']
#
#  conv2d_475 (Conv2D)            (None, 64, 64, 128)  49280       ['concatenate_86[0][0]']
#
#  batch_normalization_447 (Batch  (None, 64, 64, 128)  512        ['conv2d_475[0][0]']
#  Normalization)
#
#  activation_447 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_447[0][0]']
#
#  conv2d_476 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_24[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 128, 128, 64  32832      ['activation_447[0][0]']
#  nspose)                        )
#
#  up_sampling2d_27 (UpSampling2D  (None, 128, 128, 64  0          ['conv2d_476[0][0]']
#  )                              )
#
#  concatenate_87 (Concatenate)   (None, 128, 128, 12  0           ['conv2d_transpose_23[0][0]',
#                                 8)                                'up_sampling2d_27[0][0]']
#
#  conv2d_480 (Conv2D)            (None, 128, 128, 64  8256        ['concatenate_87[0][0]']
#                                 )
#
#  batch_normalization_451 (Batch  (None, 128, 128, 64  256        ['conv2d_480[0][0]']
#  Normalization)                 )
#
#  activation_451 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_451[0][0]']
#                                 )
#
#  conv2d_478 (Conv2D)            (None, 128, 128, 64  8256        ['concatenate_87[0][0]']
#                                 )
#
#  conv2d_481 (Conv2D)            (None, 128, 128, 64  36928       ['activation_451[0][0]']
#                                 )
#
#  batch_normalization_449 (Batch  (None, 128, 128, 64  256        ['conv2d_478[0][0]']
#  Normalization)                 )
#
#  batch_normalization_452 (Batch  (None, 128, 128, 64  256        ['conv2d_481[0][0]']
#  Normalization)                 )
#
#  activation_449 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_449[0][0]']
#                                 )
#
#  activation_452 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_452[0][0]']
#                                 )
#
#  conv2d_477 (Conv2D)            (None, 128, 128, 64  8256        ['concatenate_87[0][0]']
#                                 )
#
#  conv2d_479 (Conv2D)            (None, 128, 128, 64  36928       ['activation_449[0][0]']
#                                 )
#
#  conv2d_482 (Conv2D)            (None, 128, 128, 64  36928       ['activation_452[0][0]']
#                                 )
#
#  batch_normalization_448 (Batch  (None, 128, 128, 64  256        ['conv2d_477[0][0]']
#  Normalization)                 )
#
#  batch_normalization_450 (Batch  (None, 128, 128, 64  256        ['conv2d_479[0][0]']
#  Normalization)                 )
#
#  batch_normalization_453 (Batch  (None, 128, 128, 64  256        ['conv2d_482[0][0]']
#  Normalization)                 )
#
#  activation_448 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_448[0][0]']
#                                 )
#
#  activation_450 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_450[0][0]']
#                                 )
#
#  activation_453 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_453[0][0]']
#                                 )
#
#  concatenate_88 (Concatenate)   (None, 128, 128, 19  0           ['activation_448[0][0]',
#                                 2)                                'activation_450[0][0]',
#                                                                   'activation_453[0][0]']
#
#  conv2d_483 (Conv2D)            (None, 128, 128, 64  12352       ['concatenate_88[0][0]']
#                                 )
#
#  batch_normalization_454 (Batch  (None, 128, 128, 64  256        ['conv2d_483[0][0]']
#  Normalization)                 )
#
#  activation_454 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_454[0][0]']
#                                 )
#
#  conv2d_484 (Conv2D)            (None, 128, 128, 10  650         ['activation_454[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 59,628,042
# Trainable params: 59,586,378
# Non-trainable params: 41,664
# __________________________________________________________________________________________________

# %%
model.input_shape, model.output_shape
# Out:
# ((None, 128, 128, 3), (None, 128, 128, 10))

# %%
len(model.layers)
# Out:
# 242

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x193f9e43e50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193e1b15370>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193e1b150d0>,
#  <keras.layers.core.activation.Activation at 0x193e1b7dbb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9e43070>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a7bedc0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a16caf0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193e72c1f70>,
#  <keras.layers.core.activation.Activation at 0x193e72ae040>,
#  <keras.layers.core.activation.Activation at 0x193f9e4ee50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9db8580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a7bd910>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9e7bfd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9dc4be0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193d7923f10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193dd39d6a0>,
#  <keras.layers.core.activation.Activation at 0x193dd3dd3d0>,
#  <keras.layers.core.activation.Activation at 0x193d7936d60>,
#  <keras.layers.core.activation.Activation at 0x193f9e89a30>,
#  <keras.layers.merging.concatenate.Concatenate at 0x193f9e898b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9e89d60>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a16c9a0>,
#  <keras.layers.core.activation.Activation at 0x193e1b41040>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x193dd39d820>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9ea8d30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9e9a520>,
#  <keras.layers.core.activation.Activation at 0x193f9eb9670>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9e58670>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9eb97f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9e58640>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9ea3640>,
#  <keras.layers.core.activation.Activation at 0x193f9e58a30>,
#  <keras.layers.core.activation.Activation at 0x193f9ea8e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193dd3a1640>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9e9a760>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9ea32e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193dd3a18b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9e14820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9ea8cd0>,
#  <keras.layers.core.activation.Activation at 0x193dd3a1d60>,
#  <keras.layers.core.activation.Activation at 0x193f9ea8bb0>,
#  <keras.layers.core.activation.Activation at 0x193f9eb0880>,
#  <keras.layers.merging.concatenate.Concatenate at 0x193f9ed02b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9eca220>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9ea3340>,
#  <keras.layers.core.activation.Activation at 0x193f9ec28e0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x193f9ed89d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f0cc40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f0c9a0>,
#  <keras.layers.core.activation.Activation at 0x193f9f21580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9eec5e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f21700>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9ed87f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f159d0>,
#  <keras.layers.core.activation.Activation at 0x193f9efc5b0>,
#  <keras.layers.core.activation.Activation at 0x193f9efc370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9ed8730>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9efc9d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9ef2ac0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9ed8130>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9ed03d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9ef2a90>,
#  <keras.layers.core.activation.Activation at 0x193f9ed8e20>,
#  <keras.layers.core.activation.Activation at 0x193f9ef25e0>,
#  <keras.layers.core.activation.Activation at 0x193f9eca790>,
#  <keras.layers.merging.concatenate.Concatenate at 0x193f9efcac0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9eca940>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9ecac10>,
#  <keras.layers.core.activation.Activation at 0x193f9f04d60>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x193f9eb0a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f3ad00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f2fa60>,
#  <keras.layers.core.activation.Activation at 0x193f9f4a640>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9e140a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f4a7c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9e83df0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f33ca0>,
#  <keras.layers.core.activation.Activation at 0x193dd3a19d0>,
#  <keras.layers.core.activation.Activation at 0x193f9f3a370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9eca9a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9ef29a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f33370>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9eb0460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9e58eb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f3a5b0>,
#  <keras.layers.core.activation.Activation at 0x193f9ea8340>,
#  <keras.layers.core.activation.Activation at 0x193f9f2afd0>,
#  <keras.layers.core.activation.Activation at 0x193f9f41a60>,
#  <keras.layers.merging.concatenate.Concatenate at 0x193f9f62a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f4a8e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f5bee0>,
#  <keras.layers.core.activation.Activation at 0x193f9f548b0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x193f9f6b9a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f5b7f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195818bd9d0>,
#  <keras.layers.core.activation.Activation at 0x195818d0f70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f623d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f5b910>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f6b790>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f33820>,
#  <keras.layers.core.activation.Activation at 0x195818d0fd0>,
#  <keras.layers.core.activation.Activation at 0x195818d0fa0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f6b700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195818d0a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9ea8fd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f6b190>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195818c8f70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9ec2400>,
#  <keras.layers.core.activation.Activation at 0x193f9f6bdf0>,
#  <keras.layers.core.activation.Activation at 0x193f9f5bd60>,
#  <keras.layers.core.activation.Activation at 0x193dd3a1f70>,
#  <keras.layers.merging.concatenate.Concatenate at 0x193f9f418e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f54730>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9e833d0>,
#  <keras.layers.core.activation.Activation at 0x193f9f04220>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1958190ca30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195818eb6a0>,
#  <keras.layers.core.activation.Activation at 0x195818ebbe0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195818eb9a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195818fb5b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f2fb80>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195818fb700>,
#  <keras.layers.core.activation.Activation at 0x195818e3df0>,
#  <keras.layers.core.activation.Activation at 0x19581903790>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f4aca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195818fbf70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581926f70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9dc4c10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195818f4e50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1958191bd30>,
#  <keras.layers.core.activation.Activation at 0x195818d92e0>,
#  <keras.layers.core.activation.Activation at 0x1958190c8b0>,
#  <keras.layers.core.activation.Activation at 0x1958191bf10>,
#  <keras.layers.merging.concatenate.Concatenate at 0x19581936850>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1958192d1c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1958192d850>,
#  <keras.layers.core.activation.Activation at 0x1958193c310>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1958192d340>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x1958193c2e0>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x193e72c1a30>,
#  <keras.layers.merging.concatenate.Concatenate at 0x195819113d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9ef28b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195818e3190>,
#  <keras.layers.core.activation.Activation at 0x193f9f6bfd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195818f4880>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581954b50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195818f4700>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1958191b880>,
#  <keras.layers.core.activation.Activation at 0x195818eb2b0>,
#  <keras.layers.core.activation.Activation at 0x19581964490>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581926e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9f0c1c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581964610>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193e72b2a60>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193f9f2a850>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19581959a00>,
#  <keras.layers.core.activation.Activation at 0x1958190cca0>,
#  <keras.layers.core.activation.Activation at 0x195818d90d0>,
#  <keras.layers.core.activation.Activation at 0x1958196cf10>,
#  <keras.layers.merging.concatenate.Concatenate at 0x19581950b20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1958196c250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1958196cdf0>,
#  <keras.layers.core.activation.Activation at 0x195819742e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581974d30>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x195819742b0>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x1958193cb50>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1958196c580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195819abd00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819abbb0>,
#  <keras.layers.core.activation.Activation at 0x19581986340>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581959a30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581974790>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19581974430>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1958197c730>,
#  <keras.layers.core.activation.Activation at 0x195819a6910>,
#  <keras.layers.core.activation.Activation at 0x195819abc70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1958197c5e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195819a6a90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195819865e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19581986880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1958199e310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19581954190>,
#  <keras.layers.core.activation.Activation at 0x19581996400>,
#  <keras.layers.core.activation.Activation at 0x195819ab100>,
#  <keras.layers.core.activation.Activation at 0x195819ab5e0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1958198c040>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195818d93a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195818d9040>,
#  <keras.layers.core.activation.Activation at 0x193f9f6bca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193f9eec250>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x1958197c940>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x195819749d0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x19581964d90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195819ebd60>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819e4700>,
#  <keras.layers.core.activation.Activation at 0x195819e4a60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195819cd7f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195819fcb20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819544f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819dc880>,
#  <keras.layers.core.activation.Activation at 0x195819c8e20>,
#  <keras.layers.core.activation.Activation at 0x195819eb880>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581950c70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195819dcb20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581a03a90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19581950a90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819d53d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819eb790>,
#  <keras.layers.core.activation.Activation at 0x195819b7dc0>,
#  <keras.layers.core.activation.Activation at 0x195819ebee0>,
#  <keras.layers.core.activation.Activation at 0x195819f4040>,
#  <keras.layers.merging.concatenate.Concatenate at 0x19581a15d60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581a155e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19581a15dc0>,
#  <keras.layers.core.activation.Activation at 0x19581a1d280>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581a1d370>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x19581a1d3d0>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x195819e4ee0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x195819fcf40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195818b30d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819c8790>,
#  <keras.layers.core.activation.Activation at 0x19581a03f10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x195819c89d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581a388e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819dc190>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819747c0>,
#  <keras.layers.core.activation.Activation at 0x195819cda30>,
#  <keras.layers.core.activation.Activation at 0x19581a27dc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581a0ddf0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1958192de50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581a43eb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x195819e4820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19581974580>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19581a3d880>,
#  <keras.layers.core.activation.Activation at 0x195819cd340>,
#  <keras.layers.core.activation.Activation at 0x195819b7b80>,
#  <keras.layers.core.activation.Activation at 0x19581a547f0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x19581a54100>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581a54c10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19581a4bb50>,
#  <keras.layers.core.activation.Activation at 0x19581a3d4f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19581a43670>]

# %%
layers = [type(layer) for layer in model.layers]

# %%
from collections import Counter

item_occurrence = Counter(layers)

# Printing the occurrence of each item
for item, occurrence in item_occurrence.items():
    print(f"{item}: {occurrence}")
# Out:
# <class 'keras.engine.input_layer.InputLayer'>: 1
# <class 'keras.layers.convolutional.conv2d.Conv2D'>: 75
# <class 'keras.layers.normalization.batch_normalization.BatchNormalization'>: 70
# <class 'keras.layers.core.activation.Activation'>: 70
# <class 'keras.layers.merging.concatenate.Concatenate'>: 14
# <class 'keras.layers.pooling.max_pooling2d.MaxPooling2D'>: 4
# <class 'keras.layers.convolutional.conv2d_transpose.Conv2DTranspose'>: 4
# <class 'keras.layers.reshaping.up_sampling2d.UpSampling2D'>: 4

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 51s 214ms/step - loss: 1.0681 - iou_score: 0.1928 - val_loss: 1.2201 - val_iou_score: 0.0917
# Epoch 2/100
# 181/181 [==============================] - 34s 185ms/step - loss: 0.8587 - iou_score: 0.2895 - val_loss: 1.8394 - val_iou_score: 0.1229
# Epoch 3/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.8168 - iou_score: 0.3200 - val_loss: 0.8794 - val_iou_score: 0.2527
# Epoch 4/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.7793 - iou_score: 0.3474 - val_loss: 0.8516 - val_iou_score: 0.2645
# Epoch 5/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.7678 - iou_score: 0.3565 - val_loss: 0.8356 - val_iou_score: 0.2817
# Epoch 6/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.7462 - iou_score: 0.3725 - val_loss: 0.8548 - val_iou_score: 0.2611
# Epoch 7/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.7310 - iou_score: 0.3838 - val_loss: 0.7980 - val_iou_score: 0.3042
# Epoch 8/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.7134 - iou_score: 0.3992 - val_loss: 0.8144 - val_iou_score: 0.3000
# Epoch 9/100
# 181/181 [==============================] - 34s 191ms/step - loss: 0.7116 - iou_score: 0.3985 - val_loss: 0.9223 - val_iou_score: 0.2387
# Epoch 10/100
# 181/181 [==============================] - 35s 191ms/step - loss: 0.6975 - iou_score: 0.4096 - val_loss: 0.8240 - val_iou_score: 0.2885
# Epoch 11/100
# 181/181 [==============================] - 34s 191ms/step - loss: 0.6850 - iou_score: 0.4195 - val_loss: 0.7949 - val_iou_score: 0.3059
# Epoch 12/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.6724 - iou_score: 0.4298 - val_loss: 0.8147 - val_iou_score: 0.2993
# Epoch 13/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.6713 - iou_score: 0.4309 - val_loss: 0.7950 - val_iou_score: 0.3110
# Epoch 14/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.6689 - iou_score: 0.4329 - val_loss: 0.7739 - val_iou_score: 0.3207
# Epoch 15/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.6508 - iou_score: 0.4458 - val_loss: 0.7755 - val_iou_score: 0.3226
# Epoch 16/100
# 181/181 [==============================] - 34s 186ms/step - loss: 0.6458 - iou_score: 0.4499 - val_loss: 0.7475 - val_iou_score: 0.3414
# Epoch 17/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.6440 - iou_score: 0.4492 - val_loss: 0.7744 - val_iou_score: 0.3245
# Epoch 18/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.6372 - iou_score: 0.4568 - val_loss: 0.7692 - val_iou_score: 0.3273
# Epoch 19/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.6428 - iou_score: 0.4506 - val_loss: 0.7755 - val_iou_score: 0.3278
# Epoch 20/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.6191 - iou_score: 0.4709 - val_loss: 0.7371 - val_iou_score: 0.3474
# Epoch 21/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.6264 - iou_score: 0.4615 - val_loss: 0.7456 - val_iou_score: 0.3449
# Epoch 22/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.6117 - iou_score: 0.4756 - val_loss: 0.7491 - val_iou_score: 0.3406
# Epoch 23/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.6088 - iou_score: 0.4797 - val_loss: 0.7370 - val_iou_score: 0.3514
# Epoch 24/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.6130 - iou_score: 0.4739 - val_loss: 0.7458 - val_iou_score: 0.3455
# Epoch 25/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.6087 - iou_score: 0.4774 - val_loss: 0.7441 - val_iou_score: 0.3459
# Epoch 26/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.5961 - iou_score: 0.4880 - val_loss: 0.7290 - val_iou_score: 0.3566
# Epoch 27/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5949 - iou_score: 0.4889 - val_loss: 0.7251 - val_iou_score: 0.3593
# Epoch 28/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5821 - iou_score: 0.4990 - val_loss: 0.7384 - val_iou_score: 0.3472
# Epoch 29/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5780 - iou_score: 0.5032 - val_loss: 0.7355 - val_iou_score: 0.3524
# Epoch 30/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5841 - iou_score: 0.4968 - val_loss: 0.7293 - val_iou_score: 0.3546
# Epoch 31/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5730 - iou_score: 0.5080 - val_loss: 0.7342 - val_iou_score: 0.3546
# Epoch 32/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5676 - iou_score: 0.5124 - val_loss: 0.7414 - val_iou_score: 0.3497
# Epoch 33/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5726 - iou_score: 0.5062 - val_loss: 0.7062 - val_iou_score: 0.3703
# Epoch 34/100
# 181/181 [==============================] - 34s 186ms/step - loss: 0.5706 - iou_score: 0.5083 - val_loss: 0.7176 - val_iou_score: 0.3637
# Epoch 35/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5538 - iou_score: 0.5218 - val_loss: 0.7089 - val_iou_score: 0.3701
# Epoch 36/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.5482 - iou_score: 0.5264 - val_loss: 0.7211 - val_iou_score: 0.3589
# Epoch 37/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5527 - iou_score: 0.5233 - val_loss: 0.7281 - val_iou_score: 0.3599
# Epoch 38/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5488 - iou_score: 0.5260 - val_loss: 0.7132 - val_iou_score: 0.3701
# Epoch 39/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5438 - iou_score: 0.5315 - val_loss: 0.7024 - val_iou_score: 0.3742
# Epoch 40/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5421 - iou_score: 0.5315 - val_loss: 0.7182 - val_iou_score: 0.3640
# Epoch 41/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5404 - iou_score: 0.5307 - val_loss: 0.6957 - val_iou_score: 0.3777
# Epoch 42/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5286 - iou_score: 0.5434 - val_loss: 0.6986 - val_iou_score: 0.3760
# Epoch 43/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5253 - iou_score: 0.5452 - val_loss: 0.6990 - val_iou_score: 0.3766
# Epoch 44/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.5294 - iou_score: 0.5426 - val_loss: 0.6992 - val_iou_score: 0.3768
# Epoch 45/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5283 - iou_score: 0.5434 - val_loss: 0.7342 - val_iou_score: 0.3596
# Epoch 46/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.5222 - iou_score: 0.5467 - val_loss: 0.6966 - val_iou_score: 0.3787
# Epoch 47/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.5101 - iou_score: 0.5574 - val_loss: 0.6902 - val_iou_score: 0.3841
# Epoch 48/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.5217 - iou_score: 0.5481 - val_loss: 0.7189 - val_iou_score: 0.3659
# Epoch 49/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5211 - iou_score: 0.5471 - val_loss: 0.7301 - val_iou_score: 0.3560
# Epoch 50/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.5287 - iou_score: 0.5415 - val_loss: 0.7051 - val_iou_score: 0.3714
# Epoch 51/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5229 - iou_score: 0.5475 - val_loss: 0.7041 - val_iou_score: 0.3743
# Epoch 52/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5117 - iou_score: 0.5554 - val_loss: 0.7010 - val_iou_score: 0.3817
# Epoch 53/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.5114 - iou_score: 0.5551 - val_loss: 0.7074 - val_iou_score: 0.3755
# Epoch 54/100
# 181/181 [==============================] - 34s 186ms/step - loss: 0.5062 - iou_score: 0.5611 - val_loss: 0.6920 - val_iou_score: 0.3806
# Epoch 55/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5058 - iou_score: 0.5613 - val_loss: 0.7058 - val_iou_score: 0.3730
# Epoch 56/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.5071 - iou_score: 0.5583 - val_loss: 0.6931 - val_iou_score: 0.3834
# Epoch 57/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4952 - iou_score: 0.5689 - val_loss: 0.6960 - val_iou_score: 0.3800
# Epoch 58/100
# 181/181 [==============================] - 34s 186ms/step - loss: 0.4918 - iou_score: 0.5714 - val_loss: 0.6838 - val_iou_score: 0.3881
# Epoch 59/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.4884 - iou_score: 0.5738 - val_loss: 0.6822 - val_iou_score: 0.3879
# Epoch 60/100
# 181/181 [==============================] - 34s 186ms/step - loss: 0.4766 - iou_score: 0.5832 - val_loss: 0.6786 - val_iou_score: 0.3934
# Epoch 61/100
# 181/181 [==============================] - 34s 185ms/step - loss: 0.4901 - iou_score: 0.5730 - val_loss: 0.6916 - val_iou_score: 0.3823
# Epoch 62/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4905 - iou_score: 0.5732 - val_loss: 0.6939 - val_iou_score: 0.3811
# Epoch 63/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4808 - iou_score: 0.5800 - val_loss: 0.6778 - val_iou_score: 0.3926
# Epoch 64/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4830 - iou_score: 0.5781 - val_loss: 0.7002 - val_iou_score: 0.3798
# Epoch 65/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4777 - iou_score: 0.5818 - val_loss: 0.6746 - val_iou_score: 0.3959
# Epoch 66/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4770 - iou_score: 0.5827 - val_loss: 0.7021 - val_iou_score: 0.3778
# Epoch 67/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4715 - iou_score: 0.5891 - val_loss: 0.6961 - val_iou_score: 0.3790
# Epoch 68/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4749 - iou_score: 0.5848 - val_loss: 0.7159 - val_iou_score: 0.3707
# Epoch 69/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4677 - iou_score: 0.5914 - val_loss: 0.6877 - val_iou_score: 0.3877
# Epoch 70/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4644 - iou_score: 0.5944 - val_loss: 0.6781 - val_iou_score: 0.3945
# Epoch 71/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4722 - iou_score: 0.5885 - val_loss: 0.7091 - val_iou_score: 0.3714
# Epoch 72/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4771 - iou_score: 0.5821 - val_loss: 0.7016 - val_iou_score: 0.3783
# Epoch 73/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4850 - iou_score: 0.5749 - val_loss: 0.7008 - val_iou_score: 0.3767
# Epoch 74/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4670 - iou_score: 0.5912 - val_loss: 0.6921 - val_iou_score: 0.3847
# Epoch 75/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4668 - iou_score: 0.5904 - val_loss: 0.6895 - val_iou_score: 0.3848
# Epoch 76/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4846 - iou_score: 0.5790 - val_loss: 0.6961 - val_iou_score: 0.3836
# Epoch 77/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4721 - iou_score: 0.5878 - val_loss: 0.6936 - val_iou_score: 0.3850
# Epoch 78/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4588 - iou_score: 0.5979 - val_loss: 0.6906 - val_iou_score: 0.3885
# Epoch 79/100
# 181/181 [==============================] - 34s 187ms/step - loss: 0.4622 - iou_score: 0.5939 - val_loss: 0.6907 - val_iou_score: 0.3841
# Epoch 80/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4409 - iou_score: 0.6123 - val_loss: 0.6647 - val_iou_score: 0.4025
# Epoch 81/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4427 - iou_score: 0.6107 - val_loss: 0.6694 - val_iou_score: 0.4020
# Epoch 82/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4368 - iou_score: 0.6165 - val_loss: 0.7052 - val_iou_score: 0.3848
# Epoch 83/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4448 - iou_score: 0.6091 - val_loss: 0.6865 - val_iou_score: 0.3869
# Epoch 84/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4468 - iou_score: 0.6068 - val_loss: 0.6735 - val_iou_score: 0.3992
# Epoch 85/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4507 - iou_score: 0.6039 - val_loss: 0.6852 - val_iou_score: 0.3917
# Epoch 86/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4577 - iou_score: 0.5966 - val_loss: 0.6982 - val_iou_score: 0.3840
# Epoch 87/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4318 - iou_score: 0.6216 - val_loss: 0.6729 - val_iou_score: 0.3953
# Epoch 88/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4399 - iou_score: 0.6123 - val_loss: 0.6765 - val_iou_score: 0.3960
# Epoch 89/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4527 - iou_score: 0.6018 - val_loss: 0.6762 - val_iou_score: 0.3932
# Epoch 90/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4518 - iou_score: 0.6039 - val_loss: 0.6998 - val_iou_score: 0.3810
# Epoch 91/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4415 - iou_score: 0.6120 - val_loss: 0.6724 - val_iou_score: 0.3986
# Epoch 92/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4405 - iou_score: 0.6106 - val_loss: 0.6670 - val_iou_score: 0.4013
# Epoch 93/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4377 - iou_score: 0.6146 - val_loss: 0.6819 - val_iou_score: 0.3943
# Epoch 94/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4388 - iou_score: 0.6139 - val_loss: 0.6853 - val_iou_score: 0.3892
# Epoch 95/100
# 181/181 [==============================] - 34s 188ms/step - loss: 0.4356 - iou_score: 0.6180 - val_loss: 0.6799 - val_iou_score: 0.3939
# Epoch 96/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4233 - iou_score: 0.6279 - val_loss: 0.6747 - val_iou_score: 0.3976
# Epoch 97/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4304 - iou_score: 0.6198 - val_loss: 0.6729 - val_iou_score: 0.3992
# Epoch 98/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4286 - iou_score: 0.6221 - val_loss: 0.7037 - val_iou_score: 0.3818
# Epoch 99/100
# 181/181 [==============================] - 34s 189ms/step - loss: 0.4334 - iou_score: 0.6185 - val_loss: 0.6838 - val_iou_score: 0.3922
# Epoch 100/100
# 181/181 [==============================] - 34s 190ms/step - loss: 0.4141 - iou_score: 0.6362 - val_loss: 0.6687 - val_iou_score: 0.4006

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../../../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  47.27453291416168 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 3s 145ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.63129145
# IoU for each class:
# Building Flooded: 0.7100957036018372
# Building Non-Flooded: 0.7498827576637268
# Road Flooded: 0.510191798210144
# Road Non-Flooded: 0.8041781783103943
# Water: 0.7306455373764038
# Tree: 0.7959280014038086
# Vehicle: 0.38831740617752075
# Pool: 0.47658291459083557
# Grass: 0.8736886978149414
# Mean IoU (excluding Background): 0.67105675

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
