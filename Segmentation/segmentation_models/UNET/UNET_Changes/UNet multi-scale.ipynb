# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'efficientnetb7'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../../../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate, BatchNormalization, UpSampling2D, Activation, Conv2DTranspose
from tensorflow.keras.models import Model

def res_inception_unit(input_layer, filters):
    # First convolutional block
    conv1x1_1 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv1x1_1 = BatchNormalization()(conv1x1_1)
    conv1x1_1 = Activation('relu')(conv1x1_1)

    # Second convolutional block
    conv1x1_2 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv1x1_2 = BatchNormalization()(conv1x1_2)
    conv1x1_2 = Activation('relu')(conv1x1_2)
    conv3x3_2 = Conv2D(filters, (3, 3), padding='same')(conv1x1_2)
    conv3x3_2 = BatchNormalization()(conv3x3_2)
    conv3x3_2 = Activation('relu')(conv3x3_2)

    # Third convolutional block
    conv1x1_3 = Conv2D(filters, (1, 1), padding='same')(input_layer)
    conv1x1_3 = BatchNormalization()(conv1x1_3)
    conv1x1_3 = Activation('relu')(conv1x1_3)
    conv3x3_3 = Conv2D(filters, (3, 3), padding='same')(conv1x1_3)
    conv3x3_3 = BatchNormalization()(conv3x3_3)
    conv3x3_3 = Activation('relu')(conv3x3_3)
    conv3x3_3 = Conv2D(filters, (3, 3), padding='same')(conv3x3_3)
    conv3x3_3 = BatchNormalization()(conv3x3_3)
    conv3x3_3 = Activation('relu')(conv3x3_3)

    # Concatenate the outputs
    concatenated = concatenate([conv1x1_1, conv3x3_2, conv3x3_3], axis=-1)
    
    # Final convolution to merge outputs
    output = Conv2D(filters, (1, 1), padding='same')(concatenated)
    output = BatchNormalization()(output)
    output = Activation('relu')(output)
    
    return output

def build_model(input_shape, num_classes):
    # Encoder
    inputs = Input(input_shape)
    encoder_filters = [32, 64, 128, 256, 512]
    encoder_outputs = [inputs]
    for i, filters in enumerate(encoder_filters):
        x = res_inception_unit(encoder_outputs[-1], filters)
        encoder_outputs.append(MaxPooling2D(pool_size=(2, 2))(x) if i < len(encoder_filters) - 1 else x)

    # Bridge module
    bridge_filters = 1024
    bridge_output = res_inception_unit(encoder_outputs[-1], bridge_filters)

    # Decoder
    decoder_filters = [512, 256, 128]
    x = bridge_output
    for i, filters in enumerate(decoder_filters):
        x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(x)
        # Adjust spatial dimensions of encoder output to match those of decoder output
        encoder_output = encoder_outputs[-(i + 2)]
        encoder_output = Conv2D(filters, (1, 1), padding='same')(encoder_output)
        if encoder_output.shape[1] != x.shape[1]:
            encoder_output = UpSampling2D(size=(2, 2))(encoder_output)
        if encoder_output.shape[2] != x.shape[2]:
            encoder_output = UpSampling2D(size=(2, 2))(encoder_output)
        x = concatenate([x, encoder_output], axis=-1)
        x = res_inception_unit(x, filters)

    # Output layer
    outputs = Conv2D(num_classes, (1, 1), activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# %%
input_shape = (SIZE_X, SIZE_Y, n_channels)
model = build_model(input_shape, n_classes)
model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  128         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  128         ['input_1[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 32  9248        ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 128, 128, 32  128         ['input_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  9248        ['activation_1[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 32  9248        ['activation_4[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 128, 128, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 128, 128, 96  0           ['activation[0][0]',
#                                 )                                 'activation_2[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 32  3104        ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 32  128        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 64)   2112        ['max_pooling2d[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 64)   2112        ['max_pooling2d[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_8[0][0]']
#
#  activation_11 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   2112        ['max_pooling2d[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_8[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_11[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_9 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_9[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_12[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 192)  0           ['activation_7[0][0]',
#                                                                   'activation_9[0][0]',
#                                                                   'activation_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   12352       ['concatenate_1[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_13[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_17[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_15[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_15[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_18[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_14[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_16[0][0]']
#
#  activation_19 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_19[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 384)  0           ['activation_14[0][0]',
#                                                                   'activation_16[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 128)  49280       ['concatenate_2[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_20[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 256)  33024       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 256)  33024       ['max_pooling2d_2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_24[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_22[0][0]']
#
#  activation_25 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 256)  33024       ['max_pooling2d_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_22[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_25[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_21[0][0]']
#
#  activation_23 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_23[0][0]']
#
#  activation_26 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_26[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 16, 16, 768)  0           ['activation_21[0][0]',
#                                                                   'activation_23[0][0]',
#                                                                   'activation_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 256)  196864      ['concatenate_3[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_27[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['activation_27[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 512)    131584      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 512)    131584      ['max_pooling2d_3[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_31[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_29[0][0]']
#
#  activation_32 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_32[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 512)    131584      ['max_pooling2d_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_29[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_32[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_28[0][0]']
#
#  activation_30 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_33[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8, 8, 1536)   0           ['activation_28[0][0]',
#                                                                   'activation_30[0][0]',
#                                                                   'activation_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 512)    786944      ['concatenate_4[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 1024)   525312      ['activation_34[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 1024)   525312      ['activation_34[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 1024)   9438208     ['activation_38[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_36[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 1024)   525312      ['activation_34[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 1024)   9438208     ['activation_36[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 1024)   9438208     ['activation_39[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_35[0][0]']
#
#  activation_37 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_40[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 8, 8, 3072)   0           ['activation_35[0][0]',
#                                                                   'activation_37[0][0]',
#                                                                   'activation_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 1024)   3146752     ['concatenate_5[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 512)    131584      ['max_pooling2d_3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  2097664    ['activation_41[0][0]']
#  ose)
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 512)  0           ['conv2d_42[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'up_sampling2d[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 512)  524800      ['concatenate_6[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 512)  524800      ['concatenate_6[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 512)  524800      ['concatenate_6[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_43[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_47[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 16, 16, 1536  0           ['activation_42[0][0]',
#                                 )                                 'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 512)  786944      ['concatenate_7[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 16, 16, 256)  33024       ['max_pooling2d_2[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_48[0][0]']
#  spose)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0          ['conv2d_50[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'up_sampling2d_1[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 256)  131328      ['concatenate_8[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 32, 32, 256)  131328      ['concatenate_8[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_52[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 32, 32, 256)  131328      ['concatenate_8[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_50[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_53[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_54 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_49[0][0]']
#
#  activation_51 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_51[0][0]']
#
#  activation_54 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_54[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 768)  0           ['activation_49[0][0]',
#                                                                   'activation_51[0][0]',
#                                                                   'activation_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 32, 32, 256)  196864      ['concatenate_9[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 32, 32, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_55[0][0]']
#  spose)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0          ['conv2d_58[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'up_sampling2d_2[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 64, 64, 128)  32896       ['concatenate_10[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 64, 64, 128)  512        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_59[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 64, 64, 128)  32896       ['concatenate_10[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_59[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 64, 64, 128)  512        ['conv2d_60[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 64, 64, 128)  512        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_57[0][0]']
#
#  activation_60 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 64, 64, 128)  32896       ['concatenate_10[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_57[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_60[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 64, 64, 128)  512        ['conv2d_59[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 64, 64, 128)  512        ['conv2d_61[0][0]']
#  ormalization)
#
#  batch_normalization_61 (BatchN  (None, 64, 64, 128)  512        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_56[0][0]']
#
#  activation_58 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_58[0][0]']
#
#  activation_61 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_61[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 64, 64, 384)  0           ['activation_56[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'activation_61[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 64, 64, 128)  49280       ['concatenate_11[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 64, 64, 128)  512        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 64, 64, 10)   1290        ['activation_62[0][0]']
#
# ==================================================================================================
# Total params: 59,444,042
# Trainable params: 59,403,274
# Non-trainable params: 40,768
# __________________________________________________________________________________________________

# %%
model.input_shape, model.output_mask
# Out:
# ((None, 128, 128, 3), None)

# %%
len(model.layers)
# Out:
# 216

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x19343599700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1934359b460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1934359b610>,
#  <keras.layers.core.activation.Activation at 0x19303f7ab80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1934359b700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303f78220>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193394f3f70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19359af7040>,
#  <keras.layers.core.activation.Activation at 0x193394f3d00>,
#  <keras.layers.core.activation.Activation at 0x1934358ebe0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1934359d580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1934358a7f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303f84a00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19343570d90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19343570df0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303f96a90>,
#  <keras.layers.core.activation.Activation at 0x1934359d640>,
#  <keras.layers.core.activation.Activation at 0x1934358a970>,
#  <keras.layers.core.activation.Activation at 0x19303f96ac0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x19303f78fa0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fa0c10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303f84d60>,
#  <keras.layers.core.activation.Activation at 0x19303f84e80>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x19303f916a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fd1760>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303fd8a90>,
#  <keras.layers.core.activation.Activation at 0x19303fd86a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fbec40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fdb2b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303fb5f10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303fde4c0>,
#  <keras.layers.core.activation.Activation at 0x19303fbea60>,
#  <keras.layers.core.activation.Activation at 0x19303fde460>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fb23d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fcae50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fe7b80>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303fa07c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303fca790>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303fd1700>,
#  <keras.layers.core.activation.Activation at 0x19303fb2340>,
#  <keras.layers.core.activation.Activation at 0x19303fca880>,
#  <keras.layers.core.activation.Activation at 0x19303fe7b50>,
#  <keras.layers.merging.concatenate.Concatenate at 0x19303fdb790>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303ffe700>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303ffe640>,
#  <keras.layers.core.activation.Activation at 0x19303fe74c0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x19303fdefa0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304013e50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19304017220>,
#  <keras.layers.core.activation.Activation at 0x19304017cd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303f7aa30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930401cdc0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303ff0c10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930400d370>,
#  <keras.layers.core.activation.Activation at 0x19303f7ab20>,
#  <keras.layers.core.activation.Activation at 0x19304021a30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fca1f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930400dd90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304029d30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303f96250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19304010280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930402a9a0>,
#  <keras.layers.core.activation.Activation at 0x19303f96310>,
#  <keras.layers.core.activation.Activation at 0x193040109d0>,
#  <keras.layers.core.activation.Activation at 0x1930402a5e0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1930401c340>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930403d3d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930403d310>,
#  <keras.layers.core.activation.Activation at 0x1930403ddc0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x193040293d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304068df0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19304077700>,
#  <keras.layers.core.activation.Activation at 0x1930405d850>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304052f10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193040682b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19304036220>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19304087670>,
#  <keras.layers.core.activation.Activation at 0x193040577c0>,
#  <keras.layers.core.activation.Activation at 0x193040876a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304049250>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930405de80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304077460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19304049dc0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19304064730>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19359acbc10>,
#  <keras.layers.core.activation.Activation at 0x19304049f70>,
#  <keras.layers.core.activation.Activation at 0x19304064790>,
#  <keras.layers.core.activation.Activation at 0x19359ac6f70>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1934359d7f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303f84c10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19359a95c10>,
#  <keras.layers.core.activation.Activation at 0x19303f845b0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x19343570e50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304087d60>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193040363a0>,
#  <keras.layers.core.activation.Activation at 0x193399897f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304064dc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19339c786a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930403de50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193394f3ee0>,
#  <keras.layers.core.activation.Activation at 0x19303fcafd0>,
#  <keras.layers.core.activation.Activation at 0x19304021fd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fb2970>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930405d820>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1934358aa30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303f7aca0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930405d670>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930401c310>,
#  <keras.layers.core.activation.Activation at 0x19304052a30>,
#  <keras.layers.core.activation.Activation at 0x19304081880>,
#  <keras.layers.core.activation.Activation at 0x1930400d1f0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x19303f786d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304010a90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193040134c0>,
#  <keras.layers.core.activation.Activation at 0x19303ff8730>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a043880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0431c0>,
#  <keras.layers.core.activation.Activation at 0x19303fa0970>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303f96760>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x193040108e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303fb5460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19304010f40>,
#  <keras.layers.core.activation.Activation at 0x19304006c10>,
#  <keras.layers.core.activation.Activation at 0x19303fcad00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19303fa08b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a032880>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x19304077f40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1934359d7c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193040bdc40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19343570d30>,
#  <keras.layers.core.activation.Activation at 0x19303f91b80>,
#  <keras.layers.core.activation.Activation at 0x1930a043be0>,
#  <keras.layers.core.activation.Activation at 0x1930a050160>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1930a050580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a047a60>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19303fd8cd0>,
#  <keras.layers.core.activation.Activation at 0x1930a0566d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a05aaf0>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x1930a056610>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x19303ff0460>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1930a05ddc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a076fd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0769a0>,
#  <keras.layers.core.activation.Activation at 0x1930a0760a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a05dac0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a0919d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a07abe0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a083df0>,
#  <keras.layers.core.activation.Activation at 0x1930a07ac10>,
#  <keras.layers.core.activation.Activation at 0x1930a0a1940>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a067eb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a0671f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a0911c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a06d2e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a05dc10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a087610>,
#  <keras.layers.core.activation.Activation at 0x1930a06dfa0>,
#  <keras.layers.core.activation.Activation at 0x1930a087a90>,
#  <keras.layers.core.activation.Activation at 0x1930a091e50>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1930a09d910>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a0bac10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0be520>,
#  <keras.layers.core.activation.Activation at 0x1930a0beaf0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a091e80>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x1930a0b02b0>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x1930a0a1790>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1930a05d4f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a0c96d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x19304013fd0>,
#  <keras.layers.core.activation.Activation at 0x19304068c70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1934358a0d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a0d2040>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x193040bd6a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0db940>,
#  <keras.layers.core.activation.Activation at 0x193394ec130>,
#  <keras.layers.core.activation.Activation at 0x1930a0db970>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a050f40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a06fc70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a0d8af0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a050f10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0cdf70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0e88b0>,
#  <keras.layers.core.activation.Activation at 0x1930a050430>,
#  <keras.layers.core.activation.Activation at 0x1930a0cd310>,
#  <keras.layers.core.activation.Activation at 0x1930a0e88e0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1930a0e3a60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a0f1b20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a06f520>,
#  <keras.layers.core.activation.Activation at 0x1930a0f6430>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a0f5b20>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x1930a0e3d60>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x1930a0ff0d0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1930a10b7c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a111b20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0f59a0>,
#  <keras.layers.core.activation.Activation at 0x1930a0e86d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a11bee0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a05aa90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a1206d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0b0280>,
#  <keras.layers.core.activation.Activation at 0x1930a120a00>,
#  <keras.layers.core.activation.Activation at 0x1930a067dc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a111520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a126d30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a120dc0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a111460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a12ea00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0db760>,
#  <keras.layers.core.activation.Activation at 0x1930a111bb0>,
#  <keras.layers.core.activation.Activation at 0x1930a12e490>,
#  <keras.layers.core.activation.Activation at 0x1930a0db7c0>,
#  <keras.layers.merging.concatenate.Concatenate at 0x1930a136e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a139d60>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1930a0ff070>,
#  <keras.layers.core.activation.Activation at 0x1930a139f70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1930a136b80>]

# %%
layers = [type(layer) for layer in model.layers]

# %%
from collections import Counter

item_occurrence = Counter(layers)

# Printing the occurrence of each item
for item, occurrence in item_occurrence.items():
    print(f"{item}: {occurrence}")
# Out:
# <class 'keras.engine.input_layer.InputLayer'>: 1
# <class 'keras.layers.convolutional.conv2d.Conv2D'>: 67
# <class 'keras.layers.normalization.batch_normalization.BatchNormalization'>: 63
# <class 'keras.layers.core.activation.Activation'>: 63
# <class 'keras.layers.merging.concatenate.Concatenate'>: 12
# <class 'keras.layers.pooling.max_pooling2d.MaxPooling2D'>: 4
# <class 'keras.layers.convolutional.conv2d_transpose.Conv2DTranspose'>: 3
# <class 'keras.layers.reshaping.up_sampling2d.UpSampling2D'>: 3

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
#
# File c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File C:\Users\ABDULM~1\AppData\Local\Temp\__autograph_generated_filemg37qila.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File C:\Users\ABDULM~1\AppData\Local\Temp\__autograph_generated_filern9eevdn.py:12, in outer_factory.<locals>.inner_factory.<locals>.tf____call__(self, gt, pr)
#      10 try:
#      11     do_return = True
# ---> 12     retval_ = ag__.converted_call(ag__.ld(self).l1, (ag__.ld(gt), ag__.ld(pr)), None, fscope) + ag__.converted_call(ag__.ld(self).l2, (ag__.ld(gt), ag__.ld(pr)), None, fscope)
#      13 except:
#      14     do_return = False
#
# File C:\Users\ABDULM~1\AppData\Local\Temp\__autograph_generated_fileeqeyt4zo.py:12, in outer_factory.<locals>.inner_factory.<locals>.tf____call__(self, gt, pr)
#      10 try:
#      11     do_return = True
# ---> 12     retval_ = ag__.converted_call(ag__.ld(F).binary_crossentropy, (ag__.ld(gt), ag__.ld(pr)), dict(**ag__.ld(self).submodules), fscope)
#      13 except:
#      14     do_return = False
#
# File C:\Users\ABDULM~1\AppData\Local\Temp\__autograph_generated_filez_6i2fny.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__binary_crossentropy(gt, pr, **kwargs)
#      11 try:
#      12     do_return = True
# ---> 13     retval_ = ag__.converted_call(ag__.ld(backend).mean, (ag__.converted_call(ag__.ld(backend).binary_crossentropy, (ag__.ld(gt), ag__.ld(pr)), None, fscope),), None, fscope)
#      14 except:
#      15     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\training.py", line 1051, in train_function  *
#         return step_function(self, iterator)
#     File "c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\segmentation_models\base\objects.py", line 114, in __call__  *
#         return self.l1(gt, pr) + self.l2(gt, pr)
#     File "c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\segmentation_models\losses.py", line 130, in __call__  *
#         return F.binary_crossentropy(gt, pr, **self.submodules)
#     File "c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\segmentation_models\base\functional.py", line 256, in binary_crossentropy  *
#         return backend.mean(backend.binary_crossentropy(gt, pr))
#     File "c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\backend.py", line 5283, in binary_crossentropy
#         return tf.nn.sigmoid_cross_entropy_with_logits(labels=target, logits=output)
#
#     ValueError: `logits` and `labels` must have the same shape, received ((None, 64, 64, 10) vs (None, 128, 128, 10)).

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  49.90936815738678 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 7s 122ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.6763176
# IoU for each class:
# Building Flooded: 0.7217684388160706
# Building Non-Flooded: 0.7892397046089172
# Road Flooded: 0.6299803853034973
# Road Non-Flooded: 0.8180097341537476
# Water: 0.7891194224357605
# Tree: 0.8191736936569214
# Vehicle: 0.3988760709762573
# Pool: 0.4768211841583252
# Grass: 0.8938656449317932
# Mean IoU (excluding Background): 0.7040949

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names, class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
