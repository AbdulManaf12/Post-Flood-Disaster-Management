# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'efficientnetb7'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')
# Out:
#   0%|          | 0/1445 [00:00<?, ?it/s]
# 100%|██████████| 1445/1445 [06:42<00:00,  3.59it/s]
# TRAIN: Images loaded: 1445
# TRAIN: Masks loaded: 1445
# 100%|██████████| 450/450 [02:04<00:00,  3.62it/s]
# VAL: Images loaded: 450
# VAL: Masks loaded: 450

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = f'../../dataset/train_and_val_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

val_seperate_images = val_images
val_seperate_masks = val_masks
# Out:
# Data saved to ../../dataset/train_and_val_data(128x128).pickle
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
pickle_file_path = f'../../dataset/train_and_val_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
num = 90
display_images_with_masks(train_images[num], train_masks[num], train_masks[num])

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
if MODEL == 'unet':
    model = sm.Unet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'fpn':
    model = sm.FPN(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
else:
    raise ValueError('Unknown model')

model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 64, 64, 64)   1728        ['input_1[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 64, 64, 64)   256         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 64, 64, 64)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 64, 64, 64)  576         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 64, 64, 64)  256         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 64, 64, 64)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 64)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 16)     1040        ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 64)     1088        ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 64, 64, 64)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 64, 64, 32)   2048        ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 64, 64, 32)  128         ['block1a_project_conv[0][0]']
#  lization)
#
#  block1b_dwconv (DepthwiseConv2  (None, 64, 64, 32)  288         ['block1a_project_bn[0][0]']
#  D)
#
#  block1b_bn (BatchNormalization  (None, 64, 64, 32)  128         ['block1b_dwconv[0][0]']
#  )
#
#  block1b_activation (Activation  (None, 64, 64, 32)  0           ['block1b_bn[0][0]']
#  )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 64, 64, 32)   0           ['block1b_activation[0][0]',
#                                                                   'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 64, 64, 32)   1024        ['block1b_se_excite[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 64, 64, 32)  128         ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_drop (FixedDropout)    (None, 64, 64, 32)   0           ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)              (None, 64, 64, 32)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 64, 64, 32)  288         ['block1b_add[0][0]']
#  D)
#
#  block1c_bn (BatchNormalization  (None, 64, 64, 32)  128         ['block1c_dwconv[0][0]']
#  )
#
#  block1c_activation (Activation  (None, 64, 64, 32)  0           ['block1c_bn[0][0]']
#  )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 64, 64, 32)   0           ['block1c_activation[0][0]',
#                                                                   'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 64, 64, 32)   1024        ['block1c_se_excite[0][0]']
#
#  block1c_project_bn (BatchNorma  (None, 64, 64, 32)  128         ['block1c_project_conv[0][0]']
#  lization)
#
#  block1c_drop (FixedDropout)    (None, 64, 64, 32)   0           ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)              (None, 64, 64, 32)   0           ['block1c_drop[0][0]',
#                                                                   'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseConv2  (None, 64, 64, 32)  288         ['block1c_add[0][0]']
#  D)
#
#  block1d_bn (BatchNormalization  (None, 64, 64, 32)  128         ['block1d_dwconv[0][0]']
#  )
#
#  block1d_activation (Activation  (None, 64, 64, 32)  0           ['block1d_bn[0][0]']
#  )
#
#  block1d_se_squeeze (GlobalAver  (None, 32)          0           ['block1d_activation[0][0]']
#  agePooling2D)
#
#  block1d_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1d_se_squeeze[0][0]']
#
#  block1d_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multiply)   (None, 64, 64, 32)   0           ['block1d_activation[0][0]',
#                                                                   'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 64, 64, 32)   1024        ['block1d_se_excite[0][0]']
#
#  block1d_project_bn (BatchNorma  (None, 64, 64, 32)  128         ['block1d_project_conv[0][0]']
#  lization)
#
#  block1d_drop (FixedDropout)    (None, 64, 64, 32)   0           ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)              (None, 64, 64, 32)   0           ['block1d_drop[0][0]',
#                                                                   'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 64, 64, 192)  6144        ['block1d_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 64, 64, 192)  768        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 64, 64, 192)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv (DepthwiseConv2  (None, 32, 32, 192)  1728       ['block2a_expand_activation[0][0]
#  D)                                                              ']
#
#  block2a_bn (BatchNormalization  (None, 32, 32, 192)  768        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 32, 32, 192)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 32, 32, 192)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 32, 32, 48)   9216        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 32, 32, 288)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 32, 32, 288)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 288)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 32, 32, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 32, 32, 288)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 32, 32, 288)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 288)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 32, 32, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 32, 32, 288)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 32, 32, 288)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 288)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 32, 32, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 32, 32, 288)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2e_expand_activation[0][0]
#  D)                                                              ']
#
#  block2e_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2e_dwconv[0][0]']
#  )
#
#  block2e_activation (Activation  (None, 32, 32, 288)  0          ['block2e_bn[0][0]']
#  )
#
#  block2e_se_squeeze (GlobalAver  (None, 288)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2e_activation[0][0]',
#                                                                   'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2e_se_excite[0][0]']
#
#  block2e_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 32, 32, 48)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 32, 32, 288)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2f_expand_activation[0][0]
#  D)                                                              ']
#
#  block2f_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2f_dwconv[0][0]']
#  )
#
#  block2f_activation (Activation  (None, 32, 32, 288)  0          ['block2f_bn[0][0]']
#  )
#
#  block2f_se_squeeze (GlobalAver  (None, 288)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2f_activation[0][0]',
#                                                                   'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2f_se_excite[0][0]']
#
#  block2f_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)              (None, 32, 32, 48)   0           ['block2f_drop[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 32, 32, 288)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2g_expand_activation[0][0]
#  D)                                                              ']
#
#  block2g_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2g_dwconv[0][0]']
#  )
#
#  block2g_activation (Activation  (None, 32, 32, 288)  0          ['block2g_bn[0][0]']
#  )
#
#  block2g_se_squeeze (GlobalAver  (None, 288)         0           ['block2g_activation[0][0]']
#  agePooling2D)
#
#  block2g_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2g_se_squeeze[0][0]']
#
#  block2g_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2g_activation[0][0]',
#                                                                   'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2g_se_excite[0][0]']
#
#  block2g_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)              (None, 32, 32, 48)   0           ['block2g_drop[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 32, 32, 288)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv (DepthwiseConv2  (None, 16, 16, 288)  7200       ['block3a_expand_activation[0][0]
#  D)                                                              ']
#
#  block3a_bn (BatchNormalization  (None, 16, 16, 288)  1152       ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 16, 16, 288)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 288)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 16, 16, 288)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 16, 16, 80)   23040       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 16, 16, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 16, 16, 480)  38400       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 16, 16, 480)  1920       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 16, 16, 480)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 16, 16, 480)  12000      ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 16, 16, 480)  1920       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 16, 16, 480)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 480)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 16, 16, 480)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 16, 16, 80)   38400       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 16, 16, 80)  320         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (FixedDropout)    (None, 16, 16, 80)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 16, 16, 80)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 16, 16, 480)  38400       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 16, 16, 480)  1920       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 16, 16, 480)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 16, 16, 480)  12000      ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 16, 16, 480)  1920       ['block3c_dwconv[0][0]']
# ...
#
#  block7d_bn (BatchNormalization  (None, 4, 4, 3840)  15360       ['block7d_dwconv[0][0]']
#  )
#
#  block7d_activation (Activation  (None, 4, 4, 3840)  0           ['block7d_bn[0][0]']
#  )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 4, 4, 3840)   0           ['block7d_activation[0][0]',
#                                                                   'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 4, 4, 640)    2457600     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 4, 4, 640)   2560        ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (FixedDropout)    (None, 4, 4, 640)    0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 4, 4, 640)    0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  top_conv (Conv2D)              (None, 4, 4, 2560)   1638400     ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 4, 4, 2560)   10240       ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 4, 4, 2560)   0           ['top_bn[0][0]']
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 2560)  0           ['top_activation[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 3904)  0           ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block6a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage0a_conv (Conv2D)  (None, 8, 8, 256)    8994816     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 8, 8, 256)    589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 736)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block4a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage1a_conv (Conv2D)  (None, 16, 16, 128)  847872      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 16, 16, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 416)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block3a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage2a_conv (Conv2D)  (None, 32, 32, 64)   239616      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 32, 32, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64)  0           ['decoder_stage2b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 256)  0          ['decoder_stage3_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block2a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 32)   73728       ['decoder_stage3_concat[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3b_conv (Conv2D)  (None, 64, 64, 32)   9216        ['decoder_stage3a_relu[0][0]']
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3b_conv[0][0]']
#  lization)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3b_bn[0][0]']
#  on)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 128, 128, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 128, 128, 10  1450        ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  softmax (Activation)           (None, 128, 128, 10  0           ['final_conv[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 75,049,402
# Trainable params: 74,736,698
# Non-trainable params: 312,704
# __________________________________________________________________________________________________

# %%
len(model.layers)
# Out:
# 847

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x2a52e8b8220>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8b8160>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e8b8fa0>,
#  <keras.layers.core.activation.Activation at 0x2a52e8b8b20>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e8eb3d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ed09940>,
#  <keras.layers.core.activation.Activation at 0x2a7c87c76a0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e8ad490>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e2e5d30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e2d8b20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e2d87f0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e380040>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e345280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e380e50>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e30d580>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e3180d0>,
#  <keras.layers.core.activation.Activation at 0x2a52e318d90>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e321580>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e332b20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e332ee0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e3324c0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e372bb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e328040>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e372e80>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a51e289b20>,
#  <keras.layers.merging.add.Add at 0x2a52e3214c0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e3a6760>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cca5baf0>,
#  <keras.layers.core.activation.Activation at 0x2a51dfff8b0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e372970>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a7cc982a60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cca4dc40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cca4dfd0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a7cca4d0a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e3a6880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e3211f0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e356f40>,
#  <keras.layers.merging.add.Add at 0x2a52e321f40>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e2e5fd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e2e5340>,
#  <keras.layers.core.activation.Activation at 0x2a52e2e5d90>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e328dc0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a51e273820>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e63a4c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e63a430>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e60cf40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e6409a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e640220>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a7cc9e5b50>,
#  <keras.layers.merging.add.Add at 0x2a7cc9e5520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc9e50a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e613b50>,
#  <keras.layers.core.activation.Activation at 0x2a52e63a670>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e64f280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e2218b0>,
#  <keras.layers.core.activation.Activation at 0x2a52e221cd0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e5f9130>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e5f0040>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc96f160>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e662310>,
#  <keras.layers.merging.multiply.Multiply at 0x2a7cc91bd60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52030f8b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cc923520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc9236a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a51e051880>,
#  <keras.layers.core.activation.Activation at 0x2a51cf85880>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a7cc990be0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5697fe0a0>,
#  <keras.layers.core.activation.Activation at 0x2a7cc850c70>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a7cc811af0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a7cc880190>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc8801c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc8806d0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a51dff51c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e5f93a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cc850e20>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e60cee0>,
#  <keras.layers.merging.add.Add at 0x2a7cc969ca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e6130a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e613d30>,
#  <keras.layers.core.activation.Activation at 0x2a7c888d3d0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a7c888d2b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5e5eeccd0>,
#  <keras.layers.core.activation.Activation at 0x2a7cc909580>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a5e458aa90>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a7c88658e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a522c1f730>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a51cf3a1f0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a51e0c19a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a51e096310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a51e0966a0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a51e09e5e0>,
#  <keras.layers.merging.add.Add at 0x2a51e096640>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5e45f5850>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5e45f59d0>,
#  <keras.layers.core.activation.Activation at 0x2a51cf342e0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a51e0c4a30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5e45f5940>,
#  <keras.layers.core.activation.Activation at 0x2a52e20b6d0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e969bb0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e220910>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e22c8e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e22c640>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e22c850>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ecd76d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ecc68e0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52ecc6ee0>,
#  <keras.layers.merging.add.Add at 0x2a52ecc6c40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ece51f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ecc7880>,
#  <keras.layers.core.activation.Activation at 0x2a51e0c4ac0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52ecc7730>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ecc7c10>,
#  <keras.layers.core.activation.Activation at 0x2a52ecc7af0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a51e096280>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52ece5fa0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a51e0c1190>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e625e50>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e658d30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ece5a00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e22caf0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a51cf95250>,
#  <keras.layers.merging.add.Add at 0x2a52ecbf9a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ecc92e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ecc9c40>,
#  <keras.layers.core.activation.Activation at 0x2a51e09efd0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52ecc9f70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5e458a5b0>,
#  <keras.layers.core.activation.Activation at 0x2a52e8d1a60>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e8d83d0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a51e0c1f40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8d8520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8d8e20>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e8e78b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8d8130>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e60c4f0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e3adee0>,
#  <keras.layers.merging.add.Add at 0x2a52ecc9100>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8d2700>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e8b7340>,
#  <keras.layers.core.activation.Activation at 0x2a52e8e73d0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e381cd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e3810d0>,
#  <keras.layers.core.activation.Activation at 0x2a52e381ca0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e38e8e0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e38e400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e392700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e373cd0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e373a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8e7460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cc9c17f0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e37a310>,
#  <keras.layers.merging.add.Add at 0x2a52e37ae20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e373460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e8e92b0>,
#  <keras.layers.core.activation.Activation at 0x2a52e373f10>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e8d2250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e969940>,
#  <keras.layers.core.activation.Activation at 0x2a52e8d2190>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ecb3df0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a5e45f5520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc9b7df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc9b7b80>,
#  <keras.layers.merging.multiply.Multiply at 0x2a7cc9bc160>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e373ee0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e241eb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ecb3cd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e266850>,
#  <keras.layers.core.activation.Activation at 0x2a52e241310>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a5e45f54c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cc9b7160>,
#  <keras.layers.core.activation.Activation at 0x2a52e245a90>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a7c888b8b0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a7c888b670>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7c8897280>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7c8897be0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a7c888b8e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7c889edf0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e2413a0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a7c8897d00>,
#  <keras.layers.merging.add.Add at 0x2a52e26b790>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e300160>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7c887ab50>,
#  <keras.layers.core.activation.Activation at 0x2a7c889ea00>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e300e20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7c88976d0>,
#  <keras.layers.core.activation.Activation at 0x2a52e6177c0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e317d60>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a7c8897190>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e317460>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e317730>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e327430>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e5fbd90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e300d00>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e300e50>,
#  <keras.layers.merging.add.Add at 0x2a7c8897760>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e2425b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e26bfa0>,
#  <keras.layers.core.activation.Activation at 0x2a52e3ad4c0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a7c887aa90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7c887ac70>,
#  <keras.layers.core.activation.Activation at 0x2a5e45f5490>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e87e790>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e32feb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e87e1f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e622550>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e8a9160>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8a4b50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ecb3f70>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e8a42b0>,
#  <keras.layers.merging.add.Add at 0x2a52e87e8e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8886d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e87beb0>,
#  <keras.layers.core.activation.Activation at 0x2a52e8a4520>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e87bc70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e8a9880>,
#  <keras.layers.core.activation.Activation at 0x2a52e36ee20>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a5e5f051c0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e87bbb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e36ed30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e36e910>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e33a700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e35bfd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e8a4e80>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e36fee0>,
#  <keras.layers.merging.add.Add at 0x2a52e34a670>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc9e8df0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cca063d0>,
#  <keras.layers.core.activation.Activation at 0x2a7cca06880>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a7cca0bfd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cca0b580>,
#  <keras.layers.core.activation.Activation at 0x2a52e35bb50>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a7cca0b040>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a7cca0b640>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e5ba310>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc9e8610>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e33a880>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e35b730>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cca1b4c0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e5fbca0>,
#  <keras.layers.merging.add.Add at 0x2a52e87ec70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cc9fb940>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e32f0a0>,
#  <keras.layers.core.activation.Activation at 0x2a52e36fbb0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e8a98e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e8a9970>,
#  <keras.layers.core.activation.Activation at 0x2a7cca1b400>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e5bdb80>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e5bd610>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e5e4d90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e5ed5b0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e5edb80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e35b1f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e5d56a0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a7cca29a30>,
#  <keras.layers.merging.add.Add at 0x2a52e5bdcd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cca2d2e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cca53070>,
#  <keras.layers.core.activation.Activation at 0x2a52e5d57c0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a7cca2dfa0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e5ed100>,
#  <keras.layers.core.activation.Activation at 0x2a7cca53280>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a7cca39a00>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a7cca399d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cca2b4f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cca2bd90>,
#  <keras.layers.merging.multiply.Multiply at 0x2a7cca39d30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cca2b820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e5d5a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cca4cb50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e2bcfa0>,
#  <keras.layers.core.activation.Activation at 0x2a52e2baaf0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e2e02b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e5a8b80>,
#  <keras.layers.core.activation.Activation at 0x2a52e2bf2b0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e5a8190>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e2e9fd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e2bcf70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e5b4f40>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e5ede20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cca4cb20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a7cca1bb50>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e2bab80>,
#  <keras.layers.merging.add.Add at 0x2a52e89cee0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e87bdf0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e5c8550>,
#  <keras.layers.core.activation.Activation at 0x2a52e2bf8b0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e2e9f10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e8a9b80>,
#  <keras.layers.core.activation.Activation at 0x2a52e2ba640>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e57a0d0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e2bcd60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e59a580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e59ae50>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e589e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e58b2b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e59f4f0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e2803a0>,
#  <keras.layers.merging.add.Add at 0x2a52e582130>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e280c40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e589400>,
#  <keras.layers.core.activation.Activation at 0x2a52e5899a0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e2a49d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e270610>,
#  <keras.layers.core.activation.Activation at 0x2a52e2a42b0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e2a4a30>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e58b490>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e29c190>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e29c160>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e28bdc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e677d90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e589a30>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e28ba30>,
#  <keras.layers.merging.add.Add at 0x2a52e29c0a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e689790>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e693340>,
#  <keras.layers.core.activation.Activation at 0x2a52e682be0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e6821c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e280fa0>,
#  <keras.layers.core.activation.Activation at 0x2a52e2a4700>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e2809d0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e58b8b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e57a1f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a7cca53310>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e57a5e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e69edf0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e28bd30>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a7cca39730>,
#  <keras.layers.merging.add.Add at 0x2a52e58bac0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e6931f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e6a4b50>,
#  <keras.layers.core.activation.Activation at 0x2a52e69ea00>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e6b0f10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e6b69a0>,
#  <keras.layers.core.activation.Activation at 0x2a52e6a9b80>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e6b6040>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e28c7f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e6cbdc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e6cb6d0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e6e0790>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e69ea90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e6c1430>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e6eedc0>,
#  <keras.layers.merging.add.Add at 0x2a52e6b0370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e6c1e20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e6cb070>,
#  <keras.layers.core.activation.Activation at 0x2a52e6e02b0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e6f6bb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e6cb100>,
#  <keras.layers.core.activation.Activation at 0x2a52e6f6b80>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e70e820>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e70e520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e70eeb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7035e0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e7171f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e71dbe0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e7326d0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e72beb0>,
#  <keras.layers.merging.add.Add at 0x2a52e72bdc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7325b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e6e9e50>,
#  <keras.layers.core.activation.Activation at 0x2a52e71ddf0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e7320a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e589550>,
#  <keras.layers.core.activation.Activation at 0x2a52e6e9190>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e2707c0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e2805b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e744cd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e744550>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e73d070>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e744f70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e71ddc0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e744f40>,
#  <keras.layers.merging.add.Add at 0x2a7cca4cd30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e759970>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e756340>,
#  <keras.layers.core.activation.Activation at 0x2a52e744fa0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e761c40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e765be0>,
#  <keras.layers.core.activation.Activation at 0x2a52e7657c0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e77ec10>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e73d9a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7615b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e77ed60>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e77e520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e74a280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e7866d0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e79da60>,
#  <keras.layers.merging.add.Add at 0x2a52e776d00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7a7310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e786f40>,
#  <keras.layers.core.activation.Activation at 0x2a52e786a60>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e7a7fd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e776df0>,
#  <keras.layers.core.activation.Activation at 0x2a52e7a7490>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e7bea30>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e7bea00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7c9520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7b9e50>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e7a7b80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7ad2b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e794bb0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e7c9dc0>,
#  <keras.layers.merging.add.Add at 0x2a52e7567f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e6d2730>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e71d340>,
#  <keras.layers.core.activation.Activation at 0x2a52e7b9160>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e6e9880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e7c9970>,
#  <keras.layers.core.activation.Activation at 0x2a52e7cf190>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e7e02e0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e7c9310>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7ec580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7ece50>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e7f0e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7adc70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e7e3340>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8073a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e7f0400>,
#  <keras.layers.core.activation.Activation at 0x2a52e7f09a0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e807c40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e7ec8e0>,
#  <keras.layers.core.activation.Activation at 0x2a52e80e310>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e7fdd60>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e827310>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8274f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8277c0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e82edf0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7f0a30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e81c760>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e987040>,
#  <keras.layers.merging.add.Add at 0x2a52e8140a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e987bb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e98e460>,
#  <keras.layers.core.activation.Activation at 0x2a52e82e910>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e998b80>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e98e580>,
#  <keras.layers.core.activation.Activation at 0x2a52e9aa220>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e9aa2b0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e9a0be0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e9aa550>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e9aa100>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e97bc40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7ecc70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e807f40>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e7611c0>,
#  <keras.layers.merging.add.Add at 0x2a52e9a0fd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e9b5760>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e9ba310>,
#  <keras.layers.core.activation.Activation at 0x2a52e7e3400>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e9ba400>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e998220>,
#  <keras.layers.core.activation.Activation at 0x2a52e9c55b0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52e9cad60>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e9ba6a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e9b5700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e9d2d00>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e9ba700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e9d2c40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e7e3a90>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e9d2c10>,
#  <keras.layers.merging.add.Add at 0x2a52e9cafa0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e9f7610>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e9e8fa0>,
#  <keras.layers.core.activation.Activation at 0x2a52e9dae20>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52e9ba730>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e9d2ca0>,
#  <keras.layers.core.activation.Activation at 0x2a52ea00460>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ea208b0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e9d2640>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ea20c40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ea20220>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52ea20040>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ea24c10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e9daee0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52ea24370>,
#  <keras.layers.merging.add.Add at 0x2a52ea119a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ea3dfd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ea4ba90>,
#  <keras.layers.core.activation.Activation at 0x2a52ea35a60>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52ea4b670>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ea0b5b0>,
#  <keras.layers.core.activation.Activation at 0x2a52ea0b9a0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ea00070>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52ea204c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e7fd310>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e9b5460>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52e9c5370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ea4d160>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ea35850>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52e9b5670>,
#  <keras.layers.merging.add.Add at 0x2a52e9f74f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ea62ac0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ea5e490>,
#  <keras.layers.core.activation.Activation at 0x2a52ea4d340>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52ea20490>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e9ca160>,
#  <keras.layers.core.activation.Activation at 0x2a52ea6ad90>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ea72be0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52e9dacd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ea88850>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ea88790>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52ea8c280>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ea4d3d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ea7a9d0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52eaa75b0>,
#  <keras.layers.merging.add.Add at 0x2a52ea8c610>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eaa7e50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eaa7f70>,
#  <keras.layers.core.activation.Activation at 0x2a52ea8cb80>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52eab89a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ea88af0>,
#  <keras.layers.core.activation.Activation at 0x2a52eab84c0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52eac8160>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52ea7a3d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eac8a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eac8310>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52eac8af0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eadefa0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eae8fd0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52eae8a90>,
#  <keras.layers.merging.add.Add at 0x2a52eac82b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ead4370>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ea624c0>,
#  <keras.layers.core.activation.Activation at 0x2a52eadeee0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52eaad160>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52e9b53d0>,
#  <keras.layers.core.activation.Activation at 0x2a52ea6a730>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ea88c70>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52eaefc40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eabf490>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eafb7c0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52eaefc70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eafb910>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eadeb20>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52eafbcd0>,
#  <keras.layers.merging.add.Add at 0x2a52e9ee040>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb192b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eb12280>,
#  <keras.layers.core.activation.Activation at 0x2a52eaffaf0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52eb2a0d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eafb940>,
#  <keras.layers.core.activation.Activation at 0x2a52eb20040>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52eb19c40>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52eb31e50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb31b50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb47880>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52eb314f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb47040>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eaffb80>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52eb47100>,
#  <keras.layers.merging.add.Add at 0x2a52eb31640>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb52a00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eb19dc0>,
#  <keras.layers.core.activation.Activation at 0x2a52eb47e80>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52eb629d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eb5a3d0>,
#  <keras.layers.core.activation.Activation at 0x2a52eb3e7c0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52eb75700>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52eb2a7c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb85eb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb75fa0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52eb629a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb75f70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eb524f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb75400>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eb85040>,
#  <keras.layers.core.activation.Activation at 0x2a52eb85190>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52eafb490>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eb19190>,
#  <keras.layers.core.activation.Activation at 0x2a52eb852b0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52eafbc10>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52eafbb20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb9b3d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb19d30>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52eb93f10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb68880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eba4ee0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52ebb9b20>,
#  <keras.layers.merging.add.Add at 0x2a52ebb9ee0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ebc2820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eb93bb0>,
#  <keras.layers.core.activation.Activation at 0x2a52eb935b0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52eb9bf10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eba0eb0>,
#  <keras.layers.core.activation.Activation at 0x2a52ebcb0d0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ebb9c70>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52eba0850>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ebe74f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ebe7bb0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52ebeddf0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ebb2130>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ebdaa30>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52ec04040>,
#  <keras.layers.merging.add.Add at 0x2a52ebd50a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ec04bb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ec0b460>,
#  <keras.layers.core.activation.Activation at 0x2a52ebed910>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52ec18b80>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ec0b580>,
#  <keras.layers.core.activation.Activation at 0x2a52ec29100>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ec29160>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52ec21a60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ec29550>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ec29220>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52ebb2e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ebb9ca0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52eb195b0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52eb31c10>,
#  <keras.layers.merging.add.Add at 0x2a52ec21fd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eba46d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ebda9d0>,
#  <keras.layers.core.activation.Activation at 0x2a52ebb9d00>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52ec35d60>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ec18a00>,
#  <keras.layers.core.activation.Activation at 0x2a52ec38f10>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ec4a700>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52ec4a580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ec501f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ec504c0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52ec4a7f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ec50700>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ebb92e0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52ec50310>,
#  <keras.layers.merging.add.Add at 0x2a52ec42790>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ec758b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ec75dc0>,
#  <keras.layers.core.activation.Activation at 0x2a52ec5d7f0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52ec4a610>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ec7eac0>,
#  <keras.layers.core.activation.Activation at 0x2a52ec50640>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ec75940>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52ec4afa0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ec8f640>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52ec8f430>,
#  <keras.layers.merging.multiply.Multiply at 0x2a52ec8f1f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eca8370>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ec5d880>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52ec9e430>,
#  <keras.layers.merging.add.Add at 0x2a52ec8f340>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5341a3760>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5341b25e0>,
#  <keras.layers.core.activation.Activation at 0x2a52eca8e50>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52ec6cb20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5341a3340>,
#  <keras.layers.core.activation.Activation at 0x2a52eca8310>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a52ec64580>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52ec8fe50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eb9bd90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52eba03a0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a5341a9d60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5341bfa30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5341a31f0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a52eba4ca0>,
#  <keras.layers.merging.add.Add at 0x2a5341c9b20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5341d1460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5341c9e20>,
#  <keras.layers.core.activation.Activation at 0x2a5341bfc70>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a52ec5d250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a52ec4a250>,
#  <keras.layers.core.activation.Activation at 0x2a5341e5eb0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a5341e5370>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a52ec42df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5341eb4f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5341eba90>,
#  <keras.layers.merging.multiply.Multiply at 0x2a534202a30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5341bfd30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5341d96a0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a534214550>,
#  <keras.layers.merging.add.Add at 0x2a5341c9550>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342147f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534202100>,
#  <keras.layers.core.activation.Activation at 0x2a534202550>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a5341f62b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a53421b820>,
#  <keras.layers.core.activation.Activation at 0x2a53421be20>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a53422eac0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a53422e550>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534227880>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53423ce50>,
#  <keras.layers.merging.multiply.Multiply at 0x2a53423a490>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342025e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534258970>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a53423a1f0>,
#  <keras.layers.merging.add.Add at 0x2a53423ac40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534227280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5342083d0>,
#  <keras.layers.core.activation.Activation at 0x2a53423c0d0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a5342585e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5341d9f70>,
#  <keras.layers.core.activation.Activation at 0x2a534208280>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a534214580>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a5341c4f40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534227a60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53426ad90>,
#  <keras.layers.merging.multiply.Multiply at 0x2a5342602e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53426edc0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a53423cfd0>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a53426a1f0>,
#  <keras.layers.merging.add.Add at 0x2a5341c4ca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534288730>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a53427ec40>,
#  <keras.layers.core.activation.Activation at 0x2a53426e490>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a53428df70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a53428d640>,
#  <keras.layers.core.activation.Activation at 0x2a53427e100>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a5342a3eb0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a534260c40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342a3520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342a34c0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a53429af40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342ad160>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a53426e520>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a5342ad970>,
#  <keras.layers.merging.add.Add at 0x2a53429afa0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342ca6d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5342d2280>,
#  <keras.layers.core.activation.Activation at 0x2a5342ad130>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a5342d2370>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5342ad1f0>,
#  <keras.layers.core.activation.Activation at 0x2a5342dd520>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a5342e2cd0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a5342d2730>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342e57c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342d2b20>,
#  <keras.layers.merging.multiply.Multiply at 0x2a5342ca9d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342b8e50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534288520>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a534288640>,
#  <keras.layers.merging.add.Add at 0x2a5342796a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342d2130>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5342087f0>,
#  <keras.layers.core.activation.Activation at 0x2a5342dd220>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a5342d26a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5342e5c10>,
#  <keras.layers.core.activation.Activation at 0x2a5342f5b80>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a534306c10>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a5342e55b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53429a610>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534310880>,
#  <keras.layers.merging.multiply.Multiply at 0x2a5343172b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5342dd3d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534309070>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a53432e2e0>,
#  <keras.layers.merging.add.Add at 0x2a5342f50d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53432ee80>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5343340d0>,
#  <keras.layers.core.activation.Activation at 0x2a534317bb0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a53433e9d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534310b20>,
#  <keras.layers.core.activation.Activation at 0x2a53433e4f0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a534350190>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a534309220>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534350a30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534346bb0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a534350b20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534364160>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534317c70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5343502e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a53436e6d0>,
#  <keras.layers.core.activation.Activation at 0x2a534364f10>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a5343808b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a53435a280>,
#  <keras.layers.core.activation.Activation at 0x2a5343808e0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a5343926d0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a534374850>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5343924f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53426e0d0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a53433ea00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53432e9a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534208460>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a534364b50>,
#  <keras.layers.merging.add.Add at 0x2a534392910>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53439a9a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5343346d0>,
#  <keras.layers.core.activation.Activation at 0x2a53432e130>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a534321970>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534388040>,
#  <keras.layers.core.activation.Activation at 0x2a5343a97f0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a5343a3ee0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a5343a3670>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5343219a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5343a9e80>,
#  <keras.layers.merging.multiply.Multiply at 0x2a5343a9a30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53432ea30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5343bdf10>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a5343c9ee0>,
#  <keras.layers.merging.add.Add at 0x2a5343d5f10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5343dc850>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5343d5220>,
#  <keras.layers.core.activation.Activation at 0x2a53439af10>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a5343a3b80>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5343b7ee0>,
#  <keras.layers.core.activation.Activation at 0x2a5343eceb0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a5343d5820>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a5343b7880>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534401520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534401be0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a534408e20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5343c9160>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5343f6c40>,
#  <efficientnet.model.get_dropout.<locals>.FixedDropout at 0x2a53441e340>,
#  <keras.layers.merging.add.Add at 0x2a5343ec0d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e88f4c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534346eb0>,
#  <keras.layers.core.activation.Activation at 0x2a534408940>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x2a534433280>,
#  <keras.layers.merging.concatenate.Concatenate at 0x2a5dfc81c10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53449e1f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a53441ecd0>,
#  <keras.layers.core.activation.Activation at 0x2a534408820>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53449e940>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a53449e910>,
#  <keras.layers.core.activation.Activation at 0x2a5e45f53d0>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x2a5e457f850>,
#  <keras.layers.merging.concatenate.Concatenate at 0x2a53441e880>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534545220>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a5345452e0>,
#  <keras.layers.core.activation.Activation at 0x2a53442cbb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a5345450d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534545d30>,
#  <keras.layers.core.activation.Activation at 0x2a534444070>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x2a534545040>,
#  <keras.layers.merging.concatenate.Concatenate at 0x2a53442ccd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a538128640>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534444730>,
#  <keras.layers.core.activation.Activation at 0x2a53442cd90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534550820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a534440dc0>,
#  <keras.layers.core.activation.Activation at 0x2a534440f70>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x2a53442cf40>,
#  <keras.layers.merging.concatenate.Concatenate at 0x2a534550a30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a538138fa0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a538138490>,
#  <keras.layers.core.activation.Activation at 0x2a534440760>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53455f850>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a538150310>,
#  <keras.layers.core.activation.Activation at 0x2a538145b50>,
#  <keras.layers.reshaping.up_sampling2d.UpSampling2D at 0x2a538138cd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a534550040>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a538150850>,
#  <keras.layers.core.activation.Activation at 0x2a538131fa0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a53455fa60>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a538128eb0>,
#  <keras.layers.core.activation.Activation at 0x2a538131cd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a52e8b8550>,
#  <keras.layers.core.activation.Activation at 0x2a52e8b8c70>]

# %%
layers = [type(layer) for layer in model.layers]

# %%
from collections import Counter

item_occurrence = Counter(layers)

# Printing the occurrence of each item
for item, occurrence in item_occurrence.items():
    print(f"{item}: {occurrence}")
# Out:
# <class 'keras.engine.input_layer.InputLayer'>: 1
# <class 'keras.layers.convolutional.conv2d.Conv2D'>: 229
# <class 'keras.layers.normalization.batch_normalization.BatchNormalization'>: 173
# <class 'keras.layers.core.activation.Activation'>: 119
# <class 'keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D'>: 55
# <class 'keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D'>: 55
# <class 'keras.layers.reshaping.reshape.Reshape'>: 55
# <class 'keras.layers.merging.multiply.Multiply'>: 55
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'keras.layers.merging.add.Add'>: 48
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'efficientnet.model.get_dropout.<locals>.FixedDropout'>: 1
# <class 'keras.layers.reshaping.up_sampling2d.UpSampling2D'>: 5
# <class 'keras.layers.merging.concatenate.Concatenate'>: 4

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 99s 326ms/step - loss: 1.0120 - iou_score: 0.2093 - val_loss: 0.9601 - val_iou_score: 0.2063
# Epoch 2/100
# 181/181 [==============================] - 49s 273ms/step - loss: 0.7832 - iou_score: 0.3304 - val_loss: 0.9175 - val_iou_score: 0.2384
# Epoch 3/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.7247 - iou_score: 0.3760 - val_loss: 0.8036 - val_iou_score: 0.2978
# Epoch 4/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.6762 - iou_score: 0.4163 - val_loss: 0.8798 - val_iou_score: 0.2950
# Epoch 5/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.6517 - iou_score: 0.4364 - val_loss: 0.7617 - val_iou_score: 0.3301
# Epoch 6/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.6252 - iou_score: 0.4576 - val_loss: 0.7314 - val_iou_score: 0.3511
# Epoch 7/100
# 181/181 [==============================] - 50s 274ms/step - loss: 0.6162 - iou_score: 0.4675 - val_loss: 0.7488 - val_iou_score: 0.3427
# Epoch 8/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.5805 - iou_score: 0.4974 - val_loss: 0.7413 - val_iou_score: 0.3539
# Epoch 9/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.5776 - iou_score: 0.4986 - val_loss: 1.0116 - val_iou_score: 0.3110
# Epoch 10/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.5539 - iou_score: 0.5180 - val_loss: 0.7087 - val_iou_score: 0.3713
# Epoch 11/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.5391 - iou_score: 0.5297 - val_loss: 0.7691 - val_iou_score: 0.3342
# Epoch 12/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.5470 - iou_score: 0.5238 - val_loss: 0.7137 - val_iou_score: 0.3688
# Epoch 13/100
# 181/181 [==============================] - 51s 280ms/step - loss: 0.5370 - iou_score: 0.5316 - val_loss: 0.6919 - val_iou_score: 0.3864
# Epoch 14/100
# 181/181 [==============================] - 51s 281ms/step - loss: 0.5207 - iou_score: 0.5454 - val_loss: 0.6976 - val_iou_score: 0.3803
# Epoch 15/100
# 181/181 [==============================] - 51s 279ms/step - loss: 0.5071 - iou_score: 0.5545 - val_loss: 0.6965 - val_iou_score: 0.3823
# Epoch 16/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.5021 - iou_score: 0.5599 - val_loss: 0.6824 - val_iou_score: 0.3900
# Epoch 17/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.5051 - iou_score: 0.5574 - val_loss: 0.6966 - val_iou_score: 0.3806
# Epoch 18/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.4987 - iou_score: 0.5619 - val_loss: 0.7047 - val_iou_score: 0.3781
# Epoch 19/100
# 181/181 [==============================] - 50s 274ms/step - loss: 0.4936 - iou_score: 0.5661 - val_loss: 0.6896 - val_iou_score: 0.3912
# Epoch 20/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.4761 - iou_score: 0.5799 - val_loss: 0.6851 - val_iou_score: 0.3948
# Epoch 21/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.4776 - iou_score: 0.5796 - val_loss: 0.6800 - val_iou_score: 0.3954
# Epoch 22/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.4672 - iou_score: 0.5875 - val_loss: 0.6805 - val_iou_score: 0.3975
# Epoch 23/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.4571 - iou_score: 0.5974 - val_loss: 0.6739 - val_iou_score: 0.3975
# Epoch 24/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.4649 - iou_score: 0.5897 - val_loss: 0.6726 - val_iou_score: 0.3991
# Epoch 25/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.4538 - iou_score: 0.5964 - val_loss: 0.7007 - val_iou_score: 0.3802
# Epoch 26/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.4485 - iou_score: 0.6021 - val_loss: 0.6804 - val_iou_score: 0.3973
# Epoch 27/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.4365 - iou_score: 0.6111 - val_loss: 0.6708 - val_iou_score: 0.4020
# Epoch 28/100
# 181/181 [==============================] - 51s 280ms/step - loss: 0.4378 - iou_score: 0.6103 - val_loss: 0.6695 - val_iou_score: 0.4020
# Epoch 29/100
# 181/181 [==============================] - 50s 279ms/step - loss: 0.4306 - iou_score: 0.6157 - val_loss: 0.6629 - val_iou_score: 0.4099
# Epoch 30/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.4499 - iou_score: 0.6001 - val_loss: 0.7089 - val_iou_score: 0.3864
# Epoch 31/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.4308 - iou_score: 0.6157 - val_loss: 0.6656 - val_iou_score: 0.4055
# Epoch 32/100
# 181/181 [==============================] - 50s 274ms/step - loss: 0.4256 - iou_score: 0.6199 - val_loss: 0.6682 - val_iou_score: 0.4047
# Epoch 33/100
# 181/181 [==============================] - 49s 273ms/step - loss: 0.4185 - iou_score: 0.6253 - val_loss: 0.6782 - val_iou_score: 0.4000
# Epoch 34/100
# 181/181 [==============================] - 49s 273ms/step - loss: 0.4127 - iou_score: 0.6301 - val_loss: 0.6683 - val_iou_score: 0.4054
# Epoch 35/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.4128 - iou_score: 0.6282 - val_loss: 0.6682 - val_iou_score: 0.4056
# Epoch 36/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.4119 - iou_score: 0.6306 - val_loss: 0.6825 - val_iou_score: 0.3977
# Epoch 37/100
# 181/181 [==============================] - 50s 279ms/step - loss: 0.4074 - iou_score: 0.6345 - val_loss: 1.0168 - val_iou_score: 0.3195
# Epoch 38/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.4065 - iou_score: 0.6346 - val_loss: 0.6736 - val_iou_score: 0.4050
# Epoch 39/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.4040 - iou_score: 0.6359 - val_loss: 0.6638 - val_iou_score: 0.4098
# Epoch 40/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.4136 - iou_score: 0.6301 - val_loss: 0.7313 - val_iou_score: 0.3730
# Epoch 41/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.4042 - iou_score: 0.6365 - val_loss: 0.6746 - val_iou_score: 0.4018
# Epoch 42/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.4018 - iou_score: 0.6390 - val_loss: 0.6695 - val_iou_score: 0.4042
# Epoch 43/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.4085 - iou_score: 0.6345 - val_loss: 0.6659 - val_iou_score: 0.4070
# Epoch 44/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.3994 - iou_score: 0.6396 - val_loss: 0.6606 - val_iou_score: 0.4123
# Epoch 45/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.4010 - iou_score: 0.6383 - val_loss: 0.6704 - val_iou_score: 0.4091
# Epoch 46/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.4032 - iou_score: 0.6362 - val_loss: 0.6616 - val_iou_score: 0.4127
# Epoch 47/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3987 - iou_score: 0.6397 - val_loss: 0.6566 - val_iou_score: 0.4141
# Epoch 48/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3888 - iou_score: 0.6491 - val_loss: 0.6625 - val_iou_score: 0.4135
# Epoch 49/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3854 - iou_score: 0.6515 - val_loss: 0.6615 - val_iou_score: 0.4120
# Epoch 50/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3867 - iou_score: 0.6509 - val_loss: 0.6829 - val_iou_score: 0.4046
# Epoch 51/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3998 - iou_score: 0.6382 - val_loss: 0.7103 - val_iou_score: 0.3918
# Epoch 52/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.3859 - iou_score: 0.6503 - val_loss: 0.6706 - val_iou_score: 0.4059
# Epoch 53/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3802 - iou_score: 0.6571 - val_loss: 0.6566 - val_iou_score: 0.4147
# Epoch 54/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3655 - iou_score: 0.6694 - val_loss: 0.6601 - val_iou_score: 0.4152
# Epoch 55/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3730 - iou_score: 0.6607 - val_loss: 0.6771 - val_iou_score: 0.4052
# Epoch 56/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3749 - iou_score: 0.6599 - val_loss: 0.6765 - val_iou_score: 0.4052
# Epoch 57/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.3853 - iou_score: 0.6543 - val_loss: 0.6722 - val_iou_score: 0.4077
# Epoch 58/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3874 - iou_score: 0.6514 - val_loss: 0.6800 - val_iou_score: 0.4027
# Epoch 59/100
# 181/181 [==============================] - 50s 274ms/step - loss: 0.3734 - iou_score: 0.6611 - val_loss: 0.6572 - val_iou_score: 0.4153
# Epoch 60/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3696 - iou_score: 0.6639 - val_loss: 0.6732 - val_iou_score: 0.4076
# Epoch 61/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3580 - iou_score: 0.6747 - val_loss: 0.6644 - val_iou_score: 0.4125
# Epoch 62/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3623 - iou_score: 0.6688 - val_loss: 0.6678 - val_iou_score: 0.4098
# Epoch 63/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3616 - iou_score: 0.6713 - val_loss: 0.6608 - val_iou_score: 0.4136
# Epoch 64/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3675 - iou_score: 0.6663 - val_loss: 0.6688 - val_iou_score: 0.4114
# Epoch 65/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3656 - iou_score: 0.6678 - val_loss: 0.6668 - val_iou_score: 0.4091
# Epoch 66/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3607 - iou_score: 0.6718 - val_loss: 0.6679 - val_iou_score: 0.4126
# Epoch 67/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3594 - iou_score: 0.6727 - val_loss: 0.6690 - val_iou_score: 0.4141
# Epoch 68/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3614 - iou_score: 0.6720 - val_loss: 0.6954 - val_iou_score: 0.4013
# Epoch 69/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3659 - iou_score: 0.6682 - val_loss: 0.6782 - val_iou_score: 0.4082
# Epoch 70/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3587 - iou_score: 0.6735 - val_loss: 0.6701 - val_iou_score: 0.4100
# Epoch 71/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3568 - iou_score: 0.6748 - val_loss: 0.6694 - val_iou_score: 0.4113
# Epoch 72/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3600 - iou_score: 0.6734 - val_loss: 0.7070 - val_iou_score: 0.3923
# Epoch 73/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3623 - iou_score: 0.6721 - val_loss: 0.6646 - val_iou_score: 0.4137
# Epoch 74/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3660 - iou_score: 0.6671 - val_loss: 0.6653 - val_iou_score: 0.4157
# Epoch 75/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3607 - iou_score: 0.6715 - val_loss: 0.6628 - val_iou_score: 0.4181
# Epoch 76/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3495 - iou_score: 0.6806 - val_loss: 0.6578 - val_iou_score: 0.4177
# Epoch 77/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3471 - iou_score: 0.6822 - val_loss: 0.6638 - val_iou_score: 0.4166
# Epoch 78/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3648 - iou_score: 0.6680 - val_loss: 0.6693 - val_iou_score: 0.4118
# Epoch 79/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3393 - iou_score: 0.6897 - val_loss: 0.6901 - val_iou_score: 0.4022
# Epoch 80/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3563 - iou_score: 0.6745 - val_loss: 0.6702 - val_iou_score: 0.4121
# Epoch 81/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3440 - iou_score: 0.6855 - val_loss: 0.6809 - val_iou_score: 0.4107
# Epoch 82/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3489 - iou_score: 0.6802 - val_loss: 0.6644 - val_iou_score: 0.4141
# Epoch 83/100
# 181/181 [==============================] - 50s 275ms/step - loss: 0.3444 - iou_score: 0.6846 - val_loss: 0.6660 - val_iou_score: 0.4167
# Epoch 84/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3450 - iou_score: 0.6835 - val_loss: 0.6796 - val_iou_score: 0.4108
# Epoch 85/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3411 - iou_score: 0.6861 - val_loss: 0.6679 - val_iou_score: 0.4156
# Epoch 86/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3552 - iou_score: 0.6747 - val_loss: 0.6954 - val_iou_score: 0.4030
# Epoch 87/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3588 - iou_score: 0.6721 - val_loss: 0.6672 - val_iou_score: 0.4119
# Epoch 88/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3621 - iou_score: 0.6689 - val_loss: 0.6720 - val_iou_score: 0.4114
# Epoch 89/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3488 - iou_score: 0.6792 - val_loss: 0.6731 - val_iou_score: 0.4121
# Epoch 90/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3350 - iou_score: 0.6918 - val_loss: 0.6666 - val_iou_score: 0.4154
# Epoch 91/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3404 - iou_score: 0.6876 - val_loss: 0.6798 - val_iou_score: 0.4103
# Epoch 92/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3499 - iou_score: 0.6806 - val_loss: 0.6775 - val_iou_score: 0.4094
# Epoch 93/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3505 - iou_score: 0.6787 - val_loss: 0.6607 - val_iou_score: 0.4180
# Epoch 94/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3386 - iou_score: 0.6885 - val_loss: 0.6639 - val_iou_score: 0.4187
# Epoch 95/100
# 181/181 [==============================] - 50s 276ms/step - loss: 0.3363 - iou_score: 0.6903 - val_loss: 0.6715 - val_iou_score: 0.4166
# Epoch 96/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3387 - iou_score: 0.6882 - val_loss: 0.6769 - val_iou_score: 0.4134
# Epoch 97/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3356 - iou_score: 0.6907 - val_loss: 0.6595 - val_iou_score: 0.4195
# Epoch 98/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3430 - iou_score: 0.6831 - val_loss: 0.6619 - val_iou_score: 0.4184
# Epoch 99/100
# 181/181 [==============================] - 50s 277ms/step - loss: 0.3286 - iou_score: 0.6969 - val_loss: 0.6694 - val_iou_score: 0.4148
# Epoch 100/100
# 181/181 [==============================] - 50s 278ms/step - loss: 0.3305 - iou_score: 0.6947 - val_loss: 0.6593 - val_iou_score: 0.4202

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()})-({SIZE_X}x{SIZE_Y}).hdf5')

# %%
model.input_shape, model.output_shape
# Out:
# ((None, 128, 128, 3), (None, 128, 128, 10))

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.11it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = f'../../dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../../dataset/test_data(128x128).pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128)

# %%
pickle_file_path = f'../../dataset/test_data({SIZE_X}x{SIZE_Y}).pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128)

# %%
test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)

# %% [markdown]
# ## Validation Evaluation and Perfomance

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

val_seperate_images_, val_seperate_masks_ = preprocess_data(val_seperate_images, val_seperate_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', val_seperate_images_.shape)
print('Test Masks:', val_seperate_masks_.shape)
# Out:
# Shapes of loaded data:
# Test Images: (450, 128, 128, 3)
# Test Masks: (450, 128, 128, 10)

# %%
_, acc = model.evaluate(val_seperate_images_, val_seperate_masks_, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  51.34482979774475 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(val_seperate_images_)
predicted_masks = np.argmax(y_pred, axis=-1)
val_seperate_masks_ = np.argmax(val_seperate_masks_, axis=-1)

print(predicted_masks.shape)
print(val_seperate_masks_.shape)
# Out:
# 15/15 [==============================] - 7s 112ms/step
# (450, 128, 128)
# (450, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(val_seperate_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.69989574
# IoU for each class:
# Building Flooded: 0.7666668891906738
# Building Non-Flooded: 0.7871865630149841
# Road Flooded: 0.6222046613693237
# Road Non-Flooded: 0.8259575963020325
# Water: 0.7404447793960571
# Tree: 0.8202322125434875
# Vehicle: 0.4263927936553955
# Pool: 0.5185337066650391
# Grass: 0.8838040232658386
# Mean IoU (excluding Background): 0.7101581

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'Validation IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Test Evaluation and Perfomance

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  50.54415464401245 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 7s 119ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.6794468
# IoU for each class:
# Building Flooded: 0.7092113494873047
# Building Non-Flooded: 0.7741650938987732
# Road Flooded: 0.6317595839500427
# Road Non-Flooded: 0.8179249167442322
# Water: 0.7968690991401672
# Tree: 0.820298969745636
# Vehicle: 0.3900126516819
# Pool: 0.47762852907180786
# Grass: 0.8933501243591309
# Mean IoU (excluding Background): 0.70124674

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names[1:], class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def calculate_iou(ground_truth_mask, predicted_mask):
    intersection = np.logical_and(ground_truth_mask, predicted_mask)
    union = np.logical_or(ground_truth_mask, predicted_mask)
    iou = np.sum(intersection) / np.sum(union)
    return iou

# %%
iou_of_each_image = {}
for i in range(len(test_images)):
    iou = calculate_iou(test_masks_[i], predicted_masks[i])
    iou_of_each_image[i] = iou

# %% [markdown]
# ## Samples Visualization

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    iou = calculate_iou(ground_truth_mask, predicted_mask)
    print(f'IoU for this image: {iou}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
# IoU for this image: 1.0

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
# IoU for this image: 0.8305684873123074

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
# IoU for this image: 1.0

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
# IoU for this image: 0.95556640625

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
# IoU for this image: 1.0

# %% [markdown]
# # Error Analysis

# %%
for i in range(len(test_images)):
    if iou_of_each_image[i] < 0.50:
        print(str(i) + " : " + str(iou_of_each_image[i]))
        display_images_with_masks(test_images_seperate[i], test_masks_[i], predicted_masks[i])
# Out:
# 173 : 0.18499755859375
# 208 : 0.30633544921875
# 351 : 0.360595703125
# 414 : 0.3975111111111111
# 436 : 0.4796142578125
