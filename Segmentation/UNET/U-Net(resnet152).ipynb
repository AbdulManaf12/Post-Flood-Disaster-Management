# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 16
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'resnet152'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
def display_images_with_masks(image, mask, predicted):
    
    class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}

    color_map = {
        "Background": [0, 0, 0],
        "Building-flooded": [255, 0, 0],
        "Building-non-flooded": [0, 255, 0],
        "Road-flooded": [0, 255, 120],
        "Road-non-flooded": [0, 0, 255],
        "Water": [255, 0, 255],
        "Tree": [70, 70, 70],
        "Vehicle": [102, 102, 156],
        "Pool": [190, 153, 153],
        "Grass": [180, 165, 180]
    }

    handles = [
        Rectangle((0, 0), 1, 1, color=np.array(c)/255) for n, c in color_map.items()
    ]
    labels = [n for n, c in color_map.items()]

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 3, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
    plt.title('Image')

    plt.subplot(1, 3, 2)
    mask_colored = np.zeros_like(image, dtype=np.uint8)
    for class_name, class_idx in class_map.items():
        color = color_map[class_name]
        mask_indices = np.where(mask == class_idx)
        mask_colored[mask_indices[0], mask_indices[1], :] = color
    plt.imshow(cv2.cvtColor(mask_colored, cv2.COLOR_BGR2RGB))
    plt.title('Ground-Truth Mask')

    plt.subplot(1, 3, 3)
    mask_colored1 = np.zeros_like(image, dtype=np.uint8)
    for class_name1, class_idx1 in class_map.items():
        color1 = color_map[class_name1]
        mask_indices1 = np.where(predicted == class_idx1)
        mask_colored1[mask_indices1[0], mask_indices1[1], :] = color1
    plt.imshow(cv2.cvtColor(mask_colored1, cv2.COLOR_BGR2RGB))
    plt.title('Predicted Mask')

    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
if MODEL == 'unet':
    model = sm.Unet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'fpn':
    model = sm.FPN(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
else:
    raise ValueError('Unknown model')

model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet152_imagenet_1000_no_top.h5
# 234326024/234326024 [==============================] - 19s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 128, 128, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 128, 128, 3)  9           ['data[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 134, 134, 3)  0          ['bn_data[0][0]']
#
#  conv0 (Conv2D)                 (None, 64, 64, 64)   9408        ['zero_padding2d[0][0]']
#
#  bn0 (BatchNormalization)       (None, 64, 64, 64)   256         ['conv0[0][0]']
#
#  relu0 (Activation)             (None, 64, 64, 64)   0           ['bn0[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 66, 66, 64)  0           ['relu0[0][0]']
#  D)
#
#  pooling0 (MaxPooling2D)        (None, 32, 32, 64)   0           ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 32, 32, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 32, 32, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  stage1_unit1_conv1 (Conv2D)    (None, 32, 32, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 32, 32, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 32, 32, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 34, 34, 64)  0           ['stage1_unit1_relu2[0][0]']
#  D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 32, 32, 64)   36864       ['zero_padding2d_2[0][0]']
#
#  stage1_unit1_bn3 (BatchNormali  (None, 32, 32, 64)  256         ['stage1_unit1_conv2[0][0]']
#  zation)
#
#  stage1_unit1_relu3 (Activation  (None, 32, 32, 64)  0           ['stage1_unit1_bn3[0][0]']
#  )
#
#  stage1_unit1_conv3 (Conv2D)    (None, 32, 32, 256)  16384       ['stage1_unit1_relu3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 32, 32, 256)  16384       ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                      (None, 32, 32, 256)  0           ['stage1_unit1_conv3[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 32, 32, 256)  1024       ['add[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 32, 32, 256)  0          ['stage1_unit2_bn1[0][0]']
#  )
#
#  stage1_unit2_conv1 (Conv2D)    (None, 32, 32, 64)   16384       ['stage1_unit2_relu1[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 32, 32, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 32, 32, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 34, 34, 64)  0           ['stage1_unit2_relu2[0][0]']
#  D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 32, 32, 64)   36864       ['zero_padding2d_3[0][0]']
#
#  stage1_unit2_bn3 (BatchNormali  (None, 32, 32, 64)  256         ['stage1_unit2_conv2[0][0]']
#  zation)
#
#  stage1_unit2_relu3 (Activation  (None, 32, 32, 64)  0           ['stage1_unit2_bn3[0][0]']
#  )
#
#  stage1_unit2_conv3 (Conv2D)    (None, 32, 32, 256)  16384       ['stage1_unit2_relu3[0][0]']
#
#  add_1 (Add)                    (None, 32, 32, 256)  0           ['stage1_unit2_conv3[0][0]',
#                                                                   'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 32, 32, 256)  1024       ['add_1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 32, 32, 256)  0          ['stage1_unit3_bn1[0][0]']
#  )
#
#  stage1_unit3_conv1 (Conv2D)    (None, 32, 32, 64)   16384       ['stage1_unit3_relu1[0][0]']
#
#  stage1_unit3_bn2 (BatchNormali  (None, 32, 32, 64)  256         ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu2 (Activation  (None, 32, 32, 64)  0           ['stage1_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_4 (ZeroPadding2  (None, 34, 34, 64)  0           ['stage1_unit3_relu2[0][0]']
#  D)
#
#  stage1_unit3_conv2 (Conv2D)    (None, 32, 32, 64)   36864       ['zero_padding2d_4[0][0]']
#
#  stage1_unit3_bn3 (BatchNormali  (None, 32, 32, 64)  256         ['stage1_unit3_conv2[0][0]']
#  zation)
#
#  stage1_unit3_relu3 (Activation  (None, 32, 32, 64)  0           ['stage1_unit3_bn3[0][0]']
#  )
#
#  stage1_unit3_conv3 (Conv2D)    (None, 32, 32, 256)  16384       ['stage1_unit3_relu3[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 256)  0           ['stage1_unit3_conv3[0][0]',
#                                                                   'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 32, 32, 256)  1024       ['add_2[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 32, 32, 256)  0          ['stage2_unit1_bn1[0][0]']
#  )
#
#  stage2_unit1_conv1 (Conv2D)    (None, 32, 32, 128)  32768       ['stage2_unit1_relu1[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 34, 34, 128)  0          ['stage2_unit1_relu2[0][0]']
#  D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 16, 16, 128)  147456      ['zero_padding2d_5[0][0]']
#
#  stage2_unit1_bn3 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit1_conv2[0][0]']
#  zation)
#
#  stage2_unit1_relu3 (Activation  (None, 16, 16, 128)  0          ['stage2_unit1_bn3[0][0]']
#  )
#
#  stage2_unit1_conv3 (Conv2D)    (None, 16, 16, 512)  65536       ['stage2_unit1_relu3[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 16, 16, 512)  131072      ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                    (None, 16, 16, 512)  0           ['stage2_unit1_conv3[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 16, 16, 512)  2048       ['add_3[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 16, 16, 512)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  stage2_unit2_conv1 (Conv2D)    (None, 16, 16, 128)  65536       ['stage2_unit2_relu1[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 16, 16, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_6 (ZeroPadding2  (None, 18, 18, 128)  0          ['stage2_unit2_relu2[0][0]']
#  D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 16, 16, 128)  147456      ['zero_padding2d_6[0][0]']
#
#  stage2_unit2_bn3 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit2_conv2[0][0]']
#  zation)
#
#  stage2_unit2_relu3 (Activation  (None, 16, 16, 128)  0          ['stage2_unit2_bn3[0][0]']
#  )
#
#  stage2_unit2_conv3 (Conv2D)    (None, 16, 16, 512)  65536       ['stage2_unit2_relu3[0][0]']
#
#  add_4 (Add)                    (None, 16, 16, 512)  0           ['stage2_unit2_conv3[0][0]',
#                                                                   'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 16, 16, 512)  2048       ['add_4[0][0]']
#  zation)
#
#  stage2_unit3_relu1 (Activation  (None, 16, 16, 512)  0          ['stage2_unit3_bn1[0][0]']
#  )
#
#  stage2_unit3_conv1 (Conv2D)    (None, 16, 16, 128)  65536       ['stage2_unit3_relu1[0][0]']
#
#  stage2_unit3_bn2 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit3_conv1[0][0]']
#  zation)
#
#  stage2_unit3_relu2 (Activation  (None, 16, 16, 128)  0          ['stage2_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 18, 18, 128)  0          ['stage2_unit3_relu2[0][0]']
#  D)
#
#  stage2_unit3_conv2 (Conv2D)    (None, 16, 16, 128)  147456      ['zero_padding2d_7[0][0]']
#
#  stage2_unit3_bn3 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit3_conv2[0][0]']
#  zation)
#
#  stage2_unit3_relu3 (Activation  (None, 16, 16, 128)  0          ['stage2_unit3_bn3[0][0]']
#  )
#
#  stage2_unit3_conv3 (Conv2D)    (None, 16, 16, 512)  65536       ['stage2_unit3_relu3[0][0]']
#
#  add_5 (Add)                    (None, 16, 16, 512)  0           ['stage2_unit3_conv3[0][0]',
#                                                                   'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 16, 16, 512)  2048       ['add_5[0][0]']
#  zation)
#
#  stage2_unit4_relu1 (Activation  (None, 16, 16, 512)  0          ['stage2_unit4_bn1[0][0]']
#  )
#
#  stage2_unit4_conv1 (Conv2D)    (None, 16, 16, 128)  65536       ['stage2_unit4_relu1[0][0]']
#
#  stage2_unit4_bn2 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit4_conv1[0][0]']
#  zation)
#
#  stage2_unit4_relu2 (Activation  (None, 16, 16, 128)  0          ['stage2_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_8 (ZeroPadding2  (None, 18, 18, 128)  0          ['stage2_unit4_relu2[0][0]']
#  D)
#
#  stage2_unit4_conv2 (Conv2D)    (None, 16, 16, 128)  147456      ['zero_padding2d_8[0][0]']
#
#  stage2_unit4_bn3 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit4_conv2[0][0]']
#  zation)
#
#  stage2_unit4_relu3 (Activation  (None, 16, 16, 128)  0          ['stage2_unit4_bn3[0][0]']
#  )
#
#  stage2_unit4_conv3 (Conv2D)    (None, 16, 16, 512)  65536       ['stage2_unit4_relu3[0][0]']
#
#  add_6 (Add)                    (None, 16, 16, 512)  0           ['stage2_unit4_conv3[0][0]',
#                                                                   'add_5[0][0]']
#
#  stage2_unit5_bn1 (BatchNormali  (None, 16, 16, 512)  2048       ['add_6[0][0]']
#  zation)
#
#  stage2_unit5_relu1 (Activation  (None, 16, 16, 512)  0          ['stage2_unit5_bn1[0][0]']
#  )
#
#  stage2_unit5_conv1 (Conv2D)    (None, 16, 16, 128)  65536       ['stage2_unit5_relu1[0][0]']
#
#  stage2_unit5_bn2 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit5_conv1[0][0]']
#  zation)
#
#  stage2_unit5_relu2 (Activation  (None, 16, 16, 128)  0          ['stage2_unit5_bn2[0][0]']
#  )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 18, 18, 128)  0          ['stage2_unit5_relu2[0][0]']
#  D)
#
#  stage2_unit5_conv2 (Conv2D)    (None, 16, 16, 128)  147456      ['zero_padding2d_9[0][0]']
#
#  stage2_unit5_bn3 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit5_conv2[0][0]']
#  zation)
#
#  stage2_unit5_relu3 (Activation  (None, 16, 16, 128)  0          ['stage2_unit5_bn3[0][0]']
#  )
#
#  stage2_unit5_conv3 (Conv2D)    (None, 16, 16, 512)  65536       ['stage2_unit5_relu3[0][0]']
#
#  add_7 (Add)                    (None, 16, 16, 512)  0           ['stage2_unit5_conv3[0][0]',
#                                                                   'add_6[0][0]']
#
#  stage2_unit6_bn1 (BatchNormali  (None, 16, 16, 512)  2048       ['add_7[0][0]']
#  zation)
#
#  stage2_unit6_relu1 (Activation  (None, 16, 16, 512)  0          ['stage2_unit6_bn1[0][0]']
#  )
#
#  stage2_unit6_conv1 (Conv2D)    (None, 16, 16, 128)  65536       ['stage2_unit6_relu1[0][0]']
#
#  stage2_unit6_bn2 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit6_conv1[0][0]']
#  zation)
#
#  stage2_unit6_relu2 (Activation  (None, 16, 16, 128)  0          ['stage2_unit6_bn2[0][0]']
#  )
#
#  zero_padding2d_10 (ZeroPadding  (None, 18, 18, 128)  0          ['stage2_unit6_relu2[0][0]']
#  2D)
#
#  stage2_unit6_conv2 (Conv2D)    (None, 16, 16, 128)  147456      ['zero_padding2d_10[0][0]']
#
#  stage2_unit6_bn3 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit6_conv2[0][0]']
#  zation)
#
#  stage2_unit6_relu3 (Activation  (None, 16, 16, 128)  0          ['stage2_unit6_bn3[0][0]']
#  )
#
#  stage2_unit6_conv3 (Conv2D)    (None, 16, 16, 512)  65536       ['stage2_unit6_relu3[0][0]']
#
#  add_8 (Add)                    (None, 16, 16, 512)  0           ['stage2_unit6_conv3[0][0]',
#                                                                   'add_7[0][0]']
#
#  stage2_unit7_bn1 (BatchNormali  (None, 16, 16, 512)  2048       ['add_8[0][0]']
#  zation)
#
#  stage2_unit7_relu1 (Activation  (None, 16, 16, 512)  0          ['stage2_unit7_bn1[0][0]']
#  )
#
#  stage2_unit7_conv1 (Conv2D)    (None, 16, 16, 128)  65536       ['stage2_unit7_relu1[0][0]']
#
#  stage2_unit7_bn2 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit7_conv1[0][0]']
#  zation)
#
#  stage2_unit7_relu2 (Activation  (None, 16, 16, 128)  0          ['stage2_unit7_bn2[0][0]']
#  )
#
#  zero_padding2d_11 (ZeroPadding  (None, 18, 18, 128)  0          ['stage2_unit7_relu2[0][0]']
#  2D)
#
#  stage2_unit7_conv2 (Conv2D)    (None, 16, 16, 128)  147456      ['zero_padding2d_11[0][0]']
#
#  stage2_unit7_bn3 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit7_conv2[0][0]']
#  zation)
#
#  stage2_unit7_relu3 (Activation  (None, 16, 16, 128)  0          ['stage2_unit7_bn3[0][0]']
#  )
#
#  stage2_unit7_conv3 (Conv2D)    (None, 16, 16, 512)  65536       ['stage2_unit7_relu3[0][0]']
#
#  add_9 (Add)                    (None, 16, 16, 512)  0           ['stage2_unit7_conv3[0][0]',
#                                                                   'add_8[0][0]']
#
#  stage2_unit8_bn1 (BatchNormali  (None, 16, 16, 512)  2048       ['add_9[0][0]']
#  zation)
#
#  stage2_unit8_relu1 (Activation  (None, 16, 16, 512)  0          ['stage2_unit8_bn1[0][0]']
#  )
#
#  stage2_unit8_conv1 (Conv2D)    (None, 16, 16, 128)  65536       ['stage2_unit8_relu1[0][0]']
#
#  stage2_unit8_bn2 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit8_conv1[0][0]']
#  zation)
#
#  stage2_unit8_relu2 (Activation  (None, 16, 16, 128)  0          ['stage2_unit8_bn2[0][0]']
#  )
#
#  zero_padding2d_12 (ZeroPadding  (None, 18, 18, 128)  0          ['stage2_unit8_relu2[0][0]']
#  2D)
#
#  stage2_unit8_conv2 (Conv2D)    (None, 16, 16, 128)  147456      ['zero_padding2d_12[0][0]']
#
#  stage2_unit8_bn3 (BatchNormali  (None, 16, 16, 128)  512        ['stage2_unit8_conv2[0][0]']
#  zation)
#
#  stage2_unit8_relu3 (Activation  (None, 16, 16, 128)  0          ['stage2_unit8_bn3[0][0]']
#  )
#
#  stage2_unit8_conv3 (Conv2D)    (None, 16, 16, 512)  65536       ['stage2_unit8_relu3[0][0]']
#
#  add_10 (Add)                   (None, 16, 16, 512)  0           ['stage2_unit8_conv3[0][0]',
#                                                                   'add_9[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 16, 16, 512)  2048       ['add_10[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 16, 16, 512)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  stage3_unit1_conv1 (Conv2D)    (None, 16, 16, 256)  131072      ['stage3_unit1_relu1[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_13 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 8, 8, 256)    589824      ['zero_padding2d_13[0][0]']
#
#  stage3_unit1_bn3 (BatchNormali  (None, 8, 8, 256)   1024        ['stage3_unit1_conv2[0][0]']
#  zation)
#
#  stage3_unit1_relu3 (Activation  (None, 8, 8, 256)   0           ['stage3_unit1_bn3[0][0]']
#  )
#
#  stage3_unit1_conv3 (Conv2D)    (None, 8, 8, 1024)   262144      ['stage3_unit1_relu3[0][0]']
#
#  stage3_unit1_sc (Conv2D)       (None, 8, 8, 1024)   524288      ['stage3_unit1_relu1[0][0]']
#
#  add_11 (Add)                   (None, 8, 8, 1024)   0           ['stage3_unit1_conv3[0][0]',
#                                                                   'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 8, 8, 1024)  4096        ['add_11[0][0]']
#  zation)
#
#  stage3_unit2_relu1 (Activation  (None, 8, 8, 1024)  0           ['stage3_unit2_bn1[0][0]']
#  )
#
#  stage3_unit2_conv1 (Conv2D)    (None, 8, 8, 256)    262144      ['stage3_unit2_relu1[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 8, 8, 256)   1024        ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 8, 8, 256)   0           ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_14 (ZeroPadding  (None, 10, 10, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 8, 8, 256)    589824      ['zero_padding2d_14[0][0]']
#
#  stage3_unit2_bn3 (BatchNormali  (None, 8, 8, 256)   1024        ['stage3_unit2_conv2[0][0]']
#  zation)
#
#  stage3_unit2_relu3 (Activation  (None, 8, 8, 256)   0           ['stage3_unit2_bn3[0][0]']
#  )
#
#  stage3_unit2_conv3 (Conv2D)    (None, 8, 8, 1024)   262144      ['stage3_unit2_relu3[0][0]']
#
#  add_12 (Add)                   (None, 8, 8, 1024)   0           ['stage3_unit2_conv3[0][0]',
#                                                                   'add_11[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 8, 8, 1024)  4096        ['add_12[0][0]']
#  zation)
#
#  stage3_unit3_relu1 (Activation  (None, 8, 8, 1024)  0           ['stage3_unit3_bn1[0][0]']
#  )
#
#  stage3_unit3_conv1 (Conv2D)    (None, 8, 8, 256)    262144      ['stage3_unit3_relu1[0][0]']
#
#  stage3_unit3_bn2 (BatchNormali  (None, 8, 8, 256)   1024        ['stage3_unit3_conv1[0][0]']
#  zation)
#
#  stage3_unit3_relu2 (Activation  (None, 8, 8, 256)   0           ['stage3_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_15 (ZeroPadding  (None, 10, 10, 256)  0          ['stage3_unit3_relu2[0][0]']
#  2D)
#
#  stage3_unit3_conv2 (Conv2D)    (None, 8, 8, 256)    589824      ['zero_padding2d_15[0][0]']
#
#  stage3_unit3_bn3 (BatchNormali  (None, 8, 8, 256)   1024        ['stage3_unit3_conv2[0][0]']
#  zation)
#
#  stage3_unit3_relu3 (Activation  (None, 8, 8, 256)   0           ['stage3_unit3_bn3[0][0]']
#  )
#
#  stage3_unit3_conv3 (Conv2D)    (None, 8, 8, 1024)   262144      ['stage3_unit3_relu3[0][0]']
#
#  add_13 (Add)                   (None, 8, 8, 1024)   0           ['stage3_unit3_conv3[0][0]',
#                                                                   'add_12[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 8, 8, 1024)  4096        ['add_13[0][0]']
#  zation)
#
#  stage3_unit4_relu1 (Activation  (None, 8, 8, 1024)  0           ['stage3_unit4_bn1[0][0]']
#  )
#
#  stage3_unit4_conv1 (Conv2D)    (None, 8, 8, 256)    262144      ['stage3_unit4_relu1[0][0]']
#
#  stage3_unit4_bn2 (BatchNormali  (None, 8, 8, 256)   1024        ['stage3_unit4_conv1[0][0]']
#  zation)
#
#  stage3_unit4_relu2 (Activation  (None, 8, 8, 256)   0           ['stage3_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_16 (ZeroPadding  (None, 10, 10, 256)  0          ['stage3_unit4_relu2[0][0]']
#  2D)
#
#  stage3_unit4_conv2 (Conv2D)    (None, 8, 8, 256)    589824      ['zero_padding2d_16[0][0]']
#
#  stage3_unit4_bn3 (BatchNormali  (None, 8, 8, 256)   1024        ['stage3_unit4_conv2[0][0]']
#  zation)
#
#  stage3_unit4_relu3 (Activation  (None, 8, 8, 256)   0           ['stage3_unit4_bn3[0][0]']
#  )
#
#  stage3_unit4_conv3 (Conv2D)    (None, 8, 8, 1024)   262144      ['stage3_unit4_relu3[0][0]']
#
#  add_14 (Add)                   (None, 8, 8, 1024)   0           ['stage3_unit4_conv3[0][0]',
#                                                                   'add_13[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 8, 8, 1024)  4096        ['add_14[0][0]']
#  zation)
#
#  stage3_unit5_relu1 (Activation  (None, 8, 8, 1024)  0           ['stage3_unit5_bn1[0][0]']
#  )
# ...
#  stage4_unit2_conv3 (Conv2D)    (None, 4, 4, 2048)   1048576     ['stage4_unit2_relu3[0][0]']
#
#  add_48 (Add)                   (None, 4, 4, 2048)   0           ['stage4_unit2_conv3[0][0]',
#                                                                   'add_47[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, 4, 4, 2048)  8192        ['add_48[0][0]']
#  zation)
#
#  stage4_unit3_relu1 (Activation  (None, 4, 4, 2048)  0           ['stage4_unit3_bn1[0][0]']
#  )
#
#  stage4_unit3_conv1 (Conv2D)    (None, 4, 4, 512)    1048576     ['stage4_unit3_relu1[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 4, 4, 512)   2048        ['stage4_unit3_conv1[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 4, 4, 512)   0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_51 (ZeroPadding  (None, 6, 6, 512)   0           ['stage4_unit3_relu2[0][0]']
#  2D)
#
#  stage4_unit3_conv2 (Conv2D)    (None, 4, 4, 512)    2359296     ['zero_padding2d_51[0][0]']
#
#  stage4_unit3_bn3 (BatchNormali  (None, 4, 4, 512)   2048        ['stage4_unit3_conv2[0][0]']
#  zation)
#
#  stage4_unit3_relu3 (Activation  (None, 4, 4, 512)   0           ['stage4_unit3_bn3[0][0]']
#  )
#
#  stage4_unit3_conv3 (Conv2D)    (None, 4, 4, 2048)   1048576     ['stage4_unit3_relu3[0][0]']
#
#  add_49 (Add)                   (None, 4, 4, 2048)   0           ['stage4_unit3_conv3[0][0]',
#                                                                   'add_48[0][0]']
#
#  bn1 (BatchNormalization)       (None, 4, 4, 2048)   8192        ['add_49[0][0]']
#
#  relu1 (Activation)             (None, 4, 4, 2048)   0           ['bn1[0][0]']
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 2048)  0           ['relu1[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 3072)  0           ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 8, 8, 256)    7077888     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 8, 8, 256)    589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 768)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 16, 16, 128)  884736      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 16, 16, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 384)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 32, 32, 64)   221184      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 32, 32, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64)  0           ['decoder_stage2b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 128)  0          ['decoder_stage3_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 32)   36864       ['decoder_stage3_concat[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3b_conv (Conv2D)  (None, 64, 64, 32)   9216        ['decoder_stage3a_relu[0][0]']
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3b_conv[0][0]']
#  lization)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3b_bn[0][0]']
#  on)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 128, 128, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 128, 128, 10  1450        ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  softmax (Activation)           (None, 128, 128, 10  0           ['final_conv[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 67,296,499
# Trainable params: 67,150,637
# Non-trainable params: 145,862
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 91/91 [==============================] - 42s 245ms/step - loss: 1.1357 - iou_score: 0.1405 - val_loss: 86641.2188 - val_iou_score: 0.1047
# Epoch 2/100
# 91/91 [==============================] - 16s 180ms/step - loss: 0.9006 - iou_score: 0.2420 - val_loss: 1.2143 - val_iou_score: 0.0964
# Epoch 3/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.8427 - iou_score: 0.2864 - val_loss: 11.6125 - val_iou_score: 0.0635
# Epoch 4/100
# 91/91 [==============================] - 16s 179ms/step - loss: 0.7933 - iou_score: 0.3288 - val_loss: 1.0642 - val_iou_score: 0.1455
# Epoch 5/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.7617 - iou_score: 0.3547 - val_loss: 1.0076 - val_iou_score: 0.1933
# Epoch 6/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.7208 - iou_score: 0.3917 - val_loss: 1.1325 - val_iou_score: 0.1808
# Epoch 7/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.7009 - iou_score: 0.4071 - val_loss: 12.8666 - val_iou_score: 0.1351
# Epoch 8/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.6799 - iou_score: 0.4235 - val_loss: 0.8955 - val_iou_score: 0.2618
# Epoch 9/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.7391 - iou_score: 0.3788 - val_loss: 793.8606 - val_iou_score: 0.1082
# Epoch 10/100
# 91/91 [==============================] - 17s 182ms/step - loss: 0.7071 - iou_score: 0.4022 - val_loss: 1.1236 - val_iou_score: 0.2426
# Epoch 11/100
# 91/91 [==============================] - 17s 191ms/step - loss: 0.6934 - iou_score: 0.4135 - val_loss: 0.8813 - val_iou_score: 0.2922
# Epoch 12/100
# 91/91 [==============================] - 17s 182ms/step - loss: 0.6764 - iou_score: 0.4247 - val_loss: 0.7952 - val_iou_score: 0.3112
# Epoch 13/100
# 91/91 [==============================] - 17s 186ms/step - loss: 0.6585 - iou_score: 0.4382 - val_loss: 0.8497 - val_iou_score: 0.2835
# Epoch 14/100
# 91/91 [==============================] - 17s 187ms/step - loss: 0.6435 - iou_score: 0.4533 - val_loss: 0.7726 - val_iou_score: 0.3317
# Epoch 15/100
# 91/91 [==============================] - 17s 184ms/step - loss: 0.6321 - iou_score: 0.4649 - val_loss: 0.8633 - val_iou_score: 0.3025
# Epoch 16/100
# 91/91 [==============================] - 17s 185ms/step - loss: 0.6256 - iou_score: 0.4682 - val_loss: 0.8671 - val_iou_score: 0.2782
# Epoch 17/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.6047 - iou_score: 0.4867 - val_loss: 0.7767 - val_iou_score: 0.3332
# Epoch 18/100
# 91/91 [==============================] - 17s 185ms/step - loss: 0.6137 - iou_score: 0.4819 - val_loss: 4.2054 - val_iou_score: 0.1512
# Epoch 19/100
# 91/91 [==============================] - 17s 183ms/step - loss: 0.5910 - iou_score: 0.4988 - val_loss: 0.9427 - val_iou_score: 0.3292
# Epoch 20/100
# 91/91 [==============================] - 17s 186ms/step - loss: 0.5860 - iou_score: 0.5018 - val_loss: 0.7379 - val_iou_score: 0.3588
# Epoch 21/100
# 91/91 [==============================] - 17s 188ms/step - loss: 0.5842 - iou_score: 0.5019 - val_loss: 0.7389 - val_iou_score: 0.3565
# Epoch 22/100
# 91/91 [==============================] - 17s 185ms/step - loss: 0.5728 - iou_score: 0.5130 - val_loss: 13.1137 - val_iou_score: 0.2663
# Epoch 23/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.5834 - iou_score: 0.5033 - val_loss: 0.7608 - val_iou_score: 0.3485
# Epoch 24/100
# 91/91 [==============================] - 17s 183ms/step - loss: 0.5716 - iou_score: 0.5134 - val_loss: 0.7784 - val_iou_score: 0.3373
# Epoch 25/100
# 91/91 [==============================] - 16s 180ms/step - loss: 0.5609 - iou_score: 0.5224 - val_loss: 0.7286 - val_iou_score: 0.3663
# Epoch 26/100
# 91/91 [==============================] - 16s 180ms/step - loss: 0.5536 - iou_score: 0.5309 - val_loss: 0.9331 - val_iou_score: 0.2736
# Epoch 27/100
# 91/91 [==============================] - 16s 180ms/step - loss: 0.5491 - iou_score: 0.5315 - val_loss: 0.7296 - val_iou_score: 0.3675
# Epoch 28/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.5398 - iou_score: 0.5394 - val_loss: 0.7298 - val_iou_score: 0.3709
# Epoch 29/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.5363 - iou_score: 0.5443 - val_loss: 0.7186 - val_iou_score: 0.3779
# Epoch 30/100
# 91/91 [==============================] - 16s 179ms/step - loss: 0.5347 - iou_score: 0.5460 - val_loss: 0.7058 - val_iou_score: 0.3831
# Epoch 31/100
# 91/91 [==============================] - 17s 182ms/step - loss: 0.5207 - iou_score: 0.5585 - val_loss: 0.9401 - val_iou_score: 0.3249
# Epoch 32/100
# 91/91 [==============================] - 17s 182ms/step - loss: 0.5193 - iou_score: 0.5587 - val_loss: 4.2686 - val_iou_score: 0.2084
# Epoch 33/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.5584 - iou_score: 0.5307 - val_loss: 0.7653 - val_iou_score: 0.3436
# Epoch 34/100
# 91/91 [==============================] - 16s 179ms/step - loss: 0.5331 - iou_score: 0.5478 - val_loss: 0.7665 - val_iou_score: 0.3565
# Epoch 35/100
# 91/91 [==============================] - 16s 179ms/step - loss: 0.5098 - iou_score: 0.5664 - val_loss: 0.7393 - val_iou_score: 0.3615
# Epoch 36/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.5020 - iou_score: 0.5732 - val_loss: 0.7035 - val_iou_score: 0.3835
# Epoch 37/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.5025 - iou_score: 0.5729 - val_loss: 0.6800 - val_iou_score: 0.4011
# Epoch 38/100
# 91/91 [==============================] - 17s 182ms/step - loss: 0.5202 - iou_score: 0.5564 - val_loss: 0.8359 - val_iou_score: 0.3205
# Epoch 39/100
# 91/91 [==============================] - 17s 183ms/step - loss: 0.5034 - iou_score: 0.5737 - val_loss: 0.7632 - val_iou_score: 0.3914
# Epoch 40/100
# 91/91 [==============================] - 17s 183ms/step - loss: 0.4933 - iou_score: 0.5784 - val_loss: 0.7216 - val_iou_score: 0.3757
# Epoch 41/100
# 91/91 [==============================] - 17s 184ms/step - loss: 0.4862 - iou_score: 0.5846 - val_loss: 0.6888 - val_iou_score: 0.3977
# Epoch 42/100
# 91/91 [==============================] - 16s 181ms/step - loss: 0.4634 - iou_score: 0.6061 - val_loss: 0.7546 - val_iou_score: 0.3624
# Epoch 43/100
# 91/91 [==============================] - 17s 182ms/step - loss: 0.4877 - iou_score: 0.5840 - val_loss: 0.7325 - val_iou_score: 0.3686
# Epoch 44/100
# 91/91 [==============================] - 17s 182ms/step - loss: 0.4825 - iou_score: 0.5857 - val_loss: 0.7126 - val_iou_score: 0.3869
# Epoch 45/100
# 91/91 [==============================] - 17s 184ms/step - loss: 0.4647 - iou_score: 0.6024 - val_loss: 0.7496 - val_iou_score: 0.3700
# Epoch 46/100
# 91/91 [==============================] - 17s 183ms/step - loss: 0.4604 - iou_score: 0.6066 - val_loss: 0.8346 - val_iou_score: 0.2997
# Epoch 47/100
# 91/91 [==============================] - 17s 184ms/step - loss: 0.4785 - iou_score: 0.5925 - val_loss: 0.8112 - val_iou_score: 0.3246
# Epoch 48/100
# 91/91 [==============================] - 17s 183ms/step - loss: 0.4539 - iou_score: 0.6118 - val_loss: 0.6720 - val_iou_score: 0.4104
# Epoch 49/100
# 91/91 [==============================] - 17s 183ms/step - loss: 0.4515 - iou_score: 0.6123 - val_loss: 1.3558 - val_iou_score: 0.1816
# Epoch 50/100
# 91/91 [==============================] - 17s 184ms/step - loss: 0.4467 - iou_score: 0.6189 - val_loss: 0.7296 - val_iou_score: 0.3780
# Epoch 51/100
# 91/91 [==============================] - 17s 182ms/step - loss: 0.4416 - iou_score: 0.6223 - val_loss: 0.6639 - val_iou_score: 0.4150
# Epoch 52/100
# 91/91 [==============================] - 17s 183ms/step - loss: 0.4403 - iou_score: 0.6210 - val_loss: 0.6834 - val_iou_score: 0.4008
# Epoch 53/100
# 91/91 [==============================] - 16s 179ms/step - loss: 0.4536 - iou_score: 0.6128 - val_loss: 0.7267 - val_iou_score: 0.3808
# Epoch 54/100
# 36/91 [==========>...................] - ETA: 9s - loss: 0.4355 - iou_score: 0.6258

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  44.55001950263977 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 1s 18ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

class_APs = []

for i in range(n_classes):
    class_predicted_masks = (predicted_masks == i).astype(int)
    class_test_masks = (test_masks_ == i).astype(int)
    
    class_predicted_masks_flat = class_predicted_masks.flatten().reshape(-1, 1)
    class_test_masks_flat = class_test_masks.flatten().reshape(-1, 1)
    
    class_APs.append(average_precision_score(class_test_masks_flat, class_predicted_masks_flat, average='micro'))

mAP_score = np.mean(class_APs)
print("Overall mAP score =", mAP_score)
# Out:
# Mean IoU = 0.6040169
# IoU for each class:
# Background: 0.3007384240627289
# Building Flooded: 0.6823919415473938
# Building Non-Flooded: 0.7219418883323669
# Road Flooded: 0.49748495221138
# Road Non-Flooded: 0.7738253474235535
# Water: 0.7136574983596802
# Tree: 0.756822943687439
# Vehicle: 0.32672449946403503
# Pool: 0.40929844975471497
# Grass: 0.8572831749916077
# Overall mAP score = 0.5850917605036409

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names, class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
