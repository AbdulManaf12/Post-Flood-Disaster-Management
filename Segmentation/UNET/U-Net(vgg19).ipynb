# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'vgg19'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
if MODEL == 'unet':
    model = sm.Unet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'fpn':
    model = sm.FPN(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
else:
    raise ValueError('Unknown model')

model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv3[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 4, 4, 512)    0           ['block5_conv4[0][0]']
#
#  center_block1_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['block5_pool[0][0]']
#
#  center_block1_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block1_conv[0][0]']
#  zation)
#
#  center_block1_relu (Activation  (None, 4, 4, 512)   0           ['center_block1_bn[0][0]']
#  )
#
#  center_block2_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['center_block1_relu[0][0]']
#
#  center_block2_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block2_conv[0][0]']
#  zation)
#
#  center_block2_relu (Activation  (None, 4, 4, 512)   0           ['center_block2_bn[0][0]']
#  )
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 512)   0           ['center_block2_relu[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 1024)  0           ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block5_conv4[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 8, 8, 256)    2359296     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 8, 8, 256)    589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 768)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block4_conv4[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 16, 16, 128)  884736      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 16, 16, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 384)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block3_conv4[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 32, 32, 64)   221184      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 32, 32, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64)  0           ['decoder_stage2b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 192)  0          ['decoder_stage3_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block2_conv2[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 32)   55296       ['decoder_stage3_concat[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3b_conv (Conv2D)  (None, 64, 64, 32)   9216        ['decoder_stage3a_relu[0][0]']
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3b_conv[0][0]']
#  lization)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3b_bn[0][0]']
#  on)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 128, 128, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 128, 128, 10  1450        ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  softmax (Activation)           (None, 128, 128, 10  0           ['final_conv[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 29,063,274
# Trainable params: 29,059,242
# Non-trainable params: 4,032
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 23s 88ms/step - loss: 1.0393 - iou_score: 0.1736 - val_loss: 0.9661 - val_iou_score: 0.1865
# Epoch 2/100
# 181/181 [==============================] - 13s 73ms/step - loss: 0.8995 - iou_score: 0.2437 - val_loss: 0.9891 - val_iou_score: 0.1857
# Epoch 3/100
# 181/181 [==============================] - 13s 71ms/step - loss: 0.8583 - iou_score: 0.2743 - val_loss: 1.0223 - val_iou_score: 0.1746
# Epoch 4/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.8150 - iou_score: 0.3083 - val_loss: 0.8674 - val_iou_score: 0.2531
# Epoch 5/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.7741 - iou_score: 0.3459 - val_loss: 0.8314 - val_iou_score: 0.2742
# Epoch 6/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.7555 - iou_score: 0.3599 - val_loss: 0.8301 - val_iou_score: 0.2788
# Epoch 7/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.7266 - iou_score: 0.3860 - val_loss: 0.8051 - val_iou_score: 0.2964
# Epoch 8/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.7073 - iou_score: 0.4018 - val_loss: 0.7934 - val_iou_score: 0.3057
# Epoch 9/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.6931 - iou_score: 0.4133 - val_loss: 0.8244 - val_iou_score: 0.2916
# Epoch 10/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.6768 - iou_score: 0.4257 - val_loss: 0.8213 - val_iou_score: 0.2985
# Epoch 11/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.6569 - iou_score: 0.4434 - val_loss: 0.7929 - val_iou_score: 0.3112
# Epoch 12/100
# 181/181 [==============================] - 13s 72ms/step - loss: 0.6476 - iou_score: 0.4498 - val_loss: 0.7753 - val_iou_score: 0.3279
# Epoch 13/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.6433 - iou_score: 0.4539 - val_loss: 0.7671 - val_iou_score: 0.3292
# Epoch 14/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.6336 - iou_score: 0.4600 - val_loss: 0.7446 - val_iou_score: 0.3442
# Epoch 15/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.6158 - iou_score: 0.4745 - val_loss: 0.7531 - val_iou_score: 0.3402
# Epoch 16/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.6091 - iou_score: 0.4806 - val_loss: 0.7442 - val_iou_score: 0.3479
# Epoch 17/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.6073 - iou_score: 0.4834 - val_loss: 0.7529 - val_iou_score: 0.3433
# Epoch 18/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5917 - iou_score: 0.4954 - val_loss: 0.7491 - val_iou_score: 0.3422
# Epoch 19/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5880 - iou_score: 0.4980 - val_loss: 0.7333 - val_iou_score: 0.3545
# Epoch 20/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5793 - iou_score: 0.5039 - val_loss: 0.7564 - val_iou_score: 0.3435
# Epoch 21/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.5801 - iou_score: 0.5036 - val_loss: 0.7160 - val_iou_score: 0.3659
# Epoch 22/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5596 - iou_score: 0.5186 - val_loss: 0.7219 - val_iou_score: 0.3643
# Epoch 23/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5657 - iou_score: 0.5141 - val_loss: 0.7483 - val_iou_score: 0.3515
# Epoch 24/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.5576 - iou_score: 0.5208 - val_loss: 0.7309 - val_iou_score: 0.3576
# Epoch 25/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.5607 - iou_score: 0.5171 - val_loss: 0.7305 - val_iou_score: 0.3597
# Epoch 26/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.5473 - iou_score: 0.5302 - val_loss: 0.7294 - val_iou_score: 0.3601
# Epoch 27/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5363 - iou_score: 0.5398 - val_loss: 0.7271 - val_iou_score: 0.3606
# Epoch 28/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5468 - iou_score: 0.5308 - val_loss: 0.7226 - val_iou_score: 0.3650
# Epoch 29/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5352 - iou_score: 0.5383 - val_loss: 0.7078 - val_iou_score: 0.3744
# Epoch 30/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5170 - iou_score: 0.5543 - val_loss: 0.7090 - val_iou_score: 0.3734
# Epoch 31/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.5187 - iou_score: 0.5529 - val_loss: 0.7115 - val_iou_score: 0.3716
# Epoch 32/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.5062 - iou_score: 0.5635 - val_loss: 0.7123 - val_iou_score: 0.3732
# Epoch 33/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.5109 - iou_score: 0.5596 - val_loss: 0.7016 - val_iou_score: 0.3789
# Epoch 34/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.5026 - iou_score: 0.5667 - val_loss: 0.7149 - val_iou_score: 0.3697
# Epoch 35/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4901 - iou_score: 0.5762 - val_loss: 0.7137 - val_iou_score: 0.3717
# Epoch 36/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4839 - iou_score: 0.5806 - val_loss: 0.7098 - val_iou_score: 0.3752
# Epoch 37/100
# 181/181 [==============================] - 13s 71ms/step - loss: 0.5018 - iou_score: 0.5665 - val_loss: 0.7107 - val_iou_score: 0.3741
# Epoch 38/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.4845 - iou_score: 0.5807 - val_loss: 0.7064 - val_iou_score: 0.3777
# Epoch 39/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.4773 - iou_score: 0.5856 - val_loss: 0.7112 - val_iou_score: 0.3767
# Epoch 40/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.4725 - iou_score: 0.5884 - val_loss: 0.7043 - val_iou_score: 0.3781
# Epoch 41/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4718 - iou_score: 0.5895 - val_loss: 0.7059 - val_iou_score: 0.3800
# Epoch 42/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4680 - iou_score: 0.5937 - val_loss: 0.7054 - val_iou_score: 0.3778
# Epoch 43/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4679 - iou_score: 0.5914 - val_loss: 0.7034 - val_iou_score: 0.3815
# Epoch 44/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.4668 - iou_score: 0.5927 - val_loss: 0.6968 - val_iou_score: 0.3853
# Epoch 45/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.4529 - iou_score: 0.6038 - val_loss: 0.7022 - val_iou_score: 0.3826
# Epoch 46/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4606 - iou_score: 0.6001 - val_loss: 0.7175 - val_iou_score: 0.3730
# Epoch 47/100
# 181/181 [==============================] - 13s 70ms/step - loss: 0.4654 - iou_score: 0.5939 - val_loss: 0.7087 - val_iou_score: 0.3771
# Epoch 48/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4515 - iou_score: 0.6065 - val_loss: 0.7279 - val_iou_score: 0.3680
# Epoch 49/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4449 - iou_score: 0.6108 - val_loss: 0.7012 - val_iou_score: 0.3820
# Epoch 50/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.4344 - iou_score: 0.6184 - val_loss: 0.6984 - val_iou_score: 0.3840
# Epoch 51/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.4372 - iou_score: 0.6167 - val_loss: 0.7351 - val_iou_score: 0.3686
# Epoch 52/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4373 - iou_score: 0.6161 - val_loss: 0.7136 - val_iou_score: 0.3769
# Epoch 53/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4388 - iou_score: 0.6160 - val_loss: 0.7109 - val_iou_score: 0.3790
# Epoch 54/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4480 - iou_score: 0.6065 - val_loss: 0.7159 - val_iou_score: 0.3721
# Epoch 55/100
# 181/181 [==============================] - 13s 72ms/step - loss: 0.4445 - iou_score: 0.6091 - val_loss: 0.7135 - val_iou_score: 0.3772
# Epoch 56/100
# 181/181 [==============================] - 13s 70ms/step - loss: 0.4343 - iou_score: 0.6186 - val_loss: 0.6993 - val_iou_score: 0.3829
# Epoch 57/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.4300 - iou_score: 0.6202 - val_loss: 0.6953 - val_iou_score: 0.3862
# Epoch 58/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4278 - iou_score: 0.6236 - val_loss: 0.6959 - val_iou_score: 0.3892
# Epoch 59/100
# 181/181 [==============================] - 13s 70ms/step - loss: 0.4209 - iou_score: 0.6291 - val_loss: 0.7029 - val_iou_score: 0.3810
# Epoch 60/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4170 - iou_score: 0.6307 - val_loss: 0.6987 - val_iou_score: 0.3884
# Epoch 61/100
# 181/181 [==============================] - 13s 69ms/step - loss: 0.4202 - iou_score: 0.6277 - val_loss: 0.7109 - val_iou_score: 0.3780
# Epoch 62/100
# 181/181 [==============================] - 13s 69ms/step - loss: 0.4275 - iou_score: 0.6239 - val_loss: 0.7027 - val_iou_score: 0.3844
# Epoch 63/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.4249 - iou_score: 0.6246 - val_loss: 0.7054 - val_iou_score: 0.3801
# Epoch 64/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.4145 - iou_score: 0.6333 - val_loss: 0.7095 - val_iou_score: 0.3807
# Epoch 65/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4218 - iou_score: 0.6278 - val_loss: 0.7192 - val_iou_score: 0.3756
# Epoch 66/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.4202 - iou_score: 0.6267 - val_loss: 0.7144 - val_iou_score: 0.3780
# Epoch 67/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.4207 - iou_score: 0.6274 - val_loss: 0.6999 - val_iou_score: 0.3875
# Epoch 68/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.4079 - iou_score: 0.6375 - val_loss: 0.7078 - val_iou_score: 0.3806
# Epoch 69/100
# 181/181 [==============================] - 13s 69ms/step - loss: 0.4107 - iou_score: 0.6365 - val_loss: 0.7079 - val_iou_score: 0.3819
# Epoch 70/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4117 - iou_score: 0.6345 - val_loss: 0.6960 - val_iou_score: 0.3882
# Epoch 71/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3953 - iou_score: 0.6474 - val_loss: 0.6902 - val_iou_score: 0.3918
# Epoch 72/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.3916 - iou_score: 0.6506 - val_loss: 0.6972 - val_iou_score: 0.3888
# Epoch 73/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.3977 - iou_score: 0.6460 - val_loss: 0.7225 - val_iou_score: 0.3750
# Epoch 74/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4010 - iou_score: 0.6412 - val_loss: 0.6997 - val_iou_score: 0.3876
# Epoch 75/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4027 - iou_score: 0.6402 - val_loss: 0.7082 - val_iou_score: 0.3849
# Epoch 76/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3900 - iou_score: 0.6514 - val_loss: 0.6980 - val_iou_score: 0.3870
# Epoch 77/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3842 - iou_score: 0.6561 - val_loss: 0.6956 - val_iou_score: 0.3904
# Epoch 78/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3907 - iou_score: 0.6528 - val_loss: 0.7029 - val_iou_score: 0.3840
# Epoch 79/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4003 - iou_score: 0.6422 - val_loss: 0.7116 - val_iou_score: 0.3831
# Epoch 80/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.3947 - iou_score: 0.6468 - val_loss: 0.7079 - val_iou_score: 0.3846
# Epoch 81/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3822 - iou_score: 0.6570 - val_loss: 0.7029 - val_iou_score: 0.3882
# Epoch 82/100
# 181/181 [==============================] - 12s 69ms/step - loss: 0.3905 - iou_score: 0.6504 - val_loss: 0.7074 - val_iou_score: 0.3834
# Epoch 83/100
# 181/181 [==============================] - 13s 70ms/step - loss: 0.3923 - iou_score: 0.6501 - val_loss: 0.7045 - val_iou_score: 0.3854
# Epoch 84/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.3804 - iou_score: 0.6591 - val_loss: 0.7166 - val_iou_score: 0.3832
# Epoch 85/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3686 - iou_score: 0.6694 - val_loss: 0.7104 - val_iou_score: 0.3816
# Epoch 86/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3645 - iou_score: 0.6707 - val_loss: 0.6980 - val_iou_score: 0.3890
# Epoch 87/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3670 - iou_score: 0.6674 - val_loss: 0.7020 - val_iou_score: 0.3899
# Epoch 88/100
# 181/181 [==============================] - 12s 67ms/step - loss: 0.3609 - iou_score: 0.6747 - val_loss: 0.7002 - val_iou_score: 0.3901
# Epoch 89/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3748 - iou_score: 0.6609 - val_loss: 0.7274 - val_iou_score: 0.3780
# Epoch 90/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.4084 - iou_score: 0.6367 - val_loss: 0.7194 - val_iou_score: 0.3774
# Epoch 91/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3822 - iou_score: 0.6555 - val_loss: 0.6949 - val_iou_score: 0.3932
# Epoch 92/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3568 - iou_score: 0.6769 - val_loss: 0.6998 - val_iou_score: 0.3910
# Epoch 93/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3620 - iou_score: 0.6710 - val_loss: 0.7130 - val_iou_score: 0.3850
# Epoch 94/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3688 - iou_score: 0.6649 - val_loss: 0.6972 - val_iou_score: 0.3940
# Epoch 95/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3513 - iou_score: 0.6821 - val_loss: 0.7044 - val_iou_score: 0.3877
# Epoch 96/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3598 - iou_score: 0.6735 - val_loss: 0.7074 - val_iou_score: 0.3872
# Epoch 97/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3568 - iou_score: 0.6748 - val_loss: 0.7271 - val_iou_score: 0.3819
# Epoch 98/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3626 - iou_score: 0.6703 - val_loss: 0.7210 - val_iou_score: 0.3850
# Epoch 99/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3675 - iou_score: 0.6686 - val_loss: 0.7155 - val_iou_score: 0.3836
# Epoch 100/100
# 181/181 [==============================] - 12s 68ms/step - loss: 0.3834 - iou_score: 0.6548 - val_loss: 0.7136 - val_iou_score: 0.3861

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  45.287248492240906 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 1s 37ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

class_APs = []

for i in range(n_classes):
    class_predicted_masks = (predicted_masks == i).astype(int)
    class_test_masks = (test_masks_ == i).astype(int)
    
    class_predicted_masks_flat = class_predicted_masks.flatten().reshape(-1, 1)
    class_test_masks_flat = class_test_masks.flatten().reshape(-1, 1)
    
    class_APs.append(average_precision_score(class_test_masks_flat, class_predicted_masks_flat, average='micro'))

mAP_score = np.mean(class_APs)
print("Overall mAP score =", mAP_score)
# Out:
# Mean IoU = 0.60603523
# IoU for each class:
# Background: 0.2765428423881531
# Building Flooded: 0.639462411403656
# Building Non-Flooded: 0.6837236881256104
# Road Flooded: 0.5487202405929565
# Road Non-Flooded: 0.7857577800750732
# Water: 0.7551906108856201
# Tree: 0.7510249018669128
# Vehicle: 0.31609755754470825
# Pool: 0.44785797595977783
# Grass: 0.8559741973876953
# Overall mAP score = 0.5861493673785393

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names, class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
