# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 16
EPOCHS = 100
MODEL = 'unet'
activation = 'sigmoid'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing=None):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
def display_images_with_masks(image, mask, predicted):
    
    class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}

    color_map = {
        "Background": [0, 0, 0],
        "Building-flooded": [255, 0, 0],
        "Building-non-flooded": [0, 255, 0],
        "Road-flooded": [0, 255, 120],
        "Road-non-flooded": [0, 0, 255],
        "Water": [255, 0, 255],
        "Tree": [70, 70, 70],
        "Vehicle": [102, 102, 156],
        "Pool": [190, 153, 153],
        "Grass": [180, 165, 180]
    }

    handles = [
        Rectangle((0, 0), 1, 1, color=np.array(c)/255) for n, c in color_map.items()
    ]
    labels = [n for n, c in color_map.items()]

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 3, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
    plt.title('Image')

    plt.subplot(1, 3, 2)
    mask_colored = np.zeros_like(image, dtype=np.uint8)
    for class_name, class_idx in class_map.items():
        color = color_map[class_name]
        mask_indices = np.where(mask == class_idx)
        mask_colored[mask_indices[0], mask_indices[1], :] = color
    plt.imshow(cv2.cvtColor(mask_colored, cv2.COLOR_BGR2RGB))
    plt.title('Ground-Truth Mask')

    plt.subplot(1, 3, 3)
    mask_colored1 = np.zeros_like(image, dtype=np.uint8)
    for class_name1, class_idx1 in class_map.items():
        color1 = color_map[class_name1]
        mask_indices1 = np.where(predicted == class_idx1)
        mask_colored1[mask_indices1[0], mask_indices1[1], :] = color1
    plt.imshow(cv2.cvtColor(mask_colored1, cv2.COLOR_BGR2RGB))
    plt.title('Predicted Mask')

    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
train_images, train_masks = preprocess_data(train_images, train_masks)
val_images, val_masks = preprocess_data(val_images, val_masks)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
import segmentation_models as sm

if MODEL == 'unet':
    model = sm.Unet(input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes,  activation=activation)
elif MODEL == 'fpn':
    model = sm.FPN(input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes,  activation=activation)
else:
    raise ValueError('Unknown model')

model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_2[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 4, 4, 512)    0           ['block5_conv3[0][0]']
#
#  center_block1_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['block5_pool[0][0]']
#
#  center_block1_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block1_conv[0][0]']
#  zation)
#
#  center_block1_relu (Activation  (None, 4, 4, 512)   0           ['center_block1_bn[0][0]']
#  )
#
#  center_block2_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['center_block1_relu[0][0]']
#
#  center_block2_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block2_conv[0][0]']
#  zation)
#
#  center_block2_relu (Activation  (None, 4, 4, 512)   0           ['center_block2_bn[0][0]']
#  )
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 512)   0           ['center_block2_relu[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 1024)  0           ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block5_conv3[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 8, 8, 256)    2359296     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 8, 8, 256)    589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 768)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block4_conv3[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 16, 16, 128)  884736      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 16, 16, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 384)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block3_conv3[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 32, 32, 64)   221184      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 32, 32, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64)  0           ['decoder_stage2b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 192)  0          ['decoder_stage3_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block2_conv2[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 32)   55296       ['decoder_stage3_concat[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3b_conv (Conv2D)  (None, 64, 64, 32)   9216        ['decoder_stage3a_relu[0][0]']
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3b_conv[0][0]']
#  lization)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3b_bn[0][0]']
#  on)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 128, 128, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 128, 128, 10  1450        ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  sigmoid (Activation)           (None, 128, 128, 10  0           ['final_conv[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 23,753,578
# Trainable params: 23,749,546
# Non-trainable params: 4,032
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 91/91 [==============================] - 17s 120ms/step - loss: 1.1896 - iou_score: 0.1053 - val_loss: 1.3549 - val_iou_score: 0.0602
# Epoch 2/100
# 91/91 [==============================] - 8s 85ms/step - loss: 1.0151 - iou_score: 0.1557 - val_loss: 1.2542 - val_iou_score: 0.0674
# Epoch 3/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.9534 - iou_score: 0.2026 - val_loss: 1.7988 - val_iou_score: 0.0297
# Epoch 4/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.9225 - iou_score: 0.2292 - val_loss: 1.2474 - val_iou_score: 0.0924
# Epoch 5/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.9023 - iou_score: 0.2453 - val_loss: 1.0908 - val_iou_score: 0.1366
# Epoch 6/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.8817 - iou_score: 0.2604 - val_loss: 1.3513 - val_iou_score: 0.0782
# Epoch 7/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.8535 - iou_score: 0.2835 - val_loss: 1.4402 - val_iou_score: 0.1023
# Epoch 8/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.8427 - iou_score: 0.2965 - val_loss: 1.0582 - val_iou_score: 0.1706
# Epoch 9/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.8211 - iou_score: 0.3124 - val_loss: 1.5052 - val_iou_score: 0.0848
# Epoch 10/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.8099 - iou_score: 0.3216 - val_loss: 1.0652 - val_iou_score: 0.1567
# Epoch 11/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.7945 - iou_score: 0.3345 - val_loss: 0.9804 - val_iou_score: 0.1948
# Epoch 12/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.7881 - iou_score: 0.3374 - val_loss: 0.9639 - val_iou_score: 0.2109
# Epoch 13/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.7683 - iou_score: 0.3540 - val_loss: 0.9643 - val_iou_score: 0.2224
# Epoch 14/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.7508 - iou_score: 0.3755 - val_loss: 0.9762 - val_iou_score: 0.2172
# Epoch 15/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.7194 - iou_score: 0.4000 - val_loss: 0.9509 - val_iou_score: 0.2257
# Epoch 16/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.7187 - iou_score: 0.4017 - val_loss: 1.0844 - val_iou_score: 0.1847
# Epoch 17/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.7129 - iou_score: 0.4067 - val_loss: 0.7982 - val_iou_score: 0.3109
# Epoch 18/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6881 - iou_score: 0.4263 - val_loss: 0.8347 - val_iou_score: 0.3010
# Epoch 19/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6911 - iou_score: 0.4243 - val_loss: 0.8206 - val_iou_score: 0.3014
# Epoch 20/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6759 - iou_score: 0.4365 - val_loss: 0.7731 - val_iou_score: 0.3323
# Epoch 21/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6562 - iou_score: 0.4530 - val_loss: 0.8032 - val_iou_score: 0.3098
# Epoch 22/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6509 - iou_score: 0.4555 - val_loss: 0.7918 - val_iou_score: 0.3197
# Epoch 23/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.6506 - iou_score: 0.4574 - val_loss: 0.7987 - val_iou_score: 0.3206
# Epoch 24/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6387 - iou_score: 0.4674 - val_loss: 0.8252 - val_iou_score: 0.3019
# Epoch 25/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6363 - iou_score: 0.4669 - val_loss: 0.7811 - val_iou_score: 0.3326
# Epoch 26/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6134 - iou_score: 0.4862 - val_loss: 0.8132 - val_iou_score: 0.3135
# Epoch 27/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6195 - iou_score: 0.4819 - val_loss: 0.7561 - val_iou_score: 0.3522
# Epoch 28/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6062 - iou_score: 0.4938 - val_loss: 0.7825 - val_iou_score: 0.3391
# Epoch 29/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5939 - iou_score: 0.5024 - val_loss: 0.8633 - val_iou_score: 0.3039
# Epoch 30/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5941 - iou_score: 0.5050 - val_loss: 0.7668 - val_iou_score: 0.3409
# Epoch 31/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5799 - iou_score: 0.5142 - val_loss: 0.7620 - val_iou_score: 0.3453
# Epoch 32/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5992 - iou_score: 0.4994 - val_loss: 0.8444 - val_iou_score: 0.3104
# Epoch 33/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5765 - iou_score: 0.5183 - val_loss: 0.7413 - val_iou_score: 0.3616
# Epoch 34/100
# 91/91 [==============================] - 8s 84ms/step - loss: 0.5637 - iou_score: 0.5261 - val_loss: 0.8362 - val_iou_score: 0.3157
# Epoch 35/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5645 - iou_score: 0.5288 - val_loss: 0.7455 - val_iou_score: 0.3579
# Epoch 36/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5649 - iou_score: 0.5258 - val_loss: 0.8350 - val_iou_score: 0.3217
# Epoch 37/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5576 - iou_score: 0.5300 - val_loss: 0.7619 - val_iou_score: 0.3491
# Epoch 38/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5510 - iou_score: 0.5395 - val_loss: 0.7647 - val_iou_score: 0.3522
# Epoch 39/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5315 - iou_score: 0.5540 - val_loss: 0.7363 - val_iou_score: 0.3677
# Epoch 40/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5216 - iou_score: 0.5632 - val_loss: 0.7344 - val_iou_score: 0.3701
# Epoch 41/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5231 - iou_score: 0.5612 - val_loss: 0.7351 - val_iou_score: 0.3656
# Epoch 42/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.5274 - iou_score: 0.5580 - val_loss: 0.7519 - val_iou_score: 0.3570
# Epoch 43/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5232 - iou_score: 0.5587 - val_loss: 0.7322 - val_iou_score: 0.3715
# Epoch 44/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5029 - iou_score: 0.5739 - val_loss: 0.7543 - val_iou_score: 0.3563
# Epoch 45/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4915 - iou_score: 0.5853 - val_loss: 0.7423 - val_iou_score: 0.3610
# Epoch 46/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5018 - iou_score: 0.5780 - val_loss: 0.7638 - val_iou_score: 0.3551
# Epoch 47/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4860 - iou_score: 0.5905 - val_loss: 0.7152 - val_iou_score: 0.3846
# Epoch 48/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4705 - iou_score: 0.6033 - val_loss: 0.8489 - val_iou_score: 0.3199
# Epoch 49/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.4878 - iou_score: 0.5866 - val_loss: 0.7321 - val_iou_score: 0.3727
# Epoch 50/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4591 - iou_score: 0.6118 - val_loss: 0.7319 - val_iou_score: 0.3720
# Epoch 51/100
# 91/91 [==============================] - 8s 84ms/step - loss: 0.4501 - iou_score: 0.6184 - val_loss: 0.7753 - val_iou_score: 0.3499
# Epoch 52/100
# 91/91 [==============================] - 8s 84ms/step - loss: 0.4412 - iou_score: 0.6244 - val_loss: 0.8075 - val_iou_score: 0.3565
# Epoch 53/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4554 - iou_score: 0.6151 - val_loss: 0.7443 - val_iou_score: 0.3738
# Epoch 54/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4539 - iou_score: 0.6164 - val_loss: 0.7602 - val_iou_score: 0.3663
# Epoch 55/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4430 - iou_score: 0.6264 - val_loss: 0.7130 - val_iou_score: 0.3883
# Epoch 56/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.4375 - iou_score: 0.6306 - val_loss: 0.7331 - val_iou_score: 0.3803
# Epoch 57/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4390 - iou_score: 0.6291 - val_loss: 0.7566 - val_iou_score: 0.3681
# Epoch 58/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4315 - iou_score: 0.6352 - val_loss: 0.7342 - val_iou_score: 0.3795
# Epoch 59/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.4254 - iou_score: 0.6379 - val_loss: 0.7473 - val_iou_score: 0.3769
# Epoch 60/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4221 - iou_score: 0.6412 - val_loss: 0.7199 - val_iou_score: 0.3850
# Epoch 61/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4041 - iou_score: 0.6537 - val_loss: 0.7055 - val_iou_score: 0.3936
# Epoch 62/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3972 - iou_score: 0.6600 - val_loss: 0.7211 - val_iou_score: 0.3812
# Epoch 63/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3970 - iou_score: 0.6589 - val_loss: 0.7149 - val_iou_score: 0.3942
# Epoch 64/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3971 - iou_score: 0.6616 - val_loss: 0.8042 - val_iou_score: 0.3458
# Epoch 65/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3905 - iou_score: 0.6679 - val_loss: 0.7218 - val_iou_score: 0.3857
# Epoch 66/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3943 - iou_score: 0.6629 - val_loss: 0.7135 - val_iou_score: 0.3943
# Epoch 67/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3897 - iou_score: 0.6698 - val_loss: 0.7629 - val_iou_score: 0.3732
# Epoch 68/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4345 - iou_score: 0.6336 - val_loss: 0.7227 - val_iou_score: 0.3896
# Epoch 69/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3896 - iou_score: 0.6653 - val_loss: 0.7325 - val_iou_score: 0.3822
# Epoch 70/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.4003 - iou_score: 0.6571 - val_loss: 0.7745 - val_iou_score: 0.3742
# Epoch 71/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3831 - iou_score: 0.6719 - val_loss: 0.7072 - val_iou_score: 0.3982
# Epoch 72/100
# 91/91 [==============================] - 8s 84ms/step - loss: 0.3635 - iou_score: 0.6867 - val_loss: 0.7206 - val_iou_score: 0.3911
# Epoch 73/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3540 - iou_score: 0.6947 - val_loss: 0.7071 - val_iou_score: 0.4032
# Epoch 74/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3596 - iou_score: 0.6872 - val_loss: 0.7049 - val_iou_score: 0.4033
# Epoch 75/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3522 - iou_score: 0.6963 - val_loss: 0.7121 - val_iou_score: 0.3992
# Epoch 76/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3816 - iou_score: 0.6739 - val_loss: 0.8230 - val_iou_score: 0.3591
# Epoch 77/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3764 - iou_score: 0.6795 - val_loss: 0.7069 - val_iou_score: 0.3970
# Epoch 78/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3600 - iou_score: 0.6883 - val_loss: 0.7134 - val_iou_score: 0.4004
# Epoch 79/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3434 - iou_score: 0.7029 - val_loss: 0.7091 - val_iou_score: 0.4035
# Epoch 80/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3431 - iou_score: 0.7038 - val_loss: 0.7006 - val_iou_score: 0.4052
# Epoch 81/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3595 - iou_score: 0.6905 - val_loss: 0.7480 - val_iou_score: 0.3792
# Epoch 82/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3440 - iou_score: 0.7006 - val_loss: 0.7087 - val_iou_score: 0.4020
# Epoch 83/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3456 - iou_score: 0.7014 - val_loss: 0.7053 - val_iou_score: 0.4025
# Epoch 84/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3596 - iou_score: 0.6901 - val_loss: 0.7179 - val_iou_score: 0.3989
# Epoch 85/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3505 - iou_score: 0.6970 - val_loss: 0.7096 - val_iou_score: 0.4018
# Epoch 86/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3418 - iou_score: 0.7049 - val_loss: 0.7057 - val_iou_score: 0.4061
# Epoch 87/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3416 - iou_score: 0.7010 - val_loss: 0.6946 - val_iou_score: 0.4102
# Epoch 88/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3266 - iou_score: 0.7174 - val_loss: 0.7364 - val_iou_score: 0.3944
# Epoch 89/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3472 - iou_score: 0.6980 - val_loss: 0.7086 - val_iou_score: 0.4025
# Epoch 90/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3312 - iou_score: 0.7143 - val_loss: 0.7356 - val_iou_score: 0.3938
# Epoch 91/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3266 - iou_score: 0.7147 - val_loss: 0.7126 - val_iou_score: 0.4102
# Epoch 92/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3308 - iou_score: 0.7107 - val_loss: 0.7200 - val_iou_score: 0.4004
# Epoch 93/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3184 - iou_score: 0.7225 - val_loss: 0.7007 - val_iou_score: 0.4106
# Epoch 94/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3346 - iou_score: 0.7113 - val_loss: 0.7522 - val_iou_score: 0.3876
# Epoch 95/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3757 - iou_score: 0.6748 - val_loss: 0.7251 - val_iou_score: 0.3974
# Epoch 96/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3410 - iou_score: 0.7059 - val_loss: 0.7153 - val_iou_score: 0.4065
# Epoch 97/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3175 - iou_score: 0.7261 - val_loss: 0.7109 - val_iou_score: 0.4033
# Epoch 98/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3193 - iou_score: 0.7234 - val_loss: 0.7115 - val_iou_score: 0.4051
# Epoch 99/100
# 91/91 [==============================] - 8s 86ms/step - loss: 0.3140 - iou_score: 0.7285 - val_loss: 0.7144 - val_iou_score: 0.4045
# Epoch 100/100
# 91/91 [==============================] - 8s 85ms/step - loss: 0.3178 - iou_score: 0.7223 - val_loss: 0.7158 - val_iou_score: 0.4074

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs_activation{activation}.hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs_activation{activation}.hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  43.994078040122986 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 1s 32ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

class_APs = []

for i in range(n_classes):
    class_predicted_masks = (predicted_masks == i).astype(int)
    class_test_masks = (test_masks_ == i).astype(int)
    
    class_predicted_masks_flat = class_predicted_masks.flatten().reshape(-1, 1)
    class_test_masks_flat = class_test_masks.flatten().reshape(-1, 1)
    
    class_APs.append(average_precision_score(class_test_masks_flat, class_predicted_masks_flat, average='micro'))

mAP_score = np.mean(class_APs)
print("Overall mAP score =", mAP_score)
# Out:
# Mean IoU = 0.5960697
# IoU for each class:
# Background: 0.281524658203125
# Building Flooded: 0.6518796682357788
# Building Non-Flooded: 0.6831544637680054
# Road Flooded: 0.5223630666732788
# Road Non-Flooded: 0.7734900116920471
# Water: 0.7207953929901123
# Tree: 0.7417612671852112
# Vehicle: 0.293053537607193
# Pool: 0.4432297945022583
# Grass: 0.8494448065757751
# Overall mAP score = 0.5778045191612553

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names, class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with ({EPOCHS} Epochs and {activation} Activation)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
