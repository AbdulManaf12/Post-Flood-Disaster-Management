# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'efficientnetb7'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(train_masks), y=train_masks.flatten())
print('Class weights:', class_weights)
# Out:
# Class weights: [ 5.81992674  6.42070692  3.07775748  3.6344779   1.81121359  0.91222167
#   0.57293409 46.64265732 39.01209505  0.17757066]

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
if MODEL == 'unet':
    model = sm.Unet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'fpn':
    model = sm.FPN(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
else:
    raise ValueError('Unknown model')

dice_loss = sm.losses.DiceLoss(class_weights=class_weights)
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

model.compile('Adam', loss=total_loss, metrics=metrics)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 64, 64, 64)   1728        ['input_1[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 64, 64, 64)   256         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 64, 64, 64)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 64, 64, 64)  576         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 64, 64, 64)  256         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 64, 64, 64)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 64)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 16)     1040        ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 64)     1088        ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 64, 64, 64)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 64, 64, 32)   2048        ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 64, 64, 32)  128         ['block1a_project_conv[0][0]']
#  lization)
#
#  block1b_dwconv (DepthwiseConv2  (None, 64, 64, 32)  288         ['block1a_project_bn[0][0]']
#  D)
#
#  block1b_bn (BatchNormalization  (None, 64, 64, 32)  128         ['block1b_dwconv[0][0]']
#  )
#
#  block1b_activation (Activation  (None, 64, 64, 32)  0           ['block1b_bn[0][0]']
#  )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 64, 64, 32)   0           ['block1b_activation[0][0]',
#                                                                   'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 64, 64, 32)   1024        ['block1b_se_excite[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 64, 64, 32)  128         ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_drop (FixedDropout)    (None, 64, 64, 32)   0           ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)              (None, 64, 64, 32)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 64, 64, 32)  288         ['block1b_add[0][0]']
#  D)
#
#  block1c_bn (BatchNormalization  (None, 64, 64, 32)  128         ['block1c_dwconv[0][0]']
#  )
#
#  block1c_activation (Activation  (None, 64, 64, 32)  0           ['block1c_bn[0][0]']
#  )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 64, 64, 32)   0           ['block1c_activation[0][0]',
#                                                                   'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 64, 64, 32)   1024        ['block1c_se_excite[0][0]']
#
#  block1c_project_bn (BatchNorma  (None, 64, 64, 32)  128         ['block1c_project_conv[0][0]']
#  lization)
#
#  block1c_drop (FixedDropout)    (None, 64, 64, 32)   0           ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)              (None, 64, 64, 32)   0           ['block1c_drop[0][0]',
#                                                                   'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseConv2  (None, 64, 64, 32)  288         ['block1c_add[0][0]']
#  D)
#
#  block1d_bn (BatchNormalization  (None, 64, 64, 32)  128         ['block1d_dwconv[0][0]']
#  )
#
#  block1d_activation (Activation  (None, 64, 64, 32)  0           ['block1d_bn[0][0]']
#  )
#
#  block1d_se_squeeze (GlobalAver  (None, 32)          0           ['block1d_activation[0][0]']
#  agePooling2D)
#
#  block1d_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1d_se_squeeze[0][0]']
#
#  block1d_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multiply)   (None, 64, 64, 32)   0           ['block1d_activation[0][0]',
#                                                                   'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 64, 64, 32)   1024        ['block1d_se_excite[0][0]']
#
#  block1d_project_bn (BatchNorma  (None, 64, 64, 32)  128         ['block1d_project_conv[0][0]']
#  lization)
#
#  block1d_drop (FixedDropout)    (None, 64, 64, 32)   0           ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)              (None, 64, 64, 32)   0           ['block1d_drop[0][0]',
#                                                                   'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 64, 64, 192)  6144        ['block1d_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 64, 64, 192)  768        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 64, 64, 192)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv (DepthwiseConv2  (None, 32, 32, 192)  1728       ['block2a_expand_activation[0][0]
#  D)                                                              ']
#
#  block2a_bn (BatchNormalization  (None, 32, 32, 192)  768        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 32, 32, 192)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 32, 32, 192)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 32, 32, 48)   9216        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 32, 32, 288)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 32, 32, 288)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 288)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 32, 32, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 32, 32, 288)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 32, 32, 288)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 288)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 32, 32, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 32, 32, 288)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 32, 32, 288)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 288)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 32, 32, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 32, 32, 288)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2e_expand_activation[0][0]
#  D)                                                              ']
#
#  block2e_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2e_dwconv[0][0]']
#  )
#
#  block2e_activation (Activation  (None, 32, 32, 288)  0          ['block2e_bn[0][0]']
#  )
#
#  block2e_se_squeeze (GlobalAver  (None, 288)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2e_activation[0][0]',
#                                                                   'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2e_se_excite[0][0]']
#
#  block2e_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 32, 32, 48)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 32, 32, 288)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2f_expand_activation[0][0]
#  D)                                                              ']
#
#  block2f_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2f_dwconv[0][0]']
#  )
#
#  block2f_activation (Activation  (None, 32, 32, 288)  0          ['block2f_bn[0][0]']
#  )
#
#  block2f_se_squeeze (GlobalAver  (None, 288)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2f_activation[0][0]',
#                                                                   'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2f_se_excite[0][0]']
#
#  block2f_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)              (None, 32, 32, 48)   0           ['block2f_drop[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 32, 32, 288)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_dwconv (DepthwiseConv2  (None, 32, 32, 288)  2592       ['block2g_expand_activation[0][0]
#  D)                                                              ']
#
#  block2g_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block2g_dwconv[0][0]']
#  )
#
#  block2g_activation (Activation  (None, 32, 32, 288)  0          ['block2g_bn[0][0]']
#  )
#
#  block2g_se_squeeze (GlobalAver  (None, 288)         0           ['block2g_activation[0][0]']
#  agePooling2D)
#
#  block2g_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2g_se_squeeze[0][0]']
#
#  block2g_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block2g_activation[0][0]',
#                                                                   'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block2g_se_excite[0][0]']
#
#  block2g_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_drop (FixedDropout)    (None, 32, 32, 48)   0           ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)              (None, 32, 32, 48)   0           ['block2g_drop[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 32, 32, 288)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv (DepthwiseConv2  (None, 16, 16, 288)  7200       ['block3a_expand_activation[0][0]
#  D)                                                              ']
#
#  block3a_bn (BatchNormalization  (None, 16, 16, 288)  1152       ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 16, 16, 288)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 288)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 16, 16, 288)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 16, 16, 80)   23040       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 16, 16, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 16, 16, 480)  38400       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 16, 16, 480)  1920       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 16, 16, 480)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 16, 16, 480)  12000      ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 16, 16, 480)  1920       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 16, 16, 480)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 480)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 16, 16, 480)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 16, 16, 80)   38400       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 16, 16, 80)  320         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (FixedDropout)    (None, 16, 16, 80)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 16, 16, 80)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 16, 16, 480)  38400       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 16, 16, 480)  1920       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 16, 16, 480)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 16, 16, 480)  12000      ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 16, 16, 480)  1920       ['block3c_dwconv[0][0]']
# ...
#
#  block7d_bn (BatchNormalization  (None, 4, 4, 3840)  15360       ['block7d_dwconv[0][0]']
#  )
#
#  block7d_activation (Activation  (None, 4, 4, 3840)  0           ['block7d_bn[0][0]']
#  )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 4, 4, 3840)   0           ['block7d_activation[0][0]',
#                                                                   'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 4, 4, 640)    2457600     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 4, 4, 640)   2560        ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (FixedDropout)    (None, 4, 4, 640)    0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 4, 4, 640)    0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  top_conv (Conv2D)              (None, 4, 4, 2560)   1638400     ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 4, 4, 2560)   10240       ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 4, 4, 2560)   0           ['top_bn[0][0]']
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 2560)  0           ['top_activation[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 3904)  0           ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block6a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage0a_conv (Conv2D)  (None, 8, 8, 256)    8994816     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 8, 8, 256)    589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 736)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block4a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage1a_conv (Conv2D)  (None, 16, 16, 128)  847872      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 16, 16, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 416)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block3a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage2a_conv (Conv2D)  (None, 32, 32, 64)   239616      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 32, 32, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64)  0           ['decoder_stage2b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 256)  0          ['decoder_stage3_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block2a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 32)   73728       ['decoder_stage3_concat[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3b_conv (Conv2D)  (None, 64, 64, 32)   9216        ['decoder_stage3a_relu[0][0]']
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3b_conv[0][0]']
#  lization)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3b_bn[0][0]']
#  on)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 128, 128, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 128, 128, 10  1450        ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  softmax (Activation)           (None, 128, 128, 10  0           ['final_conv[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 75,049,402
# Trainable params: 74,736,698
# Non-trainable params: 312,704
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 95s 323ms/step - loss: -1.4361 - iou_score: 0.1307 - f1-score: 0.1876 - val_loss: -0.1226 - val_iou_score: 0.1334 - val_f1-score: 0.1733
# Epoch 2/100
# 181/181 [==============================] - 50s 278ms/step - loss: -3.0598 - iou_score: 0.2264 - f1-score: 0.3214 - val_loss: -0.1527 - val_iou_score: 0.1372 - val_f1-score: 0.1905
# Epoch 3/100
# 181/181 [==============================] - 50s 279ms/step - loss: -3.6538 - iou_score: 0.3159 - f1-score: 0.4359 - val_loss: -2.0544 - val_iou_score: 0.3162 - val_f1-score: 0.3935
# Epoch 4/100
# 181/181 [==============================] - 50s 279ms/step - loss: -3.9642 - iou_score: 0.3524 - f1-score: 0.4733 - val_loss: -1.7480 - val_iou_score: 0.3168 - val_f1-score: 0.3924
# Epoch 5/100
# 181/181 [==============================] - 49s 273ms/step - loss: -4.1440 - iou_score: 0.3711 - f1-score: 0.4921 - val_loss: -2.2973 - val_iou_score: 0.2956 - val_f1-score: 0.3772
# Epoch 6/100
# 181/181 [==============================] - 50s 278ms/step - loss: -4.3473 - iou_score: 0.3856 - f1-score: 0.5067 - val_loss: -2.4016 - val_iou_score: 0.3108 - val_f1-score: 0.3916
# Epoch 7/100
# 181/181 [==============================] - 50s 277ms/step - loss: -4.3874 - iou_score: 0.3906 - f1-score: 0.5089 - val_loss: -2.3466 - val_iou_score: 0.3510 - val_f1-score: 0.4282
# Epoch 8/100
# 181/181 [==============================] - 51s 280ms/step - loss: -4.5553 - iou_score: 0.4070 - f1-score: 0.5253 - val_loss: -2.2002 - val_iou_score: 0.2855 - val_f1-score: 0.3635
# Epoch 9/100
# 181/181 [==============================] - 50s 278ms/step - loss: -4.6575 - iou_score: 0.4142 - f1-score: 0.5328 - val_loss: -2.4984 - val_iou_score: 0.3823 - val_f1-score: 0.4599
# Epoch 10/100
# 181/181 [==============================] - 50s 278ms/step - loss: -4.6620 - iou_score: 0.4090 - f1-score: 0.5257 - val_loss: -2.5652 - val_iou_score: 0.3782 - val_f1-score: 0.4557
# Epoch 11/100
# 181/181 [==============================] - 50s 278ms/step - loss: -4.7353 - iou_score: 0.4218 - f1-score: 0.5371 - val_loss: -2.4169 - val_iou_score: 0.3567 - val_f1-score: 0.4345
# Epoch 12/100
# 181/181 [==============================] - 50s 279ms/step - loss: -5.0550 - iou_score: 0.4451 - f1-score: 0.5613 - val_loss: -2.4746 - val_iou_score: 0.3680 - val_f1-score: 0.4436
# Epoch 13/100
# 181/181 [==============================] - 51s 280ms/step - loss: -4.8893 - iou_score: 0.4358 - f1-score: 0.5503 - val_loss: -2.4837 - val_iou_score: 0.3450 - val_f1-score: 0.4238
# Epoch 14/100
# 181/181 [==============================] - 50s 278ms/step - loss: -4.8380 - iou_score: 0.4335 - f1-score: 0.5490 - val_loss: -2.5408 - val_iou_score: 0.3735 - val_f1-score: 0.4502
# Epoch 15/100
# 181/181 [==============================] - 50s 278ms/step - loss: -5.1490 - iou_score: 0.4555 - f1-score: 0.5692 - val_loss: -2.5902 - val_iou_score: 0.3793 - val_f1-score: 0.4555
# Epoch 16/100
# 181/181 [==============================] - 51s 280ms/step - loss: -4.9403 - iou_score: 0.4534 - f1-score: 0.5674 - val_loss: -2.5079 - val_iou_score: 0.3656 - val_f1-score: 0.4431
# Epoch 17/100
# 181/181 [==============================] - 50s 275ms/step - loss: -5.1915 - iou_score: 0.4567 - f1-score: 0.5696 - val_loss: -2.4965 - val_iou_score: 0.4058 - val_f1-score: 0.4816
# Epoch 18/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.0366 - iou_score: 0.4554 - f1-score: 0.5667 - val_loss: -2.6364 - val_iou_score: 0.4101 - val_f1-score: 0.4868
# Epoch 19/100
# 181/181 [==============================] - 50s 275ms/step - loss: -5.1110 - iou_score: 0.4674 - f1-score: 0.5782 - val_loss: -2.5794 - val_iou_score: 0.4061 - val_f1-score: 0.4821
# Epoch 20/100
# 181/181 [==============================] - 49s 272ms/step - loss: -5.1948 - iou_score: 0.4695 - f1-score: 0.5803 - val_loss: -2.6654 - val_iou_score: 0.4076 - val_f1-score: 0.4842
# Epoch 21/100
# 181/181 [==============================] - 50s 275ms/step - loss: -5.2577 - iou_score: 0.4679 - f1-score: 0.5793 - val_loss: -2.5368 - val_iou_score: 0.4088 - val_f1-score: 0.4853
# Epoch 22/100
# 181/181 [==============================] - 50s 278ms/step - loss: -5.1874 - iou_score: 0.4684 - f1-score: 0.5785 - val_loss: -2.5966 - val_iou_score: 0.4221 - val_f1-score: 0.4974
# Epoch 23/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.3371 - iou_score: 0.4747 - f1-score: 0.5871 - val_loss: -2.5026 - val_iou_score: 0.3888 - val_f1-score: 0.4647
# Epoch 24/100
# 181/181 [==============================] - 50s 275ms/step - loss: -5.2211 - iou_score: 0.4806 - f1-score: 0.5919 - val_loss: -2.4145 - val_iou_score: 0.4237 - val_f1-score: 0.5007
# Epoch 25/100
# 181/181 [==============================] - 50s 275ms/step - loss: -5.2426 - iou_score: 0.4888 - f1-score: 0.5978 - val_loss: -2.4866 - val_iou_score: 0.3755 - val_f1-score: 0.4540
# Epoch 26/100
# 181/181 [==============================] - 50s 274ms/step - loss: -5.4349 - iou_score: 0.4990 - f1-score: 0.6091 - val_loss: -2.6543 - val_iou_score: 0.4227 - val_f1-score: 0.4970
# Epoch 27/100
# 181/181 [==============================] - 50s 274ms/step - loss: -5.4273 - iou_score: 0.5024 - f1-score: 0.6112 - val_loss: -2.4775 - val_iou_score: 0.3840 - val_f1-score: 0.4600
# Epoch 28/100
# 181/181 [==============================] - 49s 273ms/step - loss: -5.3738 - iou_score: 0.4983 - f1-score: 0.6071 - val_loss: -2.7320 - val_iou_score: 0.4014 - val_f1-score: 0.4783
# Epoch 29/100
# 181/181 [==============================] - 50s 274ms/step - loss: -5.5932 - iou_score: 0.5018 - f1-score: 0.6100 - val_loss: -2.6526 - val_iou_score: 0.4251 - val_f1-score: 0.4970
# Epoch 30/100
# 181/181 [==============================] - 49s 272ms/step - loss: -5.4949 - iou_score: 0.4975 - f1-score: 0.6052 - val_loss: -2.6486 - val_iou_score: 0.3926 - val_f1-score: 0.4687
# Epoch 31/100
# 181/181 [==============================] - 50s 275ms/step - loss: -5.5022 - iou_score: 0.5043 - f1-score: 0.6110 - val_loss: -2.6299 - val_iou_score: 0.4044 - val_f1-score: 0.4755
# Epoch 32/100
# 181/181 [==============================] - 50s 274ms/step - loss: -5.5079 - iou_score: 0.4982 - f1-score: 0.6056 - val_loss: -2.5544 - val_iou_score: 0.4030 - val_f1-score: 0.4816
# Epoch 33/100
# 181/181 [==============================] - 50s 279ms/step - loss: -5.6578 - iou_score: 0.5090 - f1-score: 0.6178 - val_loss: -2.6703 - val_iou_score: 0.4259 - val_f1-score: 0.4999
# Epoch 34/100
# 181/181 [==============================] - 50s 276ms/step - loss: -5.5365 - iou_score: 0.5091 - f1-score: 0.6158 - val_loss: -2.6156 - val_iou_score: 0.4283 - val_f1-score: 0.5020
# Epoch 35/100
# 181/181 [==============================] - 50s 276ms/step - loss: -5.5253 - iou_score: 0.5115 - f1-score: 0.6179 - val_loss: -2.6849 - val_iou_score: 0.4435 - val_f1-score: 0.5174
# Epoch 36/100
# 181/181 [==============================] - 50s 276ms/step - loss: -5.7038 - iou_score: 0.5219 - f1-score: 0.6274 - val_loss: -2.7157 - val_iou_score: 0.4560 - val_f1-score: 0.5292
# Epoch 37/100
# 181/181 [==============================] - 50s 276ms/step - loss: -5.6352 - iou_score: 0.5194 - f1-score: 0.6255 - val_loss: -2.7680 - val_iou_score: 0.4454 - val_f1-score: 0.5181
# Epoch 38/100
# 181/181 [==============================] - 50s 276ms/step - loss: -5.6735 - iou_score: 0.5144 - f1-score: 0.6188 - val_loss: -2.6060 - val_iou_score: 0.4586 - val_f1-score: 0.5306
# Epoch 39/100
# 181/181 [==============================] - 49s 273ms/step - loss: -5.6901 - iou_score: 0.5296 - f1-score: 0.6354 - val_loss: -2.6701 - val_iou_score: 0.4158 - val_f1-score: 0.4891
# Epoch 40/100
# 181/181 [==============================] - 49s 272ms/step - loss: -5.6356 - iou_score: 0.5146 - f1-score: 0.6216 - val_loss: -2.5530 - val_iou_score: 0.4446 - val_f1-score: 0.5163
# Epoch 41/100
# 181/181 [==============================] - 49s 273ms/step - loss: -5.6964 - iou_score: 0.5274 - f1-score: 0.6337 - val_loss: -2.7007 - val_iou_score: 0.4463 - val_f1-score: 0.5182
# Epoch 42/100
# 181/181 [==============================] - 50s 274ms/step - loss: -5.5966 - iou_score: 0.5226 - f1-score: 0.6272 - val_loss: -2.6876 - val_iou_score: 0.4198 - val_f1-score: 0.4927
# Epoch 43/100
# 181/181 [==============================] - 49s 273ms/step - loss: -5.6807 - iou_score: 0.5268 - f1-score: 0.6306 - val_loss: -2.6790 - val_iou_score: 0.4454 - val_f1-score: 0.5177
# Epoch 44/100
# 181/181 [==============================] - 49s 272ms/step - loss: -5.8536 - iou_score: 0.5388 - f1-score: 0.6430 - val_loss: -2.6749 - val_iou_score: 0.4570 - val_f1-score: 0.5283
# Epoch 45/100
# 181/181 [==============================] - 50s 276ms/step - loss: -5.8639 - iou_score: 0.5432 - f1-score: 0.6458 - val_loss: -2.7931 - val_iou_score: 0.4529 - val_f1-score: 0.5249
# Epoch 46/100
# 181/181 [==============================] - 49s 271ms/step - loss: -5.8350 - iou_score: 0.5435 - f1-score: 0.6457 - val_loss: -2.6444 - val_iou_score: 0.4440 - val_f1-score: 0.5152
# Epoch 47/100
# 181/181 [==============================] - 49s 273ms/step - loss: -5.8977 - iou_score: 0.5480 - f1-score: 0.6528 - val_loss: -2.7140 - val_iou_score: 0.4486 - val_f1-score: 0.5209
# Epoch 48/100
# 181/181 [==============================] - 49s 273ms/step - loss: -5.8732 - iou_score: 0.5449 - f1-score: 0.6468 - val_loss: -2.6895 - val_iou_score: 0.4632 - val_f1-score: 0.5340
# Epoch 49/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.7932 - iou_score: 0.5365 - f1-score: 0.6385 - val_loss: -2.7508 - val_iou_score: 0.4512 - val_f1-score: 0.5245
# Epoch 50/100
# 181/181 [==============================] - 50s 275ms/step - loss: -5.7440 - iou_score: 0.5459 - f1-score: 0.6494 - val_loss: -2.7546 - val_iou_score: 0.4625 - val_f1-score: 0.5347
# Epoch 51/100
# 181/181 [==============================] - 49s 272ms/step - loss: -5.9178 - iou_score: 0.5503 - f1-score: 0.6533 - val_loss: -2.7732 - val_iou_score: 0.4546 - val_f1-score: 0.5254
# Epoch 52/100
# 181/181 [==============================] - 49s 272ms/step - loss: -5.8806 - iou_score: 0.5458 - f1-score: 0.6488 - val_loss: -2.7681 - val_iou_score: 0.4635 - val_f1-score: 0.5350
# Epoch 53/100
# 181/181 [==============================] - 50s 274ms/step - loss: -5.8082 - iou_score: 0.5497 - f1-score: 0.6509 - val_loss: -2.6894 - val_iou_score: 0.4777 - val_f1-score: 0.5492
# Epoch 54/100
# 181/181 [==============================] - 50s 274ms/step - loss: -5.9070 - iou_score: 0.5613 - f1-score: 0.6621 - val_loss: -2.7210 - val_iou_score: 0.4747 - val_f1-score: 0.5464
# Epoch 55/100
# 181/181 [==============================] - 49s 272ms/step - loss: -5.9294 - iou_score: 0.5536 - f1-score: 0.6549 - val_loss: -2.7728 - val_iou_score: 0.4696 - val_f1-score: 0.5393
# Epoch 56/100
# 181/181 [==============================] - 50s 275ms/step - loss: -5.8504 - iou_score: 0.5563 - f1-score: 0.6575 - val_loss: -2.8164 - val_iou_score: 0.4727 - val_f1-score: 0.5432
# Epoch 57/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.8314 - iou_score: 0.5406 - f1-score: 0.6425 - val_loss: -2.6371 - val_iou_score: 0.4653 - val_f1-score: 0.5360
# Epoch 58/100
# 181/181 [==============================] - 50s 275ms/step - loss: -6.0877 - iou_score: 0.5595 - f1-score: 0.6622 - val_loss: -2.6372 - val_iou_score: 0.4563 - val_f1-score: 0.5263
# Epoch 59/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.7279 - iou_score: 0.5448 - f1-score: 0.6473 - val_loss: -2.7394 - val_iou_score: 0.4560 - val_f1-score: 0.5289
# Epoch 60/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.0473 - iou_score: 0.5693 - f1-score: 0.6707 - val_loss: -2.7577 - val_iou_score: 0.4459 - val_f1-score: 0.5193
# Epoch 61/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.9084 - iou_score: 0.5604 - f1-score: 0.6607 - val_loss: -2.8529 - val_iou_score: 0.4613 - val_f1-score: 0.5329
# Epoch 62/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.8792 - iou_score: 0.5619 - f1-score: 0.6598 - val_loss: -2.7910 - val_iou_score: 0.4565 - val_f1-score: 0.5275
# Epoch 63/100
# 181/181 [==============================] - 50s 276ms/step - loss: -5.9162 - iou_score: 0.5539 - f1-score: 0.6526 - val_loss: -2.7041 - val_iou_score: 0.4687 - val_f1-score: 0.5404
# Epoch 64/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.0329 - iou_score: 0.5640 - f1-score: 0.6649 - val_loss: -2.7687 - val_iou_score: 0.4844 - val_f1-score: 0.5542
# Epoch 65/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.8939 - iou_score: 0.5702 - f1-score: 0.6680 - val_loss: -2.8145 - val_iou_score: 0.4871 - val_f1-score: 0.5583
# Epoch 66/100
# 181/181 [==============================] - 50s 274ms/step - loss: -5.9694 - iou_score: 0.5689 - f1-score: 0.6694 - val_loss: -2.8519 - val_iou_score: 0.4806 - val_f1-score: 0.5501
# Epoch 67/100
# 181/181 [==============================] - 50s 274ms/step - loss: -6.1013 - iou_score: 0.5816 - f1-score: 0.6817 - val_loss: -2.8298 - val_iou_score: 0.4918 - val_f1-score: 0.5624
# Epoch 68/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.1126 - iou_score: 0.5901 - f1-score: 0.6884 - val_loss: -2.9093 - val_iou_score: 0.4984 - val_f1-score: 0.5687
# Epoch 69/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.0252 - iou_score: 0.5816 - f1-score: 0.6782 - val_loss: -2.8057 - val_iou_score: 0.4952 - val_f1-score: 0.5647
# Epoch 70/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.0560 - iou_score: 0.5845 - f1-score: 0.6825 - val_loss: -2.8321 - val_iou_score: 0.4967 - val_f1-score: 0.5681
# Epoch 71/100
# 181/181 [==============================] - 50s 275ms/step - loss: -5.9918 - iou_score: 0.5723 - f1-score: 0.6681 - val_loss: -2.7906 - val_iou_score: 0.4891 - val_f1-score: 0.5615
# Epoch 72/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.9726 - iou_score: 0.5777 - f1-score: 0.6752 - val_loss: -2.8599 - val_iou_score: 0.4881 - val_f1-score: 0.5576
# Epoch 73/100
# 181/181 [==============================] - 50s 278ms/step - loss: -6.1502 - iou_score: 0.5788 - f1-score: 0.6762 - val_loss: -2.8097 - val_iou_score: 0.4930 - val_f1-score: 0.5652
# Epoch 74/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.2006 - iou_score: 0.5892 - f1-score: 0.6862 - val_loss: -2.8286 - val_iou_score: 0.4817 - val_f1-score: 0.5522
# Epoch 75/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.0300 - iou_score: 0.5768 - f1-score: 0.6771 - val_loss: -2.7700 - val_iou_score: 0.4645 - val_f1-score: 0.5368
# Epoch 76/100
# 181/181 [==============================] - 50s 276ms/step - loss: -5.9224 - iou_score: 0.5625 - f1-score: 0.6620 - val_loss: -2.8130 - val_iou_score: 0.4628 - val_f1-score: 0.5338
# Epoch 77/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.1908 - iou_score: 0.5837 - f1-score: 0.6813 - val_loss: -2.8108 - val_iou_score: 0.4626 - val_f1-score: 0.5342
# Epoch 78/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.1322 - iou_score: 0.5907 - f1-score: 0.6878 - val_loss: -2.6103 - val_iou_score: 0.5008 - val_f1-score: 0.5700
# Epoch 79/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.2061 - iou_score: 0.5939 - f1-score: 0.6924 - val_loss: -2.7121 - val_iou_score: 0.3994 - val_f1-score: 0.4733
# Epoch 80/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.1140 - iou_score: 0.5926 - f1-score: 0.6883 - val_loss: -2.7920 - val_iou_score: 0.4948 - val_f1-score: 0.5674
# Epoch 81/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.0759 - iou_score: 0.5933 - f1-score: 0.6899 - val_loss: -2.7747 - val_iou_score: 0.4310 - val_f1-score: 0.5024
# Epoch 82/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.2365 - iou_score: 0.5934 - f1-score: 0.6882 - val_loss: -2.7965 - val_iou_score: 0.4795 - val_f1-score: 0.5485
# Epoch 83/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.0799 - iou_score: 0.6036 - f1-score: 0.6984 - val_loss: -2.8868 - val_iou_score: 0.5051 - val_f1-score: 0.5753
# Epoch 84/100
# 181/181 [==============================] - 50s 278ms/step - loss: -6.2355 - iou_score: 0.5922 - f1-score: 0.6932 - val_loss: -2.5369 - val_iou_score: 0.3468 - val_f1-score: 0.4265
# Epoch 85/100
# 181/181 [==============================] - 50s 278ms/step - loss: -5.8954 - iou_score: 0.5453 - f1-score: 0.6473 - val_loss: -3.0839 - val_iou_score: 0.4941 - val_f1-score: 0.5672
# Epoch 86/100
# 181/181 [==============================] - 50s 279ms/step - loss: -6.3242 - iou_score: 0.5983 - f1-score: 0.7014 - val_loss: -3.2128 - val_iou_score: 0.5196 - val_f1-score: 0.5906
# Epoch 87/100
# 181/181 [==============================] - 50s 279ms/step - loss: -6.3317 - iou_score: 0.6021 - f1-score: 0.7029 - val_loss: -3.2379 - val_iou_score: 0.4885 - val_f1-score: 0.5614
# Epoch 88/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.3241 - iou_score: 0.5937 - f1-score: 0.6925 - val_loss: -3.1799 - val_iou_score: 0.5189 - val_f1-score: 0.5925
# Epoch 89/100
# 181/181 [==============================] - 50s 278ms/step - loss: -6.2271 - iou_score: 0.5897 - f1-score: 0.6907 - val_loss: -2.7193 - val_iou_score: 0.4013 - val_f1-score: 0.4811
# Epoch 90/100
# 181/181 [==============================] - 50s 276ms/step - loss: -5.5994 - iou_score: 0.5134 - f1-score: 0.6204 - val_loss: -2.8733 - val_iou_score: 0.4158 - val_f1-score: 0.4942
# Epoch 91/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.9624 - iou_score: 0.5390 - f1-score: 0.6465 - val_loss: -3.1770 - val_iou_score: 0.5106 - val_f1-score: 0.5833
# Epoch 92/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.0156 - iou_score: 0.5420 - f1-score: 0.6493 - val_loss: -3.1814 - val_iou_score: 0.4616 - val_f1-score: 0.5354
# Epoch 93/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.0876 - iou_score: 0.5669 - f1-score: 0.6713 - val_loss: -3.0105 - val_iou_score: 0.4602 - val_f1-score: 0.5337
# Epoch 94/100
# 181/181 [==============================] - 50s 277ms/step - loss: -5.8625 - iou_score: 0.5198 - f1-score: 0.6255 - val_loss: -3.1204 - val_iou_score: 0.4809 - val_f1-score: 0.5553
# Epoch 95/100
# 181/181 [==============================] - 50s 278ms/step - loss: -6.2148 - iou_score: 0.5740 - f1-score: 0.6799 - val_loss: -3.1780 - val_iou_score: 0.4884 - val_f1-score: 0.5620
# Epoch 96/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.3039 - iou_score: 0.5963 - f1-score: 0.6993 - val_loss: -3.2553 - val_iou_score: 0.5114 - val_f1-score: 0.5834
# Epoch 97/100
# 181/181 [==============================] - 50s 277ms/step - loss: -6.2744 - iou_score: 0.6042 - f1-score: 0.7042 - val_loss: -3.2302 - val_iou_score: 0.5356 - val_f1-score: 0.6067
# Epoch 98/100
# 181/181 [==============================] - 50s 278ms/step - loss: -6.2596 - iou_score: 0.6070 - f1-score: 0.7047 - val_loss: -3.2769 - val_iou_score: 0.5236 - val_f1-score: 0.5948
# Epoch 99/100
# 181/181 [==============================] - 51s 280ms/step - loss: -6.3830 - iou_score: 0.5873 - f1-score: 0.6879 - val_loss: -3.2023 - val_iou_score: 0.4767 - val_f1-score: 0.5486
# Epoch 100/100
# 181/181 [==============================] - 50s 276ms/step - loss: -6.0337 - iou_score: 0.5439 - f1-score: 0.6490 - val_loss: -3.2088 - val_iou_score: 0.5028 - val_f1-score: 0.5770

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU Score')
plt.title('Training and validation IOU Score')
plt.xlabel('Epochs')
plt.ylabel('IOU Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}_with_dice_focal_loss).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}_with_dice_focal_loss).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)

# %%
pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 7s 109ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

class_APs = []

for i in range(n_classes):
    class_predicted_masks = (predicted_masks == i).astype(int)
    class_test_masks = (test_masks_ == i).astype(int)
    
    class_predicted_masks_flat = class_predicted_masks.flatten().reshape(-1, 1)
    class_test_masks_flat = class_test_masks.flatten().reshape(-1, 1)
    
    class_APs.append(average_precision_score(class_test_masks_flat, class_predicted_masks_flat, average='micro'))

mAP_score = np.mean(class_APs)
print("Overall mAP score =", mAP_score)
# Out:
# Mean IoU = 0.5799726
# IoU for each class:
# Background: 0.30900123715400696
# Building Flooded: 0.658708930015564
# Building Non-Flooded: 0.6796920895576477
# Road Flooded: 0.5625953674316406
# Road Non-Flooded: 0.7458686232566833
# Water: 0.6539359092712402
# Tree: 0.5418031811714172
# Vehicle: 0.40101465582847595
# Pool: 0.47815585136413574
# Grass: 0.7689505219459534
# Overall mAP score = 0.5624442597480643

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    if i == 0: 
        continue
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

# Calculate mean IoU excluding background class
mean_IoU_without_background = np.mean(class_IoUs)
print("Mean IoU (excluding Background):", mean_IoU_without_background)
# Out:
# Mean IoU = 0.5799726
# IoU for each class:
# Building Flooded: 0.658708930015564
# Building Non-Flooded: 0.6796920895576477
# Road Flooded: 0.5625953674316406
# Road Non-Flooded: 0.7458686232566833
# Water: 0.6539359092712402
# Tree: 0.5418031811714172
# Vehicle: 0.40101465582847595
# Pool: 0.47815585136413574
# Grass: 0.7689505219459534
# Mean IoU (excluding Background): 0.6100806

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names, class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
