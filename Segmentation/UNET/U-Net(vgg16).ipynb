# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 8
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'vgg16'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}
    
color_map = {'Background':[0, 0, 0], 'Building-flooded':[196, 0, 0], 'Building-non-flooded': [255,128,128], 'Road-flooded':[128, 128, 0],  'Road-non-flooded':[128, 128, 128], 
                 'Water': [0, 191, 255], 'Tree':[34, 139, 34], 'Vehicle': [123, 37, 118],  'Pool':[0, 68, 255],'Grass':[127, 224, 104]}

handles = [Rectangle((0,0),1,1, color = (np.array(c)/255)) for n,c in color_map.items()]

labels = [n for n,c in color_map.items()]


def to_RGB(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """    
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    for key, val in class_map.items():
      label_seg [np.all(label == class_map[key],axis=-1)] = color_map[key]  
    return label_seg

def display_images_with_masks(image, mask, predicted):
    plt.figure(figsize=(12, 8))
    plt.subplot(131)
    plt.title('Testing Image')
    plt.imshow(image)
    plt.subplot(132)
    plt.title('Testing Label')
    plt.imshow(to_RGB(np.tile(np.expand_dims(mask, axis=-1), (1, 1, 3)))) 
    plt.subplot(133)
    plt.title('Prediction')
    plt.imshow(to_RGB(np.tile(np.expand_dims(predicted, axis=-1), (1, 1, 3))))
    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
if MODEL == 'unet':
    model = sm.Unet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'fpn':
    model = sm.FPN(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
else:
    raise ValueError('Unknown model')

model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 4, 4, 512)    0           ['block5_conv3[0][0]']
#
#  center_block1_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['block5_pool[0][0]']
#
#  center_block1_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block1_conv[0][0]']
#  zation)
#
#  center_block1_relu (Activation  (None, 4, 4, 512)   0           ['center_block1_bn[0][0]']
#  )
#
#  center_block2_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['center_block1_relu[0][0]']
#
#  center_block2_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block2_conv[0][0]']
#  zation)
#
#  center_block2_relu (Activation  (None, 4, 4, 512)   0           ['center_block2_bn[0][0]']
#  )
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 512)   0           ['center_block2_relu[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 1024)  0           ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block5_conv3[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 8, 8, 256)    2359296     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 8, 8, 256)    589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 768)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block4_conv3[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 16, 16, 128)  884736      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 16, 16, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 384)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block3_conv3[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 32, 32, 64)   221184      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 32, 32, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64)  0           ['decoder_stage2b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 192)  0          ['decoder_stage3_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block2_conv2[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 32)   55296       ['decoder_stage3_concat[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3b_conv (Conv2D)  (None, 64, 64, 32)   9216        ['decoder_stage3a_relu[0][0]']
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3b_conv[0][0]']
#  lization)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3b_bn[0][0]']
#  on)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 128, 128, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 128, 128, 10  1450        ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  softmax (Activation)           (None, 128, 128, 10  0           ['final_conv[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 23,753,578
# Trainable params: 23,749,546
# Non-trainable params: 4,032
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 21s 78ms/step - loss: 1.0336 - iou_score: 0.1793 - val_loss: 0.9575 - val_iou_score: 0.1924
# Epoch 2/100
# 181/181 [==============================] - 11s 59ms/step - loss: 0.8887 - iou_score: 0.2503 - val_loss: 1.0281 - val_iou_score: 0.1619
# Epoch 3/100
# 181/181 [==============================] - 11s 59ms/step - loss: 0.8432 - iou_score: 0.2848 - val_loss: 0.9239 - val_iou_score: 0.2194
# Epoch 4/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.8110 - iou_score: 0.3100 - val_loss: 0.9412 - val_iou_score: 0.2173
# Epoch 5/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.7665 - iou_score: 0.3496 - val_loss: 0.8313 - val_iou_score: 0.2783
# Epoch 6/100
# 181/181 [==============================] - 11s 59ms/step - loss: 0.7327 - iou_score: 0.3783 - val_loss: 0.8229 - val_iou_score: 0.2876
# Epoch 7/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.7089 - iou_score: 0.3983 - val_loss: 0.7955 - val_iou_score: 0.3045
# Epoch 8/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.6892 - iou_score: 0.4159 - val_loss: 0.7994 - val_iou_score: 0.3101
# Epoch 9/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.6687 - iou_score: 0.4316 - val_loss: 0.7888 - val_iou_score: 0.3176
# Epoch 10/100
# 181/181 [==============================] - 11s 59ms/step - loss: 0.6656 - iou_score: 0.4356 - val_loss: 0.7686 - val_iou_score: 0.3262
# Epoch 11/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.6466 - iou_score: 0.4491 - val_loss: 0.7828 - val_iou_score: 0.3163
# Epoch 12/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.6352 - iou_score: 0.4588 - val_loss: 0.7538 - val_iou_score: 0.3381
# Epoch 13/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.6248 - iou_score: 0.4672 - val_loss: 0.7515 - val_iou_score: 0.3416
# Epoch 14/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.6105 - iou_score: 0.4787 - val_loss: 0.7496 - val_iou_score: 0.3416
# Epoch 15/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.6101 - iou_score: 0.4790 - val_loss: 0.7447 - val_iou_score: 0.3443
# Epoch 16/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5979 - iou_score: 0.4886 - val_loss: 0.7480 - val_iou_score: 0.3485
# Epoch 17/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5888 - iou_score: 0.4942 - val_loss: 0.7353 - val_iou_score: 0.3547
# Epoch 18/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5809 - iou_score: 0.5011 - val_loss: 0.7456 - val_iou_score: 0.3426
# Epoch 19/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5720 - iou_score: 0.5095 - val_loss: 0.7416 - val_iou_score: 0.3501
# Epoch 20/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5691 - iou_score: 0.5106 - val_loss: 0.7399 - val_iou_score: 0.3512
# Epoch 21/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5732 - iou_score: 0.5061 - val_loss: 0.7312 - val_iou_score: 0.3555
# Epoch 22/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5597 - iou_score: 0.5188 - val_loss: 0.7326 - val_iou_score: 0.3594
# Epoch 23/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5470 - iou_score: 0.5294 - val_loss: 0.7195 - val_iou_score: 0.3628
# Epoch 24/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5393 - iou_score: 0.5348 - val_loss: 0.7313 - val_iou_score: 0.3566
# Epoch 25/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5328 - iou_score: 0.5400 - val_loss: 0.7265 - val_iou_score: 0.3602
# Epoch 26/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5287 - iou_score: 0.5425 - val_loss: 0.7350 - val_iou_score: 0.3544
# Epoch 27/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5234 - iou_score: 0.5474 - val_loss: 0.7264 - val_iou_score: 0.3601
# Epoch 28/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5219 - iou_score: 0.5499 - val_loss: 0.7161 - val_iou_score: 0.3687
# Epoch 29/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5148 - iou_score: 0.5539 - val_loss: 0.7189 - val_iou_score: 0.3667
# Epoch 30/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.5064 - iou_score: 0.5629 - val_loss: 0.7235 - val_iou_score: 0.3652
# Epoch 31/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5056 - iou_score: 0.5615 - val_loss: 0.7176 - val_iou_score: 0.3699
# Epoch 32/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.5016 - iou_score: 0.5642 - val_loss: 0.7093 - val_iou_score: 0.3739
# Epoch 33/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4866 - iou_score: 0.5776 - val_loss: 0.7123 - val_iou_score: 0.3704
# Epoch 34/100
# 181/181 [==============================] - 11s 59ms/step - loss: 0.4870 - iou_score: 0.5774 - val_loss: 0.7083 - val_iou_score: 0.3766
# Epoch 35/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4860 - iou_score: 0.5790 - val_loss: 0.7045 - val_iou_score: 0.3780
# Epoch 36/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4728 - iou_score: 0.5873 - val_loss: 0.7068 - val_iou_score: 0.3763
# Epoch 37/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4782 - iou_score: 0.5814 - val_loss: 0.7031 - val_iou_score: 0.3787
# Epoch 38/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4704 - iou_score: 0.5879 - val_loss: 0.7075 - val_iou_score: 0.3774
# Epoch 39/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4701 - iou_score: 0.5890 - val_loss: 0.7091 - val_iou_score: 0.3776
# Epoch 40/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4540 - iou_score: 0.6027 - val_loss: 0.6994 - val_iou_score: 0.3827
# Epoch 41/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4606 - iou_score: 0.5975 - val_loss: 0.7205 - val_iou_score: 0.3728
# Epoch 42/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4627 - iou_score: 0.5957 - val_loss: 0.7098 - val_iou_score: 0.3753
# Epoch 43/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4502 - iou_score: 0.6058 - val_loss: 0.7120 - val_iou_score: 0.3767
# Epoch 44/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4505 - iou_score: 0.6042 - val_loss: 0.7060 - val_iou_score: 0.3826
# Epoch 45/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4316 - iou_score: 0.6230 - val_loss: 0.7091 - val_iou_score: 0.3784
# Epoch 46/100
# 181/181 [==============================] - 11s 59ms/step - loss: 0.4428 - iou_score: 0.6103 - val_loss: 0.6909 - val_iou_score: 0.3898
# Epoch 47/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4301 - iou_score: 0.6208 - val_loss: 0.6978 - val_iou_score: 0.3864
# Epoch 48/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4327 - iou_score: 0.6202 - val_loss: 0.7011 - val_iou_score: 0.3845
# Epoch 49/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4278 - iou_score: 0.6219 - val_loss: 0.7039 - val_iou_score: 0.3849
# Epoch 50/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4257 - iou_score: 0.6248 - val_loss: 0.7182 - val_iou_score: 0.3788
# Epoch 51/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4273 - iou_score: 0.6234 - val_loss: 0.7029 - val_iou_score: 0.3842
# Epoch 52/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4198 - iou_score: 0.6299 - val_loss: 0.6995 - val_iou_score: 0.3883
# Epoch 53/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4295 - iou_score: 0.6213 - val_loss: 0.7002 - val_iou_score: 0.3850
# Epoch 54/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4362 - iou_score: 0.6152 - val_loss: 0.7109 - val_iou_score: 0.3760
# Epoch 55/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4205 - iou_score: 0.6286 - val_loss: 0.7195 - val_iou_score: 0.3718
# Epoch 56/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4336 - iou_score: 0.6183 - val_loss: 0.7016 - val_iou_score: 0.3852
# Epoch 57/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4256 - iou_score: 0.6227 - val_loss: 0.7021 - val_iou_score: 0.3832
# Epoch 58/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4115 - iou_score: 0.6346 - val_loss: 0.6937 - val_iou_score: 0.3886
# Epoch 59/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4087 - iou_score: 0.6360 - val_loss: 0.6995 - val_iou_score: 0.3869
# Epoch 60/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4085 - iou_score: 0.6361 - val_loss: 0.7164 - val_iou_score: 0.3755
# Epoch 61/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4075 - iou_score: 0.6376 - val_loss: 0.7046 - val_iou_score: 0.3796
# Epoch 62/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4017 - iou_score: 0.6426 - val_loss: 0.6996 - val_iou_score: 0.3870
# Epoch 63/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3925 - iou_score: 0.6489 - val_loss: 0.6943 - val_iou_score: 0.3903
# Epoch 64/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4056 - iou_score: 0.6370 - val_loss: 0.7042 - val_iou_score: 0.3888
# Epoch 65/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4070 - iou_score: 0.6353 - val_loss: 0.6990 - val_iou_score: 0.3873
# Epoch 66/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3904 - iou_score: 0.6521 - val_loss: 0.7011 - val_iou_score: 0.3866
# Epoch 67/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3855 - iou_score: 0.6556 - val_loss: 0.7084 - val_iou_score: 0.3849
# Epoch 68/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.4000 - iou_score: 0.6440 - val_loss: 0.7075 - val_iou_score: 0.3848
# Epoch 69/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3949 - iou_score: 0.6459 - val_loss: 0.6998 - val_iou_score: 0.3880
# Epoch 70/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3805 - iou_score: 0.6602 - val_loss: 0.7352 - val_iou_score: 0.3664
# Epoch 71/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.4012 - iou_score: 0.6410 - val_loss: 0.7128 - val_iou_score: 0.3820
# Epoch 72/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3875 - iou_score: 0.6519 - val_loss: 0.7246 - val_iou_score: 0.3749
# Epoch 73/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3853 - iou_score: 0.6540 - val_loss: 0.7101 - val_iou_score: 0.3804
# Epoch 74/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3865 - iou_score: 0.6555 - val_loss: 0.7010 - val_iou_score: 0.3895
# Epoch 75/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3770 - iou_score: 0.6591 - val_loss: 0.6943 - val_iou_score: 0.3938
# Epoch 76/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3683 - iou_score: 0.6670 - val_loss: 0.6977 - val_iou_score: 0.3906
# Epoch 77/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3716 - iou_score: 0.6630 - val_loss: 0.7088 - val_iou_score: 0.3846
# Epoch 78/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3888 - iou_score: 0.6535 - val_loss: 0.7289 - val_iou_score: 0.3718
# Epoch 79/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3870 - iou_score: 0.6529 - val_loss: 0.7011 - val_iou_score: 0.3912
# Epoch 80/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3809 - iou_score: 0.6555 - val_loss: 0.6965 - val_iou_score: 0.3924
# Epoch 81/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3627 - iou_score: 0.6719 - val_loss: 0.6990 - val_iou_score: 0.3928
# Epoch 82/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3688 - iou_score: 0.6664 - val_loss: 0.6933 - val_iou_score: 0.3967
# Epoch 83/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3622 - iou_score: 0.6714 - val_loss: 0.6933 - val_iou_score: 0.3958
# Epoch 84/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3671 - iou_score: 0.6669 - val_loss: 0.7030 - val_iou_score: 0.3871
# Epoch 85/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3678 - iou_score: 0.6674 - val_loss: 0.7008 - val_iou_score: 0.3910
# Epoch 86/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3601 - iou_score: 0.6718 - val_loss: 0.6996 - val_iou_score: 0.3912
# Epoch 87/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3511 - iou_score: 0.6794 - val_loss: 0.6998 - val_iou_score: 0.3950
# Epoch 88/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3604 - iou_score: 0.6715 - val_loss: 0.7056 - val_iou_score: 0.3926
# Epoch 89/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3913 - iou_score: 0.6490 - val_loss: 0.7064 - val_iou_score: 0.3907
# Epoch 90/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3925 - iou_score: 0.6507 - val_loss: 0.7002 - val_iou_score: 0.3910
# Epoch 91/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3654 - iou_score: 0.6688 - val_loss: 0.7108 - val_iou_score: 0.3853
# Epoch 92/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3720 - iou_score: 0.6634 - val_loss: 0.7031 - val_iou_score: 0.3878
# Epoch 93/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3573 - iou_score: 0.6758 - val_loss: 0.6971 - val_iou_score: 0.3914
# Epoch 94/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3438 - iou_score: 0.6867 - val_loss: 0.7044 - val_iou_score: 0.3922
# Epoch 95/100
# 181/181 [==============================] - 11s 61ms/step - loss: 0.3425 - iou_score: 0.6873 - val_loss: 0.6976 - val_iou_score: 0.3943
# Epoch 96/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3478 - iou_score: 0.6818 - val_loss: 0.7119 - val_iou_score: 0.3921
# Epoch 97/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3405 - iou_score: 0.6885 - val_loss: 0.7065 - val_iou_score: 0.3911
# Epoch 98/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3555 - iou_score: 0.6745 - val_loss: 0.7036 - val_iou_score: 0.3964
# Epoch 99/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3413 - iou_score: 0.6877 - val_loss: 0.7030 - val_iou_score: 0.3943
# Epoch 100/100
# 181/181 [==============================] - 11s 60ms/step - loss: 0.3465 - iou_score: 0.6821 - val_loss: 0.7075 - val_iou_score: 0.3940

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  47.42752015590668 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 1s 32ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

class_APs = []

for i in range(n_classes):
    class_predicted_masks = (predicted_masks == i).astype(int)
    class_test_masks = (test_masks_ == i).astype(int)
    
    class_predicted_masks_flat = class_predicted_masks.flatten().reshape(-1, 1)
    class_test_masks_flat = class_test_masks.flatten().reshape(-1, 1)
    
    class_APs.append(average_precision_score(class_test_masks_flat, class_predicted_masks_flat, average='micro'))

mAP_score = np.mean(class_APs)
print("Overall mAP score =", mAP_score)
# Out:
# Mean IoU = 0.6376397
# IoU for each class:
# Background: 0.4276190400123596
# Building Flooded: 0.6449142098426819
# Building Non-Flooded: 0.7166215777397156
# Road Flooded: 0.5926026105880737
# Road Non-Flooded: 0.7934584617614746
# Water: 0.7710520625114441
# Tree: 0.7763617634773254
# Vehicle: 0.334619402885437
# Pool: 0.45136940479278564
# Grass: 0.8677783608436584
# Overall mAP score = 0.619436535587431

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names, class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
