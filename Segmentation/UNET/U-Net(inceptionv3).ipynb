# %%
import os
import cv2
import glob
import pickle
import numpy as np
from tqdm import tqdm
from keras.utils import normalize
from matplotlib import pyplot as plt
from keras.utils import to_categorical
from matplotlib.patches import Rectangle
from sklearn.metrics import average_precision_score

SIZE_X = 128
SIZE_Y = 128
n_channels = 3
n_classes = 10
Batch_size = 16
EPOCHS = 100
MODEL = 'unet'
BACKBONE = 'inceptionv3'
encoder_weights = 'imagenet'
activation = 'softmax'
parent_directory = r'E:\Segmentation\datasets\FloodNet-Supervised_v1.0'

# %%
def load_images(parent_directory, split='train'):
    images = []
    masks = [] 

    image_folder_path = f'{parent_directory}\{split}\{split}-org-img'
    for img_path in tqdm(glob.glob(os.path.join(image_folder_path, "*.jpg"))):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        images.append(img)

        mask_path = (img_path.replace('org', 'label')).replace('jpg', 'png')
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        masks.append(mask)
                
    images = np.array(images)
    masks = np.array(masks)

    print(f'{split.upper()}: Images loaded: {images.shape[0]}')
    print(f'{split.upper()}: Masks loaded: {masks.shape[0]}')

    return images, masks

# %%
def preprocess_data(images, masks, unet_preporcessing):
    if unet_preporcessing:
        images = unet_preporcessing(images)
    else:
        images = normalize(images, axis=1)
        
    masks = np.expand_dims(masks, axis=-1)
    masks = to_categorical(masks, num_classes=n_classes)
    masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], n_classes))

    return images, masks

# %%
def display_images_with_masks(image, mask, predicted):
    
    class_map= {'Background':0, 'Building-flooded':1, 'Building-non-flooded':2, 'Road-flooded':3, 'Road-non-flooded':4, 'Water':5, 'Tree':6, 'Vehicle':7, 'Pool':8, 'Grass':9}

    color_map = {
        "Background": [0, 0, 0],
        "Building-flooded": [255, 0, 0],
        "Building-non-flooded": [0, 255, 0],
        "Road-flooded": [0, 255, 120],
        "Road-non-flooded": [0, 0, 255],
        "Water": [255, 0, 255],
        "Tree": [70, 70, 70],
        "Vehicle": [102, 102, 156],
        "Pool": [190, 153, 153],
        "Grass": [180, 165, 180]
    }

    handles = [
        Rectangle((0, 0), 1, 1, color=np.array(c)/255) for n, c in color_map.items()
    ]
    labels = [n for n, c in color_map.items()]

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 3, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
    plt.title('Image')

    plt.subplot(1, 3, 2)
    mask_colored = np.zeros_like(image, dtype=np.uint8)
    for class_name, class_idx in class_map.items():
        color = color_map[class_name]
        mask_indices = np.where(mask == class_idx)
        mask_colored[mask_indices[0], mask_indices[1], :] = color
    plt.imshow(cv2.cvtColor(mask_colored, cv2.COLOR_BGR2RGB))
    plt.title('Ground-Truth Mask')

    plt.subplot(1, 3, 3)
    mask_colored1 = np.zeros_like(image, dtype=np.uint8)
    for class_name1, class_idx1 in class_map.items():
        color1 = color_map[class_name1]
        mask_indices1 = np.where(predicted == class_idx1)
        mask_colored1[mask_indices1[0], mask_indices1[1], :] = color1
    plt.imshow(cv2.cvtColor(mask_colored1, cv2.COLOR_BGR2RGB))
    plt.title('Predicted Mask')

    plt.legend(handles, labels, bbox_to_anchor =(-0.8,-0.5), loc='lower center', ncol=5)
    plt.show()

# %%
#Load the images
train_images, train_masks = load_images(parent_directory, split='train')
val_images, val_masks = load_images(parent_directory, split='val')

# %%
data_to_save = {
    'train_images': train_images,
    'train_masks': train_masks,
    'val_images': val_images,
    'val_masks': val_masks
}

pickle_file_path = 'dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)

# %%
pickle_file_path = '../dataset/train_and_val_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

train_images = loaded_data['train_images']
train_masks = loaded_data['train_masks']
val_images = loaded_data['val_images']
val_masks = loaded_data['val_masks']

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128)

# %%
import segmentation_models as sm

preprocess_input = sm.get_preprocessing(BACKBONE)

train_images, train_masks = preprocess_data(train_images, train_masks, preprocess_input)
val_images, val_masks = preprocess_data(val_images, val_masks, preprocess_input)

print('Shapes of loaded data:')
print('Train Images:', train_images.shape)
print('Train Masks:', train_masks.shape)
print('Val Images:', val_images.shape)
print('Val Masks:', val_masks.shape)
# Out:
# Segmentation Models: using `keras` framework.
# Shapes of loaded data:
# Train Images: (1445, 128, 128, 3)
# Train Masks: (1445, 128, 128, 10)
# Val Images: (450, 128, 128, 3)
# Val Masks: (450, 128, 128, 10)

# %%
if MODEL == 'unet':
    model = sm.Unet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'fpn':
    model = sm.FPN(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'pspnet':
    model = sm.PSPNet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
elif MODEL == 'linknet':
    model = sm.Linknet(BACKBONE, input_shape=(SIZE_X, SIZE_Y, n_channels), classes=n_classes, encoder_weights=encoder_weights,  activation=activation)
else:
    raise ValueError('Unknown model')

model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 32)  96          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 64, 64, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 32)  96          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64)  192         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 16, 16, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 16, 16, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 16, 16, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 16, 16, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 16, 16, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 16, 16, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 16, 16, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 16, 16, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 16, 16, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 16, 16, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 16, 16, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 96)     82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 96)    288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 8, 8, 96)     0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 288)   0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 8, 8, 768)    0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 128)   384         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 128)    114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 128)   384         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 128)    114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 128)   384         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 128)   384         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 128)    114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 128)    114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 128)   384         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 128)   384         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 8, 8, 768)   0           ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 192)    172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 192)    172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 192)    147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 192)   576         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 192)   576         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 192)   576         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 192)   576         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 8, 8, 768)    0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 160)   480         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 160)    179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 160)   480         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 160)    179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 160)   480         ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 160)   480         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 160)    179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 160)    179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 160)   480         ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 8, 8, 160)   480         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 8, 8, 768)   0           ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 192)    215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 192)    215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 192)    147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 192)   576         ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 192)   576         ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 8, 8, 192)   576         ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 8, 8, 192)   576         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 8, 8, 768)    0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 8, 8, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 8, 8, 160)   480         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 8, 8, 160)    179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 8, 8, 160)   480         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 8, 8, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 8, 8, 160)    179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 8, 8, 160)   480         ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 8, 8, 160)   480         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 8, 8, 160)    179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 8, 8, 160)    179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 8, 8, 160)   480         ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 8, 8, 160)   480         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 8, 8, 160)    0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 8, 8, 768)   0           ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 8, 8, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 8, 8, 192)    215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 8, 8, 192)    215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 8, 8, 192)    147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 8, 8, 192)   576         ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 8, 8, 192)   576         ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 8, 8, 192)   576         ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 8, 8, 192)   576         ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_59[0][0]']
#
#  mixed6 (Concatenate)           (None, 8, 8, 768)    0           ['activation_50[0][0]',
#                                                                   'activation_53[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'activation_59[0][0]']
#
# ...
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 4, 4, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 4, 4, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 4, 4, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 4, 4, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 4, 4, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 4, 4, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 4, 4, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 4, 4, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 2048)  0           ['mixed10[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 2816)  0           ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'mixed7[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 8, 8, 256)    6488064     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 8, 8, 256)    589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 544)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'mixed2[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 16, 16, 128)  626688      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 16, 16, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 320)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'activation_4[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 32, 32, 64)   184320      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 32, 32, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64)  0           ['decoder_stage2b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 128)  0          ['decoder_stage3_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'activation_2[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 32)   36864       ['decoder_stage3_concat[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3b_conv (Conv2D)  (None, 64, 64, 32)   9216        ['decoder_stage3a_relu[0][0]']
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3b_conv[0][0]']
#  lization)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3b_bn[0][0]']
#  on)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 128, 128, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 128, 128, 10  1450        ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  softmax (Activation)           (None, 128, 128, 10  0           ['final_conv[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 29,934,410
# Trainable params: 29,897,994
# Non-trainable params: 36,416
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_images, y=train_masks, batch_size=Batch_size, epochs=EPOCHS, validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 91/91 [==============================] - 28s 162ms/step - loss: 1.0663 - iou_score: 0.1858 - val_loss: 25.6106 - val_iou_score: 0.0271
# Epoch 2/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.8186 - iou_score: 0.3094 - val_loss: 1.9586 - val_iou_score: 0.0918
# Epoch 3/100
# 91/91 [==============================] - 10s 107ms/step - loss: 0.7513 - iou_score: 0.3571 - val_loss: 0.9633 - val_iou_score: 0.2196
# Epoch 4/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.7129 - iou_score: 0.3913 - val_loss: 1.0124 - val_iou_score: 0.2094
# Epoch 5/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.6695 - iou_score: 0.4299 - val_loss: 0.7857 - val_iou_score: 0.3207
# Epoch 6/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.6406 - iou_score: 0.4538 - val_loss: 0.7646 - val_iou_score: 0.3334
# Epoch 7/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.6248 - iou_score: 0.4650 - val_loss: 0.8111 - val_iou_score: 0.3056
# Epoch 8/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.6130 - iou_score: 0.4736 - val_loss: 0.7982 - val_iou_score: 0.3221
# Epoch 9/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.6021 - iou_score: 0.4834 - val_loss: 1.5427 - val_iou_score: 0.2424
# Epoch 10/100
# 91/91 [==============================] - 10s 106ms/step - loss: 0.5926 - iou_score: 0.4915 - val_loss: 0.7611 - val_iou_score: 0.3439
# Epoch 11/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.5753 - iou_score: 0.5083 - val_loss: 0.8384 - val_iou_score: 0.3208
# Epoch 12/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.5449 - iou_score: 0.5341 - val_loss: 0.8349 - val_iou_score: 0.3064
# Epoch 13/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.5603 - iou_score: 0.5222 - val_loss: 5.0474 - val_iou_score: 0.1014
# Epoch 14/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.5397 - iou_score: 0.5386 - val_loss: 0.8116 - val_iou_score: 0.3462
# Epoch 15/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.5278 - iou_score: 0.5458 - val_loss: 0.7127 - val_iou_score: 0.3795
# Epoch 16/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.5074 - iou_score: 0.5637 - val_loss: 0.7044 - val_iou_score: 0.3860
# Epoch 17/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.4923 - iou_score: 0.5750 - val_loss: 0.7164 - val_iou_score: 0.3807
# Epoch 18/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.4967 - iou_score: 0.5745 - val_loss: 0.7378 - val_iou_score: 0.3677
# Epoch 19/100
# 91/91 [==============================] - 10s 114ms/step - loss: 0.4971 - iou_score: 0.5734 - val_loss: 0.7543 - val_iou_score: 0.3561
# Epoch 20/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.4836 - iou_score: 0.5873 - val_loss: 0.7611 - val_iou_score: 0.3601
# Epoch 21/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.4678 - iou_score: 0.5970 - val_loss: 0.6704 - val_iou_score: 0.4097
# Epoch 22/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.4563 - iou_score: 0.6083 - val_loss: 0.6634 - val_iou_score: 0.4155
# Epoch 23/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.4354 - iou_score: 0.6270 - val_loss: 0.7977 - val_iou_score: 0.3362
# Epoch 24/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.4342 - iou_score: 0.6268 - val_loss: 0.6670 - val_iou_score: 0.4131
# Epoch 25/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.4315 - iou_score: 0.6260 - val_loss: 0.7215 - val_iou_score: 0.3876
# Epoch 26/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.4276 - iou_score: 0.6331 - val_loss: 0.6956 - val_iou_score: 0.3969
# Epoch 27/100
# 91/91 [==============================] - 10s 111ms/step - loss: 0.4272 - iou_score: 0.6314 - val_loss: 0.7158 - val_iou_score: 0.3919
# Epoch 28/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.4150 - iou_score: 0.6417 - val_loss: 0.7089 - val_iou_score: 0.3931
# Epoch 29/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.4175 - iou_score: 0.6395 - val_loss: 0.7030 - val_iou_score: 0.3986
# Epoch 30/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.4100 - iou_score: 0.6451 - val_loss: 0.6642 - val_iou_score: 0.4187
# Epoch 31/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.4120 - iou_score: 0.6442 - val_loss: 0.7026 - val_iou_score: 0.4011
# Epoch 32/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.4051 - iou_score: 0.6472 - val_loss: 0.7384 - val_iou_score: 0.3740
# Epoch 33/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.4052 - iou_score: 0.6492 - val_loss: 0.7467 - val_iou_score: 0.3800
# Epoch 34/100
# 91/91 [==============================] - 10s 115ms/step - loss: 0.4107 - iou_score: 0.6436 - val_loss: 0.7292 - val_iou_score: 0.3915
# Epoch 35/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.3819 - iou_score: 0.6710 - val_loss: 0.6919 - val_iou_score: 0.4076
# Epoch 36/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3965 - iou_score: 0.6562 - val_loss: 0.7079 - val_iou_score: 0.3976
# Epoch 37/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3784 - iou_score: 0.6743 - val_loss: 0.6481 - val_iou_score: 0.4321
# Epoch 38/100
# 91/91 [==============================] - 10s 106ms/step - loss: 0.3834 - iou_score: 0.6654 - val_loss: 0.6443 - val_iou_score: 0.4334
# Epoch 39/100
# 91/91 [==============================] - 10s 111ms/step - loss: 0.3605 - iou_score: 0.6848 - val_loss: 0.6431 - val_iou_score: 0.4345
# Epoch 40/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3670 - iou_score: 0.6807 - val_loss: 0.6500 - val_iou_score: 0.4305
# Epoch 41/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3574 - iou_score: 0.6915 - val_loss: 0.6654 - val_iou_score: 0.4216
# Epoch 42/100
# 91/91 [==============================] - 10s 107ms/step - loss: 0.3572 - iou_score: 0.6888 - val_loss: 0.6660 - val_iou_score: 0.4198
# Epoch 43/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3695 - iou_score: 0.6776 - val_loss: 0.8055 - val_iou_score: 0.3452
# Epoch 44/100
# 91/91 [==============================] - 10s 107ms/step - loss: 0.3694 - iou_score: 0.6809 - val_loss: 0.6792 - val_iou_score: 0.4133
# Epoch 45/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3549 - iou_score: 0.6944 - val_loss: 0.6820 - val_iou_score: 0.4090
# Epoch 46/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3679 - iou_score: 0.6822 - val_loss: 0.7665 - val_iou_score: 0.3660
# Epoch 47/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3726 - iou_score: 0.6771 - val_loss: 0.7199 - val_iou_score: 0.3869
# Epoch 48/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.3627 - iou_score: 0.6836 - val_loss: 0.6837 - val_iou_score: 0.4055
# Epoch 49/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3458 - iou_score: 0.6995 - val_loss: 0.6494 - val_iou_score: 0.4301
# Epoch 50/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3345 - iou_score: 0.7070 - val_loss: 0.6731 - val_iou_score: 0.4217
# Epoch 51/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3508 - iou_score: 0.6927 - val_loss: 0.7307 - val_iou_score: 0.3831
# Epoch 52/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3487 - iou_score: 0.6950 - val_loss: 0.6369 - val_iou_score: 0.4406
# Epoch 53/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3418 - iou_score: 0.6995 - val_loss: 0.6737 - val_iou_score: 0.4128
# Epoch 54/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.3567 - iou_score: 0.6867 - val_loss: 0.6971 - val_iou_score: 0.4140
# Epoch 55/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3348 - iou_score: 0.7056 - val_loss: 0.6400 - val_iou_score: 0.4392
# Epoch 56/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3384 - iou_score: 0.7022 - val_loss: 0.6814 - val_iou_score: 0.4096
# Epoch 57/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3229 - iou_score: 0.7160 - val_loss: 0.6253 - val_iou_score: 0.4479
# Epoch 58/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.3285 - iou_score: 0.7105 - val_loss: 0.6380 - val_iou_score: 0.4437
# Epoch 59/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3252 - iou_score: 0.7119 - val_loss: 0.6494 - val_iou_score: 0.4374
# Epoch 60/100
# 91/91 [==============================] - 10s 111ms/step - loss: 0.3147 - iou_score: 0.7241 - val_loss: 0.6291 - val_iou_score: 0.4441
# Epoch 61/100
# 91/91 [==============================] - 10s 111ms/step - loss: 0.3210 - iou_score: 0.7178 - val_loss: 0.6344 - val_iou_score: 0.4411
# Epoch 62/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3281 - iou_score: 0.7122 - val_loss: 0.6720 - val_iou_score: 0.4204
# Epoch 63/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3300 - iou_score: 0.7100 - val_loss: 0.6475 - val_iou_score: 0.4342
# Epoch 64/100
# 91/91 [==============================] - 10s 107ms/step - loss: 0.3251 - iou_score: 0.7129 - val_loss: 0.6510 - val_iou_score: 0.4325
# Epoch 65/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3107 - iou_score: 0.7285 - val_loss: 0.6711 - val_iou_score: 0.4301
# Epoch 66/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3158 - iou_score: 0.7202 - val_loss: 0.6475 - val_iou_score: 0.4354
# Epoch 67/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3167 - iou_score: 0.7214 - val_loss: 0.6373 - val_iou_score: 0.4405
# Epoch 68/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3195 - iou_score: 0.7198 - val_loss: 0.7469 - val_iou_score: 0.3900
# Epoch 69/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3200 - iou_score: 0.7203 - val_loss: 0.6346 - val_iou_score: 0.4445
# Epoch 70/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3177 - iou_score: 0.7197 - val_loss: 0.6740 - val_iou_score: 0.4248
# Epoch 71/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3205 - iou_score: 0.7203 - val_loss: 0.7143 - val_iou_score: 0.3978
# Epoch 72/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3342 - iou_score: 0.7041 - val_loss: 0.6497 - val_iou_score: 0.4348
# Epoch 73/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3132 - iou_score: 0.7212 - val_loss: 0.6588 - val_iou_score: 0.4274
# Epoch 74/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3121 - iou_score: 0.7235 - val_loss: 0.6638 - val_iou_score: 0.4327
# Epoch 75/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3110 - iou_score: 0.7245 - val_loss: 0.6313 - val_iou_score: 0.4487
# Epoch 76/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3185 - iou_score: 0.7181 - val_loss: 0.6450 - val_iou_score: 0.4434
# Epoch 77/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3046 - iou_score: 0.7312 - val_loss: 0.6349 - val_iou_score: 0.4459
# Epoch 78/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.2936 - iou_score: 0.7398 - val_loss: 0.6352 - val_iou_score: 0.4452
# Epoch 79/100
# 91/91 [==============================] - 10s 112ms/step - loss: 0.2869 - iou_score: 0.7457 - val_loss: 0.6672 - val_iou_score: 0.4274
# Epoch 80/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.2962 - iou_score: 0.7361 - val_loss: 0.6393 - val_iou_score: 0.4435
# Epoch 81/100
# 91/91 [==============================] - 10s 113ms/step - loss: 0.2738 - iou_score: 0.7579 - val_loss: 0.6364 - val_iou_score: 0.4469
# Epoch 82/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.3071 - iou_score: 0.7286 - val_loss: 0.7188 - val_iou_score: 0.4178
# Epoch 83/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.2963 - iou_score: 0.7374 - val_loss: 0.6848 - val_iou_score: 0.4211
# Epoch 84/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.2984 - iou_score: 0.7344 - val_loss: 0.6369 - val_iou_score: 0.4452
# Epoch 85/100
# 91/91 [==============================] - 10s 111ms/step - loss: 0.2956 - iou_score: 0.7385 - val_loss: 0.6380 - val_iou_score: 0.4439
# Epoch 86/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.2892 - iou_score: 0.7454 - val_loss: 0.6866 - val_iou_score: 0.4135
# Epoch 87/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.3137 - iou_score: 0.7221 - val_loss: 0.7521 - val_iou_score: 0.3812
# Epoch 88/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3205 - iou_score: 0.7229 - val_loss: 0.6874 - val_iou_score: 0.4148
# Epoch 89/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.3207 - iou_score: 0.7205 - val_loss: 0.7596 - val_iou_score: 0.3729
# Epoch 90/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3124 - iou_score: 0.7268 - val_loss: 0.6904 - val_iou_score: 0.4101
# Epoch 91/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.3074 - iou_score: 0.7304 - val_loss: 0.6736 - val_iou_score: 0.4187
# Epoch 92/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.3027 - iou_score: 0.7346 - val_loss: 0.6511 - val_iou_score: 0.4393
# Epoch 93/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.2894 - iou_score: 0.7452 - val_loss: 0.6459 - val_iou_score: 0.4451
# Epoch 94/100
# 91/91 [==============================] - 10s 108ms/step - loss: 0.2925 - iou_score: 0.7419 - val_loss: 0.6528 - val_iou_score: 0.4348
# Epoch 95/100
# 91/91 [==============================] - 10s 111ms/step - loss: 0.2885 - iou_score: 0.7436 - val_loss: 0.8093 - val_iou_score: 0.4066
# Epoch 96/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.2776 - iou_score: 0.7539 - val_loss: 0.6431 - val_iou_score: 0.4419
# Epoch 97/100
# 91/91 [==============================] - 10s 112ms/step - loss: 0.2772 - iou_score: 0.7520 - val_loss: 0.6335 - val_iou_score: 0.4483
# Epoch 98/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.2731 - iou_score: 0.7576 - val_loss: 0.6431 - val_iou_score: 0.4424
# Epoch 99/100
# 91/91 [==============================] - 10s 109ms/step - loss: 0.2809 - iou_score: 0.7495 - val_loss: 0.6604 - val_iou_score: 0.4345
# Epoch 100/100
# 91/91 [==============================] - 10s 110ms/step - loss: 0.2759 - iou_score: 0.7554 - val_loss: 0.6399 - val_iou_score: 0.4470

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU-Score')
plt.plot(epochs, val_acc, 'r', label='Validation IOU-Score')
plt.title('Training and validation IOU-Score')
plt.xlabel('Epochs')
plt.ylabel('IOU-Score')
plt.legend()
plt.show()

# %%
model.save(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
model.load_weights(f'weights/{MODEL.upper()}_model_with_{EPOCHS}_epochs({MODEL.upper()}_{BACKBONE.capitalize()}).hdf5')

# %%
test_images, test_masks = load_images(parent_directory, split='test')
test_images_seperate = test_images

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)
# Out:
# 100%|██████████| 448/448 [02:24<00:00,  3.09it/s]
# TEST: Images loaded: 448
# TEST: Masks loaded: 448

# %%
data_to_save = {
    'test_images': test_images,
    'test_masks': test_masks,
    'test_images_seperate': test_images_seperate
}

pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f'Data saved to {pickle_file_path}')

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Data saved to ../dataset/test_data.pickle
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
pickle_file_path = '../dataset/test_data.pickle'

with open(pickle_file_path, 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)

test_images = loaded_data['test_images']
test_masks = loaded_data['test_masks']
test_images_seperate = loaded_data['test_images_seperate']

test_images, test_masks = preprocess_data(test_images, test_masks, preprocess_input)

print('Shapes of loaded data:')
print('Test Images:', test_images.shape)
print('Test Masks:', test_masks.shape)
# Out:
# Shapes of loaded data:
# Test Images: (448, 128, 128, 3)
# Test Masks: (448, 128, 128, 10)

# %%
_, acc = model.evaluate(test_images, test_masks, verbose=0)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# Accuracy is =  47.378310561180115 %

# %%
from keras.metrics import MeanIoU
import numpy as np

y_pred = model.predict(test_images)
predicted_masks = np.argmax(y_pred, axis=-1)
test_masks_ = np.argmax(test_masks, axis=-1)

print(predicted_masks.shape)
print(test_masks_.shape)
# Out:
# 14/14 [==============================] - 2s 48ms/step
# (448, 128, 128)
# (448, 128, 128)

# %%
class_names = ["Background", "Building Flooded", "Building Non-Flooded", "Road Flooded", "Road Non-Flooded",
               "Water", "Tree", "Vehicle", "Pool", "Grass"]

n_classes = len(class_names)  
IOU_keras = MeanIoU(num_classes=n_classes)

IOU_keras.update_state(test_masks_, predicted_masks)
print("Mean IoU =", IOU_keras.result().numpy())

values = np.array(IOU_keras.get_weights())
values = values.reshape(n_classes, n_classes)

class_IoUs = []
print("IoU for each class:")
for i in range(n_classes):
    class_IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(class_IoU)
    print(f"{class_names[i]}: {class_IoU}")

class_APs = []

for i in range(n_classes):
    class_predicted_masks = (predicted_masks == i).astype(int)
    class_test_masks = (test_masks_ == i).astype(int)
    
    class_predicted_masks_flat = class_predicted_masks.flatten().reshape(-1, 1)
    class_test_masks_flat = class_test_masks.flatten().reshape(-1, 1)
    
    class_APs.append(average_precision_score(class_test_masks_flat, class_predicted_masks_flat, average='micro'))

mAP_score = np.mean(class_APs)
print("Overall mAP score =", mAP_score)
# Out:
# Mean IoU = 0.64795387
# IoU for each class:
# Background: 0.40546607971191406
# Building Flooded: 0.6912083029747009
# Building Non-Flooded: 0.7585427761077881
# Road Flooded: 0.5986037254333496
# Road Non-Flooded: 0.809526264667511
# Water: 0.7556893229484558
# Tree: 0.7657685875892639
# Vehicle: 0.3578411340713501
# Pool: 0.46491315960884094
# Grass: 0.8719797134399414
# Overall mAP score = 0.6316580492553258

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(class_names, class_IoUs, color='blue')
plt.title(f'IoU for Each Class using {MODEL.upper()} with {BACKBONE.capitalize()} Backbone ({EPOCHS} Epochs)')
plt.xlabel('Classes')
plt.ylabel('IoU')
plt.ylim(0, 1) 
plt.xticks(rotation=45, ha='right')  

for bar, value in zip(bars, class_IoUs):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
def display_random_function():
    image_id = np.random.randint(0, len(test_images))
    image = test_images_seperate[image_id]
    ground_truth_mask = test_masks_[image_id]
    predicted_mask = predicted_masks[image_id]

    print(f'Image Shape: {image.shape}')
    print(f'Ground Truth Mask Shape: {ground_truth_mask.shape}')
    print(f'Predicted Mask Shape: {predicted_mask.shape}')

    display_images_with_masks(image, ground_truth_mask, predicted_mask)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)

# %%
display_random_function()
# Out:
# Image Shape: (128, 128, 3)
# Ground Truth Mask Shape: (128, 128)
# Predicted Mask Shape: (128, 128)
