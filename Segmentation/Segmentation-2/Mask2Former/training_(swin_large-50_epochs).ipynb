# %%
import torch
import transformers
import evaluate

torch.__version__, transformers.__version__, evaluate.__version__
# Out:
# ('1.13.1+cu116', '4.38.2', '0.4.1')

# %%
# !python train.py --backbone 'facebook/mask2former-swin-large-ade-semantic' --batch 4 --imgsz 128 128 --lr 0.0001 --epochs 50
# Out:
# Namespace(epochs=50, lr=0.0001, batch=4, imgsz=[128, 128], scheduler=False, scheduler_epochs=[50])
# Mask2FormerForUniversalSegmentation(
#   (model): Mask2FormerModel(
#     (pixel_level_module): Mask2FormerPixelLevelModule(
#       (encoder): SwinBackbone(
#         (embeddings): SwinEmbeddings(
#           (patch_embeddings): SwinPatchEmbeddings(
#             (projection): Conv2d(3, 192, kernel_size=(4, 4), stride=(4, 4))
#           )
#           (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (encoder): SwinEncoder(
#           (layers): ModuleList(
#             (0): SwinStage(
#               (blocks): ModuleList(
#                 (0): SwinLayer(
#                   (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   (attention): SwinAttention(
#                     (self): SwinSelfAttention(
# ...

# %%
# !python test.py --model outputs/model_iou/ --batch 16 --imgsz 128 128
# Out:
# Namespace(batch=16, imgsz=[128, 128], model='outputs/model_iou/')
# Validating
# Namespace(batch=16, imgsz=[128, 128], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[128, 128], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[128, 128], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[128, 128], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[128, 128], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[128, 128], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[128, 128], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[128, 128], model='outputs/model_iou/')
# IOU Each Class:
# Building-flooded: 0.6589395500206684
# Building-non-flooded: 0.7664411694506489
# Road-flooded: 0.6868435988609849
# Road-non-flooded: 0.8101128513122708
# Water: 0.8146694241476212
# Tree: 0.8233100714631825
# Vehicle: 0.3858000363790699
# Pool: 0.5502194051682107
# Grass: 0.8981838710965392
#
# Test mIOU: 0.7105
# TESTING COMPLETE
# ...

# %%
# !python test.py --model outputs/model_iou/ --batch 16 --imgsz 320 320
# Out:
# Namespace(batch=16, imgsz=[320, 320], model='outputs/model_iou/')
# Validating
# Namespace(batch=16, imgsz=[320, 320], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[320, 320], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[320, 320], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[320, 320], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[320, 320], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[320, 320], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[320, 320], model='outputs/model_iou/')
# Namespace(batch=16, imgsz=[320, 320], model='outputs/model_iou/')
# IOU Each Class:
# Building-flooded: 0.695230257137755
# Building-non-flooded: 0.7652390755702199
# Road-flooded: 0.6257414673029742
# Road-non-flooded: 0.8019661027454686
# Water: 0.7841392930126183
# Tree: 0.8039375700973482
# Vehicle: 0.33445447697057795
# Pool: 0.4049778100196296
# Grass: 0.882346678341647
#
# Test mIOU: 0.6776
# TESTING COMPLETE
# ...
