# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import VGG16
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'A'
model_name = 'VGG-16'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'A_validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
Vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(256, 256, 3))
model = Sequential()
model.add(Vgg16)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 2048)              67110912
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 81,827,649
# Trainable params: 67,112,961
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs = 50, batch_size = 32, validation_data = (val_images, val_labels))
# Out:
# Epoch 1/50
# 35/35 [==============================] - 10s 208ms/step - loss: 3.8515 - accuracy: 0.7007 - val_loss: 0.7125 - val_accuracy: 0.8619
# Epoch 2/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.5608 - accuracy: 0.8970 - val_loss: 0.3565 - val_accuracy: 0.9163
# Epoch 3/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.2686 - accuracy: 0.9265 - val_loss: 0.5879 - val_accuracy: 0.8661
# Epoch 4/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.1227 - accuracy: 0.9561 - val_loss: 0.2374 - val_accuracy: 0.9331
# Epoch 5/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0570 - accuracy: 0.9812 - val_loss: 0.2353 - val_accuracy: 0.9372
# Epoch 6/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0500 - accuracy: 0.9821 - val_loss: 0.1755 - val_accuracy: 0.9372
# Epoch 7/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0165 - accuracy: 0.9946 - val_loss: 0.2071 - val_accuracy: 0.9289
# Epoch 8/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0120 - accuracy: 0.9982 - val_loss: 0.2098 - val_accuracy: 0.9205
# Epoch 9/50
# 35/35 [==============================] - 5s 140ms/step - loss: 0.0086 - accuracy: 0.9982 - val_loss: 0.2168 - val_accuracy: 0.9289
# Epoch 10/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0079 - accuracy: 0.9955 - val_loss: 0.2041 - val_accuracy: 0.9289
# Epoch 11/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2160 - val_accuracy: 0.9331
# Epoch 12/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9247
# Epoch 13/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2073 - val_accuracy: 0.9247
# Epoch 14/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2177 - val_accuracy: 0.9205
# Epoch 15/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9289
# Epoch 16/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9247
# Epoch 17/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2195 - val_accuracy: 0.9289
# Epoch 18/50
# 35/35 [==============================] - 5s 139ms/step - loss: 9.9550e-04 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9247
# Epoch 19/50
# 35/35 [==============================] - 5s 139ms/step - loss: 8.3799e-04 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9247
# Epoch 20/50
# 35/35 [==============================] - 5s 138ms/step - loss: 9.1405e-04 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9247
# Epoch 21/50
# 35/35 [==============================] - 5s 139ms/step - loss: 6.6001e-04 - accuracy: 1.0000 - val_loss: 0.2152 - val_accuracy: 0.9289
# Epoch 22/50
# 35/35 [==============================] - 5s 139ms/step - loss: 5.6060e-04 - accuracy: 1.0000 - val_loss: 0.2157 - val_accuracy: 0.9331
# Epoch 23/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9247
# Epoch 24/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9331
# Epoch 25/50
# 35/35 [==============================] - 5s 139ms/step - loss: 4.3583e-04 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9331
# Epoch 26/50
# 35/35 [==============================] - 5s 139ms/step - loss: 5.2779e-04 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9331
# Epoch 27/50
# 35/35 [==============================] - 5s 139ms/step - loss: 4.3561e-04 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9289
# Epoch 28/50
# 35/35 [==============================] - 5s 138ms/step - loss: 4.0253e-04 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9247
# Epoch 29/50
# 35/35 [==============================] - 5s 138ms/step - loss: 4.6934e-04 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9331
# Epoch 30/50
# 35/35 [==============================] - 5s 140ms/step - loss: 3.4311e-04 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9289
# Epoch 31/50
# 35/35 [==============================] - 5s 139ms/step - loss: 3.0904e-04 - accuracy: 1.0000 - val_loss: 0.2197 - val_accuracy: 0.9372
# Epoch 32/50
# 35/35 [==============================] - 5s 138ms/step - loss: 2.8888e-04 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9289
# Epoch 33/50
# 35/35 [==============================] - 5s 138ms/step - loss: 3.4447e-04 - accuracy: 1.0000 - val_loss: 0.2169 - val_accuracy: 0.9331
# Epoch 34/50
# 35/35 [==============================] - 5s 139ms/step - loss: 4.2999e-04 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9289
# Epoch 35/50
# 35/35 [==============================] - 5s 140ms/step - loss: 2.7293e-04 - accuracy: 1.0000 - val_loss: 0.2308 - val_accuracy: 0.9331
# Epoch 36/50
# 35/35 [==============================] - 5s 140ms/step - loss: 4.8489e-04 - accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.9247
# Epoch 37/50
# 35/35 [==============================] - 5s 139ms/step - loss: 3.0787e-04 - accuracy: 1.0000 - val_loss: 0.2161 - val_accuracy: 0.9331
# Epoch 38/50
# 35/35 [==============================] - 5s 138ms/step - loss: 2.7239e-04 - accuracy: 1.0000 - val_loss: 0.2172 - val_accuracy: 0.9372
# Epoch 39/50
# 35/35 [==============================] - 5s 138ms/step - loss: 2.2211e-04 - accuracy: 1.0000 - val_loss: 0.2181 - val_accuracy: 0.9372
# Epoch 40/50
# 35/35 [==============================] - 5s 139ms/step - loss: 2.7325e-04 - accuracy: 1.0000 - val_loss: 0.2348 - val_accuracy: 0.9289
# Epoch 41/50
# 35/35 [==============================] - 5s 139ms/step - loss: 1.9761e-04 - accuracy: 1.0000 - val_loss: 0.2298 - val_accuracy: 0.9331
# Epoch 42/50
# 35/35 [==============================] - 5s 140ms/step - loss: 2.0158e-04 - accuracy: 1.0000 - val_loss: 0.2205 - val_accuracy: 0.9289
# Epoch 43/50
# 35/35 [==============================] - 5s 139ms/step - loss: 2.2109e-04 - accuracy: 1.0000 - val_loss: 0.2360 - val_accuracy: 0.9289
# Epoch 44/50
# 35/35 [==============================] - 5s 139ms/step - loss: 2.8375e-04 - accuracy: 1.0000 - val_loss: 0.2163 - val_accuracy: 0.9247
# Epoch 45/50
# 35/35 [==============================] - 5s 138ms/step - loss: 2.2860e-04 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9372
# Epoch 46/50
# 35/35 [==============================] - 5s 140ms/step - loss: 1.9011e-04 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9331
# Epoch 47/50
# 35/35 [==============================] - 5s 139ms/step - loss: 1.4098e-04 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 0.9331
# Epoch 48/50
# 35/35 [==============================] - 5s 139ms/step - loss: 2.2982e-04 - accuracy: 1.0000 - val_loss: 0.2192 - val_accuracy: 0.9372
# Epoch 49/50
# 35/35 [==============================] - 5s 139ms/step - loss: 1.7274e-04 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9372
# Epoch 50/50
# 35/35 [==============================] - 5s 139ms/step - loss: 2.4291e-04 - accuracy: 1.0000 - val_loss: 0.2354 - val_accuracy: 0.9289

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'A_test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 241ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       110
#            1       0.95      0.95      0.95       131
#
#     accuracy                           0.95       241
#    macro avg       0.95      0.95      0.95       241
# weighted avg       0.95      0.95      0.95       241
