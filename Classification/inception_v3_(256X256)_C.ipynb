# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import InceptionV3
from tensorflow.keras.utils import Sequence
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

def save_pickle(data, file_path):
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)
        
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_val_data_path = os.path.join(data_saved_dir, 'C_preprocessed_data(256, 256).pkl')
train_images, train_labels, val_images, val_labels = load_pickle(train_val_data_path)

# %%
random_state = 42

train_indices = np.arange(len(train_images))
np.random.seed(random_state)
np.random.shuffle(train_indices)
train_images = train_images[train_indices]
train_labels = train_labels[train_indices]

val_indices = np.arange(len(val_images))
np.random.seed(random_state)
np.random.shuffle(val_indices)
val_images = val_images[val_indices]
val_labels = val_labels[val_indices]

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

batch_size = 16
train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)

# %%
IncV3 = InceptionV3(include_top = False, weights = "imagenet",input_shape = (256,256,3))

model = Sequential()
model.add(IncV3)
    
for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units = 2048, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(units = 1, activation = "sigmoid"))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 6, 6, 2048)        21802784
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 2048)              150996992
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 172,801,825
# Trainable params: 150,999,041
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator)
# Out:
# Epoch 1/50
# 288/288 [==============================] - 25s 67ms/step - loss: 5.7111 - accuracy: 0.8359 - val_loss: 11.6334 - val_accuracy: 0.5025
# Epoch 2/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.2449 - accuracy: 0.9503 - val_loss: 5.1747 - val_accuracy: 0.5159
# Epoch 3/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1167 - accuracy: 0.9655 - val_loss: 4.4447 - val_accuracy: 0.5233
# Epoch 4/50
# 288/288 [==============================] - 18s 61ms/step - loss: 0.0728 - accuracy: 0.9766 - val_loss: 5.0733 - val_accuracy: 0.5208
# Epoch 5/50
# 288/288 [==============================] - 18s 61ms/step - loss: 0.1089 - accuracy: 0.9690 - val_loss: 5.5481 - val_accuracy: 0.5221
# Epoch 6/50
# 288/288 [==============================] - 17s 61ms/step - loss: 0.0854 - accuracy: 0.9737 - val_loss: 5.7672 - val_accuracy: 0.5208
# Epoch 7/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1209 - accuracy: 0.9677 - val_loss: 5.7135 - val_accuracy: 0.5147
# Epoch 8/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1108 - accuracy: 0.9683 - val_loss: 6.1785 - val_accuracy: 0.5098
# Epoch 9/50
# 288/288 [==============================] - 17s 61ms/step - loss: 0.2004 - accuracy: 0.9540 - val_loss: 5.9021 - val_accuracy: 0.5049
# Epoch 10/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1105 - accuracy: 0.9683 - val_loss: 5.3721 - val_accuracy: 0.5123
# Epoch 11/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1171 - accuracy: 0.9709 - val_loss: 7.8454 - val_accuracy: 0.5110
# Epoch 12/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1163 - accuracy: 0.9740 - val_loss: 8.8327 - val_accuracy: 0.5208
# Epoch 13/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1395 - accuracy: 0.9690 - val_loss: 7.5378 - val_accuracy: 0.5270
# Epoch 14/50
# 288/288 [==============================] - 17s 59ms/step - loss: 0.1091 - accuracy: 0.9750 - val_loss: 9.8889 - val_accuracy: 0.5159
# Epoch 15/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1345 - accuracy: 0.9720 - val_loss: 9.7076 - val_accuracy: 0.5343
# Epoch 16/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0749 - accuracy: 0.9820 - val_loss: 11.0342 - val_accuracy: 0.5147
# Epoch 17/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1835 - accuracy: 0.9694 - val_loss: 16.1476 - val_accuracy: 0.5196
# Epoch 18/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.2451 - accuracy: 0.9668 - val_loss: 8.5877 - val_accuracy: 0.5110
# Epoch 19/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0737 - accuracy: 0.9863 - val_loss: 10.3289 - val_accuracy: 0.5270
# Epoch 20/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0574 - accuracy: 0.9863 - val_loss: 9.4640 - val_accuracy: 0.5025
# Epoch 21/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0486 - accuracy: 0.9902 - val_loss: 10.5688 - val_accuracy: 0.5306
# Epoch 22/50
# 288/288 [==============================] - 17s 59ms/step - loss: 0.0881 - accuracy: 0.9779 - val_loss: 16.2598 - val_accuracy: 0.5147
# Epoch 23/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1186 - accuracy: 0.9796 - val_loss: 11.8102 - val_accuracy: 0.5074
# Epoch 24/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1238 - accuracy: 0.9763 - val_loss: 10.5360 - val_accuracy: 0.5233
# Epoch 25/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.5029 - accuracy: 0.9581 - val_loss: 18.3808 - val_accuracy: 0.5074
# Epoch 26/50
# 288/288 [==============================] - 17s 59ms/step - loss: 0.0672 - accuracy: 0.9848 - val_loss: 10.4766 - val_accuracy: 0.5208
# Epoch 27/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0395 - accuracy: 0.9896 - val_loss: 13.8449 - val_accuracy: 0.5074
# Epoch 28/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1521 - accuracy: 0.9755 - val_loss: 10.9495 - val_accuracy: 0.5221
# Epoch 29/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0691 - accuracy: 0.9863 - val_loss: 14.9568 - val_accuracy: 0.5135
# Epoch 30/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0851 - accuracy: 0.9863 - val_loss: 18.7281 - val_accuracy: 0.5147
# Epoch 31/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0386 - accuracy: 0.9928 - val_loss: 15.0375 - val_accuracy: 0.5208
# Epoch 32/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0532 - accuracy: 0.9885 - val_loss: 16.8475 - val_accuracy: 0.5184
# Epoch 33/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0873 - accuracy: 0.9861 - val_loss: 18.4797 - val_accuracy: 0.5147
# Epoch 34/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0785 - accuracy: 0.9863 - val_loss: 13.7934 - val_accuracy: 0.5159
# Epoch 35/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0374 - accuracy: 0.9907 - val_loss: 22.5826 - val_accuracy: 0.5172
# Epoch 36/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1956 - accuracy: 0.9803 - val_loss: 20.2124 - val_accuracy: 0.5368
# Epoch 37/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0672 - accuracy: 0.9876 - val_loss: 18.3332 - val_accuracy: 0.5110
# Epoch 38/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0872 - accuracy: 0.9859 - val_loss: 17.6988 - val_accuracy: 0.5245
# Epoch 39/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0808 - accuracy: 0.9889 - val_loss: 25.0571 - val_accuracy: 0.5184
# Epoch 40/50
# 288/288 [==============================] - 17s 59ms/step - loss: 0.0832 - accuracy: 0.9885 - val_loss: 18.6907 - val_accuracy: 0.5196
# Epoch 41/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0749 - accuracy: 0.9881 - val_loss: 15.5122 - val_accuracy: 0.5270
# Epoch 42/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0285 - accuracy: 0.9931 - val_loss: 15.9714 - val_accuracy: 0.5061
# Epoch 43/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1132 - accuracy: 0.9859 - val_loss: 22.2312 - val_accuracy: 0.5086
# Epoch 44/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0891 - accuracy: 0.9863 - val_loss: 24.5795 - val_accuracy: 0.5135
# Epoch 45/50
# 288/288 [==============================] - 17s 59ms/step - loss: 0.0763 - accuracy: 0.9915 - val_loss: 20.3804 - val_accuracy: 0.5343
# Epoch 46/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1065 - accuracy: 0.9874 - val_loss: 23.7649 - val_accuracy: 0.5221
# Epoch 47/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1386 - accuracy: 0.9865 - val_loss: 29.3030 - val_accuracy: 0.5196
# Epoch 48/50
# 288/288 [==============================] - 17s 61ms/step - loss: 0.0693 - accuracy: 0.9900 - val_loss: 24.6121 - val_accuracy: 0.5172
# Epoch 49/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0474 - accuracy: 0.9913 - val_loss: 19.9535 - val_accuracy: 0.5147
# Epoch 50/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0706 - accuracy: 0.9905 - val_loss: 25.5650 - val_accuracy: 0.5233

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.4, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'C_preprocessed_data test_images(256, 256).pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 3s 48ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.82      0.90       131
#            1       0.82      0.98      0.90       109
#
#     accuracy                           0.90       240
#    macro avg       0.90      0.90      0.90       240
# weighted avg       0.91      0.90      0.90       240

# %%
model_saved = r'D:\My Code\Classification\models'
save_pickle(model, os.path.join(model_saved, 'C_InceptionV3 (256X256).pkl'))
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 94). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://e9e319ca-e6fa-48cb-81a4-4d1c72a39ba0/assets
# INFO:tensorflow:Assets written to: ram://e9e319ca-e6fa-48cb-81a4-4d1c72a39ba0/assets
