# %%
import os
import pickle
import seaborn as sns
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import InceptionV3
from tensorflow.keras.utils import Sequence
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

def save_pickle(data, file_path):
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)
        
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_val_data_path = os.path.join(data_saved_dir, 'C_preprocessed_data(256, 256).pkl')
train_images, train_labels, val_images, val_labels = load_pickle(train_val_data_path)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

batch_size = 16
train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)

# %%
IncV3 = InceptionV3(include_top = False, weights = "imagenet",input_shape = (256,256,3))

model = Sequential()
model.add(IncV3)
    
for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units = 2048, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(units = 1, activation = "sigmoid"))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 6, 6, 2048)        21802784
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 2048)              150996992
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 172,801,825
# Trainable params: 150,999,041
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator)
# Out:
# Epoch 1/50
# 288/288 [==============================] - 27s 69ms/step - loss: 6.6224 - accuracy: 0.8357 - val_loss: 9.3636 - val_accuracy: 0.5319
# Epoch 2/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.2044 - accuracy: 0.9460 - val_loss: 4.6190 - val_accuracy: 0.5270
# Epoch 3/50
# 288/288 [==============================] - 17s 59ms/step - loss: 0.0953 - accuracy: 0.9692 - val_loss: 4.5640 - val_accuracy: 0.5135
# Epoch 4/50
# 288/288 [==============================] - 17s 59ms/step - loss: 0.0820 - accuracy: 0.9714 - val_loss: 4.5322 - val_accuracy: 0.5098
# Epoch 5/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1207 - accuracy: 0.9688 - val_loss: 7.6591 - val_accuracy: 0.5147
# Epoch 6/50
# 288/288 [==============================] - 17s 61ms/step - loss: 0.1373 - accuracy: 0.9653 - val_loss: 4.6690 - val_accuracy: 0.5245
# Epoch 7/50
# 288/288 [==============================] - 18s 61ms/step - loss: 0.0948 - accuracy: 0.9714 - val_loss: 5.4059 - val_accuracy: 0.5196
# Epoch 8/50
# 288/288 [==============================] - 18s 61ms/step - loss: 0.0675 - accuracy: 0.9768 - val_loss: 5.1558 - val_accuracy: 0.5159
# Epoch 9/50
# 288/288 [==============================] - 18s 61ms/step - loss: 0.0874 - accuracy: 0.9776 - val_loss: 5.8237 - val_accuracy: 0.5368
# Epoch 10/50
# 288/288 [==============================] - 18s 61ms/step - loss: 0.2614 - accuracy: 0.9486 - val_loss: 9.2438 - val_accuracy: 0.5233
# Epoch 11/50
# 288/288 [==============================] - 18s 62ms/step - loss: 0.2520 - accuracy: 0.9486 - val_loss: 4.7741 - val_accuracy: 0.5172
# Epoch 12/50
# 288/288 [==============================] - 18s 62ms/step - loss: 0.1196 - accuracy: 0.9677 - val_loss: 5.9488 - val_accuracy: 0.5245
# Epoch 13/50
# 288/288 [==============================] - 18s 62ms/step - loss: 0.0698 - accuracy: 0.9770 - val_loss: 5.5711 - val_accuracy: 0.5245
# Epoch 14/50
50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1072 - accuracy: 0.9816 - val_loss: 13.7761 - val_accuracy: 0.5172
# Epoch 34/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0395 - accuracy: 0.9920 - val_loss: 15.0745 - val_accuracy: 0.5135
# Epoch 35/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.2087 - accuracy: 0.9776 - val_loss: 22.8242 - val_accuracy: 0.5172
# Epoch 36/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0804 - accuracy: 0.9883 - val_loss: 18.8001 - val_accuracy: 0.5123
# Epoch 37/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0518 - accuracy: 0.9896 - val_loss: 19.4111 - val_accuracy: 0.5270
# Epoch 38/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0526 - accuracy: 0.9896 - val_loss: 17.3312 - val_accuracy: 0.5221
# Epoch 39/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.1381 - accuracy: 0.9820 - val_loss: 21.4380 - val_accuracy: 0.5184
# Epoch 40/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0800 - accuracy: 0.9874 - val_loss: 17.6231 - val_accuracy: 0.5233
# Epoch 41/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0444 - accuracy: 0.9900 - val_loss: 13.7356 - val_accuracy: 0.5196
# Epoch 42/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0516 - accuracy: 0.9876 - val_loss: 14.3344 - val_accuracy: 0.5184
# Epoch 43/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0311 - accuracy: 0.9898 - val_loss: 17.1372 - val_accuracy: 0.5184
# Epoch 44/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0552 - accuracy: 0.9876 - val_loss: 21.4381 - val_accuracy: 0.5184
# Epoch 45/50
# 288/288 [==============================] - 17s 61ms/step - loss: 0.1066 - accuracy: 0.9842 - val_loss: 20.7259 - val_accuracy: 0.5208
# Epoch 46/50
# 288/288 [==============================] - 18s 61ms/step - loss: 0.0590 - accuracy: 0.9874 - val_loss: 20.8049 - val_accuracy: 0.5147
# Epoch 47/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0493 - accuracy: 0.9896 - val_loss: 18.4763 - val_accuracy: 0.5233
# Epoch 48/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0486 - accuracy: 0.9896 - val_loss: 16.1347 - val_accuracy: 0.5172
# Epoch 49/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0501 - accuracy: 0.9883 - val_loss: 24.0713 - val_accuracy: 0.5172
# Epoch 50/50
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0375 - accuracy: 0.9928 - val_loss: 18.4720 - val_accuracy: 0.5184

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'C_preprocessed_data test_images(256, 256).pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 3s 49ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       131
#            1       0.88      0.94      0.91       109
#
#     accuracy                           0.92       240
#    macro avg       0.92      0.92      0.92       240
# weighted avg       0.92      0.92      0.92       240

# %%
model_saved = r'D:\My Code\Classification\models'
save_pickle(model, os.path.join(model_saved, 'C_InceptionV3 (256X256).pkl'))
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 94). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://8bc2b7b4-b8bb-4865-8a33-b24872918489/assets
# INFO:tensorflow:Assets written to: ram://8bc2b7b4-b8bb-4865-8a33-b24872918489/assets
