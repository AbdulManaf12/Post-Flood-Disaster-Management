# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import ResNet50
from keras.utils import Sequence
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'D'
model_name = 'RestNet50'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

batch_size = 16
train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)

# %%
ResNet50_model = ResNet50(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(ResNet50_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 292,027,265
# Trainable params: 268,439,553
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator)
# Out:
# Epoch 1/50
# 300/300 [==============================] - 31s 89ms/step - loss: 4.6125 - accuracy: 0.5667 - val_loss: 0.6345 - val_accuracy: 0.6695
# Epoch 2/50
# 300/300 [==============================] - 25s 82ms/step - loss: 0.6826 - accuracy: 0.5623 - val_loss: 0.6661 - val_accuracy: 0.6904
# Epoch 3/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6877 - accuracy: 0.5356 - val_loss: 0.6863 - val_accuracy: 0.5607
# Epoch 4/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6921 - accuracy: 0.5222 - val_loss: 0.6895 - val_accuracy: 0.5816
# Epoch 5/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6928 - accuracy: 0.5091 - val_loss: 0.6896 - val_accuracy: 0.5565
# Epoch 6/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6850 - accuracy: 0.5314 - val_loss: 0.6432 - val_accuracy: 0.6192
# Epoch 7/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6901 - accuracy: 0.5247 - val_loss: 0.6894 - val_accuracy: 0.5481
# Epoch 8/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6929 - accuracy: 0.5066 - val_loss: 0.6894 - val_accuracy: 0.5565
# Epoch 9/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6923 - accuracy: 0.5085 - val_loss: 0.6882 - val_accuracy: 0.5607
# Epoch 10/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6822 - accuracy: 0.5444 - val_loss: 0.6919 - val_accuracy: 0.5439
# Epoch 11/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6897 - val_accuracy: 0.5523
# Epoch 12/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6666 - accuracy: 0.5742 - val_loss: 0.6810 - val_accuracy: 0.5941
# Epoch 13/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6767 - accuracy: 0.5511 - val_loss: 0.6352 - val_accuracy: 0.6234
# Epoch 14/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6525 - accuracy: 0.5909 - val_loss: 0.6457 - val_accuracy: 0.6109
# Epoch 15/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6664 - accuracy: 0.5636 - val_loss: 0.6183 - val_accuracy: 0.6736
# Epoch 16/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6552 - accuracy: 0.5853 - val_loss: 0.6164 - val_accuracy: 0.7113
# Epoch 17/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6497 - accuracy: 0.5924 - val_loss: 0.6137 - val_accuracy: 0.7071
# Epoch 18/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6438 - accuracy: 0.6064 - val_loss: 0.6334 - val_accuracy: 0.6485
# Epoch 19/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6417 - accuracy: 0.6118 - val_loss: 0.6170 - val_accuracy: 0.6862
# Epoch 20/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6214 - accuracy: 0.6350 - val_loss: 0.6254 - val_accuracy: 0.6653
# Epoch 21/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6356 - accuracy: 0.6175 - val_loss: 0.6134 - val_accuracy: 0.6778
# Epoch 22/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6347 - accuracy: 0.6152 - val_loss: 0.6060 - val_accuracy: 0.6904
# Epoch 23/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6338 - accuracy: 0.6221 - val_loss: 0.6027 - val_accuracy: 0.6904
# Epoch 24/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6188 - accuracy: 0.6369 - val_loss: 0.6166 - val_accuracy: 0.6736
# Epoch 25/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6283 - accuracy: 0.6281 - val_loss: 0.6216 - val_accuracy: 0.6611
# Epoch 26/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6214 - accuracy: 0.6287 - val_loss: 0.6288 - val_accuracy: 0.6485
# Epoch 27/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6267 - accuracy: 0.6329 - val_loss: 0.5978 - val_accuracy: 0.7197
# Epoch 28/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6216 - accuracy: 0.6317 - val_loss: 0.6015 - val_accuracy: 0.6904
# Epoch 29/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6230 - accuracy: 0.6379 - val_loss: 0.6007 - val_accuracy: 0.6820
# Epoch 30/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6291 - accuracy: 0.6237 - val_loss: 0.5947 - val_accuracy: 0.7197
# Epoch 31/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6273 - accuracy: 0.6266 - val_loss: 0.5971 - val_accuracy: 0.6987
# Epoch 32/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6200 - accuracy: 0.6346 - val_loss: 0.5918 - val_accuracy: 0.7155
# Epoch 33/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6189 - accuracy: 0.6333 - val_loss: 0.6324 - val_accuracy: 0.6611
# Epoch 34/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6298 - accuracy: 0.6243 - val_loss: 0.5975 - val_accuracy: 0.7029
# Epoch 35/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6145 - accuracy: 0.6423 - val_loss: 0.5876 - val_accuracy: 0.7197
# Epoch 36/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6296 - accuracy: 0.6314 - val_loss: 0.5939 - val_accuracy: 0.7197
# Epoch 37/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6165 - accuracy: 0.6388 - val_loss: 0.6014 - val_accuracy: 0.6946
# Epoch 38/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6195 - accuracy: 0.6413 - val_loss: 0.5877 - val_accuracy: 0.7155
# Epoch 39/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6211 - accuracy: 0.6344 - val_loss: 0.5809 - val_accuracy: 0.7322
# Epoch 40/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6107 - accuracy: 0.6469 - val_loss: 0.6250 - val_accuracy: 0.6778
# Epoch 41/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6172 - accuracy: 0.6417 - val_loss: 0.5885 - val_accuracy: 0.7113
# Epoch 42/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6243 - accuracy: 0.6260 - val_loss: 0.6239 - val_accuracy: 0.6904
# Epoch 43/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6225 - accuracy: 0.6331 - val_loss: 0.5803 - val_accuracy: 0.7197
# Epoch 44/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6203 - accuracy: 0.6323 - val_loss: 0.5789 - val_accuracy: 0.7197
# Epoch 45/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6131 - accuracy: 0.6415 - val_loss: 0.6105 - val_accuracy: 0.6778
# Epoch 46/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6110 - accuracy: 0.6461 - val_loss: 0.6559 - val_accuracy: 0.6444
# Epoch 47/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6160 - accuracy: 0.6406 - val_loss: 0.5823 - val_accuracy: 0.7238
# Epoch 48/50
# 300/300 [==============================] - 25s 84ms/step - loss: 0.6160 - accuracy: 0.6406 - val_loss: 0.5770 - val_accuracy: 0.7322
# Epoch 49/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6162 - accuracy: 0.6367 - val_loss: 0.6963 - val_accuracy: 0.5983
# Epoch 50/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.6156 - accuracy: 0.6392 - val_loss: 0.5875 - val_accuracy: 0.7197

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.4, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 118ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.50      0.66       110
#            1       0.70      0.99      0.82       131
#
#     accuracy                           0.77       241
#    macro avg       0.84      0.75      0.74       241
# weighted avg       0.83      0.77      0.75       241

# %%
model_saved = r'D:\My Code\Classification\models'
model.save(os.path.join(model_saved, f'{model_name}_{dataset_code} (256X256).h5'))
