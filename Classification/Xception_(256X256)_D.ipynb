# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import Xception
from keras.utils import Sequence
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'D'
model_name = 'Xception'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

batch_size = 16
train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)

# %%
Xception_model = Xception(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(Xception_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 8, 8, 2048)        20861480
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 289,301,033
# Trainable params: 268,439,553
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator)
# Out:
# Epoch 1/50
# 300/300 [==============================] - 31s 89ms/step - loss: 3.3321 - accuracy: 0.8453 - val_loss: 0.5742 - val_accuracy: 0.8870
# Epoch 2/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2062 - accuracy: 0.9417 - val_loss: 0.3907 - val_accuracy: 0.9247
# Epoch 3/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1184 - accuracy: 0.9647 - val_loss: 0.7190 - val_accuracy: 0.8828
# Epoch 4/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1478 - accuracy: 0.9566 - val_loss: 0.5304 - val_accuracy: 0.9079
# Epoch 5/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1344 - accuracy: 0.9626 - val_loss: 0.5059 - val_accuracy: 0.9163
# Epoch 6/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1386 - accuracy: 0.9624 - val_loss: 0.8127 - val_accuracy: 0.8996
# Epoch 7/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1237 - accuracy: 0.9649 - val_loss: 0.7903 - val_accuracy: 0.9079
# Epoch 8/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1805 - accuracy: 0.9607 - val_loss: 0.9605 - val_accuracy: 0.9121
# Epoch 9/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1990 - accuracy: 0.9607 - val_loss: 1.0700 - val_accuracy: 0.8954
# Epoch 10/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2871 - accuracy: 0.9553 - val_loss: 0.8371 - val_accuracy: 0.8912
# Epoch 11/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1757 - accuracy: 0.9708 - val_loss: 1.7073 - val_accuracy: 0.9038
# Epoch 12/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1718 - accuracy: 0.9749 - val_loss: 0.7810 - val_accuracy: 0.9247
# Epoch 13/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1042 - accuracy: 0.9802 - val_loss: 1.4847 - val_accuracy: 0.9038
# Epoch 14/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1329 - accuracy: 0.9770 - val_loss: 0.8963 - val_accuracy: 0.9331
# Epoch 15/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1028 - accuracy: 0.9808 - val_loss: 0.9550 - val_accuracy: 0.9121
# Epoch 16/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.0988 - accuracy: 0.9843 - val_loss: 1.3781 - val_accuracy: 0.8912
# Epoch 17/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1237 - accuracy: 0.9787 - val_loss: 1.6221 - val_accuracy: 0.9121
# Epoch 18/50
# 300/300 [==============================] - 25s 82ms/step - loss: 0.3702 - accuracy: 0.9699 - val_loss: 1.9892 - val_accuracy: 0.9079
# Epoch 19/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2225 - accuracy: 0.9758 - val_loss: 1.3785 - val_accuracy: 0.8996
# Epoch 20/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2838 - accuracy: 0.9747 - val_loss: 2.3964 - val_accuracy: 0.8828
# Epoch 21/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2628 - accuracy: 0.9816 - val_loss: 2.3056 - val_accuracy: 0.9079
# Epoch 22/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2327 - accuracy: 0.9787 - val_loss: 1.8089 - val_accuracy: 0.9205
# Epoch 23/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1654 - accuracy: 0.9833 - val_loss: 2.1076 - val_accuracy: 0.9163
# Epoch 24/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1952 - accuracy: 0.9818 - val_loss: 3.2765 - val_accuracy: 0.9038
# Epoch 25/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2573 - accuracy: 0.9814 - val_loss: 2.2797 - val_accuracy: 0.9247
# Epoch 26/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1587 - accuracy: 0.9879 - val_loss: 1.9775 - val_accuracy: 0.9414
# Epoch 27/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1245 - accuracy: 0.9885 - val_loss: 2.1304 - val_accuracy: 0.9163
# Epoch 28/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1299 - accuracy: 0.9904 - val_loss: 2.1170 - val_accuracy: 0.9331
# Epoch 29/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1142 - accuracy: 0.9871 - val_loss: 2.7132 - val_accuracy: 0.9079
# Epoch 30/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.0649 - accuracy: 0.9921 - val_loss: 2.5734 - val_accuracy: 0.9163
# Epoch 31/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1638 - accuracy: 0.9866 - val_loss: 2.9839 - val_accuracy: 0.9247
# Epoch 32/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2187 - accuracy: 0.9862 - val_loss: 2.0107 - val_accuracy: 0.9414
# Epoch 33/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2741 - accuracy: 0.9833 - val_loss: 3.7603 - val_accuracy: 0.9038
# Epoch 34/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1755 - accuracy: 0.9879 - val_loss: 2.7275 - val_accuracy: 0.9372
# Epoch 35/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1756 - accuracy: 0.9881 - val_loss: 4.8500 - val_accuracy: 0.9038
# Epoch 36/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1476 - accuracy: 0.9896 - val_loss: 3.0560 - val_accuracy: 0.9289
# Epoch 37/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.0991 - accuracy: 0.9912 - val_loss: 6.1748 - val_accuracy: 0.9079
# Epoch 38/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2276 - accuracy: 0.9900 - val_loss: 4.5879 - val_accuracy: 0.9121
# Epoch 39/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1522 - accuracy: 0.9910 - val_loss: 4.7711 - val_accuracy: 0.9163
# Epoch 40/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.3036 - accuracy: 0.9887 - val_loss: 4.9636 - val_accuracy: 0.9163
# Epoch 41/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2192 - accuracy: 0.9898 - val_loss: 8.3113 - val_accuracy: 0.9038
# Epoch 42/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1668 - accuracy: 0.9908 - val_loss: 4.2887 - val_accuracy: 0.9247
# Epoch 43/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1155 - accuracy: 0.9948 - val_loss: 4.1970 - val_accuracy: 0.9414
# Epoch 44/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1510 - accuracy: 0.9914 - val_loss: 4.4600 - val_accuracy: 0.9205
# Epoch 45/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.0505 - accuracy: 0.9950 - val_loss: 5.4785 - val_accuracy: 0.9163
# Epoch 46/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2372 - accuracy: 0.9879 - val_loss: 6.3752 - val_accuracy: 0.9163
# Epoch 47/50
# 300/300 [==============================] - 25s 82ms/step - loss: 0.0874 - accuracy: 0.9960 - val_loss: 5.5264 - val_accuracy: 0.9289
# Epoch 48/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2074 - accuracy: 0.9925 - val_loss: 6.7400 - val_accuracy: 0.9038
# Epoch 49/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.1533 - accuracy: 0.9927 - val_loss: 6.6140 - val_accuracy: 0.9247
# Epoch 50/50
# 300/300 [==============================] - 25s 83ms/step - loss: 0.2863 - accuracy: 0.9900 - val_loss: 7.9723 - val_accuracy: 0.9121

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.4, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 142ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95       110
#            1       0.97      0.94      0.95       131
#
#     accuracy                           0.95       241
#    macro avg       0.95      0.95      0.95       241
# weighted avg       0.95      0.95      0.95       241

# %%
model_saved = r'D:\My Code\Classification\models'
model.save(os.path.join(model_saved, f'{dataset_code}_{model_name}  (256X256).h5'))
