# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import MobileNet
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'A'
model_name = 'MobileNet_(3x)'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\A_augmented(30)_training.pkl'
val_data_path = f'{data_saved_dir}\A_validation.pkl'
test_data_path = f'{data_saved_dir}\A_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (5739, 256, 256, 3)
# Validation images: (838, 256, 256, 3)
# Testing images: (845, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
mobile_net = MobileNet(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(mobile_net)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 8, 8, 1024)       3228864
#  nal)
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_2 (Dense)             (None, 2048)              134219776
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 137,450,689
# Trainable params: 134,221,825
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 179/180 [============================>.] - ETA: 0s - loss: 3.6635 - accuracy: 0.8714
# Epoch 1: val_accuracy improved from -inf to 0.89021, saving model to F:\models_10\A_MobileNet_(3x)\A_MobileNet_(3x)-weights-improvement-01-0.89.hdf5
# 180/180 [==============================] - 15s 69ms/step - loss: 3.6449 - accuracy: 0.8718 - val_loss: 0.7234 - val_accuracy: 0.8902
# Epoch 2/50
# 180/180 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9646
# Epoch 2: val_accuracy did not improve from 0.89021
# 180/180 [==============================] - 9s 52ms/step - loss: 0.1286 - accuracy: 0.9646 - val_loss: 0.7635 - val_accuracy: 0.8437
# Epoch 3/50
# 179/180 [============================>.] - ETA: 0s - loss: 0.0506 - accuracy: 0.9837
# Epoch 3: val_accuracy improved from 0.89021 to 0.92959, saving model to F:\models_10\A_MobileNet_(3x)\A_MobileNet_(3x)-weights-improvement-03-0.93.hdf5
# 180/180 [==============================] - 12s 67ms/step - loss: 0.0515 - accuracy: 0.9836 - val_loss: 0.3145 - val_accuracy: 0.9296
# Epoch 4/50
# 180/180 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9941
# Epoch 4: val_accuracy did not improve from 0.92959
# 180/180 [==============================] - 9s 52ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 0.4497 - val_accuracy: 0.9069
# Epoch 5/50
# 179/180 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9925
# Epoch 5: val_accuracy did not improve from 0.92959
# 180/180 [==============================] - 9s 51ms/step - loss: 0.0217 - accuracy: 0.9925 - val_loss: 0.4295 - val_accuracy: 0.9189
# Epoch 6/50
# 179/180 [============================>.] - ETA: 0s - loss: 0.0574 - accuracy: 0.9827
# Epoch 6: val_accuracy did not improve from 0.92959
# 180/180 [==============================] - 9s 52ms/step - loss: 0.0572 - accuracy: 0.9827 - val_loss: 0.7596 - val_accuracy: 0.8759
# Epoch 7/50
# 180/180 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9821
# Epoch 7: val_accuracy did not improve from 0.92959
# 180/180 [==============================] - 9s 52ms/step - loss: 0.0931 - accuracy: 0.9821 - val_loss: 1.3838 - val_accuracy: 0.8652
# Epoch 8/50
# 180/180 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9773
# Epoch 8: val_accuracy improved from 0.92959 to 0.93079, saving model to F:\models_10\A_MobileNet_(3x)\A_MobileNet_(3x)-weights-improvement-08-0.93.hdf5
# 180/180 [==============================] - 12s 67ms/step - loss: 0.1169 - accuracy: 0.9773 - val_loss: 0.4524 - val_accuracy: 0.9308
# Epoch 9/50
# 180/180 [==============================] - ETA: 0s - loss: 0.1481 - accuracy: 0.9744
# Epoch 9: val_accuracy did not improve from 0.93079
# 180/180 [==============================] - 9s 52ms/step - loss: 0.1481 - accuracy: 0.9744 - val_loss: 0.5567 - val_accuracy: 0.9284
# Epoch 10/50
# 180/180 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9861
# Epoch 10: val_accuracy did not improve from 0.93079
# 180/180 [==============================] - 9s 52ms/step - loss: 0.0569 - accuracy: 0.9861 - val_loss: 0.4891 - val_accuracy: 0.9236
# Epoch 11/50
# 179/180 [============================>.] - ETA: 0s - loss: 0.0431 - accuracy: 0.9895
# Epoch 11: val_accuracy improved from 0.93079 to 0.96539, saving model to F:\models_10\A_MobileNet_(3x)\A_MobileNet_(3x)-weights-improvement-11-0.97.hdf5
# 180/180 [==============================] - 12s 66ms/step - loss: 0.0443 - accuracy: 0.9892 - val_loss: 0.3138 - val_accuracy: 0.9654
# Epoch 12/50
# 180/180 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9873
# Epoch 12: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 51ms/step - loss: 0.0692 - accuracy: 0.9873 - val_loss: 0.7475 - val_accuracy: 0.9260
# Epoch 13/50
# 179/180 [============================>.] - ETA: 0s - loss: 0.1821 - accuracy: 0.9794
# Epoch 13: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 51ms/step - loss: 0.1829 - accuracy: 0.9793 - val_loss: 1.0749 - val_accuracy: 0.9093
# Epoch 14/50
# 179/180 [============================>.] - ETA: 0s - loss: 0.2645 - accuracy: 0.9753
# Epoch 14: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 52ms/step - loss: 0.2640 - accuracy: 0.9751 - val_loss: 1.0238 - val_accuracy: 0.9153
# Epoch 15/50
# 179/180 [============================>.] - ETA: 0s - loss: 0.1025 - accuracy: 0.9851
# Epoch 15: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 52ms/step - loss: 0.1019 - accuracy: 0.9852 - val_loss: 0.4840 - val_accuracy: 0.9654
# Epoch 16/50
# 180/180 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9873
# Epoch 16: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 52ms/step - loss: 0.0805 - accuracy: 0.9873 - val_loss: 0.6507 - val_accuracy: 0.9487
# Epoch 17/50
# 179/180 [============================>.] - ETA: 0s - loss: 0.0924 - accuracy: 0.9914
# Epoch 17: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 51ms/step - loss: 0.0919 - accuracy: 0.9915 - val_loss: 0.8962 - val_accuracy: 0.9320
# Epoch 18/50
# 180/180 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9897
# Epoch 18: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 51ms/step - loss: 0.0923 - accuracy: 0.9897 - val_loss: 1.2196 - val_accuracy: 0.9236
# Epoch 19/50
# 180/180 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9888
# Epoch 19: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 52ms/step - loss: 0.0834 - accuracy: 0.9888 - val_loss: 0.6203 - val_accuracy: 0.9523
# Epoch 20/50
# 180/180 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9883
# Epoch 20: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 51ms/step - loss: 0.1207 - accuracy: 0.9883 - val_loss: 0.7066 - val_accuracy: 0.9642
# Epoch 21/50
# 180/180 [==============================] - ETA: 0s - loss: 0.1937 - accuracy: 0.9840
# Epoch 21: val_accuracy did not improve from 0.96539
# 180/180 [==============================] - 9s 51ms/step - loss: 0.1937 - accuracy: 0.9840 - val_loss: 1.1992 - val_accuracy: 0.9499
# Epoch 21: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 27/27 [==============================] - 1s 28ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       712
#            1       0.80      0.94      0.86       133
#
#     accuracy                           0.95       845
#    macro avg       0.89      0.95      0.92       845
# weighted avg       0.96      0.95      0.95       845

# %% [markdown]
# #### Testing on model which is last best saved

# %%
model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'

models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['A_MobileNet_(3x)-weights-improvement-11-0.97.hdf5']
# Best model loaded ...
# 27/27 [==============================] - 3s 38ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       712
#            1       0.85      0.92      0.88       133
#
#     accuracy                           0.96       845
#    macro avg       0.92      0.94      0.93       845
# weighted avg       0.96      0.96      0.96       845
