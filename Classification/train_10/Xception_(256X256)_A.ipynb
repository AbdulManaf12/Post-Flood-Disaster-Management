# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import Xception
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'A'
model_name = 'Xception'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
# model_saved_dir = r'D:\My Code\Classification\models'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\A_training.pkl'
val_data_path = f'{data_saved_dir}\A_validation.pkl'
test_data_path = f'{data_saved_dir}\A_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (3921, 256, 256, 3)
# Validation images: (838, 256, 256, 3)
# Testing images: (845, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
Xception_model = Xception(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(Xception_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 8, 8, 2048)        20861480
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 289,301,033
# Trainable params: 268,439,553
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 123/123 [==============================] - ETA: 0s - loss: 3.6288 - accuracy: 0.8934
# Epoch 1: val_accuracy improved from -inf to 0.92840, saving model to F:\models_10\A_Xception\A_Xception-weights-improvement-01-0.93.hdf5
# 123/123 [==============================] - 28s 192ms/step - loss: 3.6288 - accuracy: 0.8934 - val_loss: 0.1848 - val_accuracy: 0.9284
# Epoch 2/50
# 123/123 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9505
# Epoch 2: val_accuracy improved from 0.92840 to 0.94749, saving model to F:\models_10\A_Xception\A_Xception-weights-improvement-02-0.95.hdf5
# 123/123 [==============================] - 22s 178ms/step - loss: 0.1418 - accuracy: 0.9505 - val_loss: 0.1339 - val_accuracy: 0.9475
# Epoch 3/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9666
# Epoch 3: val_accuracy improved from 0.94749 to 0.95823, saving model to F:\models_10\A_Xception\A_Xception-weights-improvement-03-0.96.hdf5
# 123/123 [==============================] - 22s 178ms/step - loss: 0.0924 - accuracy: 0.9666 - val_loss: 0.1119 - val_accuracy: 0.9582
# Epoch 4/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9745
# Epoch 4: val_accuracy did not improve from 0.95823
# 123/123 [==============================] - 17s 133ms/step - loss: 0.0693 - accuracy: 0.9745 - val_loss: 0.1279 - val_accuracy: 0.9582
# Epoch 5/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9824
# Epoch 5: val_accuracy improved from 0.95823 to 0.96539, saving model to F:\models_10\A_Xception\A_Xception-weights-improvement-05-0.97.hdf5
# 123/123 [==============================] - 22s 179ms/step - loss: 0.0528 - accuracy: 0.9824 - val_loss: 0.1348 - val_accuracy: 0.9654
# Epoch 6/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9837
# Epoch 6: val_accuracy did not improve from 0.96539
# 123/123 [==============================] - 17s 134ms/step - loss: 0.0503 - accuracy: 0.9837 - val_loss: 0.1647 - val_accuracy: 0.9558
# Epoch 7/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9824
# Epoch 7: val_accuracy did not improve from 0.96539
# 123/123 [==============================] - 17s 134ms/step - loss: 0.0453 - accuracy: 0.9824 - val_loss: 0.1057 - val_accuracy: 0.9618
# Epoch 8/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9870
# Epoch 8: val_accuracy did not improve from 0.96539
# 123/123 [==============================] - 17s 134ms/step - loss: 0.0369 - accuracy: 0.9870 - val_loss: 0.1220 - val_accuracy: 0.9630
# Epoch 9/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0318 - accuracy: 0.9895
# Epoch 9: val_accuracy improved from 0.96539 to 0.96897, saving model to F:\models_10\A_Xception\A_Xception-weights-improvement-09-0.97.hdf5
# 123/123 [==============================] - 22s 178ms/step - loss: 0.0318 - accuracy: 0.9895 - val_loss: 0.1164 - val_accuracy: 0.9690
# Epoch 10/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9880
# Epoch 10: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 17s 134ms/step - loss: 0.0326 - accuracy: 0.9880 - val_loss: 0.1596 - val_accuracy: 0.9630
# Epoch 11/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9837
# Epoch 11: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 16s 134ms/step - loss: 0.0484 - accuracy: 0.9837 - val_loss: 0.1900 - val_accuracy: 0.9618
# Epoch 12/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9816
# Epoch 12: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 16s 133ms/step - loss: 0.0589 - accuracy: 0.9816 - val_loss: 0.1724 - val_accuracy: 0.9594
# Epoch 13/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9898
# Epoch 13: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 16s 133ms/step - loss: 0.0419 - accuracy: 0.9898 - val_loss: 0.2520 - val_accuracy: 0.9523
# Epoch 14/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9842
# Epoch 14: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 16s 133ms/step - loss: 0.0430 - accuracy: 0.9842 - val_loss: 0.1984 - val_accuracy: 0.9582
# Epoch 15/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9839
# Epoch 15: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 16s 133ms/step - loss: 0.0463 - accuracy: 0.9839 - val_loss: 0.1753 - val_accuracy: 0.9558
# Epoch 16/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9913
# Epoch 16: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 16s 133ms/step - loss: 0.0241 - accuracy: 0.9913 - val_loss: 0.1948 - val_accuracy: 0.9535
# Epoch 17/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9941
# Epoch 17: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 16s 133ms/step - loss: 0.0213 - accuracy: 0.9941 - val_loss: 0.2596 - val_accuracy: 0.9535
# Epoch 17: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 27/27 [==============================] - 3s 98ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       712
#            1       1.00      0.80      0.89       133
#
#     accuracy                           0.97       845
#    macro avg       0.98      0.90      0.93       845
# weighted avg       0.97      0.97      0.97       845

# %% [markdown]
# #### Testing on model which is last best saved

# %%
model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'

models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['A_Xception-weights-improvement-09-0.97.hdf5']
# Best model loaded ...
# 27/27 [==============================] - 5s 91ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       712
#            1       0.97      0.87      0.92       133
#
#     accuracy                           0.98       845
#    macro avg       0.98      0.93      0.95       845
# weighted avg       0.98      0.98      0.98       845
