# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import VGG16
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'B'
model_name = 'VGG-16'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\B_training.pkl'
val_data_path = f'{data_saved_dir}\B_validation.pkl'
test_data_path = f'{data_saved_dir}\B_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (4586, 256, 256, 3)
# Validation images: (979, 256, 256, 3)
# Testing images: (990, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
Vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(256, 256, 3))
model = Sequential()
model.add(Vgg16)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 2048)              67110912
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 81,827,649
# Trainable params: 67,112,961
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 144/144 [==============================] - ETA: 0s - loss: 1.3050 - accuracy: 0.8419
# Epoch 1: val_accuracy improved from -inf to 0.91624, saving model to F:\models_10\B_VGG-16\B_VGG-16-weights-improvement-01-0.92.hdf5
# 144/144 [==============================] - 26s 158ms/step - loss: 1.3050 - accuracy: 0.8419 - val_loss: 0.2261 - val_accuracy: 0.9162
# Epoch 2/50
# 144/144 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9230
# Epoch 2: val_accuracy improved from 0.91624 to 0.91931, saving model to F:\models_10\B_VGG-16\B_VGG-16-weights-improvement-02-0.92.hdf5
# 144/144 [==============================] - 21s 148ms/step - loss: 0.1941 - accuracy: 0.9230 - val_loss: 0.2163 - val_accuracy: 0.9193
# Epoch 3/50
# 144/144 [==============================] - ETA: 0s - loss: 0.1423 - accuracy: 0.9461
# Epoch 3: val_accuracy did not improve from 0.91931
# 144/144 [==============================] - 20s 137ms/step - loss: 0.1423 - accuracy: 0.9461 - val_loss: 0.2458 - val_accuracy: 0.9122
# Epoch 4/50
# 144/144 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9631
# Epoch 4: val_accuracy did not improve from 0.91931
# 144/144 [==============================] - 20s 139ms/step - loss: 0.1060 - accuracy: 0.9631 - val_loss: 0.3471 - val_accuracy: 0.8917
# Epoch 5/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0936 - accuracy: 0.9682
# Epoch 5: val_accuracy improved from 0.91931 to 0.92033, saving model to F:\models_10\B_VGG-16\B_VGG-16-weights-improvement-05-0.92.hdf5
# 144/144 [==============================] - 21s 148ms/step - loss: 0.0936 - accuracy: 0.9682 - val_loss: 0.2405 - val_accuracy: 0.9203
# Epoch 6/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.9699
# Epoch 6: val_accuracy did not improve from 0.92033
# 144/144 [==============================] - 20s 137ms/step - loss: 0.0772 - accuracy: 0.9699 - val_loss: 0.2249 - val_accuracy: 0.9183
# Epoch 7/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9686
# Epoch 7: val_accuracy did not improve from 0.92033
# 144/144 [==============================] - 20s 137ms/step - loss: 0.0827 - accuracy: 0.9686 - val_loss: 0.3150 - val_accuracy: 0.9060
# Epoch 8/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9762
# Epoch 8: val_accuracy improved from 0.92033 to 0.93156, saving model to F:\models_10\B_VGG-16\B_VGG-16-weights-improvement-08-0.93.hdf5
# 144/144 [==============================] - 21s 147ms/step - loss: 0.0573 - accuracy: 0.9762 - val_loss: 0.2287 - val_accuracy: 0.9316
# Epoch 9/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9850
# Epoch 9: val_accuracy improved from 0.93156 to 0.93258, saving model to F:\models_10\B_VGG-16\B_VGG-16-weights-improvement-09-0.93.hdf5
# 144/144 [==============================] - 21s 147ms/step - loss: 0.0436 - accuracy: 0.9850 - val_loss: 0.2174 - val_accuracy: 0.9326
# Epoch 10/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9843
# Epoch 10: val_accuracy did not improve from 0.93258
# 144/144 [==============================] - 20s 137ms/step - loss: 0.0478 - accuracy: 0.9843 - val_loss: 0.2484 - val_accuracy: 0.9285
# Epoch 11/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9727
# Epoch 11: val_accuracy did not improve from 0.93258
# 144/144 [==============================] - 20s 137ms/step - loss: 0.0806 - accuracy: 0.9727 - val_loss: 0.4864 - val_accuracy: 0.8815
# Epoch 12/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9717
# Epoch 12: val_accuracy did not improve from 0.93258
# 144/144 [==============================] - 20s 138ms/step - loss: 0.0758 - accuracy: 0.9717 - val_loss: 0.2093 - val_accuracy: 0.9316
# Epoch 13/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9834
# Epoch 13: val_accuracy did not improve from 0.93258
# 144/144 [==============================] - 20s 137ms/step - loss: 0.0440 - accuracy: 0.9834 - val_loss: 0.2738 - val_accuracy: 0.9122
# Epoch 14/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9904
# Epoch 14: val_accuracy did not improve from 0.93258
# 144/144 [==============================] - 20s 138ms/step - loss: 0.0294 - accuracy: 0.9904 - val_loss: 0.2440 - val_accuracy: 0.9244
# Epoch 15/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9924
# Epoch 15: val_accuracy did not improve from 0.93258
# 144/144 [==============================] - 20s 138ms/step - loss: 0.0240 - accuracy: 0.9924 - val_loss: 0.2377 - val_accuracy: 0.9275
# Epoch 16/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9839
# Epoch 16: val_accuracy did not improve from 0.93258
# 144/144 [==============================] - 20s 138ms/step - loss: 0.0450 - accuracy: 0.9839 - val_loss: 0.3157 - val_accuracy: 0.9254
# Epoch 17/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9860
# Epoch 17: val_accuracy improved from 0.93258 to 0.93871, saving model to F:\models_10\B_VGG-16\B_VGG-16-weights-improvement-17-0.94.hdf5
# 144/144 [==============================] - 21s 147ms/step - loss: 0.0370 - accuracy: 0.9860 - val_loss: 0.2578 - val_accuracy: 0.9387
# Epoch 18/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9852
# Epoch 18: val_accuracy did not improve from 0.93871
# 144/144 [==============================] - 20s 138ms/step - loss: 0.0420 - accuracy: 0.9852 - val_loss: 0.2819 - val_accuracy: 0.9265
# Epoch 19/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9869
# Epoch 19: val_accuracy did not improve from 0.93871
# 144/144 [==============================] - 20s 137ms/step - loss: 0.0361 - accuracy: 0.9869 - val_loss: 0.4655 - val_accuracy: 0.9081
# Epoch 20/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9902
# Epoch 20: val_accuracy did not improve from 0.93871
# 144/144 [==============================] - 20s 137ms/step - loss: 0.0279 - accuracy: 0.9902 - val_loss: 0.2683 - val_accuracy: 0.9254
# Epoch 21/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9943
# Epoch 21: val_accuracy did not improve from 0.93871
# 144/144 [==============================] - 20s 138ms/step - loss: 0.0148 - accuracy: 0.9943 - val_loss: 0.4748 - val_accuracy: 0.9152
# Epoch 22/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9841
# Epoch 22: val_accuracy did not improve from 0.93871
# 144/144 [==============================] - 20s 138ms/step - loss: 0.0484 - accuracy: 0.9841 - val_loss: 0.9596 - val_accuracy: 0.8621
# Epoch 22: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 31/31 [==============================] - 4s 137ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       764
#            1       0.99      0.46      0.63       226
#
#     accuracy                           0.88       990
#    macro avg       0.93      0.73      0.78       990
# weighted avg       0.89      0.88      0.86       990

# %% [markdown]
# #### Testing on model which is last best saved

# %%
model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['B_VGG-16-weights-improvement-17-0.94.hdf5']
# Best model loaded ...
# 31/31 [==============================] - 7s 142ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       764
#            1       0.90      0.80      0.85       226
#
#     accuracy                           0.93       990
#    macro avg       0.92      0.89      0.90       990
# weighted avg       0.93      0.93      0.93       990
