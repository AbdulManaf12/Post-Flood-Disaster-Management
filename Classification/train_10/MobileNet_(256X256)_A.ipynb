# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import MobileNet
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'A'
model_name = 'MobileNet'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
# model_saved_dir = r'D:\My Code\Classification\models'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\A_training.pkl'
val_data_path = f'{data_saved_dir}\A_validation.pkl'
test_data_path = f'{data_saved_dir}\A_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (3921, 256, 256, 3)
# Validation images: (838, 256, 256, 3)
# Testing images: (845, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
mobile_net = MobileNet(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(mobile_net)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 8, 8, 1024)       3228864
#  nal)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 2048)              134219776
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 137,450,689
# Trainable params: 134,221,825
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 123/123 [==============================] - ETA: 0s - loss: 4.6958 - accuracy: 0.9148
# Epoch 1: val_accuracy improved from -inf to 0.95585, saving model to F:\models_10\A_MobileNet\A_MobileNet-weights-improvement-01-0.96.hdf5
# 123/123 [==============================] - 14s 87ms/step - loss: 4.6958 - accuracy: 0.9148 - val_loss: 0.6822 - val_accuracy: 0.9558
# Epoch 2/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.2429 - accuracy: 0.9766
# Epoch 2: val_accuracy improved from 0.95585 to 0.96420, saving model to F:\models_10\A_MobileNet\A_MobileNet-weights-improvement-02-0.96.hdf5
# 123/123 [==============================] - 10s 80ms/step - loss: 0.2409 - accuracy: 0.9768 - val_loss: 0.2576 - val_accuracy: 0.9642
# Epoch 3/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.0777 - accuracy: 0.9856
# Epoch 3: val_accuracy improved from 0.96420 to 0.96897, saving model to F:\models_10\A_MobileNet\A_MobileNet-weights-improvement-03-0.97.hdf5
# 123/123 [==============================] - 10s 78ms/step - loss: 0.0771 - accuracy: 0.9857 - val_loss: 0.2204 - val_accuracy: 0.9690
# Epoch 4/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9959
# Epoch 4: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 7s 54ms/step - loss: 0.0217 - accuracy: 0.9957 - val_loss: 0.2309 - val_accuracy: 0.9678
# Epoch 5/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9962
# Epoch 5: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 7s 53ms/step - loss: 0.0156 - accuracy: 0.9962 - val_loss: 0.2783 - val_accuracy: 0.9606
# Epoch 6/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9941
# Epoch 6: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 7s 54ms/step - loss: 0.0209 - accuracy: 0.9941 - val_loss: 0.2200 - val_accuracy: 0.9666
# Epoch 7/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9967
# Epoch 7: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 7s 53ms/step - loss: 0.0176 - accuracy: 0.9967 - val_loss: 0.2147 - val_accuracy: 0.9678
# Epoch 8/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.0292 - accuracy: 0.9920
# Epoch 8: val_accuracy did not improve from 0.96897
# 123/123 [==============================] - 7s 53ms/step - loss: 0.0290 - accuracy: 0.9921 - val_loss: 0.4255 - val_accuracy: 0.9535
# Epoch 9/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.0499 - accuracy: 0.9905
# Epoch 9: val_accuracy improved from 0.96897 to 0.97017, saving model to F:\models_10\A_MobileNet\A_MobileNet-weights-improvement-09-0.97.hdf5
# 123/123 [==============================] - 9s 77ms/step - loss: 0.0495 - accuracy: 0.9906 - val_loss: 0.3271 - val_accuracy: 0.9702
# Epoch 10/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.0777 - accuracy: 0.9882
# Epoch 10: val_accuracy did not improve from 0.97017
# 123/123 [==============================] - 7s 54ms/step - loss: 0.0810 - accuracy: 0.9880 - val_loss: 0.5661 - val_accuracy: 0.9666
# Epoch 11/50
# 123/123 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9895
# Epoch 11: val_accuracy did not improve from 0.97017
# 123/123 [==============================] - 7s 54ms/step - loss: 0.1055 - accuracy: 0.9895 - val_loss: 0.5575 - val_accuracy: 0.9618
# Epoch 12/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.0885 - accuracy: 0.9920
# Epoch 12: val_accuracy did not improve from 0.97017
# 123/123 [==============================] - 7s 54ms/step - loss: 0.0878 - accuracy: 0.9921 - val_loss: 0.5732 - val_accuracy: 0.9642
# Epoch 13/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.0356 - accuracy: 0.9964
# Epoch 13: val_accuracy did not improve from 0.97017
# 123/123 [==============================] - 7s 53ms/step - loss: 0.0354 - accuracy: 0.9964 - val_loss: 0.5848 - val_accuracy: 0.9690
# Epoch 14/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9929
# Epoch 14: val_accuracy did not improve from 0.97017
# 123/123 [==============================] - 7s 53ms/step - loss: 0.0692 - accuracy: 0.9929 - val_loss: 0.5035 - val_accuracy: 0.9678
# Epoch 15/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.0562 - accuracy: 0.9931
# Epoch 15: val_accuracy did not improve from 0.97017
# 123/123 [==============================] - 7s 53ms/step - loss: 0.0557 - accuracy: 0.9931 - val_loss: 0.7106 - val_accuracy: 0.9654
# Epoch 16/50
# 122/123 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9956
# Epoch 16: val_accuracy did not improve from 0.97017
# 123/123 [==============================] - 6s 53ms/step - loss: 0.0346 - accuracy: 0.9957 - val_loss: 0.5286 - val_accuracy: 0.9666
# Epoch 17/50
# 123/123 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9903
# Epoch 17: val_accuracy did not improve from 0.97017
# 123/123 [==============================] - 7s 53ms/step - loss: 0.1152 - accuracy: 0.9903 - val_loss: 0.9613 - val_accuracy: 0.9642
# Epoch 17: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 27/27 [==============================] - 1s 33ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       712
#            1       0.98      0.77      0.87       133
#
#     accuracy                           0.96       845
#    macro avg       0.97      0.89      0.92       845
# weighted avg       0.96      0.96      0.96       845

# %% [markdown]
# #### Testing on model which is last best saved

# %%
model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'

models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['A_MobileNet-weights-improvement-09-0.97.hdf5']
# Best model loaded ...
# 27/27 [==============================] - 3s 35ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       712
#            1       0.96      0.92      0.94       133
#
#     accuracy                           0.98       845
#    macro avg       0.97      0.96      0.96       845
# weighted avg       0.98      0.98      0.98       845
