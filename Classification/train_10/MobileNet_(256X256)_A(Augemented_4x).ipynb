# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import MobileNet
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'A'
model_name = 'MobileNet_(4x)'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
# model_saved_dir = r'D:\My Code\Classification\models'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\A_augmented(40)_training.pkl'
val_data_path = f'{data_saved_dir}\A_validation.pkl'
test_data_path = f'{data_saved_dir}\A_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (6345, 256, 256, 3)
# Validation images: (838, 256, 256, 3)
# Testing images: (845, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
mobile_net = MobileNet(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(mobile_net)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 8, 8, 1024)       3228864
#  nal)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 2048)              134219776
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 137,450,689
# Trainable params: 134,221,825
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 199/199 [==============================] - ETA: 0s - loss: 5.9276 - accuracy: 0.8670
# Epoch 1: val_accuracy improved from -inf to 0.92243, saving model to F:\models_10\A_MobileNet_(4x)\A_MobileNet_(4x)-weights-improvement-01-0.92.hdf5
# 199/199 [==============================] - 17s 71ms/step - loss: 5.9276 - accuracy: 0.8670 - val_loss: 0.2817 - val_accuracy: 0.9224
# Epoch 2/50
# 198/199 [============================>.] - ETA: 0s - loss: 0.0947 - accuracy: 0.9663
# Epoch 2: val_accuracy did not improve from 0.92243
# 199/199 [==============================] - 10s 51ms/step - loss: 0.0958 - accuracy: 0.9660 - val_loss: 0.3299 - val_accuracy: 0.9045
# Epoch 3/50
# 198/199 [============================>.] - ETA: 0s - loss: 0.0373 - accuracy: 0.9857
# Epoch 3: val_accuracy improved from 0.92243 to 0.93079, saving model to F:\models_10\A_MobileNet_(4x)\A_MobileNet_(4x)-weights-improvement-03-0.93.hdf5
# 199/199 [==============================] - 13s 66ms/step - loss: 0.0373 - accuracy: 0.9857 - val_loss: 0.2552 - val_accuracy: 0.9308
# Epoch 4/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9918
# Epoch 4: val_accuracy improved from 0.93079 to 0.93675, saving model to F:\models_10\A_MobileNet_(4x)\A_MobileNet_(4x)-weights-improvement-04-0.94.hdf5
# 199/199 [==============================] - 13s 66ms/step - loss: 0.0233 - accuracy: 0.9918 - val_loss: 0.2264 - val_accuracy: 0.9368
# Epoch 5/50
# 198/199 [============================>.] - ETA: 0s - loss: 0.0244 - accuracy: 0.9914
# Epoch 5: val_accuracy did not improve from 0.93675
# 199/199 [==============================] - 10s 51ms/step - loss: 0.0243 - accuracy: 0.9915 - val_loss: 0.5708 - val_accuracy: 0.8914
# Epoch 6/50
# 198/199 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9864
# Epoch 6: val_accuracy improved from 0.93675 to 0.95823, saving model to F:\models_10\A_MobileNet_(4x)\A_MobileNet_(4x)-weights-improvement-06-0.96.hdf5
# 199/199 [==============================] - 13s 65ms/step - loss: 0.0375 - accuracy: 0.9864 - val_loss: 0.1639 - val_accuracy: 0.9582
# Epoch 7/50
# 198/199 [============================>.] - ETA: 0s - loss: 0.0393 - accuracy: 0.9875
# Epoch 7: val_accuracy did not improve from 0.95823
# 199/199 [==============================] - 10s 50ms/step - loss: 0.0394 - accuracy: 0.9874 - val_loss: 0.3347 - val_accuracy: 0.9427
# Epoch 8/50
# 198/199 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.9753
# Epoch 8: val_accuracy did not improve from 0.95823
# 199/199 [==============================] - 10s 50ms/step - loss: 0.1275 - accuracy: 0.9754 - val_loss: 0.4125 - val_accuracy: 0.9368
# Epoch 9/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9847
# Epoch 9: val_accuracy did not improve from 0.95823
# 199/199 [==============================] - 10s 51ms/step - loss: 0.0624 - accuracy: 0.9847 - val_loss: 0.2614 - val_accuracy: 0.9523
# Epoch 10/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9910
# Epoch 10: val_accuracy did not improve from 0.95823
# 199/199 [==============================] - 10s 51ms/step - loss: 0.0353 - accuracy: 0.9910 - val_loss: 0.2320 - val_accuracy: 0.9558
# Epoch 11/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9904
# Epoch 11: val_accuracy did not improve from 0.95823
# 199/199 [==============================] - 10s 51ms/step - loss: 0.0309 - accuracy: 0.9904 - val_loss: 0.3217 - val_accuracy: 0.9523
# Epoch 12/50
# 198/199 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.9884
# Epoch 12: val_accuracy did not improve from 0.95823
# 199/199 [==============================] - 10s 51ms/step - loss: 0.0622 - accuracy: 0.9882 - val_loss: 0.5149 - val_accuracy: 0.9141
# Epoch 13/50
# 198/199 [============================>.] - ETA: 0s - loss: 0.0472 - accuracy: 0.9889
# Epoch 13: val_accuracy did not improve from 0.95823
# 199/199 [==============================] - 10s 50ms/step - loss: 0.0470 - accuracy: 0.9890 - val_loss: 0.7990 - val_accuracy: 0.8735
# Epoch 14/50
# 198/199 [============================>.] - ETA: 0s - loss: 0.0733 - accuracy: 0.9869
# Epoch 14: val_accuracy improved from 0.95823 to 0.96301, saving model to F:\models_10\A_MobileNet_(4x)\A_MobileNet_(4x)-weights-improvement-14-0.96.hdf5
# 199/199 [==============================] - 13s 65ms/step - loss: 0.0779 - accuracy: 0.9864 - val_loss: 0.3223 - val_accuracy: 0.9630
# Epoch 15/50
# 199/199 [==============================] - ETA: 0s - loss: 0.6135 - accuracy: 0.9574
# Epoch 15: val_accuracy did not improve from 0.96301
# 199/199 [==============================] - 10s 51ms/step - loss: 0.6135 - accuracy: 0.9574 - val_loss: 1.3620 - val_accuracy: 0.9284
# Epoch 16/50
# 199/199 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.9718
# Epoch 16: val_accuracy did not improve from 0.96301
# 199/199 [==============================] - 10s 51ms/step - loss: 0.3149 - accuracy: 0.9718 - val_loss: 1.0392 - val_accuracy: 0.9248
# Epoch 16: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 27/27 [==============================] - 1s 35ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96       712
#            1       0.70      0.97      0.81       133
#
#     accuracy                           0.93       845
#    macro avg       0.85      0.95      0.88       845
# weighted avg       0.95      0.93      0.93       845

# %% [markdown]
# #### Testing on model which is last best saved

# %%
model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'

models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['A_MobileNet_(4x)-weights-improvement-14-0.96.hdf5']
# Best model loaded ...
# 27/27 [==============================] - 1s 34ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       712
#            1       0.85      0.91      0.88       133
#
#     accuracy                           0.96       845
#    macro avg       0.91      0.94      0.93       845
# weighted avg       0.96      0.96      0.96       845
