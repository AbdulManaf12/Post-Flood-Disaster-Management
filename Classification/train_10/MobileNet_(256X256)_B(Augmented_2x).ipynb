# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import MobileNet
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'B'
model_name = 'MobileNet_(2x)'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
# model_saved_dir = r'D:\My Code\Classification\models'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\B_augmented(20)_training.pkl'
val_data_path = f'{data_saved_dir}\B_validation.pkl'
test_data_path = f'{data_saved_dir}\B_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (6656, 256, 256, 3)
# Validation images: (979, 256, 256, 3)
# Testing images: (990, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
mobile_net = MobileNet(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(mobile_net)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 8, 8, 1024)       3228864
#  nal)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 2048)              134219776
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 137,450,689
# Trainable params: 134,221,825
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 207/208 [============================>.] - ETA: 0s - loss: 5.2858 - accuracy: 0.8418
# Epoch 1: val_accuracy improved from -inf to 0.87028, saving model to F:\models_10\B_MobileNet_(2x)\B_MobileNet_(2x)-weights-improvement-01-0.87.hdf5
# 208/208 [==============================] - 17s 69ms/step - loss: 5.2614 - accuracy: 0.8422 - val_loss: 0.5026 - val_accuracy: 0.8703
# Epoch 2/50
# 208/208 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9558
# Epoch 2: val_accuracy improved from 0.87028 to 0.89275, saving model to F:\models_10\B_MobileNet_(2x)\B_MobileNet_(2x)-weights-improvement-02-0.89.hdf5
# 208/208 [==============================] - 13s 65ms/step - loss: 0.1288 - accuracy: 0.9558 - val_loss: 0.4063 - val_accuracy: 0.8927
# Epoch 3/50
# 208/208 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9758
# Epoch 3: val_accuracy did not improve from 0.89275
# 208/208 [==============================] - 11s 52ms/step - loss: 0.0665 - accuracy: 0.9758 - val_loss: 0.5158 - val_accuracy: 0.8784
# Epoch 4/50
# 208/208 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9863
# Epoch 4: val_accuracy did not improve from 0.89275
# 208/208 [==============================] - 11s 53ms/step - loss: 0.0400 - accuracy: 0.9863 - val_loss: 0.6300 - val_accuracy: 0.8754
# Epoch 5/50
# 208/208 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9830
# Epoch 5: val_accuracy improved from 0.89275 to 0.89377, saving model to F:\models_10\B_MobileNet_(2x)\B_MobileNet_(2x)-weights-improvement-05-0.89.hdf5
# 208/208 [==============================] - 14s 66ms/step - loss: 0.0485 - accuracy: 0.9830 - val_loss: 0.5500 - val_accuracy: 0.8938
# Epoch 6/50
# 207/208 [============================>.] - ETA: 0s - loss: 0.0347 - accuracy: 0.9875
# Epoch 6: val_accuracy did not improve from 0.89377
# 208/208 [==============================] - 11s 52ms/step - loss: 0.0346 - accuracy: 0.9875 - val_loss: 0.6206 - val_accuracy: 0.8846
# Epoch 7/50
# 207/208 [============================>.] - ETA: 0s - loss: 0.0465 - accuracy: 0.9855
# Epoch 7: val_accuracy did not improve from 0.89377
# 208/208 [==============================] - 11s 52ms/step - loss: 0.0486 - accuracy: 0.9851 - val_loss: 0.7733 - val_accuracy: 0.8733
# Epoch 8/50
# 207/208 [============================>.] - ETA: 0s - loss: 0.0599 - accuracy: 0.9834
# Epoch 8: val_accuracy did not improve from 0.89377
# 208/208 [==============================] - 11s 52ms/step - loss: 0.0596 - accuracy: 0.9835 - val_loss: 1.0792 - val_accuracy: 0.8509
# Epoch 9/50
# 207/208 [============================>.] - ETA: 0s - loss: 0.1905 - accuracy: 0.9651
# Epoch 9: val_accuracy improved from 0.89377 to 0.93565, saving model to F:\models_10\B_MobileNet_(2x)\B_MobileNet_(2x)-weights-improvement-09-0.94.hdf5
# 208/208 [==============================] - 14s 66ms/step - loss: 0.1896 - accuracy: 0.9653 - val_loss: 0.4975 - val_accuracy: 0.9356
# Epoch 10/50
# 207/208 [============================>.] - ETA: 0s - loss: 0.1344 - accuracy: 0.9712
# Epoch 10: val_accuracy did not improve from 0.93565
# 208/208 [==============================] - 11s 52ms/step - loss: 0.1346 - accuracy: 0.9712 - val_loss: 0.8716 - val_accuracy: 0.8590
# Epoch 11/50
# 208/208 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9854
# Epoch 11: val_accuracy did not improve from 0.93565
# 208/208 [==============================] - 11s 53ms/step - loss: 0.0491 - accuracy: 0.9854 - val_loss: 0.5681 - val_accuracy: 0.9203
# Epoch 12/50
# 207/208 [============================>.] - ETA: 0s - loss: 0.0587 - accuracy: 0.9869
# Epoch 12: val_accuracy did not improve from 0.93565
# 208/208 [==============================] - 11s 52ms/step - loss: 0.0586 - accuracy: 0.9868 - val_loss: 0.6723 - val_accuracy: 0.9234
# Epoch 12: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 31/31 [==============================] - 2s 36ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       764
#            1       0.78      0.92      0.85       226
#
#     accuracy                           0.92       990
#    macro avg       0.88      0.92      0.90       990
# weighted avg       0.93      0.92      0.93       990

# %% [markdown]
# #### Testing on model which is last best saved

# %%
model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'

models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['B_MobileNet_(2x)-weights-improvement-09-0.94.hdf5']
# Best model loaded ...
# 31/31 [==============================] - 2s 39ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       764
#            1       0.83      0.90      0.86       226
#
#     accuracy                           0.93       990
#    macro avg       0.90      0.92      0.91       990
# weighted avg       0.94      0.93      0.94       990
