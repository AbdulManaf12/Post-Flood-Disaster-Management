# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import ResNet50
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'A'
model_name = 'ResNet-50'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\A_training.pkl'
val_data_path = f'{data_saved_dir}\A_validation.pkl'
test_data_path = f'{data_saved_dir}\A_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (3921, 256, 256, 3)
# Validation images: (838, 256, 256, 3)
# Testing images: (845, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
ResNet50_model = ResNet50(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(ResNet50_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 292,027,265
# Trainable params: 268,439,553
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 123/123 [==============================] - ETA: 0s - loss: 3.5666 - accuracy: 0.7876
# Epoch 1: val_accuracy improved from -inf to 0.84726, saving model to F:\models_10\A_ResNet-50\A_ResNet-50-weights-improvement-01-0.85.hdf5
# 123/123 [==============================] - 29s 193ms/step - loss: 3.5666 - accuracy: 0.7876 - val_loss: 0.8610 - val_accuracy: 0.8473
# Epoch 2/50
# 123/123 [==============================] - ETA: 0s - loss: 0.4342 - accuracy: 0.8411
# Epoch 2: val_accuracy improved from 0.84726 to 0.87470, saving model to F:\models_10\A_ResNet-50\A_ResNet-50-weights-improvement-02-0.87.hdf5
# 123/123 [==============================] - 22s 177ms/step - loss: 0.4342 - accuracy: 0.8411 - val_loss: 0.3458 - val_accuracy: 0.8747
# Epoch 3/50
# 123/123 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8498
# Epoch 3: val_accuracy did not improve from 0.87470
# 123/123 [==============================] - 16s 131ms/step - loss: 0.4036 - accuracy: 0.8498 - val_loss: 0.3351 - val_accuracy: 0.8723
# Epoch 4/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3748 - accuracy: 0.8511
# Epoch 4: val_accuracy improved from 0.87470 to 0.87828, saving model to F:\models_10\A_ResNet-50\A_ResNet-50-weights-improvement-04-0.88.hdf5
# 123/123 [==============================] - 22s 179ms/step - loss: 0.3748 - accuracy: 0.8511 - val_loss: 0.3063 - val_accuracy: 0.8783
# Epoch 5/50
# 123/123 [==============================] - ETA: 0s - loss: 0.4056 - accuracy: 0.8460
# Epoch 5: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 128ms/step - loss: 0.4056 - accuracy: 0.8460 - val_loss: 0.3639 - val_accuracy: 0.8473
# Epoch 6/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3926 - accuracy: 0.8457
# Epoch 6: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 128ms/step - loss: 0.3926 - accuracy: 0.8457 - val_loss: 0.3121 - val_accuracy: 0.8473
# Epoch 7/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3865 - accuracy: 0.8505
# Epoch 7: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 128ms/step - loss: 0.3865 - accuracy: 0.8505 - val_loss: 0.3366 - val_accuracy: 0.8473
# Epoch 8/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.8452
# Epoch 8: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 129ms/step - loss: 0.3905 - accuracy: 0.8452 - val_loss: 0.3162 - val_accuracy: 0.8473
# Epoch 9/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3795 - accuracy: 0.8465
# Epoch 9: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 128ms/step - loss: 0.3795 - accuracy: 0.8465 - val_loss: 0.3038 - val_accuracy: 0.8484
# Epoch 10/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3923 - accuracy: 0.8452
# Epoch 10: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 129ms/step - loss: 0.3923 - accuracy: 0.8452 - val_loss: 0.3674 - val_accuracy: 0.8473
# Epoch 11/50
# 123/123 [==============================] - ETA: 0s - loss: 0.4061 - accuracy: 0.8460
# Epoch 11: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 129ms/step - loss: 0.4061 - accuracy: 0.8460 - val_loss: 0.3418 - val_accuracy: 0.8473
# Epoch 12/50
# 123/123 [==============================] - ETA: 0s - loss: 0.4025 - accuracy: 0.8454
# Epoch 12: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 129ms/step - loss: 0.4025 - accuracy: 0.8454 - val_loss: 0.3189 - val_accuracy: 0.8473
# Epoch 13/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3900 - accuracy: 0.8457
# Epoch 13: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 127ms/step - loss: 0.3900 - accuracy: 0.8457 - val_loss: 0.3118 - val_accuracy: 0.8473
# Epoch 14/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3788 - accuracy: 0.8457
# Epoch 14: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 129ms/step - loss: 0.3788 - accuracy: 0.8457 - val_loss: 0.3466 - val_accuracy: 0.8473
# Epoch 15/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3959 - accuracy: 0.8454
# Epoch 15: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 129ms/step - loss: 0.3959 - accuracy: 0.8454 - val_loss: 0.3163 - val_accuracy: 0.8473
# Epoch 16/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3998 - accuracy: 0.8457
# Epoch 16: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 130ms/step - loss: 0.3998 - accuracy: 0.8457 - val_loss: 0.3377 - val_accuracy: 0.8473
# Epoch 17/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3781 - accuracy: 0.8454
# Epoch 17: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 129ms/step - loss: 0.3781 - accuracy: 0.8454 - val_loss: 0.3172 - val_accuracy: 0.8473
# Epoch 18/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3779 - accuracy: 0.8452
# Epoch 18: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 129ms/step - loss: 0.3779 - accuracy: 0.8452 - val_loss: 0.3254 - val_accuracy: 0.8473
# Epoch 19/50
# 123/123 [==============================] - ETA: 0s - loss: 0.3741 - accuracy: 0.8454
# Epoch 19: val_accuracy did not improve from 0.87828
# 123/123 [==============================] - 16s 127ms/step - loss: 0.3741 - accuracy: 0.8454 - val_loss: 0.3122 - val_accuracy: 0.8473
# Epoch 19: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 27/27 [==============================] - 3s 89ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       712
#            1       0.00      0.00      0.00       133
#
#     accuracy                           0.84       845
#    macro avg       0.42      0.50      0.46       845
# weighted avg       0.71      0.84      0.77       845
# c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### Testing on model which is last best saved

# %%
model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'

models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['A_ResNet-50-weights-improvement-04-0.88.hdf5']
# Best model loaded ...
# 27/27 [==============================] - 5s 92ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93       712
#            1       0.79      0.20      0.31       133
#
#     accuracy                           0.87       845
#    macro avg       0.83      0.59      0.62       845
# weighted avg       0.86      0.87      0.83       845
