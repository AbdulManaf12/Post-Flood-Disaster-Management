# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import VGG16
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'A'
model_name = 'VGG-16'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\A_training.pkl'
val_data_path = f'{data_saved_dir}\A_validation.pkl'
test_data_path = f'{data_saved_dir}\A_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (3921, 256, 256, 3)
# Validation images: (838, 256, 256, 3)
# Testing images: (845, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
Vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(256, 256, 3))
model = Sequential()
model.add(Vgg16)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 2048)              67110912
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 81,827,649
# Trainable params: 67,112,961
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 123/123 [==============================] - ETA: 0s - loss: 1.2825 - accuracy: 0.8559
# Epoch 1: val_accuracy improved from -inf to 0.91050, saving model to F:\models_10\A_VGG-16\A_VGG-16-weights-improvement-01-0.91.hdf5
# 123/123 [==============================] - 23s 161ms/step - loss: 1.2825 - accuracy: 0.8559 - val_loss: 0.2142 - val_accuracy: 0.9105
# Epoch 2/50
# 123/123 [==============================] - ETA: 0s - loss: 0.1594 - accuracy: 0.9408
# Epoch 2: val_accuracy improved from 0.91050 to 0.94153, saving model to F:\models_10\A_VGG-16\A_VGG-16-weights-improvement-02-0.94.hdf5
# 123/123 [==============================] - 18s 147ms/step - loss: 0.1594 - accuracy: 0.9408 - val_loss: 0.1676 - val_accuracy: 0.9415
# Epoch 3/50
# 123/123 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9648
# Epoch 3: val_accuracy improved from 0.94153 to 0.94630, saving model to F:\models_10\A_VGG-16\A_VGG-16-weights-improvement-03-0.95.hdf5
# 123/123 [==============================] - 18s 149ms/step - loss: 0.1016 - accuracy: 0.9648 - val_loss: 0.1420 - val_accuracy: 0.9463
# Epoch 4/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9770
# Epoch 4: val_accuracy improved from 0.94630 to 0.94988, saving model to F:\models_10\A_VGG-16\A_VGG-16-weights-improvement-04-0.95.hdf5
# 123/123 [==============================] - 18s 148ms/step - loss: 0.0635 - accuracy: 0.9770 - val_loss: 0.1282 - val_accuracy: 0.9499
# Epoch 5/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9852
# Epoch 5: val_accuracy did not improve from 0.94988
# 123/123 [==============================] - 17s 136ms/step - loss: 0.0456 - accuracy: 0.9852 - val_loss: 0.1355 - val_accuracy: 0.9439
# Epoch 6/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9850
# Epoch 6: val_accuracy did not improve from 0.94988
# 123/123 [==============================] - 17s 138ms/step - loss: 0.0428 - accuracy: 0.9850 - val_loss: 0.1716 - val_accuracy: 0.9451
# Epoch 7/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0377 - accuracy: 0.9878
# Epoch 7: val_accuracy did not improve from 0.94988
# 123/123 [==============================] - 17s 136ms/step - loss: 0.0377 - accuracy: 0.9878 - val_loss: 0.1614 - val_accuracy: 0.9439
# Epoch 8/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9918
# Epoch 8: val_accuracy did not improve from 0.94988
# 123/123 [==============================] - 17s 137ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 0.1939 - val_accuracy: 0.9403
# Epoch 9/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9832
# Epoch 9: val_accuracy did not improve from 0.94988
# 123/123 [==============================] - 17s 137ms/step - loss: 0.0447 - accuracy: 0.9832 - val_loss: 0.1639 - val_accuracy: 0.9415
# Epoch 10/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9809
# Epoch 10: val_accuracy improved from 0.94988 to 0.95346, saving model to F:\models_10\A_VGG-16\A_VGG-16-weights-improvement-10-0.95.hdf5
# 123/123 [==============================] - 18s 148ms/step - loss: 0.0561 - accuracy: 0.9809 - val_loss: 0.1726 - val_accuracy: 0.9535
# Epoch 11/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9867
# Epoch 11: val_accuracy did not improve from 0.95346
# 123/123 [==============================] - 17s 137ms/step - loss: 0.0365 - accuracy: 0.9867 - val_loss: 0.2091 - val_accuracy: 0.9463
# Epoch 12/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9936
# Epoch 12: val_accuracy did not improve from 0.95346
# 123/123 [==============================] - 17s 137ms/step - loss: 0.0227 - accuracy: 0.9936 - val_loss: 0.2051 - val_accuracy: 0.9260
# Epoch 13/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9916
# Epoch 13: val_accuracy did not improve from 0.95346
# 123/123 [==============================] - 17s 137ms/step - loss: 0.0240 - accuracy: 0.9916 - val_loss: 0.3660 - val_accuracy: 0.9260
# Epoch 14/50
# 123/123 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9748
# Epoch 14: val_accuracy did not improve from 0.95346
# 123/123 [==============================] - 17s 137ms/step - loss: 0.0700 - accuracy: 0.9748 - val_loss: 0.2001 - val_accuracy: 0.9451
# Epoch 14: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 27/27 [==============================] - 4s 132ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       712
#            1       0.93      0.74      0.83       133
#
#     accuracy                           0.95       845
#    macro avg       0.94      0.87      0.90       845
# weighted avg       0.95      0.95      0.95       845

# %% [markdown]
# #### Testing on model which is last best saved

# %%
models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['A_VGG-16-weights-improvement-10-0.95.hdf5']
# Best model loaded ...
# 27/27 [==============================] - 3s 107ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       712
#            1       0.88      0.75      0.81       133
#
#     accuracy                           0.95       845
#    macro avg       0.92      0.87      0.89       845
# weighted avg       0.94      0.95      0.94       845
