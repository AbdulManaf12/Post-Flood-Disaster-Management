# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import ResNet50
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 16
dataset_code = 'B'
model_name = 'ResNet-50'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
# model_saved_dir = r'D:\My Code\Classification\models'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\B_training.pkl'
val_data_path = f'{data_saved_dir}\B_validation.pkl'
test_data_path = f'{data_saved_dir}\B_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (4586, 256, 256, 3)
# Validation images: (979, 256, 256, 3)
# Testing images: (990, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
ResNet50_model = ResNet50(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(ResNet50_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 292,027,265
# Trainable params: 268,439,553
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 287/287 [==============================] - ETA: 0s - loss: 2.7630 - accuracy: 0.7407
# Epoch 1: val_accuracy improved from -inf to 0.77630, saving model to F:\models_10\B_ResNet-50\B_ResNet-50-weights-improvement-01-0.78.hdf5
# 287/287 [==============================] - 38s 115ms/step - loss: 2.7630 - accuracy: 0.7407 - val_loss: 0.4697 - val_accuracy: 0.7763
# Epoch 2/50
# 287/287 [==============================] - ETA: 0s - loss: 0.5288 - accuracy: 0.7734
# Epoch 2: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 88ms/step - loss: 0.5288 - accuracy: 0.7734 - val_loss: 0.4988 - val_accuracy: 0.7763
# Epoch 3/50
# 287/287 [==============================] - ETA: 0s - loss: 0.5223 - accuracy: 0.7726
# Epoch 3: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 25s 89ms/step - loss: 0.5223 - accuracy: 0.7726 - val_loss: 0.4341 - val_accuracy: 0.7763
# Epoch 4/50
# 287/287 [==============================] - ETA: 0s - loss: 0.5161 - accuracy: 0.7739
# Epoch 4: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.5161 - accuracy: 0.7739 - val_loss: 0.4360 - val_accuracy: 0.7763
# Epoch 5/50
# 287/287 [==============================] - ETA: 0s - loss: 0.5053 - accuracy: 0.7745
# Epoch 5: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 89ms/step - loss: 0.5053 - accuracy: 0.7745 - val_loss: 0.4494 - val_accuracy: 0.7763
# Epoch 6/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4910 - accuracy: 0.7741
# Epoch 6: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 89ms/step - loss: 0.4910 - accuracy: 0.7741 - val_loss: 0.4208 - val_accuracy: 0.7763
# Epoch 7/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4767 - accuracy: 0.7741
# Epoch 7: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4767 - accuracy: 0.7741 - val_loss: 0.4457 - val_accuracy: 0.7763
# Epoch 8/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4753 - accuracy: 0.7745
# Epoch 8: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4753 - accuracy: 0.7745 - val_loss: 0.4197 - val_accuracy: 0.7763
# Epoch 9/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4781 - accuracy: 0.7743
# Epoch 9: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4781 - accuracy: 0.7743 - val_loss: 0.4551 - val_accuracy: 0.7763
# Epoch 10/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4862 - accuracy: 0.7741
# Epoch 10: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 89ms/step - loss: 0.4862 - accuracy: 0.7741 - val_loss: 0.4275 - val_accuracy: 0.7763
# Epoch 11/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4926 - accuracy: 0.7743
# Epoch 11: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4926 - accuracy: 0.7743 - val_loss: 0.4714 - val_accuracy: 0.7753
# Epoch 12/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4643 - accuracy: 0.7743
# Epoch 12: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 25s 89ms/step - loss: 0.4643 - accuracy: 0.7743 - val_loss: 0.4446 - val_accuracy: 0.7763
# Epoch 13/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4697 - accuracy: 0.7743
# Epoch 13: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 25s 89ms/step - loss: 0.4697 - accuracy: 0.7743 - val_loss: 0.4424 - val_accuracy: 0.7763
# Epoch 14/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4754 - accuracy: 0.7743
# Epoch 14: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 89ms/step - loss: 0.4754 - accuracy: 0.7743 - val_loss: 0.4341 - val_accuracy: 0.7763
# Epoch 15/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4691 - accuracy: 0.7743
# Epoch 15: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4691 - accuracy: 0.7743 - val_loss: 0.4163 - val_accuracy: 0.7763
# Epoch 16/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4758 - accuracy: 0.7743
# Epoch 16: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 89ms/step - loss: 0.4758 - accuracy: 0.7743 - val_loss: 0.4169 - val_accuracy: 0.7763
# Epoch 17/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4678 - accuracy: 0.7743
# Epoch 17: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4678 - accuracy: 0.7743 - val_loss: 0.4154 - val_accuracy: 0.7763
# Epoch 18/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4852 - accuracy: 0.7743
# Epoch 18: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4852 - accuracy: 0.7743 - val_loss: 0.4161 - val_accuracy: 0.7763
# Epoch 19/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.7743
# Epoch 19: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4900 - accuracy: 0.7743 - val_loss: 0.4353 - val_accuracy: 0.7763
# Epoch 20/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4956 - accuracy: 0.7743
# Epoch 20: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4956 - accuracy: 0.7743 - val_loss: 0.4277 - val_accuracy: 0.7763
# Epoch 21/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7743
# Epoch 21: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4936 - accuracy: 0.7743 - val_loss: 0.4291 - val_accuracy: 0.7763
# Epoch 22/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4901 - accuracy: 0.7743
# Epoch 22: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4901 - accuracy: 0.7743 - val_loss: 0.4315 - val_accuracy: 0.7763
# Epoch 23/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4732 - accuracy: 0.7743
# Epoch 23: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4732 - accuracy: 0.7743 - val_loss: 0.4267 - val_accuracy: 0.7763
# Epoch 24/50
# 287/287 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 89ms/step - loss: 0.4716 - accuracy: 0.7743 - val_loss: 0.4466 - val_accuracy: 0.7763
# Epoch 41/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4497 - accuracy: 0.7743
# Epoch 41: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4497 - accuracy: 0.7743 - val_loss: 0.4182 - val_accuracy: 0.7763
# Epoch 42/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4616 - accuracy: 0.7743
# Epoch 42: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4616 - accuracy: 0.7743 - val_loss: 0.4026 - val_accuracy: 0.7763
# Epoch 43/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4674 - accuracy: 0.7743
# Epoch 43: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4674 - accuracy: 0.7743 - val_loss: 0.4116 - val_accuracy: 0.7763
# Epoch 44/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4562 - accuracy: 0.7743
# Epoch 44: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4562 - accuracy: 0.7743 - val_loss: 0.4077 - val_accuracy: 0.7763
# Epoch 45/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.7743
# Epoch 45: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4490 - accuracy: 0.7743 - val_loss: 0.4008 - val_accuracy: 0.7763
# Epoch 46/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7743
# Epoch 46: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 25s 89ms/step - loss: 0.4591 - accuracy: 0.7743 - val_loss: 0.4020 - val_accuracy: 0.7763
# Epoch 47/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4472 - accuracy: 0.7743
# Epoch 47: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4472 - accuracy: 0.7743 - val_loss: 0.4097 - val_accuracy: 0.7763
# Epoch 48/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7743
# Epoch 48: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 90ms/step - loss: 0.4468 - accuracy: 0.7743 - val_loss: 0.4102 - val_accuracy: 0.7763
# Epoch 49/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.7743
# Epoch 49: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 25s 88ms/step - loss: 0.4502 - accuracy: 0.7743 - val_loss: 0.3999 - val_accuracy: 0.7763
# Epoch 50/50
# 287/287 [==============================] - ETA: 0s - loss: 0.4525 - accuracy: 0.7743
# Epoch 50: val_accuracy did not improve from 0.77630
# 287/287 [==============================] - 26s 89ms/step - loss: 0.4525 - accuracy: 0.7743 - val_loss: 0.3988 - val_accuracy: 0.7763

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 62/62 [==============================] - 4s 49ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       764
#            1       0.00      0.00      0.00       226
#
#     accuracy                           0.77       990
#    macro avg       0.39      0.50      0.44       990
# weighted avg       0.60      0.77      0.67       990
# c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Abdul Manaf\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### Testing on model which is last best saved

# %%
model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'

models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['B_ResNet-50-weights-improvement-01-0.78.hdf5']
# Best model loaded ...
# 62/62 [==============================] - 6s 51ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       764
#            1       0.67      0.01      0.02       226
#
#     accuracy                           0.77       990
#    macro avg       0.72      0.50      0.44       990
# weighted avg       0.75      0.77      0.68       990
