# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.applications import Xception
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'B'
model_name = 'Xception'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
# model_saved_dir = r'D:\My Code\Classification\models'
model_saved_dir = r'F:\models_10'
train_data_path = f'{data_saved_dir}\B_training.pkl'
val_data_path = f'{data_saved_dir}\B_validation.pkl'
test_data_path = f'{data_saved_dir}\B_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (4586, 256, 256, 3)
# Validation images: (979, 256, 256, 3)
# Testing images: (990, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
Xception_model = Xception(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(Xception_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 8, 8, 2048)        20861480
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 289,301,033
# Trainable params: 268,439,553
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
filepath = f'{model_dir}\{dataset_code}_{model_name}-{filename}.hdf5'
 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 144/144 [==============================] - ETA: 0s - loss: 3.3243 - accuracy: 0.8539
# Epoch 1: val_accuracy improved from -inf to 0.92237, saving model to F:\models_10\B_Xception\B_Xception-weights-improvement-01-0.92.hdf5
# 144/144 [==============================] - 31s 186ms/step - loss: 3.3243 - accuracy: 0.8539 - val_loss: 0.4082 - val_accuracy: 0.9224
# Epoch 2/50
# 144/144 [==============================] - ETA: 0s - loss: 0.2092 - accuracy: 0.9368
# Epoch 2: val_accuracy improved from 0.92237 to 0.93871, saving model to F:\models_10\B_Xception\B_Xception-weights-improvement-02-0.94.hdf5
# 144/144 [==============================] - 25s 174ms/step - loss: 0.2092 - accuracy: 0.9368 - val_loss: 0.1861 - val_accuracy: 0.9387
# Epoch 3/50
# 144/144 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9618
# Epoch 3: val_accuracy did not improve from 0.93871
# 144/144 [==============================] - 20s 134ms/step - loss: 0.1088 - accuracy: 0.9618 - val_loss: 0.2150 - val_accuracy: 0.9367
# Epoch 4/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9756
# Epoch 4: val_accuracy did not improve from 0.93871
# 144/144 [==============================] - 19s 133ms/step - loss: 0.0729 - accuracy: 0.9756 - val_loss: 0.3025 - val_accuracy: 0.9193
# Epoch 5/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9758
# Epoch 5: val_accuracy improved from 0.93871 to 0.94076, saving model to F:\models_10\B_Xception\B_Xception-weights-improvement-05-0.94.hdf5
# 144/144 [==============================] - 26s 178ms/step - loss: 0.0724 - accuracy: 0.9758 - val_loss: 0.2477 - val_accuracy: 0.9408
# Epoch 6/50
# 144/144 [==============================] - ETA: 0s - loss: 0.1004 - accuracy: 0.9693
# Epoch 6: val_accuracy did not improve from 0.94076
# 144/144 [==============================] - 19s 133ms/step - loss: 0.1004 - accuracy: 0.9693 - val_loss: 0.2727 - val_accuracy: 0.9377
# Epoch 7/50
# 144/144 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9669
# Epoch 7: val_accuracy improved from 0.94076 to 0.94484, saving model to F:\models_10\B_Xception\B_Xception-weights-improvement-07-0.94.hdf5
# 144/144 [==============================] - 26s 177ms/step - loss: 0.1092 - accuracy: 0.9669 - val_loss: 0.3214 - val_accuracy: 0.9448
# Epoch 8/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9721
# Epoch 8: val_accuracy improved from 0.94484 to 0.94995, saving model to F:\models_10\B_Xception\B_Xception-weights-improvement-08-0.95.hdf5
# 144/144 [==============================] - 25s 173ms/step - loss: 0.0999 - accuracy: 0.9721 - val_loss: 0.2343 - val_accuracy: 0.9499
# Epoch 9/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9804
# Epoch 9: val_accuracy improved from 0.94995 to 0.95301, saving model to F:\models_10\B_Xception\B_Xception-weights-improvement-09-0.95.hdf5
# 144/144 [==============================] - 25s 172ms/step - loss: 0.0634 - accuracy: 0.9804 - val_loss: 0.2470 - val_accuracy: 0.9530
# Epoch 10/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9832
# Epoch 10: val_accuracy did not improve from 0.95301
# 144/144 [==============================] - 20s 133ms/step - loss: 0.0564 - accuracy: 0.9832 - val_loss: 0.3179 - val_accuracy: 0.9479
# Epoch 11/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9808
# Epoch 11: val_accuracy did not improve from 0.95301
# 144/144 [==============================] - 19s 134ms/step - loss: 0.0759 - accuracy: 0.9808 - val_loss: 0.3723 - val_accuracy: 0.9469
# Epoch 12/50
# 144/144 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9815
# Epoch 12: val_accuracy did not improve from 0.95301
# 144/144 [==============================] - 19s 134ms/step - loss: 0.0733 - accuracy: 0.9815 - val_loss: 0.3480 - val_accuracy: 0.9438
# Epoch 12: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 31/31 [==============================] - 4s 100ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       764
#            1       0.94      0.81      0.87       226
#
#     accuracy                           0.94       990
#    macro avg       0.94      0.90      0.92       990
# weighted avg       0.94      0.94      0.94       990

# %% [markdown]
# #### Testing on model which is last best saved

# %%
model_dir = f'{model_saved_dir}\{dataset_code}_{model_name}'

models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# ['B_Xception-weights-improvement-09-0.95.hdf5']
# Best model loaded ...
# 31/31 [==============================] - 6s 99ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       764
#            1       0.92      0.85      0.88       226
#
#     accuracy                           0.95       990
#    macro avg       0.94      0.91      0.92       990
# weighted avg       0.95      0.95      0.95       990
