# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import MobileNet
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'A'
model_name = 'MobileNet'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
_MobileNet = MobileNet(include_top=False, weights='imagenet', input_shape=(256, 256, 3))
model = Sequential()
model.add(_MobileNet)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 8, 8, 1024)       3228864
#  nal)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 2048)              134219776
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 137,450,689
# Trainable params: 134,221,825
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs = 50, batch_size = 32, validation_data = (val_images, val_labels))
# Out:
# Epoch 1/50
# 35/35 [==============================] - 7s 93ms/step - loss: 12.7056 - accuracy: 0.8423 - val_loss: 1.7387 - val_accuracy: 0.9498
# Epoch 2/50
# 35/35 [==============================] - 2s 57ms/step - loss: 1.1468 - accuracy: 0.9633 - val_loss: 1.7718 - val_accuracy: 0.9289
# Epoch 3/50
# 35/35 [==============================] - 2s 59ms/step - loss: 0.5748 - accuracy: 0.9758 - val_loss: 2.2301 - val_accuracy: 0.9372
# Epoch 4/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.1207 - accuracy: 0.9919 - val_loss: 1.2914 - val_accuracy: 0.9665
# Epoch 5/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.1034 - accuracy: 0.9937 - val_loss: 1.8297 - val_accuracy: 0.9498
# Epoch 6/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.0143 - accuracy: 0.9973 - val_loss: 2.4801 - val_accuracy: 0.9331
# Epoch 7/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.2512 - accuracy: 0.9892 - val_loss: 2.2091 - val_accuracy: 0.9247
# Epoch 8/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.1754 - accuracy: 0.9901 - val_loss: 1.8487 - val_accuracy: 0.9414
# Epoch 9/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.1243 - accuracy: 0.9919 - val_loss: 1.6140 - val_accuracy: 0.9498
# Epoch 10/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.0272 - accuracy: 0.9964 - val_loss: 1.3202 - val_accuracy: 0.9665
# Epoch 11/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.0378 - accuracy: 0.9955 - val_loss: 1.7918 - val_accuracy: 0.9498
# Epoch 12/50
# 35/35 [==============================] - 2s 58ms/step - loss: 0.0486 - accuracy: 0.9973 - val_loss: 1.4309 - val_accuracy: 0.9623
# Epoch 13/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.0641 - accuracy: 0.9973 - val_loss: 1.4115 - val_accuracy: 0.9498
# Epoch 14/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.0507 - accuracy: 0.9982 - val_loss: 1.5939 - val_accuracy: 0.9582
# Epoch 15/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.0391 - accuracy: 0.9964 - val_loss: 2.3888 - val_accuracy: 0.9414
# Epoch 16/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.0981 - accuracy: 0.9937 - val_loss: 1.8399 - val_accuracy: 0.9540
# Epoch 17/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.0015 - accuracy: 0.9991 - val_loss: 1.7911 - val_accuracy: 0.9456
# Epoch 18/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.0754 - accuracy: 0.9973 - val_loss: 2.2437 - val_accuracy: 0.9372
# Epoch 19/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 1.6799 - val_accuracy: 0.9498
# Epoch 20/50
# 35/35 [==============================] - 2s 57ms/step - loss: 2.5785e-08 - accuracy: 1.0000 - val_loss: 1.7136 - val_accuracy: 0.9498
# Epoch 21/50
# 35/35 [==============================] - 2s 55ms/step - loss: 0.0155 - accuracy: 0.9982 - val_loss: 2.3868 - val_accuracy: 0.9456
# Epoch 22/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.0154 - accuracy: 0.9964 - val_loss: 1.3924 - val_accuracy: 0.9498
# Epoch 23/50
# 35/35 [==============================] - 2s 56ms/step - loss: 1.3932e-04 - accuracy: 1.0000 - val_loss: 1.4898 - val_accuracy: 0.9665
# Epoch 24/50
# 35/35 [==============================] - 2s 56ms/step - loss: 1.8511e-09 - accuracy: 1.0000 - val_loss: 1.4898 - val_accuracy: 0.9665
# Epoch 25/50
# 35/35 [==============================] - 2s 55ms/step - loss: 2.1751e-11 - accuracy: 1.0000 - val_loss: 1.4897 - val_accuracy: 0.9665
# Epoch 26/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 2.6499 - val_accuracy: 0.9247
# Epoch 27/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.1718 - accuracy: 0.9946 - val_loss: 1.8807 - val_accuracy: 0.9498
# Epoch 28/50
# 35/35 [==============================] - 2s 55ms/step - loss: 0.2139 - accuracy: 0.9892 - val_loss: 1.7537 - val_accuracy: 0.9582
# Epoch 29/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.2855 - accuracy: 0.9892 - val_loss: 2.6539 - val_accuracy: 0.9456
# Epoch 30/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.1323 - accuracy: 0.9928 - val_loss: 1.6606 - val_accuracy: 0.9623
# Epoch 31/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.1984 - accuracy: 0.9946 - val_loss: 2.2285 - val_accuracy: 0.9707
# Epoch 32/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.2938 - accuracy: 0.9892 - val_loss: 1.6926 - val_accuracy: 0.9582
# Epoch 33/50
# 35/35 [==============================] - 2s 58ms/step - loss: 0.1303 - accuracy: 0.9946 - val_loss: 2.3068 - val_accuracy: 0.9623
# Epoch 34/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.7551 - accuracy: 0.9830 - val_loss: 3.1469 - val_accuracy: 0.9582
# Epoch 35/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.4759 - accuracy: 0.9884 - val_loss: 4.3562 - val_accuracy: 0.9372
# Epoch 36/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.7329 - accuracy: 0.9866 - val_loss: 4.4457 - val_accuracy: 0.9665
# Epoch 37/50
# 35/35 [==============================] - 2s 57ms/step - loss: 1.1073 - accuracy: 0.9830 - val_loss: 5.6380 - val_accuracy: 0.9498
# Epoch 38/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.6417 - accuracy: 0.9901 - val_loss: 10.8620 - val_accuracy: 0.9121
# Epoch 39/50
# 35/35 [==============================] - 2s 57ms/step - loss: 1.4105 - accuracy: 0.9821 - val_loss: 6.8125 - val_accuracy: 0.9582
# Epoch 40/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.1055 - accuracy: 0.9964 - val_loss: 6.3100 - val_accuracy: 0.9582
# Epoch 41/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.2943 - accuracy: 0.9946 - val_loss: 5.0159 - val_accuracy: 0.9582
# Epoch 42/50
# 35/35 [==============================] - 2s 57ms/step - loss: 2.6760e-08 - accuracy: 1.0000 - val_loss: 4.3818 - val_accuracy: 0.9707
# Epoch 43/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.7276 - accuracy: 0.9910 - val_loss: 13.2503 - val_accuracy: 0.9372
# Epoch 44/50
# 35/35 [==============================] - 2s 58ms/step - loss: 0.4714 - accuracy: 0.9937 - val_loss: 5.1527 - val_accuracy: 0.9498
# Epoch 45/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.2338 - accuracy: 0.9973 - val_loss: 8.6357 - val_accuracy: 0.9540
# Epoch 46/50
# 35/35 [==============================] - 2s 57ms/step - loss: 0.0335 - accuracy: 0.9991 - val_loss: 10.3783 - val_accuracy: 0.9498
# Epoch 47/50
# 35/35 [==============================] - 2s 55ms/step - loss: 0.1829 - accuracy: 0.9991 - val_loss: 8.5051 - val_accuracy: 0.9498
# Epoch 48/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.0244 - accuracy: 0.9991 - val_loss: 13.0629 - val_accuracy: 0.9414
# Epoch 49/50
# 35/35 [==============================] - 2s 55ms/step - loss: 0.0051 - accuracy: 0.9991 - val_loss: 7.8334 - val_accuracy: 0.9540
# Epoch 50/50
# 35/35 [==============================] - 2s 56ms/step - loss: 0.0774 - accuracy: 0.9991 - val_loss: 11.4839 - val_accuracy: 0.9456

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 1s 58ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       110
#            1       0.98      0.95      0.96       131
#
#     accuracy                           0.96       241
#    macro avg       0.96      0.96      0.96       241
# weighted avg       0.96      0.96      0.96       241

# %%
model_saved = r'D:\My Code\Classification\models'
model.save(os.path.join(model_saved, f'{dataset_code}_{model_name} (256X256).h5'))
