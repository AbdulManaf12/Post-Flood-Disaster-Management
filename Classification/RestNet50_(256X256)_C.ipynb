# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import ResNet50
from tensorflow.keras.utils import Sequence
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'C'
model_name = 'RestNet50'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

batch_size = 16
train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)

# %%
ResNet50_model = ResNet50(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(ResNet50_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 292,027,265
# Trainable params: 268,439,553
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator)
# Out:
# Epoch 1/50
# 279/279 [==============================] - 29s 87ms/step - loss: 4.6127 - accuracy: 0.5795 - val_loss: 0.6225 - val_accuracy: 0.7155
# Epoch 2/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6605 - accuracy: 0.6147 - val_loss: 0.6517 - val_accuracy: 0.5481
# Epoch 3/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6515 - accuracy: 0.6297 - val_loss: 0.5972 - val_accuracy: 0.6736
# Epoch 4/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6454 - accuracy: 0.6156 - val_loss: 0.6482 - val_accuracy: 0.6067
# Epoch 5/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6660 - accuracy: 0.5894 - val_loss: 0.6301 - val_accuracy: 0.7197
# Epoch 6/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6529 - accuracy: 0.6147 - val_loss: 0.6275 - val_accuracy: 0.7113
# Epoch 7/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6520 - accuracy: 0.6163 - val_loss: 0.5974 - val_accuracy: 0.7238
# Epoch 8/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6515 - accuracy: 0.6147 - val_loss: 0.5957 - val_accuracy: 0.7113
# Epoch 9/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6865 - accuracy: 0.5538 - val_loss: 0.6833 - val_accuracy: 0.5649
# Epoch 10/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6866 - accuracy: 0.5529 - val_loss: 0.6757 - val_accuracy: 0.5732
# Epoch 11/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6886 - accuracy: 0.5495 - val_loss: 0.6868 - val_accuracy: 0.5481
# Epoch 12/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6866 - accuracy: 0.5500 - val_loss: 0.6804 - val_accuracy: 0.5607
# Epoch 13/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6839 - accuracy: 0.5594 - val_loss: 0.6817 - val_accuracy: 0.5565
# Epoch 14/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6827 - accuracy: 0.5607 - val_loss: 1.0627 - val_accuracy: 0.5439
# Epoch 15/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6895 - accuracy: 0.5477 - val_loss: 0.6801 - val_accuracy: 0.5649
# Epoch 16/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6841 - accuracy: 0.5549 - val_loss: 0.6778 - val_accuracy: 0.5732
# Epoch 17/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6861 - accuracy: 0.5526 - val_loss: 0.6848 - val_accuracy: 0.5649
# Epoch 18/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6864 - accuracy: 0.5533 - val_loss: 0.6898 - val_accuracy: 0.5439
# Epoch 19/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6897 - accuracy: 0.5423 - val_loss: 0.6897 - val_accuracy: 0.5439
# Epoch 20/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6890 - accuracy: 0.5428 - val_loss: 0.6851 - val_accuracy: 0.5523
# Epoch 21/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6890 - accuracy: 0.5444 - val_loss: 0.6780 - val_accuracy: 0.5732
# Epoch 22/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6894 - accuracy: 0.5464 - val_loss: 0.6891 - val_accuracy: 0.5439
# Epoch 23/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6891 - accuracy: 0.5493 - val_loss: 0.6764 - val_accuracy: 0.5858
# Epoch 24/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6878 - accuracy: 0.5455 - val_loss: 0.6841 - val_accuracy: 0.5523
# Epoch 25/50
# 279/279 [==============================] - 23s 81ms/step - loss: 0.6872 - accuracy: 0.5484 - val_loss: 0.6838 - val_accuracy: 0.5565
# Epoch 26/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6894 - accuracy: 0.5426 - val_loss: 0.6893 - val_accuracy: 0.5439
# Epoch 27/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6894 - accuracy: 0.5426 - val_loss: 0.6893 - val_accuracy: 0.5439
# Epoch 28/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6892 - accuracy: 0.5428 - val_loss: 0.6893 - val_accuracy: 0.5439
# Epoch 29/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6891 - accuracy: 0.5435 - val_loss: 0.6832 - val_accuracy: 0.5523
# Epoch 30/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6867 - accuracy: 0.5504 - val_loss: 0.6817 - val_accuracy: 0.5607
# Epoch 31/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6869 - accuracy: 0.5500 - val_loss: 0.6810 - val_accuracy: 0.5649
# Epoch 32/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6880 - accuracy: 0.5488 - val_loss: 0.6797 - val_accuracy: 0.5774
# Epoch 33/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6869 - accuracy: 0.5497 - val_loss: 0.6781 - val_accuracy: 0.5774
# Epoch 34/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6854 - accuracy: 0.5547 - val_loss: 0.6756 - val_accuracy: 0.5774
# Epoch 35/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6847 - accuracy: 0.5549 - val_loss: 0.6761 - val_accuracy: 0.5774
# Epoch 36/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6841 - accuracy: 0.5544 - val_loss: 0.6755 - val_accuracy: 0.5732
# Epoch 37/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6854 - accuracy: 0.5558 - val_loss: 0.6744 - val_accuracy: 0.5774
# Epoch 38/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6838 - accuracy: 0.5540 - val_loss: 0.6785 - val_accuracy: 0.5732
# Epoch 39/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6833 - accuracy: 0.5558 - val_loss: 0.6776 - val_accuracy: 0.5732
# Epoch 40/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6861 - accuracy: 0.5482 - val_loss: 0.6856 - val_accuracy: 0.5523
# Epoch 41/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6849 - accuracy: 0.5526 - val_loss: 0.6829 - val_accuracy: 0.5690
# Epoch 42/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6819 - accuracy: 0.5553 - val_loss: 0.6750 - val_accuracy: 0.5774
# Epoch 43/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6821 - accuracy: 0.5585 - val_loss: 0.6756 - val_accuracy: 0.5732
# Epoch 44/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6820 - accuracy: 0.5551 - val_loss: 0.6795 - val_accuracy: 0.5690
# Epoch 45/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6810 - accuracy: 0.5625 - val_loss: 0.7115 - val_accuracy: 0.5523
# Epoch 46/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6825 - accuracy: 0.5591 - val_loss: 0.6870 - val_accuracy: 0.5481
# Epoch 47/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6827 - accuracy: 0.5607 - val_loss: 0.6823 - val_accuracy: 0.5732
# Epoch 48/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6812 - accuracy: 0.5585 - val_loss: 0.6854 - val_accuracy: 0.5607
# Epoch 49/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6775 - accuracy: 0.5636 - val_loss: 0.6860 - val_accuracy: 0.5816
# Epoch 50/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.6797 - accuracy: 0.5596 - val_loss: 0.6742 - val_accuracy: 0.5858

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.4, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 121ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.15      0.25       110
#            1       0.57      0.95      0.71       131
#
#     accuracy                           0.59       241
#    macro avg       0.64      0.55      0.48       241
# weighted avg       0.63      0.59      0.50       241

# %%
model_saved = r'D:\My Code\Classification\models'
model.save(os.path.join(model_saved, f'{dataset_code}_{model_name} (256X256).h5'))
