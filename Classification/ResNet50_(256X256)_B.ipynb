# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import ResNet50
from keras.utils import Sequence
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'B'
model_name = 'RestNet50'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

batch_size = 16
train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)

# %%
ResNet50_model = ResNet50(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(ResNet50_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 292,027,265
# Trainable params: 268,439,553
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator)
# Out:
# Epoch 1/50
# 130/130 [==============================] - 18s 102ms/step - loss: 8.3273 - accuracy: 0.5566 - val_loss: 0.6680 - val_accuracy: 0.6904
# Epoch 2/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6692 - accuracy: 0.6500 - val_loss: 0.6462 - val_accuracy: 0.6151
# Epoch 3/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6338 - accuracy: 0.6533 - val_loss: 0.6382 - val_accuracy: 0.6109
# Epoch 4/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6337 - accuracy: 0.6394 - val_loss: 0.6228 - val_accuracy: 0.6904
# Epoch 5/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6135 - accuracy: 0.6639 - val_loss: 0.6514 - val_accuracy: 0.5690
# Epoch 6/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6389 - accuracy: 0.6336 - val_loss: 0.6133 - val_accuracy: 0.6987
# Epoch 7/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6376 - accuracy: 0.6360 - val_loss: 0.6806 - val_accuracy: 0.6109
# Epoch 8/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6325 - accuracy: 0.6582 - val_loss: 0.6696 - val_accuracy: 0.5356
# Epoch 9/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6795 - accuracy: 0.6100 - val_loss: 0.6803 - val_accuracy: 0.5649
# Epoch 10/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6769 - accuracy: 0.5932 - val_loss: 0.6881 - val_accuracy: 0.5481
# Epoch 11/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6693 - accuracy: 0.6110 - val_loss: 0.6563 - val_accuracy: 0.6025
# Epoch 12/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6738 - accuracy: 0.6023 - val_loss: 0.6884 - val_accuracy: 0.5523
# Epoch 13/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6671 - accuracy: 0.6134 - val_loss: 0.6857 - val_accuracy: 0.5565
# Epoch 14/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6582 - accuracy: 0.6221 - val_loss: 0.6868 - val_accuracy: 0.5565
# Epoch 15/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6718 - accuracy: 0.6013 - val_loss: 0.6798 - val_accuracy: 0.5816
# Epoch 16/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6710 - accuracy: 0.6023 - val_loss: 0.6841 - val_accuracy: 0.5523
# Epoch 17/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6689 - accuracy: 0.6091 - val_loss: 0.6878 - val_accuracy: 0.5523
# Epoch 18/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6617 - accuracy: 0.6182 - val_loss: 0.6919 - val_accuracy: 0.5523
# Epoch 19/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6696 - accuracy: 0.6033 - val_loss: 0.6777 - val_accuracy: 0.5607
# Epoch 20/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6674 - accuracy: 0.6134 - val_loss: 0.6955 - val_accuracy: 0.5481
# Epoch 21/50
# 130/130 [==============================] - 12s 90ms/step - loss: 0.6722 - accuracy: 0.6004 - val_loss: 0.6836 - val_accuracy: 0.5732
# Epoch 22/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6654 - accuracy: 0.6115 - val_loss: 0.6939 - val_accuracy: 0.5481
# Epoch 23/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6722 - accuracy: 0.6028 - val_loss: 0.6827 - val_accuracy: 0.5732
# Epoch 24/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6676 - accuracy: 0.6095 - val_loss: 0.6677 - val_accuracy: 0.5523
# Epoch 25/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6599 - accuracy: 0.6264 - val_loss: 0.6918 - val_accuracy: 0.5565
# Epoch 26/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6677 - accuracy: 0.6124 - val_loss: 0.6826 - val_accuracy: 0.5690
# Epoch 27/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6535 - accuracy: 0.6379 - val_loss: 0.6556 - val_accuracy: 0.6569
# Epoch 28/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6699 - accuracy: 0.6033 - val_loss: 0.6981 - val_accuracy: 0.5439
# Epoch 29/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6737 - accuracy: 0.5980 - val_loss: 0.6957 - val_accuracy: 0.5481
# Epoch 30/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6634 - accuracy: 0.6172 - val_loss: 0.6955 - val_accuracy: 0.5481
# Epoch 31/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6623 - accuracy: 0.6163 - val_loss: 0.6982 - val_accuracy: 0.5439
# Epoch 32/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6735 - accuracy: 0.5980 - val_loss: 0.6960 - val_accuracy: 0.5481
# Epoch 33/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6717 - accuracy: 0.6023 - val_loss: 0.6884 - val_accuracy: 0.5607
# Epoch 34/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6695 - accuracy: 0.6062 - val_loss: 0.6902 - val_accuracy: 0.5523
# Epoch 35/50
# 130/130 [==============================] - 11s 88ms/step - loss: 0.6727 - accuracy: 0.5994 - val_loss: 0.6908 - val_accuracy: 0.5523
# Epoch 36/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6699 - accuracy: 0.6038 - val_loss: 0.6843 - val_accuracy: 0.5732
# Epoch 37/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6526 - accuracy: 0.6394 - val_loss: 0.6935 - val_accuracy: 0.5523
# Epoch 38/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6644 - accuracy: 0.6095 - val_loss: 0.6885 - val_accuracy: 0.5607
# Epoch 39/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6603 - accuracy: 0.6187 - val_loss: 0.6970 - val_accuracy: 0.5439
# Epoch 40/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6377 - accuracy: 0.6538 - val_loss: 0.6195 - val_accuracy: 0.7155
# Epoch 41/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6397 - accuracy: 0.6509 - val_loss: 0.6275 - val_accuracy: 0.7029
# Epoch 42/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6281 - accuracy: 0.6572 - val_loss: 0.6870 - val_accuracy: 0.5690
# Epoch 43/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6296 - accuracy: 0.6567 - val_loss: 0.6075 - val_accuracy: 0.7071
# Epoch 44/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6266 - accuracy: 0.6668 - val_loss: 0.6117 - val_accuracy: 0.7113
# Epoch 45/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6245 - accuracy: 0.6654 - val_loss: 0.6449 - val_accuracy: 0.6360
# Epoch 46/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6177 - accuracy: 0.6702 - val_loss: 0.6053 - val_accuracy: 0.7155
# Epoch 47/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6016 - accuracy: 0.6928 - val_loss: 0.6013 - val_accuracy: 0.7155
# Epoch 48/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6106 - accuracy: 0.6808 - val_loss: 0.6308 - val_accuracy: 0.6611
# Epoch 49/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6045 - accuracy: 0.6875 - val_loss: 0.6187 - val_accuracy: 0.7029
# Epoch 50/50
# 130/130 [==============================] - 12s 89ms/step - loss: 0.6140 - accuracy: 0.6784 - val_loss: 0.5997 - val_accuracy: 0.7155

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.4, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 1s 109ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.55      0.70       110
#            1       0.72      0.98      0.83       131
#
#     accuracy                           0.78       241
#    macro avg       0.84      0.77      0.76       241
# weighted avg       0.83      0.78      0.77       241

# %%
model_saved = r'D:\My Code\Classification\models'
model.save(os.path.join(model_saved, f'{dataset_code}_{model_name} (256X256).h5'))
