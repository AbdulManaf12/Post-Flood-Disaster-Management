# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import ResNet50
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'A'
model_name = 'RestNet50'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
ResNet50_model = ResNet50(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(ResNet50_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 7s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 292,027,265
# Trainable params: 268,439,553
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs = 50, batch_size = 32, validation_data = (val_images, val_labels))
# Out:
# Epoch 1/50
# 35/35 [==============================] - 13s 188ms/step - loss: 19.0256 - accuracy: 0.5296 - val_loss: 1.4962 - val_accuracy: 0.6736
# Epoch 2/50
# 35/35 [==============================] - 5s 130ms/step - loss: 1.5928 - accuracy: 0.6111 - val_loss: 0.5994 - val_accuracy: 0.6485
# Epoch 3/50
# 35/35 [==============================] - 5s 129ms/step - loss: 0.6034 - accuracy: 0.6944 - val_loss: 0.5958 - val_accuracy: 0.6987
# Epoch 4/50
# 35/35 [==============================] - 5s 129ms/step - loss: 0.5922 - accuracy: 0.6703 - val_loss: 0.6349 - val_accuracy: 0.5858
# Epoch 5/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5753 - accuracy: 0.7124 - val_loss: 0.5927 - val_accuracy: 0.7113
# Epoch 6/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5904 - accuracy: 0.6927 - val_loss: 0.5842 - val_accuracy: 0.7197
# Epoch 7/50
# 35/35 [==============================] - 5s 129ms/step - loss: 0.5694 - accuracy: 0.7007 - val_loss: 0.5803 - val_accuracy: 0.7155
# Epoch 8/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6002 - accuracy: 0.6927 - val_loss: 0.5859 - val_accuracy: 0.7197
# Epoch 9/50
# 35/35 [==============================] - 4s 129ms/step - loss: 0.5693 - accuracy: 0.7061 - val_loss: 0.6608 - val_accuracy: 0.5439
# Epoch 10/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5887 - accuracy: 0.6953 - val_loss: 0.6453 - val_accuracy: 0.5732
# Epoch 11/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5921 - accuracy: 0.6613 - val_loss: 0.6098 - val_accuracy: 0.6527
# Epoch 12/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5901 - accuracy: 0.6676 - val_loss: 0.5748 - val_accuracy: 0.6946
# Epoch 13/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5487 - accuracy: 0.7088 - val_loss: 0.5856 - val_accuracy: 0.6904
# Epoch 14/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5338 - accuracy: 0.7231 - val_loss: 0.5772 - val_accuracy: 0.7113
# Epoch 15/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5335 - accuracy: 0.7177 - val_loss: 0.5968 - val_accuracy: 0.6276
# Epoch 16/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5400 - accuracy: 0.7043 - val_loss: 0.5515 - val_accuracy: 0.7197
# Epoch 17/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5344 - accuracy: 0.7177 - val_loss: 0.5445 - val_accuracy: 0.7071
# Epoch 18/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5353 - accuracy: 0.7106 - val_loss: 0.5673 - val_accuracy: 0.7197
# Epoch 19/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5690 - accuracy: 0.6568 - val_loss: 0.6217 - val_accuracy: 0.6109
# Epoch 20/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6030 - accuracy: 0.6362 - val_loss: 0.5941 - val_accuracy: 0.7071
# Epoch 21/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6356 - accuracy: 0.6452 - val_loss: 0.6260 - val_accuracy: 0.6109
# Epoch 22/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6275 - accuracy: 0.6532 - val_loss: 0.6327 - val_accuracy: 0.7155
# Epoch 23/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6191 - accuracy: 0.6667 - val_loss: 0.5775 - val_accuracy: 0.7071
# Epoch 24/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6346 - accuracy: 0.6228 - val_loss: 0.6070 - val_accuracy: 0.7238
# Epoch 25/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5948 - accuracy: 0.6676 - val_loss: 0.5632 - val_accuracy: 0.7280
# Epoch 26/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5976 - accuracy: 0.6640 - val_loss: 0.6108 - val_accuracy: 0.6276
# Epoch 27/50
# 35/35 [==============================] - 5s 129ms/step - loss: 0.6211 - accuracy: 0.6416 - val_loss: 0.5707 - val_accuracy: 0.7155
# Epoch 28/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6194 - accuracy: 0.6299 - val_loss: 0.6467 - val_accuracy: 0.6820
# Epoch 29/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6261 - accuracy: 0.6550 - val_loss: 0.6045 - val_accuracy: 0.6987
# Epoch 30/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6149 - accuracy: 0.6756 - val_loss: 0.5667 - val_accuracy: 0.7197
# Epoch 31/50
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5874 - accuracy: 0.6962 - val_loss: 0.5648 - val_accuracy: 0.7197
# Epoch 32/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5925 - accuracy: 0.6891 - val_loss: 0.5755 - val_accuracy: 0.7197
# Epoch 33/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6012 - accuracy: 0.6855 - val_loss: 0.6303 - val_accuracy: 0.6109
# Epoch 34/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5910 - accuracy: 0.6631 - val_loss: 0.6154 - val_accuracy: 0.6025
# Epoch 35/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6105 - accuracy: 0.6640 - val_loss: 0.5952 - val_accuracy: 0.7197
# Epoch 36/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6272 - accuracy: 0.6514 - val_loss: 0.6330 - val_accuracy: 0.6611
# Epoch 37/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6313 - accuracy: 0.6523 - val_loss: 0.5907 - val_accuracy: 0.7029
# Epoch 38/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6021 - accuracy: 0.6837 - val_loss: 0.5934 - val_accuracy: 0.7197
# Epoch 39/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5849 - accuracy: 0.7007 - val_loss: 0.6009 - val_accuracy: 0.7238
# Epoch 40/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5873 - accuracy: 0.7061 - val_loss: 0.5770 - val_accuracy: 0.7113
# Epoch 41/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5750 - accuracy: 0.7097 - val_loss: 0.5727 - val_accuracy: 0.7071
# Epoch 42/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5834 - accuracy: 0.7034 - val_loss: 0.5974 - val_accuracy: 0.6527
# Epoch 43/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5955 - accuracy: 0.6837 - val_loss: 0.5919 - val_accuracy: 0.6904
# Epoch 44/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5775 - accuracy: 0.6998 - val_loss: 0.5841 - val_accuracy: 0.6946
# Epoch 45/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5599 - accuracy: 0.7285 - val_loss: 0.5737 - val_accuracy: 0.7197
# Epoch 46/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5733 - accuracy: 0.7186 - val_loss: 0.5697 - val_accuracy: 0.7364
# Epoch 47/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5534 - accuracy: 0.7294 - val_loss: 0.5628 - val_accuracy: 0.7238
# Epoch 48/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5529 - accuracy: 0.7339 - val_loss: 0.5756 - val_accuracy: 0.7071
# Epoch 49/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5654 - accuracy: 0.7151 - val_loss: 0.5739 - val_accuracy: 0.7113
# Epoch 50/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5583 - accuracy: 0.7240 - val_loss: 0.5691 - val_accuracy: 0.7280

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 123ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.55      0.70       110
#            1       0.72      0.98      0.83       131
#
#     accuracy                           0.78       241
#    macro avg       0.84      0.77      0.76       241
# weighted avg       0.83      0.78      0.77       241

# %%
model_saved = r'D:\My Code\Classification\models'
model.save(os.path.join(model_saved, f'{dataset_code}_{model_name} (256X256).h5'))
