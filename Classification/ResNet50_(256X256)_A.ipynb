# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import ResNet50
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'A'
model_name = 'RestNet50'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'A_validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
ResNet50_model = ResNet50(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(ResNet50_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 292,027,265
# Trainable params: 268,439,553
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs = 50, batch_size = 32, validation_data = (val_images, val_labels))
# Out:
# Epoch 1/50
# 35/35 [==============================] - 12s 191ms/step - loss: 16.2220 - accuracy: 0.5215 - val_loss: 5.1016 - val_accuracy: 0.4561
# Epoch 2/50
# 35/35 [==============================] - 5s 130ms/step - loss: 2.4991 - accuracy: 0.5627 - val_loss: 0.7842 - val_accuracy: 0.6653
# Epoch 3/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6533 - accuracy: 0.6738 - val_loss: 0.6271 - val_accuracy: 0.5900
# Epoch 4/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6067 - accuracy: 0.6720 - val_loss: 0.5828 - val_accuracy: 0.6862
# Epoch 5/50
# 35/35 [==============================] - 5s 132ms/step - loss: 0.5671 - accuracy: 0.6944 - val_loss: 0.5798 - val_accuracy: 0.7113
# Epoch 6/50
# 35/35 [==============================] - 4s 129ms/step - loss: 0.5719 - accuracy: 0.6909 - val_loss: 0.5729 - val_accuracy: 0.7197
# Epoch 7/50
# 35/35 [==============================] - 5s 132ms/step - loss: 0.5464 - accuracy: 0.7339 - val_loss: 0.5658 - val_accuracy: 0.7071
# Epoch 8/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5552 - accuracy: 0.7222 - val_loss: 0.5858 - val_accuracy: 0.7071
# Epoch 9/50
# 35/35 [==============================] - 5s 132ms/step - loss: 0.5997 - accuracy: 0.6819 - val_loss: 0.5882 - val_accuracy: 0.7197
# Epoch 10/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5915 - accuracy: 0.6918 - val_loss: 0.5847 - val_accuracy: 0.6736
# Epoch 11/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5836 - accuracy: 0.6792 - val_loss: 0.5956 - val_accuracy: 0.6904
# Epoch 12/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5617 - accuracy: 0.7043 - val_loss: 0.5861 - val_accuracy: 0.7238
# Epoch 13/50
# 35/35 [==============================] - 5s 132ms/step - loss: 0.5865 - accuracy: 0.6900 - val_loss: 0.6027 - val_accuracy: 0.6653
# Epoch 14/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5953 - accuracy: 0.6774 - val_loss: 0.5797 - val_accuracy: 0.7155
# Epoch 15/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5994 - accuracy: 0.6470 - val_loss: 0.6040 - val_accuracy: 0.7113
# Epoch 16/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6269 - accuracy: 0.6165 - val_loss: 0.6110 - val_accuracy: 0.6444
# Epoch 17/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6358 - accuracy: 0.6254 - val_loss: 0.6391 - val_accuracy: 0.6946
# Epoch 18/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6255 - accuracy: 0.6694 - val_loss: 0.5903 - val_accuracy: 0.7197
# Epoch 19/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6005 - accuracy: 0.6514 - val_loss: 0.6264 - val_accuracy: 0.7155
# Epoch 20/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6457 - accuracy: 0.6344 - val_loss: 0.6291 - val_accuracy: 0.6695
# Epoch 21/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6314 - accuracy: 0.6550 - val_loss: 0.6207 - val_accuracy: 0.6862
# Epoch 22/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6397 - accuracy: 0.6461 - val_loss: 0.6147 - val_accuracy: 0.6820
# Epoch 23/50
# 35/35 [==============================] - 5s 129ms/step - loss: 0.6324 - accuracy: 0.6550 - val_loss: 0.7174 - val_accuracy: 0.5230
# Epoch 24/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6814 - accuracy: 0.5717 - val_loss: 0.6715 - val_accuracy: 0.6276
# Epoch 25/50
# 35/35 [==============================] - 4s 129ms/step - loss: 0.6798 - accuracy: 0.5582 - val_loss: 0.6778 - val_accuracy: 0.5816
# Epoch 26/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6755 - accuracy: 0.5753 - val_loss: 0.6782 - val_accuracy: 0.5690
# Epoch 27/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6667 - accuracy: 0.6120 - val_loss: 0.6739 - val_accuracy: 0.4937
# Epoch 28/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6496 - accuracy: 0.6219 - val_loss: 0.6393 - val_accuracy: 0.7280
# Epoch 29/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6578 - accuracy: 0.6102 - val_loss: 0.6232 - val_accuracy: 0.7071
# Epoch 30/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6407 - accuracy: 0.6353 - val_loss: 0.6430 - val_accuracy: 0.6987
# Epoch 31/50
# 35/35 [==============================] - 5s 132ms/step - loss: 0.6228 - accuracy: 0.6613 - val_loss: 0.6539 - val_accuracy: 0.6527
# Epoch 32/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6289 - accuracy: 0.6532 - val_loss: 0.6041 - val_accuracy: 0.7322
# Epoch 33/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6171 - accuracy: 0.6658 - val_loss: 0.6040 - val_accuracy: 0.7197
# Epoch 34/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6291 - accuracy: 0.6389 - val_loss: 0.6117 - val_accuracy: 0.6946
# Epoch 35/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6162 - accuracy: 0.6505 - val_loss: 0.6021 - val_accuracy: 0.7322
# Epoch 36/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6080 - accuracy: 0.6685 - val_loss: 0.6037 - val_accuracy: 0.6527
# Epoch 37/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6111 - accuracy: 0.6577 - val_loss: 0.5976 - val_accuracy: 0.7071
# Epoch 38/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5958 - accuracy: 0.6792 - val_loss: 0.5920 - val_accuracy: 0.6946
# Epoch 39/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6184 - accuracy: 0.6532 - val_loss: 0.5949 - val_accuracy: 0.7155
# Epoch 40/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6302 - accuracy: 0.6505 - val_loss: 0.6001 - val_accuracy: 0.7197
# Epoch 41/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6123 - accuracy: 0.6586 - val_loss: 0.5889 - val_accuracy: 0.7071
# Epoch 42/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6259 - accuracy: 0.6452 - val_loss: 0.5889 - val_accuracy: 0.6987
# Epoch 43/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6025 - accuracy: 0.6694 - val_loss: 0.5991 - val_accuracy: 0.7238
# Epoch 44/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5974 - accuracy: 0.6774 - val_loss: 0.5855 - val_accuracy: 0.7113
# Epoch 45/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6037 - accuracy: 0.6658 - val_loss: 0.5944 - val_accuracy: 0.7238
# Epoch 46/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.5939 - accuracy: 0.6756 - val_loss: 0.5819 - val_accuracy: 0.7071
# Epoch 47/50
# 35/35 [==============================] - 4s 129ms/step - loss: 0.5763 - accuracy: 0.6971 - val_loss: 0.6040 - val_accuracy: 0.6736
# Epoch 48/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.6159 - accuracy: 0.6505 - val_loss: 0.5916 - val_accuracy: 0.7238
# Epoch 49/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.6130 - accuracy: 0.6541 - val_loss: 0.5857 - val_accuracy: 0.7029
# Epoch 50/50
# 35/35 [==============================] - 4s 128ms/step - loss: 0.6091 - accuracy: 0.6711 - val_loss: 0.6009 - val_accuracy: 0.6736

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'A_test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 149ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77       110
#            1       0.81      0.79      0.80       131
#
#     accuracy                           0.78       241
#    macro avg       0.78      0.78      0.78       241
# weighted avg       0.78      0.78      0.78       241
