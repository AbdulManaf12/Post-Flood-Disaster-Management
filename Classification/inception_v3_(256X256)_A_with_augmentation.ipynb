# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import InceptionV3
from tensorflow.keras.utils import Sequence
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'A_with_augmentation'
model_name = 'inception_v3'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'A_validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

batch_size = 16
train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)

# %%
IncV3 = InceptionV3(include_top = False, weights = "imagenet",input_shape = (256,256,3))

model = Sequential()
model.add(IncV3)
    
for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units = 2048, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(units = 1, activation = "sigmoid"))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 6, 6, 2048)        21802784
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 2048)              150996992
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 172,801,825
# Trainable params: 150,999,041
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator)
# Out:
# Epoch 1/50
# 279/279 [==============================] - 24s 65ms/step - loss: 7.2624 - accuracy: 0.8244 - val_loss: 0.6324 - val_accuracy: 0.9331
# Epoch 2/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.3430 - accuracy: 0.9382 - val_loss: 0.2307 - val_accuracy: 0.9414
# Epoch 3/50
# 279/279 [==============================] - 16s 57ms/step - loss: 0.1075 - accuracy: 0.9626 - val_loss: 0.3092 - val_accuracy: 0.9289
# Epoch 4/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0883 - accuracy: 0.9713 - val_loss: 0.3135 - val_accuracy: 0.9289
# Epoch 5/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.1096 - accuracy: 0.9637 - val_loss: 0.2676 - val_accuracy: 0.9205
# Epoch 6/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0960 - accuracy: 0.9698 - val_loss: 0.2907 - val_accuracy: 0.9331
# Epoch 7/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0992 - accuracy: 0.9664 - val_loss: 0.2717 - val_accuracy: 0.9456
# Epoch 8/50
# 279/279 [==============================] - 16s 58ms/step - loss: 0.0825 - accuracy: 0.9747 - val_loss: 0.5686 - val_accuracy: 0.8870
# Epoch 9/50
# 279/279 [==============================] - 16s 58ms/step - loss: 0.3096 - accuracy: 0.9478 - val_loss: 0.2298 - val_accuracy: 0.9289
# Epoch 10/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.2533 - accuracy: 0.9462 - val_loss: 0.3291 - val_accuracy: 0.9498
# Epoch 11/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.1012 - accuracy: 0.9709 - val_loss: 0.2476 - val_accuracy: 0.9456
# Epoch 12/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0883 - accuracy: 0.9736 - val_loss: 0.2837 - val_accuracy: 0.9247
# Epoch 13/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0912 - accuracy: 0.9765 - val_loss: 0.2809 - val_accuracy: 0.9414
# Epoch 14/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0950 - accuracy: 0.9718 - val_loss: 0.5638 - val_accuracy: 0.8828
# Epoch 15/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0704 - accuracy: 0.9807 - val_loss: 0.4005 - val_accuracy: 0.9289
# Epoch 16/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.2215 - accuracy: 0.9599 - val_loss: 0.9074 - val_accuracy: 0.8912
# Epoch 17/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.2223 - accuracy: 0.9532 - val_loss: 0.4024 - val_accuracy: 0.9079
# Epoch 18/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.1264 - accuracy: 0.9637 - val_loss: 0.2864 - val_accuracy: 0.9331
# Epoch 19/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0998 - accuracy: 0.9760 - val_loss: 0.4281 - val_accuracy: 0.9247
# Epoch 20/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0735 - accuracy: 0.9812 - val_loss: 0.3665 - val_accuracy: 0.9540
# Epoch 21/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0405 - accuracy: 0.9890 - val_loss: 0.4071 - val_accuracy: 0.9540
# Epoch 22/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.2804 - accuracy: 0.9603 - val_loss: 0.3122 - val_accuracy: 0.9372
# Epoch 23/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0915 - accuracy: 0.9747 - val_loss: 0.3292 - val_accuracy: 0.9414
# Epoch 24/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0554 - accuracy: 0.9852 - val_loss: 0.4622 - val_accuracy: 0.9331
# Epoch 25/50
# 279/279 [==============================] - 16s 57ms/step - loss: 0.0623 - accuracy: 0.9834 - val_loss: 0.5548 - val_accuracy: 0.9414
# Epoch 26/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.1346 - accuracy: 0.9749 - val_loss: 1.0275 - val_accuracy: 0.8954
# Epoch 27/50
# 279/279 [==============================] - 16s 57ms/step - loss: 0.0730 - accuracy: 0.9816 - val_loss: 0.5783 - val_accuracy: 0.9331
# Epoch 28/50
# 279/279 [==============================] - 16s 57ms/step - loss: 0.0683 - accuracy: 0.9836 - val_loss: 0.4279 - val_accuracy: 0.9289
# Epoch 29/50
# 279/279 [==============================] - 16s 57ms/step - loss: 0.1072 - accuracy: 0.9794 - val_loss: 0.5747 - val_accuracy: 0.9331
# Epoch 30/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0710 - accuracy: 0.9854 - val_loss: 0.8592 - val_accuracy: 0.9331
# Epoch 31/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.1891 - accuracy: 0.9707 - val_loss: 0.4767 - val_accuracy: 0.9456
# Epoch 32/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0511 - accuracy: 0.9841 - val_loss: 0.6041 - val_accuracy: 0.9372
# Epoch 33/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0896 - accuracy: 0.9798 - val_loss: 0.6771 - val_accuracy: 0.9414
# Epoch 34/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0898 - accuracy: 0.9823 - val_loss: 0.8835 - val_accuracy: 0.9079
# Epoch 35/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0922 - accuracy: 0.9789 - val_loss: 0.7844 - val_accuracy: 0.9372
# Epoch 36/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0540 - accuracy: 0.9875 - val_loss: 0.6809 - val_accuracy: 0.9247
# Epoch 37/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0551 - accuracy: 0.9888 - val_loss: 0.5600 - val_accuracy: 0.9331
# Epoch 38/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0772 - accuracy: 0.9852 - val_loss: 0.5929 - val_accuracy: 0.9289
# Epoch 39/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0331 - accuracy: 0.9922 - val_loss: 0.5410 - val_accuracy: 0.9372
# Epoch 40/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0390 - accuracy: 0.9897 - val_loss: 0.5564 - val_accuracy: 0.9414
# Epoch 41/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0521 - accuracy: 0.9888 - val_loss: 0.7258 - val_accuracy: 0.9331
# Epoch 42/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.1952 - accuracy: 0.9787 - val_loss: 1.1830 - val_accuracy: 0.9331
# Epoch 43/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0967 - accuracy: 0.9870 - val_loss: 0.8615 - val_accuracy: 0.9498
# Epoch 44/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0477 - accuracy: 0.9904 - val_loss: 1.1194 - val_accuracy: 0.9414
# Epoch 45/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0510 - accuracy: 0.9895 - val_loss: 0.8188 - val_accuracy: 0.9372
# Epoch 46/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0303 - accuracy: 0.9928 - val_loss: 0.6375 - val_accuracy: 0.9414
# Epoch 47/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0440 - accuracy: 0.9906 - val_loss: 0.5584 - val_accuracy: 0.9456
# Epoch 48/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0637 - accuracy: 0.9884 - val_loss: 0.8249 - val_accuracy: 0.9372
# Epoch 49/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.1261 - accuracy: 0.9830 - val_loss: 0.8847 - val_accuracy: 0.9205
# Epoch 50/50
# 279/279 [==============================] - 16s 56ms/step - loss: 0.0761 - accuracy: 0.9872 - val_loss: 0.6462 - val_accuracy: 0.9498

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.3, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'A_test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 3s 162ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       110
#            1       0.90      0.97      0.93       131
#
#     accuracy                           0.93       241
#    macro avg       0.93      0.92      0.92       241
# weighted avg       0.93      0.93      0.92       241
