# %%
import os
import pickle
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import InceptionV3
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

def save_pickle(data, file_path):
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)
        
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_val_data_path = os.path.join(data_saved_dir, 'A_preprocessed_data(224, 224).pkl')
train_images, train_labels, val_images, val_labels = load_pickle(train_val_data_path)

# %%
IncV3 = InceptionV3(include_top = False, weights = "imagenet",input_shape = (224,224,3))

model = Sequential()
model.add(IncV3)
    
for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units = 2048, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(units = 1, activation = "sigmoid"))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 2048)              104859648
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 126,664,481
# Trainable params: 104,861,697
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs = 50, batch_size = 32, validation_data = (val_images, val_labels))
# Out:
# Epoch 1/50
# 36/36 [==============================] - 11s 134ms/step - loss: 20.3714 - accuracy: 0.7361 - val_loss: 3.4774 - val_accuracy: 0.9020
# Epoch 2/50
# 36/36 [==============================] - 2s 67ms/step - loss: 1.8922 - accuracy: 0.9262 - val_loss: 3.0508 - val_accuracy: 0.9069
# Epoch 3/50
# 36/36 [==============================] - 2s 68ms/step - loss: 1.3888 - accuracy: 0.9427 - val_loss: 4.1165 - val_accuracy: 0.8873
# Epoch 4/50
# 36/36 [==============================] - 2s 67ms/step - loss: 1.0852 - accuracy: 0.9427 - val_loss: 3.2044 - val_accuracy: 0.8971
# Epoch 5/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.9396 - accuracy: 0.9540 - val_loss: 3.1390 - val_accuracy: 0.9265
# Epoch 6/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.3305 - accuracy: 0.9818 - val_loss: 2.9012 - val_accuracy: 0.9118
# Epoch 7/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.1211 - accuracy: 0.9887 - val_loss: 2.8292 - val_accuracy: 0.9069
# Epoch 8/50
# 36/36 [==============================] - 2s 66ms/step - loss: 0.2070 - accuracy: 0.9826 - val_loss: 3.0021 - val_accuracy: 0.8971
# Epoch 9/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.0951 - accuracy: 0.9905 - val_loss: 2.5499 - val_accuracy: 0.9069
# Epoch 10/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.1345 - accuracy: 0.9878 - val_loss: 2.4691 - val_accuracy: 0.9167
# Epoch 11/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.0582 - accuracy: 0.9931 - val_loss: 3.1313 - val_accuracy: 0.8873
# Epoch 12/50
# 36/36 [==============================] - 2s 66ms/step - loss: 0.1417 - accuracy: 0.9913 - val_loss: 2.9677 - val_accuracy: 0.9020
# Epoch 13/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.1704 - accuracy: 0.9870 - val_loss: 3.4135 - val_accuracy: 0.8775
# Epoch 14/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.0661 - accuracy: 0.9905 - val_loss: 2.9615 - val_accuracy: 0.9167
# Epoch 15/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.1294 - accuracy: 0.9913 - val_loss: 2.8908 - val_accuracy: 0.8971
# Epoch 16/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.0910 - accuracy: 0.9913 - val_loss: 3.0375 - val_accuracy: 0.9020
# Epoch 17/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.0756 - accuracy: 0.9948 - val_loss: 3.2350 - val_accuracy: 0.9069
# Epoch 18/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.0374 - accuracy: 0.9948 - val_loss: 2.8997 - val_accuracy: 0.9167
# Epoch 19/50
# 36/36 [==============================] - 2s 66ms/step - loss: 0.2211 - accuracy: 0.9870 - val_loss: 2.9634 - val_accuracy: 0.9167
# Epoch 20/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.1095 - accuracy: 0.9939 - val_loss: 3.2762 - val_accuracy: 0.9118
# Epoch 21/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.1661 - accuracy: 0.9896 - val_loss: 2.9393 - val_accuracy: 0.9118
# Epoch 22/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.3397 - accuracy: 0.9740 - val_loss: 5.4134 - val_accuracy: 0.8578
# Epoch 23/50
# 36/36 [==============================] - 2s 66ms/step - loss: 0.2202 - accuracy: 0.9809 - val_loss: 5.8142 - val_accuracy: 0.8725
# Epoch 24/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.3504 - accuracy: 0.9809 - val_loss: 6.6516 - val_accuracy: 0.8725
# Epoch 25/50
# 36/36 [==============================] - 2s 65ms/step - loss: 0.2556 - accuracy: 0.9835 - val_loss: 3.6734 - val_accuracy: 0.9265
# Epoch 26/50
# 36/36 [==============================] - 2s 65ms/step - loss: 0.2297 - accuracy: 0.9870 - val_loss: 4.5891 - val_accuracy: 0.9216
# Epoch 27/50
# 36/36 [==============================] - 2s 66ms/step - loss: 1.0287 - accuracy: 0.9670 - val_loss: 5.4858 - val_accuracy: 0.8971
# Epoch 28/50
# 36/36 [==============================] - 2s 66ms/step - loss: 0.1094 - accuracy: 0.9948 - val_loss: 4.9961 - val_accuracy: 0.9167
# Epoch 29/50
# 36/36 [==============================] - 2s 66ms/step - loss: 0.1662 - accuracy: 0.9939 - val_loss: 6.0795 - val_accuracy: 0.8824
# Epoch 30/50
# 36/36 [==============================] - 2s 65ms/step - loss: 0.1174 - accuracy: 0.9913 - val_loss: 4.6716 - val_accuracy: 0.9167
# Epoch 31/50
# 36/36 [==============================] - 2s 65ms/step - loss: 0.2133 - accuracy: 0.9878 - val_loss: 4.8202 - val_accuracy: 0.9265
# Epoch 32/50
# 36/36 [==============================] - 2s 66ms/step - loss: 0.0472 - accuracy: 0.9948 - val_loss: 4.6872 - val_accuracy: 0.9167
# Epoch 33/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.1460 - accuracy: 0.9905 - val_loss: 4.3627 - val_accuracy: 0.9265
# Epoch 34/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.1247 - accuracy: 0.9922 - val_loss: 4.2949 - val_accuracy: 0.9118
# Epoch 35/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.0876 - accuracy: 0.9957 - val_loss: 4.8563 - val_accuracy: 0.9118
# Epoch 36/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.5081 - accuracy: 0.9800 - val_loss: 4.8997 - val_accuracy: 0.9216
# Epoch 37/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.0619 - accuracy: 0.9965 - val_loss: 5.3144 - val_accuracy: 0.8971
# Epoch 38/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.1824 - accuracy: 0.9931 - val_loss: 5.1897 - val_accuracy: 0.9069
# Epoch 39/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.0744 - accuracy: 0.9983 - val_loss: 3.8232 - val_accuracy: 0.9363
# Epoch 40/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.0450 - accuracy: 0.9957 - val_loss: 4.4577 - val_accuracy: 0.9363
# Epoch 41/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.0912 - accuracy: 0.9957 - val_loss: 7.3672 - val_accuracy: 0.8922
# Epoch 42/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.1446 - accuracy: 0.9931 - val_loss: 5.3722 - val_accuracy: 0.9167
# Epoch 43/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.0310 - accuracy: 0.9974 - val_loss: 4.6471 - val_accuracy: 0.9216
# Epoch 44/50
# 36/36 [==============================] - 2s 69ms/step - loss: 0.1496 - accuracy: 0.9957 - val_loss: 4.8208 - val_accuracy: 0.9314
# Epoch 45/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.0929 - accuracy: 0.9948 - val_loss: 5.1815 - val_accuracy: 0.8971
# Epoch 46/50
# 36/36 [==============================] - 2s 69ms/step - loss: 0.0975 - accuracy: 0.9965 - val_loss: 7.2630 - val_accuracy: 0.8725
# Epoch 47/50
# 36/36 [==============================] - 2s 66ms/step - loss: 0.0259 - accuracy: 0.9983 - val_loss: 8.0502 - val_accuracy: 0.8676
# Epoch 48/50
# 36/36 [==============================] - 2s 66ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 4.9118 - val_accuracy: 0.9216
# Epoch 49/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.0708 - accuracy: 0.9939 - val_loss: 8.9044 - val_accuracy: 0.8676
# Epoch 50/50
# 36/36 [==============================] - 2s 67ms/step - loss: 0.2239 - accuracy: 0.9913 - val_loss: 5.6519 - val_accuracy: 0.9216

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'A_preprocessed_data test_images(224, 224).pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 169ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.90       131
#            1       0.86      0.94      0.89       109
#
#     accuracy                           0.90       240
#    macro avg       0.90      0.90      0.90       240
# weighted avg       0.90      0.90      0.90       240

# %%
model_saved = r'D:\My Code\Classification\models'
save_pickle(model, os.path.join(model_saved, 'A_InceptionV3 (244x224).pkl'))
