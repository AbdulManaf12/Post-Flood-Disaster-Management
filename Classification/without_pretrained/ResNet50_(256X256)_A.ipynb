# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import ResNet50
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'A'
model_name = 'RestNet50'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
ResNet50_model = ResNet50(include_top=False, weights=None, input_shape=(256, 256, 3))

model = Sequential()
model.add(ResNet50_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 292,027,265
# Trainable params: 268,439,553
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs = 100, batch_size = 32, validation_data = (val_images, val_labels))
# Out:
# Epoch 1/100
# 35/35 [==============================] - 12s 190ms/step - loss: 2.9577 - accuracy: 0.5116 - val_loss: 0.9288 - val_accuracy: 0.4854
# Epoch 2/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.9397 - accuracy: 0.5663 - val_loss: 0.5961 - val_accuracy: 0.6695
# Epoch 3/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.6718 - accuracy: 0.6156 - val_loss: 0.6512 - val_accuracy: 0.6151
# Epoch 4/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.6594 - accuracy: 0.6075 - val_loss: 0.6176 - val_accuracy: 0.5858
# Epoch 5/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.6188 - accuracy: 0.6559 - val_loss: 0.6391 - val_accuracy: 0.6485
# Epoch 6/100
# 35/35 [==============================] - 4s 126ms/step - loss: 0.6453 - accuracy: 0.6344 - val_loss: 0.6081 - val_accuracy: 0.6695
# Epoch 7/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.6359 - accuracy: 0.6434 - val_loss: 0.6125 - val_accuracy: 0.6778
# Epoch 8/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.6238 - accuracy: 0.6747 - val_loss: 0.5948 - val_accuracy: 0.6527
# Epoch 9/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.6084 - accuracy: 0.6783 - val_loss: 0.6080 - val_accuracy: 0.6736
# Epoch 10/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.6104 - accuracy: 0.6694 - val_loss: 0.5982 - val_accuracy: 0.6527
# Epoch 11/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.5900 - accuracy: 0.6801 - val_loss: 0.5780 - val_accuracy: 0.6820
# Epoch 12/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.5780 - accuracy: 0.7043 - val_loss: 0.5613 - val_accuracy: 0.6736
# Epoch 13/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.5810 - accuracy: 0.7159 - val_loss: 0.5987 - val_accuracy: 0.6820
# Epoch 14/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5721 - accuracy: 0.7016 - val_loss: 0.5805 - val_accuracy: 0.6820
# Epoch 15/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.5965 - accuracy: 0.6729 - val_loss: 0.5713 - val_accuracy: 0.7406
# Epoch 16/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.5761 - accuracy: 0.7025 - val_loss: 0.5694 - val_accuracy: 0.7322
# Epoch 17/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5705 - accuracy: 0.7195 - val_loss: 0.5877 - val_accuracy: 0.6653
# Epoch 18/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.5669 - accuracy: 0.7204 - val_loss: 0.5726 - val_accuracy: 0.6820
# Epoch 19/100
# 35/35 [==============================] - 4s 126ms/step - loss: 0.5440 - accuracy: 0.7348 - val_loss: 0.5236 - val_accuracy: 0.7113
# Epoch 20/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.5230 - accuracy: 0.7518 - val_loss: 0.5323 - val_accuracy: 0.6946
# Epoch 21/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.5492 - accuracy: 0.7079 - val_loss: 0.5242 - val_accuracy: 0.7699
# Epoch 22/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5350 - accuracy: 0.7168 - val_loss: 0.6539 - val_accuracy: 0.6151
# Epoch 23/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5705 - accuracy: 0.6900 - val_loss: 0.5513 - val_accuracy: 0.6862
# Epoch 24/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.5211 - accuracy: 0.7446 - val_loss: 0.5118 - val_accuracy: 0.7573
# Epoch 25/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.5162 - accuracy: 0.7384 - val_loss: 0.5072 - val_accuracy: 0.7280
# Epoch 26/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5132 - accuracy: 0.7536 - val_loss: 0.5041 - val_accuracy: 0.6987
# Epoch 27/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4973 - accuracy: 0.7464 - val_loss: 0.5516 - val_accuracy: 0.7364
# Epoch 28/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.5164 - accuracy: 0.7545 - val_loss: 0.5256 - val_accuracy: 0.7741
# Epoch 29/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.5425 - accuracy: 0.6864 - val_loss: 0.5944 - val_accuracy: 0.7322
# Epoch 30/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5444 - accuracy: 0.6720 - val_loss: 0.5093 - val_accuracy: 0.7364
# Epoch 31/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5604 - accuracy: 0.6694 - val_loss: 0.4949 - val_accuracy: 0.7280
# Epoch 32/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5220 - accuracy: 0.6909 - val_loss: 0.5248 - val_accuracy: 0.7615
# Epoch 33/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.5479 - accuracy: 0.6783 - val_loss: 0.5440 - val_accuracy: 0.7113
# Epoch 34/100
# 35/35 [==============================] - 4s 126ms/step - loss: 0.5116 - accuracy: 0.7133 - val_loss: 0.5333 - val_accuracy: 0.7490
# Epoch 35/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.5318 - accuracy: 0.6362 - val_loss: 0.5485 - val_accuracy: 0.7824
# Epoch 36/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.5124 - accuracy: 0.7204 - val_loss: 0.4744 - val_accuracy: 0.7699
# Epoch 37/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4517 - accuracy: 0.7509 - val_loss: 0.4733 - val_accuracy: 0.7741
# Epoch 38/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4620 - accuracy: 0.7697 - val_loss: 0.4620 - val_accuracy: 0.7699
# Epoch 39/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4688 - accuracy: 0.7688 - val_loss: 0.4933 - val_accuracy: 0.7782
# Epoch 40/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4624 - accuracy: 0.7625 - val_loss: 0.5025 - val_accuracy: 0.7238
# Epoch 41/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4579 - accuracy: 0.7590 - val_loss: 0.4589 - val_accuracy: 0.7573
# Epoch 42/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4427 - accuracy: 0.7599 - val_loss: 0.4620 - val_accuracy: 0.7573
# Epoch 43/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4562 - accuracy: 0.7634 - val_loss: 0.4487 - val_accuracy: 0.7866
# Epoch 44/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4762 - accuracy: 0.7590 - val_loss: 0.4993 - val_accuracy: 0.7950
# Epoch 45/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.4994 - accuracy: 0.7437 - val_loss: 0.5545 - val_accuracy: 0.7699
# Epoch 46/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.5202 - accuracy: 0.7115 - val_loss: 0.4951 - val_accuracy: 0.7490
# Epoch 47/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4715 - accuracy: 0.7599 - val_loss: 0.5172 - val_accuracy: 0.7155
# Epoch 48/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4767 - accuracy: 0.7464 - val_loss: 0.4728 - val_accuracy: 0.7615
# Epoch 49/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.4448 - accuracy: 0.8002 - val_loss: 0.4913 - val_accuracy: 0.7824
# Epoch 50/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.4452 - accuracy: 0.7805 - val_loss: 0.4711 - val_accuracy: 0.7741
# Epoch 51/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4648 - accuracy: 0.7778 - val_loss: 0.4994 - val_accuracy: 0.7657
# Epoch 52/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4610 - accuracy: 0.7894 - val_loss: 0.4765 - val_accuracy: 0.7950
# Epoch 53/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4533 - accuracy: 0.7608 - val_loss: 0.4666 - val_accuracy: 0.7908
# Epoch 54/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4379 - accuracy: 0.7885 - val_loss: 0.4716 - val_accuracy: 0.8033
# Epoch 55/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4509 - accuracy: 0.7670 - val_loss: 0.4529 - val_accuracy: 0.7699
# Epoch 56/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4556 - accuracy: 0.7652 - val_loss: 0.4673 - val_accuracy: 0.7908
# Epoch 57/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4096 - accuracy: 0.8011 - val_loss: 0.4481 - val_accuracy: 0.7782
# Epoch 58/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.4510 - accuracy: 0.7805 - val_loss: 0.4621 - val_accuracy: 0.7866
# Epoch 59/100
# 35/35 [==============================] - 5s 136ms/step - loss: 0.4042 - accuracy: 0.8118 - val_loss: 0.4585 - val_accuracy: 0.8033
# Epoch 60/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4119 - accuracy: 0.7993 - val_loss: 0.4524 - val_accuracy: 0.7908
# Epoch 61/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.4422 - accuracy: 0.7661 - val_loss: 0.4810 - val_accuracy: 0.8033
# Epoch 62/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.5039 - accuracy: 0.7016 - val_loss: 0.4592 - val_accuracy: 0.7741
# Epoch 63/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.4891 - accuracy: 0.7079 - val_loss: 0.4525 - val_accuracy: 0.7950
# Epoch 64/100
# 35/35 [==============================] - 5s 135ms/step - loss: 0.4611 - accuracy: 0.7249 - val_loss: 0.5013 - val_accuracy: 0.7615
# Epoch 65/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.4636 - accuracy: 0.7285 - val_loss: 0.4834 - val_accuracy: 0.7615
# Epoch 66/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.4705 - accuracy: 0.7142 - val_loss: 0.4508 - val_accuracy: 0.7950
# Epoch 67/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4579 - accuracy: 0.7258 - val_loss: 0.5379 - val_accuracy: 0.7071
# Epoch 68/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.4873 - accuracy: 0.7052 - val_loss: 0.4867 - val_accuracy: 0.7824
# Epoch 69/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.4506 - accuracy: 0.7294 - val_loss: 0.4557 - val_accuracy: 0.7950
# Epoch 70/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.4969 - accuracy: 0.6882 - val_loss: 0.5396 - val_accuracy: 0.6904
# Epoch 71/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4755 - accuracy: 0.6837 - val_loss: 0.4804 - val_accuracy: 0.7782
# Epoch 72/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4453 - accuracy: 0.7303 - val_loss: 0.4497 - val_accuracy: 0.7741
# Epoch 73/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4505 - accuracy: 0.7392 - val_loss: 0.4533 - val_accuracy: 0.8033
# Epoch 74/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4485 - accuracy: 0.7339 - val_loss: 0.4365 - val_accuracy: 0.7992
# Epoch 75/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4503 - accuracy: 0.7186 - val_loss: 0.4677 - val_accuracy: 0.7908
# Epoch 76/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4572 - accuracy: 0.7240 - val_loss: 0.5107 - val_accuracy: 0.7657
# Epoch 77/100
# 35/35 [==============================] - 4s 126ms/step - loss: 0.4460 - accuracy: 0.7366 - val_loss: 0.4383 - val_accuracy: 0.8075
# Epoch 78/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.4214 - accuracy: 0.7312 - val_loss: 0.4411 - val_accuracy: 0.7992
# Epoch 79/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4527 - accuracy: 0.7222 - val_loss: 0.4569 - val_accuracy: 0.7699
# Epoch 80/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.4601 - accuracy: 0.7106 - val_loss: 0.4787 - val_accuracy: 0.7573
# Epoch 81/100
# 35/35 [==============================] - 4s 126ms/step - loss: 0.4722 - accuracy: 0.6962 - val_loss: 0.4826 - val_accuracy: 0.7490
# Epoch 82/100
# 35/35 [==============================] - 4s 126ms/step - loss: 0.4375 - accuracy: 0.7249 - val_loss: 0.5186 - val_accuracy: 0.6904
# Epoch 83/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4512 - accuracy: 0.7159 - val_loss: 0.4498 - val_accuracy: 0.7782
# Epoch 84/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.4461 - accuracy: 0.7240 - val_loss: 0.4487 - val_accuracy: 0.7992
# Epoch 85/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4453 - accuracy: 0.7124 - val_loss: 0.4470 - val_accuracy: 0.7824
# Epoch 86/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.4134 - accuracy: 0.7428 - val_loss: 0.4349 - val_accuracy: 0.8033
# Epoch 87/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4406 - accuracy: 0.7213 - val_loss: 0.4672 - val_accuracy: 0.7782
# Epoch 88/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4882 - accuracy: 0.7088 - val_loss: 0.5718 - val_accuracy: 0.7866
# Epoch 89/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.4729 - accuracy: 0.7213 - val_loss: 0.4464 - val_accuracy: 0.7950
# Epoch 90/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.3986 - accuracy: 0.7419 - val_loss: 0.4279 - val_accuracy: 0.8117
# Epoch 91/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4119 - accuracy: 0.7348 - val_loss: 0.5185 - val_accuracy: 0.7531
# Epoch 92/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.4338 - accuracy: 0.7159 - val_loss: 0.4248 - val_accuracy: 0.8075
# Epoch 93/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4106 - accuracy: 0.7410 - val_loss: 0.4114 - val_accuracy: 0.8201
# Epoch 94/100
# 35/35 [==============================] - 4s 129ms/step - loss: 0.4074 - accuracy: 0.7357 - val_loss: 0.4475 - val_accuracy: 0.7908
# Epoch 95/100
# 35/35 [==============================] - 4s 127ms/step - loss: 0.4164 - accuracy: 0.7312 - val_loss: 0.4770 - val_accuracy: 0.7238
# Epoch 96/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4127 - accuracy: 0.7473 - val_loss: 0.4214 - val_accuracy: 0.7992
# Epoch 97/100
# 35/35 [==============================] - 5s 129ms/step - loss: 0.4246 - accuracy: 0.7321 - val_loss: 0.4358 - val_accuracy: 0.7908
# Epoch 98/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.3944 - accuracy: 0.7634 - val_loss: 0.4469 - val_accuracy: 0.7782
# Epoch 99/100
# 35/35 [==============================] - 4s 128ms/step - loss: 0.4064 - accuracy: 0.7410 - val_loss: 0.5165 - val_accuracy: 0.7782
# Epoch 100/100
# 35/35 [==============================] - 5s 130ms/step - loss: 0.4627 - accuracy: 0.7097 - val_loss: 0.4789 - val_accuracy: 0.7866

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 128ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.86      0.78       110
#            1       0.86      0.70      0.77       131
#
#     accuracy                           0.78       241
#    macro avg       0.78      0.78      0.78       241
# weighted avg       0.79      0.78      0.78       241
