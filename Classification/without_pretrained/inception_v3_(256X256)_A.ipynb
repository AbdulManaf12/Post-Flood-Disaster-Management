# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import InceptionV3
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'A'
model_name = 'inception_v3'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
IncV3 = InceptionV3(include_top = False, weights = None,input_shape = (256,256,3))

model = Sequential()
model.add(IncV3)
    
for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units = 2048, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(units = 1, activation = "sigmoid"))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 6, 6, 2048)        21802784
#
#  flatten_1 (Flatten)         (None, 73728)             0
#
#  dense_2 (Dense)             (None, 2048)              150996992
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 172,801,825
# Trainable params: 150,999,041
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs = 100, batch_size = 32, validation_data = (val_images, val_labels))
# Out:
# Epoch 1/100
# 35/35 [==============================] - 9s 140ms/step - loss: 0.6947 - accuracy: 0.5242 - val_loss: 0.6930 - val_accuracy: 0.4561
# Epoch 2/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.6883 - accuracy: 0.5448 - val_loss: 0.6836 - val_accuracy: 0.5439
# Epoch 3/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.6848 - accuracy: 0.5466 - val_loss: 0.6822 - val_accuracy: 0.5439
# Epoch 4/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.6826 - accuracy: 0.5448 - val_loss: 0.6786 - val_accuracy: 0.5439
# Epoch 5/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.6770 - accuracy: 0.5600 - val_loss: 0.6757 - val_accuracy: 0.5439
# Epoch 6/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.6756 - accuracy: 0.5573 - val_loss: 0.6703 - val_accuracy: 0.5774
# Epoch 7/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.6697 - accuracy: 0.5995 - val_loss: 0.6659 - val_accuracy: 0.5481
# Epoch 8/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.6665 - accuracy: 0.5932 - val_loss: 0.6586 - val_accuracy: 0.5816
# Epoch 9/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.6592 - accuracy: 0.6183 - val_loss: 0.6539 - val_accuracy: 0.6527
# Epoch 10/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.6534 - accuracy: 0.6317 - val_loss: 0.6432 - val_accuracy: 0.6653
# Epoch 11/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.6398 - accuracy: 0.6550 - val_loss: 0.6357 - val_accuracy: 0.6402
# Epoch 12/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.6346 - accuracy: 0.6640 - val_loss: 0.6307 - val_accuracy: 0.6402
# Epoch 13/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.6297 - accuracy: 0.6864 - val_loss: 0.6289 - val_accuracy: 0.6234
# Epoch 14/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.6231 - accuracy: 0.6640 - val_loss: 0.6230 - val_accuracy: 0.7029
# Epoch 15/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.6173 - accuracy: 0.6738 - val_loss: 0.6115 - val_accuracy: 0.6736
# Epoch 16/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.6070 - accuracy: 0.6971 - val_loss: 0.6071 - val_accuracy: 0.7071
# Epoch 17/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.6017 - accuracy: 0.7043 - val_loss: 0.5955 - val_accuracy: 0.6946
# Epoch 18/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.5901 - accuracy: 0.7106 - val_loss: 0.5917 - val_accuracy: 0.6736
# Epoch 19/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.5871 - accuracy: 0.7106 - val_loss: 0.6040 - val_accuracy: 0.6695
# Epoch 20/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.5857 - accuracy: 0.7195 - val_loss: 0.5822 - val_accuracy: 0.6904
# Epoch 21/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.5744 - accuracy: 0.7348 - val_loss: 0.5818 - val_accuracy: 0.6862
# Epoch 22/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.5720 - accuracy: 0.7177 - val_loss: 0.5729 - val_accuracy: 0.7155
# Epoch 23/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.5614 - accuracy: 0.7330 - val_loss: 0.5762 - val_accuracy: 0.7113
# Epoch 24/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.5549 - accuracy: 0.7357 - val_loss: 0.5803 - val_accuracy: 0.7155
# Epoch 25/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.5466 - accuracy: 0.7500 - val_loss: 0.5663 - val_accuracy: 0.7113
# Epoch 26/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.5362 - accuracy: 0.7554 - val_loss: 0.5611 - val_accuracy: 0.7238
# Epoch 27/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.5366 - accuracy: 0.7572 - val_loss: 0.5540 - val_accuracy: 0.7197
# Epoch 28/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.5450 - accuracy: 0.7321 - val_loss: 0.5530 - val_accuracy: 0.7406
# Epoch 29/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.5506 - accuracy: 0.7401 - val_loss: 0.5551 - val_accuracy: 0.7280
# Epoch 30/100
# 35/35 [==============================] - 3s 91ms/step - loss: 0.5330 - accuracy: 0.7715 - val_loss: 0.5467 - val_accuracy: 0.7322
# Epoch 31/100
# 35/35 [==============================] - 3s 91ms/step - loss: 0.5294 - accuracy: 0.7428 - val_loss: 0.5449 - val_accuracy: 0.7364
# Epoch 32/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.5264 - accuracy: 0.7661 - val_loss: 0.5423 - val_accuracy: 0.7364
# Epoch 33/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.5178 - accuracy: 0.7599 - val_loss: 0.5481 - val_accuracy: 0.7113
# Epoch 34/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.5083 - accuracy: 0.7832 - val_loss: 0.5378 - val_accuracy: 0.7406
# Epoch 35/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4990 - accuracy: 0.7814 - val_loss: 0.5368 - val_accuracy: 0.7364
# Epoch 36/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.5093 - accuracy: 0.7661 - val_loss: 0.5341 - val_accuracy: 0.7448
# Epoch 37/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4946 - accuracy: 0.7876 - val_loss: 0.5478 - val_accuracy: 0.7238
# Epoch 38/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.5080 - accuracy: 0.7625 - val_loss: 0.5357 - val_accuracy: 0.7406
# Epoch 39/100
# 35/35 [==============================] - 3s 85ms/step - loss: 0.5022 - accuracy: 0.7634 - val_loss: 0.5371 - val_accuracy: 0.7490
# Epoch 40/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.4899 - accuracy: 0.7858 - val_loss: 0.5258 - val_accuracy: 0.7448
# Epoch 41/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.4947 - accuracy: 0.7742 - val_loss: 0.5528 - val_accuracy: 0.7364
# Epoch 42/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.4936 - accuracy: 0.7733 - val_loss: 0.5546 - val_accuracy: 0.7406
# Epoch 43/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.4907 - accuracy: 0.7769 - val_loss: 0.5224 - val_accuracy: 0.7448
# Epoch 44/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.4805 - accuracy: 0.7984 - val_loss: 0.5255 - val_accuracy: 0.7364
# Epoch 45/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4846 - accuracy: 0.7957 - val_loss: 0.5241 - val_accuracy: 0.7448
# Epoch 46/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.4758 - accuracy: 0.7939 - val_loss: 0.5174 - val_accuracy: 0.7490
# Epoch 47/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4847 - accuracy: 0.7912 - val_loss: 0.5307 - val_accuracy: 0.7531
# Epoch 48/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4756 - accuracy: 0.7867 - val_loss: 0.5383 - val_accuracy: 0.7280
# Epoch 49/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4727 - accuracy: 0.7966 - val_loss: 0.5141 - val_accuracy: 0.7490
# Epoch 50/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4680 - accuracy: 0.8011 - val_loss: 0.5122 - val_accuracy: 0.7490
# Epoch 51/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.4584 - accuracy: 0.8020 - val_loss: 0.5123 - val_accuracy: 0.7448
# Epoch 52/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.4813 - accuracy: 0.7769 - val_loss: 0.5113 - val_accuracy: 0.7448
# Epoch 53/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.4684 - accuracy: 0.7948 - val_loss: 0.5177 - val_accuracy: 0.7490
# Epoch 54/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4653 - accuracy: 0.8002 - val_loss: 0.5093 - val_accuracy: 0.7490
# Epoch 55/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.4592 - accuracy: 0.8163 - val_loss: 0.5079 - val_accuracy: 0.7531
# Epoch 56/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.4601 - accuracy: 0.7948 - val_loss: 0.5065 - val_accuracy: 0.7531
# Epoch 57/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4556 - accuracy: 0.8082 - val_loss: 0.5164 - val_accuracy: 0.7280
# Epoch 58/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4554 - accuracy: 0.8127 - val_loss: 0.5090 - val_accuracy: 0.7490
# Epoch 59/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.4510 - accuracy: 0.7957 - val_loss: 0.5153 - val_accuracy: 0.7573
# Epoch 60/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4453 - accuracy: 0.8073 - val_loss: 0.5169 - val_accuracy: 0.7322
# Epoch 61/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4386 - accuracy: 0.8190 - val_loss: 0.5071 - val_accuracy: 0.7490
# Epoch 62/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4656 - accuracy: 0.7993 - val_loss: 0.5022 - val_accuracy: 0.7531
# Epoch 63/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4599 - accuracy: 0.7975 - val_loss: 0.5278 - val_accuracy: 0.7280
# Epoch 64/100
# 35/35 [==============================] - 3s 86ms/step - loss: 0.4522 - accuracy: 0.7984 - val_loss: 0.5010 - val_accuracy: 0.7490
# Epoch 65/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.4402 - accuracy: 0.8181 - val_loss: 0.4982 - val_accuracy: 0.7615
# Epoch 66/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.4428 - accuracy: 0.8136 - val_loss: 0.4986 - val_accuracy: 0.7657
# Epoch 67/100
# 35/35 [==============================] - 3s 88ms/step - loss: 0.4452 - accuracy: 0.8002 - val_loss: 0.5164 - val_accuracy: 0.7364
# Epoch 68/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4447 - accuracy: 0.8127 - val_loss: 0.4946 - val_accuracy: 0.7573
# Epoch 69/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4457 - accuracy: 0.8172 - val_loss: 0.5413 - val_accuracy: 0.7280
# Epoch 70/100
# 35/35 [==============================] - 3s 91ms/step - loss: 0.4441 - accuracy: 0.8002 - val_loss: 0.5039 - val_accuracy: 0.7657
# Epoch 71/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4423 - accuracy: 0.8065 - val_loss: 0.5120 - val_accuracy: 0.7448
# Epoch 72/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4436 - accuracy: 0.8082 - val_loss: 0.5061 - val_accuracy: 0.7406
# Epoch 73/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4350 - accuracy: 0.8091 - val_loss: 0.4904 - val_accuracy: 0.7573
# Epoch 74/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4395 - accuracy: 0.8065 - val_loss: 0.4914 - val_accuracy: 0.7657
# Epoch 75/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4362 - accuracy: 0.8145 - val_loss: 0.5290 - val_accuracy: 0.7741
# Epoch 76/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4426 - accuracy: 0.8002 - val_loss: 0.4904 - val_accuracy: 0.7741
# Epoch 77/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4210 - accuracy: 0.8190 - val_loss: 0.4956 - val_accuracy: 0.7490
# Epoch 78/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4267 - accuracy: 0.8190 - val_loss: 0.4886 - val_accuracy: 0.7699
# Epoch 79/100
# 35/35 [==============================] - 3s 91ms/step - loss: 0.4343 - accuracy: 0.8172 - val_loss: 0.4865 - val_accuracy: 0.7573
# Epoch 80/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4261 - accuracy: 0.8145 - val_loss: 0.4852 - val_accuracy: 0.7531
# Epoch 81/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4289 - accuracy: 0.8091 - val_loss: 0.4850 - val_accuracy: 0.7741
# Epoch 82/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4307 - accuracy: 0.8208 - val_loss: 0.4855 - val_accuracy: 0.7657
# Epoch 83/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4288 - accuracy: 0.8154 - val_loss: 0.5290 - val_accuracy: 0.7741
# Epoch 84/100
# 35/35 [==============================] - 3s 91ms/step - loss: 0.4179 - accuracy: 0.8199 - val_loss: 0.4877 - val_accuracy: 0.7490
# Epoch 85/100
# 35/35 [==============================] - 3s 91ms/step - loss: 0.4242 - accuracy: 0.8136 - val_loss: 0.4957 - val_accuracy: 0.7782
# Epoch 86/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4139 - accuracy: 0.8289 - val_loss: 0.4805 - val_accuracy: 0.7824
# Epoch 87/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4370 - accuracy: 0.8056 - val_loss: 0.5088 - val_accuracy: 0.7699
# Epoch 88/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.4219 - accuracy: 0.8172 - val_loss: 0.4823 - val_accuracy: 0.7573
# Epoch 89/100
# 35/35 [==============================] - 3s 87ms/step - loss: 0.4108 - accuracy: 0.8342 - val_loss: 0.4885 - val_accuracy: 0.7490
# Epoch 90/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4095 - accuracy: 0.8324 - val_loss: 0.4897 - val_accuracy: 0.7657
# Epoch 91/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4129 - accuracy: 0.8297 - val_loss: 0.4800 - val_accuracy: 0.7741
# Epoch 92/100
# 35/35 [==============================] - 3s 91ms/step - loss: 0.4137 - accuracy: 0.8145 - val_loss: 0.4784 - val_accuracy: 0.7741
# Epoch 93/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4250 - accuracy: 0.8199 - val_loss: 0.4777 - val_accuracy: 0.7782
# Epoch 94/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4109 - accuracy: 0.8342 - val_loss: 0.4752 - val_accuracy: 0.7782
# Epoch 95/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4026 - accuracy: 0.8324 - val_loss: 0.4789 - val_accuracy: 0.7531
# Epoch 96/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.3966 - accuracy: 0.8297 - val_loss: 0.4736 - val_accuracy: 0.7782
# Epoch 97/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4005 - accuracy: 0.8369 - val_loss: 0.4741 - val_accuracy: 0.7615
# Epoch 98/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4102 - accuracy: 0.8306 - val_loss: 0.4738 - val_accuracy: 0.7782
# Epoch 99/100
# 35/35 [==============================] - 3s 90ms/step - loss: 0.4088 - accuracy: 0.8387 - val_loss: 0.4976 - val_accuracy: 0.7531
# Epoch 100/100
# 35/35 [==============================] - 3s 89ms/step - loss: 0.4327 - accuracy: 0.8118 - val_loss: 0.4692 - val_accuracy: 0.7866

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 77ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       110
#            1       0.81      0.87      0.84       131
#
#     accuracy                           0.82       241
#    macro avg       0.82      0.81      0.81       241
# weighted avg       0.82      0.82      0.82       241

# %%
# model_saved = r'D:\My Code\Classification\models'
# model.save(os.path.join(model_saved, f'{dataset_code}_{model_name} (256X256).h5'))
