# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.applications import Xception
from keras.utils import Sequence
from keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

dataset_code = 'C'
model_name = 'Xception'
data_saved_dir = r'D:\My Code\Classification\pickle_data'
train_data_path = os.path.join(data_saved_dir, f'{dataset_code}_training.pkl')
train_images, train_labels = load_pickle(train_data_path)

val_data_path = os.path.join(data_saved_dir, 'validation_data.pkl')
val_images, val_labels = load_pickle(val_data_path)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

batch_size = 16
train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)

# %%
Xception_model = Xception(include_top=False, weights='imagenet', input_shape=(256, 256, 3))

model = Sequential()
model.add(Xception_model)

for layer in model.layers:
    layer.trainable = False

model.add(Flatten())
model.add(Dense(units=2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 8, 8, 2048)        20861480
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 2048)              268437504
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 289,301,033
# Trainable params: 268,439,553
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator)
# Out:
# Epoch 1/50
# 279/279 [==============================] - 29s 88ms/step - loss: 3.7526 - accuracy: 0.8510 - val_loss: 0.5839 - val_accuracy: 0.9079
# Epoch 2/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2574 - accuracy: 0.9364 - val_loss: 0.3507 - val_accuracy: 0.9247
# Epoch 3/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1395 - accuracy: 0.9615 - val_loss: 0.5156 - val_accuracy: 0.9163
# Epoch 4/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.0888 - accuracy: 0.9749 - val_loss: 0.6395 - val_accuracy: 0.9205
# Epoch 5/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.1013 - accuracy: 0.9731 - val_loss: 0.5447 - val_accuracy: 0.9163
# Epoch 6/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.1936 - accuracy: 0.9595 - val_loss: 0.5618 - val_accuracy: 0.8996
# Epoch 7/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.1634 - accuracy: 0.9633 - val_loss: 0.5011 - val_accuracy: 0.9331
# Epoch 8/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2042 - accuracy: 0.9662 - val_loss: 0.6725 - val_accuracy: 0.9372
# Epoch 9/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2741 - accuracy: 0.9586 - val_loss: 0.8811 - val_accuracy: 0.9247
# Epoch 10/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1465 - accuracy: 0.9707 - val_loss: 0.7839 - val_accuracy: 0.9331
# Epoch 11/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2069 - accuracy: 0.9662 - val_loss: 1.0524 - val_accuracy: 0.9247
# Epoch 12/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2400 - accuracy: 0.9691 - val_loss: 0.7555 - val_accuracy: 0.9247
# Epoch 13/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1660 - accuracy: 0.9738 - val_loss: 0.7510 - val_accuracy: 0.9372
# Epoch 14/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1224 - accuracy: 0.9812 - val_loss: 0.8304 - val_accuracy: 0.9121
# Epoch 15/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.1494 - accuracy: 0.9756 - val_loss: 0.9269 - val_accuracy: 0.9205
# Epoch 16/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1631 - accuracy: 0.9810 - val_loss: 0.9789 - val_accuracy: 0.9289
# Epoch 17/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1332 - accuracy: 0.9805 - val_loss: 0.6567 - val_accuracy: 0.9205
# Epoch 18/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.3382 - accuracy: 0.9677 - val_loss: 2.2858 - val_accuracy: 0.9121
# Epoch 19/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.4119 - accuracy: 0.9709 - val_loss: 2.6796 - val_accuracy: 0.9205
# Epoch 20/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2341 - accuracy: 0.9814 - val_loss: 1.8331 - val_accuracy: 0.9331
# Epoch 21/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1600 - accuracy: 0.9852 - val_loss: 1.5686 - val_accuracy: 0.9247
# Epoch 22/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.0994 - accuracy: 0.9881 - val_loss: 1.4412 - val_accuracy: 0.9456
# Epoch 23/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.0825 - accuracy: 0.9901 - val_loss: 1.4667 - val_accuracy: 0.9456
# Epoch 24/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2084 - accuracy: 0.9850 - val_loss: 2.4244 - val_accuracy: 0.9331
# Epoch 25/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2870 - accuracy: 0.9830 - val_loss: 2.3060 - val_accuracy: 0.9163
# Epoch 26/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.2452 - accuracy: 0.9832 - val_loss: 2.8602 - val_accuracy: 0.9121
# Epoch 27/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.1038 - accuracy: 0.9904 - val_loss: 2.2760 - val_accuracy: 0.9205
# Epoch 28/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1430 - accuracy: 0.9904 - val_loss: 2.0318 - val_accuracy: 0.9372
# Epoch 29/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1697 - accuracy: 0.9890 - val_loss: 2.6709 - val_accuracy: 0.9331
# Epoch 30/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1541 - accuracy: 0.9875 - val_loss: 2.2025 - val_accuracy: 0.9372
# Epoch 31/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1462 - accuracy: 0.9892 - val_loss: 3.5830 - val_accuracy: 0.9205
# Epoch 32/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1024 - accuracy: 0.9922 - val_loss: 3.0149 - val_accuracy: 0.9289
# Epoch 33/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1905 - accuracy: 0.9908 - val_loss: 2.7307 - val_accuracy: 0.9205
# Epoch 34/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.3464 - accuracy: 0.9870 - val_loss: 4.1203 - val_accuracy: 0.9331
# Epoch 35/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.3180 - accuracy: 0.9875 - val_loss: 4.4439 - val_accuracy: 0.9372
# Epoch 36/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2393 - accuracy: 0.9904 - val_loss: 4.9012 - val_accuracy: 0.9331
# Epoch 37/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1993 - accuracy: 0.9901 - val_loss: 5.2858 - val_accuracy: 0.9205
# Epoch 38/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1721 - accuracy: 0.9924 - val_loss: 4.6569 - val_accuracy: 0.9247
# Epoch 39/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.4103 - accuracy: 0.9895 - val_loss: 5.3190 - val_accuracy: 0.9289
# Epoch 40/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.5148 - accuracy: 0.9866 - val_loss: 7.6616 - val_accuracy: 0.9121
# Epoch 41/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1462 - accuracy: 0.9935 - val_loss: 5.3911 - val_accuracy: 0.9289
# Epoch 42/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1548 - accuracy: 0.9937 - val_loss: 5.6351 - val_accuracy: 0.9289
# Epoch 43/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.2416 - accuracy: 0.9922 - val_loss: 5.0012 - val_accuracy: 0.9289
# Epoch 44/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1383 - accuracy: 0.9935 - val_loss: 5.7223 - val_accuracy: 0.9331
# Epoch 45/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1699 - accuracy: 0.9944 - val_loss: 5.0186 - val_accuracy: 0.9205
# Epoch 46/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1012 - accuracy: 0.9948 - val_loss: 4.3650 - val_accuracy: 0.9331
# Epoch 47/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1226 - accuracy: 0.9953 - val_loss: 4.4148 - val_accuracy: 0.9247
# Epoch 48/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.1703 - accuracy: 0.9942 - val_loss: 4.5015 - val_accuracy: 0.9372
# Epoch 49/50
# 279/279 [==============================] - 23s 83ms/step - loss: 0.0520 - accuracy: 0.9971 - val_loss: 6.2939 - val_accuracy: 0.9079
# Epoch 50/50
# 279/279 [==============================] - 23s 82ms/step - loss: 0.2309 - accuracy: 0.9922 - val_loss: 4.2299 - val_accuracy: 0.9289

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.4, 1)
plt.show()

# %%
test_data_path = os.path.join(data_saved_dir, 'test_data.pkl')
test_images, test_labels = load_pickle(test_data_path)

predictions = model.predict(test_images)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 2s 138ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93       110
#            1       0.91      0.98      0.95       131
#
#     accuracy                           0.94       241
#    macro avg       0.95      0.94      0.94       241
# weighted avg       0.94      0.94      0.94       241

# %%
model_saved = r'D:\My Code\Classification\models'
model.save(os.path.join(model_saved, f'{dataset_code}_{model_name} (256X256).h5'))
